# %%
import pandas as pd
pd.options.display.max_rows = 1000

# %%
url = "https://www.reddit.com/r/tea/wiki/vendors/page_01/"
tables = pd.read_html(url)

# %%
len(tables)
# Out:
# 2

# %%
tables[0]
# Out:
#                 Vendor/Website Link  \
# 0                Adagio & Adagio UK
# 1                         Adore Tea
# 2    Andrews & Dunham Damn Fine Tea
# 3          ANGEL SPECIALTY PRODUCTS
# 4                          Anmo Cha
# ..                              ...
# 188                    Zen Tea Life
# 189                      Zerama Tea
# 190                           Zesta
# 191                     Zhi Herbals
# 192                         Zhi Tea
#
#                          Reddit User / Vendor Comments Shipping Origin  \
# 0    "Sells flavored and unflavored tea of all vari...        USA & UK
# 1    "Good variety, some lovely teas and I can't go...       Australia
# 2    "Unflavored Black tea blends so robust that'll...             USA
# 3    "Highest quality specialty teas and chai. Manu...             USA
# 4    "ANMO art/cha are specialized in Hongkong stor...         Germany
# ..                                                 ...             ...
# ...

# %%
tables[1]
# Out:
#               Tea              Temperature Minutes
# 0           Black             95°C / 205°F   3 - 5
# 1    Oolong/White             85°C / 185°F   3 - 4
# 2    Green/Yellow             80°C / 176°F   2 - 3
# 3  Herbal/Tisanes  100°C / 212°F (boiling)  5 - 15

# %%
ratings, useless_table = tables

# %%
ratings
# Out:
#                           Vendor/Website Link  \
# 0                          Adagio & Adagio UK
# 1                                   Adore Tea
# 2              Andrews & Dunham Damn Fine Tea
# 3                    ANGEL SPECIALTY PRODUCTS
# 4                                    Anmo Cha
# 5                                  Arbor Teas
# 6                                    Argo Tea
# 7                                  Art of Tea
# 8                            Bamboo Tea House
# 9                            Bana Tea Company
# 10                                    BANGtea
# 11                   Beautiful Taiwan Tea Co.
# 12                            BitterLeaf Teas
# 13                           Breakaawy Matcha
# 14                               Brooklyn Tea
# 15            C.C. Fine Tea (Formerly Smacha)
# 16                          Camellia Sinensis
# 17                         Cameron Tea Taiwan
# 18                               Capital Teas
# ...

# %%
curated_ratings = (
    ratings
    [ratings["Shipping Range"].str.contains("International", na=False)]
    .sort_values("2018 voting Rank1")
)

# %%
curated_ratings.iloc[0]
# Out:
# Vendor/Website Link                           Yunnan Sourcing & Yunnan Sourcing US
# Reddit User / Vendor Comments    "Fantastic range of teas from Yunnan province,...
# Shipping Origin                                                        China & USA
# Shipping Range                                                       International
# 2018 voting Rank1                                                              1.0
# Name: 184, dtype: object

# %%
curated_ratings.iloc[1]
# Out:
# Vendor/Website Link                                                      White2Tea
# Reddit User / Vendor Comments    "Sells a highly curated selection of self-pres...
# Shipping Origin                                                              China
# Shipping Range                                                       International
# 2018 voting Rank1                                                              2.0
# Name: 178, dtype: object

# %%
curated_ratings.iloc[2]
# Out:
# Vendor/Website Link                                              Crimson Lotus Tea
# Reddit User / Vendor Comments    "A small start-up devoted to selling self-pres...
# Shipping Origin                                                              China
# Shipping Range                                                       International
# 2018 voting Rank1                                                              3.0
# Name: 21, dtype: object

# %%
curated_ratings.iloc[3]
# Out:
# Vendor/Website Link                                                       What-Cha
# Reddit User / Vendor Comments    "UK-based shop with a large catalogue of quali...
# Shipping Origin                                                                 UK
# Shipping Range                                                       International
# 2018 voting Rank1                                                              4.0
# Name: 176, dtype: object

# %%
curated_ratings.iloc[4]
# Out:
# Vendor/Website Link                                                       Mei Leaf
# Reddit User / Vendor Comments    "Online vendor and teahouse sourcing a wide se...
# Shipping Origin                                                                 UK
# Shipping Range                                                       International
# 2018 voting Rank1                                                              5.0
# Name: 77, dtype: object

# %%
curated_ratings.iloc[5]
# Out:
# Vendor/Website Link                                                BitterLeaf Teas
# Reddit User / Vendor Comments    Based in Kunming, Yunnan, and specializes in P...
# Shipping Origin                                                              China
# Shipping Range                                                       International
# 2018 voting Rank1                                                              6.0
# Name: 12, dtype: object

# %%
curated_ratings.iloc[6]
# Out:
# Vendor/Website Link                                                         Yunomi
# Reddit User / Vendor Comments    "Japanese, Western-facing shop focused on Japa...
# Shipping Origin                                                              Japan
# Shipping Range                                                       International
# 2018 voting Rank1                                                              7.0
# Name: 185, dtype: object

# %%
curated_ratings.iloc[7]
# Out:
# Vendor/Website Link                                             Adagio & Adagio UK
# Reddit User / Vendor Comments    "Sells flavored and unflavored tea of all vari...
# Shipping Origin                                                           USA & UK
# Shipping Range                                                       International
# 2018 voting Rank1                                                              8.0
# Name: 0, dtype: object

# %%
curated_ratings.iloc[8]
# Out:
# Vendor/Website Link                                                       Teavivre
# Reddit User / Vendor Comments    "The customer facing branch of Thes and Teas, ...
# Shipping Origin                                                        China & USA
# Shipping Range                                                       International
# 2018 voting Rank1                                                              9.0
# Name: 156, dtype: object

# %%
curated_ratings.iloc[9]
# Out:
# Vendor/Website Link                                       Beautiful Taiwan Tea Co.
# Reddit User / Vendor Comments    "I would recommend them for good Taiwanese ool...
# Shipping Origin                                                                USA
# Shipping Range                                                       International
# 2018 voting Rank1                                                             10.0
# Name: 11, dtype: object

# %%
curated_ratings.iloc[-1]
# Out:
# Vendor/Website Link                                                     Zerama Tea
# Reddit User / Vendor Comments    "Zerama tea is a US based online shop for teas...
# Shipping Origin                                                                USA
# Shipping Range                                                       International
# 2018 voting Rank1                                                              NaN
# Name: 189, dtype: object

# %% [markdown]
# _______________________
