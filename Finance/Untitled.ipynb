# %%
import yfinance as yf
import pandas as pd
pd.set_option('display.max_rows', 200)

# %% [markdown]
# #### Warning: I edited yfinance's *base* as per this post to fix an issue
# https://github.com/ranaroussi/yfinance/pull/371/files/7e137357296a1df177399d26543e889848efc021

# %%
t = yf.Ticker("4001.SR")

# %%
dir(t)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_balancesheet',
#  '_base_url',
#  '_calendar',
#  '_cashflow',
#  '_download_options',
#  '_earnings',
#  '_expirations',
#  '_financials',
#  '_fundamentals',
#  '_get_fundamentals',
#  '_history',
#  '_info',
#  '_institutional_holders',
#  '_isin',
#  '_major_holders',
#  '_options2df',
#  '_recommendations',
#  '_scrape_url',
#  '_sustainability',
#  'actions',
#  'balance_sheet',
#  'balancesheet',
#  'calendar',
#  'cashflow',
#  'dividends',
#  'earnings',
#  'financials',
#  'get_actions',
#  'get_balance_sheet',
#  'get_balancesheet',
#  'get_calendar',
# ...

# %% [markdown]
# ## Hist

# %%
t.history(period="max")
# Out:
#               Open    High     Low   Close    Volume  Dividends  Stock Splits
# Date
# 2010-03-04    8.20    8.20    8.09    8.09  300148.0        0.0           0.0
# 2010-03-07    8.13    8.20    8.09    8.16  293744.0        0.0           0.0
# 2010-03-08    8.24    8.24    8.16    8.16  561004.0        0.0           0.0
# 2010-03-09    8.20    8.20    8.09    8.16  408404.0        0.0           0.0
# 2010-03-10    8.16    8.20    8.16    8.16  230664.0        0.0           0.0
# ...            ...     ...     ...     ...       ...        ...           ...
# 2020-08-06  119.20  119.80  119.00  119.20   56895.0        0.0           0.0
# 2020-08-09  119.00  120.00  118.60  119.00  102734.0        0.0           0.0
# 2020-08-10  118.20  120.00  118.00  120.00   84287.0        0.0           0.0
# 2020-08-11  120.00  120.00  119.20  120.00   84050.0        0.0           0.0
# 2020-08-12  120.00  120.00  119.00  119.20   64389.0        0.0           0.0
#
# [2495 rows x 7 columns]

# %% [markdown]
# ## Info

# %%
t.info
# Out:
# {'zip': '11531',
#  'sector': 'Consumer Cyclical',
# ...

# %%
import pymongo as pm
import json

# %%
client = pm.MongoClient("mongodb://localhost:27017/")
db = client["tadawul"]
companies = db["companies"]

# %%
# All relvant variables we're going to extract from each company
columns = ["city", "industry", "twoHundredDayAverage", "trailingAnnualDividendYield", "payoutRatio", "averageDailyVolume10Day", "fiftyDayAverage", "trailingAnnualDividendRate", "averageVolume10days", "dividendRate", "trailingPE", "averageVolume", "priceToSalesTrailing12Months", "fiftyTwoWeekHigh", "forwardPE", "fiveYearAvgDividendYield", "dividendYield", "symbol", "profitMargins", "52WeekChange", "forwardEps", "bookValue"]

# %%
# DataFrame of comapnies and their ID, Name and sector
# Source: https://www.mubasher.info/countries/sa/companies
# Date: 2020/8/12
html = '<body id="mi" ng-app="app" ng-controller="MainController" class="ar ng-scope" data-gr-c-s-loaded="true"><nav class="header__countries-menu mm-menu mm-offcanvas mm-top mm-front" id="countries-menu"><div class="mm-panel mm-opened mm-current" id="mm-8"><ul class="mm-listview mm-first mm-last">\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=ae&amp;url=/countries/sa/companies">الإمارات</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=bh&amp;url=/countries/sa/companies">البحرين</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=om&amp;url=/countries/sa/companies">عُمان</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=qa&amp;url=/countries/sa/companies">قطر</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=kw&amp;url=/countries/sa/companies">الكويت</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=eg&amp;url=/countries/sa/companies">مصر</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=jo&amp;url=/countries/sa/companies">الأردن</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=tn&amp;url=/countries/sa/companies">تونس</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=ma&amp;url=/countries/sa/companies">المغرب</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=ps&amp;url=/countries/sa/companies">فلسطين</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=iq&amp;url=/countries/sa/companies">العراق</a>\n        </li>\n      </ul></div></nav><nav class="header__main-menu mm-menu mm-border-full mm-effect-slide-menu mm-effect-zoom-panels mm-pageshadow mm-offcanvas mm-right mm-hasnavbar-top mm-hasnavbar" id="main-menu"><div class="mm-navbar mm-navbar-top mm-hasbtns"><a class="mm-prev mm-btn mm-hidden"></a><a class="mm-title"> </a><a class="mm-close mm-btn" href="#wrapper"></a></div><div class="mm-panel mm-opened mm-current" id="mm-0"><ul class="mm-listview mm-first mm-last">\n        <li id="markets">\n          <a class="mm-next mm-fullsubopen" href="#mm-1" data-target="#mm-1"></a><span href="javascript:;">الأسواق</span>\n          \n        </li>\n        <li id="news">\n          <a class="mm-next mm-fullsubopen" href="#mm-2" data-target="#mm-2"></a><span href="javascript:;">الأخبار</span>\n          \n        </li>\n        <li id="companies">\n          <a class="mm-next mm-fullsubopen" href="#mm-3" data-target="#mm-3"></a><span href="javascript:;">الشركات</span>\n          \n        </li>\n        <li id="funds">\n          <a class="mm-next mm-fullsubopen" href="#mm-4" data-target="#mm-4"></a><span href="javascript:;">صناديق الاستثمار</span>\n          \n        </li>\n        <li id="analysis-tool">\n          <a class="mm-next mm-fullsubopen" href="#mm-5" data-target="#mm-5"></a><span href="javascript:;">أدوات التحليل</span>\n          \n\n        </li>\n        <li id="islamic-economy">\n          <a href="/news/islamic-finance">الاقتصاد الإسلامي</a>\n        </li>\n        <!--<li class="global__hide-for-ltr" id="radio" th:if="${#locale.getLanguage() == \'ar\'}">\n          <span th:text="#{navigation.radio}">راديو مباشر</span>\n          <ul>\n            <li>\n              <a th:href="${@url.to(\'RPC#live\')}" th:text="#{navigation.radio.live}"/>\n            </li>\n            <li>\n              <a th:href="${@url.to(\'RPC#latestEpisodesPage\', countryCode)}">آخر الحلقات</a>\n            </li>\n            <li>\n              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تقارير-اقتصادية\'}">تقارير اقتصادية</a>\n            </li>\n            <li>\n              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تغطية-خاصة\'}">تغطية خاصة</a>\n            </li>\n            <li>\n              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'مقالات\'}">مقالات</a>\n            </li>\n            <li>\n              <a th:href="${@url.to(\'RPC#programs\')}" th:text="#{navigation.radio.programs}"/>\n            </li>\n            <li>\n              <a th:href="${@url.to(\'RPC#videoPrograms\')}" th:text="#{navigation.radio.videoPrograms}"/>\n            </li>\n            <li>\n              <a th:href="${@url.to(\'RPC#getExperts\')}">ضيوفنا</a>\n            </li>\n            <li>\n              <a th:href="${@url.to(\'RPC#getPresenters\')}">المذيعون</a>\n            </li>\n          </ul>\n        </li>-->\n        <li class="global__hide-for-ltr" id="video">\n          <a href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">مباشر TV</a>\n        </li>\n        \n        <li id="fixedincome">\n          <a class="mm-next mm-fullsubopen" href="#mm-6" data-target="#mm-6"></a><span>السندات</span>\n          \n        </li>\n        <li>\n          <a class="mm-next mm-fullsubopen" href="#mm-7" data-target="#mm-7"></a><span>شخصي</span>\n          \n        </li>\n        <li>\n          <a href="http://tawasul.mubasher.info/" target="_blank">تواصل</a>\n        </li>\n        <!-- <li>\n          <a th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank" th:text="#{components.header.decypha}" target="_blank">\n          </a>\n        </li> -->\n        <li>\n          <a ng-click="decypha(\'decypha\')">ديسيفا</a>\n        </li>\n\n        <!--Add according to MFP-187-->\n\n        <li>\n          <a href="https://contest.mubasher.info/#/home" target="_blank">المستثمر اﻷول</a>\n        </li>\n        <li>\n\n          <!--Integrating Mubasher Pulse-->\n\n        </li><li>\n        <style>\n\n          .pulse-logo2{\n            padding: 5px 5px 4px;\n            min-width: 82px;\n            min-height: 21px;\n            max-width: 27%;\n          }\n\n        </style>\n\n        <a target="_blank" href="https://pulse.mubasher.info">\n          <img class="pulse-logo2" src="../../../images/pulse-logo.png">\n        </a>\n        </li>\n        <li>\n\n\n        </li><li>\n          <a href="http://magazine.mubasher.info/" target="_blank">\n            مجلة مباشر\n          </a>\n        </li>\n\n        <li class="mm-divider"></li>\n        <li>\n          <a href="https://english.mubasher.info">ENGLISH</a>\n        </li>\n        <li>\n          \n        </li>\n        <li>\n          <a class="header__login__text" href="/account/login">دخول</a>\n          \n        </li>\n      </ul></div><div class="mm-panel mm-hidden" id="mm-1"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الأسواق</a></div><ul class="mm-listview mm-first mm-last">\n            <li>\n              <a href="/markets/TDWL">سوق الأسهم السعودي</a>\n            </li>\n            <li>\n              <a href="/markets/EGX">البورصة المصرية</a>\n            </li>\n            <li>\n              <a href="/markets/DFM">سوق دبي المالي</a>\n            </li>\n            <li>\n              <a href="/markets/ADX">سوق أبوظبي</a>\n            </li>\n            <li>\n              <a href="/markets/BB">بورصة البحرين</a>\n            </li>\n            <li>\n              <a href="/markets/QE">بورصة قطر</a>\n            </li>\n            <li>\n              <a href="/markets/MSM">سوق مسقط</a>\n            </li>\n            <li>\n              <a href="/markets/BK">سوق الكويت</a>\n            </li>\n            <li>\n              <a href="/markets/ASE">بورصة عمان</a>\n            </li>\n            <li>\n              <a href="/markets/CSE">سوق الدار البيضاء</a>\n            </li>\n            <li>\n              <a href="/markets/BDT">بورصة تونس</a>\n            </li>\n            <li>\n              <a href="/markets/PEX">سوق فلسطين</a>\n            </li>\n            <li>\n              <a href="/markets/ISX">سوق العراق</a>\n            </li>\n            <li>\n              <a href="/international-indices">مؤشرات الأسواق العالمية</a>\n            </li>\n            <li>\n              <a href="/markets/commodities-prices">أسعار المعادن والطاقة</a>\n            </li>\n            <li>\n              <a href="/countries/sa/currencies">أسعار العملات</a>\n            </li>\n          </ul></div><div class="mm-panel mm-hidden" id="mm-2"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الأخبار</a></div><ul class="mm-listview mm-first mm-last">\n            <!-- now -->\n            <li class="mm-divider">يحدث الآن</li>\n            <li>\n              <a href="/news/sa/now/top">أهم الأخبار</a>\n            </li>\n            <li>\n              <a href="/news/sa/now/exclusive">حصرياً مباشر</a>\n            </li>\n            <li>\n              <a href="/news/sa/now/latest">آخر الأخبار</a>\n            </li>\n            \n              <li>\n                <a href="/news/sa/now/announcements">إعلانات السوق</a>\n              </li>\n              \n            \n            <li class="global__hide-for-ltr">\n              <a href="/news/sa/now/popular">منتشر الآن</a>\n            </li>\n            <li>\n              <a href="/news/sa/now/trending/">الأكثر مشاركة</a>\n            </li>\n            <li>\n              <a href="/news/now/news-releases">بيانات صحفية</a>\n            </li>\n<!--            <li>\n              <a th:href="${@url.to(\'NPC#miscellaneousNews\', countryCode)}"\n                 th:text="#{navigation.news.now.misc}"/>\n            </li>-->\n            <!-- recommendations-->\n            <li class="mm-divider">نبض السوق</li>\n            <li>\n              <a href="/news/sa/pulse/stocks">أخبار الأسهم</a>\n            </li>\n            <li>\n              <a href="/news/sa/pulse/analysis">تحليلات إخبارية</a>\n            </li>\n            <li>\n              <a href="/news/sa/pulse/local">اقتصاد محلي</a>\n            </li>\n            <li>\n              <a href="/news/sa/pulse/recommendations">توصيات</a>\n            </li>\n            <li class="mm-divider">أخبار القطاعات</li>\n            <li>\n              <a href="/news/sa/category/banking">بنوك</a>\n            </li>\n            <li>\n              <a href="/news/sa/category/realEstate">عقارات</a>\n            </li>\n            <li class="mm-divider">أخبار الدول</li>\n            <li>\n              <a href="/news/eg/now/latest">مصر</a>\n            </li>\n            <li>\n              <a href="/news/sa/now/latest">السعودية</a>\n            </li>\n            <li>\n              <a href="/news/ae/now/latest">الإمارات</a>\n            </li>\n            <li>\n              <a href="/news/bh/now/latest">البحرين</a>\n            </li>\n            <li>\n              <a href="/news/qa/now/latest">قطر</a>\n            </li>\n            <li>\n              <a href="/news/om/now/latest">عمان</a>\n            </li>\n            <li>\n              <a href="/news/kw/now/latest">الكويت</a>\n            </li>\n            <li>\n              <a href="/news/jo/now/latest">الأردن</a>\n            </li>\n            <li>\n              <a href="/news/ma/now/latest">المغرب</a>\n            </li>\n            <li>\n              <a href="/news/tn/now/latest">تونس</a>\n            </li>\n            <li>\n              <a href="/news/ps/now/latest">فلسطين</a>\n            </li>\n            <li>\n              <a href="/news/iq/now/latest">العراق</a>\n            </li>\n\n            <!-- regions-->\n            <li class="mm-divider">أخبار إقليمية</li>\n            <li>\n              <a href="/news/regions/gulf">الخليج</a>\n            </li>\n            <li>\n              <a href="/news/regions/levant">الشام</a>\n            </li>\n            <li>\n              <a href="/news/regions/north-africa">شمال أفريقيا</a>\n            </li>\n            <li>\n              <a href="/news/regions/middle-east">الشرق الأوسط</a>\n            </li>\n\n            <!-- international -->\n            <li class="mm-divider">أخبار عالمية</li>\n            <li>\n              <a href="/news/international/global-economy">اقتصاد عالمى</a>\n            </li>\n            <li>\n              <a href="/news/international/goods-and-metals">أحداث عالمية</a>\n            </li>\n              <li>\n                <a href="/news/international/global-indices">مؤشرات عالمية</a>\n              </li>\n              <li>\n                <a href="/news/international/oil-and-energy">نفط ومعادن</a>\n              </li>\n              <li>\n                <a href="/news/international/currencies">عملات</a>\n              </li>\n              <li>\n                <a href="/news/international/global-reports">تقارير عالمية</a>\n              </li>\n          </ul></div><div class="mm-panel mm-hidden" id="mm-3"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الشركات</a></div><ul class="mm-listview mm-first mm-last">\n            <li>\n              <a href="/countries/sa/companies">الشركات المدرجة</a>\n            </li>\n            <li>\n              <a href="/countries/sa/events">مفكرة الشركات</a>\n            </li>\n            <li>\n              <a href="/countries/sa/stock-prices">أسعار الأسهم</a>\n            </li>\n            <li>\n              <a href="/countries/sa/earnings">إعلانات الأرباح</a>\n            </li>\n            <li>\n              <a href="/countries/sa/fair-values">القيم العادلة</a>\n            </li>\n            <li>\n              <a href="/countries/sa/corporate-action">الإجراءات</a>\n            </li>\n            \n            <li>\n              <a href="/countries/sa/major-shareholders">كبار الملاك</a>\n            </li>\n            <li>\n              <a href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>\n            </li>\n            <li class="mm-divider">الاكتتابات</li>\n            <li>\n              <a href="/countries/sa/ipos">قائمة الإكتتابات</a>\n            </li>\n            <li>\n              <a href="/ipo/list">بحث فى الاكتتابات</a>\n            </li>\n            <li>\n              <a href="/ipos/news">أخبار الاكتتابات</a>\n            </li>\n            <li>\n              <a href="/ipo/calendar">مفكرة الاكتتابات</a>\n            </li>\n          </ul></div><div class="mm-panel mm-hidden" id="mm-4"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">صناديق الاستثمار</a></div><ul class="mm-listview mm-first mm-last">\n            <li>\n              <a href="/countries/sa/funds">صناديق الاستثمار</a>\n            </li>\n            <li>\n              <a href="/countries/sa/funds-statistics">إحصائيات الصناديق</a>\n            </li>\n          </ul></div><div class="mm-panel mm-hidden" id="mm-5"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">أدوات التحليل</a></div><ul class="mm-listview mm-first mm-last">\n            \n              \n              <li>\n                <a href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>\n              </li>\n              <li>\n                <a href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>\n              </li>\n              <li>\n                <a href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>\n              </li>\n              <li>\n                <a href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>\n              </li>\n              <li>\n                <a href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>\n              </li>\n            \n\n            <li class="mm-divider">\n            </li>\n            <li>\n              <a href="/analysis-tools/performance-comparison">مقارنة الأداء</a>\n            </li>\n          </ul></div><div class="mm-panel mm-hidden" id="mm-6"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">السندات</a></div><ul class="mm-listview mm-first mm-last">\n            <li>\n              <a href="/fixedincome/bond/search" id="fixedIncomeBondScreener">بحث عن سندات</a>\n            </li>\n            <li>\n              <a href="/fixed-income/news" id="fixedIncomeNews">أخبار السندات وأذون الخزانة</a>\n            </li>\n            <li>\n              <a href="/fixedincome/calendar/searchForEvent" id="fixedIncomeCalendar">قائمة الأحداث</a>\n            </li>\n            <li>\n              <a href="/fixedincome/analytics/drawCurve" id="fixedIncomeAnalytics">تحليلات فنية</a>\n            </li>\n            <li>\n              <a href="/fixedincome/leagueTables/view" id="fixedIncomeLeagueTables">جداول الديون</a>\n            </li>\n            <li>\n              <a href="/fixedincome/research/search" id="fixedIncomeProspectus">تقارير</a>\n            </li>\n          </ul></div><div class="mm-panel mm-hidden" id="mm-7"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">شخصي</a></div><ul class="mm-listview mm-first mm-last">\n            <li>\n              <a href="/my/alerts">التنبيهات</a>\n            </li>\n            <li>\n              <a href="/my/watch-list">أسهمي</a>\n            </li>\n            <li>\n              <a href="/my/newsletters">النشرة البريدية</a>\n            </li>\n          </ul></div></nav>\n\n\n<div class="js-wrapper mm-page mm-slideout" id="wrapper">\n  <svg class="hidden" version="1.1" viewBox="0 0 0 0" xmlns="http://www.w3.org/2000/svg">\n  <defs>\n    <style>\n      .logo-white-path {\n        clip-rule: evenodd;\n        fill-rule: evenodd;\n        fill: white;\n        font-size: 46.6299px;\n        font-family: \'HelveticaNeue\';\n      }\n\n      .logo-path {\n        clip-rule: evenodd;\n        fill-rule: evenodd;\n        fill: #324651;\n        text-align: center;\n        font-size: 46.6299px;\n        font-family: \'HelveticaNeue\';\n      }\n    </style>\n    <g id="logo-white">\n      <path class="logo-white-path" d="M209.596 29.677c-6.25 0.016-11.243-4.937-11.261-11.188 c-0.018-6.191 5.027-11.29 11.194-11.29c6.182-0.004 11.3 5.1 11.3 11.226C220.852 24.6 215.8 29.7 209.6 29.7"></path>\n      <path class="logo-white-path" d="M228.308 37.976c6.231-0.01 11.3 5 11.3 11.2 c0.015 6.189-5.011 11.227-11.233 11.252c-6.213 0.025-11.246-4.99-11.271-11.209C217.063 43 222.1 38 228.3 38"></path>\n      <path class="logo-white-path" d="M350.278 190.471c-6.27-0.009-11.204-4.942-11.197-11.212 c0.013-6.26 4.968-11.18 11.248-11.176c6.242 0 11.3 5 11.2 11.224C361.555 185.5 356.5 190.5 350.3 190.5"></path>\n      <path class="logo-white-path" d="M186.161 37.976c6.26 0 11.2 5 11.2 11.2 c-0.01 6.241-4.993 11.239-11.209 11.226c-6.257-0.017-11.212-4.99-11.212-11.228C174.949 42.9 179.9 38 186.2 38"></path>\n      <path class="logo-white-path" d="M455.92 80.125c-21.212 0-38.405 17.191-38.405 38.4 c0 4.3 0.7 8.4 2 12.316l-48.126 0.003l13.9-27.74h-3.242c0 0-2.13 0.019-2.822 0.1 c-2.13 0.126-3.67 0.098-7.926 1.351c-3.949 1.159-7.026 2.719-9.881 4.503c-2.381 1.493-5.863 4.278-8.803 7.7 c-2.912 3.325-5.713 7.695-5.713 7.695l-3.294 6.464l-41.201 0.003L364.7 0l-76.514 49.172l25.429-0.036L260.64 156.919h193.847 c0 0 0.9 0 1.4 0.01c21.212 0 38.4-17.183 38.4-38.403C494.32 97.3 477.1 80.1 455.9 80.125z M455.92 133.3 c-7.998 0-14.48-6.479-14.48-14.47c0-7.998 6.482-14.476 14.48-14.476c7.996 0 14.5 6.5 14.5 14.5 C470.393 126.8 463.9 133.3 455.9 133.327z"></path>\n      <path class="logo-white-path" d="M269.61 81.427c0 0-1.617 0.013-2.842 0.09c-2.001 0.132-3.655 0.07-7.903 1.3 c-3.946 1.162-7.021 2.722-9.876 4.507c-2.378 1.488-5.868 4.279-8.813 7.662c-2.904 3.327-5.282 8.108-5.282 8.108l-14.116 27.7 h-16.391l19.092-39.485h-3.237c0 0-1.617 0.015-2.835 0.095c-2.012 0.13-3.665 0.068-7.905 1.3 c-3.957 1.161-7.034 2.717-9.892 4.502c-2.373 1.493-5.857 4.28-8.808 7.668c-2.899 3.321-5.282 8.104-5.282 8.104l-8.901 17.8 h-16.959l13.92-27.753h-3.245c0 0-2.141 0.019-2.822 0.057c-2.133 0.126-3.663 0.098-7.926 1.4 c-3.944 1.159-7.026 2.719-9.884 4.503c-2.378 1.493-5.857 4.28-8.808 7.669c-2.904 3.329-5.708 7.695-5.708 7.695l-3.291 6.5 l-52.558-0.005l14.007-27.748h-3.242c0 0-2.131 0.019-2.815 0.057c-2.136 0.126-3.678 0.098-7.934 1.4 c-3.944 1.159-7.021 2.719-9.877 4.503c-2.383 1.493-5.858 4.28-8.813 7.669c-2.906 3.329-5.114 7.843-5.114 7.843l-16.204 31.1 l0 0c0 0-3.136 6.731-7.038 11.469c-3.094 3.766-7.43 6.804-9.757 8.194c-2.313 1.384-7.141 3.645-11.872 4.5 C5.251 180.9 0 180.5 0 180.502s2.33 2.1 5 3.806c2.034 1.4 4.3 2.4 5.5 3 c2.481 1.1 4.3 1.7 6.9 2.253c2.531 0.6 4.8 0.8 4.8 0.763s1.621 0.2 3.2 0.169c0.707 0 1.62-0.024 2.848-0.09 c2.001-0.134 3.5 0 7.904-1.323c4.033-1.188 7.072-2.582 9.92-4.368c2.383-1.478 5.952-4.249 8.904-7.627 c2.907-3.337 5.296-8.019 5.296-8.019l6.043-12.125l169.4 0.009l12.816-26.07l24.302-49.431H269.61z"></path>\n      <path class="logo-white-path" d="M30.239 76.472V55.626H22.45v-2.789h18.735v2.789h-7.819v20.846H30.239z"></path>\n      <path class="logo-white-path" d="M44.296 76.472V52.836h4.71l5.592 16.735c0.518 1.6 0.9 2.7 1.1 3.499c0.269-0.861 0.687-2.123 1.258-3.789 l5.658-16.446h4.209v23.636h-3.015V56.689l-6.869 19.783h-2.822l-6.835-20.121v20.121H44.296z"></path>\n    </g>\n    <g id="logo">\n      <path class="logo-path" d="M209.596 29.677c-6.25 0.016-11.243-4.937-11.261-11.188 c-0.018-6.191 5.027-11.29 11.194-11.29c6.182-0.004 11.3 5.1 11.3 11.226C220.852 24.6 215.8 29.7 209.6 29.7"></path>\n      <path class="logo-path" d="M228.308 37.976c6.231-0.01 11.3 5 11.3 11.2 c0.015 6.189-5.011 11.227-11.233 11.252c-6.213 0.025-11.246-4.99-11.271-11.209C217.063 43 222.1 38 228.3 38"></path>\n      <path class="logo-path" d="M350.278 190.471c-6.27-0.009-11.204-4.942-11.197-11.212 c0.013-6.26 4.968-11.18 11.248-11.176c6.242 0 11.3 5 11.2 11.224C361.555 185.5 356.5 190.5 350.3 190.5"></path>\n      <path class="logo-path" d="M186.161 37.976c6.26 0 11.2 5 11.2 11.2 c-0.01 6.241-4.993 11.239-11.209 11.226c-6.257-0.017-11.212-4.99-11.212-11.228C174.949 42.9 179.9 38 186.2 38"></path>\n      <path class="logo-path" d="M455.92 80.125c-21.212 0-38.405 17.191-38.405 38.4 c0 4.3 0.7 8.4 2 12.316l-48.126 0.003l13.9-27.74h-3.242c0 0-2.13 0.019-2.822 0.1 c-2.13 0.126-3.67 0.098-7.926 1.351c-3.949 1.159-7.026 2.719-9.881 4.503c-2.381 1.493-5.863 4.278-8.803 7.7 c-2.912 3.325-5.713 7.695-5.713 7.695l-3.294 6.464l-41.201 0.003L364.7 0l-76.514 49.172l25.429-0.036L260.64 156.919h193.847 c0 0 0.9 0 1.4 0.01c21.212 0 38.4-17.183 38.4-38.403C494.32 97.3 477.1 80.1 455.9 80.125z M455.92 133.3 c-7.998 0-14.48-6.479-14.48-14.47c0-7.998 6.482-14.476 14.48-14.476c7.996 0 14.5 6.5 14.5 14.5 C470.393 126.8 463.9 133.3 455.9 133.327z"></path>\n      <path class="logo-path" d="M269.61 81.427c0 0-1.617 0.013-2.842 0.09c-2.001 0.132-3.655 0.07-7.903 1.3 c-3.946 1.162-7.021 2.722-9.876 4.507c-2.378 1.488-5.868 4.279-8.813 7.662c-2.904 3.327-5.282 8.108-5.282 8.108l-14.116 27.7 h-16.391l19.092-39.485h-3.237c0 0-1.617 0.015-2.835 0.095c-2.012 0.13-3.665 0.068-7.905 1.3 c-3.957 1.161-7.034 2.717-9.892 4.502c-2.373 1.493-5.857 4.28-8.808 7.668c-2.899 3.321-5.282 8.104-5.282 8.104l-8.901 17.8 h-16.959l13.92-27.753h-3.245c0 0-2.141 0.019-2.822 0.057c-2.133 0.126-3.663 0.098-7.926 1.4 c-3.944 1.159-7.026 2.719-9.884 4.503c-2.378 1.493-5.857 4.28-8.808 7.669c-2.904 3.329-5.708 7.695-5.708 7.695l-3.291 6.5 l-52.558-0.005l14.007-27.748h-3.242c0 0-2.131 0.019-2.815 0.057c-2.136 0.126-3.678 0.098-7.934 1.4 c-3.944 1.159-7.021 2.719-9.877 4.503c-2.383 1.493-5.858 4.28-8.813 7.669c-2.906 3.329-5.114 7.843-5.114 7.843l-16.204 31.1 l0 0c0 0-3.136 6.731-7.038 11.469c-3.094 3.766-7.43 6.804-9.757 8.194c-2.313 1.384-7.141 3.645-11.872 4.5 C5.251 180.9 0 180.5 0 180.502s2.33 2.1 5 3.806c2.034 1.4 4.3 2.4 5.5 3 c2.481 1.1 4.3 1.7 6.9 2.253c2.531 0.6 4.8 0.8 4.8 0.763s1.621 0.2 3.2 0.169c0.707 0 1.62-0.024 2.848-0.09 c2.001-0.134 3.5 0 7.904-1.323c4.033-1.188 7.072-2.582 9.92-4.368c2.383-1.478 5.952-4.249 8.904-7.627 c2.907-3.337 5.296-8.019 5.296-8.019l6.043-12.125l169.4 0.009l12.816-26.07l24.302-49.431H269.61z"></path>\n      <path class="logo-path" d="M30.239 76.472V55.626H22.45v-2.789h18.735v2.789h-7.819v20.846H30.239z"></path>\n      <path class="logo-path" d="M44.296 76.472V52.836h4.71l5.592 16.735c0.518 1.6 0.9 2.7 1.1 3.499c0.269-0.861 0.687-2.123 1.258-3.789 l5.658-16.446h4.209v23.636h-3.015V56.689l-6.869 19.783h-2.822l-6.835-20.121v20.121H44.296z"></path>\n    </g>\n    <g id="logo-white-en">\n      <defs>\n        <rect height="65.7" width="326.9" x="-55"></rect>\n      </defs>\n      <clipPath>\n        <use overflow="visible" xlink:href="#SVGID_1_"></use>\n      </clipPath>\n      <path class="logo-white-path" d="M41.694 20.162c-1.315 0-1.315 0.987-1.315 0.987l0.094 13.8 c0 0 0.6 8.648-8.178 8.648c0 0-8.364 0.093-8.364-8.082V21.29c0 0 0.234-1.174-1.27-1.174c-1.362 0-1.221 1.174-1.221 1.174V36 c0 0 0.2 10.1 10.9 10.104c10.386 0 10.669-9.675 10.669-10.433V21.243C42.964 21.2 43 20.2 41.7 20.2"></path>\n      <path class="logo-white-path" d="M20.915 21.431c0 0 0-0.799-0.799-1.127c-0.777-0.321-1.27 0.422-1.457 0.6 l-7.425 10.293c0 0-0.469 0.61-1.034-0.282l-8.13-10.292c0 0-0.517-0.611-1.128-0.423c-0.611 0.189-0.894 0.704-0.846 1.6 L0 44.74c0 0-0.046 1.4 1.3 1.363s1.316-1.222 1.316-1.222V25.144l7.002 9.023c0 0 1.1 1.5 2.209-0.188 c1.081-1.646 6.626-8.882 6.626-8.882v19.736c0 0-0.088 1.3 1.5 1.175c1.175-0.094 0.988-1.22 0.988-1.22V21.431z"></path>\n      <path class="logo-white-path" d="M168.546 43.734l-10.309-6.813c0 0 8.648-0.179 8.648-8.471 c0-8.294-8.531-8.118-8.531-8.118h-8.412c-2.107 0-1.953 1.6-1.953 1.6v22.69c0 0-0.038 1.5 1.1 1.5 c1.265 0 1.222-1.436 1.222-1.436V22.702h6.516c0.474 0 3.1 0 5.3 1.304c2.192 1.3 3.7 7.198-0.177 9.6 c-2.785 1.717-6.459 1.008-7.642 0.889c-1.185-0.12-1.306 0.414-1.483 1.186c-0.177 0.8 0.9 1.4 0.9 1.362l13.21 8.5 c0 0 1.4 1.2 2.1 0.18C169.967 44.4 168.5 43.7 168.5 43.7"></path>\n      <path class="logo-white-path" d="M95.522 19.596c-6.516-0.711-11.492 3.376-11.373 7.8 c0.117 4.4 3 5.7 8.1 6.634c5.096 0.9 7 1.7 7 1.658c2.665 1 2.5 4.3 1 5.9 c-1.423 1.601-4.148 2.558-5.766 2.616c-3.879 0.146-6.052-2.374-6.052-2.374c-0.492-0.407-0.683-1.486-1.69-1.25 c-1.347 0.316-0.296 1.836-0.296 1.836c2.311 3.2 7.2 3.6 7.2 3.554c5.45 0.7 8.648-3.139 8.648-3.139 c2.963-3.852 0.987-8.363-1.976-9.429c-3.17-1.142-6.139-1.234-10.05-2.065c-3.909-0.828-3.495-4.087-3.495-4.087 c0.059-2.37 2.252-5.271 7.643-5.332c5.392-0.059 8.5 3.4 8.5 3.436c1.304 1.4 2.1 0.5 2.133-0.12 c0.06-0.591-0.058-1.183-0.531-1.776C104.121 23.1 102 20.3 95.5 19.6"></path>\n      <path class="logo-white-path" d="M124.084 20.618c-1.126 0-1.185 1.067-1.185 1.067v15.166h-14.336V21.862 c0 0 0.296-1.42-1.305-1.362c-1.304 0.047-1.067 1.42-1.067 1.42v14.575h-0.889c0 0-1.303-0.06-1.303 1.2 c0 1.3 1.2 1.3 1.2 1.305h1.007v5.746c0 0 0 1.2 1.2 1.243c1.246 0 1.187-1.184 1.187-1.184v-5.984h14.1v6.103 c0 0-0.008 1.1 1.2 1.137c1.226 0 1.269-1.195 1.269-1.195V21.743C125.209 21.7 125.2 20.6 124.1 20.6"></path>\n      <path class="logo-white-path" d="M86.101 44.016c0 0-10.841-21.504-11.849-23.163c-1.007-1.66-2.072 0-2.072 0 l-8.047 15.604l-2.395 0.015c-0.888 0-0.982 0.633-0.982 1.284c0 1.1 1.1 0.9 1.1 0.929h1.067c0 0-2.447 4.637-2.726 5.3 c-0.355 0.889-0.416 1.5 0.5 1.955c1.008 0.5 1.659-0.77 1.659-0.77l3.436-6.399H80.71l2.903 5.9 c0 0 1 2 2.1 1.305C86.87 45.3 86.1 44 86.1 44 M66.965 36.374l5.984-12.026c0 0 0.296-0.475 0.6 0.1 c0.296 0.5 6 12 6 11.967H66.965z"></path>\n      <path class="logo-white-path" d="M58.314 34.283c0 0 3.87-1.954 3.87-6.575c0-4.622-4.563-7.199-8.294-7.199 h-6.517c0 0-1.512 0.2-1.512 1.744v10.479h-1.833c0 0-0.799-0.094-0.799 1.271c0 1.1 0.6 1.2 0.6 1.173h2.066v9.447 c0 0-0.046 1.5 1.5 1.48h7.213c0 0 6.016-0.165 6.016-6.837C60.57 35.9 58.3 34.3 58.3 34.3 M48.203 22.7 l6.338-0.005c1.718 0 5.1 1.7 5.1 5.451c0 4.443-5.095 4.501-5.095 4.501h-6.338V22.736z M53.557 43.831h-5.351v-8.748 l6.435-0.008c0.858 0 3.5 0.9 3.5 4.031C58.143 43.7 53.6 43.8 53.6 43.8"></path>\n      <path class="logo-white-path" d="M146.17 23.033c0 0 1.3 0.1 1.305-1.304c0-1.244-1.305-1.125-1.305-1.125 h-15.818c-2.251 0-2.012 1.717-2.012 1.717V36.54l-1.653 0.009c0 0-1.132 0.229-1.132 1.177c0 1.2 1.1 1.4 1.1 1.361h1.669 v4.917c0 2.5 1.7 2.1 1.7 2.073h15.818c0 0 0.9 0 0.889-1.185s-0.95-1.007-0.95-1.007h-14.798v-4.799h15.284 c0 0 0.937-0.177 0.937-1.361c0-1.186-1.125-1.246-1.125-1.246h-15.228V23.033H146.17z"></path>\n    </g>\n    <g id="logo-en">\n      <defs>\n        <rect height="65.7" width="326.9" x="-55"></rect>\n      </defs>\n      <clipPath>\n        <use overflow="visible" xlink:href="#SVGID_1_"></use>\n      </clipPath>\n      <path class="logo-path" d="M41.694 20.162c-1.315 0-1.315 0.987-1.315 0.987l0.094 13.8 c0 0 0.6 8.648-8.178 8.648c0 0-8.364 0.093-8.364-8.082V21.29c0 0 0.234-1.174-1.27-1.174c-1.362 0-1.221 1.174-1.221 1.174V36 c0 0 0.2 10.1 10.9 10.104c10.386 0 10.669-9.675 10.669-10.433V21.243C42.964 21.2 43 20.2 41.7 20.2"></path>\n      <path class="logo-path" d="M20.915 21.431c0 0 0-0.799-0.799-1.127c-0.777-0.321-1.27 0.422-1.457 0.6 l-7.425 10.293c0 0-0.469 0.61-1.034-0.282l-8.13-10.292c0 0-0.517-0.611-1.128-0.423c-0.611 0.189-0.894 0.704-0.846 1.6 L0 44.74c0 0-0.046 1.4 1.3 1.363s1.316-1.222 1.316-1.222V25.144l7.002 9.023c0 0 1.1 1.5 2.209-0.188 c1.081-1.646 6.626-8.882 6.626-8.882v19.736c0 0-0.088 1.3 1.5 1.175c1.175-0.094 0.988-1.22 0.988-1.22V21.431z"></path>\n      <path class="logo-path" d="M168.546 43.734l-10.309-6.813c0 0 8.648-0.179 8.648-8.471 c0-8.294-8.531-8.118-8.531-8.118h-8.412c-2.107 0-1.953 1.6-1.953 1.6v22.69c0 0-0.038 1.5 1.1 1.5 c1.265 0 1.222-1.436 1.222-1.436V22.702h6.516c0.474 0 3.1 0 5.3 1.304c2.192 1.3 3.7 7.198-0.177 9.6 c-2.785 1.717-6.459 1.008-7.642 0.889c-1.185-0.12-1.306 0.414-1.483 1.186c-0.177 0.8 0.9 1.4 0.9 1.362l13.21 8.5 c0 0 1.4 1.2 2.1 0.18C169.967 44.4 168.5 43.7 168.5 43.7"></path>\n      <path class="logo-path" d="M95.522 19.596c-6.516-0.711-11.492 3.376-11.373 7.8 c0.117 4.4 3 5.7 8.1 6.634c5.096 0.9 7 1.7 7 1.658c2.665 1 2.5 4.3 1 5.9 c-1.423 1.601-4.148 2.558-5.766 2.616c-3.879 0.146-6.052-2.374-6.052-2.374c-0.492-0.407-0.683-1.486-1.69-1.25 c-1.347 0.316-0.296 1.836-0.296 1.836c2.311 3.2 7.2 3.6 7.2 3.554c5.45 0.7 8.648-3.139 8.648-3.139 c2.963-3.852 0.987-8.363-1.976-9.429c-3.17-1.142-6.139-1.234-10.05-2.065c-3.909-0.828-3.495-4.087-3.495-4.087 c0.059-2.37 2.252-5.271 7.643-5.332c5.392-0.059 8.5 3.4 8.5 3.436c1.304 1.4 2.1 0.5 2.133-0.12 c0.06-0.591-0.058-1.183-0.531-1.776C104.121 23.1 102 20.3 95.5 19.6"></path>\n      <path class="logo-path" d="M124.084 20.618c-1.126 0-1.185 1.067-1.185 1.067v15.166h-14.336V21.862 c0 0 0.296-1.42-1.305-1.362c-1.304 0.047-1.067 1.42-1.067 1.42v14.575h-0.889c0 0-1.303-0.06-1.303 1.2 c0 1.3 1.2 1.3 1.2 1.305h1.007v5.746c0 0 0 1.2 1.2 1.243c1.246 0 1.187-1.184 1.187-1.184v-5.984h14.1v6.103 c0 0-0.008 1.1 1.2 1.137c1.226 0 1.269-1.195 1.269-1.195V21.743C125.209 21.7 125.2 20.6 124.1 20.6"></path>\n      <path class="logo-path" d="M86.101 44.016c0 0-10.841-21.504-11.849-23.163c-1.007-1.66-2.072 0-2.072 0 l-8.047 15.604l-2.395 0.015c-0.888 0-0.982 0.633-0.982 1.284c0 1.1 1.1 0.9 1.1 0.929h1.067c0 0-2.447 4.637-2.726 5.3 c-0.355 0.889-0.416 1.5 0.5 1.955c1.008 0.5 1.659-0.77 1.659-0.77l3.436-6.399H80.71l2.903 5.9 c0 0 1 2 2.1 1.305C86.87 45.3 86.1 44 86.1 44 M66.965 36.374l5.984-12.026c0 0 0.296-0.475 0.6 0.1 c0.296 0.5 6 12 6 11.967H66.965z"></path>\n      <path class="logo-path" d="M58.314 34.283c0 0 3.87-1.954 3.87-6.575c0-4.622-4.563-7.199-8.294-7.199 h-6.517c0 0-1.512 0.2-1.512 1.744v10.479h-1.833c0 0-0.799-0.094-0.799 1.271c0 1.1 0.6 1.2 0.6 1.173h2.066v9.447 c0 0-0.046 1.5 1.5 1.48h7.213c0 0 6.016-0.165 6.016-6.837C60.57 35.9 58.3 34.3 58.3 34.3 M48.203 22.7 l6.338-0.005c1.718 0 5.1 1.7 5.1 5.451c0 4.443-5.095 4.501-5.095 4.501h-6.338V22.736z M53.557 43.831h-5.351v-8.748 l6.435-0.008c0.858 0 3.5 0.9 3.5 4.031C58.143 43.7 53.6 43.8 53.6 43.8"></path>\n      <path class="logo-path" d="M146.17 23.033c0 0 1.3 0.1 1.305-1.304c0-1.244-1.305-1.125-1.305-1.125 h-15.818c-2.251 0-2.012 1.717-2.012 1.717V36.54l-1.653 0.009c0 0-1.132 0.229-1.132 1.177c0 1.2 1.1 1.4 1.1 1.361h1.669 v4.917c0 2.5 1.7 2.1 1.7 2.073h15.818c0 0 0.9 0 0.889-1.185s-0.95-1.007-0.95-1.007h-14.798v-4.799h15.284 c0 0 0.937-0.177 0.937-1.361c0-1.186-1.125-1.246-1.125-1.246h-15.228V23.033H146.17z"></path>\n    </g>\n  </defs>\n</svg>\n  <!--<script type="text/javascript" xmlns:th="http://www.thymeleaf.org" th:fragment="body">-->\n  <!--(function () {-->\n    <!--var em = document.createElement(\'script\');-->\n    <!--em.type = \'text/javascript\';-->\n    <!--em.async = true;-->\n    <!--em.src =-->\n      <!--(\'https:\' == document.location.protocol ? \'https://me-ssl\' : \'http://me-cdn\') + \'.effectivemeasure.net/em.js\';-->\n    <!--var s = document.getElementsByTagName(\'script\')[0];-->\n    <!--s.parentNode.insertBefore(em, s);-->\n  <!--}());-->\n<!--</script>-->\n\n\n  <div class="">\n\n    <header class="header">\n      <!-- DESKTOP ADS BLOCK -->\n\n      <!-- DESKTOP ADS BLOCK -->\n      <!-- MOBILE ADS BLOCK -->\n      \n\n      \n      <!-- MOBILE ADS BLOCK -->\n      <div class="header__top-for-mobile">\n        <div class="top-bar__triggers">\n          <a class="main-menu-trigger fa fa-bars fa-2x" href="#main-menu" style="float: right;"></a>\n          <!-- Logo -->\n          <div class="header__logo header-logo-margins" onclick="window.location.href=\'/countries/sa\'">\n            \n  <svg viewBox="0 0 494.387 190.555">\n    <use xlink:href="#logo-white"></use>\n  </svg>\n  \n\n          </div>\n          <a class="countries-menu-trigger header-country-margins" href="#countries-menu">\n            <span>السعودية</span>\n            <span class="fa fa-caret-down fa-4x"></span>\n          </a>\n          <!-- ngRepeat: image in images --><img ng-repeat="image in images" src="/assets/ui/images/mobile-logo-G20.png" class="ng-scope"><!-- end ngRepeat: image in images --><img ng-repeat="image in images" src="/assets/ui/images/mobile-logo-vision.png" class="ng-scope"><!-- end ngRepeat: image in images -->\n          <div class="header__left-side left-search-icon">\n            <a class="search-trigger js-search-trigger fa fa-search fa-2x" href="javascript:;" style="float: left;">\n            </a>\n          </div>\n        </div>\n        <!-- Search -->\n        <div class="search js-search" id="search">\n          <i class="fa fa-search fa-2x search__icon"></i>\n          <angucomplete-alt id="autocomplete__companies" input-class="search__input" minlength="1" ng-controller="AutocompleteController" pause="400" placeholder="اكتب كلمة البحث أو رمز الشركة" selected-object="selectItem" text-no-results="عفواً, لم يتم العثور على أي نتائج" text-searching="جارٍ البحث..." title-field="label" remote-url="/api/1/companySearch?query=" class="ng-scope ng-isolate-scope"><div class="angucomplete-holder" ng-class="{\'angucomplete-dropdown-visible\': showDropdown}">  <input id="autocomplete__companies_value" ng-model="searchStr" ng-disabled="disableInput" type="" placeholder="اكتب كلمة البحث أو رمز الشركة" maxlength="524288" ng-focus="onFocusHandler()" class="search__input ng-valid-maxlength" ng-blur="hideResults($event)" autocapitalize="off" autocorrect="off" autocomplete="off" ng-change="inputChangeHandler(searchStr)">  <div id="autocomplete__companies_dropdown" class="angucomplete-dropdown ng-hide" ng-show="showDropdown"><div class="angucomplete-searching ng-hide" ng-show="searching"><div class="spinner"><div class="dot1"></div><div class="dot2"></div></div></div>    <div class="angucomplete-searching ng-binding" ng-show="!searching &amp;&amp; (!results || results.length == 0)" ng-bind="textNoResults">عفواً, لم يتم العثور على أي نتائج</div>    <!-- ngRepeat: result in results -->  </div></div></angucomplete-alt>\n        </div>\n      </div>\n      <div class="header-desktop mi-show-for-large-up">\n        <div class="header__top-for-desktop">\n          <div class="header__top-for-desktop-row">\n            <a class="header__other-site" href="http://tawasul.mubasher.info/" target="_blank">\n              <i class="fa fa-caret-right fa-2x"></i>\n              تواصل\n            </a>\n            <a class="header__other-site" href="http://magazine.mubasher.info/" target="_blank">\n              <i class="fa fa-caret-right fa-2x"></i>\n              مجلة مباشر\n            </a>\n            <a class="header__other-site" href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">\n              <i class="fa fa-play-circle"></i>\n              <div style="direction: ltr; display: inline-block;">TV مباشر</div>\n            </a>\n            \n            <a class="header__other-site" href="/contact">\n              <i class="fa fa-envelope"></i>\n              اتصل بنا\n            </a>\n            <a class="header__other-site" href="/advertise">\n              <i class="fa fa-envelope"></i>\n              اعلن معنا\n            </a>\n            <!-- <a th:if="${#locale.getLanguage() == \'ar\'}" class="header__login-button" style="background: #458D37 !important;" th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank"\n                th:text="#{components.header.decypha}">ديسيفا</a>\n            <a th:if="${#locale.getLanguage() == \'en\'}" class="header__login-button" style="background: #458D37 !important; font-family: Roboto,sans-serif !important;" th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank"\n                th:text="#{components.header.decypha}">ديسيفا</a> -->\n\n            <!-- Page Content Buttons -->\n            <a class="header__login-button" ng-click="decypha(\'decypha\')" style="background: #458D37 !important; font-family: Roboto,sans-serif !important;">ديسيفا</a>\n            <!-- Page Content Button -->\n\n            <!--Add according to MFP-187-->\n            <a class="header__login-button" style="background: #00c2d6 !important;" target="_blank" href="https://contest.mubasher.info/#/home">المستثمر اﻷول</a>\n            \n\n            <style>\n\n              /*.pulse-logo{*/\n              /*display: inline-block;*/\n              /*width: 252px;*/\n              /*height: 100%;*/\n              /*background: #212121 url(../images/pulse-logo.png) no-repeat center 2px;*/\n              /*padding: 10px 50px 29px;*/\n              /*text-align: center;*/\n              /*color: black;*/\n              /*text-decoration: none;*/\n              /*margin-top: -6px;*/\n\n              /*}*/\n\n              .pulse-logo2{\n                padding: 5px 5px 4px;\n                min-width: 82px;\n                min-height: 21px;\n                max-width: 27%;\n              }\n\n            </style>\n\n            <a target="_blank" href="https://pulse.mubasher.info">\n              <img class="pulse-logo2" src="../../../images/pulse-logo.png">\n            </a>\n\n\n            <span class="header__spacer">\n              &nbsp;\n            </span>\n\n            <a class="header__social-link" target="_blank" href="https://twitter.com/mubasher"><i class="fa fa-twitter fa-lg"></i></a>\n            <a class="header__social-link" href="https://www.facebook.com/Mubasher.Info"><i class="fa fa-facebook fa-lg"></i></a>\n            <a class="header__social-link" href="https://www.youtube.com/channel/UC7hnxb7gD4nKZdZk3ZlZCYg">\n              <i class="fa fa-youtube fa-lg"></i>\n            </a>\n            <a class="header__social-link" href="https://www.linkedin.com/company/1477149">\n              <i class="fa fa-linkedin fa-lg"></i>\n            </a>\n            <a class="header__social-link" href="/news/rss"><i class="fa fa-rss fa-lg"></i></a>\n            <a class="header__social-link" href="https://play.google.com/store/apps/details?id=net.mis.mubasherinfo">\n              <i class="fa fa-android fa-lg"></i>\n            </a>\n            <a class="header__social-link" href="https://itunes.apple.com/app/imubasher/id494539772?mt=8">\n              <i class="fa fa-apple fa-lg"></i>\n            </a>\n\n            <a class="header__login-button" href="/account/login">\n              دخول\n              <i class="fa fa-user fa-lg"></i>\n            </a>\n            \n            \n            <a class="header__language" href="https://english.mubasher.info">\n              <span>ENGLISH</span>\n            </a>\n          </div>\n        </div>\n        <div class="header__columns">\n          <div class="header__column1">\n            <!-- Logo -->\n            <div class="header__logo-wrapper">\n              <div class="header__logo" onclick="window.location.href=\'/countries/sa\'">\n                \n  <svg viewBox="0 0 494.387 190.555">\n    <use xlink:href="#logo"></use>\n  </svg>\n  \n\n              </div>\n\n              <div class="countries-menu-trigger">\n                <a href="javascript:;" id="mi-js-countries-menu-trigger">\n                  <span>السعودية</span>\n                  <span class="fa fa-caret-down"></span>\n                </a>\n                <nav class="header__countries-menu--desktop mi-js-countries-menu-desktop" style="">\n                  <ul>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=ae&amp;url=/countries/sa/companies">الإمارات</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=bh&amp;url=/countries/sa/companies">البحرين</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=om&amp;url=/countries/sa/companies">عُمان</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=qa&amp;url=/countries/sa/companies">قطر</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=kw&amp;url=/countries/sa/companies">الكويت</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=eg&amp;url=/countries/sa/companies">مصر</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=jo&amp;url=/countries/sa/companies">الأردن</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=tn&amp;url=/countries/sa/companies">تونس</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=ma&amp;url=/countries/sa/companies">المغرب</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=ps&amp;url=/countries/sa/companies">فلسطين</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=iq&amp;url=/countries/sa/companies">العراق</a>\n                    </li>\n                  </ul>\n                </nav>\n              </div>\n            </div>\n            <!--Market Status -->\n            <div class="header__market-status">\n              <div class="header__market-status-column">\n                <div class="header__market-status-row">\n                  <a class="header__market-name" href="/markets/TDWL">TDWL</a>\n                  <span class="header__market-status--close">مغلق</span>\n                </div>\n                \n              </div>\n              <span class="header__market-time">12 أغسطس 04:32 م</span>\n            </div>\n          </div>\n\n          <div class="header__column1 banner-logo-desktop" ng-class="{\'banner-desktop-en\':(getLanguage == \'en\')}">\n            <!-- Logo -->\n            <div class="header__logo-wrapper">\n              <!-- ngRepeat: image in images --><div class="header__logo ng-scope" ng-repeat="image in images">\n                  <div class="tooltip tooltipstered"><img src="/assets/ui/images/logo-G20.png">\n                    <span class="tooltiptext ng-binding" ng-class="{\'tooltip-desktop-en\':(getLanguage == \'en\')}" style="left: 95%">مجموعة العشرين 2020</span>\n                  </div>\n              </div><!-- end ngRepeat: image in images --><div class="header__logo ng-scope" ng-repeat="image in images">\n                  <div class="tooltip tooltipstered"><img src="/assets/ui/images/logo-vision.png">\n                    <span class="tooltiptext ng-binding" ng-class="{\'tooltip-desktop-en\':(getLanguage == \'en\')}" style="left: 95%">رؤية المملكة العربية السعودية 2030</span>\n                  </div>\n              </div><!-- end ngRepeat: image in images -->\n            </div>\n          </div>\n\n<!--          <div class="header__column2">\n\n             &lt;!&ndash;<div th:replace="components/ads/news/dfp/desktop/LB2"/>&ndash;&gt;\n\n            &lt;!&ndash;=====to display default leaderboard ad-slot [728,90] ======&ndash;&gt;\n            <div th:if="${isHomePage}">\n              <div th:replace="components/ads/home/leaderboard"/>\n            </div>\n            <div th:unless="${isHomePage}">\n              <div>\n                <iframe id="leaderboard-ros-001" style="width: 736px; height: 108px;" class="ad-iframe" src="/ads/LB2"></iframe>\n              </div>\n            </div>\n\n\n            </div>-->\n\n           <!--======= billboard 790x250 ============ -->\n        </div>\n\n        <nav class="header__navigation mi-js-desktop-menu-container">\n          <ul class="dl-menu mi-show-for-large-up mi-js-desktop-menu" style="position: static; top: auto;">\n            <li class="dl-menu__menu-item dl-menu__menu-item--iconic-item">\n              <a href="/countries/sa">\n                <i class="fa fa-home fa-2x"></i>\n              </a>\n            </li>\n            <li class="dl-menu__menu-item" id="markets">\n              <a href="javascript:;">الأسواق</a>\n              <div class="mi-js-submenu">\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/markets/TDWL">سوق الأسهم السعودي</a>\n                    </li>\n                    <li>\n                      <a href="/markets/EGX">البورصة المصرية</a>\n                    </li>\n                    <li>\n                      <a href="/markets/DFM">سوق دبي المالي</a>\n                    </li>\n                    <li>\n                      <a href="/markets/ADX">سوق أبوظبي</a>\n                    </li>\n                    <li>\n                      <a href="/markets/BB">بورصة البحرين</a>\n                    </li>\n                  </ul>\n                </div>\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/markets/QE">بورصة قطر</a>\n                    </li>\n                    <li>\n                      <a href="/markets/MSM">سوق مسقط</a>\n                    </li>\n                    <li>\n                      <a href="/markets/BK">سوق الكويت</a>\n                    </li>\n                    <li>\n                      <a href="/markets/ASE">بورصة عمان</a>\n                    </li>\n                  </ul>\n                </div>\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/markets/CSE">سوق الدار البيضاء</a>\n                    </li>\n                    <li>\n                      <a href="/markets/BDT">بورصة تونس</a>\n                    </li>\n                    <li>\n                      <a href="/markets/PEX">سوق فلسطين</a>\n                    </li>\n                    <li>\n                      <a href="/markets/ISX">سوق العراق</a>\n                    </li>\n                  </ul>\n                </div>\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/international-indices">مؤشرات الأسواق العالمية</a>\n                    </li>\n                    <li>\n                      <a href="/markets/commodities-prices">أسعار المعادن والطاقة</a>\n                    </li>\n                    <li>\n                      <a href="/countries/sa/currencies">أسعار العملات</a>\n                    </li>\n                    <!--<li>\n                      <a th:href="${@url.to(\'RMPC#regionalMap\')}"\n                         th:text="#{navigation.markets.regional-map}"/>\n                    </li>-->\n                  </ul>\n                </div>\n              </div>\n            </li>\n            <li class="dl-menu__menu-item" id="news">\n              <a href="javascript:;">الأخبار</a>\n              <div class="mi-js-submenu">\n                <ul class="dl-submenu">\n                  <li>\n                    <a href="javascript:;">يحدث الآن</a>\n                    <div class="nav-column">\n                      <h3>يحدث الآن</h3>\n                      <ul class="dl-submenu">\n                        <li>\n                          <a href="/news/sa/now/top">أهم الأخبار</a>\n                        </li>\n                        <li>\n                          <a href="/news/sa/now/exclusive">حصرياً مباشر</a>\n                        </li>\n                        <li>\n                          <a href="/news/sa/now/latest">آخر الأخبار</a>\n                        </li>\n                        \n                          <li>\n                            <a href="/news/sa/now/announcements">إعلانات السوق</a>\n                          </li>\n                          \n                        \n                        <li class="global__hide-for-ltr">\n                          <a href="/news/sa/now/popular">منتشر الآن</a>\n                        </li>\n                        <li>\n                          <a href="/news/sa/now/trending/">الأكثر مشاركة</a>\n                        </li>\n                        <li>\n                          <a href="/news/now/news-releases">بيانات صحفية</a>\n                        </li>\n                        <li>\n                          <a href="/news/international/misc">أخبار منوعة</a>\n                        </li>\n                      </ul>\n                    </div>\n                  </li>\n                  <li>\n                    <a href="javascript:;">نبض السوق</a>\n                    <div class="nav-column">\n                      <h3>نبض السوق</h3>\n                      <ul class="dl-submenu">\n                        <li>\n                          <a href="/news/sa/pulse/stocks">أخبار الأسهم</a>\n                        </li>\n                        <li>\n                          <a href="/news/sa/pulse/analysis">تحليلات إخبارية</a>\n                        </li>\n                        <li>\n                          <a href="/news/sa/pulse/local">اقتصاد محلي</a>\n                        </li>\n                        <li>\n                          <a href="/news/sa/pulse/recommendations">توصيات</a>\n                        </li>\n                      </ul>\n                      <h3>أخبار القطاعات</h3>\n                      <ul class="dl-submenu">\n                        <li>\n                          <a href="/news/sa/category/banking">بنوك</a>\n                        </li><li>\n                          <a href="/news/sa/category/realEstate">عقارات</a>\n                        </li>\n                      </ul>\n                    </div>\n                  </li>\n                  <li>\n                    <a href="javascript:;">أخبار الدول</a>\n                    <div class="nav-column">\n                      <h3>أخبار الدول</h3>\n                      <ul class="dl-submenu">\n                        <li>\n                          <a href="/news/eg/now/latest">مصر</a>\n                        </li>\n                        <li>\n                          <a href="/news/sa/now/latest">السعودية</a>\n                        </li>\n                        <li>\n                          <a href="/news/ae/now/latest">الإمارات</a>\n                        </li>\n                        <li>\n                          <a href="/news/bh/now/latest">البحرين</a>\n                        </li>\n                        <li>\n                          <a href="/news/qa/now/latest">قطر</a>\n                        </li>\n                        <li>\n                          <a href="/news/om/now/latest">عمان</a>\n                        </li>\n                      </ul>\n                    </div>\n                  </li>\n                  <li>\n                    <a href="javascript:;">أخبار الدول</a>\n                    <div class="nav-column">\n                      <h3 class="invisible">أخبار الدول</h3>\n                      <ul class="dl-submenu">\n                        <li>\n                          <a href="/news/kw/now/latest">الكويت</a>\n                        </li>\n                        <li>\n                          <a href="/news/jo/now/latest">الأردن</a>\n                        </li>\n                        <li>\n                          <a href="/news/ma/now/latest">المغرب</a>\n                        </li>\n                        <li>\n                          <a href="/news/tn/now/latest">تونس</a>\n                        </li>\n                        <li>\n                          <a href="/news/ps/now/latest">فلسطين</a>\n                        </li>\n                        <li>\n                          <a href="/news/iq/now/latest">العراق</a>\n                        </li>\n                      </ul>\n                    </div>\n                  </li>\n                  <li>\n                    <a href="javascript:;">أخبار إقليمية</a>\n                    <div class="nav-column">\n                      <h3>أخبار إقليمية</h3>\n                      <ul class="dl-submenu">\n                        <li>\n                          <a href="/news/regions/gulf">الخليج</a>\n                        </li>\n                        <li>\n                          <a href="/news/regions/levant">الشام</a>\n                        </li>\n                        <li>\n                          <a href="/news/regions/north-africa">شمال أفريقيا</a>\n                        </li>\n                        <li>\n                          <a href="/news/regions/middle-east">الشرق الأوسط</a>\n                        </li>\n                      </ul>\n                    </div>\n                  </li>\n\n\n                  <li>\n                    <a href="javascript:;">أخبار عالمية</a>\n                    <div class="nav-column">\n                      <h3>أخبار عالمية</h3>\n                      <ul class="dl-submenu">\n                        <li>\n                          <a href="/news/international/global-economy">اقتصاد عالمى</a>\n                        </li>\n                        <li>\n                          <a href="/news/international/goods-and-metals">أحداث عالمية</a>\n                        </li>\n                        <li>\n                          <a href="/news/international/global-indices">مؤشرات عالمية</a>\n                        </li>\n                        <li>\n                          <a href="/news/international/oil-and-energy">نفط ومعادن</a>\n                        </li>\n                        <li>\n                          <a href="/news/international/currencies">عملات</a>\n                        </li>\n                        <li>\n                          <a href="/news/international/global-reports">تقارير عالمية</a>\n                        </li>\n                      </ul>\n                    </div>\n                  </li>\n                </ul>\n              </div>\n            </li>\n            <li class="dl-menu__menu-item" id="companies">\n              <a href="javascript:;">الشركات</a>\n              <div class="mi-js-submenu">\n                <div class="nav-column">\n                  <h3 class="invisible">.</h3>\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/countries/sa/companies">الشركات المدرجة</a>\n                    </li>\n                    <li>\n                      <a href="/countries/sa/events">مفكرة الشركات</a>\n                    </li>\n                    <li>\n                      <a href="/countries/sa/stock-prices">أسعار الأسهم</a>\n                    </li>\n                    <li>\n                      <a href="/countries/sa/fair-values">القيم العادلة</a>\n                    </li>\n                  </ul>\n                </div>\n                <div class="nav-column">\n                  <h3 class="invisible">.</h3>\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/countries/sa/earnings">إعلانات الأرباح</a>\n                    </li>\n                    <li>\n                      <a href="/countries/sa/corporate-action">الإجراءات</a>\n                    </li>\n                    \n                    <li>\n                      <a href="/countries/sa/major-shareholders">كبار الملاك</a>\n                    </li>\n                    <li>\n                      <a href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>\n                    </li>\n                  </ul>\n                </div>\n                <div class="nav-column">\n                  <h3>الاكتتابات</h3>\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/countries/sa/ipos">قائمة الإكتتابات</a>\n                    </li>\n                    <li>\n                      <a href="/ipo/list">بحث فى الاكتتابات</a>\n                    </li>\n                    <li>\n                      <a href="/ipos/news">أخبار الاكتتابات</a>\n                    </li>\n                    <li>\n                      <a href="/ipo/calendar">مفكرة الاكتتابات</a>\n                    </li>\n                  </ul>\n                </div>\n              </div>\n            </li>\n            <li class="dl-menu__menu-item" id="funds">\n              <a href="javascript:;">صناديق الاستثمار</a>\n              <div class="mi-js-submenu">\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/countries/sa/funds">صناديق الاستثمار</a>\n                    </li>\n                  </ul>\n                </div>\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/countries/sa/funds-statistics">إحصائيات الصناديق</a>\n                    </li>\n                  </ul>\n                </div>\n              </div>\n            </li>\n            <li class="dl-menu__menu-item" id="analysis-tools">\n              <a href="javascript:;">أدوات التحليل</a>\n              <!-- If current country has one market only -->\n              <div class="mi-js-submenu">\n                \n                  <div class="nav-column">\n                    <ul class="dl-submenu">\n                      <li>\n                        <a href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>\n                      </li>\n                      <li>\n                        <a href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>\n                      </li>\n                      <li>\n                        <a href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>\n                      </li>\n                    </ul>\n                  </div>\n                  <div class="nav-column">\n                    <ul class="dl-submenu">\n                      <li>\n                        <a href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>\n                      </li>\n                      <li>\n                        <a href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>\n                      </li>\n                      <li>\n                        <a href="/analysis-tools/performance-comparison">مقارنة الأداء</a>\n                      </li>\n                    </ul>\n                  </div>\n                \n\n                \n              </div>\n            </li>\n            <li class="dl-menu__menu-item" id="islamic-economy">\n              <a href="/news/islamic-finance">الاقتصاد الإسلامي</a>\n            </li>\n            <!--<li id="radio"\n                class="dl-menu__menu-item global__hide-for-ltr"\n                id="radio"\n                th:if="${#locale.getLanguage() == \'ar\'}">\n              <a href="javascript:;" th:text="#{navigation.radio}"/>\n              <div class="mi-js-submenu">\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a th:href="${@url.to(\'RPC#live\')}" th:text="#{navigation.radio.live}"/>\n                    </li>\n                    <li>\n                      <a th:href="${@url.to(\'RPC#latestEpisodesPage\', countryCode)}">آخر الحلقات</a>\n                    </li>\n                    <li>\n                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تقارير-اقتصادية\'}">تقارير\n                        اقتصادية</a>\n                    </li>\n                    <li>\n                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تغطية-خاصة\'}">تغطية خاصة</a>\n                    </li>\n                    <li>\n                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'مقالات\'}">مقالات</a>\n                    </li>\n                  </ul>\n                </div>\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a th:href="${@url.to(\'RPC#programs\')}" th:text="#{navigation.radio.programs}"/>\n                    </li>\n                    <li>\n                      <a th:href="${@url.to(\'RPC#videoPrograms\')}" th:text="#{navigation.radio.videoPrograms}"/>\n                    </li>\n                    <li>\n                      <a th:href="${@url.to(\'RPC#getExperts\')}">ضيوفنا</a>\n                    </li>\n                    <li>\n                      <a th:href="${@url.to(\'RPC#getPresenters\')}">المذيعون</a>\n                    </li>\n                  </ul>\n                </div>\n              </div>\n            </li>-->\n            <li class="dl-menu__menu-item global__hide-for-ltr" id="video">\n              <a href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">مباشر TV</a>\n            </li>\n            \n            <li class="dl-menu__menu-item" id="fixedincome">\n              <a href="javascript:;">السندات</a>\n              <div class="mi-js-submenu">\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/fixedincome/bond/search" id="fixedIncomeBondScreener">بحث عن سندات</a>\n                    </li>\n                    <li>\n                      <a href="/fixed-income/news" id="fixedIncomeNews">أخبار السندات وأذون الخزانة</a>\n                    </li>\n                    <li>\n                      <a href="/fixedincome/calendar/searchForEvent" id="fixedIncomeCalendar">قائمة الأحداث</a>\n                    </li>\n                  </ul>\n                </div>\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/fixedincome/analytics/drawCurve" id="fixedIncomeAnalytics">تحليلات فنية</a>\n                    </li>\n                    <li>\n                      <a href="/fixedincome/leagueTables/view" id="fixedIncomeLeagueTables">جداول الديون</a>\n                    </li>\n                    <li>\n                      <a href="/fixedincome/research/search" id="fixedIncomeProspectus">تقارير</a>\n                    </li>\n                  </ul>\n                </div>\n              </div>\n            </li>\n            <li class="dl-menu__menu-item" id="personal">\n              <a href="javascript:;">شخصي</a>\n              <div class="mi-js-submenu">\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/my/alerts">التنبيهات</a>\n                    </li>\n                    <li>\n                      <a href="/my/watch-list">أسهمي</a>\n                    </li>\n                    <li>\n                      <a href="/my/newsletters">النشرة البريدية</a>\n                    </li>\n                  </ul>\n                </div>\n              </div>\n            </li>\n            <li class="dl-menu__menu-item dl-menu__menu-item--iconic-item">\n              <a class="js-search-trigger" href="javascript:;">\n                <i class="fa fa-search fa-2x"></i>\n              </a>\n            </li>\n          </ul>\n          <!-- Search -->\n          <div class="search js-search js-desktop-search" id="search" style="position: absolute; top: 0px;">\n            <angucomplete-alt id="autocomplete__companies" input-class="search__input" minlength="1" ng-controller="AutocompleteController" pause="400" selected-object="selectItem" text-no-results="عفواً, لم يتم العثور على أي نتائج" text-searching="جارٍ البحث..." title-field="label" remote-url="/api/1/companySearch?query=" placeholder="اكتب كلمة البحث أو رمز الشركة" class="ng-scope ng-isolate-scope"><div class="angucomplete-holder" ng-class="{\'angucomplete-dropdown-visible\': showDropdown}">  <input id="autocomplete__companies_value" ng-model="searchStr" ng-disabled="disableInput" type="" placeholder="اكتب كلمة البحث أو رمز الشركة" maxlength="524288" ng-focus="onFocusHandler()" class="search__input ng-valid-maxlength" ng-blur="hideResults($event)" autocapitalize="off" autocorrect="off" autocomplete="off" ng-change="inputChangeHandler(searchStr)">  <div id="autocomplete__companies_dropdown" class="angucomplete-dropdown ng-hide" ng-show="showDropdown"><div class="angucomplete-searching ng-hide" ng-show="searching"><div class="spinner"><div class="dot1"></div><div class="dot2"></div></div></div>    <div class="angucomplete-searching ng-binding" ng-show="!searching &amp;&amp; (!results || results.length == 0)" ng-bind="textNoResults">عفواً, لم يتم العثور على أي نتائج</div>    <!-- ngRepeat: result in results -->  </div></div></angucomplete-alt>\n            <i class="fa fa-search fa-2x"></i>\n          </div>\n        </nav>\n      </div>\n    </header>\n\n    <div id="Leaderboard">\n    </div>\n\n    <div></div>\n\n    <div class="mi-content">\n      <div>\n  <!--<div th:replace="components/ads/internal/mobile-banner" />-->\n\n  <main class="mi-main-content">\n    \n  <h1 class="mi-section__title">الشركات المدرجة</h1>\n\n  <div class="mi-table-container ng-scope" ng-controller="PagedTableController as table" country="sa" src="/api/1/listed-companies">\n    <div class="global__table-container md-whiteframe-z1 ng-isolate-scope" st-init="" st-pipe="fetch" st-table="table.data">\n      <span class="global__no-results ng-hide" ng-show="table.rows.length == 0 &amp;&amp; table.loaded">عفواّ, لم نعثر على أى نتائج</span>\n      <table class="mi-table" ng-hide="!table.loaded || table.rows.length == 0" style="">\n\n        <thead class="mi-table__thead">\n          <tr class="mi-table__thead-tr">\n            <th st-ratio="20" style="width: 20%;">الشركة</th>\n            <th>السهم</th>\n            <th class="mi-hide-for-small">القطاع</th>\n            \n            <th>آخر سعر</th>\n            <th>نسبة التغيير</th>\n            <th class="mi-hide-for-small">آخر تحديث</th>\n          </tr>\n        </thead>\n        <tbody class="mi-table__tbody" ng-hide="table.reloading">\n          <!-- ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/1090/profile" class="ng-binding" href="/markets/TDWL/stocks/1090/profile">سامبا</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/1090" class="ng-binding" href="/markets/TDWL/stocks/1090">1090</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">البنوك</td>\n            \n            <td class="number ng-binding">26.1</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              1.56%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/1050/profile" class="ng-binding" href="/markets/TDWL/stocks/1050/profile">السعودي الفرنسي</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/1050" class="ng-binding" href="/markets/TDWL/stocks/1050">1050</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">البنوك</td>\n            \n            <td class="number ng-binding">31.5</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              3.11%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/1020/profile" class="ng-binding" href="/markets/TDWL/stocks/1020/profile">الجزيرة</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/1020" class="ng-binding" href="/markets/TDWL/stocks/1020">1020</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">البنوك</td>\n            \n            <td class="number ng-binding">12.1</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              0.33%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/1010/profile" class="ng-binding" href="/markets/TDWL/stocks/1010/profile">الرياض</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/1010" class="ng-binding" href="/markets/TDWL/stocks/1010">1010</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">البنوك</td>\n            \n            <td class="number ng-binding">17.06</td>\n            <td class="number ng-binding" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              0.00%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/1060/profile" class="ng-binding" href="/markets/TDWL/stocks/1060/profile">ساب</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/1060" class="ng-binding" href="/markets/TDWL/stocks/1060">1060</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">البنوك</td>\n            \n            <td class="number ng-binding">23.98</td>\n            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              -0.08%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/1080/profile" class="ng-binding" href="/markets/TDWL/stocks/1080/profile">العربي</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/1080" class="ng-binding" href="/markets/TDWL/stocks/1080">1080</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">البنوك</td>\n            \n            <td class="number ng-binding">19.32</td>\n            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              -0.41%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/1120/profile" class="ng-binding" href="/markets/TDWL/stocks/1120/profile">الراجحي</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/1120" class="ng-binding" href="/markets/TDWL/stocks/1120">1120</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">البنوك</td>\n            \n            <td class="number ng-binding">62.5</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              0.97%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2190/profile" class="ng-binding" href="/markets/TDWL/stocks/2190/profile">سيسكو</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2190" class="ng-binding" href="/markets/TDWL/stocks/2190">2190</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">النقل</td>\n            \n            <td class="number ng-binding">22.64</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              1.71%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2030/profile" class="ng-binding" href="/markets/TDWL/stocks/2030/profile">المصافي</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2030" class="ng-binding" href="/markets/TDWL/stocks/2030">2030</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">الطاقة</td>\n            \n            <td class="number ng-binding">46.8</td>\n            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              -1.27%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2150/profile" class="ng-binding" href="/markets/TDWL/stocks/2150/profile">زجاج</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2150" class="ng-binding" href="/markets/TDWL/stocks/2150">2150</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>\n            \n            <td class="number ng-binding">24.34</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              9.94%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/6010/profile" class="ng-binding" href="/markets/TDWL/stocks/6010/profile">نادك</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/6010" class="ng-binding" href="/markets/TDWL/stocks/6010">6010</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">إنتاج الأغذية</td>\n            \n            <td class="number ng-binding">31.35</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              0.64%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/6020/profile" class="ng-binding" href="/markets/TDWL/stocks/6020/profile">جاكو</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/6020" class="ng-binding" href="/markets/TDWL/stocks/6020">6020</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">إنتاج الأغذية</td>\n            \n            <td class="number ng-binding">15.3</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              1.19%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/6040/profile" class="ng-binding" href="/markets/TDWL/stocks/6040/profile">تبوك الزراعية</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/6040" class="ng-binding" href="/markets/TDWL/stocks/6040">6040</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">إنتاج الأغذية</td>\n            \n            <td class="number ng-binding">22.24</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              4.91%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4010/profile" class="ng-binding" href="/markets/TDWL/stocks/4010/profile">دور</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4010" class="ng-binding" href="/markets/TDWL/stocks/4010">4010</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">الخدمات الإستهلاكية</td>\n            \n            <td class="number ng-binding">26.8</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              1.90%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2160/profile" class="ng-binding" href="/markets/TDWL/stocks/2160/profile">أميانتيت</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2160" class="ng-binding" href="/markets/TDWL/stocks/2160">2160</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">السلع الرأسمالية</td>\n            \n            <td class="number ng-binding">11.52</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              0.52%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/3010/profile" class="ng-binding" href="/markets/TDWL/stocks/3010/profile">أسمنت العربية</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/3010" class="ng-binding" href="/markets/TDWL/stocks/3010">3010</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>\n            \n            <td class="number ng-binding">29.4</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              0.34%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/3020/profile" class="ng-binding" href="/markets/TDWL/stocks/3020/profile">أسمنت اليمامة</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/3020" class="ng-binding" href="/markets/TDWL/stocks/3020">3020</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>\n            \n            <td class="number ng-binding">24.16</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              0.25%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2170/profile" class="ng-binding" href="/markets/TDWL/stocks/2170/profile">اللجين</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2170" class="ng-binding" href="/markets/TDWL/stocks/2170">2170</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>\n            \n            <td class="number ng-binding">26.7</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              0.38%\n            </td>\n            <td class="mi-hide-for-small ng-binding">29 أبريل 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/3030/profile" class="ng-binding" href="/markets/TDWL/stocks/3030/profile">أسمنت السعودية</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/3030" class="ng-binding" href="/markets/TDWL/stocks/3030">3030</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>\n            \n            <td class="number ng-binding">56.6</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              0.18%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/3040/profile" class="ng-binding" href="/markets/TDWL/stocks/3040/profile">أسمنت القصيم</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/3040" class="ng-binding" href="/markets/TDWL/stocks/3040">3040</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>\n            \n            <td class="number ng-binding">66.2</td>\n            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              -0.90%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index -->\n        </tbody>\n      </table>\n      <div ng-show="table.searcing" class="ng-hide">\n        <span class="global__loading">جارى التصفية, يرجى الإنتظار ...</span>\n        <div>\n    <div class="sk-spinner sk-spinner-wave">\n        <div class="sk-rect1"></div>\n        <div class="sk-rect2"></div>\n        <div class="sk-rect3"></div>\n        <div class="sk-rect4"></div>\n        <div class="sk-rect5"></div>\n    </div>\n</div>\n      </div>\n      <div ng-hide="table.loaded" class="ng-hide" style="">\n        <div>\n    <div class="sk-spinner sk-spinner-wave">\n        <div class="sk-rect1"></div>\n        <div class="sk-rect2"></div>\n        <div class="sk-rect3"></div>\n        <div class="sk-rect4"></div>\n        <div class="sk-rect5"></div>\n    </div>\n</div>\n      </div>\n      <div st-items-by-page="20" st-pagination="" st-template="/assets/ui/ngt/components/pagination/pagination.ng.html" class="ng-isolate-scope"><!-- ngIf: pages.length >= 2 --><div class="pagination ng-scope" ng-if="pages.length >= 2">\n    <nav role="navigation" aria-label="Pagination">\n        <ul class="cd-pagination no-space" role="menubar" aria-label="Pagination">\n            <!-- ngIf: currentPage > 1 -->\n            <!-- ngIf: currentPage > 1 -->\n            <!-- ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope current">\n                <a ng-click="selectPage(page)" class="ng-binding">1</a>\n            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">\n                <a ng-click="selectPage(page)" class="ng-binding">2</a>\n            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">\n                <a ng-click="selectPage(page)" class="ng-binding">3</a>\n            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">\n                <a ng-click="selectPage(page)" class="ng-binding">4</a>\n            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">\n                <a ng-click="selectPage(page)" class="ng-binding">5</a>\n            </li><!-- end ngRepeat: page in pages -->\n            <!-- ngIf: currentPage < numPages --><li class="cd-pagination__button ng-scope" ng-if="currentPage < numPages">\n                <a ng-click="selectPage(currentPage+1)" href="" class="ng-binding">\n                  التالي\n                    <i class="fa fa-angle-left fa-lg"></i>\n                </a>\n            </li><!-- end ngIf: currentPage < numPages -->\n            <!-- ngIf: currentPage < numPages --><li ng-if="currentPage < numPages" class="ng-scope">\n                <a ng-click="selectPage(numPages)">\n                    <i class="fa fa-angle-double-left  fa-lg"></i>\n                </a>\n            </li><!-- end ngIf: currentPage < numPages -->\n        </ul>\n    </nav>\n</div><!-- end ngIf: pages.length >= 2 -->\n</div>\n    </div>\n  </div>\n\n  \n\n  <!-- Speakol Widget - Removal IB-51 -->\n  <!-- <div th:replace="components/ads/common/speakol-one"/> -->\n\n\n\n\n\n  </main>\n  <aside class="mi-sidebar mi-show-for-large-up">\n    <!-- Radio component doesn\'t exist in English version -->\n\n    <!---->\n\n  <!--  <div th:unless="${device.isMobile()}">\n      <div>\n        <iframe onload="adjustIframeSize(this);" class="ad-iframe" src="/ads/side-bar"></iframe>\n      </div>\n      <script>\n        function adjustIframeSize(self) {\n          var index = 0;\n          var interval = setInterval( function(){\n            if (index < 3) {\n              self.style.height=self.contentDocument.body.scrollHeight +10 + \'px\';self.style.width=\'310px\';\n              index = index + 1;\n            } else {\n              clearInterval(interval)\n            }\n          }, 1);\n\n        }\n\n\n      </script>\n    </div>-->\n    <div>\n\n    <div class="mi-popular-news news-sidebar-mub md-whiteframe-z1 ng-scope" ng-controller="PopularNewsController as popular">\n    <h2 class="global__h2--collapsed">الأخبار الأكثر</h2>\n    <v-tabs active="tabs.active" class="vTabs--secondary ng-isolate-scope" control="tabs">\n      <!-- ngRepeat: page in popular.pages --><v-tab ng-bind="page.title" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope is-active" role="tab" aria-selected="true" tabindex="0">قراءة</v-tab><!-- end ngRepeat: page in popular.pages --><v-tab ng-bind="page.title" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope" role="tab" aria-selected="false" tabindex="-1">مشاركة</v-tab><!-- end ngRepeat: page in popular.pages -->\n    </v-tabs>\n\n    <v-pages active="tabs.active" class="vPages--default ng-isolate-scope" control="tabs" ng-swipe-left="tabs.next()" ng-swipe-right="tabs.previous()">\n      <!-- ngRepeat: page in popular.pages --><v-page ng-bind-html="page.content | unsafe" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope is-active" role="tabpanel">\n    \n    \n<!--      <th:block>\n        <div th:remove="tag" th:if="${i.index == 1}">\n          <div th:replace="components/ads/internal/native" ></div>\n          <div th:replace="components/ads/internal/mobile-native" ></div>\n        </div>\n      </th:block>-->\n      <div class="mi-home-media-block">\n        <a class="mi-home-media-block__image" href="/news/3680410/%D9%87%D9%8A%D8%A6%D8%A9-%D8%A7%D9%84%D9%86%D9%82%D9%84-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%B5%D8%B1%D9%81-%D8%AF%D8%B9%D9%85-%D8%A7%D9%84%D8%A3%D9%81%D8%B1%D8%A7%D8%AF-%D8%A7%D9%84%D8%B9%D8%A7%D9%85%D9%84%D9%8A%D9%86-%D9%81%D9%8A-%D9%86%D8%B4%D8%A7%D8%B7-%D8%AA%D9%88%D8%AC%D9%8A%D9%87-%D8%A7%D9%84%D9%85%D8%B1%D9%83%D8%A8%D8%A7%D8%AA-%D9%82%D8%B1%D9%8A%D8%A8%D8%A7-/">\n          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="فرع تابع لهيئة العامة للنقل السعودية" src="https://static.mubasher.info/File.Story_Image/3e19073c5aca3db54ef2c06eb4bf5ea6/144.jpg">\n        </a>\n        <div class="mi-home-media-block__content">\n          <a class="mi-home-media-block__title" href="/news/3680410/%D9%87%D9%8A%D8%A6%D8%A9-%D8%A7%D9%84%D9%86%D9%82%D9%84-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%B5%D8%B1%D9%81-%D8%AF%D8%B9%D9%85-%D8%A7%D9%84%D8%A3%D9%81%D8%B1%D8%A7%D8%AF-%D8%A7%D9%84%D8%B9%D8%A7%D9%85%D9%84%D9%8A%D9%86-%D9%81%D9%8A-%D9%86%D8%B4%D8%A7%D8%B7-%D8%AA%D9%88%D8%AC%D9%8A%D9%87-%D8%A7%D9%84%D9%85%D8%B1%D9%83%D8%A8%D8%A7%D8%AA-%D9%82%D8%B1%D9%8A%D8%A8%D8%A7-/">هيئة النقل السعودية: صرف دعم الأفراد العاملين في نشاط توجيه المركبات قريباً</a>\n        </div>\n        \n      </div>\n    \n    \n<!--      <th:block>\n        <div th:remove="tag" th:if="${i.index == 1}">\n          <div th:replace="components/ads/internal/native" ></div>\n          <div th:replace="components/ads/internal/mobile-native" ></div>\n        </div>\n      </th:block>-->\n      <div class="mi-home-media-block">\n        <a class="mi-home-media-block__image" href="/news/3680099/%D8%A7%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D8%B5%D8%AF%D8%B1-%D9%82%D8%B1%D8%A7%D8%B1%D8%A7-%D8%A8%D8%B4%D8%A3%D9%86-%D8%A7%D9%84%D9%85%D8%A8%D8%AA%D8%B9%D8%AB%D9%8A%D9%86/">\n          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="وزير التعليم السعودي، حمد بن محمد آل الشيخ، أرشيفية" src="https://static.mubasher.info/File.Story_Image/9e9e9919f67b43d61c15c7fd734289d3/144.jpg">\n        </a>\n        <div class="mi-home-media-block__content">\n          <a class="mi-home-media-block__title" href="/news/3680099/%D8%A7%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D8%B5%D8%AF%D8%B1-%D9%82%D8%B1%D8%A7%D8%B1%D8%A7-%D8%A8%D8%B4%D8%A3%D9%86-%D8%A7%D9%84%D9%85%D8%A8%D8%AA%D8%B9%D8%AB%D9%8A%D9%86/">التعليم السعودية تصدر قراراً بشأن المبتعثين</a>\n        </div>\n        \n      </div>\n    \n    \n<!--      <th:block>\n        <div th:remove="tag" th:if="${i.index == 1}">\n          <div th:replace="components/ads/internal/native" ></div>\n          <div th:replace="components/ads/internal/mobile-native" ></div>\n        </div>\n      </th:block>-->\n      <div class="mi-home-media-block">\n        <a class="mi-home-media-block__image" href="/news/3680101/%D9%85%D8%AD%D8%AF%D8%AB-%D8%A7%D9%84%D8%B0%D9%87%D8%A8-%D9%8A%D8%AA%D9%87%D8%A7%D9%88%D9%89-93-%D8%AF%D9%88%D9%84%D8%A7%D8%B1%D8%A7-%D8%B9%D9%86%D8%AF-%D8%A7%D9%84%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D9%85%D8%B9-%D9%85%D9%83%D8%A7%D8%B3%D8%A8-%D8%A7%D9%84%D8%A3%D8%B3%D9%87%D9%85/">\n          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/caeadbca5bf2481c2d38f04625e51f00/144.jpg">\n        </a>\n        <div class="mi-home-media-block__content">\n          <a class="mi-home-media-block__title" href="/news/3680101/%D9%85%D8%AD%D8%AF%D8%AB-%D8%A7%D9%84%D8%B0%D9%87%D8%A8-%D9%8A%D8%AA%D9%87%D8%A7%D9%88%D9%89-93-%D8%AF%D9%88%D9%84%D8%A7%D8%B1%D8%A7-%D8%B9%D9%86%D8%AF-%D8%A7%D9%84%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D9%85%D8%B9-%D9%85%D9%83%D8%A7%D8%B3%D8%A8-%D8%A7%D9%84%D8%A3%D8%B3%D9%87%D9%85/">محدث.. الذهب يتهاوى 93 دولاراً عند التسوية مع مكاسب الأسهم</a>\n        </div>\n        \n      </div>\n    \n    \n<!--      <th:block>\n        <div th:remove="tag" th:if="${i.index == 1}">\n          <div th:replace="components/ads/internal/native" ></div>\n          <div th:replace="components/ads/internal/mobile-native" ></div>\n        </div>\n      </th:block>-->\n      <div class="mi-home-media-block">\n        <a class="mi-home-media-block__image" href="/news/3679355/%D8%A7%D9%84%D9%84%D9%8A%D8%B1%D8%A9-%D8%A7%D9%84%D8%AA%D8%B1%D9%83%D9%8A%D8%A9-%D8%AA%D9%87%D8%A8%D8%B7-%D8%A5%D9%84%D9%89-%D9%85%D8%B3%D8%AA%D9%88%D9%89-%D8%AA%D8%A7%D8%B1%D9%8A%D8%AE%D9%8A-%D8%AC%D8%AF%D9%8A%D8%AF/">\n          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/1242bfad1995396ce3f6470a3d5584c2/144.jpg">\n        </a>\n        <div class="mi-home-media-block__content">\n          <a class="mi-home-media-block__title" href="/news/3679355/%D8%A7%D9%84%D9%84%D9%8A%D8%B1%D8%A9-%D8%A7%D9%84%D8%AA%D8%B1%D9%83%D9%8A%D8%A9-%D8%AA%D9%87%D8%A8%D8%B7-%D8%A5%D9%84%D9%89-%D9%85%D8%B3%D8%AA%D9%88%D9%89-%D8%AA%D8%A7%D8%B1%D9%8A%D8%AE%D9%8A-%D8%AC%D8%AF%D9%8A%D8%AF/">الليرة التركية تهبط إلى مستوى تاريخي جديد</a>\n        </div>\n        \n      </div>\n    \n    \n<!--      <th:block>\n        <div th:remove="tag" th:if="${i.index == 1}">\n          <div th:replace="components/ads/internal/native" ></div>\n          <div th:replace="components/ads/internal/mobile-native" ></div>\n        </div>\n      </th:block>-->\n      <div class="mi-home-media-block">\n        <a class="mi-home-media-block__image" href="/news/3679705/%D8%B9%D9%85%D9%84%D8%A9-%D8%A7%D9%84%D8%A8%D9%8A%D8%AA%D9%83%D9%88%D9%8A%D9%86-%D8%AA%D8%B9%D8%A7%D9%88%D8%AF-%D8%A7%D9%84%D8%B5%D8%B9%D9%88%D8%AF-%D8%A3%D8%B9%D9%84%D9%89-12-%D8%A3%D9%84%D9%81-%D8%AF%D9%88%D9%84%D8%A7%D8%B1/">\n          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/ab491b6531081c6058fa5b203b6cbecc/144.jpg">\n        </a>\n        <div class="mi-home-media-block__content">\n          <a class="mi-home-media-block__title" href="/news/3679705/%D8%B9%D9%85%D9%84%D8%A9-%D8%A7%D9%84%D8%A8%D9%8A%D8%AA%D9%83%D9%88%D9%8A%D9%86-%D8%AA%D8%B9%D8%A7%D9%88%D8%AF-%D8%A7%D9%84%D8%B5%D8%B9%D9%88%D8%AF-%D8%A3%D8%B9%D9%84%D9%89-12-%D8%A3%D9%84%D9%81-%D8%AF%D9%88%D9%84%D8%A7%D8%B1/">عملة البيتكوين تعاود الصعود أعلى 12 ألف دولار</a>\n        </div>\n        \n      </div>\n    \n    \n<!--      <th:block>\n        <div th:remove="tag" th:if="${i.index == 1}">\n          <div th:replace="components/ads/internal/native" ></div>\n          <div th:replace="components/ads/internal/mobile-native" ></div>\n        </div>\n      </th:block>-->\n      <div class="mi-home-media-block">\n        <a class="mi-home-media-block__image" href="/news/3679783/%D8%A3%D8%B1%D8%A7%D9%85%D9%83%D9%88-%D8%AA%D8%B1%D9%81%D8%B9-%D8%A3%D8%B3%D8%B9%D8%A7%D8%B1-%D8%A7%D9%84%D8%A8%D9%86%D8%B2%D9%8A%D9%86-%D8%A8%D9%86%D8%AD%D9%88-11-%D8%AD%D8%AA%D9%89-10-%D8%B3%D8%A8%D8%AA%D9%85%D8%A8%D8%B1/">\n          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="محطة للتزود بالوقود" src="https://static.mubasher.info/File.Story_Image/cf61a8737c62c57737e53b3677aa2bbc/144.jpg">\n        </a>\n        <div class="mi-home-media-block__content">\n          <a class="mi-home-media-block__title" href="/news/3679783/%D8%A3%D8%B1%D8%A7%D9%85%D9%83%D9%88-%D8%AA%D8%B1%D9%81%D8%B9-%D8%A3%D8%B3%D8%B9%D8%A7%D8%B1-%D8%A7%D9%84%D8%A8%D9%86%D8%B2%D9%8A%D9%86-%D8%A8%D9%86%D8%AD%D9%88-11-%D8%AD%D8%AA%D9%89-10-%D8%B3%D8%A8%D8%AA%D9%85%D8%A8%D8%B1/">أرامكو ترفع أسعار البنزين بنحو 11% حتى 10 سبتمبر</a>\n        </div>\n        \n      </div>\n    \n    \n<!--      <th:block>\n        <div th:remove="tag" th:if="${i.index == 1}">\n          <div th:replace="components/ads/internal/native" ></div>\n          <div th:replace="components/ads/internal/mobile-native" ></div>\n        </div>\n      </th:block>-->\n      <div class="mi-home-media-block">\n        <a class="mi-home-media-block__image" href="/news/3680546/%D8%A8%D9%803-%D8%B6%D9%88%D8%A7%D8%A8%D8%B7-%D8%A7%D9%84%D8%AA%D9%82%D8%A7%D8%B9%D8%AF-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D9%88%D8%B6%D8%AD-%D8%B7%D8%B1%D9%8A%D9%82%D8%A9-%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D8%A7%D9%84%D9%85%D8%B9%D8%A7%D8%B4-%D9%84%D9%85%D9%88%D8%B8%D9%81%D9%8A-%D8%A7%D9%84%D9%82%D8%B7%D8%A7%D8%B9-%D8%A7%D9%84%D8%B9%D8%A7%D9%85/">\n          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="مؤسسة التقاعد السعودية" src="https://static.mubasher.info/File.Story_Image/68cc490a847f0daba3afd0ddbd6d06c8/144.jpg">\n        </a>\n        <div class="mi-home-media-block__content">\n          <a class="mi-home-media-block__title" href="/news/3680546/%D8%A8%D9%803-%D8%B6%D9%88%D8%A7%D8%A8%D8%B7-%D8%A7%D9%84%D8%AA%D9%82%D8%A7%D8%B9%D8%AF-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D9%88%D8%B6%D8%AD-%D8%B7%D8%B1%D9%8A%D9%82%D8%A9-%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D8%A7%D9%84%D9%85%D8%B9%D8%A7%D8%B4-%D9%84%D9%85%D9%88%D8%B8%D9%81%D9%8A-%D8%A7%D9%84%D9%82%D8%B7%D8%A7%D8%B9-%D8%A7%D9%84%D8%B9%D8%A7%D9%85/">بـ3 ضوابط.. التقاعد السعودية توضح طريقة تسوية المعاش لموظفي القطاع العام</a>\n        </div>\n        \n      </div>\n    \n\n    <a class="mi-article-widget__more-button" href="/news/SA/now/popular">\n      <span>المزيد</span>\n      <i class="fa fa-chevron-left"></i>\n    </a>\n  \n  </v-page><!-- end ngRepeat: page in popular.pages --><v-page ng-bind-html="page.content | unsafe" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope" role="tabpanel">\n    \n    \n\n    <a class="mi-article-widget__more-button" href="/news/SA/now/trending/">\n      <span>المزيد</span>\n      <i class="fa fa-chevron-left"></i>\n    </a>\n  \n  </v-page><!-- end ngRepeat: page in popular.pages -->\n    </v-pages>\n  </div>\n    <div id="MPU">\n\n    </div>\n\n    </div>\n\n    <!-- Speakol Widget - Removal IB-51 -->\n    <!-- <div th:replace="components/ads/common/speakol-two"/> -->\n\n<!--    <div th:unless="${device.isMobile()}">\n      <div th:replace="components/ads/insticator/insticator-widget"/>\n    </div>-->\n    <!-- -->\n\n    <!-- PS -->\n    <!--<div th:replace="components/ads/internal/may-like-articles" />-->\n\n    <!--<div th:replace="components/ads/internal/second-fold" />-->\n    <!--    <div th:if="${#locale.getLanguage() == \'ar\'}">\n          <span class="home__title">راديو مباشر</span>\n          <div class="internal-radio-carousel-container"></div>\n        </div>-->\n  </aside>\n\n\n\n<!--  <div th:replace="components/ads/internal/mobile-fullpage"/>-->\n\n  <!--<div th:replace="components/ads/internal/mobile-interstitial"/>-->\n<!--commented out as per Fayoumi\'s request-->\n  <!--<div th:replace="components/ads/internal/mobile-outstream"/>-->\n\n  <!--MFP-228 New Fixed-Replacement-ROS ads-->\n<!--  <div th:replace="components/ads/home/mobile-fixed-replacement"/>\n\n  <div th:replace="components/ads/news/dfp/mobile/MPU3"/>-->\n\n<!--Commented out as per Fayoumi\'s request-->\n  <!--<div th:replace="components/ads/internal/outstream"/>-->\n\n\n\n<!--  <div th:if="${device.isMobile()}">\n    <div th:replace="components/ads/dfp/mobile-internal-pages"/>\n  </div>-->\n\n<!--  <div th:if="${device.isMobile()}">\n    <div th:replace="components/ads/insticator/insticator-widget"/>\n  </div>-->\n\n <!-- <div th:replace="components/ads/internal/mobile-above-footer"/>-->\n</div>\n    </div>\n    <footer>\n  <div class="mi-footer">\n    <div class="mi-show-for-large-up mi-footer__main-menu">\n      <ul>\n        <li class="mi-footer__menu-item mi-footer__menu__markets" id="markets">\n          <div class="mi-footer__menu-level1">الأسواق</div>\n          <ul>\n            <h3 class="mi-footer__menu-level2 invisible">الأسواق</h3>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/TDWL">سوق الأسهم السعودي</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/EGX">البورصة المصرية</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/DFM">سوق دبي المالي</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/ADX">سوق أبوظبي</a>\n            </li>\n          </ul>\n          <ul>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/BB">بورصة البحرين</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/QE">بورصة قطر</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/MSM">سوق مسقط</a>\n            </li>\n          </ul>\n          <ul>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/KSE">سوق الكويت</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/ASE">بورصة عمان</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/CSE">سوق الدار البيضاء</a>\n            </li>\n          </ul>\n          <ul>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/BDT">بورصة تونس</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/PEX">سوق فلسطين</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/ISX">سوق العراق</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/international-indices">مؤشرات الأسواق العالمية</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/commodities-prices">أسعار المعادن والطاقة</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/countries/sa/currencies">أسعار العملات</a>\n            </li>\n            <!--<li>\n              <a class="mi-footer__menu-level3"\n                 th:href="${@url.to(\'RMPC#regionalMap\')}"\n                 th:text="#{navigation.markets.regional-map}"/>\n            </li>-->\n          </ul>\n        </li>\n        <li class="mi-footer__menu-item mi-footer__menu__news" id="news">\n          <ul>\n            <div class="mi-footer__menu-level1">الأخبار</div>\n            <li class="mi-footer__menu__news__submenu">\n              <h3 class="mi-footer__menu-level2">أخبار الدول</h3>\n              <ul>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/eg/now/latest">مصر</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/now/latest">السعودية</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/ae/now/latest">الإمارات</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/bh/now/latest">البحرين</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/qa/now/latest">قطر</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/om/now/latest">عمان</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/kw/now/latest">الكويت</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/jo/now/latest">الأردن</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/ma/now/latest">المغرب</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/tn/now/latest">تونس</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/ps/now/latest">فلسطين</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/iq/now/latest">العراق</a>\n                </li>\n              </ul>\n            </li>\n            <li class="mi-footer__menu__news__submenu">\n              <h3 class="mi-footer__menu-level2">أخبار إقليمية</h3>\n              <ul>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/regions/gulf">الخليج</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/regions/levant">الشام</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/regions/north-africa">شمال أفريقيا</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/regions/middle-east">الشرق الأوسط</a>\n                </li>\n              </ul>\n              <!-- happening now -->\n              <h3 class="mi-footer__menu-level2">يحدث الآن</h3>\n              <ul>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/now/top">أهم الأخبار</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/now/exclusive">حصرياً مباشر</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/now/latest">آخر الأخبار</a>\n                </li>\n                \n                  <li>\n                    <a class="mi-footer__menu-level3" href="/news/sa/now/announcements">إعلانات السوق</a>\n                  </li>\n                  \n                \n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/now/popular">منتشر الآن</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/now/trending/">الأكثر مشاركة</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/now/news-releases">بيانات صحفية</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/international/misc">أخبار منوعة</a>\n                </li>\n              </ul>\n            </li>\n            <li class="mi-footer__menu__news__submenu">\n              <h3 class="mi-footer__menu-level2">نبض السوق</h3>\n              <ul>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/stocks">أخبار الأسهم</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/analysis">تحليلات إخبارية</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/local">اقتصاد محلي</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/recommendations">توصيات</a>\n                </li>\n              </ul>\n              <h3 class="mi-footer__menu-level2">أخبار القطاعات</h3>\n              <ul>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/category/banking">بنوك</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/category/realEstate">عقارات</a>\n                </li>\n              </ul>\n              <h3 class="mi-footer__menu-level2">أخبار عالمية</h3>\n              <ul>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/international/global-economy">اقتصاد عالمى</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/international/goods-and-metals">أحداث عالمية</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/international/global-indices">مؤشرات عالمية</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/international/oil-and-energy">نفط ومعادن</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/international/currencies">عملات</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/international/global-reports">تقارير عالمية</a>\n                </li>\n              </ul>\n            </li>\n          </ul>\n        </li>\n        <li class="mi-footer__menu-item mi-footer__menu__companies" id="companies">\n          <div class="mi-footer__menu-level1">الشركات</div>\n          <ul>\n            <h3 class="mi-footer__menu-level2 invisible">الشركات</h3>\n            <li>\n              <a class="mi-footer__menu-level3" href="/countries/sa/companies">الشركات المدرجة</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/countries/sa/events">مفكرة الشركات</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/countries/sa/stock-prices">أسعار الأسهم</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/countries/sa/earnings">إعلانات الأرباح</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/countries/sa/fair-values">القيم العادلة</a>\n            </li>\n            <li>\n              \n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/countries/sa/major-shareholders">كبار الملاك</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/countries/sa/ipos">قائمة الإكتتابات</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/ipo/list">بحث فى الاكتتابات</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/ipos/news">أخبار الاكتتابات</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/ipo/calendar">مفكرة الاكتتابات</a>\n            </li>\n          </ul>\n        </li>\n        <li class="mi-footer__menu-item mi-footer__menu__analysis-tools" id="analysis-tools">\n          <div class="mi-footer__menu-level1">أدوات التحليل</div>\n          <!-- If current country has one market only -->\n          \n            <ul>\n              <h3 class="mi-footer__menu-level2 invisible">أدوات التحليل</h3>\n              <li>\n                <a class="mi-footer__menu-level3" href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>\n              </li>\n              <li>\n                <a class="mi-footer__menu-level3" href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>\n              </li>\n              <li>\n                <a class="mi-footer__menu-level3" href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>\n              </li>\n              <li>\n                <a class="mi-footer__menu-level3" href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>\n              </li>\n              <li>\n                <a class="mi-footer__menu-level3" href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>\n              </li>\n              <li>\n                <a class="mi-footer__menu-level3" href="/analysis-tools/performance-comparison">مقارنة الأداء</a>\n              </li>\n            </ul>\n          \n          <!-- If current country has more than one markets i.e UAE -->\n          \n        </li>\n      </ul>\n    </div>\n\n    <div class="mi-footer__second-fold">\n      <div class="mi-footer__column1">\n        <div class="mi-footer__copyright">\n          <div class="mi-footer__logo" onclick="window.location.href=\'/countries/sa\'">\n            \n  <svg viewBox="0 0 494.387 190.555">\n    <use xlink:href="#logo-white"></use>\n  </svg>\n  \n\n          </div>\n          <span>جميع الحقوق تعود لشركة مباشر العالمية © 2005 - 2020</span>\n        </div>\n        <ul class="mi-footer__links">\n          <li>\n            <a href="/s/Terms">اتفاقية الاستخدام</a>\n          </li>\n          <li>\n            <a href="/s/disclaimer">إخلاء المسؤولية</a>\n          </li>\n          <li>\n            <a href="/s/aboutus">من نحن</a>\n          </li>\n          <li>\n            <a href="/contact">اتصل بنا</a>\n          </li>\n          <li>\n            <a href="/advertise">أعلن معنا</a>\n          </li>\n          <li>\n            <a href="http://www.decypha.com/" target="_blank">موقع ديسيفا</a>\n          </li>\n          <li>\n            <a href="/ir-services" target="_blank">خدمات المواقع</a>\n          </li>\n          <li>\n            <a href="/s/Jobs">وظائف</a>\n          </li>\n          <li>\n              <a target="_blank" href="/decypha-packages">ديسيفا</a>\n          </li>\n          <li>\n            <a href="/s/privacy-policy" target="_blank">سياسة الخصوصية</a>\n          </li>\n          <!--<li th:if="${#locale.getLanguage() == \'en\'}">\n            <a href="/s/decypha-financial-intelligence" th:text="#{components.footer.decypha-financial-intelligence}">Decypha Financial Intelligence</a>\n          </li>-->\n        </ul>\n        <div>جميع البيانات متأخرة 15 دقيقة أثناء الجلسة</div>\n        <div>هذا الموقع مرخص من وزراة الثقافة والإعلام السعودية</div>\n        <div>رقم التسجيل :ت 1 125 1435</div>\n      </div>\n      <div class="mi-footer__column2">\n        <ul class="mi-footer__social-icons">\n          <li>\n            <a target="_blank" href="https://twitter.com/mubasher"><i class="fa fa-twitter fa-2x"></i></a>\n          </li>\n          <li>\n            <a href="https://www.facebook.com/Mubasher.Info"><i class="fa fa-facebook fa-2x"></i></a>\n          </li>\n          <li>\n            <a href="https://www.youtube.com/channel/UC7hnxb7gD4nKZdZk3ZlZCYg"><i class="fa fa-youtube fa-2x"></i></a>\n          </li>\n          <li>\n            <a href="https://www.linkedin.com/company/1477149"><i class="fa fa-linkedin fa-2x"></i></a>\n          </li>\n          <li>\n            <a href="/news/rss"><i class="fa fa-rss fa-2x"></i></a>\n          </li>\n          <li>\n            <a href="https://play.google.com/store/apps/details?id=net.mis.mubasherinfo">\n              <i class="fa fa-android fa-2x"></i></a>\n          </li>\n          <li>\n            <a href="https://itunes.apple.com/app/imubasher/id494539772?mt=8"><i class="fa fa-apple fa-2x"></i></a>\n          </li>\n      \n    \n</ul></div></div></div></footer>\n    \n    \n  </div>\n\n\n  <script src="//code.jquery.com/jquery-2.1.4.min.js"></script>\n  <script src="//ajax.googleapis.com/ajax/libs/angularjs/1.3.15/angular.min.js"></script>\n\n  <script src="/assets/ui/lib.min.js"></script>\n  <script src="/assets/ui/main.min.js"></script>\n  <div id="mi-js-scripts"></div>\n  <script>\n    <!-- Fix menu trigger on android browser4 -->\n    $(".dl-menu__menu-item").click(function () {\n      $(this).addClass(".dl-menu-item__hoverd");\n    });\n\n    $(document).ready(function () {\n      $(\'.tooltip\').tooltipster();\n      setTimeout(function(){ dataLayer.push({\nevent: "triggerAds"\n});\n      console.log("triggerAds");\n\n      }, 1000);\n    });\n  </script>\n  \n\n  <div pg-ng-tooltip=""></div>\n</div>\n\n  <!-- Twitter universal website tag code -->\n  <script>\n    !function(e,t,n,s,u,a){e.twq||(s=e.twq=function(){s.exe?s.exe.apply(s,arguments):s.queue.push(arguments);\n    },s.version=\'1.1\',s.queue=[],u=t.createElement(n),u.async=!0,u.src=\'//static.ads-twitter.com/uwt.js\',\n      a=t.getElementsByTagName(n)[0],a.parentNode.insertBefore(u,a))}(window,document,\'script\');\n    // Insert Twitter Pixel ID and Standard Event data below\n    twq(\'init\',\'nyana\');\n    twq(\'track\',\'PageView\');\n  </script>\n  <!-- End Twitter universal website tag code -->\n\n\n\n<div id="mm-blocker" class="mm-slideout"></div></body>' + '<body id="mi" ng-app="app" ng-controller="MainController" class="ar ng-scope" data-gr-c-s-loaded="true"><nav class="header__countries-menu mm-menu mm-offcanvas mm-top mm-front" id="countries-menu"><div class="mm-panel mm-opened mm-current" id="mm-8"><ul class="mm-listview mm-first mm-last">\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=ae&amp;url=/countries/sa/companies">الإمارات</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=bh&amp;url=/countries/sa/companies">البحرين</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=om&amp;url=/countries/sa/companies">عُمان</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=qa&amp;url=/countries/sa/companies">قطر</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=kw&amp;url=/countries/sa/companies">الكويت</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=eg&amp;url=/countries/sa/companies">مصر</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=jo&amp;url=/countries/sa/companies">الأردن</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=tn&amp;url=/countries/sa/companies">تونس</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=ma&amp;url=/countries/sa/companies">المغرب</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=ps&amp;url=/countries/sa/companies">فلسطين</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=iq&amp;url=/countries/sa/companies">العراق</a>\n        </li>\n      </ul></div></nav><nav class="header__main-menu mm-menu mm-border-full mm-effect-slide-menu mm-effect-zoom-panels mm-pageshadow mm-offcanvas mm-right mm-hasnavbar-top mm-hasnavbar" id="main-menu"><div class="mm-navbar mm-navbar-top mm-hasbtns"><a class="mm-prev mm-btn mm-hidden"></a><a class="mm-title"> </a><a class="mm-close mm-btn" href="#wrapper"></a></div><div class="mm-panel mm-opened mm-current" id="mm-0"><ul class="mm-listview mm-first mm-last">\n        <li id="markets">\n          <a class="mm-next mm-fullsubopen" href="#mm-1" data-target="#mm-1"></a><span href="javascript:;">الأسواق</span>\n          \n        </li>\n        <li id="news">\n          <a class="mm-next mm-fullsubopen" href="#mm-2" data-target="#mm-2"></a><span href="javascript:;">الأخبار</span>\n          \n        </li>\n        <li id="companies">\n          <a class="mm-next mm-fullsubopen" href="#mm-3" data-target="#mm-3"></a><span href="javascript:;">الشركات</span>\n          \n        </li>\n        <li id="funds">\n          <a class="mm-next mm-fullsubopen" href="#mm-4" data-target="#mm-4"></a><span href="javascript:;">صناديق الاستثمار</span>\n          \n        </li>\n        <li id="analysis-tool">\n          <a class="mm-next mm-fullsubopen" href="#mm-5" data-target="#mm-5"></a><span href="javascript:;">أدوات التحليل</span>\n          \n\n        </li>\n        <li id="islamic-economy">\n          <a href="/news/islamic-finance">الاقتصاد الإسلامي</a>\n        </li>\n        <!--<li class="global__hide-for-ltr" id="radio" th:if="${#locale.getLanguage() == \'ar\'}">\n          <span th:text="#{navigation.radio}">راديو مباشر</span>\n          <ul>\n            <li>\n              <a th:href="${@url.to(\'RPC#live\')}" th:text="#{navigation.radio.live}"/>\n            </li>\n            <li>\n              <a th:href="${@url.to(\'RPC#latestEpisodesPage\', countryCode)}">آخر الحلقات</a>\n            </li>\n            <li>\n              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تقارير-اقتصادية\'}">تقارير اقتصادية</a>\n            </li>\n            <li>\n              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تغطية-خاصة\'}">تغطية خاصة</a>\n            </li>\n            <li>\n              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'مقالات\'}">مقالات</a>\n            </li>\n            <li>\n              <a th:href="${@url.to(\'RPC#programs\')}" th:text="#{navigation.radio.programs}"/>\n            </li>\n            <li>\n              <a th:href="${@url.to(\'RPC#videoPrograms\')}" th:text="#{navigation.radio.videoPrograms}"/>\n            </li>\n            <li>\n              <a th:href="${@url.to(\'RPC#getExperts\')}">ضيوفنا</a>\n            </li>\n            <li>\n              <a th:href="${@url.to(\'RPC#getPresenters\')}">المذيعون</a>\n            </li>\n          </ul>\n        </li>-->\n        <li class="global__hide-for-ltr" id="video">\n          <a href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">مباشر TV</a>\n        </li>\n        \n        <li id="fixedincome">\n          <a class="mm-next mm-fullsubopen" href="#mm-6" data-target="#mm-6"></a><span>السندات</span>\n          \n        </li>\n        <li>\n          <a class="mm-next mm-fullsubopen" href="#mm-7" data-target="#mm-7"></a><span>شخصي</span>\n          \n        </li>\n        <li>\n          <a href="http://tawasul.mubasher.info/" target="_blank">تواصل</a>\n        </li>\n        <!-- <li>\n          <a th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank" th:text="#{components.header.decypha}" target="_blank">\n          </a>\n        </li> -->\n        <li>\n          <a ng-click="decypha(\'decypha\')">ديسيفا</a>\n        </li>\n\n        <!--Add according to MFP-187-->\n\n        <li>\n          <a href="https://contest.mubasher.info/#/home" target="_blank">المستثمر اﻷول</a>\n        </li>\n        <li>\n\n          <!--Integrating Mubasher Pulse-->\n\n        </li><li>\n        <style>\n\n          .pulse-logo2{\n            padding: 5px 5px 4px;\n            min-width: 82px;\n            min-height: 21px;\n            max-width: 27%;\n          }\n\n        </style>\n\n        <a target="_blank" href="https://pulse.mubasher.info">\n          <img class="pulse-logo2" src="../../../images/pulse-logo.png">\n        </a>\n        </li>\n        <li>\n\n\n        </li><li>\n          <a href="http://magazine.mubasher.info/" target="_blank">\n            مجلة مباشر\n          </a>\n        </li>\n\n        <li class="mm-divider"></li>\n        <li>\n          <a href="https://english.mubasher.info">ENGLISH</a>\n        </li>\n        <li>\n          \n        </li>\n        <li>\n          <a class="header__login__text" href="/account/login">دخول</a>\n          \n        </li>\n      </ul></div><div class="mm-panel mm-hidden" id="mm-1"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الأسواق</a></div><ul class="mm-listview mm-first mm-last">\n            <li>\n              <a href="/markets/TDWL">سوق الأسهم السعودي</a>\n            </li>\n            <li>\n              <a href="/markets/EGX">البورصة المصرية</a>\n            </li>\n            <li>\n              <a href="/markets/DFM">سوق دبي المالي</a>\n            </li>\n            <li>\n              <a href="/markets/ADX">سوق أبوظبي</a>\n            </li>\n            <li>\n              <a href="/markets/BB">بورصة البحرين</a>\n            </li>\n            <li>\n              <a href="/markets/QE">بورصة قطر</a>\n            </li>\n            <li>\n              <a href="/markets/MSM">سوق مسقط</a>\n            </li>\n            <li>\n              <a href="/markets/BK">سوق الكويت</a>\n            </li>\n            <li>\n              <a href="/markets/ASE">بورصة عمان</a>\n            </li>\n            <li>\n              <a href="/markets/CSE">سوق الدار البيضاء</a>\n            </li>\n            <li>\n              <a href="/markets/BDT">بورصة تونس</a>\n            </li>\n            <li>\n              <a href="/markets/PEX">سوق فلسطين</a>\n            </li>\n            <li>\n              <a href="/markets/ISX">سوق العراق</a>\n            </li>\n            <li>\n              <a href="/international-indices">مؤشرات الأسواق العالمية</a>\n            </li>\n            <li>\n              <a href="/markets/commodities-prices">أسعار المعادن والطاقة</a>\n            </li>\n            <li>\n              <a href="/countries/sa/currencies">أسعار العملات</a>\n            </li>\n          </ul></div><div class="mm-panel mm-hidden" id="mm-2"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الأخبار</a></div><ul class="mm-listview mm-first mm-last">\n            <!-- now -->\n            <li class="mm-divider">يحدث الآن</li>\n            <li>\n              <a href="/news/sa/now/top">أهم الأخبار</a>\n            </li>\n            <li>\n              <a href="/news/sa/now/exclusive">حصرياً مباشر</a>\n            </li>\n            <li>\n              <a href="/news/sa/now/latest">آخر الأخبار</a>\n            </li>\n            \n              <li>\n                <a href="/news/sa/now/announcements">إعلانات السوق</a>\n              </li>\n              \n            \n            <li class="global__hide-for-ltr">\n              <a href="/news/sa/now/popular">منتشر الآن</a>\n            </li>\n            <li>\n              <a href="/news/sa/now/trending/">الأكثر مشاركة</a>\n            </li>\n            <li>\n              <a href="/news/now/news-releases">بيانات صحفية</a>\n            </li>\n<!--            <li>\n              <a th:href="${@url.to(\'NPC#miscellaneousNews\', countryCode)}"\n                 th:text="#{navigation.news.now.misc}"/>\n            </li>-->\n            <!-- recommendations-->\n            <li class="mm-divider">نبض السوق</li>\n            <li>\n              <a href="/news/sa/pulse/stocks">أخبار الأسهم</a>\n            </li>\n            <li>\n              <a href="/news/sa/pulse/analysis">تحليلات إخبارية</a>\n            </li>\n            <li>\n              <a href="/news/sa/pulse/local">اقتصاد محلي</a>\n            </li>\n            <li>\n              <a href="/news/sa/pulse/recommendations">توصيات</a>\n            </li>\n            <li class="mm-divider">أخبار القطاعات</li>\n            <li>\n              <a href="/news/sa/category/banking">بنوك</a>\n            </li>\n            <li>\n              <a href="/news/sa/category/realEstate">عقارات</a>\n            </li>\n            <li class="mm-divider">أخبار الدول</li>\n            <li>\n              <a href="/news/eg/now/latest">مصر</a>\n            </li>\n            <li>\n              <a href="/news/sa/now/latest">السعودية</a>\n            </li>\n            <li>\n              <a href="/news/ae/now/latest">الإمارات</a>\n            </li>\n            <li>\n              <a href="/news/bh/now/latest">البحرين</a>\n            </li>\n            <li>\n              <a href="/news/qa/now/latest">قطر</a>\n            </li>\n            <li>\n              <a href="/news/om/now/latest">عمان</a>\n            </li>\n            <li>\n              <a href="/news/kw/now/latest">الكويت</a>\n            </li>\n            <li>\n              <a href="/news/jo/now/latest">الأردن</a>\n            </li>\n            <li>\n              <a href="/news/ma/now/latest">المغرب</a>\n            </li>\n            <li>\n              <a href="/news/tn/now/latest">تونس</a>\n            </li>\n            <li>\n              <a href="/news/ps/now/latest">فلسطين</a>\n            </li>\n            <li>\n              <a href="/news/iq/now/latest">العراق</a>\n            </li>\n\n            <!-- regions-->\n            <li class="mm-divider">أخبار إقليمية</li>\n            <li>\n              <a href="/news/regions/gulf">الخليج</a>\n            </li>\n            <li>\n              <a href="/news/regions/levant">الشام</a>\n            </li>\n            <li>\n              <a href="/news/regions/north-africa">شمال أفريقيا</a>\n            </li>\n            <li>\n              <a href="/news/regions/middle-east">الشرق الأوسط</a>\n            </li>\n\n            <!-- international -->\n            <li class="mm-divider">أخبار عالمية</li>\n            <li>\n              <a href="/news/international/global-economy">اقتصاد عالمى</a>\n            </li>\n            <li>\n              <a href="/news/international/goods-and-metals">أحداث عالمية</a>\n            </li>\n              <li>\n                <a href="/news/international/global-indices">مؤشرات عالمية</a>\n              </li>\n              <li>\n                <a href="/news/international/oil-and-energy">نفط ومعادن</a>\n              </li>\n              <li>\n                <a href="/news/international/currencies">عملات</a>\n              </li>\n              <li>\n                <a href="/news/international/global-reports">تقارير عالمية</a>\n              </li>\n          </ul></div><div class="mm-panel mm-hidden" id="mm-3"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الشركات</a></div><ul class="mm-listview mm-first mm-last">\n            <li>\n              <a href="/countries/sa/companies">الشركات المدرجة</a>\n            </li>\n            <li>\n              <a href="/countries/sa/events">مفكرة الشركات</a>\n            </li>\n            <li>\n              <a href="/countries/sa/stock-prices">أسعار الأسهم</a>\n            </li>\n            <li>\n              <a href="/countries/sa/earnings">إعلانات الأرباح</a>\n            </li>\n            <li>\n              <a href="/countries/sa/fair-values">القيم العادلة</a>\n            </li>\n            <li>\n              <a href="/countries/sa/corporate-action">الإجراءات</a>\n            </li>\n            \n            <li>\n              <a href="/countries/sa/major-shareholders">كبار الملاك</a>\n            </li>\n            <li>\n              <a href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>\n            </li>\n            <li class="mm-divider">الاكتتابات</li>\n            <li>\n              <a href="/countries/sa/ipos">قائمة الإكتتابات</a>\n            </li>\n            <li>\n              <a href="/ipo/list">بحث فى الاكتتابات</a>\n            </li>\n            <li>\n              <a href="/ipos/news">أخبار الاكتتابات</a>\n            </li>\n            <li>\n              <a href="/ipo/calendar">مفكرة الاكتتابات</a>\n            </li>\n          </ul></div><div class="mm-panel mm-hidden" id="mm-4"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">صناديق الاستثمار</a></div><ul class="mm-listview mm-first mm-last">\n            <li>\n              <a href="/countries/sa/funds">صناديق الاستثمار</a>\n            </li>\n            <li>\n              <a href="/countries/sa/funds-statistics">إحصائيات الصناديق</a>\n            </li>\n          </ul></div><div class="mm-panel mm-hidden" id="mm-5"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">أدوات التحليل</a></div><ul class="mm-listview mm-first mm-last">\n            \n              \n              <li>\n                <a href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>\n              </li>\n              <li>\n                <a href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>\n              </li>\n              <li>\n                <a href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>\n              </li>\n              <li>\n                <a href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>\n              </li>\n              <li>\n                <a href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>\n              </li>\n            \n\n            <li class="mm-divider">\n            </li>\n            <li>\n              <a href="/analysis-tools/performance-comparison">مقارنة الأداء</a>\n            </li>\n          </ul></div><div class="mm-panel mm-hidden" id="mm-6"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">السندات</a></div><ul class="mm-listview mm-first mm-last">\n            <li>\n              <a href="/fixedincome/bond/search" id="fixedIncomeBondScreener">بحث عن سندات</a>\n            </li>\n            <li>\n              <a href="/fixed-income/news" id="fixedIncomeNews">أخبار السندات وأذون الخزانة</a>\n            </li>\n            <li>\n              <a href="/fixedincome/calendar/searchForEvent" id="fixedIncomeCalendar">قائمة الأحداث</a>\n            </li>\n            <li>\n              <a href="/fixedincome/analytics/drawCurve" id="fixedIncomeAnalytics">تحليلات فنية</a>\n            </li>\n            <li>\n              <a href="/fixedincome/leagueTables/view" id="fixedIncomeLeagueTables">جداول الديون</a>\n            </li>\n            <li>\n              <a href="/fixedincome/research/search" id="fixedIncomeProspectus">تقارير</a>\n            </li>\n          </ul></div><div class="mm-panel mm-hidden" id="mm-7"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">شخصي</a></div><ul class="mm-listview mm-first mm-last">\n            <li>\n              <a href="/my/alerts">التنبيهات</a>\n            </li>\n            <li>\n              <a href="/my/watch-list">أسهمي</a>\n            </li>\n            <li>\n              <a href="/my/newsletters">النشرة البريدية</a>\n            </li>\n          </ul></div></nav>\n\n\n<div class="js-wrapper mm-page mm-slideout" id="wrapper">\n  <svg class="hidden" version="1.1" viewBox="0 0 0 0" xmlns="http://www.w3.org/2000/svg">\n  <defs>\n    <style>\n      .logo-white-path {\n        clip-rule: evenodd;\n        fill-rule: evenodd;\n        fill: white;\n        font-size: 46.6299px;\n        font-family: \'HelveticaNeue\';\n      }\n\n      .logo-path {\n        clip-rule: evenodd;\n        fill-rule: evenodd;\n        fill: #324651;\n        text-align: center;\n        font-size: 46.6299px;\n        font-family: \'HelveticaNeue\';\n      }\n    </style>\n    <g id="logo-white">\n      <path class="logo-white-path" d="M209.596 29.677c-6.25 0.016-11.243-4.937-11.261-11.188 c-0.018-6.191 5.027-11.29 11.194-11.29c6.182-0.004 11.3 5.1 11.3 11.226C220.852 24.6 215.8 29.7 209.6 29.7"></path>\n      <path class="logo-white-path" d="M228.308 37.976c6.231-0.01 11.3 5 11.3 11.2 c0.015 6.189-5.011 11.227-11.233 11.252c-6.213 0.025-11.246-4.99-11.271-11.209C217.063 43 222.1 38 228.3 38"></path>\n      <path class="logo-white-path" d="M350.278 190.471c-6.27-0.009-11.204-4.942-11.197-11.212 c0.013-6.26 4.968-11.18 11.248-11.176c6.242 0 11.3 5 11.2 11.224C361.555 185.5 356.5 190.5 350.3 190.5"></path>\n      <path class="logo-white-path" d="M186.161 37.976c6.26 0 11.2 5 11.2 11.2 c-0.01 6.241-4.993 11.239-11.209 11.226c-6.257-0.017-11.212-4.99-11.212-11.228C174.949 42.9 179.9 38 186.2 38"></path>\n      <path class="logo-white-path" d="M455.92 80.125c-21.212 0-38.405 17.191-38.405 38.4 c0 4.3 0.7 8.4 2 12.316l-48.126 0.003l13.9-27.74h-3.242c0 0-2.13 0.019-2.822 0.1 c-2.13 0.126-3.67 0.098-7.926 1.351c-3.949 1.159-7.026 2.719-9.881 4.503c-2.381 1.493-5.863 4.278-8.803 7.7 c-2.912 3.325-5.713 7.695-5.713 7.695l-3.294 6.464l-41.201 0.003L364.7 0l-76.514 49.172l25.429-0.036L260.64 156.919h193.847 c0 0 0.9 0 1.4 0.01c21.212 0 38.4-17.183 38.4-38.403C494.32 97.3 477.1 80.1 455.9 80.125z M455.92 133.3 c-7.998 0-14.48-6.479-14.48-14.47c0-7.998 6.482-14.476 14.48-14.476c7.996 0 14.5 6.5 14.5 14.5 C470.393 126.8 463.9 133.3 455.9 133.327z"></path>\n      <path class="logo-white-path" d="M269.61 81.427c0 0-1.617 0.013-2.842 0.09c-2.001 0.132-3.655 0.07-7.903 1.3 c-3.946 1.162-7.021 2.722-9.876 4.507c-2.378 1.488-5.868 4.279-8.813 7.662c-2.904 3.327-5.282 8.108-5.282 8.108l-14.116 27.7 h-16.391l19.092-39.485h-3.237c0 0-1.617 0.015-2.835 0.095c-2.012 0.13-3.665 0.068-7.905 1.3 c-3.957 1.161-7.034 2.717-9.892 4.502c-2.373 1.493-5.857 4.28-8.808 7.668c-2.899 3.321-5.282 8.104-5.282 8.104l-8.901 17.8 h-16.959l13.92-27.753h-3.245c0 0-2.141 0.019-2.822 0.057c-2.133 0.126-3.663 0.098-7.926 1.4 c-3.944 1.159-7.026 2.719-9.884 4.503c-2.378 1.493-5.857 4.28-8.808 7.669c-2.904 3.329-5.708 7.695-5.708 7.695l-3.291 6.5 l-52.558-0.005l14.007-27.748h-3.242c0 0-2.131 0.019-2.815 0.057c-2.136 0.126-3.678 0.098-7.934 1.4 c-3.944 1.159-7.021 2.719-9.877 4.503c-2.383 1.493-5.858 4.28-8.813 7.669c-2.906 3.329-5.114 7.843-5.114 7.843l-16.204 31.1 l0 0c0 0-3.136 6.731-7.038 11.469c-3.094 3.766-7.43 6.804-9.757 8.194c-2.313 1.384-7.141 3.645-11.872 4.5 C5.251 180.9 0 180.5 0 180.502s2.33 2.1 5 3.806c2.034 1.4 4.3 2.4 5.5 3 c2.481 1.1 4.3 1.7 6.9 2.253c2.531 0.6 4.8 0.8 4.8 0.763s1.621 0.2 3.2 0.169c0.707 0 1.62-0.024 2.848-0.09 c2.001-0.134 3.5 0 7.904-1.323c4.033-1.188 7.072-2.582 9.92-4.368c2.383-1.478 5.952-4.249 8.904-7.627 c2.907-3.337 5.296-8.019 5.296-8.019l6.043-12.125l169.4 0.009l12.816-26.07l24.302-49.431H269.61z"></path>\n      <path class="logo-white-path" d="M30.239 76.472V55.626H22.45v-2.789h18.735v2.789h-7.819v20.846H30.239z"></path>\n      <path class="logo-white-path" d="M44.296 76.472V52.836h4.71l5.592 16.735c0.518 1.6 0.9 2.7 1.1 3.499c0.269-0.861 0.687-2.123 1.258-3.789 l5.658-16.446h4.209v23.636h-3.015V56.689l-6.869 19.783h-2.822l-6.835-20.121v20.121H44.296z"></path>\n    </g>\n    <g id="logo">\n      <path class="logo-path" d="M209.596 29.677c-6.25 0.016-11.243-4.937-11.261-11.188 c-0.018-6.191 5.027-11.29 11.194-11.29c6.182-0.004 11.3 5.1 11.3 11.226C220.852 24.6 215.8 29.7 209.6 29.7"></path>\n      <path class="logo-path" d="M228.308 37.976c6.231-0.01 11.3 5 11.3 11.2 c0.015 6.189-5.011 11.227-11.233 11.252c-6.213 0.025-11.246-4.99-11.271-11.209C217.063 43 222.1 38 228.3 38"></path>\n      <path class="logo-path" d="M350.278 190.471c-6.27-0.009-11.204-4.942-11.197-11.212 c0.013-6.26 4.968-11.18 11.248-11.176c6.242 0 11.3 5 11.2 11.224C361.555 185.5 356.5 190.5 350.3 190.5"></path>\n      <path class="logo-path" d="M186.161 37.976c6.26 0 11.2 5 11.2 11.2 c-0.01 6.241-4.993 11.239-11.209 11.226c-6.257-0.017-11.212-4.99-11.212-11.228C174.949 42.9 179.9 38 186.2 38"></path>\n      <path class="logo-path" d="M455.92 80.125c-21.212 0-38.405 17.191-38.405 38.4 c0 4.3 0.7 8.4 2 12.316l-48.126 0.003l13.9-27.74h-3.242c0 0-2.13 0.019-2.822 0.1 c-2.13 0.126-3.67 0.098-7.926 1.351c-3.949 1.159-7.026 2.719-9.881 4.503c-2.381 1.493-5.863 4.278-8.803 7.7 c-2.912 3.325-5.713 7.695-5.713 7.695l-3.294 6.464l-41.201 0.003L364.7 0l-76.514 49.172l25.429-0.036L260.64 156.919h193.847 c0 0 0.9 0 1.4 0.01c21.212 0 38.4-17.183 38.4-38.403C494.32 97.3 477.1 80.1 455.9 80.125z M455.92 133.3 c-7.998 0-14.48-6.479-14.48-14.47c0-7.998 6.482-14.476 14.48-14.476c7.996 0 14.5 6.5 14.5 14.5 C470.393 126.8 463.9 133.3 455.9 133.327z"></path>\n      <path class="logo-path" d="M269.61 81.427c0 0-1.617 0.013-2.842 0.09c-2.001 0.132-3.655 0.07-7.903 1.3 c-3.946 1.162-7.021 2.722-9.876 4.507c-2.378 1.488-5.868 4.279-8.813 7.662c-2.904 3.327-5.282 8.108-5.282 8.108l-14.116 27.7 h-16.391l19.092-39.485h-3.237c0 0-1.617 0.015-2.835 0.095c-2.012 0.13-3.665 0.068-7.905 1.3 c-3.957 1.161-7.034 2.717-9.892 4.502c-2.373 1.493-5.857 4.28-8.808 7.668c-2.899 3.321-5.282 8.104-5.282 8.104l-8.901 17.8 h-16.959l13.92-27.753h-3.245c0 0-2.141 0.019-2.822 0.057c-2.133 0.126-3.663 0.098-7.926 1.4 c-3.944 1.159-7.026 2.719-9.884 4.503c-2.378 1.493-5.857 4.28-8.808 7.669c-2.904 3.329-5.708 7.695-5.708 7.695l-3.291 6.5 l-52.558-0.005l14.007-27.748h-3.242c0 0-2.131 0.019-2.815 0.057c-2.136 0.126-3.678 0.098-7.934 1.4 c-3.944 1.159-7.021 2.719-9.877 4.503c-2.383 1.493-5.858 4.28-8.813 7.669c-2.906 3.329-5.114 7.843-5.114 7.843l-16.204 31.1 l0 0c0 0-3.136 6.731-7.038 11.469c-3.094 3.766-7.43 6.804-9.757 8.194c-2.313 1.384-7.141 3.645-11.872 4.5 C5.251 180.9 0 180.5 0 180.502s2.33 2.1 5 3.806c2.034 1.4 4.3 2.4 5.5 3 c2.481 1.1 4.3 1.7 6.9 2.253c2.531 0.6 4.8 0.8 4.8 0.763s1.621 0.2 3.2 0.169c0.707 0 1.62-0.024 2.848-0.09 c2.001-0.134 3.5 0 7.904-1.323c4.033-1.188 7.072-2.582 9.92-4.368c2.383-1.478 5.952-4.249 8.904-7.627 c2.907-3.337 5.296-8.019 5.296-8.019l6.043-12.125l169.4 0.009l12.816-26.07l24.302-49.431H269.61z"></path>\n      <path class="logo-path" d="M30.239 76.472V55.626H22.45v-2.789h18.735v2.789h-7.819v20.846H30.239z"></path>\n      <path class="logo-path" d="M44.296 76.472V52.836h4.71l5.592 16.735c0.518 1.6 0.9 2.7 1.1 3.499c0.269-0.861 0.687-2.123 1.258-3.789 l5.658-16.446h4.209v23.636h-3.015V56.689l-6.869 19.783h-2.822l-6.835-20.121v20.121H44.296z"></path>\n    </g>\n    <g id="logo-white-en">\n      <defs>\n        <rect height="65.7" width="326.9" x="-55"></rect>\n      </defs>\n      <clipPath>\n        <use overflow="visible" xlink:href="#SVGID_1_"></use>\n      </clipPath>\n      <path class="logo-white-path" d="M41.694 20.162c-1.315 0-1.315 0.987-1.315 0.987l0.094 13.8 c0 0 0.6 8.648-8.178 8.648c0 0-8.364 0.093-8.364-8.082V21.29c0 0 0.234-1.174-1.27-1.174c-1.362 0-1.221 1.174-1.221 1.174V36 c0 0 0.2 10.1 10.9 10.104c10.386 0 10.669-9.675 10.669-10.433V21.243C42.964 21.2 43 20.2 41.7 20.2"></path>\n      <path class="logo-white-path" d="M20.915 21.431c0 0 0-0.799-0.799-1.127c-0.777-0.321-1.27 0.422-1.457 0.6 l-7.425 10.293c0 0-0.469 0.61-1.034-0.282l-8.13-10.292c0 0-0.517-0.611-1.128-0.423c-0.611 0.189-0.894 0.704-0.846 1.6 L0 44.74c0 0-0.046 1.4 1.3 1.363s1.316-1.222 1.316-1.222V25.144l7.002 9.023c0 0 1.1 1.5 2.209-0.188 c1.081-1.646 6.626-8.882 6.626-8.882v19.736c0 0-0.088 1.3 1.5 1.175c1.175-0.094 0.988-1.22 0.988-1.22V21.431z"></path>\n      <path class="logo-white-path" d="M168.546 43.734l-10.309-6.813c0 0 8.648-0.179 8.648-8.471 c0-8.294-8.531-8.118-8.531-8.118h-8.412c-2.107 0-1.953 1.6-1.953 1.6v22.69c0 0-0.038 1.5 1.1 1.5 c1.265 0 1.222-1.436 1.222-1.436V22.702h6.516c0.474 0 3.1 0 5.3 1.304c2.192 1.3 3.7 7.198-0.177 9.6 c-2.785 1.717-6.459 1.008-7.642 0.889c-1.185-0.12-1.306 0.414-1.483 1.186c-0.177 0.8 0.9 1.4 0.9 1.362l13.21 8.5 c0 0 1.4 1.2 2.1 0.18C169.967 44.4 168.5 43.7 168.5 43.7"></path>\n      <path class="logo-white-path" d="M95.522 19.596c-6.516-0.711-11.492 3.376-11.373 7.8 c0.117 4.4 3 5.7 8.1 6.634c5.096 0.9 7 1.7 7 1.658c2.665 1 2.5 4.3 1 5.9 c-1.423 1.601-4.148 2.558-5.766 2.616c-3.879 0.146-6.052-2.374-6.052-2.374c-0.492-0.407-0.683-1.486-1.69-1.25 c-1.347 0.316-0.296 1.836-0.296 1.836c2.311 3.2 7.2 3.6 7.2 3.554c5.45 0.7 8.648-3.139 8.648-3.139 c2.963-3.852 0.987-8.363-1.976-9.429c-3.17-1.142-6.139-1.234-10.05-2.065c-3.909-0.828-3.495-4.087-3.495-4.087 c0.059-2.37 2.252-5.271 7.643-5.332c5.392-0.059 8.5 3.4 8.5 3.436c1.304 1.4 2.1 0.5 2.133-0.12 c0.06-0.591-0.058-1.183-0.531-1.776C104.121 23.1 102 20.3 95.5 19.6"></path>\n      <path class="logo-white-path" d="M124.084 20.618c-1.126 0-1.185 1.067-1.185 1.067v15.166h-14.336V21.862 c0 0 0.296-1.42-1.305-1.362c-1.304 0.047-1.067 1.42-1.067 1.42v14.575h-0.889c0 0-1.303-0.06-1.303 1.2 c0 1.3 1.2 1.3 1.2 1.305h1.007v5.746c0 0 0 1.2 1.2 1.243c1.246 0 1.187-1.184 1.187-1.184v-5.984h14.1v6.103 c0 0-0.008 1.1 1.2 1.137c1.226 0 1.269-1.195 1.269-1.195V21.743C125.209 21.7 125.2 20.6 124.1 20.6"></path>\n      <path class="logo-white-path" d="M86.101 44.016c0 0-10.841-21.504-11.849-23.163c-1.007-1.66-2.072 0-2.072 0 l-8.047 15.604l-2.395 0.015c-0.888 0-0.982 0.633-0.982 1.284c0 1.1 1.1 0.9 1.1 0.929h1.067c0 0-2.447 4.637-2.726 5.3 c-0.355 0.889-0.416 1.5 0.5 1.955c1.008 0.5 1.659-0.77 1.659-0.77l3.436-6.399H80.71l2.903 5.9 c0 0 1 2 2.1 1.305C86.87 45.3 86.1 44 86.1 44 M66.965 36.374l5.984-12.026c0 0 0.296-0.475 0.6 0.1 c0.296 0.5 6 12 6 11.967H66.965z"></path>\n      <path class="logo-white-path" d="M58.314 34.283c0 0 3.87-1.954 3.87-6.575c0-4.622-4.563-7.199-8.294-7.199 h-6.517c0 0-1.512 0.2-1.512 1.744v10.479h-1.833c0 0-0.799-0.094-0.799 1.271c0 1.1 0.6 1.2 0.6 1.173h2.066v9.447 c0 0-0.046 1.5 1.5 1.48h7.213c0 0 6.016-0.165 6.016-6.837C60.57 35.9 58.3 34.3 58.3 34.3 M48.203 22.7 l6.338-0.005c1.718 0 5.1 1.7 5.1 5.451c0 4.443-5.095 4.501-5.095 4.501h-6.338V22.736z M53.557 43.831h-5.351v-8.748 l6.435-0.008c0.858 0 3.5 0.9 3.5 4.031C58.143 43.7 53.6 43.8 53.6 43.8"></path>\n      <path class="logo-white-path" d="M146.17 23.033c0 0 1.3 0.1 1.305-1.304c0-1.244-1.305-1.125-1.305-1.125 h-15.818c-2.251 0-2.012 1.717-2.012 1.717V36.54l-1.653 0.009c0 0-1.132 0.229-1.132 1.177c0 1.2 1.1 1.4 1.1 1.361h1.669 v4.917c0 2.5 1.7 2.1 1.7 2.073h15.818c0 0 0.9 0 0.889-1.185s-0.95-1.007-0.95-1.007h-14.798v-4.799h15.284 c0 0 0.937-0.177 0.937-1.361c0-1.186-1.125-1.246-1.125-1.246h-15.228V23.033H146.17z"></path>\n    </g>\n    <g id="logo-en">\n      <defs>\n        <rect height="65.7" width="326.9" x="-55"></rect>\n      </defs>\n      <clipPath>\n        <use overflow="visible" xlink:href="#SVGID_1_"></use>\n      </clipPath>\n      <path class="logo-path" d="M41.694 20.162c-1.315 0-1.315 0.987-1.315 0.987l0.094 13.8 c0 0 0.6 8.648-8.178 8.648c0 0-8.364 0.093-8.364-8.082V21.29c0 0 0.234-1.174-1.27-1.174c-1.362 0-1.221 1.174-1.221 1.174V36 c0 0 0.2 10.1 10.9 10.104c10.386 0 10.669-9.675 10.669-10.433V21.243C42.964 21.2 43 20.2 41.7 20.2"></path>\n      <path class="logo-path" d="M20.915 21.431c0 0 0-0.799-0.799-1.127c-0.777-0.321-1.27 0.422-1.457 0.6 l-7.425 10.293c0 0-0.469 0.61-1.034-0.282l-8.13-10.292c0 0-0.517-0.611-1.128-0.423c-0.611 0.189-0.894 0.704-0.846 1.6 L0 44.74c0 0-0.046 1.4 1.3 1.363s1.316-1.222 1.316-1.222V25.144l7.002 9.023c0 0 1.1 1.5 2.209-0.188 c1.081-1.646 6.626-8.882 6.626-8.882v19.736c0 0-0.088 1.3 1.5 1.175c1.175-0.094 0.988-1.22 0.988-1.22V21.431z"></path>\n      <path class="logo-path" d="M168.546 43.734l-10.309-6.813c0 0 8.648-0.179 8.648-8.471 c0-8.294-8.531-8.118-8.531-8.118h-8.412c-2.107 0-1.953 1.6-1.953 1.6v22.69c0 0-0.038 1.5 1.1 1.5 c1.265 0 1.222-1.436 1.222-1.436V22.702h6.516c0.474 0 3.1 0 5.3 1.304c2.192 1.3 3.7 7.198-0.177 9.6 c-2.785 1.717-6.459 1.008-7.642 0.889c-1.185-0.12-1.306 0.414-1.483 1.186c-0.177 0.8 0.9 1.4 0.9 1.362l13.21 8.5 c0 0 1.4 1.2 2.1 0.18C169.967 44.4 168.5 43.7 168.5 43.7"></path>\n      <path class="logo-path" d="M95.522 19.596c-6.516-0.711-11.492 3.376-11.373 7.8 c0.117 4.4 3 5.7 8.1 6.634c5.096 0.9 7 1.7 7 1.658c2.665 1 2.5 4.3 1 5.9 c-1.423 1.601-4.148 2.558-5.766 2.616c-3.879 0.146-6.052-2.374-6.052-2.374c-0.492-0.407-0.683-1.486-1.69-1.25 c-1.347 0.316-0.296 1.836-0.296 1.836c2.311 3.2 7.2 3.6 7.2 3.554c5.45 0.7 8.648-3.139 8.648-3.139 c2.963-3.852 0.987-8.363-1.976-9.429c-3.17-1.142-6.139-1.234-10.05-2.065c-3.909-0.828-3.495-4.087-3.495-4.087 c0.059-2.37 2.252-5.271 7.643-5.332c5.392-0.059 8.5 3.4 8.5 3.436c1.304 1.4 2.1 0.5 2.133-0.12 c0.06-0.591-0.058-1.183-0.531-1.776C104.121 23.1 102 20.3 95.5 19.6"></path>\n      <path class="logo-path" d="M124.084 20.618c-1.126 0-1.185 1.067-1.185 1.067v15.166h-14.336V21.862 c0 0 0.296-1.42-1.305-1.362c-1.304 0.047-1.067 1.42-1.067 1.42v14.575h-0.889c0 0-1.303-0.06-1.303 1.2 c0 1.3 1.2 1.3 1.2 1.305h1.007v5.746c0 0 0 1.2 1.2 1.243c1.246 0 1.187-1.184 1.187-1.184v-5.984h14.1v6.103 c0 0-0.008 1.1 1.2 1.137c1.226 0 1.269-1.195 1.269-1.195V21.743C125.209 21.7 125.2 20.6 124.1 20.6"></path>\n      <path class="logo-path" d="M86.101 44.016c0 0-10.841-21.504-11.849-23.163c-1.007-1.66-2.072 0-2.072 0 l-8.047 15.604l-2.395 0.015c-0.888 0-0.982 0.633-0.982 1.284c0 1.1 1.1 0.9 1.1 0.929h1.067c0 0-2.447 4.637-2.726 5.3 c-0.355 0.889-0.416 1.5 0.5 1.955c1.008 0.5 1.659-0.77 1.659-0.77l3.436-6.399H80.71l2.903 5.9 c0 0 1 2 2.1 1.305C86.87 45.3 86.1 44 86.1 44 M66.965 36.374l5.984-12.026c0 0 0.296-0.475 0.6 0.1 c0.296 0.5 6 12 6 11.967H66.965z"></path>\n      <path class="logo-path" d="M58.314 34.283c0 0 3.87-1.954 3.87-6.575c0-4.622-4.563-7.199-8.294-7.199 h-6.517c0 0-1.512 0.2-1.512 1.744v10.479h-1.833c0 0-0.799-0.094-0.799 1.271c0 1.1 0.6 1.2 0.6 1.173h2.066v9.447 c0 0-0.046 1.5 1.5 1.48h7.213c0 0 6.016-0.165 6.016-6.837C60.57 35.9 58.3 34.3 58.3 34.3 M48.203 22.7 l6.338-0.005c1.718 0 5.1 1.7 5.1 5.451c0 4.443-5.095 4.501-5.095 4.501h-6.338V22.736z M53.557 43.831h-5.351v-8.748 l6.435-0.008c0.858 0 3.5 0.9 3.5 4.031C58.143 43.7 53.6 43.8 53.6 43.8"></path>\n      <path class="logo-path" d="M146.17 23.033c0 0 1.3 0.1 1.305-1.304c0-1.244-1.305-1.125-1.305-1.125 h-15.818c-2.251 0-2.012 1.717-2.012 1.717V36.54l-1.653 0.009c0 0-1.132 0.229-1.132 1.177c0 1.2 1.1 1.4 1.1 1.361h1.669 v4.917c0 2.5 1.7 2.1 1.7 2.073h15.818c0 0 0.9 0 0.889-1.185s-0.95-1.007-0.95-1.007h-14.798v-4.799h15.284 c0 0 0.937-0.177 0.937-1.361c0-1.186-1.125-1.246-1.125-1.246h-15.228V23.033H146.17z"></path>\n    </g>\n  </defs>\n</svg>\n  <!--<script type="text/javascript" xmlns:th="http://www.thymeleaf.org" th:fragment="body">-->\n  <!--(function () {-->\n    <!--var em = document.createElement(\'script\');-->\n    <!--em.type = \'text/javascript\';-->\n    <!--em.async = true;-->\n    <!--em.src =-->\n      <!--(\'https:\' == document.location.protocol ? \'https://me-ssl\' : \'http://me-cdn\') + \'.effectivemeasure.net/em.js\';-->\n    <!--var s = document.getElementsByTagName(\'script\')[0];-->\n    <!--s.parentNode.insertBefore(em, s);-->\n  <!--}());-->\n<!--</script>-->\n\n\n  <div class="">\n\n    <header class="header">\n      <!-- DESKTOP ADS BLOCK -->\n\n      <!-- DESKTOP ADS BLOCK -->\n      <!-- MOBILE ADS BLOCK -->\n      \n\n      \n      <!-- MOBILE ADS BLOCK -->\n      <div class="header__top-for-mobile">\n        <div class="top-bar__triggers">\n          <a class="main-menu-trigger fa fa-bars fa-2x" href="#main-menu" style="float: right;"></a>\n          <!-- Logo -->\n          <div class="header__logo header-logo-margins" onclick="window.location.href=\'/countries/sa\'">\n            \n  <svg viewBox="0 0 494.387 190.555">\n    <use xlink:href="#logo-white"></use>\n  </svg>\n  \n\n          </div>\n          <a class="countries-menu-trigger header-country-margins" href="#countries-menu">\n            <span>السعودية</span>\n            <span class="fa fa-caret-down fa-4x"></span>\n          </a>\n          <!-- ngRepeat: image in images --><img ng-repeat="image in images" src="/assets/ui/images/mobile-logo-G20.png" class="ng-scope"><!-- end ngRepeat: image in images --><img ng-repeat="image in images" src="/assets/ui/images/mobile-logo-vision.png" class="ng-scope"><!-- end ngRepeat: image in images -->\n          <div class="header__left-side left-search-icon">\n            <a class="search-trigger js-search-trigger fa fa-search fa-2x" href="javascript:;" style="float: left;">\n            </a>\n          </div>\n        </div>\n        <!-- Search -->\n        <div class="search js-search" id="search">\n          <i class="fa fa-search fa-2x search__icon"></i>\n          <angucomplete-alt id="autocomplete__companies" input-class="search__input" minlength="1" ng-controller="AutocompleteController" pause="400" placeholder="اكتب كلمة البحث أو رمز الشركة" selected-object="selectItem" text-no-results="عفواً, لم يتم العثور على أي نتائج" text-searching="جارٍ البحث..." title-field="label" remote-url="/api/1/companySearch?query=" class="ng-scope ng-isolate-scope"><div class="angucomplete-holder" ng-class="{\'angucomplete-dropdown-visible\': showDropdown}">  <input id="autocomplete__companies_value" ng-model="searchStr" ng-disabled="disableInput" type="" placeholder="اكتب كلمة البحث أو رمز الشركة" maxlength="524288" ng-focus="onFocusHandler()" class="search__input ng-valid-maxlength" ng-blur="hideResults($event)" autocapitalize="off" autocorrect="off" autocomplete="off" ng-change="inputChangeHandler(searchStr)">  <div id="autocomplete__companies_dropdown" class="angucomplete-dropdown ng-hide" ng-show="showDropdown"><div class="angucomplete-searching ng-hide" ng-show="searching"><div class="spinner"><div class="dot1"></div><div class="dot2"></div></div></div>    <div class="angucomplete-searching ng-binding" ng-show="!searching &amp;&amp; (!results || results.length == 0)" ng-bind="textNoResults">عفواً, لم يتم العثور على أي نتائج</div>    <!-- ngRepeat: result in results -->  </div></div></angucomplete-alt>\n        </div>\n      </div>\n      <div class="header-desktop mi-show-for-large-up">\n        <div class="header__top-for-desktop">\n          <div class="header__top-for-desktop-row">\n            <a class="header__other-site" href="http://tawasul.mubasher.info/" target="_blank">\n              <i class="fa fa-caret-right fa-2x"></i>\n              تواصل\n            </a>\n            <a class="header__other-site" href="http://magazine.mubasher.info/" target="_blank">\n              <i class="fa fa-caret-right fa-2x"></i>\n              مجلة مباشر\n            </a>\n            <a class="header__other-site" href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">\n              <i class="fa fa-play-circle"></i>\n              <div style="direction: ltr; display: inline-block;">TV مباشر</div>\n            </a>\n            \n            <a class="header__other-site" href="/contact">\n              <i class="fa fa-envelope"></i>\n              اتصل بنا\n            </a>\n            <a class="header__other-site" href="/advertise">\n              <i class="fa fa-envelope"></i>\n              اعلن معنا\n            </a>\n            <!-- <a th:if="${#locale.getLanguage() == \'ar\'}" class="header__login-button" style="background: #458D37 !important;" th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank"\n                th:text="#{components.header.decypha}">ديسيفا</a>\n            <a th:if="${#locale.getLanguage() == \'en\'}" class="header__login-button" style="background: #458D37 !important; font-family: Roboto,sans-serif !important;" th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank"\n                th:text="#{components.header.decypha}">ديسيفا</a> -->\n\n            <!-- Page Content Buttons -->\n            <a class="header__login-button" ng-click="decypha(\'decypha\')" style="background: #458D37 !important; font-family: Roboto,sans-serif !important;">ديسيفا</a>\n            <!-- Page Content Button -->\n\n            <!--Add according to MFP-187-->\n            <a class="header__login-button" style="background: #00c2d6 !important;" target="_blank" href="https://contest.mubasher.info/#/home">المستثمر اﻷول</a>\n            \n\n            <style>\n\n              /*.pulse-logo{*/\n              /*display: inline-block;*/\n              /*width: 252px;*/\n              /*height: 100%;*/\n              /*background: #212121 url(../images/pulse-logo.png) no-repeat center 2px;*/\n              /*padding: 10px 50px 29px;*/\n              /*text-align: center;*/\n              /*color: black;*/\n              /*text-decoration: none;*/\n              /*margin-top: -6px;*/\n\n              /*}*/\n\n              .pulse-logo2{\n                padding: 5px 5px 4px;\n                min-width: 82px;\n                min-height: 21px;\n                max-width: 27%;\n              }\n\n            </style>\n\n            <a target="_blank" href="https://pulse.mubasher.info">\n              <img class="pulse-logo2" src="../../../images/pulse-logo.png">\n            </a>\n\n\n            <span class="header__spacer">\n              &nbsp;\n            </span>\n\n            <a class="header__social-link" target="_blank" href="https://twitter.com/mubasher"><i class="fa fa-twitter fa-lg"></i></a>\n            <a class="header__social-link" href="https://www.facebook.com/Mubasher.Info"><i class="fa fa-facebook fa-lg"></i></a>\n            <a class="header__social-link" href="https://www.youtube.com/channel/UC7hnxb7gD4nKZdZk3ZlZCYg">\n              <i class="fa fa-youtube fa-lg"></i>\n            </a>\n            <a class="header__social-link" href="https://www.linkedin.com/company/1477149">\n              <i class="fa fa-linkedin fa-lg"></i>\n            </a>\n            <a class="header__social-link" href="/news/rss"><i class="fa fa-rss fa-lg"></i></a>\n            <a class="header__social-link" href="https://play.google.com/store/apps/details?id=net.mis.mubasherinfo">\n              <i class="fa fa-android fa-lg"></i>\n            </a>\n            <a class="header__social-link" href="https://itunes.apple.com/app/imubasher/id494539772?mt=8">\n              <i class="fa fa-apple fa-lg"></i>\n            </a>\n\n            <a class="header__login-button" href="/account/login">\n              دخول\n              <i class="fa fa-user fa-lg"></i>\n            </a>\n            \n            \n            <a class="header__language" href="https://english.mubasher.info">\n              <span>ENGLISH</span>\n            </a>\n          </div>\n        </div>\n        <div class="header__columns">\n          <div class="header__column1">\n            <!-- Logo -->\n            <div class="header__logo-wrapper">\n              <div class="header__logo" onclick="window.location.href=\'/countries/sa\'">\n                \n  <svg viewBox="0 0 494.387 190.555">\n    <use xlink:href="#logo"></use>\n  </svg>\n  \n\n              </div>\n\n              <div class="countries-menu-trigger">\n                <a href="javascript:;" id="mi-js-countries-menu-trigger">\n                  <span>السعودية</span>\n                  <span class="fa fa-caret-down"></span>\n                </a>\n                <nav class="header__countries-menu--desktop mi-js-countries-menu-desktop" style="">\n                  <ul>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=ae&amp;url=/countries/sa/companies">الإمارات</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=bh&amp;url=/countries/sa/companies">البحرين</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=om&amp;url=/countries/sa/companies">عُمان</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=qa&amp;url=/countries/sa/companies">قطر</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=kw&amp;url=/countries/sa/companies">الكويت</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=eg&amp;url=/countries/sa/companies">مصر</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=jo&amp;url=/countries/sa/companies">الأردن</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=tn&amp;url=/countries/sa/companies">تونس</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=ma&amp;url=/countries/sa/companies">المغرب</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=ps&amp;url=/countries/sa/companies">فلسطين</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=iq&amp;url=/countries/sa/companies">العراق</a>\n                    </li>\n                  </ul>\n                </nav>\n              </div>\n            </div>\n            <!--Market Status -->\n            <div class="header__market-status">\n              <div class="header__market-status-column">\n                <div class="header__market-status-row">\n                  <a class="header__market-name" href="/markets/TDWL">TDWL</a>\n                  <span class="header__market-status--close">مغلق</span>\n                </div>\n                \n              </div>\n              <span class="header__market-time">12 أغسطس 04:32 م</span>\n            </div>\n          </div>\n\n          <div class="header__column1 banner-logo-desktop" ng-class="{\'banner-desktop-en\':(getLanguage == \'en\')}">\n            <!-- Logo -->\n            <div class="header__logo-wrapper">\n              <!-- ngRepeat: image in images --><div class="header__logo ng-scope" ng-repeat="image in images">\n                  <div class="tooltip tooltipstered"><img src="/assets/ui/images/logo-G20.png">\n                    <span class="tooltiptext ng-binding" ng-class="{\'tooltip-desktop-en\':(getLanguage == \'en\')}" style="left: 95%">مجموعة العشرين 2020</span>\n                  </div>\n              </div><!-- end ngRepeat: image in images --><div class="header__logo ng-scope" ng-repeat="image in images">\n                  <div class="tooltip tooltipstered"><img src="/assets/ui/images/logo-vision.png">\n                    <span class="tooltiptext ng-binding" ng-class="{\'tooltip-desktop-en\':(getLanguage == \'en\')}" style="left: 95%">رؤية المملكة العربية السعودية 2030</span>\n                  </div>\n              </div><!-- end ngRepeat: image in images -->\n            </div>\n          </div>\n\n<!--          <div class="header__column2">\n\n             &lt;!&ndash;<div th:replace="components/ads/news/dfp/desktop/LB2"/>&ndash;&gt;\n\n            &lt;!&ndash;=====to display default leaderboard ad-slot [728,90] ======&ndash;&gt;\n            <div th:if="${isHomePage}">\n              <div th:replace="components/ads/home/leaderboard"/>\n            </div>\n            <div th:unless="${isHomePage}">\n              <div>\n                <iframe id="leaderboard-ros-001" style="width: 736px; height: 108px;" class="ad-iframe" src="/ads/LB2"></iframe>\n              </div>\n            </div>\n\n\n            </div>-->\n\n           <!--======= billboard 790x250 ============ -->\n        </div>\n\n        <nav class="header__navigation mi-js-desktop-menu-container">\n          <ul class="dl-menu mi-show-for-large-up mi-js-desktop-menu" style="position: static; top: auto;">\n            <li class="dl-menu__menu-item dl-menu__menu-item--iconic-item">\n              <a href="/countries/sa">\n                <i class="fa fa-home fa-2x"></i>\n              </a>\n            </li>\n            <li class="dl-menu__menu-item" id="markets">\n              <a href="javascript:;">الأسواق</a>\n              <div class="mi-js-submenu">\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/markets/TDWL">سوق الأسهم السعودي</a>\n                    </li>\n                    <li>\n                      <a href="/markets/EGX">البورصة المصرية</a>\n                    </li>\n                    <li>\n                      <a href="/markets/DFM">سوق دبي المالي</a>\n                    </li>\n                    <li>\n                      <a href="/markets/ADX">سوق أبوظبي</a>\n                    </li>\n                    <li>\n                      <a href="/markets/BB">بورصة البحرين</a>\n                    </li>\n                  </ul>\n                </div>\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/markets/QE">بورصة قطر</a>\n                    </li>\n                    <li>\n                      <a href="/markets/MSM">سوق مسقط</a>\n                    </li>\n                    <li>\n                      <a href="/markets/BK">سوق الكويت</a>\n                    </li>\n                    <li>\n                      <a href="/markets/ASE">بورصة عمان</a>\n                    </li>\n                  </ul>\n                </div>\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/markets/CSE">سوق الدار البيضاء</a>\n                    </li>\n                    <li>\n                      <a href="/markets/BDT">بورصة تونس</a>\n                    </li>\n                    <li>\n                      <a href="/markets/PEX">سوق فلسطين</a>\n                    </li>\n                    <li>\n                      <a href="/markets/ISX">سوق العراق</a>\n                    </li>\n                  </ul>\n                </div>\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/international-indices">مؤشرات الأسواق العالمية</a>\n                    </li>\n                    <li>\n                      <a href="/markets/commodities-prices">أسعار المعادن والطاقة</a>\n                    </li>\n                    <li>\n                      <a href="/countries/sa/currencies">أسعار العملات</a>\n                    </li>\n                    <!--<li>\n                      <a th:href="${@url.to(\'RMPC#regionalMap\')}"\n                         th:text="#{navigation.markets.regional-map}"/>\n                    </li>-->\n                  </ul>\n                </div>\n              </div>\n            </li>\n            <li class="dl-menu__menu-item" id="news">\n              <a href="javascript:;">الأخبار</a>\n              <div class="mi-js-submenu">\n                <ul class="dl-submenu">\n                  <li>\n                    <a href="javascript:;">يحدث الآن</a>\n                    <div class="nav-column">\n                      <h3>يحدث الآن</h3>\n                      <ul class="dl-submenu">\n                        <li>\n                          <a href="/news/sa/now/top">أهم الأخبار</a>\n                        </li>\n                        <li>\n                          <a href="/news/sa/now/exclusive">حصرياً مباشر</a>\n                        </li>\n                        <li>\n                          <a href="/news/sa/now/latest">آخر الأخبار</a>\n                        </li>\n                        \n                          <li>\n                            <a href="/news/sa/now/announcements">إعلانات السوق</a>\n                          </li>\n                          \n                        \n                        <li class="global__hide-for-ltr">\n                          <a href="/news/sa/now/popular">منتشر الآن</a>\n                        </li>\n                        <li>\n                          <a href="/news/sa/now/trending/">الأكثر مشاركة</a>\n                        </li>\n                        <li>\n                          <a href="/news/now/news-releases">بيانات صحفية</a>\n                        </li>\n                        <li>\n                          <a href="/news/international/misc">أخبار منوعة</a>\n                        </li>\n                      </ul>\n                    </div>\n                  </li>\n                  <li>\n                    <a href="javascript:;">نبض السوق</a>\n                    <div class="nav-column">\n                      <h3>نبض السوق</h3>\n                      <ul class="dl-submenu">\n                        <li>\n                          <a href="/news/sa/pulse/stocks">أخبار الأسهم</a>\n                        </li>\n                        <li>\n                          <a href="/news/sa/pulse/analysis">تحليلات إخبارية</a>\n                        </li>\n                        <li>\n                          <a href="/news/sa/pulse/local">اقتصاد محلي</a>\n                        </li>\n                        <li>\n                          <a href="/news/sa/pulse/recommendations">توصيات</a>\n                        </li>\n                      </ul>\n                      <h3>أخبار القطاعات</h3>\n                      <ul class="dl-submenu">\n                        <li>\n                          <a href="/news/sa/category/banking">بنوك</a>\n                        </li><li>\n                          <a href="/news/sa/category/realEstate">عقارات</a>\n                        </li>\n                      </ul>\n                    </div>\n                  </li>\n                  <li>\n                    <a href="javascript:;">أخبار الدول</a>\n                    <div class="nav-column">\n                      <h3>أخبار الدول</h3>\n                      <ul class="dl-submenu">\n                        <li>\n                          <a href="/news/eg/now/latest">مصر</a>\n                        </li>\n                        <li>\n                          <a href="/news/sa/now/latest">السعودية</a>\n                        </li>\n                        <li>\n                          <a href="/news/ae/now/latest">الإمارات</a>\n                        </li>\n                        <li>\n                          <a href="/news/bh/now/latest">البحرين</a>\n                        </li>\n                        <li>\n                          <a href="/news/qa/now/latest">قطر</a>\n                        </li>\n                        <li>\n                          <a href="/news/om/now/latest">عمان</a>\n                        </li>\n                      </ul>\n                    </div>\n                  </li>\n                  <li>\n                    <a href="javascript:;">أخبار الدول</a>\n                    <div class="nav-column">\n                      <h3 class="invisible">أخبار الدول</h3>\n                      <ul class="dl-submenu">\n                        <li>\n                          <a href="/news/kw/now/latest">الكويت</a>\n                        </li>\n                        <li>\n                          <a href="/news/jo/now/latest">الأردن</a>\n                        </li>\n                        <li>\n                          <a href="/news/ma/now/latest">المغرب</a>\n                        </li>\n                        <li>\n                          <a href="/news/tn/now/latest">تونس</a>\n                        </li>\n                        <li>\n                          <a href="/news/ps/now/latest">فلسطين</a>\n                        </li>\n                        <li>\n                          <a href="/news/iq/now/latest">العراق</a>\n                        </li>\n                      </ul>\n                    </div>\n                  </li>\n                  <li>\n                    <a href="javascript:;">أخبار إقليمية</a>\n                    <div class="nav-column">\n                      <h3>أخبار إقليمية</h3>\n                      <ul class="dl-submenu">\n                        <li>\n                          <a href="/news/regions/gulf">الخليج</a>\n                        </li>\n                        <li>\n                          <a href="/news/regions/levant">الشام</a>\n                        </li>\n                        <li>\n                          <a href="/news/regions/north-africa">شمال أفريقيا</a>\n                        </li>\n                        <li>\n                          <a href="/news/regions/middle-east">الشرق الأوسط</a>\n                        </li>\n                      </ul>\n                    </div>\n                  </li>\n\n\n                  <li>\n                    <a href="javascript:;">أخبار عالمية</a>\n                    <div class="nav-column">\n                      <h3>أخبار عالمية</h3>\n                      <ul class="dl-submenu">\n                        <li>\n                          <a href="/news/international/global-economy">اقتصاد عالمى</a>\n                        </li>\n                        <li>\n                          <a href="/news/international/goods-and-metals">أحداث عالمية</a>\n                        </li>\n                        <li>\n                          <a href="/news/international/global-indices">مؤشرات عالمية</a>\n                        </li>\n                        <li>\n                          <a href="/news/international/oil-and-energy">نفط ومعادن</a>\n                        </li>\n                        <li>\n                          <a href="/news/international/currencies">عملات</a>\n                        </li>\n                        <li>\n                          <a href="/news/international/global-reports">تقارير عالمية</a>\n                        </li>\n                      </ul>\n                    </div>\n                  </li>\n                </ul>\n              </div>\n            </li>\n            <li class="dl-menu__menu-item" id="companies">\n              <a href="javascript:;">الشركات</a>\n              <div class="mi-js-submenu">\n                <div class="nav-column">\n                  <h3 class="invisible">.</h3>\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/countries/sa/companies">الشركات المدرجة</a>\n                    </li>\n                    <li>\n                      <a href="/countries/sa/events">مفكرة الشركات</a>\n                    </li>\n                    <li>\n                      <a href="/countries/sa/stock-prices">أسعار الأسهم</a>\n                    </li>\n                    <li>\n                      <a href="/countries/sa/fair-values">القيم العادلة</a>\n                    </li>\n                  </ul>\n                </div>\n                <div class="nav-column">\n                  <h3 class="invisible">.</h3>\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/countries/sa/earnings">إعلانات الأرباح</a>\n                    </li>\n                    <li>\n                      <a href="/countries/sa/corporate-action">الإجراءات</a>\n                    </li>\n                    \n                    <li>\n                      <a href="/countries/sa/major-shareholders">كبار الملاك</a>\n                    </li>\n                    <li>\n                      <a href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>\n                    </li>\n                  </ul>\n                </div>\n                <div class="nav-column">\n                  <h3>الاكتتابات</h3>\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/countries/sa/ipos">قائمة الإكتتابات</a>\n                    </li>\n                    <li>\n                      <a href="/ipo/list">بحث فى الاكتتابات</a>\n                    </li>\n                    <li>\n                      <a href="/ipos/news">أخبار الاكتتابات</a>\n                    </li>\n                    <li>\n                      <a href="/ipo/calendar">مفكرة الاكتتابات</a>\n                    </li>\n                  </ul>\n                </div>\n              </div>\n            </li>\n            <li class="dl-menu__menu-item" id="funds">\n              <a href="javascript:;">صناديق الاستثمار</a>\n              <div class="mi-js-submenu">\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/countries/sa/funds">صناديق الاستثمار</a>\n                    </li>\n                  </ul>\n                </div>\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/countries/sa/funds-statistics">إحصائيات الصناديق</a>\n                    </li>\n                  </ul>\n                </div>\n              </div>\n            </li>\n            <li class="dl-menu__menu-item" id="analysis-tools">\n              <a href="javascript:;">أدوات التحليل</a>\n              <!-- If current country has one market only -->\n              <div class="mi-js-submenu">\n                \n                  <div class="nav-column">\n                    <ul class="dl-submenu">\n                      <li>\n                        <a href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>\n                      </li>\n                      <li>\n                        <a href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>\n                      </li>\n                      <li>\n                        <a href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>\n                      </li>\n                    </ul>\n                  </div>\n                  <div class="nav-column">\n                    <ul class="dl-submenu">\n                      <li>\n                        <a href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>\n                      </li>\n                      <li>\n                        <a href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>\n                      </li>\n                      <li>\n                        <a href="/analysis-tools/performance-comparison">مقارنة الأداء</a>\n                      </li>\n                    </ul>\n                  </div>\n                \n\n                \n              </div>\n            </li>\n            <li class="dl-menu__menu-item" id="islamic-economy">\n              <a href="/news/islamic-finance">الاقتصاد الإسلامي</a>\n            </li>\n            <!--<li id="radio"\n                class="dl-menu__menu-item global__hide-for-ltr"\n                id="radio"\n                th:if="${#locale.getLanguage() == \'ar\'}">\n              <a href="javascript:;" th:text="#{navigation.radio}"/>\n              <div class="mi-js-submenu">\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a th:href="${@url.to(\'RPC#live\')}" th:text="#{navigation.radio.live}"/>\n                    </li>\n                    <li>\n                      <a th:href="${@url.to(\'RPC#latestEpisodesPage\', countryCode)}">آخر الحلقات</a>\n                    </li>\n                    <li>\n                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تقارير-اقتصادية\'}">تقارير\n                        اقتصادية</a>\n                    </li>\n                    <li>\n                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تغطية-خاصة\'}">تغطية خاصة</a>\n                    </li>\n                    <li>\n                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'مقالات\'}">مقالات</a>\n                    </li>\n                  </ul>\n                </div>\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a th:href="${@url.to(\'RPC#programs\')}" th:text="#{navigation.radio.programs}"/>\n                    </li>\n                    <li>\n                      <a th:href="${@url.to(\'RPC#videoPrograms\')}" th:text="#{navigation.radio.videoPrograms}"/>\n                    </li>\n                    <li>\n                      <a th:href="${@url.to(\'RPC#getExperts\')}">ضيوفنا</a>\n                    </li>\n                    <li>\n                      <a th:href="${@url.to(\'RPC#getPresenters\')}">المذيعون</a>\n                    </li>\n                  </ul>\n                </div>\n              </div>\n            </li>-->\n            <li class="dl-menu__menu-item global__hide-for-ltr" id="video">\n              <a href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">مباشر TV</a>\n            </li>\n            \n            <li class="dl-menu__menu-item" id="fixedincome">\n              <a href="javascript:;">السندات</a>\n              <div class="mi-js-submenu">\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/fixedincome/bond/search" id="fixedIncomeBondScreener">بحث عن سندات</a>\n                    </li>\n                    <li>\n                      <a href="/fixed-income/news" id="fixedIncomeNews">أخبار السندات وأذون الخزانة</a>\n                    </li>\n                    <li>\n                      <a href="/fixedincome/calendar/searchForEvent" id="fixedIncomeCalendar">قائمة الأحداث</a>\n                    </li>\n                  </ul>\n                </div>\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/fixedincome/analytics/drawCurve" id="fixedIncomeAnalytics">تحليلات فنية</a>\n                    </li>\n                    <li>\n                      <a href="/fixedincome/leagueTables/view" id="fixedIncomeLeagueTables">جداول الديون</a>\n                    </li>\n                    <li>\n                      <a href="/fixedincome/research/search" id="fixedIncomeProspectus">تقارير</a>\n                    </li>\n                  </ul>\n                </div>\n              </div>\n            </li>\n            <li class="dl-menu__menu-item" id="personal">\n              <a href="javascript:;">شخصي</a>\n              <div class="mi-js-submenu">\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/my/alerts">التنبيهات</a>\n                    </li>\n                    <li>\n                      <a href="/my/watch-list">أسهمي</a>\n                    </li>\n                    <li>\n                      <a href="/my/newsletters">النشرة البريدية</a>\n                    </li>\n                  </ul>\n                </div>\n              </div>\n            </li>\n            <li class="dl-menu__menu-item dl-menu__menu-item--iconic-item">\n              <a class="js-search-trigger" href="javascript:;">\n                <i class="fa fa-search fa-2x"></i>\n              </a>\n            </li>\n          </ul>\n          <!-- Search -->\n          <div class="search js-search js-desktop-search" id="search" style="position: absolute; top: 0px;">\n            <angucomplete-alt id="autocomplete__companies" input-class="search__input" minlength="1" ng-controller="AutocompleteController" pause="400" selected-object="selectItem" text-no-results="عفواً, لم يتم العثور على أي نتائج" text-searching="جارٍ البحث..." title-field="label" remote-url="/api/1/companySearch?query=" placeholder="اكتب كلمة البحث أو رمز الشركة" class="ng-scope ng-isolate-scope"><div class="angucomplete-holder" ng-class="{\'angucomplete-dropdown-visible\': showDropdown}">  <input id="autocomplete__companies_value" ng-model="searchStr" ng-disabled="disableInput" type="" placeholder="اكتب كلمة البحث أو رمز الشركة" maxlength="524288" ng-focus="onFocusHandler()" class="search__input ng-valid-maxlength" ng-blur="hideResults($event)" autocapitalize="off" autocorrect="off" autocomplete="off" ng-change="inputChangeHandler(searchStr)">  <div id="autocomplete__companies_dropdown" class="angucomplete-dropdown ng-hide" ng-show="showDropdown"><div class="angucomplete-searching ng-hide" ng-show="searching"><div class="spinner"><div class="dot1"></div><div class="dot2"></div></div></div>    <div class="angucomplete-searching ng-binding" ng-show="!searching &amp;&amp; (!results || results.length == 0)" ng-bind="textNoResults">عفواً, لم يتم العثور على أي نتائج</div>    <!-- ngRepeat: result in results -->  </div></div></angucomplete-alt>\n            <i class="fa fa-search fa-2x"></i>\n          </div>\n        </nav>\n      </div>\n    </header>\n\n    <div id="Leaderboard">\n    </div>\n\n    <div></div>\n\n    <div class="mi-content">\n      <div>\n  <!--<div th:replace="components/ads/internal/mobile-banner" />-->\n\n  <main class="mi-main-content">\n    \n  <h1 class="mi-section__title">الشركات المدرجة</h1>\n\n  <div class="mi-table-container ng-scope" ng-controller="PagedTableController as table" country="sa" src="/api/1/listed-companies">\n    <div class="global__table-container md-whiteframe-z1 ng-isolate-scope" st-init="" st-pipe="fetch" st-table="table.data">\n      <span class="global__no-results ng-hide" ng-show="table.rows.length == 0 &amp;&amp; table.loaded">عفواّ, لم نعثر على أى نتائج</span>\n      <table class="mi-table" ng-hide="!table.loaded || table.rows.length == 0" style="">\n\n        <thead class="mi-table__thead">\n          <tr class="mi-table__thead-tr">\n            <th st-ratio="20" style="width: 20%;">الشركة</th>\n            <th>السهم</th>\n            <th class="mi-hide-for-small">القطاع</th>\n            \n            <th>آخر سعر</th>\n            <th>نسبة التغيير</th>\n            <th class="mi-hide-for-small">آخر تحديث</th>\n          </tr>\n        </thead>\n        <tbody class="mi-table__tbody" ng-hide="table.reloading">\n          <!-- ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/3050/profile" class="ng-binding" href="/markets/TDWL/stocks/3050/profile">أسمنت الجنوب</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/3050" class="ng-binding" href="/markets/TDWL/stocks/3050">3050</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>\n            \n            <td class="number ng-binding">63.7</td>\n            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              -0.62%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/3060/profile" class="ng-binding" href="/markets/TDWL/stocks/3060/profile">أسمنت ينبع</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/3060" class="ng-binding" href="/markets/TDWL/stocks/3060">3060</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>\n            \n            <td class="number ng-binding">31.75</td>\n            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              -0.78%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/3080/profile" class="ng-binding" href="/markets/TDWL/stocks/3080/profile">أسمنت الشرقية</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/3080" class="ng-binding" href="/markets/TDWL/stocks/3080">3080</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>\n            \n            <td class="number ng-binding">34.65</td>\n            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              -0.72%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/3090/profile" class="ng-binding" href="/markets/TDWL/stocks/3090/profile">أسمنت تبوك</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/3090" class="ng-binding" href="/markets/TDWL/stocks/3090">3090</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>\n            \n            <td class="number ng-binding">13.32</td>\n            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              -0.30%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2180/profile" class="ng-binding" href="/markets/TDWL/stocks/2180/profile">فيبكو</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2180" class="ng-binding" href="/markets/TDWL/stocks/2180">2180</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>\n            \n            <td class="number ng-binding">45</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              2.39%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2010/profile" class="ng-binding" href="/markets/TDWL/stocks/2010/profile">سابك</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2010" class="ng-binding" href="/markets/TDWL/stocks/2010">2010</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>\n            \n            <td class="number ng-binding">88.2</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              0.34%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2020/profile" class="ng-binding" href="/markets/TDWL/stocks/2020/profile">سافكو</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2020" class="ng-binding" href="/markets/TDWL/stocks/2020">2020</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>\n            \n            <td class="number ng-binding">84.1</td>\n            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              -1.06%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2200/profile" class="ng-binding" href="/markets/TDWL/stocks/2200/profile">أنابيب</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2200" class="ng-binding" href="/markets/TDWL/stocks/2200">2200</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>\n            \n            <td class="number ng-binding">12.88</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              0.63%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2240/profile" class="ng-binding" href="/markets/TDWL/stocks/2240/profile">الزامل للصناعة</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2240" class="ng-binding" href="/markets/TDWL/stocks/2240">2240</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>\n            \n            <td class="number ng-binding">17.02</td>\n            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              -0.23%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2210/profile" class="ng-binding" href="/markets/TDWL/stocks/2210/profile">نماء للكيماويات</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2210" class="ng-binding" href="/markets/TDWL/stocks/2210">2210</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>\n            \n            <td class="number ng-binding">22.8</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              0.09%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2220/profile" class="ng-binding" href="/markets/TDWL/stocks/2220/profile">معدنية</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2220" class="ng-binding" href="/markets/TDWL/stocks/2220">2220</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>\n            \n            <td class="number ng-binding">17.08</td>\n            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              -1.04%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2090/profile" class="ng-binding" href="/markets/TDWL/stocks/2090/profile">جبسكو</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2090" class="ng-binding" href="/markets/TDWL/stocks/2090">2090</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>\n            \n            <td class="number ng-binding">17.14</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              0.23%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2250/profile" class="ng-binding" href="/markets/TDWL/stocks/2250/profile">المجموعة السعودية</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2250" class="ng-binding" href="/markets/TDWL/stocks/2250">2250</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>\n            \n            <td class="number ng-binding">20.3</td>\n            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              -0.98%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2230/profile" class="ng-binding" href="/markets/TDWL/stocks/2230/profile">الكيميائية</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2230" class="ng-binding" href="/markets/TDWL/stocks/2230">2230</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">الرعاية الصحية</td>\n            \n            <td class="number ng-binding">25.8</td>\n            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              -0.39%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2040/profile" class="ng-binding" href="/markets/TDWL/stocks/2040/profile">الخزف السعودي</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2040" class="ng-binding" href="/markets/TDWL/stocks/2040">2040</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">السلع الرأسمالية</td>\n            \n            <td class="number ng-binding">39.1</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              0.90%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2050/profile" class="ng-binding" href="/markets/TDWL/stocks/2050/profile">مجموعة صافولا</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2050" class="ng-binding" href="/markets/TDWL/stocks/2050">2050</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">إنتاج الأغذية</td>\n            \n            <td class="number ng-binding">47.7</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              1.71%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2060/profile" class="ng-binding" href="/markets/TDWL/stocks/2060/profile">التصنيع</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2060" class="ng-binding" href="/markets/TDWL/stocks/2060">2060</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>\n            \n            <td class="number ng-binding">10.82</td>\n            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              -0.18%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2070/profile" class="ng-binding" href="/markets/TDWL/stocks/2070/profile">الدوائية</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2070" class="ng-binding" href="/markets/TDWL/stocks/2070">2070</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">الادوية</td>\n            \n            <td class="number ng-binding">31.6</td>\n            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              -2.47%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2140/profile" class="ng-binding" href="/markets/TDWL/stocks/2140/profile">أيان</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2140" class="ng-binding" href="/markets/TDWL/stocks/2140">2140</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">السلع الرأسمالية</td>\n            \n            <td class="number ng-binding">13.5</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              0.90%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2120/profile" class="ng-binding" href="/markets/TDWL/stocks/2120/profile">متطورة</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2120" class="ng-binding" href="/markets/TDWL/stocks/2120">2120</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">الإستثمار والتمويل</td>\n            \n            <td class="number ng-binding">14.22</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              1.28%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index -->\n        </tbody>\n      </table>\n      <div ng-show="table.searcing" class="ng-hide">\n        <span class="global__loading">جارى التصفية, يرجى الإنتظار ...</span>\n        <div>\n    <div class="sk-spinner sk-spinner-wave">\n        <div class="sk-rect1"></div>\n        <div class="sk-rect2"></div>\n        <div class="sk-rect3"></div>\n        <div class="sk-rect4"></div>\n        <div class="sk-rect5"></div>\n    </div>\n</div>\n      </div>\n      <div ng-hide="table.loaded" class="ng-hide" style="">\n        <div>\n    <div class="sk-spinner sk-spinner-wave">\n        <div class="sk-rect1"></div>\n        <div class="sk-rect2"></div>\n        <div class="sk-rect3"></div>\n        <div class="sk-rect4"></div>\n        <div class="sk-rect5"></div>\n    </div>\n</div>\n      </div>\n      <div st-items-by-page="20" st-pagination="" st-template="/assets/ui/ngt/components/pagination/pagination.ng.html" class="ng-isolate-scope"><!-- ngIf: pages.length >= 2 --><div class="pagination ng-scope" ng-if="pages.length >= 2">\n    <nav role="navigation" aria-label="Pagination">\n        <ul class="cd-pagination no-space" role="menubar" aria-label="Pagination">\n            <!-- ngIf: currentPage > 1 --><li ng-if="currentPage > 1" class="ng-scope">\n                <a ng-click="selectPage(1)">\n                    <i class="fa fa-angle-double-right fa-lg"></i>\n                </a>\n            </li><!-- end ngIf: currentPage > 1 -->\n            <!-- ngIf: currentPage > 1 --><li class="cd-pagination__button ng-scope" aria-disabled="true" ng-if="currentPage > 1">\n                <a ng-click="selectPage(currentPage-1)" class="ng-binding">\n                  <i class="fa fa-lg fa-angle-right"></i>\n                  السابق\n                </a>\n            </li><!-- end ngIf: currentPage > 1 -->\n            <!-- ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">\n                <a ng-click="selectPage(page)" class="ng-binding">1</a>\n            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope current">\n                <a ng-click="selectPage(page)" class="ng-binding">2</a>\n            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">\n                <a ng-click="selectPage(page)" class="ng-binding">3</a>\n            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">\n                <a ng-click="selectPage(page)" class="ng-binding">4</a>\n            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">\n                <a ng-click="selectPage(page)" class="ng-binding">5</a>\n            </li><!-- end ngRepeat: page in pages -->\n            <!-- ngIf: currentPage < numPages --><li class="cd-pagination__button ng-scope" ng-if="currentPage < numPages">\n                <a ng-click="selectPage(currentPage+1)" href="" class="ng-binding">\n                  التالي\n                    <i class="fa fa-angle-left fa-lg"></i>\n                </a>\n            </li><!-- end ngIf: currentPage < numPages -->\n            <!-- ngIf: currentPage < numPages --><li ng-if="currentPage < numPages" class="ng-scope">\n                <a ng-click="selectPage(numPages)">\n                    <i class="fa fa-angle-double-left  fa-lg"></i>\n                </a>\n            </li><!-- end ngIf: currentPage < numPages -->\n        </ul>\n    </nav>\n</div><!-- end ngIf: pages.length >= 2 -->\n</div>\n    </div>\n  </div>\n\n  \n\n  <!-- Speakol Widget - Removal IB-51 -->\n  <!-- <div th:replace="components/ads/common/speakol-one"/> -->\n\n\n\n\n\n  </main>\n  <aside class="mi-sidebar mi-show-for-large-up">\n    <!-- Radio component doesn\'t exist in English version -->\n\n    <!---->\n\n  <!--  <div th:unless="${device.isMobile()}">\n      <div>\n        <iframe onload="adjustIframeSize(this);" class="ad-iframe" src="/ads/side-bar"></iframe>\n      </div>\n      <script>\n        function adjustIframeSize(self) {\n          var index = 0;\n          var interval = setInterval( function(){\n            if (index < 3) {\n              self.style.height=self.contentDocument.body.scrollHeight +10 + \'px\';self.style.width=\'310px\';\n              index = index + 1;\n            } else {\n              clearInterval(interval)\n            }\n          }, 1);\n\n        }\n\n\n      </script>\n    </div>-->\n    <div>\n\n    <div class="mi-popular-news news-sidebar-mub md-whiteframe-z1 ng-scope" ng-controller="PopularNewsController as popular">\n    <h2 class="global__h2--collapsed">الأخبار الأكثر</h2>\n    <v-tabs active="tabs.active" class="vTabs--secondary ng-isolate-scope" control="tabs">\n      <!-- ngRepeat: page in popular.pages --><v-tab ng-bind="page.title" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope is-active" role="tab" aria-selected="true" tabindex="0">قراءة</v-tab><!-- end ngRepeat: page in popular.pages --><v-tab ng-bind="page.title" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope" role="tab" aria-selected="false" tabindex="-1">مشاركة</v-tab><!-- end ngRepeat: page in popular.pages -->\n    </v-tabs>\n\n    <v-pages active="tabs.active" class="vPages--default ng-isolate-scope" control="tabs" ng-swipe-left="tabs.next()" ng-swipe-right="tabs.previous()">\n      <!-- ngRepeat: page in popular.pages --><v-page ng-bind-html="page.content | unsafe" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope is-active" role="tabpanel">\n    \n    \n<!--      <th:block>\n        <div th:remove="tag" th:if="${i.index == 1}">\n          <div th:replace="components/ads/internal/native" ></div>\n          <div th:replace="components/ads/internal/mobile-native" ></div>\n        </div>\n      </th:block>-->\n      <div class="mi-home-media-block">\n        <a class="mi-home-media-block__image" href="/news/3680410/%D9%87%D9%8A%D8%A6%D8%A9-%D8%A7%D9%84%D9%86%D9%82%D9%84-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%B5%D8%B1%D9%81-%D8%AF%D8%B9%D9%85-%D8%A7%D9%84%D8%A3%D9%81%D8%B1%D8%A7%D8%AF-%D8%A7%D9%84%D8%B9%D8%A7%D9%85%D9%84%D9%8A%D9%86-%D9%81%D9%8A-%D9%86%D8%B4%D8%A7%D8%B7-%D8%AA%D9%88%D8%AC%D9%8A%D9%87-%D8%A7%D9%84%D9%85%D8%B1%D9%83%D8%A8%D8%A7%D8%AA-%D9%82%D8%B1%D9%8A%D8%A8%D8%A7-/">\n          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="فرع تابع لهيئة العامة للنقل السعودية" src="https://static.mubasher.info/File.Story_Image/3e19073c5aca3db54ef2c06eb4bf5ea6/144.jpg">\n        </a>\n        <div class="mi-home-media-block__content">\n          <a class="mi-home-media-block__title" href="/news/3680410/%D9%87%D9%8A%D8%A6%D8%A9-%D8%A7%D9%84%D9%86%D9%82%D9%84-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%B5%D8%B1%D9%81-%D8%AF%D8%B9%D9%85-%D8%A7%D9%84%D8%A3%D9%81%D8%B1%D8%A7%D8%AF-%D8%A7%D9%84%D8%B9%D8%A7%D9%85%D9%84%D9%8A%D9%86-%D9%81%D9%8A-%D9%86%D8%B4%D8%A7%D8%B7-%D8%AA%D9%88%D8%AC%D9%8A%D9%87-%D8%A7%D9%84%D9%85%D8%B1%D9%83%D8%A8%D8%A7%D8%AA-%D9%82%D8%B1%D9%8A%D8%A8%D8%A7-/">هيئة النقل السعودية: صرف دعم الأفراد العاملين في نشاط توجيه المركبات قريباً</a>\n        </div>\n        \n      </div>\n    \n    \n<!--      <th:block>\n        <div th:remove="tag" th:if="${i.index == 1}">\n          <div th:replace="components/ads/internal/native" ></div>\n          <div th:replace="components/ads/internal/mobile-native" ></div>\n        </div>\n      </th:block>-->\n      <div class="mi-home-media-block">\n        <a class="mi-home-media-block__image" href="/news/3680099/%D8%A7%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D8%B5%D8%AF%D8%B1-%D9%82%D8%B1%D8%A7%D8%B1%D8%A7-%D8%A8%D8%B4%D8%A3%D9%86-%D8%A7%D9%84%D9%85%D8%A8%D8%AA%D8%B9%D8%AB%D9%8A%D9%86/">\n          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="وزير التعليم السعودي، حمد بن محمد آل الشيخ، أرشيفية" src="https://static.mubasher.info/File.Story_Image/9e9e9919f67b43d61c15c7fd734289d3/144.jpg">\n        </a>\n        <div class="mi-home-media-block__content">\n          <a class="mi-home-media-block__title" href="/news/3680099/%D8%A7%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D8%B5%D8%AF%D8%B1-%D9%82%D8%B1%D8%A7%D8%B1%D8%A7-%D8%A8%D8%B4%D8%A3%D9%86-%D8%A7%D9%84%D9%85%D8%A8%D8%AA%D8%B9%D8%AB%D9%8A%D9%86/">التعليم السعودية تصدر قراراً بشأن المبتعثين</a>\n        </div>\n        \n      </div>\n    \n    \n<!--      <th:block>\n        <div th:remove="tag" th:if="${i.index == 1}">\n          <div th:replace="components/ads/internal/native" ></div>\n          <div th:replace="components/ads/internal/mobile-native" ></div>\n        </div>\n      </th:block>-->\n      <div class="mi-home-media-block">\n        <a class="mi-home-media-block__image" href="/news/3680101/%D9%85%D8%AD%D8%AF%D8%AB-%D8%A7%D9%84%D8%B0%D9%87%D8%A8-%D9%8A%D8%AA%D9%87%D8%A7%D9%88%D9%89-93-%D8%AF%D9%88%D9%84%D8%A7%D8%B1%D8%A7-%D8%B9%D9%86%D8%AF-%D8%A7%D9%84%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D9%85%D8%B9-%D9%85%D9%83%D8%A7%D8%B3%D8%A8-%D8%A7%D9%84%D8%A3%D8%B3%D9%87%D9%85/">\n          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/caeadbca5bf2481c2d38f04625e51f00/144.jpg">\n        </a>\n        <div class="mi-home-media-block__content">\n          <a class="mi-home-media-block__title" href="/news/3680101/%D9%85%D8%AD%D8%AF%D8%AB-%D8%A7%D9%84%D8%B0%D9%87%D8%A8-%D9%8A%D8%AA%D9%87%D8%A7%D9%88%D9%89-93-%D8%AF%D9%88%D9%84%D8%A7%D8%B1%D8%A7-%D8%B9%D9%86%D8%AF-%D8%A7%D9%84%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D9%85%D8%B9-%D9%85%D9%83%D8%A7%D8%B3%D8%A8-%D8%A7%D9%84%D8%A3%D8%B3%D9%87%D9%85/">محدث.. الذهب يتهاوى 93 دولاراً عند التسوية مع مكاسب الأسهم</a>\n        </div>\n        \n      </div>\n    \n    \n<!--      <th:block>\n        <div th:remove="tag" th:if="${i.index == 1}">\n          <div th:replace="components/ads/internal/native" ></div>\n          <div th:replace="components/ads/internal/mobile-native" ></div>\n        </div>\n      </th:block>-->\n      <div class="mi-home-media-block">\n        <a class="mi-home-media-block__image" href="/news/3679355/%D8%A7%D9%84%D9%84%D9%8A%D8%B1%D8%A9-%D8%A7%D9%84%D8%AA%D8%B1%D9%83%D9%8A%D8%A9-%D8%AA%D9%87%D8%A8%D8%B7-%D8%A5%D9%84%D9%89-%D9%85%D8%B3%D8%AA%D9%88%D9%89-%D8%AA%D8%A7%D8%B1%D9%8A%D8%AE%D9%8A-%D8%AC%D8%AF%D9%8A%D8%AF/">\n          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/1242bfad1995396ce3f6470a3d5584c2/144.jpg">\n        </a>\n        <div class="mi-home-media-block__content">\n          <a class="mi-home-media-block__title" href="/news/3679355/%D8%A7%D9%84%D9%84%D9%8A%D8%B1%D8%A9-%D8%A7%D9%84%D8%AA%D8%B1%D9%83%D9%8A%D8%A9-%D8%AA%D9%87%D8%A8%D8%B7-%D8%A5%D9%84%D9%89-%D9%85%D8%B3%D8%AA%D9%88%D9%89-%D8%AA%D8%A7%D8%B1%D9%8A%D8%AE%D9%8A-%D8%AC%D8%AF%D9%8A%D8%AF/">الليرة التركية تهبط إلى مستوى تاريخي جديد</a>\n        </div>\n        \n      </div>\n    \n    \n<!--      <th:block>\n        <div th:remove="tag" th:if="${i.index == 1}">\n          <div th:replace="components/ads/internal/native" ></div>\n          <div th:replace="components/ads/internal/mobile-native" ></div>\n        </div>\n      </th:block>-->\n      <div class="mi-home-media-block">\n        <a class="mi-home-media-block__image" href="/news/3679705/%D8%B9%D9%85%D9%84%D8%A9-%D8%A7%D9%84%D8%A8%D9%8A%D8%AA%D9%83%D9%88%D9%8A%D9%86-%D8%AA%D8%B9%D8%A7%D9%88%D8%AF-%D8%A7%D9%84%D8%B5%D8%B9%D9%88%D8%AF-%D8%A3%D8%B9%D9%84%D9%89-12-%D8%A3%D9%84%D9%81-%D8%AF%D9%88%D9%84%D8%A7%D8%B1/">\n          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/ab491b6531081c6058fa5b203b6cbecc/144.jpg">\n        </a>\n        <div class="mi-home-media-block__content">\n          <a class="mi-home-media-block__title" href="/news/3679705/%D8%B9%D9%85%D9%84%D8%A9-%D8%A7%D9%84%D8%A8%D9%8A%D8%AA%D9%83%D9%88%D9%8A%D9%86-%D8%AA%D8%B9%D8%A7%D9%88%D8%AF-%D8%A7%D9%84%D8%B5%D8%B9%D9%88%D8%AF-%D8%A3%D8%B9%D9%84%D9%89-12-%D8%A3%D9%84%D9%81-%D8%AF%D9%88%D9%84%D8%A7%D8%B1/">عملة البيتكوين تعاود الصعود أعلى 12 ألف دولار</a>\n        </div>\n        \n      </div>\n    \n    \n<!--      <th:block>\n        <div th:remove="tag" th:if="${i.index == 1}">\n          <div th:replace="components/ads/internal/native" ></div>\n          <div th:replace="components/ads/internal/mobile-native" ></div>\n        </div>\n      </th:block>-->\n      <div class="mi-home-media-block">\n        <a class="mi-home-media-block__image" href="/news/3679783/%D8%A3%D8%B1%D8%A7%D9%85%D9%83%D9%88-%D8%AA%D8%B1%D9%81%D8%B9-%D8%A3%D8%B3%D8%B9%D8%A7%D8%B1-%D8%A7%D9%84%D8%A8%D9%86%D8%B2%D9%8A%D9%86-%D8%A8%D9%86%D8%AD%D9%88-11-%D8%AD%D8%AA%D9%89-10-%D8%B3%D8%A8%D8%AA%D9%85%D8%A8%D8%B1/">\n          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="محطة للتزود بالوقود" src="https://static.mubasher.info/File.Story_Image/cf61a8737c62c57737e53b3677aa2bbc/144.jpg">\n        </a>\n        <div class="mi-home-media-block__content">\n          <a class="mi-home-media-block__title" href="/news/3679783/%D8%A3%D8%B1%D8%A7%D9%85%D9%83%D9%88-%D8%AA%D8%B1%D9%81%D8%B9-%D8%A3%D8%B3%D8%B9%D8%A7%D8%B1-%D8%A7%D9%84%D8%A8%D9%86%D8%B2%D9%8A%D9%86-%D8%A8%D9%86%D8%AD%D9%88-11-%D8%AD%D8%AA%D9%89-10-%D8%B3%D8%A8%D8%AA%D9%85%D8%A8%D8%B1/">أرامكو ترفع أسعار البنزين بنحو 11% حتى 10 سبتمبر</a>\n        </div>\n        \n      </div>\n    \n    \n<!--      <th:block>\n        <div th:remove="tag" th:if="${i.index == 1}">\n          <div th:replace="components/ads/internal/native" ></div>\n          <div th:replace="components/ads/internal/mobile-native" ></div>\n        </div>\n      </th:block>-->\n      <div class="mi-home-media-block">\n        <a class="mi-home-media-block__image" href="/news/3680546/%D8%A8%D9%803-%D8%B6%D9%88%D8%A7%D8%A8%D8%B7-%D8%A7%D9%84%D8%AA%D9%82%D8%A7%D8%B9%D8%AF-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D9%88%D8%B6%D8%AD-%D8%B7%D8%B1%D9%8A%D9%82%D8%A9-%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D8%A7%D9%84%D9%85%D8%B9%D8%A7%D8%B4-%D9%84%D9%85%D9%88%D8%B8%D9%81%D9%8A-%D8%A7%D9%84%D9%82%D8%B7%D8%A7%D8%B9-%D8%A7%D9%84%D8%B9%D8%A7%D9%85/">\n          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="مؤسسة التقاعد السعودية" src="https://static.mubasher.info/File.Story_Image/68cc490a847f0daba3afd0ddbd6d06c8/144.jpg">\n        </a>\n        <div class="mi-home-media-block__content">\n          <a class="mi-home-media-block__title" href="/news/3680546/%D8%A8%D9%803-%D8%B6%D9%88%D8%A7%D8%A8%D8%B7-%D8%A7%D9%84%D8%AA%D9%82%D8%A7%D8%B9%D8%AF-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D9%88%D8%B6%D8%AD-%D8%B7%D8%B1%D9%8A%D9%82%D8%A9-%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D8%A7%D9%84%D9%85%D8%B9%D8%A7%D8%B4-%D9%84%D9%85%D9%88%D8%B8%D9%81%D9%8A-%D8%A7%D9%84%D9%82%D8%B7%D8%A7%D8%B9-%D8%A7%D9%84%D8%B9%D8%A7%D9%85/">بـ3 ضوابط.. التقاعد السعودية توضح طريقة تسوية المعاش لموظفي القطاع العام</a>\n        </div>\n        \n      </div>\n    \n\n    <a class="mi-article-widget__more-button" href="/news/SA/now/popular">\n      <span>المزيد</span>\n      <i class="fa fa-chevron-left"></i>\n    </a>\n  \n  </v-page><!-- end ngRepeat: page in popular.pages --><v-page ng-bind-html="page.content | unsafe" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope" role="tabpanel">\n    \n    \n\n    <a class="mi-article-widget__more-button" href="/news/SA/now/trending/">\n      <span>المزيد</span>\n      <i class="fa fa-chevron-left"></i>\n    </a>\n  \n  </v-page><!-- end ngRepeat: page in popular.pages -->\n    </v-pages>\n  </div>\n    <div id="MPU">\n\n    </div>\n\n    </div>\n\n    <!-- Speakol Widget - Removal IB-51 -->\n    <!-- <div th:replace="components/ads/common/speakol-two"/> -->\n\n<!--    <div th:unless="${device.isMobile()}">\n      <div th:replace="components/ads/insticator/insticator-widget"/>\n    </div>-->\n    <!-- -->\n\n    <!-- PS -->\n    <!--<div th:replace="components/ads/internal/may-like-articles" />-->\n\n    <!--<div th:replace="components/ads/internal/second-fold" />-->\n    <!--    <div th:if="${#locale.getLanguage() == \'ar\'}">\n          <span class="home__title">راديو مباشر</span>\n          <div class="internal-radio-carousel-container"></div>\n        </div>-->\n  </aside>\n\n\n\n<!--  <div th:replace="components/ads/internal/mobile-fullpage"/>-->\n\n  <!--<div th:replace="components/ads/internal/mobile-interstitial"/>-->\n<!--commented out as per Fayoumi\'s request-->\n  <!--<div th:replace="components/ads/internal/mobile-outstream"/>-->\n\n  <!--MFP-228 New Fixed-Replacement-ROS ads-->\n<!--  <div th:replace="components/ads/home/mobile-fixed-replacement"/>\n\n  <div th:replace="components/ads/news/dfp/mobile/MPU3"/>-->\n\n<!--Commented out as per Fayoumi\'s request-->\n  <!--<div th:replace="components/ads/internal/outstream"/>-->\n\n\n\n<!--  <div th:if="${device.isMobile()}">\n    <div th:replace="components/ads/dfp/mobile-internal-pages"/>\n  </div>-->\n\n<!--  <div th:if="${device.isMobile()}">\n    <div th:replace="components/ads/insticator/insticator-widget"/>\n  </div>-->\n\n <!-- <div th:replace="components/ads/internal/mobile-above-footer"/>-->\n</div>\n    </div>\n    <footer>\n  <div class="mi-footer">\n    <div class="mi-show-for-large-up mi-footer__main-menu">\n      <ul>\n        <li class="mi-footer__menu-item mi-footer__menu__markets" id="markets">\n          <div class="mi-footer__menu-level1">الأسواق</div>\n          <ul>\n            <h3 class="mi-footer__menu-level2 invisible">الأسواق</h3>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/TDWL">سوق الأسهم السعودي</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/EGX">البورصة المصرية</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/DFM">سوق دبي المالي</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/ADX">سوق أبوظبي</a>\n            </li>\n          </ul>\n          <ul>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/BB">بورصة البحرين</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/QE">بورصة قطر</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/MSM">سوق مسقط</a>\n            </li>\n          </ul>\n          <ul>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/KSE">سوق الكويت</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/ASE">بورصة عمان</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/CSE">سوق الدار البيضاء</a>\n            </li>\n          </ul>\n          <ul>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/BDT">بورصة تونس</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/PEX">سوق فلسطين</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/ISX">سوق العراق</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/international-indices">مؤشرات الأسواق العالمية</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/commodities-prices">أسعار المعادن والطاقة</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/countries/sa/currencies">أسعار العملات</a>\n            </li>\n            <!--<li>\n              <a class="mi-footer__menu-level3"\n                 th:href="${@url.to(\'RMPC#regionalMap\')}"\n                 th:text="#{navigation.markets.regional-map}"/>\n            </li>-->\n          </ul>\n        </li>\n        <li class="mi-footer__menu-item mi-footer__menu__news" id="news">\n          <ul>\n            <div class="mi-footer__menu-level1">الأخبار</div>\n            <li class="mi-footer__menu__news__submenu">\n              <h3 class="mi-footer__menu-level2">أخبار الدول</h3>\n              <ul>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/eg/now/latest">مصر</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/now/latest">السعودية</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/ae/now/latest">الإمارات</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/bh/now/latest">البحرين</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/qa/now/latest">قطر</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/om/now/latest">عمان</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/kw/now/latest">الكويت</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/jo/now/latest">الأردن</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/ma/now/latest">المغرب</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/tn/now/latest">تونس</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/ps/now/latest">فلسطين</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/iq/now/latest">العراق</a>\n                </li>\n              </ul>\n            </li>\n            <li class="mi-footer__menu__news__submenu">\n              <h3 class="mi-footer__menu-level2">أخبار إقليمية</h3>\n              <ul>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/regions/gulf">الخليج</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/regions/levant">الشام</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/regions/north-africa">شمال أفريقيا</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/regions/middle-east">الشرق الأوسط</a>\n                </li>\n              </ul>\n              <!-- happening now -->\n              <h3 class="mi-footer__menu-level2">يحدث الآن</h3>\n              <ul>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/now/top">أهم الأخبار</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/now/exclusive">حصرياً مباشر</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/now/latest">آخر الأخبار</a>\n                </li>\n                \n                  <li>\n                    <a class="mi-footer__menu-level3" href="/news/sa/now/announcements">إعلانات السوق</a>\n                  </li>\n                  \n                \n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/now/popular">منتشر الآن</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/now/trending/">الأكثر مشاركة</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/now/news-releases">بيانات صحفية</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/international/misc">أخبار منوعة</a>\n                </li>\n              </ul>\n            </li>\n            <li class="mi-footer__menu__news__submenu">\n              <h3 class="mi-footer__menu-level2">نبض السوق</h3>\n              <ul>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/stocks">أخبار الأسهم</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/analysis">تحليلات إخبارية</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/local">اقتصاد محلي</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/recommendations">توصيات</a>\n                </li>\n              </ul>\n              <h3 class="mi-footer__menu-level2">أخبار القطاعات</h3>\n              <ul>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/category/banking">بنوك</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/category/realEstate">عقارات</a>\n                </li>\n              </ul>\n              <h3 class="mi-footer__menu-level2">أخبار عالمية</h3>\n              <ul>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/international/global-economy">اقتصاد عالمى</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/international/goods-and-metals">أحداث عالمية</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/international/global-indices">مؤشرات عالمية</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/international/oil-and-energy">نفط ومعادن</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/international/currencies">عملات</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/international/global-reports">تقارير عالمية</a>\n                </li>\n              </ul>\n            </li>\n          </ul>\n        </li>\n        <li class="mi-footer__menu-item mi-footer__menu__companies" id="companies">\n          <div class="mi-footer__menu-level1">الشركات</div>\n          <ul>\n            <h3 class="mi-footer__menu-level2 invisible">الشركات</h3>\n            <li>\n              <a class="mi-footer__menu-level3" href="/countries/sa/companies">الشركات المدرجة</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/countries/sa/events">مفكرة الشركات</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/countries/sa/stock-prices">أسعار الأسهم</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/countries/sa/earnings">إعلانات الأرباح</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/countries/sa/fair-values">القيم العادلة</a>\n            </li>\n            <li>\n              \n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/countries/sa/major-shareholders">كبار الملاك</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/countries/sa/ipos">قائمة الإكتتابات</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/ipo/list">بحث فى الاكتتابات</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/ipos/news">أخبار الاكتتابات</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/ipo/calendar">مفكرة الاكتتابات</a>\n            </li>\n          </ul>\n        </li>\n        <li class="mi-footer__menu-item mi-footer__menu__analysis-tools" id="analysis-tools">\n          <div class="mi-footer__menu-level1">أدوات التحليل</div>\n          <!-- If current country has one market only -->\n          \n            <ul>\n              <h3 class="mi-footer__menu-level2 invisible">أدوات التحليل</h3>\n              <li>\n                <a class="mi-footer__menu-level3" href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>\n              </li>\n              <li>\n                <a class="mi-footer__menu-level3" href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>\n              </li>\n              <li>\n                <a class="mi-footer__menu-level3" href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>\n              </li>\n              <li>\n                <a class="mi-footer__menu-level3" href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>\n              </li>\n              <li>\n                <a class="mi-footer__menu-level3" href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>\n              </li>\n              <li>\n                <a class="mi-footer__menu-level3" href="/analysis-tools/performance-comparison">مقارنة الأداء</a>\n              </li>\n            </ul>\n          \n          <!-- If current country has more than one markets i.e UAE -->\n          \n        </li>\n      </ul>\n    </div>\n\n    <div class="mi-footer__second-fold">\n      <div class="mi-footer__column1">\n        <div class="mi-footer__copyright">\n          <div class="mi-footer__logo" onclick="window.location.href=\'/countries/sa\'">\n            \n  <svg viewBox="0 0 494.387 190.555">\n    <use xlink:href="#logo-white"></use>\n  </svg>\n  \n\n          </div>\n          <span>جميع الحقوق تعود لشركة مباشر العالمية © 2005 - 2020</span>\n        </div>\n        <ul class="mi-footer__links">\n          <li>\n            <a href="/s/Terms">اتفاقية الاستخدام</a>\n          </li>\n          <li>\n            <a href="/s/disclaimer">إخلاء المسؤولية</a>\n          </li>\n          <li>\n            <a href="/s/aboutus">من نحن</a>\n          </li>\n          <li>\n            <a href="/contact">اتصل بنا</a>\n          </li>\n          <li>\n            <a href="/advertise">أعلن معنا</a>\n          </li>\n          <li>\n            <a href="http://www.decypha.com/" target="_blank">موقع ديسيفا</a>\n          </li>\n          <li>\n            <a href="/ir-services" target="_blank">خدمات المواقع</a>\n          </li>\n          <li>\n            <a href="/s/Jobs">وظائف</a>\n          </li>\n          <li>\n              <a target="_blank" href="/decypha-packages">ديسيفا</a>\n          </li>\n          <li>\n            <a href="/s/privacy-policy" target="_blank">سياسة الخصوصية</a>\n          </li>\n          <!--<li th:if="${#locale.getLanguage() == \'en\'}">\n            <a href="/s/decypha-financial-intelligence" th:text="#{components.footer.decypha-financial-intelligence}">Decypha Financial Intelligence</a>\n          </li>-->\n        </ul>\n        <div>جميع البيانات متأخرة 15 دقيقة أثناء الجلسة</div>\n        <div>هذا الموقع مرخص من وزراة الثقافة والإعلام السعودية</div>\n        <div>رقم التسجيل :ت 1 125 1435</div>\n      </div>\n      <div class="mi-footer__column2">\n        <ul class="mi-footer__social-icons">\n          <li>\n            <a target="_blank" href="https://twitter.com/mubasher"><i class="fa fa-twitter fa-2x"></i></a>\n          </li>\n          <li>\n            <a href="https://www.facebook.com/Mubasher.Info"><i class="fa fa-facebook fa-2x"></i></a>\n          </li>\n          <li>\n            <a href="https://www.youtube.com/channel/UC7hnxb7gD4nKZdZk3ZlZCYg"><i class="fa fa-youtube fa-2x"></i></a>\n          </li>\n          <li>\n            <a href="https://www.linkedin.com/company/1477149"><i class="fa fa-linkedin fa-2x"></i></a>\n          </li>\n          <li>\n            <a href="/news/rss"><i class="fa fa-rss fa-2x"></i></a>\n          </li>\n          <li>\n            <a href="https://play.google.com/store/apps/details?id=net.mis.mubasherinfo">\n              <i class="fa fa-android fa-2x"></i></a>\n          </li>\n          <li>\n            <a href="https://itunes.apple.com/app/imubasher/id494539772?mt=8"><i class="fa fa-apple fa-2x"></i></a>\n          </li>\n      \n    \n</ul></div></div></div></footer>\n    \n    \n  </div>\n\n\n  <script src="//code.jquery.com/jquery-2.1.4.min.js"></script>\n  <script src="//ajax.googleapis.com/ajax/libs/angularjs/1.3.15/angular.min.js"></script>\n\n  <script src="/assets/ui/lib.min.js"></script>\n  <script src="/assets/ui/main.min.js"></script>\n  <div id="mi-js-scripts"></div>\n  <script>\n    <!-- Fix menu trigger on android browser4 -->\n    $(".dl-menu__menu-item").click(function () {\n      $(this).addClass(".dl-menu-item__hoverd");\n    });\n\n    $(document).ready(function () {\n      $(\'.tooltip\').tooltipster();\n      setTimeout(function(){ dataLayer.push({\nevent: "triggerAds"\n});\n      console.log("triggerAds");\n\n      }, 1000);\n    });\n  </script>\n  \n\n  <div pg-ng-tooltip=""></div>\n</div>\n\n  <!-- Twitter universal website tag code -->\n  <script>\n    !function(e,t,n,s,u,a){e.twq||(s=e.twq=function(){s.exe?s.exe.apply(s,arguments):s.queue.push(arguments);\n    },s.version=\'1.1\',s.queue=[],u=t.createElement(n),u.async=!0,u.src=\'//static.ads-twitter.com/uwt.js\',\n      a=t.getElementsByTagName(n)[0],a.parentNode.insertBefore(u,a))}(window,document,\'script\');\n    // Insert Twitter Pixel ID and Standard Event data below\n    twq(\'init\',\'nyana\');\n    twq(\'track\',\'PageView\');\n  </script>\n  <!-- End Twitter universal website tag code -->\n\n\n\n<div id="mm-blocker" class="mm-slideout"></div></body>' + '<body id="mi" ng-app="app" ng-controller="MainController" class="ar ng-scope" data-gr-c-s-loaded="true"><nav class="header__countries-menu mm-menu mm-offcanvas mm-top mm-front" id="countries-menu"><div class="mm-panel mm-opened mm-current" id="mm-8"><ul class="mm-listview mm-first mm-last">\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=ae&amp;url=/countries/sa/companies">الإمارات</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=bh&amp;url=/countries/sa/companies">البحرين</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=om&amp;url=/countries/sa/companies">عُمان</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=qa&amp;url=/countries/sa/companies">قطر</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=kw&amp;url=/countries/sa/companies">الكويت</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=eg&amp;url=/countries/sa/companies">مصر</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=jo&amp;url=/countries/sa/companies">الأردن</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=tn&amp;url=/countries/sa/companies">تونس</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=ma&amp;url=/countries/sa/companies">المغرب</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=ps&amp;url=/countries/sa/companies">فلسطين</a>\n        </li>\n        <li class="header__country-selector__country">\n          <a href="/change-country?to=iq&amp;url=/countries/sa/companies">العراق</a>\n        </li>\n      </ul></div></nav><nav class="header__main-menu mm-menu mm-border-full mm-effect-slide-menu mm-effect-zoom-panels mm-pageshadow mm-offcanvas mm-right mm-hasnavbar-top mm-hasnavbar" id="main-menu"><div class="mm-navbar mm-navbar-top mm-hasbtns"><a class="mm-prev mm-btn mm-hidden"></a><a class="mm-title"> </a><a class="mm-close mm-btn" href="#wrapper"></a></div><div class="mm-panel mm-opened mm-current" id="mm-0"><ul class="mm-listview mm-first mm-last">\n        <li id="markets">\n          <a class="mm-next mm-fullsubopen" href="#mm-1" data-target="#mm-1"></a><span href="javascript:;">الأسواق</span>\n          \n        </li>\n        <li id="news">\n          <a class="mm-next mm-fullsubopen" href="#mm-2" data-target="#mm-2"></a><span href="javascript:;">الأخبار</span>\n          \n        </li>\n        <li id="companies">\n          <a class="mm-next mm-fullsubopen" href="#mm-3" data-target="#mm-3"></a><span href="javascript:;">الشركات</span>\n          \n        </li>\n        <li id="funds">\n          <a class="mm-next mm-fullsubopen" href="#mm-4" data-target="#mm-4"></a><span href="javascript:;">صناديق الاستثمار</span>\n          \n        </li>\n        <li id="analysis-tool">\n          <a class="mm-next mm-fullsubopen" href="#mm-5" data-target="#mm-5"></a><span href="javascript:;">أدوات التحليل</span>\n          \n\n        </li>\n        <li id="islamic-economy">\n          <a href="/news/islamic-finance">الاقتصاد الإسلامي</a>\n        </li>\n        <!--<li class="global__hide-for-ltr" id="radio" th:if="${#locale.getLanguage() == \'ar\'}">\n          <span th:text="#{navigation.radio}">راديو مباشر</span>\n          <ul>\n            <li>\n              <a th:href="${@url.to(\'RPC#live\')}" th:text="#{navigation.radio.live}"/>\n            </li>\n            <li>\n              <a th:href="${@url.to(\'RPC#latestEpisodesPage\', countryCode)}">آخر الحلقات</a>\n            </li>\n            <li>\n              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تقارير-اقتصادية\'}">تقارير اقتصادية</a>\n            </li>\n            <li>\n              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تغطية-خاصة\'}">تغطية خاصة</a>\n            </li>\n            <li>\n              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'مقالات\'}">مقالات</a>\n            </li>\n            <li>\n              <a th:href="${@url.to(\'RPC#programs\')}" th:text="#{navigation.radio.programs}"/>\n            </li>\n            <li>\n              <a th:href="${@url.to(\'RPC#videoPrograms\')}" th:text="#{navigation.radio.videoPrograms}"/>\n            </li>\n            <li>\n              <a th:href="${@url.to(\'RPC#getExperts\')}">ضيوفنا</a>\n            </li>\n            <li>\n              <a th:href="${@url.to(\'RPC#getPresenters\')}">المذيعون</a>\n            </li>\n          </ul>\n        </li>-->\n        <li class="global__hide-for-ltr" id="video">\n          <a href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">مباشر TV</a>\n        </li>\n        \n        <li id="fixedincome">\n          <a class="mm-next mm-fullsubopen" href="#mm-6" data-target="#mm-6"></a><span>السندات</span>\n          \n        </li>\n        <li>\n          <a class="mm-next mm-fullsubopen" href="#mm-7" data-target="#mm-7"></a><span>شخصي</span>\n          \n        </li>\n        <li>\n          <a href="http://tawasul.mubasher.info/" target="_blank">تواصل</a>\n        </li>\n        <!-- <li>\n          <a th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank" th:text="#{components.header.decypha}" target="_blank">\n          </a>\n        </li> -->\n        <li>\n          <a ng-click="decypha(\'decypha\')">ديسيفا</a>\n        </li>\n\n        <!--Add according to MFP-187-->\n\n        <li>\n          <a href="https://contest.mubasher.info/#/home" target="_blank">المستثمر اﻷول</a>\n        </li>\n        <li>\n\n          <!--Integrating Mubasher Pulse-->\n\n        </li><li>\n        <style>\n\n          .pulse-logo2{\n            padding: 5px 5px 4px;\n            min-width: 82px;\n            min-height: 21px;\n            max-width: 27%;\n          }\n\n        </style>\n\n        <a target="_blank" href="https://pulse.mubasher.info">\n          <img class="pulse-logo2" src="../../../images/pulse-logo.png">\n        </a>\n        </li>\n        <li>\n\n\n        </li><li>\n          <a href="http://magazine.mubasher.info/" target="_blank">\n            مجلة مباشر\n          </a>\n        </li>\n\n        <li class="mm-divider"></li>\n        <li>\n          <a href="https://english.mubasher.info">ENGLISH</a>\n        </li>\n        <li>\n          \n        </li>\n        <li>\n          <a class="header__login__text" href="/account/login">دخول</a>\n          \n        </li>\n      </ul></div><div class="mm-panel mm-hidden" id="mm-1"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الأسواق</a></div><ul class="mm-listview mm-first mm-last">\n            <li>\n              <a href="/markets/TDWL">سوق الأسهم السعودي</a>\n            </li>\n            <li>\n              <a href="/markets/EGX">البورصة المصرية</a>\n            </li>\n            <li>\n              <a href="/markets/DFM">سوق دبي المالي</a>\n            </li>\n            <li>\n              <a href="/markets/ADX">سوق أبوظبي</a>\n            </li>\n            <li>\n              <a href="/markets/BB">بورصة البحرين</a>\n            </li>\n            <li>\n              <a href="/markets/QE">بورصة قطر</a>\n            </li>\n            <li>\n              <a href="/markets/MSM">سوق مسقط</a>\n            </li>\n            <li>\n              <a href="/markets/BK">سوق الكويت</a>\n            </li>\n            <li>\n              <a href="/markets/ASE">بورصة عمان</a>\n            </li>\n            <li>\n              <a href="/markets/CSE">سوق الدار البيضاء</a>\n            </li>\n            <li>\n              <a href="/markets/BDT">بورصة تونس</a>\n            </li>\n            <li>\n              <a href="/markets/PEX">سوق فلسطين</a>\n            </li>\n            <li>\n              <a href="/markets/ISX">سوق العراق</a>\n            </li>\n            <li>\n              <a href="/international-indices">مؤشرات الأسواق العالمية</a>\n            </li>\n            <li>\n              <a href="/markets/commodities-prices">أسعار المعادن والطاقة</a>\n            </li>\n            <li>\n              <a href="/countries/sa/currencies">أسعار العملات</a>\n            </li>\n          </ul></div><div class="mm-panel mm-hidden" id="mm-2"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الأخبار</a></div><ul class="mm-listview mm-first mm-last">\n            <!-- now -->\n            <li class="mm-divider">يحدث الآن</li>\n            <li>\n              <a href="/news/sa/now/top">أهم الأخبار</a>\n            </li>\n            <li>\n              <a href="/news/sa/now/exclusive">حصرياً مباشر</a>\n            </li>\n            <li>\n              <a href="/news/sa/now/latest">آخر الأخبار</a>\n            </li>\n            \n              <li>\n                <a href="/news/sa/now/announcements">إعلانات السوق</a>\n              </li>\n              \n            \n            <li class="global__hide-for-ltr">\n              <a href="/news/sa/now/popular">منتشر الآن</a>\n            </li>\n            <li>\n              <a href="/news/sa/now/trending/">الأكثر مشاركة</a>\n            </li>\n            <li>\n              <a href="/news/now/news-releases">بيانات صحفية</a>\n            </li>\n<!--            <li>\n              <a th:href="${@url.to(\'NPC#miscellaneousNews\', countryCode)}"\n                 th:text="#{navigation.news.now.misc}"/>\n            </li>-->\n            <!-- recommendations-->\n            <li class="mm-divider">نبض السوق</li>\n            <li>\n              <a href="/news/sa/pulse/stocks">أخبار الأسهم</a>\n            </li>\n            <li>\n              <a href="/news/sa/pulse/analysis">تحليلات إخبارية</a>\n            </li>\n            <li>\n              <a href="/news/sa/pulse/local">اقتصاد محلي</a>\n            </li>\n            <li>\n              <a href="/news/sa/pulse/recommendations">توصيات</a>\n            </li>\n            <li class="mm-divider">أخبار القطاعات</li>\n            <li>\n              <a href="/news/sa/category/banking">بنوك</a>\n            </li>\n            <li>\n              <a href="/news/sa/category/realEstate">عقارات</a>\n            </li>\n            <li class="mm-divider">أخبار الدول</li>\n            <li>\n              <a href="/news/eg/now/latest">مصر</a>\n            </li>\n            <li>\n              <a href="/news/sa/now/latest">السعودية</a>\n            </li>\n            <li>\n              <a href="/news/ae/now/latest">الإمارات</a>\n            </li>\n            <li>\n              <a href="/news/bh/now/latest">البحرين</a>\n            </li>\n            <li>\n              <a href="/news/qa/now/latest">قطر</a>\n            </li>\n            <li>\n              <a href="/news/om/now/latest">عمان</a>\n            </li>\n            <li>\n              <a href="/news/kw/now/latest">الكويت</a>\n            </li>\n            <li>\n              <a href="/news/jo/now/latest">الأردن</a>\n            </li>\n            <li>\n              <a href="/news/ma/now/latest">المغرب</a>\n            </li>\n            <li>\n              <a href="/news/tn/now/latest">تونس</a>\n            </li>\n            <li>\n              <a href="/news/ps/now/latest">فلسطين</a>\n            </li>\n            <li>\n              <a href="/news/iq/now/latest">العراق</a>\n            </li>\n\n            <!-- regions-->\n            <li class="mm-divider">أخبار إقليمية</li>\n            <li>\n              <a href="/news/regions/gulf">الخليج</a>\n            </li>\n            <li>\n              <a href="/news/regions/levant">الشام</a>\n            </li>\n            <li>\n              <a href="/news/regions/north-africa">شمال أفريقيا</a>\n            </li>\n            <li>\n              <a href="/news/regions/middle-east">الشرق الأوسط</a>\n            </li>\n\n            <!-- international -->\n            <li class="mm-divider">أخبار عالمية</li>\n            <li>\n              <a href="/news/international/global-economy">اقتصاد عالمى</a>\n            </li>\n            <li>\n              <a href="/news/international/goods-and-metals">أحداث عالمية</a>\n            </li>\n              <li>\n                <a href="/news/international/global-indices">مؤشرات عالمية</a>\n              </li>\n              <li>\n                <a href="/news/international/oil-and-energy">نفط ومعادن</a>\n              </li>\n              <li>\n                <a href="/news/international/currencies">عملات</a>\n              </li>\n              <li>\n                <a href="/news/international/global-reports">تقارير عالمية</a>\n              </li>\n          </ul></div><div class="mm-panel mm-hidden" id="mm-3"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الشركات</a></div><ul class="mm-listview mm-first mm-last">\n            <li>\n              <a href="/countries/sa/companies">الشركات المدرجة</a>\n            </li>\n            <li>\n              <a href="/countries/sa/events">مفكرة الشركات</a>\n            </li>\n            <li>\n              <a href="/countries/sa/stock-prices">أسعار الأسهم</a>\n            </li>\n            <li>\n              <a href="/countries/sa/earnings">إعلانات الأرباح</a>\n            </li>\n            <li>\n              <a href="/countries/sa/fair-values">القيم العادلة</a>\n            </li>\n            <li>\n              <a href="/countries/sa/corporate-action">الإجراءات</a>\n            </li>\n            \n            <li>\n              <a href="/countries/sa/major-shareholders">كبار الملاك</a>\n            </li>\n            <li>\n              <a href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>\n            </li>\n            <li class="mm-divider">الاكتتابات</li>\n            <li>\n              <a href="/countries/sa/ipos">قائمة الإكتتابات</a>\n            </li>\n            <li>\n              <a href="/ipo/list">بحث فى الاكتتابات</a>\n            </li>\n            <li>\n              <a href="/ipos/news">أخبار الاكتتابات</a>\n            </li>\n            <li>\n              <a href="/ipo/calendar">مفكرة الاكتتابات</a>\n            </li>\n          </ul></div><div class="mm-panel mm-hidden" id="mm-4"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">صناديق الاستثمار</a></div><ul class="mm-listview mm-first mm-last">\n            <li>\n              <a href="/countries/sa/funds">صناديق الاستثمار</a>\n            </li>\n            <li>\n              <a href="/countries/sa/funds-statistics">إحصائيات الصناديق</a>\n            </li>\n          </ul></div><div class="mm-panel mm-hidden" id="mm-5"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">أدوات التحليل</a></div><ul class="mm-listview mm-first mm-last">\n            \n              \n              <li>\n                <a href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>\n              </li>\n              <li>\n                <a href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>\n              </li>\n              <li>\n                <a href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>\n              </li>\n              <li>\n                <a href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>\n              </li>\n              <li>\n                <a href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>\n              </li>\n            \n\n            <li class="mm-divider">\n            </li>\n            <li>\n              <a href="/analysis-tools/performance-comparison">مقارنة الأداء</a>\n            </li>\n          </ul></div><div class="mm-panel mm-hidden" id="mm-6"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">السندات</a></div><ul class="mm-listview mm-first mm-last">\n            <li>\n              <a href="/fixedincome/bond/search" id="fixedIncomeBondScreener">بحث عن سندات</a>\n            </li>\n            <li>\n              <a href="/fixed-income/news" id="fixedIncomeNews">أخبار السندات وأذون الخزانة</a>\n            </li>\n            <li>\n              <a href="/fixedincome/calendar/searchForEvent" id="fixedIncomeCalendar">قائمة الأحداث</a>\n            </li>\n            <li>\n              <a href="/fixedincome/analytics/drawCurve" id="fixedIncomeAnalytics">تحليلات فنية</a>\n            </li>\n            <li>\n              <a href="/fixedincome/leagueTables/view" id="fixedIncomeLeagueTables">جداول الديون</a>\n            </li>\n            <li>\n              <a href="/fixedincome/research/search" id="fixedIncomeProspectus">تقارير</a>\n            </li>\n          </ul></div><div class="mm-panel mm-hidden" id="mm-7"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">شخصي</a></div><ul class="mm-listview mm-first mm-last">\n            <li>\n              <a href="/my/alerts">التنبيهات</a>\n            </li>\n            <li>\n              <a href="/my/watch-list">أسهمي</a>\n            </li>\n            <li>\n              <a href="/my/newsletters">النشرة البريدية</a>\n            </li>\n          </ul></div></nav>\n\n\n<div class="js-wrapper mm-page mm-slideout" id="wrapper">\n  <svg class="hidden" version="1.1" viewBox="0 0 0 0" xmlns="http://www.w3.org/2000/svg">\n  <defs>\n    <style>\n      .logo-white-path {\n        clip-rule: evenodd;\n        fill-rule: evenodd;\n        fill: white;\n        font-size: 46.6299px;\n        font-family: \'HelveticaNeue\';\n      }\n\n      .logo-path {\n        clip-rule: evenodd;\n        fill-rule: evenodd;\n        fill: #324651;\n        text-align: center;\n        font-size: 46.6299px;\n        font-family: \'HelveticaNeue\';\n      }\n    </style>\n    <g id="logo-white">\n      <path class="logo-white-path" d="M209.596 29.677c-6.25 0.016-11.243-4.937-11.261-11.188 c-0.018-6.191 5.027-11.29 11.194-11.29c6.182-0.004 11.3 5.1 11.3 11.226C220.852 24.6 215.8 29.7 209.6 29.7"></path>\n      <path class="logo-white-path" d="M228.308 37.976c6.231-0.01 11.3 5 11.3 11.2 c0.015 6.189-5.011 11.227-11.233 11.252c-6.213 0.025-11.246-4.99-11.271-11.209C217.063 43 222.1 38 228.3 38"></path>\n      <path class="logo-white-path" d="M350.278 190.471c-6.27-0.009-11.204-4.942-11.197-11.212 c0.013-6.26 4.968-11.18 11.248-11.176c6.242 0 11.3 5 11.2 11.224C361.555 185.5 356.5 190.5 350.3 190.5"></path>\n      <path class="logo-white-path" d="M186.161 37.976c6.26 0 11.2 5 11.2 11.2 c-0.01 6.241-4.993 11.239-11.209 11.226c-6.257-0.017-11.212-4.99-11.212-11.228C174.949 42.9 179.9 38 186.2 38"></path>\n      <path class="logo-white-path" d="M455.92 80.125c-21.212 0-38.405 17.191-38.405 38.4 c0 4.3 0.7 8.4 2 12.316l-48.126 0.003l13.9-27.74h-3.242c0 0-2.13 0.019-2.822 0.1 c-2.13 0.126-3.67 0.098-7.926 1.351c-3.949 1.159-7.026 2.719-9.881 4.503c-2.381 1.493-5.863 4.278-8.803 7.7 c-2.912 3.325-5.713 7.695-5.713 7.695l-3.294 6.464l-41.201 0.003L364.7 0l-76.514 49.172l25.429-0.036L260.64 156.919h193.847 c0 0 0.9 0 1.4 0.01c21.212 0 38.4-17.183 38.4-38.403C494.32 97.3 477.1 80.1 455.9 80.125z M455.92 133.3 c-7.998 0-14.48-6.479-14.48-14.47c0-7.998 6.482-14.476 14.48-14.476c7.996 0 14.5 6.5 14.5 14.5 C470.393 126.8 463.9 133.3 455.9 133.327z"></path>\n      <path class="logo-white-path" d="M269.61 81.427c0 0-1.617 0.013-2.842 0.09c-2.001 0.132-3.655 0.07-7.903 1.3 c-3.946 1.162-7.021 2.722-9.876 4.507c-2.378 1.488-5.868 4.279-8.813 7.662c-2.904 3.327-5.282 8.108-5.282 8.108l-14.116 27.7 h-16.391l19.092-39.485h-3.237c0 0-1.617 0.015-2.835 0.095c-2.012 0.13-3.665 0.068-7.905 1.3 c-3.957 1.161-7.034 2.717-9.892 4.502c-2.373 1.493-5.857 4.28-8.808 7.668c-2.899 3.321-5.282 8.104-5.282 8.104l-8.901 17.8 h-16.959l13.92-27.753h-3.245c0 0-2.141 0.019-2.822 0.057c-2.133 0.126-3.663 0.098-7.926 1.4 c-3.944 1.159-7.026 2.719-9.884 4.503c-2.378 1.493-5.857 4.28-8.808 7.669c-2.904 3.329-5.708 7.695-5.708 7.695l-3.291 6.5 l-52.558-0.005l14.007-27.748h-3.242c0 0-2.131 0.019-2.815 0.057c-2.136 0.126-3.678 0.098-7.934 1.4 c-3.944 1.159-7.021 2.719-9.877 4.503c-2.383 1.493-5.858 4.28-8.813 7.669c-2.906 3.329-5.114 7.843-5.114 7.843l-16.204 31.1 l0 0c0 0-3.136 6.731-7.038 11.469c-3.094 3.766-7.43 6.804-9.757 8.194c-2.313 1.384-7.141 3.645-11.872 4.5 C5.251 180.9 0 180.5 0 180.502s2.33 2.1 5 3.806c2.034 1.4 4.3 2.4 5.5 3 c2.481 1.1 4.3 1.7 6.9 2.253c2.531 0.6 4.8 0.8 4.8 0.763s1.621 0.2 3.2 0.169c0.707 0 1.62-0.024 2.848-0.09 c2.001-0.134 3.5 0 7.904-1.323c4.033-1.188 7.072-2.582 9.92-4.368c2.383-1.478 5.952-4.249 8.904-7.627 c2.907-3.337 5.296-8.019 5.296-8.019l6.043-12.125l169.4 0.009l12.816-26.07l24.302-49.431H269.61z"></path>\n      <path class="logo-white-path" d="M30.239 76.472V55.626H22.45v-2.789h18.735v2.789h-7.819v20.846H30.239z"></path>\n      <path class="logo-white-path" d="M44.296 76.472V52.836h4.71l5.592 16.735c0.518 1.6 0.9 2.7 1.1 3.499c0.269-0.861 0.687-2.123 1.258-3.789 l5.658-16.446h4.209v23.636h-3.015V56.689l-6.869 19.783h-2.822l-6.835-20.121v20.121H44.296z"></path>\n    </g>\n    <g id="logo">\n      <path class="logo-path" d="M209.596 29.677c-6.25 0.016-11.243-4.937-11.261-11.188 c-0.018-6.191 5.027-11.29 11.194-11.29c6.182-0.004 11.3 5.1 11.3 11.226C220.852 24.6 215.8 29.7 209.6 29.7"></path>\n      <path class="logo-path" d="M228.308 37.976c6.231-0.01 11.3 5 11.3 11.2 c0.015 6.189-5.011 11.227-11.233 11.252c-6.213 0.025-11.246-4.99-11.271-11.209C217.063 43 222.1 38 228.3 38"></path>\n      <path class="logo-path" d="M350.278 190.471c-6.27-0.009-11.204-4.942-11.197-11.212 c0.013-6.26 4.968-11.18 11.248-11.176c6.242 0 11.3 5 11.2 11.224C361.555 185.5 356.5 190.5 350.3 190.5"></path>\n      <path class="logo-path" d="M186.161 37.976c6.26 0 11.2 5 11.2 11.2 c-0.01 6.241-4.993 11.239-11.209 11.226c-6.257-0.017-11.212-4.99-11.212-11.228C174.949 42.9 179.9 38 186.2 38"></path>\n      <path class="logo-path" d="M455.92 80.125c-21.212 0-38.405 17.191-38.405 38.4 c0 4.3 0.7 8.4 2 12.316l-48.126 0.003l13.9-27.74h-3.242c0 0-2.13 0.019-2.822 0.1 c-2.13 0.126-3.67 0.098-7.926 1.351c-3.949 1.159-7.026 2.719-9.881 4.503c-2.381 1.493-5.863 4.278-8.803 7.7 c-2.912 3.325-5.713 7.695-5.713 7.695l-3.294 6.464l-41.201 0.003L364.7 0l-76.514 49.172l25.429-0.036L260.64 156.919h193.847 c0 0 0.9 0 1.4 0.01c21.212 0 38.4-17.183 38.4-38.403C494.32 97.3 477.1 80.1 455.9 80.125z M455.92 133.3 c-7.998 0-14.48-6.479-14.48-14.47c0-7.998 6.482-14.476 14.48-14.476c7.996 0 14.5 6.5 14.5 14.5 C470.393 126.8 463.9 133.3 455.9 133.327z"></path>\n      <path class="logo-path" d="M269.61 81.427c0 0-1.617 0.013-2.842 0.09c-2.001 0.132-3.655 0.07-7.903 1.3 c-3.946 1.162-7.021 2.722-9.876 4.507c-2.378 1.488-5.868 4.279-8.813 7.662c-2.904 3.327-5.282 8.108-5.282 8.108l-14.116 27.7 h-16.391l19.092-39.485h-3.237c0 0-1.617 0.015-2.835 0.095c-2.012 0.13-3.665 0.068-7.905 1.3 c-3.957 1.161-7.034 2.717-9.892 4.502c-2.373 1.493-5.857 4.28-8.808 7.668c-2.899 3.321-5.282 8.104-5.282 8.104l-8.901 17.8 h-16.959l13.92-27.753h-3.245c0 0-2.141 0.019-2.822 0.057c-2.133 0.126-3.663 0.098-7.926 1.4 c-3.944 1.159-7.026 2.719-9.884 4.503c-2.378 1.493-5.857 4.28-8.808 7.669c-2.904 3.329-5.708 7.695-5.708 7.695l-3.291 6.5 l-52.558-0.005l14.007-27.748h-3.242c0 0-2.131 0.019-2.815 0.057c-2.136 0.126-3.678 0.098-7.934 1.4 c-3.944 1.159-7.021 2.719-9.877 4.503c-2.383 1.493-5.858 4.28-8.813 7.669c-2.906 3.329-5.114 7.843-5.114 7.843l-16.204 31.1 l0 0c0 0-3.136 6.731-7.038 11.469c-3.094 3.766-7.43 6.804-9.757 8.194c-2.313 1.384-7.141 3.645-11.872 4.5 C5.251 180.9 0 180.5 0 180.502s2.33 2.1 5 3.806c2.034 1.4 4.3 2.4 5.5 3 c2.481 1.1 4.3 1.7 6.9 2.253c2.531 0.6 4.8 0.8 4.8 0.763s1.621 0.2 3.2 0.169c0.707 0 1.62-0.024 2.848-0.09 c2.001-0.134 3.5 0 7.904-1.323c4.033-1.188 7.072-2.582 9.92-4.368c2.383-1.478 5.952-4.249 8.904-7.627 c2.907-3.337 5.296-8.019 5.296-8.019l6.043-12.125l169.4 0.009l12.816-26.07l24.302-49.431H269.61z"></path>\n      <path class="logo-path" d="M30.239 76.472V55.626H22.45v-2.789h18.735v2.789h-7.819v20.846H30.239z"></path>\n      <path class="logo-path" d="M44.296 76.472V52.836h4.71l5.592 16.735c0.518 1.6 0.9 2.7 1.1 3.499c0.269-0.861 0.687-2.123 1.258-3.789 l5.658-16.446h4.209v23.636h-3.015V56.689l-6.869 19.783h-2.822l-6.835-20.121v20.121H44.296z"></path>\n    </g>\n    <g id="logo-white-en">\n      <defs>\n        <rect height="65.7" width="326.9" x="-55"></rect>\n      </defs>\n      <clipPath>\n        <use overflow="visible" xlink:href="#SVGID_1_"></use>\n      </clipPath>\n      <path class="logo-white-path" d="M41.694 20.162c-1.315 0-1.315 0.987-1.315 0.987l0.094 13.8 c0 0 0.6 8.648-8.178 8.648c0 0-8.364 0.093-8.364-8.082V21.29c0 0 0.234-1.174-1.27-1.174c-1.362 0-1.221 1.174-1.221 1.174V36 c0 0 0.2 10.1 10.9 10.104c10.386 0 10.669-9.675 10.669-10.433V21.243C42.964 21.2 43 20.2 41.7 20.2"></path>\n      <path class="logo-white-path" d="M20.915 21.431c0 0 0-0.799-0.799-1.127c-0.777-0.321-1.27 0.422-1.457 0.6 l-7.425 10.293c0 0-0.469 0.61-1.034-0.282l-8.13-10.292c0 0-0.517-0.611-1.128-0.423c-0.611 0.189-0.894 0.704-0.846 1.6 L0 44.74c0 0-0.046 1.4 1.3 1.363s1.316-1.222 1.316-1.222V25.144l7.002 9.023c0 0 1.1 1.5 2.209-0.188 c1.081-1.646 6.626-8.882 6.626-8.882v19.736c0 0-0.088 1.3 1.5 1.175c1.175-0.094 0.988-1.22 0.988-1.22V21.431z"></path>\n      <path class="logo-white-path" d="M168.546 43.734l-10.309-6.813c0 0 8.648-0.179 8.648-8.471 c0-8.294-8.531-8.118-8.531-8.118h-8.412c-2.107 0-1.953 1.6-1.953 1.6v22.69c0 0-0.038 1.5 1.1 1.5 c1.265 0 1.222-1.436 1.222-1.436V22.702h6.516c0.474 0 3.1 0 5.3 1.304c2.192 1.3 3.7 7.198-0.177 9.6 c-2.785 1.717-6.459 1.008-7.642 0.889c-1.185-0.12-1.306 0.414-1.483 1.186c-0.177 0.8 0.9 1.4 0.9 1.362l13.21 8.5 c0 0 1.4 1.2 2.1 0.18C169.967 44.4 168.5 43.7 168.5 43.7"></path>\n      <path class="logo-white-path" d="M95.522 19.596c-6.516-0.711-11.492 3.376-11.373 7.8 c0.117 4.4 3 5.7 8.1 6.634c5.096 0.9 7 1.7 7 1.658c2.665 1 2.5 4.3 1 5.9 c-1.423 1.601-4.148 2.558-5.766 2.616c-3.879 0.146-6.052-2.374-6.052-2.374c-0.492-0.407-0.683-1.486-1.69-1.25 c-1.347 0.316-0.296 1.836-0.296 1.836c2.311 3.2 7.2 3.6 7.2 3.554c5.45 0.7 8.648-3.139 8.648-3.139 c2.963-3.852 0.987-8.363-1.976-9.429c-3.17-1.142-6.139-1.234-10.05-2.065c-3.909-0.828-3.495-4.087-3.495-4.087 c0.059-2.37 2.252-5.271 7.643-5.332c5.392-0.059 8.5 3.4 8.5 3.436c1.304 1.4 2.1 0.5 2.133-0.12 c0.06-0.591-0.058-1.183-0.531-1.776C104.121 23.1 102 20.3 95.5 19.6"></path>\n      <path class="logo-white-path" d="M124.084 20.618c-1.126 0-1.185 1.067-1.185 1.067v15.166h-14.336V21.862 c0 0 0.296-1.42-1.305-1.362c-1.304 0.047-1.067 1.42-1.067 1.42v14.575h-0.889c0 0-1.303-0.06-1.303 1.2 c0 1.3 1.2 1.3 1.2 1.305h1.007v5.746c0 0 0 1.2 1.2 1.243c1.246 0 1.187-1.184 1.187-1.184v-5.984h14.1v6.103 c0 0-0.008 1.1 1.2 1.137c1.226 0 1.269-1.195 1.269-1.195V21.743C125.209 21.7 125.2 20.6 124.1 20.6"></path>\n      <path class="logo-white-path" d="M86.101 44.016c0 0-10.841-21.504-11.849-23.163c-1.007-1.66-2.072 0-2.072 0 l-8.047 15.604l-2.395 0.015c-0.888 0-0.982 0.633-0.982 1.284c0 1.1 1.1 0.9 1.1 0.929h1.067c0 0-2.447 4.637-2.726 5.3 c-0.355 0.889-0.416 1.5 0.5 1.955c1.008 0.5 1.659-0.77 1.659-0.77l3.436-6.399H80.71l2.903 5.9 c0 0 1 2 2.1 1.305C86.87 45.3 86.1 44 86.1 44 M66.965 36.374l5.984-12.026c0 0 0.296-0.475 0.6 0.1 c0.296 0.5 6 12 6 11.967H66.965z"></path>\n      <path class="logo-white-path" d="M58.314 34.283c0 0 3.87-1.954 3.87-6.575c0-4.622-4.563-7.199-8.294-7.199 h-6.517c0 0-1.512 0.2-1.512 1.744v10.479h-1.833c0 0-0.799-0.094-0.799 1.271c0 1.1 0.6 1.2 0.6 1.173h2.066v9.447 c0 0-0.046 1.5 1.5 1.48h7.213c0 0 6.016-0.165 6.016-6.837C60.57 35.9 58.3 34.3 58.3 34.3 M48.203 22.7 l6.338-0.005c1.718 0 5.1 1.7 5.1 5.451c0 4.443-5.095 4.501-5.095 4.501h-6.338V22.736z M53.557 43.831h-5.351v-8.748 l6.435-0.008c0.858 0 3.5 0.9 3.5 4.031C58.143 43.7 53.6 43.8 53.6 43.8"></path>\n      <path class="logo-white-path" d="M146.17 23.033c0 0 1.3 0.1 1.305-1.304c0-1.244-1.305-1.125-1.305-1.125 h-15.818c-2.251 0-2.012 1.717-2.012 1.717V36.54l-1.653 0.009c0 0-1.132 0.229-1.132 1.177c0 1.2 1.1 1.4 1.1 1.361h1.669 v4.917c0 2.5 1.7 2.1 1.7 2.073h15.818c0 0 0.9 0 0.889-1.185s-0.95-1.007-0.95-1.007h-14.798v-4.799h15.284 c0 0 0.937-0.177 0.937-1.361c0-1.186-1.125-1.246-1.125-1.246h-15.228V23.033H146.17z"></path>\n    </g>\n    <g id="logo-en">\n      <defs>\n        <rect height="65.7" width="326.9" x="-55"></rect>\n      </defs>\n      <clipPath>\n        <use overflow="visible" xlink:href="#SVGID_1_"></use>\n      </clipPath>\n      <path class="logo-path" d="M41.694 20.162c-1.315 0-1.315 0.987-1.315 0.987l0.094 13.8 c0 0 0.6 8.648-8.178 8.648c0 0-8.364 0.093-8.364-8.082V21.29c0 0 0.234-1.174-1.27-1.174c-1.362 0-1.221 1.174-1.221 1.174V36 c0 0 0.2 10.1 10.9 10.104c10.386 0 10.669-9.675 10.669-10.433V21.243C42.964 21.2 43 20.2 41.7 20.2"></path>\n      <path class="logo-path" d="M20.915 21.431c0 0 0-0.799-0.799-1.127c-0.777-0.321-1.27 0.422-1.457 0.6 l-7.425 10.293c0 0-0.469 0.61-1.034-0.282l-8.13-10.292c0 0-0.517-0.611-1.128-0.423c-0.611 0.189-0.894 0.704-0.846 1.6 L0 44.74c0 0-0.046 1.4 1.3 1.363s1.316-1.222 1.316-1.222V25.144l7.002 9.023c0 0 1.1 1.5 2.209-0.188 c1.081-1.646 6.626-8.882 6.626-8.882v19.736c0 0-0.088 1.3 1.5 1.175c1.175-0.094 0.988-1.22 0.988-1.22V21.431z"></path>\n      <path class="logo-path" d="M168.546 43.734l-10.309-6.813c0 0 8.648-0.179 8.648-8.471 c0-8.294-8.531-8.118-8.531-8.118h-8.412c-2.107 0-1.953 1.6-1.953 1.6v22.69c0 0-0.038 1.5 1.1 1.5 c1.265 0 1.222-1.436 1.222-1.436V22.702h6.516c0.474 0 3.1 0 5.3 1.304c2.192 1.3 3.7 7.198-0.177 9.6 c-2.785 1.717-6.459 1.008-7.642 0.889c-1.185-0.12-1.306 0.414-1.483 1.186c-0.177 0.8 0.9 1.4 0.9 1.362l13.21 8.5 c0 0 1.4 1.2 2.1 0.18C169.967 44.4 168.5 43.7 168.5 43.7"></path>\n      <path class="logo-path" d="M95.522 19.596c-6.516-0.711-11.492 3.376-11.373 7.8 c0.117 4.4 3 5.7 8.1 6.634c5.096 0.9 7 1.7 7 1.658c2.665 1 2.5 4.3 1 5.9 c-1.423 1.601-4.148 2.558-5.766 2.616c-3.879 0.146-6.052-2.374-6.052-2.374c-0.492-0.407-0.683-1.486-1.69-1.25 c-1.347 0.316-0.296 1.836-0.296 1.836c2.311 3.2 7.2 3.6 7.2 3.554c5.45 0.7 8.648-3.139 8.648-3.139 c2.963-3.852 0.987-8.363-1.976-9.429c-3.17-1.142-6.139-1.234-10.05-2.065c-3.909-0.828-3.495-4.087-3.495-4.087 c0.059-2.37 2.252-5.271 7.643-5.332c5.392-0.059 8.5 3.4 8.5 3.436c1.304 1.4 2.1 0.5 2.133-0.12 c0.06-0.591-0.058-1.183-0.531-1.776C104.121 23.1 102 20.3 95.5 19.6"></path>\n      <path class="logo-path" d="M124.084 20.618c-1.126 0-1.185 1.067-1.185 1.067v15.166h-14.336V21.862 c0 0 0.296-1.42-1.305-1.362c-1.304 0.047-1.067 1.42-1.067 1.42v14.575h-0.889c0 0-1.303-0.06-1.303 1.2 c0 1.3 1.2 1.3 1.2 1.305h1.007v5.746c0 0 0 1.2 1.2 1.243c1.246 0 1.187-1.184 1.187-1.184v-5.984h14.1v6.103 c0 0-0.008 1.1 1.2 1.137c1.226 0 1.269-1.195 1.269-1.195V21.743C125.209 21.7 125.2 20.6 124.1 20.6"></path>\n      <path class="logo-path" d="M86.101 44.016c0 0-10.841-21.504-11.849-23.163c-1.007-1.66-2.072 0-2.072 0 l-8.047 15.604l-2.395 0.015c-0.888 0-0.982 0.633-0.982 1.284c0 1.1 1.1 0.9 1.1 0.929h1.067c0 0-2.447 4.637-2.726 5.3 c-0.355 0.889-0.416 1.5 0.5 1.955c1.008 0.5 1.659-0.77 1.659-0.77l3.436-6.399H80.71l2.903 5.9 c0 0 1 2 2.1 1.305C86.87 45.3 86.1 44 86.1 44 M66.965 36.374l5.984-12.026c0 0 0.296-0.475 0.6 0.1 c0.296 0.5 6 12 6 11.967H66.965z"></path>\n      <path class="logo-path" d="M58.314 34.283c0 0 3.87-1.954 3.87-6.575c0-4.622-4.563-7.199-8.294-7.199 h-6.517c0 0-1.512 0.2-1.512 1.744v10.479h-1.833c0 0-0.799-0.094-0.799 1.271c0 1.1 0.6 1.2 0.6 1.173h2.066v9.447 c0 0-0.046 1.5 1.5 1.48h7.213c0 0 6.016-0.165 6.016-6.837C60.57 35.9 58.3 34.3 58.3 34.3 M48.203 22.7 l6.338-0.005c1.718 0 5.1 1.7 5.1 5.451c0 4.443-5.095 4.501-5.095 4.501h-6.338V22.736z M53.557 43.831h-5.351v-8.748 l6.435-0.008c0.858 0 3.5 0.9 3.5 4.031C58.143 43.7 53.6 43.8 53.6 43.8"></path>\n      <path class="logo-path" d="M146.17 23.033c0 0 1.3 0.1 1.305-1.304c0-1.244-1.305-1.125-1.305-1.125 h-15.818c-2.251 0-2.012 1.717-2.012 1.717V36.54l-1.653 0.009c0 0-1.132 0.229-1.132 1.177c0 1.2 1.1 1.4 1.1 1.361h1.669 v4.917c0 2.5 1.7 2.1 1.7 2.073h15.818c0 0 0.9 0 0.889-1.185s-0.95-1.007-0.95-1.007h-14.798v-4.799h15.284 c0 0 0.937-0.177 0.937-1.361c0-1.186-1.125-1.246-1.125-1.246h-15.228V23.033H146.17z"></path>\n    </g>\n  </defs>\n</svg>\n  <!--<script type="text/javascript" xmlns:th="http://www.thymeleaf.org" th:fragment="body">-->\n  <!--(function () {-->\n    <!--var em = document.createElement(\'script\');-->\n    <!--em.type = \'text/javascript\';-->\n    <!--em.async = true;-->\n    <!--em.src =-->\n      <!--(\'https:\' == document.location.protocol ? \'https://me-ssl\' : \'http://me-cdn\') + \'.effectivemeasure.net/em.js\';-->\n    <!--var s = document.getElementsByTagName(\'script\')[0];-->\n    <!--s.parentNode.insertBefore(em, s);-->\n  <!--}());-->\n<!--</script>-->\n\n\n  <div class="">\n\n    <header class="header">\n      <!-- DESKTOP ADS BLOCK -->\n\n      <!-- DESKTOP ADS BLOCK -->\n      <!-- MOBILE ADS BLOCK -->\n      \n\n      \n      <!-- MOBILE ADS BLOCK -->\n      <div class="header__top-for-mobile">\n        <div class="top-bar__triggers">\n          <a class="main-menu-trigger fa fa-bars fa-2x" href="#main-menu" style="float: right;"></a>\n          <!-- Logo -->\n          <div class="header__logo header-logo-margins" onclick="window.location.href=\'/countries/sa\'">\n            \n  <svg viewBox="0 0 494.387 190.555">\n    <use xlink:href="#logo-white"></use>\n  </svg>\n  \n\n          </div>\n          <a class="countries-menu-trigger header-country-margins" href="#countries-menu">\n            <span>السعودية</span>\n            <span class="fa fa-caret-down fa-4x"></span>\n          </a>\n          <!-- ngRepeat: image in images --><img ng-repeat="image in images" src="/assets/ui/images/mobile-logo-G20.png" class="ng-scope"><!-- end ngRepeat: image in images --><img ng-repeat="image in images" src="/assets/ui/images/mobile-logo-vision.png" class="ng-scope"><!-- end ngRepeat: image in images -->\n          <div class="header__left-side left-search-icon">\n            <a class="search-trigger js-search-trigger fa fa-search fa-2x" href="javascript:;" style="float: left;">\n            </a>\n          </div>\n        </div>\n        <!-- Search -->\n        <div class="search js-search" id="search">\n          <i class="fa fa-search fa-2x search__icon"></i>\n          <angucomplete-alt id="autocomplete__companies" input-class="search__input" minlength="1" ng-controller="AutocompleteController" pause="400" placeholder="اكتب كلمة البحث أو رمز الشركة" selected-object="selectItem" text-no-results="عفواً, لم يتم العثور على أي نتائج" text-searching="جارٍ البحث..." title-field="label" remote-url="/api/1/companySearch?query=" class="ng-scope ng-isolate-scope"><div class="angucomplete-holder" ng-class="{\'angucomplete-dropdown-visible\': showDropdown}">  <input id="autocomplete__companies_value" ng-model="searchStr" ng-disabled="disableInput" type="" placeholder="اكتب كلمة البحث أو رمز الشركة" maxlength="524288" ng-focus="onFocusHandler()" class="search__input ng-valid-maxlength" ng-blur="hideResults($event)" autocapitalize="off" autocorrect="off" autocomplete="off" ng-change="inputChangeHandler(searchStr)">  <div id="autocomplete__companies_dropdown" class="angucomplete-dropdown ng-hide" ng-show="showDropdown"><div class="angucomplete-searching ng-hide" ng-show="searching"><div class="spinner"><div class="dot1"></div><div class="dot2"></div></div></div>    <div class="angucomplete-searching ng-binding" ng-show="!searching &amp;&amp; (!results || results.length == 0)" ng-bind="textNoResults">عفواً, لم يتم العثور على أي نتائج</div>    <!-- ngRepeat: result in results -->  </div></div></angucomplete-alt>\n        </div>\n      </div>\n      <div class="header-desktop mi-show-for-large-up">\n        <div class="header__top-for-desktop">\n          <div class="header__top-for-desktop-row">\n            <a class="header__other-site" href="http://tawasul.mubasher.info/" target="_blank">\n              <i class="fa fa-caret-right fa-2x"></i>\n              تواصل\n            </a>\n            <a class="header__other-site" href="http://magazine.mubasher.info/" target="_blank">\n              <i class="fa fa-caret-right fa-2x"></i>\n              مجلة مباشر\n            </a>\n            <a class="header__other-site" href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">\n              <i class="fa fa-play-circle"></i>\n              <div style="direction: ltr; display: inline-block;">TV مباشر</div>\n            </a>\n            \n            <a class="header__other-site" href="/contact">\n              <i class="fa fa-envelope"></i>\n              اتصل بنا\n            </a>\n            <a class="header__other-site" href="/advertise">\n              <i class="fa fa-envelope"></i>\n              اعلن معنا\n            </a>\n            <!-- <a th:if="${#locale.getLanguage() == \'ar\'}" class="header__login-button" style="background: #458D37 !important;" th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank"\n                th:text="#{components.header.decypha}">ديسيفا</a>\n            <a th:if="${#locale.getLanguage() == \'en\'}" class="header__login-button" style="background: #458D37 !important; font-family: Roboto,sans-serif !important;" th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank"\n                th:text="#{components.header.decypha}">ديسيفا</a> -->\n\n            <!-- Page Content Buttons -->\n            <a class="header__login-button" ng-click="decypha(\'decypha\')" style="background: #458D37 !important; font-family: Roboto,sans-serif !important;">ديسيفا</a>\n            <!-- Page Content Button -->\n\n            <!--Add according to MFP-187-->\n            <a class="header__login-button" style="background: #00c2d6 !important;" target="_blank" href="https://contest.mubasher.info/#/home">المستثمر اﻷول</a>\n            \n\n            <style>\n\n              /*.pulse-logo{*/\n              /*display: inline-block;*/\n              /*width: 252px;*/\n              /*height: 100%;*/\n              /*background: #212121 url(../images/pulse-logo.png) no-repeat center 2px;*/\n              /*padding: 10px 50px 29px;*/\n              /*text-align: center;*/\n              /*color: black;*/\n              /*text-decoration: none;*/\n              /*margin-top: -6px;*/\n\n              /*}*/\n\n              .pulse-logo2{\n                padding: 5px 5px 4px;\n                min-width: 82px;\n                min-height: 21px;\n                max-width: 27%;\n              }\n\n            </style>\n\n            <a target="_blank" href="https://pulse.mubasher.info">\n              <img class="pulse-logo2" src="../../../images/pulse-logo.png">\n            </a>\n\n\n            <span class="header__spacer">\n              &nbsp;\n            </span>\n\n            <a class="header__social-link" target="_blank" href="https://twitter.com/mubasher"><i class="fa fa-twitter fa-lg"></i></a>\n            <a class="header__social-link" href="https://www.facebook.com/Mubasher.Info"><i class="fa fa-facebook fa-lg"></i></a>\n            <a class="header__social-link" href="https://www.youtube.com/channel/UC7hnxb7gD4nKZdZk3ZlZCYg">\n              <i class="fa fa-youtube fa-lg"></i>\n            </a>\n            <a class="header__social-link" href="https://www.linkedin.com/company/1477149">\n              <i class="fa fa-linkedin fa-lg"></i>\n            </a>\n            <a class="header__social-link" href="/news/rss"><i class="fa fa-rss fa-lg"></i></a>\n            <a class="header__social-link" href="https://play.google.com/store/apps/details?id=net.mis.mubasherinfo">\n              <i class="fa fa-android fa-lg"></i>\n            </a>\n            <a class="header__social-link" href="https://itunes.apple.com/app/imubasher/id494539772?mt=8">\n              <i class="fa fa-apple fa-lg"></i>\n            </a>\n\n            <a class="header__login-button" href="/account/login">\n              دخول\n              <i class="fa fa-user fa-lg"></i>\n            </a>\n            \n            \n            <a class="header__language" href="https://english.mubasher.info">\n              <span>ENGLISH</span>\n            </a>\n          </div>\n        </div>\n        <div class="header__columns">\n          <div class="header__column1">\n            <!-- Logo -->\n            <div class="header__logo-wrapper">\n              <div class="header__logo" onclick="window.location.href=\'/countries/sa\'">\n                \n  <svg viewBox="0 0 494.387 190.555">\n    <use xlink:href="#logo"></use>\n  </svg>\n  \n\n              </div>\n\n              <div class="countries-menu-trigger">\n                <a href="javascript:;" id="mi-js-countries-menu-trigger">\n                  <span>السعودية</span>\n                  <span class="fa fa-caret-down"></span>\n                </a>\n                <nav class="header__countries-menu--desktop mi-js-countries-menu-desktop" style="">\n                  <ul>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=ae&amp;url=/countries/sa/companies">الإمارات</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=bh&amp;url=/countries/sa/companies">البحرين</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=om&amp;url=/countries/sa/companies">عُمان</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=qa&amp;url=/countries/sa/companies">قطر</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=kw&amp;url=/countries/sa/companies">الكويت</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=eg&amp;url=/countries/sa/companies">مصر</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=jo&amp;url=/countries/sa/companies">الأردن</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=tn&amp;url=/countries/sa/companies">تونس</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=ma&amp;url=/countries/sa/companies">المغرب</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=ps&amp;url=/countries/sa/companies">فلسطين</a>\n                    </li>\n                    <li class="header__country-selector--desktop__country">\n                      <a href="/change-country?to=iq&amp;url=/countries/sa/companies">العراق</a>\n                    </li>\n                  </ul>\n                </nav>\n              </div>\n            </div>\n            <!--Market Status -->\n            <div class="header__market-status">\n              <div class="header__market-status-column">\n                <div class="header__market-status-row">\n                  <a class="header__market-name" href="/markets/TDWL">TDWL</a>\n                  <span class="header__market-status--close">مغلق</span>\n                </div>\n                \n              </div>\n              <span class="header__market-time">12 أغسطس 04:32 م</span>\n            </div>\n          </div>\n\n          <div class="header__column1 banner-logo-desktop" ng-class="{\'banner-desktop-en\':(getLanguage == \'en\')}">\n            <!-- Logo -->\n            <div class="header__logo-wrapper">\n              <!-- ngRepeat: image in images --><div class="header__logo ng-scope" ng-repeat="image in images">\n                  <div class="tooltip tooltipstered"><img src="/assets/ui/images/logo-G20.png">\n                    <span class="tooltiptext ng-binding" ng-class="{\'tooltip-desktop-en\':(getLanguage == \'en\')}" style="left: 95%">مجموعة العشرين 2020</span>\n                  </div>\n              </div><!-- end ngRepeat: image in images --><div class="header__logo ng-scope" ng-repeat="image in images">\n                  <div class="tooltip tooltipstered"><img src="/assets/ui/images/logo-vision.png">\n                    <span class="tooltiptext ng-binding" ng-class="{\'tooltip-desktop-en\':(getLanguage == \'en\')}" style="left: 95%">رؤية المملكة العربية السعودية 2030</span>\n                  </div>\n              </div><!-- end ngRepeat: image in images -->\n            </div>\n          </div>\n\n<!--          <div class="header__column2">\n\n             &lt;!&ndash;<div th:replace="components/ads/news/dfp/desktop/LB2"/>&ndash;&gt;\n\n            &lt;!&ndash;=====to display default leaderboard ad-slot [728,90] ======&ndash;&gt;\n            <div th:if="${isHomePage}">\n              <div th:replace="components/ads/home/leaderboard"/>\n            </div>\n            <div th:unless="${isHomePage}">\n              <div>\n                <iframe id="leaderboard-ros-001" style="width: 736px; height: 108px;" class="ad-iframe" src="/ads/LB2"></iframe>\n              </div>\n            </div>\n\n\n            </div>-->\n\n           <!--======= billboard 790x250 ============ -->\n        </div>\n\n        <nav class="header__navigation mi-js-desktop-menu-container">\n          <ul class="dl-menu mi-show-for-large-up mi-js-desktop-menu" style="position: static; top: auto;">\n            <li class="dl-menu__menu-item dl-menu__menu-item--iconic-item">\n              <a href="/countries/sa">\n                <i class="fa fa-home fa-2x"></i>\n              </a>\n            </li>\n            <li class="dl-menu__menu-item" id="markets">\n              <a href="javascript:;">الأسواق</a>\n              <div class="mi-js-submenu">\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/markets/TDWL">سوق الأسهم السعودي</a>\n                    </li>\n                    <li>\n                      <a href="/markets/EGX">البورصة المصرية</a>\n                    </li>\n                    <li>\n                      <a href="/markets/DFM">سوق دبي المالي</a>\n                    </li>\n                    <li>\n                      <a href="/markets/ADX">سوق أبوظبي</a>\n                    </li>\n                    <li>\n                      <a href="/markets/BB">بورصة البحرين</a>\n                    </li>\n                  </ul>\n                </div>\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/markets/QE">بورصة قطر</a>\n                    </li>\n                    <li>\n                      <a href="/markets/MSM">سوق مسقط</a>\n                    </li>\n                    <li>\n                      <a href="/markets/BK">سوق الكويت</a>\n                    </li>\n                    <li>\n                      <a href="/markets/ASE">بورصة عمان</a>\n                    </li>\n                  </ul>\n                </div>\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/markets/CSE">سوق الدار البيضاء</a>\n                    </li>\n                    <li>\n                      <a href="/markets/BDT">بورصة تونس</a>\n                    </li>\n                    <li>\n                      <a href="/markets/PEX">سوق فلسطين</a>\n                    </li>\n                    <li>\n                      <a href="/markets/ISX">سوق العراق</a>\n                    </li>\n                  </ul>\n                </div>\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/international-indices">مؤشرات الأسواق العالمية</a>\n                    </li>\n                    <li>\n                      <a href="/markets/commodities-prices">أسعار المعادن والطاقة</a>\n                    </li>\n                    <li>\n                      <a href="/countries/sa/currencies">أسعار العملات</a>\n                    </li>\n                    <!--<li>\n                      <a th:href="${@url.to(\'RMPC#regionalMap\')}"\n                         th:text="#{navigation.markets.regional-map}"/>\n                    </li>-->\n                  </ul>\n                </div>\n              </div>\n            </li>\n            <li class="dl-menu__menu-item" id="news">\n              <a href="javascript:;">الأخبار</a>\n              <div class="mi-js-submenu">\n                <ul class="dl-submenu">\n                  <li>\n                    <a href="javascript:;">يحدث الآن</a>\n                    <div class="nav-column">\n                      <h3>يحدث الآن</h3>\n                      <ul class="dl-submenu">\n                        <li>\n                          <a href="/news/sa/now/top">أهم الأخبار</a>\n                        </li>\n                        <li>\n                          <a href="/news/sa/now/exclusive">حصرياً مباشر</a>\n                        </li>\n                        <li>\n                          <a href="/news/sa/now/latest">آخر الأخبار</a>\n                        </li>\n                        \n                          <li>\n                            <a href="/news/sa/now/announcements">إعلانات السوق</a>\n                          </li>\n                          \n                        \n                        <li class="global__hide-for-ltr">\n                          <a href="/news/sa/now/popular">منتشر الآن</a>\n                        </li>\n                        <li>\n                          <a href="/news/sa/now/trending/">الأكثر مشاركة</a>\n                        </li>\n                        <li>\n                          <a href="/news/now/news-releases">بيانات صحفية</a>\n                        </li>\n                        <li>\n                          <a href="/news/international/misc">أخبار منوعة</a>\n                        </li>\n                      </ul>\n                    </div>\n                  </li>\n                  <li>\n                    <a href="javascript:;">نبض السوق</a>\n                    <div class="nav-column">\n                      <h3>نبض السوق</h3>\n                      <ul class="dl-submenu">\n                        <li>\n                          <a href="/news/sa/pulse/stocks">أخبار الأسهم</a>\n                        </li>\n                        <li>\n                          <a href="/news/sa/pulse/analysis">تحليلات إخبارية</a>\n                        </li>\n                        <li>\n                          <a href="/news/sa/pulse/local">اقتصاد محلي</a>\n                        </li>\n                        <li>\n                          <a href="/news/sa/pulse/recommendations">توصيات</a>\n                        </li>\n                      </ul>\n                      <h3>أخبار القطاعات</h3>\n                      <ul class="dl-submenu">\n                        <li>\n                          <a href="/news/sa/category/banking">بنوك</a>\n                        </li><li>\n                          <a href="/news/sa/category/realEstate">عقارات</a>\n                        </li>\n                      </ul>\n                    </div>\n                  </li>\n                  <li>\n                    <a href="javascript:;">أخبار الدول</a>\n                    <div class="nav-column">\n                      <h3>أخبار الدول</h3>\n                      <ul class="dl-submenu">\n                        <li>\n                          <a href="/news/eg/now/latest">مصر</a>\n                        </li>\n                        <li>\n                          <a href="/news/sa/now/latest">السعودية</a>\n                        </li>\n                        <li>\n                          <a href="/news/ae/now/latest">الإمارات</a>\n                        </li>\n                        <li>\n                          <a href="/news/bh/now/latest">البحرين</a>\n                        </li>\n                        <li>\n                          <a href="/news/qa/now/latest">قطر</a>\n                        </li>\n                        <li>\n                          <a href="/news/om/now/latest">عمان</a>\n                        </li>\n                      </ul>\n                    </div>\n                  </li>\n                  <li>\n                    <a href="javascript:;">أخبار الدول</a>\n                    <div class="nav-column">\n                      <h3 class="invisible">أخبار الدول</h3>\n                      <ul class="dl-submenu">\n                        <li>\n                          <a href="/news/kw/now/latest">الكويت</a>\n                        </li>\n                        <li>\n                          <a href="/news/jo/now/latest">الأردن</a>\n                        </li>\n                        <li>\n                          <a href="/news/ma/now/latest">المغرب</a>\n                        </li>\n                        <li>\n                          <a href="/news/tn/now/latest">تونس</a>\n                        </li>\n                        <li>\n                          <a href="/news/ps/now/latest">فلسطين</a>\n                        </li>\n                        <li>\n                          <a href="/news/iq/now/latest">العراق</a>\n                        </li>\n                      </ul>\n                    </div>\n                  </li>\n                  <li>\n                    <a href="javascript:;">أخبار إقليمية</a>\n                    <div class="nav-column">\n                      <h3>أخبار إقليمية</h3>\n                      <ul class="dl-submenu">\n                        <li>\n                          <a href="/news/regions/gulf">الخليج</a>\n                        </li>\n                        <li>\n                          <a href="/news/regions/levant">الشام</a>\n                        </li>\n                        <li>\n                          <a href="/news/regions/north-africa">شمال أفريقيا</a>\n                        </li>\n                        <li>\n                          <a href="/news/regions/middle-east">الشرق الأوسط</a>\n                        </li>\n                      </ul>\n                    </div>\n                  </li>\n\n\n                  <li>\n                    <a href="javascript:;">أخبار عالمية</a>\n                    <div class="nav-column">\n                      <h3>أخبار عالمية</h3>\n                      <ul class="dl-submenu">\n                        <li>\n                          <a href="/news/international/global-economy">اقتصاد عالمى</a>\n                        </li>\n                        <li>\n                          <a href="/news/international/goods-and-metals">أحداث عالمية</a>\n                        </li>\n                        <li>\n                          <a href="/news/international/global-indices">مؤشرات عالمية</a>\n                        </li>\n                        <li>\n                          <a href="/news/international/oil-and-energy">نفط ومعادن</a>\n                        </li>\n                        <li>\n                          <a href="/news/international/currencies">عملات</a>\n                        </li>\n                        <li>\n                          <a href="/news/international/global-reports">تقارير عالمية</a>\n                        </li>\n                      </ul>\n                    </div>\n                  </li>\n                </ul>\n              </div>\n            </li>\n            <li class="dl-menu__menu-item" id="companies">\n              <a href="javascript:;">الشركات</a>\n              <div class="mi-js-submenu">\n                <div class="nav-column">\n                  <h3 class="invisible">.</h3>\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/countries/sa/companies">الشركات المدرجة</a>\n                    </li>\n                    <li>\n                      <a href="/countries/sa/events">مفكرة الشركات</a>\n                    </li>\n                    <li>\n                      <a href="/countries/sa/stock-prices">أسعار الأسهم</a>\n                    </li>\n                    <li>\n                      <a href="/countries/sa/fair-values">القيم العادلة</a>\n                    </li>\n                  </ul>\n                </div>\n                <div class="nav-column">\n                  <h3 class="invisible">.</h3>\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/countries/sa/earnings">إعلانات الأرباح</a>\n                    </li>\n                    <li>\n                      <a href="/countries/sa/corporate-action">الإجراءات</a>\n                    </li>\n                    \n                    <li>\n                      <a href="/countries/sa/major-shareholders">كبار الملاك</a>\n                    </li>\n                    <li>\n                      <a href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>\n                    </li>\n                  </ul>\n                </div>\n                <div class="nav-column">\n                  <h3>الاكتتابات</h3>\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/countries/sa/ipos">قائمة الإكتتابات</a>\n                    </li>\n                    <li>\n                      <a href="/ipo/list">بحث فى الاكتتابات</a>\n                    </li>\n                    <li>\n                      <a href="/ipos/news">أخبار الاكتتابات</a>\n                    </li>\n                    <li>\n                      <a href="/ipo/calendar">مفكرة الاكتتابات</a>\n                    </li>\n                  </ul>\n                </div>\n              </div>\n            </li>\n            <li class="dl-menu__menu-item" id="funds">\n              <a href="javascript:;">صناديق الاستثمار</a>\n              <div class="mi-js-submenu">\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/countries/sa/funds">صناديق الاستثمار</a>\n                    </li>\n                  </ul>\n                </div>\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/countries/sa/funds-statistics">إحصائيات الصناديق</a>\n                    </li>\n                  </ul>\n                </div>\n              </div>\n            </li>\n            <li class="dl-menu__menu-item" id="analysis-tools">\n              <a href="javascript:;">أدوات التحليل</a>\n              <!-- If current country has one market only -->\n              <div class="mi-js-submenu">\n                \n                  <div class="nav-column">\n                    <ul class="dl-submenu">\n                      <li>\n                        <a href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>\n                      </li>\n                      <li>\n                        <a href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>\n                      </li>\n                      <li>\n                        <a href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>\n                      </li>\n                    </ul>\n                  </div>\n                  <div class="nav-column">\n                    <ul class="dl-submenu">\n                      <li>\n                        <a href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>\n                      </li>\n                      <li>\n                        <a href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>\n                      </li>\n                      <li>\n                        <a href="/analysis-tools/performance-comparison">مقارنة الأداء</a>\n                      </li>\n                    </ul>\n                  </div>\n                \n\n                \n              </div>\n            </li>\n            <li class="dl-menu__menu-item" id="islamic-economy">\n              <a href="/news/islamic-finance">الاقتصاد الإسلامي</a>\n            </li>\n            <!--<li id="radio"\n                class="dl-menu__menu-item global__hide-for-ltr"\n                id="radio"\n                th:if="${#locale.getLanguage() == \'ar\'}">\n              <a href="javascript:;" th:text="#{navigation.radio}"/>\n              <div class="mi-js-submenu">\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a th:href="${@url.to(\'RPC#live\')}" th:text="#{navigation.radio.live}"/>\n                    </li>\n                    <li>\n                      <a th:href="${@url.to(\'RPC#latestEpisodesPage\', countryCode)}">آخر الحلقات</a>\n                    </li>\n                    <li>\n                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تقارير-اقتصادية\'}">تقارير\n                        اقتصادية</a>\n                    </li>\n                    <li>\n                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تغطية-خاصة\'}">تغطية خاصة</a>\n                    </li>\n                    <li>\n                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'مقالات\'}">مقالات</a>\n                    </li>\n                  </ul>\n                </div>\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a th:href="${@url.to(\'RPC#programs\')}" th:text="#{navigation.radio.programs}"/>\n                    </li>\n                    <li>\n                      <a th:href="${@url.to(\'RPC#videoPrograms\')}" th:text="#{navigation.radio.videoPrograms}"/>\n                    </li>\n                    <li>\n                      <a th:href="${@url.to(\'RPC#getExperts\')}">ضيوفنا</a>\n                    </li>\n                    <li>\n                      <a th:href="${@url.to(\'RPC#getPresenters\')}">المذيعون</a>\n                    </li>\n                  </ul>\n                </div>\n              </div>\n            </li>-->\n            <li class="dl-menu__menu-item global__hide-for-ltr" id="video">\n              <a href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">مباشر TV</a>\n            </li>\n            \n            <li class="dl-menu__menu-item" id="fixedincome">\n              <a href="javascript:;">السندات</a>\n              <div class="mi-js-submenu">\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/fixedincome/bond/search" id="fixedIncomeBondScreener">بحث عن سندات</a>\n                    </li>\n                    <li>\n                      <a href="/fixed-income/news" id="fixedIncomeNews">أخبار السندات وأذون الخزانة</a>\n                    </li>\n                    <li>\n                      <a href="/fixedincome/calendar/searchForEvent" id="fixedIncomeCalendar">قائمة الأحداث</a>\n                    </li>\n                  </ul>\n                </div>\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/fixedincome/analytics/drawCurve" id="fixedIncomeAnalytics">تحليلات فنية</a>\n                    </li>\n                    <li>\n                      <a href="/fixedincome/leagueTables/view" id="fixedIncomeLeagueTables">جداول الديون</a>\n                    </li>\n                    <li>\n                      <a href="/fixedincome/research/search" id="fixedIncomeProspectus">تقارير</a>\n                    </li>\n                  </ul>\n                </div>\n              </div>\n            </li>\n            <li class="dl-menu__menu-item" id="personal">\n              <a href="javascript:;">شخصي</a>\n              <div class="mi-js-submenu">\n                <div class="nav-column">\n                  <ul class="dl-submenu">\n                    <li>\n                      <a href="/my/alerts">التنبيهات</a>\n                    </li>\n                    <li>\n                      <a href="/my/watch-list">أسهمي</a>\n                    </li>\n                    <li>\n                      <a href="/my/newsletters">النشرة البريدية</a>\n                    </li>\n                  </ul>\n                </div>\n              </div>\n            </li>\n            <li class="dl-menu__menu-item dl-menu__menu-item--iconic-item">\n              <a class="js-search-trigger" href="javascript:;">\n                <i class="fa fa-search fa-2x"></i>\n              </a>\n            </li>\n          </ul>\n          <!-- Search -->\n          <div class="search js-search js-desktop-search" id="search" style="position: absolute; top: 0px;">\n            <angucomplete-alt id="autocomplete__companies" input-class="search__input" minlength="1" ng-controller="AutocompleteController" pause="400" selected-object="selectItem" text-no-results="عفواً, لم يتم العثور على أي نتائج" text-searching="جارٍ البحث..." title-field="label" remote-url="/api/1/companySearch?query=" placeholder="اكتب كلمة البحث أو رمز الشركة" class="ng-scope ng-isolate-scope"><div class="angucomplete-holder" ng-class="{\'angucomplete-dropdown-visible\': showDropdown}">  <input id="autocomplete__companies_value" ng-model="searchStr" ng-disabled="disableInput" type="" placeholder="اكتب كلمة البحث أو رمز الشركة" maxlength="524288" ng-focus="onFocusHandler()" class="search__input ng-valid-maxlength" ng-blur="hideResults($event)" autocapitalize="off" autocorrect="off" autocomplete="off" ng-change="inputChangeHandler(searchStr)">  <div id="autocomplete__companies_dropdown" class="angucomplete-dropdown ng-hide" ng-show="showDropdown"><div class="angucomplete-searching ng-hide" ng-show="searching"><div class="spinner"><div class="dot1"></div><div class="dot2"></div></div></div>    <div class="angucomplete-searching ng-binding" ng-show="!searching &amp;&amp; (!results || results.length == 0)" ng-bind="textNoResults">عفواً, لم يتم العثور على أي نتائج</div>    <!-- ngRepeat: result in results -->  </div></div></angucomplete-alt>\n            <i class="fa fa-search fa-2x"></i>\n          </div>\n        </nav>\n      </div>\n    </header>\n\n    <div id="Leaderboard">\n    </div>\n\n    <div></div>\n\n    <div class="mi-content">\n      <div>\n  <!--<div th:replace="components/ads/internal/mobile-banner" />-->\n\n  <main class="mi-main-content">\n    \n  <h1 class="mi-section__title">الشركات المدرجة</h1>\n\n  <div class="mi-table-container ng-scope" ng-controller="PagedTableController as table" country="sa" src="/api/1/listed-companies">\n    <div class="global__table-container md-whiteframe-z1 ng-isolate-scope" st-init="" st-pipe="fetch" st-table="table.data">\n      <span class="global__no-results ng-hide" ng-show="table.rows.length == 0 &amp;&amp; table.loaded">عفواّ, لم نعثر على أى نتائج</span>\n      <table class="mi-table" ng-hide="!table.loaded || table.rows.length == 0" style="">\n\n        <thead class="mi-table__thead">\n          <tr class="mi-table__thead-tr">\n            <th st-ratio="20" style="width: 20%;">الشركة</th>\n            <th>السهم</th>\n            <th class="mi-hide-for-small">القطاع</th>\n            \n            <th>آخر سعر</th>\n            <th>نسبة التغيير</th>\n            <th class="mi-hide-for-small">آخر تحديث</th>\n          </tr>\n        </thead>\n        <tbody class="mi-table__tbody" ng-hide="table.reloading">\n          <!-- ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2110/profile" class="ng-binding" href="/markets/TDWL/stocks/2110/profile">الكابلات السعودية</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2110" class="ng-binding" href="/markets/TDWL/stocks/2110">2110</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">السلع الرأسمالية</td>\n            \n            <td class="number ng-binding">14.3</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              0.56%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2100/profile" class="ng-binding" href="/markets/TDWL/stocks/2100/profile">وفرة</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2100" class="ng-binding" href="/markets/TDWL/stocks/2100">2100</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">إنتاج الأغذية</td>\n            \n            <td class="number ng-binding">59.3</td>\n            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              -1.33%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2080/profile" class="ng-binding" href="/markets/TDWL/stocks/2080/profile">الغاز</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/2080" class="ng-binding" href="/markets/TDWL/stocks/2080">2080</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">المرافق العامة</td>\n            \n            <td class="number ng-binding">29</td>\n            <td class="number ng-binding" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              0.00%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4020/profile" class="ng-binding" href="/markets/TDWL/stocks/4020/profile">العقارية</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4020" class="ng-binding" href="/markets/TDWL/stocks/4020">4020</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">إدارة وتطوير العقارات</td>\n            \n            <td class="number ng-binding">13.16</td>\n            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              -0.30%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4030/profile" class="ng-binding" href="/markets/TDWL/stocks/4030/profile">البحري</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4030" class="ng-binding" href="/markets/TDWL/stocks/4030">4030</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">الطاقة</td>\n            \n            <td class="number ng-binding">38.3</td>\n            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              -0.65%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4040/profile" class="ng-binding" href="/markets/TDWL/stocks/4040/profile">سابتكو</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4040" class="ng-binding" href="/markets/TDWL/stocks/4040">4040</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">النقل</td>\n            \n            <td class="number ng-binding">16.3</td>\n            <td class="number ng-binding" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              0.00%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4050/profile" class="ng-binding" href="/markets/TDWL/stocks/4050/profile">ساسكو</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4050" class="ng-binding" href="/markets/TDWL/stocks/4050">4050</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">تجزئة السلع الكمالية</td>\n            \n            <td class="number ng-binding">29.4</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              0.68%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4061/profile" class="ng-binding" href="/markets/TDWL/stocks/4061/profile">أنعام القابضة</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4061" class="ng-binding" href="/markets/TDWL/stocks/4061">4061</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">تجزئة الأغذية</td>\n            \n            <td class="number ng-binding">188</td>\n            <td class="number ng-binding" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              0.00%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4070/profile" class="ng-binding" href="/markets/TDWL/stocks/4070/profile">تهامة</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4070" class="ng-binding" href="/markets/TDWL/stocks/4070">4070</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">الإعلام والترفيه</td>\n            \n            <td class="number ng-binding">23.52</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              0.94%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4080/profile" class="ng-binding" href="/markets/TDWL/stocks/4080/profile">عسير</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4080" class="ng-binding" href="/markets/TDWL/stocks/4080">4080</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">الإستثمار والتمويل</td>\n            \n            <td class="number ng-binding">11.52</td>\n            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              -0.69%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4090/profile" class="ng-binding" href="/markets/TDWL/stocks/4090/profile">طيبة</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4090" class="ng-binding" href="/markets/TDWL/stocks/4090">4090</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">إدارة وتطوير العقارات</td>\n            \n            <td class="number ng-binding">29.6</td>\n            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              -0.17%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4100/profile" class="ng-binding" href="/markets/TDWL/stocks/4100/profile">مكة</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4100" class="ng-binding" href="/markets/TDWL/stocks/4100">4100</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">إدارة وتطوير العقارات</td>\n            \n            <td class="number ng-binding">58.6</td>\n            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              -0.68%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4110/profile" class="ng-binding" href="/markets/TDWL/stocks/4110/profile">باتك</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4110" class="ng-binding" href="/markets/TDWL/stocks/4110">4110</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">النقل</td>\n            \n            <td class="number ng-binding">26.15</td>\n            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              -0.76%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4130/profile" class="ng-binding" href="/markets/TDWL/stocks/4130/profile">الباحة</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4130" class="ng-binding" href="/markets/TDWL/stocks/4130">4130</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">الإستثمار والتمويل</td>\n            \n            <td class="number ng-binding">17.98</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              1.93%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4140/profile" class="ng-binding" href="/markets/TDWL/stocks/4140/profile">صادرات</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4140" class="ng-binding" href="/markets/TDWL/stocks/4140">4140</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">السلع الرأسمالية</td>\n            \n            <td class="number ng-binding">63.1</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              2.60%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4150/profile" class="ng-binding" href="/markets/TDWL/stocks/4150/profile">التعمير</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4150" class="ng-binding" href="/markets/TDWL/stocks/4150">4150</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">إدارة وتطوير العقارات</td>\n            \n            <td class="number ng-binding">15.64</td>\n            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              -0.38%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4160/profile" class="ng-binding" href="/markets/TDWL/stocks/4160/profile">ثمار</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4160" class="ng-binding" href="/markets/TDWL/stocks/4160">4160</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding"></td>\n            \n            <td class="number ng-binding">17.2</td>\n            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              -7.82%\n            </td>\n            <td class="mi-hide-for-small ng-binding">10 ديسمبر 2019</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4170/profile" class="ng-binding" href="/markets/TDWL/stocks/4170/profile">شمس</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4170" class="ng-binding" href="/markets/TDWL/stocks/4170">4170</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">الخدمات الإستهلاكية</td>\n            \n            <td class="number ng-binding">31.35</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              0.64%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4180/profile" class="ng-binding" href="/markets/TDWL/stocks/4180/profile">مجموعة فتيحي</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4180" class="ng-binding" href="/markets/TDWL/stocks/4180">4180</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">السلع طويلة الاجل</td>\n            \n            <td class="number ng-binding">11.34</td>\n            <td class="number ng-binding" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              0.00%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4190/profile" class="ng-binding" href="/markets/TDWL/stocks/4190/profile">جرير</a>\n            </td>\n            <td>\n              <a ng-href="/markets/TDWL/stocks/4190" class="ng-binding" href="/markets/TDWL/stocks/4190">4190</a>\n            </td>\n            <td class="mi-hide-for-small ng-binding">تجزئة السلع الكمالية</td>\n            \n            <td class="number ng-binding">166</td>\n            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">\n              1.97%\n            </td>\n            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>\n          </tr><!-- end ngRepeat: row in table.rows track by $index -->\n        </tbody>\n      </table>\n      <div ng-show="table.searcing" class="ng-hide">\n        <span class="global__loading">جارى التصفية, يرجى الإنتظار ...</span>\n        <div>\n    <div class="sk-spinner sk-spinner-wave">\n        <div class="sk-rect1"></div>\n        <div class="sk-rect2"></div>\n        <div class="sk-rect3"></div>\n        <div class="sk-rect4"></div>\n        <div class="sk-rect5"></div>\n    </div>\n</div>\n      </div>\n      <div ng-hide="table.loaded" class="ng-hide" style="">\n        <div>\n    <div class="sk-spinner sk-spinner-wave">\n        <div class="sk-rect1"></div>\n        <div class="sk-rect2"></div>\n        <div class="sk-rect3"></div>\n        <div class="sk-rect4"></div>\n        <div class="sk-rect5"></div>\n    </div>\n</div>\n      </div>\n      <div st-items-by-page="20" st-pagination="" st-template="/assets/ui/ngt/components/pagination/pagination.ng.html" class="ng-isolate-scope"><!-- ngIf: pages.length >= 2 --><div class="pagination ng-scope" ng-if="pages.length >= 2">\n    <nav role="navigation" aria-label="Pagination">\n        <ul class="cd-pagination no-space" role="menubar" aria-label="Pagination">\n            <!-- ngIf: currentPage > 1 --><li ng-if="currentPage > 1" class="ng-scope">\n                <a ng-click="selectPage(1)">\n                    <i class="fa fa-angle-double-right fa-lg"></i>\n                </a>\n            </li><!-- end ngIf: currentPage > 1 -->\n            <!-- ngIf: currentPage > 1 --><li class="cd-pagination__button ng-scope" aria-disabled="true" ng-if="currentPage > 1">\n                <a ng-click="selectPage(currentPage-1)" class="ng-binding">\n                  <i class="fa fa-lg fa-angle-right"></i>\n                  السابق\n                </a>\n            </li><!-- end ngIf: currentPage > 1 -->\n            <!-- ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">\n                <a ng-click="selectPage(page)" class="ng-binding">1</a>\n            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">\n                <a ng-click="selectPage(page)" class="ng-binding">2</a>\n            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope current">\n                <a ng-click="selectPage(page)" class="ng-binding">3</a>\n            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">\n                <a ng-click="selectPage(page)" class="ng-binding">4</a>\n            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">\n                <a ng-click="selectPage(page)" class="ng-binding">5</a>\n            </li><!-- end ngRepeat: page in pages -->\n            <!-- ngIf: currentPage < numPages --><li class="cd-pagination__button ng-scope" ng-if="currentPage < numPages">\n                <a ng-click="selectPage(currentPage+1)" href="" class="ng-binding">\n                  التالي\n                    <i class="fa fa-angle-left fa-lg"></i>\n                </a>\n            </li><!-- end ngIf: currentPage < numPages -->\n            <!-- ngIf: currentPage < numPages --><li ng-if="currentPage < numPages" class="ng-scope">\n                <a ng-click="selectPage(numPages)">\n                    <i class="fa fa-angle-double-left  fa-lg"></i>\n                </a>\n            </li><!-- end ngIf: currentPage < numPages -->\n        </ul>\n    </nav>\n</div><!-- end ngIf: pages.length >= 2 -->\n</div>\n    </div>\n  </div>\n\n  \n\n  <!-- Speakol Widget - Removal IB-51 -->\n  <!-- <div th:replace="components/ads/common/speakol-one"/> -->\n\n\n\n\n\n  </main>\n  <aside class="mi-sidebar mi-show-for-large-up">\n    <!-- Radio component doesn\'t exist in English version -->\n\n    <!---->\n\n  <!--  <div th:unless="${device.isMobile()}">\n      <div>\n        <iframe onload="adjustIframeSize(this);" class="ad-iframe" src="/ads/side-bar"></iframe>\n      </div>\n      <script>\n        function adjustIframeSize(self) {\n          var index = 0;\n          var interval = setInterval( function(){\n            if (index < 3) {\n              self.style.height=self.contentDocument.body.scrollHeight +10 + \'px\';self.style.width=\'310px\';\n              index = index + 1;\n            } else {\n              clearInterval(interval)\n            }\n          }, 1);\n\n        }\n\n\n      </script>\n    </div>-->\n    <div>\n\n    <div class="mi-popular-news news-sidebar-mub md-whiteframe-z1 ng-scope" ng-controller="PopularNewsController as popular">\n    <h2 class="global__h2--collapsed">الأخبار الأكثر</h2>\n    <v-tabs active="tabs.active" class="vTabs--secondary ng-isolate-scope" control="tabs">\n      <!-- ngRepeat: page in popular.pages --><v-tab ng-bind="page.title" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope is-active" role="tab" aria-selected="true" tabindex="0">قراءة</v-tab><!-- end ngRepeat: page in popular.pages --><v-tab ng-bind="page.title" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope" role="tab" aria-selected="false" tabindex="-1">مشاركة</v-tab><!-- end ngRepeat: page in popular.pages -->\n    </v-tabs>\n\n    <v-pages active="tabs.active" class="vPages--default ng-isolate-scope" control="tabs" ng-swipe-left="tabs.next()" ng-swipe-right="tabs.previous()">\n      <!-- ngRepeat: page in popular.pages --><v-page ng-bind-html="page.content | unsafe" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope is-active" role="tabpanel">\n    \n    \n<!--      <th:block>\n        <div th:remove="tag" th:if="${i.index == 1}">\n          <div th:replace="components/ads/internal/native" ></div>\n          <div th:replace="components/ads/internal/mobile-native" ></div>\n        </div>\n      </th:block>-->\n      <div class="mi-home-media-block">\n        <a class="mi-home-media-block__image" href="/news/3680410/%D9%87%D9%8A%D8%A6%D8%A9-%D8%A7%D9%84%D9%86%D9%82%D9%84-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%B5%D8%B1%D9%81-%D8%AF%D8%B9%D9%85-%D8%A7%D9%84%D8%A3%D9%81%D8%B1%D8%A7%D8%AF-%D8%A7%D9%84%D8%B9%D8%A7%D9%85%D9%84%D9%8A%D9%86-%D9%81%D9%8A-%D9%86%D8%B4%D8%A7%D8%B7-%D8%AA%D9%88%D8%AC%D9%8A%D9%87-%D8%A7%D9%84%D9%85%D8%B1%D9%83%D8%A8%D8%A7%D8%AA-%D9%82%D8%B1%D9%8A%D8%A8%D8%A7-/">\n          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="فرع تابع لهيئة العامة للنقل السعودية" src="https://static.mubasher.info/File.Story_Image/3e19073c5aca3db54ef2c06eb4bf5ea6/144.jpg">\n        </a>\n        <div class="mi-home-media-block__content">\n          <a class="mi-home-media-block__title" href="/news/3680410/%D9%87%D9%8A%D8%A6%D8%A9-%D8%A7%D9%84%D9%86%D9%82%D9%84-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%B5%D8%B1%D9%81-%D8%AF%D8%B9%D9%85-%D8%A7%D9%84%D8%A3%D9%81%D8%B1%D8%A7%D8%AF-%D8%A7%D9%84%D8%B9%D8%A7%D9%85%D9%84%D9%8A%D9%86-%D9%81%D9%8A-%D9%86%D8%B4%D8%A7%D8%B7-%D8%AA%D9%88%D8%AC%D9%8A%D9%87-%D8%A7%D9%84%D9%85%D8%B1%D9%83%D8%A8%D8%A7%D8%AA-%D9%82%D8%B1%D9%8A%D8%A8%D8%A7-/">هيئة النقل السعودية: صرف دعم الأفراد العاملين في نشاط توجيه المركبات قريباً</a>\n        </div>\n        \n      </div>\n    \n    \n<!--      <th:block>\n        <div th:remove="tag" th:if="${i.index == 1}">\n          <div th:replace="components/ads/internal/native" ></div>\n          <div th:replace="components/ads/internal/mobile-native" ></div>\n        </div>\n      </th:block>-->\n      <div class="mi-home-media-block">\n        <a class="mi-home-media-block__image" href="/news/3680099/%D8%A7%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D8%B5%D8%AF%D8%B1-%D9%82%D8%B1%D8%A7%D8%B1%D8%A7-%D8%A8%D8%B4%D8%A3%D9%86-%D8%A7%D9%84%D9%85%D8%A8%D8%AA%D8%B9%D8%AB%D9%8A%D9%86/">\n          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="وزير التعليم السعودي، حمد بن محمد آل الشيخ، أرشيفية" src="https://static.mubasher.info/File.Story_Image/9e9e9919f67b43d61c15c7fd734289d3/144.jpg">\n        </a>\n        <div class="mi-home-media-block__content">\n          <a class="mi-home-media-block__title" href="/news/3680099/%D8%A7%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D8%B5%D8%AF%D8%B1-%D9%82%D8%B1%D8%A7%D8%B1%D8%A7-%D8%A8%D8%B4%D8%A3%D9%86-%D8%A7%D9%84%D9%85%D8%A8%D8%AA%D8%B9%D8%AB%D9%8A%D9%86/">التعليم السعودية تصدر قراراً بشأن المبتعثين</a>\n        </div>\n        \n      </div>\n    \n    \n<!--      <th:block>\n        <div th:remove="tag" th:if="${i.index == 1}">\n          <div th:replace="components/ads/internal/native" ></div>\n          <div th:replace="components/ads/internal/mobile-native" ></div>\n        </div>\n      </th:block>-->\n      <div class="mi-home-media-block">\n        <a class="mi-home-media-block__image" href="/news/3680101/%D9%85%D8%AD%D8%AF%D8%AB-%D8%A7%D9%84%D8%B0%D9%87%D8%A8-%D9%8A%D8%AA%D9%87%D8%A7%D9%88%D9%89-93-%D8%AF%D9%88%D9%84%D8%A7%D8%B1%D8%A7-%D8%B9%D9%86%D8%AF-%D8%A7%D9%84%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D9%85%D8%B9-%D9%85%D9%83%D8%A7%D8%B3%D8%A8-%D8%A7%D9%84%D8%A3%D8%B3%D9%87%D9%85/">\n          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/caeadbca5bf2481c2d38f04625e51f00/144.jpg">\n        </a>\n        <div class="mi-home-media-block__content">\n          <a class="mi-home-media-block__title" href="/news/3680101/%D9%85%D8%AD%D8%AF%D8%AB-%D8%A7%D9%84%D8%B0%D9%87%D8%A8-%D9%8A%D8%AA%D9%87%D8%A7%D9%88%D9%89-93-%D8%AF%D9%88%D9%84%D8%A7%D8%B1%D8%A7-%D8%B9%D9%86%D8%AF-%D8%A7%D9%84%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D9%85%D8%B9-%D9%85%D9%83%D8%A7%D8%B3%D8%A8-%D8%A7%D9%84%D8%A3%D8%B3%D9%87%D9%85/">محدث.. الذهب يتهاوى 93 دولاراً عند التسوية مع مكاسب الأسهم</a>\n        </div>\n        \n      </div>\n    \n    \n<!--      <th:block>\n        <div th:remove="tag" th:if="${i.index == 1}">\n          <div th:replace="components/ads/internal/native" ></div>\n          <div th:replace="components/ads/internal/mobile-native" ></div>\n        </div>\n      </th:block>-->\n      <div class="mi-home-media-block">\n        <a class="mi-home-media-block__image" href="/news/3679355/%D8%A7%D9%84%D9%84%D9%8A%D8%B1%D8%A9-%D8%A7%D9%84%D8%AA%D8%B1%D9%83%D9%8A%D8%A9-%D8%AA%D9%87%D8%A8%D8%B7-%D8%A5%D9%84%D9%89-%D9%85%D8%B3%D8%AA%D9%88%D9%89-%D8%AA%D8%A7%D8%B1%D9%8A%D8%AE%D9%8A-%D8%AC%D8%AF%D9%8A%D8%AF/">\n          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/1242bfad1995396ce3f6470a3d5584c2/144.jpg">\n        </a>\n        <div class="mi-home-media-block__content">\n          <a class="mi-home-media-block__title" href="/news/3679355/%D8%A7%D9%84%D9%84%D9%8A%D8%B1%D8%A9-%D8%A7%D9%84%D8%AA%D8%B1%D9%83%D9%8A%D8%A9-%D8%AA%D9%87%D8%A8%D8%B7-%D8%A5%D9%84%D9%89-%D9%85%D8%B3%D8%AA%D9%88%D9%89-%D8%AA%D8%A7%D8%B1%D9%8A%D8%AE%D9%8A-%D8%AC%D8%AF%D9%8A%D8%AF/">الليرة التركية تهبط إلى مستوى تاريخي جديد</a>\n        </div>\n        \n      </div>\n    \n    \n<!--      <th:block>\n        <div th:remove="tag" th:if="${i.index == 1}">\n          <div th:replace="components/ads/internal/native" ></div>\n          <div th:replace="components/ads/internal/mobile-native" ></div>\n        </div>\n      </th:block>-->\n      <div class="mi-home-media-block">\n        <a class="mi-home-media-block__image" href="/news/3679705/%D8%B9%D9%85%D9%84%D8%A9-%D8%A7%D9%84%D8%A8%D9%8A%D8%AA%D9%83%D9%88%D9%8A%D9%86-%D8%AA%D8%B9%D8%A7%D9%88%D8%AF-%D8%A7%D9%84%D8%B5%D8%B9%D9%88%D8%AF-%D8%A3%D8%B9%D9%84%D9%89-12-%D8%A3%D9%84%D9%81-%D8%AF%D9%88%D9%84%D8%A7%D8%B1/">\n          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/ab491b6531081c6058fa5b203b6cbecc/144.jpg">\n        </a>\n        <div class="mi-home-media-block__content">\n          <a class="mi-home-media-block__title" href="/news/3679705/%D8%B9%D9%85%D9%84%D8%A9-%D8%A7%D9%84%D8%A8%D9%8A%D8%AA%D9%83%D9%88%D9%8A%D9%86-%D8%AA%D8%B9%D8%A7%D9%88%D8%AF-%D8%A7%D9%84%D8%B5%D8%B9%D9%88%D8%AF-%D8%A3%D8%B9%D9%84%D9%89-12-%D8%A3%D9%84%D9%81-%D8%AF%D9%88%D9%84%D8%A7%D8%B1/">عملة البيتكوين تعاود الصعود أعلى 12 ألف دولار</a>\n        </div>\n        \n      </div>\n    \n    \n<!--      <th:block>\n        <div th:remove="tag" th:if="${i.index == 1}">\n          <div th:replace="components/ads/internal/native" ></div>\n          <div th:replace="components/ads/internal/mobile-native" ></div>\n        </div>\n      </th:block>-->\n      <div class="mi-home-media-block">\n        <a class="mi-home-media-block__image" href="/news/3679783/%D8%A3%D8%B1%D8%A7%D9%85%D9%83%D9%88-%D8%AA%D8%B1%D9%81%D8%B9-%D8%A3%D8%B3%D8%B9%D8%A7%D8%B1-%D8%A7%D9%84%D8%A8%D9%86%D8%B2%D9%8A%D9%86-%D8%A8%D9%86%D8%AD%D9%88-11-%D8%AD%D8%AA%D9%89-10-%D8%B3%D8%A8%D8%AA%D9%85%D8%A8%D8%B1/">\n          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="محطة للتزود بالوقود" src="https://static.mubasher.info/File.Story_Image/cf61a8737c62c57737e53b3677aa2bbc/144.jpg">\n        </a>\n        <div class="mi-home-media-block__content">\n          <a class="mi-home-media-block__title" href="/news/3679783/%D8%A3%D8%B1%D8%A7%D9%85%D9%83%D9%88-%D8%AA%D8%B1%D9%81%D8%B9-%D8%A3%D8%B3%D8%B9%D8%A7%D8%B1-%D8%A7%D9%84%D8%A8%D9%86%D8%B2%D9%8A%D9%86-%D8%A8%D9%86%D8%AD%D9%88-11-%D8%AD%D8%AA%D9%89-10-%D8%B3%D8%A8%D8%AA%D9%85%D8%A8%D8%B1/">أرامكو ترفع أسعار البنزين بنحو 11% حتى 10 سبتمبر</a>\n        </div>\n        \n      </div>\n    \n    \n<!--      <th:block>\n        <div th:remove="tag" th:if="${i.index == 1}">\n          <div th:replace="components/ads/internal/native" ></div>\n          <div th:replace="components/ads/internal/mobile-native" ></div>\n        </div>\n      </th:block>-->\n      <div class="mi-home-media-block">\n        <a class="mi-home-media-block__image" href="/news/3680546/%D8%A8%D9%803-%D8%B6%D9%88%D8%A7%D8%A8%D8%B7-%D8%A7%D9%84%D8%AA%D9%82%D8%A7%D8%B9%D8%AF-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D9%88%D8%B6%D8%AD-%D8%B7%D8%B1%D9%8A%D9%82%D8%A9-%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D8%A7%D9%84%D9%85%D8%B9%D8%A7%D8%B4-%D9%84%D9%85%D9%88%D8%B8%D9%81%D9%8A-%D8%A7%D9%84%D9%82%D8%B7%D8%A7%D8%B9-%D8%A7%D9%84%D8%B9%D8%A7%D9%85/">\n          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="مؤسسة التقاعد السعودية" src="https://static.mubasher.info/File.Story_Image/68cc490a847f0daba3afd0ddbd6d06c8/144.jpg">\n        </a>\n        <div class="mi-home-media-block__content">\n          <a class="mi-home-media-block__title" href="/news/3680546/%D8%A8%D9%803-%D8%B6%D9%88%D8%A7%D8%A8%D8%B7-%D8%A7%D9%84%D8%AA%D9%82%D8%A7%D8%B9%D8%AF-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D9%88%D8%B6%D8%AD-%D8%B7%D8%B1%D9%8A%D9%82%D8%A9-%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D8%A7%D9%84%D9%85%D8%B9%D8%A7%D8%B4-%D9%84%D9%85%D9%88%D8%B8%D9%81%D9%8A-%D8%A7%D9%84%D9%82%D8%B7%D8%A7%D8%B9-%D8%A7%D9%84%D8%B9%D8%A7%D9%85/">بـ3 ضوابط.. التقاعد السعودية توضح طريقة تسوية المعاش لموظفي القطاع العام</a>\n        </div>\n        \n      </div>\n    \n\n    <a class="mi-article-widget__more-button" href="/news/SA/now/popular">\n      <span>المزيد</span>\n      <i class="fa fa-chevron-left"></i>\n    </a>\n  \n  </v-page><!-- end ngRepeat: page in popular.pages --><v-page ng-bind-html="page.content | unsafe" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope" role="tabpanel">\n    \n    \n\n    <a class="mi-article-widget__more-button" href="/news/SA/now/trending/">\n      <span>المزيد</span>\n      <i class="fa fa-chevron-left"></i>\n    </a>\n  \n  </v-page><!-- end ngRepeat: page in popular.pages -->\n    </v-pages>\n  </div>\n    <div id="MPU">\n\n    </div>\n\n    </div>\n\n    <!-- Speakol Widget - Removal IB-51 -->\n    <!-- <div th:replace="components/ads/common/speakol-two"/> -->\n\n<!--    <div th:unless="${device.isMobile()}">\n      <div th:replace="components/ads/insticator/insticator-widget"/>\n    </div>-->\n    <!-- -->\n\n    <!-- PS -->\n    <!--<div th:replace="components/ads/internal/may-like-articles" />-->\n\n    <!--<div th:replace="components/ads/internal/second-fold" />-->\n    <!--    <div th:if="${#locale.getLanguage() == \'ar\'}">\n          <span class="home__title">راديو مباشر</span>\n          <div class="internal-radio-carousel-container"></div>\n        </div>-->\n  </aside>\n\n\n\n<!--  <div th:replace="components/ads/internal/mobile-fullpage"/>-->\n\n  <!--<div th:replace="components/ads/internal/mobile-interstitial"/>-->\n<!--commented out as per Fayoumi\'s request-->\n  <!--<div th:replace="components/ads/internal/mobile-outstream"/>-->\n\n  <!--MFP-228 New Fixed-Replacement-ROS ads-->\n<!--  <div th:replace="components/ads/home/mobile-fixed-replacement"/>\n\n  <div th:replace="components/ads/news/dfp/mobile/MPU3"/>-->\n\n<!--Commented out as per Fayoumi\'s request-->\n  <!--<div th:replace="components/ads/internal/outstream"/>-->\n\n\n\n<!--  <div th:if="${device.isMobile()}">\n    <div th:replace="components/ads/dfp/mobile-internal-pages"/>\n  </div>-->\n\n<!--  <div th:if="${device.isMobile()}">\n    <div th:replace="components/ads/insticator/insticator-widget"/>\n  </div>-->\n\n <!-- <div th:replace="components/ads/internal/mobile-above-footer"/>-->\n</div>\n    </div>\n    <footer>\n  <div class="mi-footer">\n    <div class="mi-show-for-large-up mi-footer__main-menu">\n      <ul>\n        <li class="mi-footer__menu-item mi-footer__menu__markets" id="markets">\n          <div class="mi-footer__menu-level1">الأسواق</div>\n          <ul>\n            <h3 class="mi-footer__menu-level2 invisible">الأسواق</h3>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/TDWL">سوق الأسهم السعودي</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/EGX">البورصة المصرية</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/DFM">سوق دبي المالي</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/ADX">سوق أبوظبي</a>\n            </li>\n          </ul>\n          <ul>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/BB">بورصة البحرين</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/QE">بورصة قطر</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/MSM">سوق مسقط</a>\n            </li>\n          </ul>\n          <ul>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/KSE">سوق الكويت</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/ASE">بورصة عمان</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/CSE">سوق الدار البيضاء</a>\n            </li>\n          </ul>\n          <ul>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/BDT">بورصة تونس</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/PEX">سوق فلسطين</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/ISX">سوق العراق</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/international-indices">مؤشرات الأسواق العالمية</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/markets/commodities-prices">أسعار المعادن والطاقة</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/countries/sa/currencies">أسعار العملات</a>\n            </li>\n            <!--<li>\n              <a class="mi-footer__menu-level3"\n                 th:href="${@url.to(\'RMPC#regionalMap\')}"\n                 th:text="#{navigation.markets.regional-map}"/>\n            </li>-->\n          </ul>\n        </li>\n        <li class="mi-footer__menu-item mi-footer__menu__news" id="news">\n          <ul>\n            <div class="mi-footer__menu-level1">الأخبار</div>\n            <li class="mi-footer__menu__news__submenu">\n              <h3 class="mi-footer__menu-level2">أخبار الدول</h3>\n              <ul>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/eg/now/latest">مصر</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/now/latest">السعودية</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/ae/now/latest">الإمارات</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/bh/now/latest">البحرين</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/qa/now/latest">قطر</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/om/now/latest">عمان</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/kw/now/latest">الكويت</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/jo/now/latest">الأردن</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/ma/now/latest">المغرب</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/tn/now/latest">تونس</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/ps/now/latest">فلسطين</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/iq/now/latest">العراق</a>\n                </li>\n              </ul>\n            </li>\n            <li class="mi-footer__menu__news__submenu">\n              <h3 class="mi-footer__menu-level2">أخبار إقليمية</h3>\n              <ul>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/regions/gulf">الخليج</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/regions/levant">الشام</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/regions/north-africa">شمال أفريقيا</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/regions/middle-east">الشرق الأوسط</a>\n                </li>\n              </ul>\n              <!-- happening now -->\n              <h3 class="mi-footer__menu-level2">يحدث الآن</h3>\n              <ul>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/now/top">أهم الأخبار</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/now/exclusive">حصرياً مباشر</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/now/latest">آخر الأخبار</a>\n                </li>\n                \n                  <li>\n                    <a class="mi-footer__menu-level3" href="/news/sa/now/announcements">إعلانات السوق</a>\n                  </li>\n                  \n                \n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/now/popular">منتشر الآن</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/now/trending/">الأكثر مشاركة</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/now/news-releases">بيانات صحفية</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/international/misc">أخبار منوعة</a>\n                </li>\n              </ul>\n            </li>\n            <li class="mi-footer__menu__news__submenu">\n              <h3 class="mi-footer__menu-level2">نبض السوق</h3>\n              <ul>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/stocks">أخبار الأسهم</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/analysis">تحليلات إخبارية</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/local">اقتصاد محلي</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/recommendations">توصيات</a>\n                </li>\n              </ul>\n              <h3 class="mi-footer__menu-level2">أخبار القطاعات</h3>\n              <ul>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/category/banking">بنوك</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/sa/category/realEstate">عقارات</a>\n                </li>\n              </ul>\n              <h3 class="mi-footer__menu-level2">أخبار عالمية</h3>\n              <ul>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/international/global-economy">اقتصاد عالمى</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/international/goods-and-metals">أحداث عالمية</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/international/global-indices">مؤشرات عالمية</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/international/oil-and-energy">نفط ومعادن</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/international/currencies">عملات</a>\n                </li>\n                <li>\n                  <a class="mi-footer__menu-level3" href="/news/international/global-reports">تقارير عالمية</a>\n                </li>\n              </ul>\n            </li>\n          </ul>\n        </li>\n        <li class="mi-footer__menu-item mi-footer__menu__companies" id="companies">\n          <div class="mi-footer__menu-level1">الشركات</div>\n          <ul>\n            <h3 class="mi-footer__menu-level2 invisible">الشركات</h3>\n            <li>\n              <a class="mi-footer__menu-level3" href="/countries/sa/companies">الشركات المدرجة</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/countries/sa/events">مفكرة الشركات</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/countries/sa/stock-prices">أسعار الأسهم</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/countries/sa/earnings">إعلانات الأرباح</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/countries/sa/fair-values">القيم العادلة</a>\n            </li>\n            <li>\n              \n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/countries/sa/major-shareholders">كبار الملاك</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/countries/sa/ipos">قائمة الإكتتابات</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/ipo/list">بحث فى الاكتتابات</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/ipos/news">أخبار الاكتتابات</a>\n            </li>\n            <li>\n              <a class="mi-footer__menu-level3" href="/ipo/calendar">مفكرة الاكتتابات</a>\n            </li>\n          </ul>\n        </li>\n        <li class="mi-footer__menu-item mi-footer__menu__analysis-tools" id="analysis-tools">\n          <div class="mi-footer__menu-level1">أدوات التحليل</div>\n          <!-- If current country has one market only -->\n          \n            <ul>\n              <h3 class="mi-footer__menu-level2 invisible">أدوات التحليل</h3>\n              <li>\n                <a class="mi-footer__menu-level3" href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>\n              </li>\n              <li>\n                <a class="mi-footer__menu-level3" href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>\n              </li>\n              <li>\n                <a class="mi-footer__menu-level3" href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>\n              </li>\n              <li>\n                <a class="mi-footer__menu-level3" href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>\n              </li>\n              <li>\n                <a class="mi-footer__menu-level3" href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>\n              </li>\n              <li>\n                <a class="mi-footer__menu-level3" href="/analysis-tools/performance-comparison">مقارنة الأداء</a>\n              </li>\n            </ul>\n          \n          <!-- If current country has more than one markets i.e UAE -->\n          \n        </li>\n      </ul>\n    </div>\n\n    <div class="mi-footer__second-fold">\n      <div class="mi-footer__column1">\n        <div class="mi-footer__copyright">\n          <div class="mi-footer__logo" onclick="window.location.href=\'/countries/sa\'">\n            \n  <svg viewBox="0 0 494.387 190.555">\n    <use xlink:href="#logo-white"></use>\n  </svg>\n  \n\n          </div>\n          <span>جميع الحقوق تعود لشركة مباشر العالمية © 2005 - 2020</span>\n        </div>\n        <ul class="mi-footer__links">\n          <li>\n            <a href="/s/Terms">اتفاقية الاستخدام</a>\n          </li>\n          <li>\n            <a href="/s/disclaimer">إخلاء المسؤولية</a>\n          </li>\n          <li>\n            <a href="/s/aboutus">من نحن</a>\n          </li>\n          <li>\n            <a href="/contact">اتصل بنا</a>\n          </li>\n          <li>\n            <a href="/advertise">أعلن معنا</a>\n          </li>\n          <li>\n            <a href="http://www.decypha.com/" target="_blank">موقع ديسيفا</a>\n          </li>\n          <li>\n            <a href="/ir-services" target="_blank">خدمات المواقع</a>\n          </li>\n          <li>\n            <a href="/s/Jobs">وظائف</a>\n          </li>\n          <li>\n              <a target="_blank" href="/decypha-packages">ديسيفا</a>\n          </li>\n          <li>\n            <a href="/s/privacy-policy" target="_blank">سياسة الخصوصية</a>\n          </li>\n          <!--<li th:if="${#locale.getLanguage() == \'en\'}">\n            <a href="/s/decypha-financial-intelligence" th:text="#{components.footer.decypha-financial-intelligence}">Decypha Financial Intelligence</a>\n          </li>-->\n        </ul>\n        <div>جميع البيانات متأخرة 15 دقيقة أثناء الجلسة</div>\n        <div>هذا الموقع مرخص من وزراة الثقافة والإعلام السعودية</div>\n        <div>رقم التسجيل :ت 1 125 1435</div>\n      </div>\n      <div class="mi-footer__column2">\n        <ul class="mi-footer__social-icons">\n          <li>\n            <a target="_blank" href="https://twitter.com/mubasher"><i class="fa fa-twitter fa-2x"></i></a>\n          </li>\n          <li>\n            <a href="https://www.facebook.com/Mubasher.Info"><i class="fa fa-facebook fa-2x"></i></a>\n          </li>\n          <li>\n            <a href="https://www.youtube.com/channel/UC7hnxb7gD4nKZdZk3ZlZCYg"><i class="fa fa-youtube fa-2x"></i></a>\n          </li>\n          <li>\n            <a href="https://www.linkedin.com/company/1477149"><i class="fa fa-linkedin fa-2x"></i></a>\n          </li>\n          <li>\n            <a href="/news/rss"><i class="fa fa-rss fa-2x"></i></a>\n          </li>\n          <li>\n            <a href="https://play.google.com/store/apps/details?id=net.mis.mubasherinfo">\n              <i class="fa fa-android fa-2x"></i></a>\n          </li>\n          <li>\n            <a href="https://itunes.apple.com/app/imubasher/id494539772?mt=8"><i class="fa fa-apple fa-2x"></i></a>\n          </li>\n      \n    \n</ul></div></div></div></footer>\n    \n    \n  </div>\n\n\n  <script src="//code.jquery.com/jquery-2.1.4.min.js"></script>\n  <script src="//ajax.googleapis.com/ajax/libs/angularjs/1.3.15/angular.min.js"></script>\n\n  <script src="/assets/ui/lib.min.js"></script>\n  <script src="/assets/ui/main.min.js"></script>\n  <div id="mi-js-scripts"></div>\n  <script>\n    <!-- Fix menu trigger on android browser4 -->\n    $(".dl-menu__menu-item").click(function () {\n      $(this).addClass(".dl-menu-item__hoverd");\n    });\n\n    $(document).ready(function () {\n      $(\'.tooltip\').tooltipster();\n      setTimeout(function(){ dataLayer.push({\nevent: "triggerAds"\n});\n      console.log("triggerAds");\n\n      }, 1000);\n    });\n  </script>\n  \n\n  <div pg-ng-tooltip=""></div>\n</div>\n\n  <!-- Twitter universal website tag code -->\n  <script>\n    !function(e,t,n,s,u,a){e.twq||(s=e.twq=function(){s.exe?s.exe.apply(s,arguments):s.queue.push(arguments);\n    },s.version=\'1.1\',s.queue=[],u=t.createElement(n),u.async=!0,u.src=\'//static.ads-twitter.com/uwt.js\',\n      a=t.getElementsByTagName(n)[0],a.parentNode.insertBefore(u,a))}(window,document,\'script\');\n    // Insert Twitter Pixel ID and Standard Event data below\n    twq(\'init\',\'nyana\');\n    twq(\'track\',\'PageView\');\n  </script>\n  <!-- End Twitter universal website tag code -->\n\n\n\n<div id="mm-blocker" class="mm-slideout"></div></body>' + '<body id="mi" ng-app="app" ng-controller="MainController" class="ar ng-scope" data-gr-c-s-loaded="true"><nav class="header__countries-menu mm-menu mm-offcanvas mm-top mm-front" id="countries-menu"><div class="mm-panel mm-opened mm-current" id="mm-8"><ul class="mm-listview mm-first mm-last">        <li class="header__country-selector__country">          <a href="/change-country?to=ae&amp;url=/countries/sa/companies">الإمارات</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=bh&amp;url=/countries/sa/companies">البحرين</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=om&amp;url=/countries/sa/companies">عُمان</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=qa&amp;url=/countries/sa/companies">قطر</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=kw&amp;url=/countries/sa/companies">الكويت</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=eg&amp;url=/countries/sa/companies">مصر</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=jo&amp;url=/countries/sa/companies">الأردن</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=tn&amp;url=/countries/sa/companies">تونس</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=ma&amp;url=/countries/sa/companies">المغرب</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=ps&amp;url=/countries/sa/companies">فلسطين</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=iq&amp;url=/countries/sa/companies">العراق</a>        </li>      </ul></div></nav><nav class="header__main-menu mm-menu mm-border-full mm-effect-slide-menu mm-effect-zoom-panels mm-pageshadow mm-offcanvas mm-right mm-hasnavbar-top mm-hasnavbar" id="main-menu"><div class="mm-navbar mm-navbar-top mm-hasbtns"><a class="mm-prev mm-btn mm-hidden"></a><a class="mm-title"> </a><a class="mm-close mm-btn" href="#wrapper"></a></div><div class="mm-panel mm-opened mm-current" id="mm-0"><ul class="mm-listview mm-first mm-last">        <li id="markets">          <a class="mm-next mm-fullsubopen" href="#mm-1" data-target="#mm-1"></a><span href="javascript:;">الأسواق</span>                  </li>        <li id="news">          <a class="mm-next mm-fullsubopen" href="#mm-2" data-target="#mm-2"></a><span href="javascript:;">الأخبار</span>                  </li>        <li id="companies">          <a class="mm-next mm-fullsubopen" href="#mm-3" data-target="#mm-3"></a><span href="javascript:;">الشركات</span>                  </li>        <li id="funds">          <a class="mm-next mm-fullsubopen" href="#mm-4" data-target="#mm-4"></a><span href="javascript:;">صناديق الاستثمار</span>                  </li>        <li id="analysis-tool">          <a class="mm-next mm-fullsubopen" href="#mm-5" data-target="#mm-5"></a><span href="javascript:;">أدوات التحليل</span>                  </li>        <li id="islamic-economy">          <a href="/news/islamic-finance">الاقتصاد الإسلامي</a>        </li>        <!--<li class="global__hide-for-ltr" id="radio" th:if="${#locale.getLanguage() == \'ar\'}">          <span th:text="#{navigation.radio}">راديو مباشر</span>          <ul>            <li>              <a th:href="${@url.to(\'RPC#live\')}" th:text="#{navigation.radio.live}"/>            </li>            <li>              <a th:href="${@url.to(\'RPC#latestEpisodesPage\', countryCode)}">آخر الحلقات</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تقارير-اقتصادية\'}">تقارير اقتصادية</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تغطية-خاصة\'}">تغطية خاصة</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'مقالات\'}">مقالات</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#programs\')}" th:text="#{navigation.radio.programs}"/>            </li>            <li>              <a th:href="${@url.to(\'RPC#videoPrograms\')}" th:text="#{navigation.radio.videoPrograms}"/>            </li>            <li>              <a th:href="${@url.to(\'RPC#getExperts\')}">ضيوفنا</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#getPresenters\')}">المذيعون</a>            </li>          </ul>        </li>-->        <li class="global__hide-for-ltr" id="video">          <a href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">مباشر TV</a>        </li>                <li id="fixedincome">          <a class="mm-next mm-fullsubopen" href="#mm-6" data-target="#mm-6"></a><span>السندات</span>                  </li>        <li>          <a class="mm-next mm-fullsubopen" href="#mm-7" data-target="#mm-7"></a><span>شخصي</span>                  </li>        <li>          <a href="http://tawasul.mubasher.info/" target="_blank">تواصل</a>        </li>        <!-- <li>          <a th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank" th:text="#{components.header.decypha}" target="_blank">          </a>        </li> -->        <li>          <a ng-click="decypha(\'decypha\')">ديسيفا</a>        </li>        <!--Add according to MFP-187-->        <li>          <a href="https://contest.mubasher.info/#/home" target="_blank">المستثمر اﻷول</a>        </li>        <li>          <!--Integrating Mubasher Pulse-->        </li><li>        <style>          .pulse-logo2{            padding: 5px 5px 4px;            min-width: 82px;            min-height: 21px;            max-width: 27%;          }        </style>        <a target="_blank" href="https://pulse.mubasher.info">          <img class="pulse-logo2" src="../../../images/pulse-logo.png">        </a>        </li>        <li>        </li><li>          <a href="http://magazine.mubasher.info/" target="_blank">            مجلة مباشر          </a>        </li>        <li class="mm-divider"></li>        <li>          <a href="https://english.mubasher.info">ENGLISH</a>        </li>        <li>                  </li>        <li>          <a class="header__login__text" href="/account/login">دخول</a>                  </li>      </ul></div><div class="mm-panel mm-hidden" id="mm-1"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الأسواق</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/markets/TDWL">سوق الأسهم السعودي</a>            </li>            <li>              <a href="/markets/EGX">البورصة المصرية</a>            </li>            <li>              <a href="/markets/DFM">سوق دبي المالي</a>            </li>            <li>              <a href="/markets/ADX">سوق أبوظبي</a>            </li>            <li>              <a href="/markets/BB">بورصة البحرين</a>            </li>            <li>              <a href="/markets/QE">بورصة قطر</a>            </li>            <li>              <a href="/markets/MSM">سوق مسقط</a>            </li>            <li>              <a href="/markets/BK">سوق الكويت</a>            </li>            <li>              <a href="/markets/ASE">بورصة عمان</a>            </li>            <li>              <a href="/markets/CSE">سوق الدار البيضاء</a>            </li>            <li>              <a href="/markets/BDT">بورصة تونس</a>            </li>            <li>              <a href="/markets/PEX">سوق فلسطين</a>            </li>            <li>              <a href="/markets/ISX">سوق العراق</a>            </li>            <li>              <a href="/international-indices">مؤشرات الأسواق العالمية</a>            </li>            <li>              <a href="/markets/commodities-prices">أسعار المعادن والطاقة</a>            </li>            <li>              <a href="/countries/sa/currencies">أسعار العملات</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-2"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الأخبار</a></div><ul class="mm-listview mm-first mm-last">            <!-- now -->            <li class="mm-divider">يحدث الآن</li>            <li>              <a href="/news/sa/now/top">أهم الأخبار</a>            </li>            <li>              <a href="/news/sa/now/exclusive">حصرياً مباشر</a>            </li>            <li>              <a href="/news/sa/now/latest">آخر الأخبار</a>            </li>                          <li>                <a href="/news/sa/now/announcements">إعلانات السوق</a>              </li>                                      <li class="global__hide-for-ltr">              <a href="/news/sa/now/popular">منتشر الآن</a>            </li>            <li>              <a href="/news/sa/now/trending/">الأكثر مشاركة</a>            </li>            <li>              <a href="/news/now/news-releases">بيانات صحفية</a>            </li><!--            <li>              <a th:href="${@url.to(\'NPC#miscellaneousNews\', countryCode)}"                 th:text="#{navigation.news.now.misc}"/>            </li>-->            <!-- recommendations-->            <li class="mm-divider">نبض السوق</li>            <li>              <a href="/news/sa/pulse/stocks">أخبار الأسهم</a>            </li>            <li>              <a href="/news/sa/pulse/analysis">تحليلات إخبارية</a>            </li>            <li>              <a href="/news/sa/pulse/local">اقتصاد محلي</a>            </li>            <li>              <a href="/news/sa/pulse/recommendations">توصيات</a>            </li>            <li class="mm-divider">أخبار القطاعات</li>            <li>              <a href="/news/sa/category/banking">بنوك</a>            </li>            <li>              <a href="/news/sa/category/realEstate">عقارات</a>            </li>            <li class="mm-divider">أخبار الدول</li>            <li>              <a href="/news/eg/now/latest">مصر</a>            </li>            <li>              <a href="/news/sa/now/latest">السعودية</a>            </li>            <li>              <a href="/news/ae/now/latest">الإمارات</a>            </li>            <li>              <a href="/news/bh/now/latest">البحرين</a>            </li>            <li>              <a href="/news/qa/now/latest">قطر</a>            </li>            <li>              <a href="/news/om/now/latest">عمان</a>            </li>            <li>              <a href="/news/kw/now/latest">الكويت</a>            </li>            <li>              <a href="/news/jo/now/latest">الأردن</a>            </li>            <li>              <a href="/news/ma/now/latest">المغرب</a>            </li>            <li>              <a href="/news/tn/now/latest">تونس</a>            </li>            <li>              <a href="/news/ps/now/latest">فلسطين</a>            </li>            <li>              <a href="/news/iq/now/latest">العراق</a>            </li>            <!-- regions-->            <li class="mm-divider">أخبار إقليمية</li>            <li>              <a href="/news/regions/gulf">الخليج</a>            </li>            <li>              <a href="/news/regions/levant">الشام</a>            </li>            <li>              <a href="/news/regions/north-africa">شمال أفريقيا</a>            </li>            <li>              <a href="/news/regions/middle-east">الشرق الأوسط</a>            </li>            <!-- international -->            <li class="mm-divider">أخبار عالمية</li>            <li>              <a href="/news/international/global-economy">اقتصاد عالمى</a>            </li>            <li>              <a href="/news/international/goods-and-metals">أحداث عالمية</a>            </li>              <li>                <a href="/news/international/global-indices">مؤشرات عالمية</a>              </li>              <li>                <a href="/news/international/oil-and-energy">نفط ومعادن</a>              </li>              <li>                <a href="/news/international/currencies">عملات</a>              </li>              <li>                <a href="/news/international/global-reports">تقارير عالمية</a>              </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-3"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الشركات</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/countries/sa/companies">الشركات المدرجة</a>            </li>            <li>              <a href="/countries/sa/events">مفكرة الشركات</a>            </li>            <li>              <a href="/countries/sa/stock-prices">أسعار الأسهم</a>            </li>            <li>              <a href="/countries/sa/earnings">إعلانات الأرباح</a>            </li>            <li>              <a href="/countries/sa/fair-values">القيم العادلة</a>            </li>            <li>              <a href="/countries/sa/corporate-action">الإجراءات</a>            </li>                        <li>              <a href="/countries/sa/major-shareholders">كبار الملاك</a>            </li>            <li>              <a href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>            </li>            <li class="mm-divider">الاكتتابات</li>            <li>              <a href="/countries/sa/ipos">قائمة الإكتتابات</a>            </li>            <li>              <a href="/ipo/list">بحث فى الاكتتابات</a>            </li>            <li>              <a href="/ipos/news">أخبار الاكتتابات</a>            </li>            <li>              <a href="/ipo/calendar">مفكرة الاكتتابات</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-4"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">صناديق الاستثمار</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/countries/sa/funds">صناديق الاستثمار</a>            </li>            <li>              <a href="/countries/sa/funds-statistics">إحصائيات الصناديق</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-5"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">أدوات التحليل</a></div><ul class="mm-listview mm-first mm-last">                                        <li>                <a href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>              </li>              <li>                <a href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>              </li>              <li>                <a href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>              </li>              <li>                <a href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>              </li>              <li>                <a href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>              </li>                        <li class="mm-divider">            </li>            <li>              <a href="/analysis-tools/performance-comparison">مقارنة الأداء</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-6"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">السندات</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/fixedincome/bond/search" id="fixedIncomeBondScreener">بحث عن سندات</a>            </li>            <li>              <a href="/fixed-income/news" id="fixedIncomeNews">أخبار السندات وأذون الخزانة</a>            </li>            <li>              <a href="/fixedincome/calendar/searchForEvent" id="fixedIncomeCalendar">قائمة الأحداث</a>            </li>            <li>              <a href="/fixedincome/analytics/drawCurve" id="fixedIncomeAnalytics">تحليلات فنية</a>            </li>            <li>              <a href="/fixedincome/leagueTables/view" id="fixedIncomeLeagueTables">جداول الديون</a>            </li>            <li>              <a href="/fixedincome/research/search" id="fixedIncomeProspectus">تقارير</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-7"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">شخصي</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/my/alerts">التنبيهات</a>            </li>            <li>              <a href="/my/watch-list">أسهمي</a>            </li>            <li>              <a href="/my/newsletters">النشرة البريدية</a>            </li>          </ul></div></nav><div class="js-wrapper mm-page mm-slideout" id="wrapper">  <svg class="hidden" version="1.1" viewBox="0 0 0 0" xmlns="http://www.w3.org/2000/svg">  <defs>    <style>      .logo-white-path {        clip-rule: evenodd;        fill-rule: evenodd;        fill: white;        font-size: 46.6299px;        font-family: \'HelveticaNeue\';      }      .logo-path {        clip-rule: evenodd;        fill-rule: evenodd;        fill: #324651;        text-align: center;        font-size: 46.6299px;        font-family: \'HelveticaNeue\';      }    </style>    <g id="logo-white">      <path class="logo-white-path" d="M209.596 29.677c-6.25 0.016-11.243-4.937-11.261-11.188 c-0.018-6.191 5.027-11.29 11.194-11.29c6.182-0.004 11.3 5.1 11.3 11.226C220.852 24.6 215.8 29.7 209.6 29.7"></path>      <path class="logo-white-path" d="M228.308 37.976c6.231-0.01 11.3 5 11.3 11.2 c0.015 6.189-5.011 11.227-11.233 11.252c-6.213 0.025-11.246-4.99-11.271-11.209C217.063 43 222.1 38 228.3 38"></path>      <path class="logo-white-path" d="M350.278 190.471c-6.27-0.009-11.204-4.942-11.197-11.212 c0.013-6.26 4.968-11.18 11.248-11.176c6.242 0 11.3 5 11.2 11.224C361.555 185.5 356.5 190.5 350.3 190.5"></path>      <path class="logo-white-path" d="M186.161 37.976c6.26 0 11.2 5 11.2 11.2 c-0.01 6.241-4.993 11.239-11.209 11.226c-6.257-0.017-11.212-4.99-11.212-11.228C174.949 42.9 179.9 38 186.2 38"></path>      <path class="logo-white-path" d="M455.92 80.125c-21.212 0-38.405 17.191-38.405 38.4 c0 4.3 0.7 8.4 2 12.316l-48.126 0.003l13.9-27.74h-3.242c0 0-2.13 0.019-2.822 0.1 c-2.13 0.126-3.67 0.098-7.926 1.351c-3.949 1.159-7.026 2.719-9.881 4.503c-2.381 1.493-5.863 4.278-8.803 7.7 c-2.912 3.325-5.713 7.695-5.713 7.695l-3.294 6.464l-41.201 0.003L364.7 0l-76.514 49.172l25.429-0.036L260.64 156.919h193.847 c0 0 0.9 0 1.4 0.01c21.212 0 38.4-17.183 38.4-38.403C494.32 97.3 477.1 80.1 455.9 80.125z M455.92 133.3 c-7.998 0-14.48-6.479-14.48-14.47c0-7.998 6.482-14.476 14.48-14.476c7.996 0 14.5 6.5 14.5 14.5 C470.393 126.8 463.9 133.3 455.9 133.327z"></path>      <path class="logo-white-path" d="M269.61 81.427c0 0-1.617 0.013-2.842 0.09c-2.001 0.132-3.655 0.07-7.903 1.3 c-3.946 1.162-7.021 2.722-9.876 4.507c-2.378 1.488-5.868 4.279-8.813 7.662c-2.904 3.327-5.282 8.108-5.282 8.108l-14.116 27.7 h-16.391l19.092-39.485h-3.237c0 0-1.617 0.015-2.835 0.095c-2.012 0.13-3.665 0.068-7.905 1.3 c-3.957 1.161-7.034 2.717-9.892 4.502c-2.373 1.493-5.857 4.28-8.808 7.668c-2.899 3.321-5.282 8.104-5.282 8.104l-8.901 17.8 h-16.959l13.92-27.753h-3.245c0 0-2.141 0.019-2.822 0.057c-2.133 0.126-3.663 0.098-7.926 1.4 c-3.944 1.159-7.026 2.719-9.884 4.503c-2.378 1.493-5.857 4.28-8.808 7.669c-2.904 3.329-5.708 7.695-5.708 7.695l-3.291 6.5 l-52.558-0.005l14.007-27.748h-3.242c0 0-2.131 0.019-2.815 0.057c-2.136 0.126-3.678 0.098-7.934 1.4 c-3.944 1.159-7.021 2.719-9.877 4.503c-2.383 1.493-5.858 4.28-8.813 7.669c-2.906 3.329-5.114 7.843-5.114 7.843l-16.204 31.1 l0 0c0 0-3.136 6.731-7.038 11.469c-3.094 3.766-7.43 6.804-9.757 8.194c-2.313 1.384-7.141 3.645-11.872 4.5 C5.251 180.9 0 180.5 0 180.502s2.33 2.1 5 3.806c2.034 1.4 4.3 2.4 5.5 3 c2.481 1.1 4.3 1.7 6.9 2.253c2.531 0.6 4.8 0.8 4.8 0.763s1.621 0.2 3.2 0.169c0.707 0 1.62-0.024 2.848-0.09 c2.001-0.134 3.5 0 7.904-1.323c4.033-1.188 7.072-2.582 9.92-4.368c2.383-1.478 5.952-4.249 8.904-7.627 c2.907-3.337 5.296-8.019 5.296-8.019l6.043-12.125l169.4 0.009l12.816-26.07l24.302-49.431H269.61z"></path>      <path class="logo-white-path" d="M30.239 76.472V55.626H22.45v-2.789h18.735v2.789h-7.819v20.846H30.239z"></path>      <path class="logo-white-path" d="M44.296 76.472V52.836h4.71l5.592 16.735c0.518 1.6 0.9 2.7 1.1 3.499c0.269-0.861 0.687-2.123 1.258-3.789 l5.658-16.446h4.209v23.636h-3.015V56.689l-6.869 19.783h-2.822l-6.835-20.121v20.121H44.296z"></path>    </g>    <g id="logo">      <path class="logo-path" d="M209.596 29.677c-6.25 0.016-11.243-4.937-11.261-11.188 c-0.018-6.191 5.027-11.29 11.194-11.29c6.182-0.004 11.3 5.1 11.3 11.226C220.852 24.6 215.8 29.7 209.6 29.7"></path>      <path class="logo-path" d="M228.308 37.976c6.231-0.01 11.3 5 11.3 11.2 c0.015 6.189-5.011 11.227-11.233 11.252c-6.213 0.025-11.246-4.99-11.271-11.209C217.063 43 222.1 38 228.3 38"></path>      <path class="logo-path" d="M350.278 190.471c-6.27-0.009-11.204-4.942-11.197-11.212 c0.013-6.26 4.968-11.18 11.248-11.176c6.242 0 11.3 5 11.2 11.224C361.555 185.5 356.5 190.5 350.3 190.5"></path>      <path class="logo-path" d="M186.161 37.976c6.26 0 11.2 5 11.2 11.2 c-0.01 6.241-4.993 11.239-11.209 11.226c-6.257-0.017-11.212-4.99-11.212-11.228C174.949 42.9 179.9 38 186.2 38"></path>      <path class="logo-path" d="M455.92 80.125c-21.212 0-38.405 17.191-38.405 38.4 c0 4.3 0.7 8.4 2 12.316l-48.126 0.003l13.9-27.74h-3.242c0 0-2.13 0.019-2.822 0.1 c-2.13 0.126-3.67 0.098-7.926 1.351c-3.949 1.159-7.026 2.719-9.881 4.503c-2.381 1.493-5.863 4.278-8.803 7.7 c-2.912 3.325-5.713 7.695-5.713 7.695l-3.294 6.464l-41.201 0.003L364.7 0l-76.514 49.172l25.429-0.036L260.64 156.919h193.847 c0 0 0.9 0 1.4 0.01c21.212 0 38.4-17.183 38.4-38.403C494.32 97.3 477.1 80.1 455.9 80.125z M455.92 133.3 c-7.998 0-14.48-6.479-14.48-14.47c0-7.998 6.482-14.476 14.48-14.476c7.996 0 14.5 6.5 14.5 14.5 C470.393 126.8 463.9 133.3 455.9 133.327z"></path>      <path class="logo-path" d="M269.61 81.427c0 0-1.617 0.013-2.842 0.09c-2.001 0.132-3.655 0.07-7.903 1.3 c-3.946 1.162-7.021 2.722-9.876 4.507c-2.378 1.488-5.868 4.279-8.813 7.662c-2.904 3.327-5.282 8.108-5.282 8.108l-14.116 27.7 h-16.391l19.092-39.485h-3.237c0 0-1.617 0.015-2.835 0.095c-2.012 0.13-3.665 0.068-7.905 1.3 c-3.957 1.161-7.034 2.717-9.892 4.502c-2.373 1.493-5.857 4.28-8.808 7.668c-2.899 3.321-5.282 8.104-5.282 8.104l-8.901 17.8 h-16.959l13.92-27.753h-3.245c0 0-2.141 0.019-2.822 0.057c-2.133 0.126-3.663 0.098-7.926 1.4 c-3.944 1.159-7.026 2.719-9.884 4.503c-2.378 1.493-5.857 4.28-8.808 7.669c-2.904 3.329-5.708 7.695-5.708 7.695l-3.291 6.5 l-52.558-0.005l14.007-27.748h-3.242c0 0-2.131 0.019-2.815 0.057c-2.136 0.126-3.678 0.098-7.934 1.4 c-3.944 1.159-7.021 2.719-9.877 4.503c-2.383 1.493-5.858 4.28-8.813 7.669c-2.906 3.329-5.114 7.843-5.114 7.843l-16.204 31.1 l0 0c0 0-3.136 6.731-7.038 11.469c-3.094 3.766-7.43 6.804-9.757 8.194c-2.313 1.384-7.141 3.645-11.872 4.5 C5.251 180.9 0 180.5 0 180.502s2.33 2.1 5 3.806c2.034 1.4 4.3 2.4 5.5 3 c2.481 1.1 4.3 1.7 6.9 2.253c2.531 0.6 4.8 0.8 4.8 0.763s1.621 0.2 3.2 0.169c0.707 0 1.62-0.024 2.848-0.09 c2.001-0.134 3.5 0 7.904-1.323c4.033-1.188 7.072-2.582 9.92-4.368c2.383-1.478 5.952-4.249 8.904-7.627 c2.907-3.337 5.296-8.019 5.296-8.019l6.043-12.125l169.4 0.009l12.816-26.07l24.302-49.431H269.61z"></path>      <path class="logo-path" d="M30.239 76.472V55.626H22.45v-2.789h18.735v2.789h-7.819v20.846H30.239z"></path>      <path class="logo-path" d="M44.296 76.472V52.836h4.71l5.592 16.735c0.518 1.6 0.9 2.7 1.1 3.499c0.269-0.861 0.687-2.123 1.258-3.789 l5.658-16.446h4.209v23.636h-3.015V56.689l-6.869 19.783h-2.822l-6.835-20.121v20.121H44.296z"></path>    </g>    <g id="logo-white-en">      <defs>        <rect height="65.7" width="326.9" x="-55"></rect>      </defs>      <clipPath>        <use overflow="visible" xlink:href="#SVGID_1_"></use>      </clipPath>      <path class="logo-white-path" d="M41.694 20.162c-1.315 0-1.315 0.987-1.315 0.987l0.094 13.8 c0 0 0.6 8.648-8.178 8.648c0 0-8.364 0.093-8.364-8.082V21.29c0 0 0.234-1.174-1.27-1.174c-1.362 0-1.221 1.174-1.221 1.174V36 c0 0 0.2 10.1 10.9 10.104c10.386 0 10.669-9.675 10.669-10.433V21.243C42.964 21.2 43 20.2 41.7 20.2"></path>      <path class="logo-white-path" d="M20.915 21.431c0 0 0-0.799-0.799-1.127c-0.777-0.321-1.27 0.422-1.457 0.6 l-7.425 10.293c0 0-0.469 0.61-1.034-0.282l-8.13-10.292c0 0-0.517-0.611-1.128-0.423c-0.611 0.189-0.894 0.704-0.846 1.6 L0 44.74c0 0-0.046 1.4 1.3 1.363s1.316-1.222 1.316-1.222V25.144l7.002 9.023c0 0 1.1 1.5 2.209-0.188 c1.081-1.646 6.626-8.882 6.626-8.882v19.736c0 0-0.088 1.3 1.5 1.175c1.175-0.094 0.988-1.22 0.988-1.22V21.431z"></path>      <path class="logo-white-path" d="M168.546 43.734l-10.309-6.813c0 0 8.648-0.179 8.648-8.471 c0-8.294-8.531-8.118-8.531-8.118h-8.412c-2.107 0-1.953 1.6-1.953 1.6v22.69c0 0-0.038 1.5 1.1 1.5 c1.265 0 1.222-1.436 1.222-1.436V22.702h6.516c0.474 0 3.1 0 5.3 1.304c2.192 1.3 3.7 7.198-0.177 9.6 c-2.785 1.717-6.459 1.008-7.642 0.889c-1.185-0.12-1.306 0.414-1.483 1.186c-0.177 0.8 0.9 1.4 0.9 1.362l13.21 8.5 c0 0 1.4 1.2 2.1 0.18C169.967 44.4 168.5 43.7 168.5 43.7"></path>      <path class="logo-white-path" d="M95.522 19.596c-6.516-0.711-11.492 3.376-11.373 7.8 c0.117 4.4 3 5.7 8.1 6.634c5.096 0.9 7 1.7 7 1.658c2.665 1 2.5 4.3 1 5.9 c-1.423 1.601-4.148 2.558-5.766 2.616c-3.879 0.146-6.052-2.374-6.052-2.374c-0.492-0.407-0.683-1.486-1.69-1.25 c-1.347 0.316-0.296 1.836-0.296 1.836c2.311 3.2 7.2 3.6 7.2 3.554c5.45 0.7 8.648-3.139 8.648-3.139 c2.963-3.852 0.987-8.363-1.976-9.429c-3.17-1.142-6.139-1.234-10.05-2.065c-3.909-0.828-3.495-4.087-3.495-4.087 c0.059-2.37 2.252-5.271 7.643-5.332c5.392-0.059 8.5 3.4 8.5 3.436c1.304 1.4 2.1 0.5 2.133-0.12 c0.06-0.591-0.058-1.183-0.531-1.776C104.121 23.1 102 20.3 95.5 19.6"></path>      <path class="logo-white-path" d="M124.084 20.618c-1.126 0-1.185 1.067-1.185 1.067v15.166h-14.336V21.862 c0 0 0.296-1.42-1.305-1.362c-1.304 0.047-1.067 1.42-1.067 1.42v14.575h-0.889c0 0-1.303-0.06-1.303 1.2 c0 1.3 1.2 1.3 1.2 1.305h1.007v5.746c0 0 0 1.2 1.2 1.243c1.246 0 1.187-1.184 1.187-1.184v-5.984h14.1v6.103 c0 0-0.008 1.1 1.2 1.137c1.226 0 1.269-1.195 1.269-1.195V21.743C125.209 21.7 125.2 20.6 124.1 20.6"></path>      <path class="logo-white-path" d="M86.101 44.016c0 0-10.841-21.504-11.849-23.163c-1.007-1.66-2.072 0-2.072 0 l-8.047 15.604l-2.395 0.015c-0.888 0-0.982 0.633-0.982 1.284c0 1.1 1.1 0.9 1.1 0.929h1.067c0 0-2.447 4.637-2.726 5.3 c-0.355 0.889-0.416 1.5 0.5 1.955c1.008 0.5 1.659-0.77 1.659-0.77l3.436-6.399H80.71l2.903 5.9 c0 0 1 2 2.1 1.305C86.87 45.3 86.1 44 86.1 44 M66.965 36.374l5.984-12.026c0 0 0.296-0.475 0.6 0.1 c0.296 0.5 6 12 6 11.967H66.965z"></path>      <path class="logo-white-path" d="M58.314 34.283c0 0 3.87-1.954 3.87-6.575c0-4.622-4.563-7.199-8.294-7.199 h-6.517c0 0-1.512 0.2-1.512 1.744v10.479h-1.833c0 0-0.799-0.094-0.799 1.271c0 1.1 0.6 1.2 0.6 1.173h2.066v9.447 c0 0-0.046 1.5 1.5 1.48h7.213c0 0 6.016-0.165 6.016-6.837C60.57 35.9 58.3 34.3 58.3 34.3 M48.203 22.7 l6.338-0.005c1.718 0 5.1 1.7 5.1 5.451c0 4.443-5.095 4.501-5.095 4.501h-6.338V22.736z M53.557 43.831h-5.351v-8.748 l6.435-0.008c0.858 0 3.5 0.9 3.5 4.031C58.143 43.7 53.6 43.8 53.6 43.8"></path>      <path class="logo-white-path" d="M146.17 23.033c0 0 1.3 0.1 1.305-1.304c0-1.244-1.305-1.125-1.305-1.125 h-15.818c-2.251 0-2.012 1.717-2.012 1.717V36.54l-1.653 0.009c0 0-1.132 0.229-1.132 1.177c0 1.2 1.1 1.4 1.1 1.361h1.669 v4.917c0 2.5 1.7 2.1 1.7 2.073h15.818c0 0 0.9 0 0.889-1.185s-0.95-1.007-0.95-1.007h-14.798v-4.799h15.284 c0 0 0.937-0.177 0.937-1.361c0-1.186-1.125-1.246-1.125-1.246h-15.228V23.033H146.17z"></path>    </g>    <g id="logo-en">      <defs>        <rect height="65.7" width="326.9" x="-55"></rect>      </defs>      <clipPath>        <use overflow="visible" xlink:href="#SVGID_1_"></use>      </clipPath>      <path class="logo-path" d="M41.694 20.162c-1.315 0-1.315 0.987-1.315 0.987l0.094 13.8 c0 0 0.6 8.648-8.178 8.648c0 0-8.364 0.093-8.364-8.082V21.29c0 0 0.234-1.174-1.27-1.174c-1.362 0-1.221 1.174-1.221 1.174V36 c0 0 0.2 10.1 10.9 10.104c10.386 0 10.669-9.675 10.669-10.433V21.243C42.964 21.2 43 20.2 41.7 20.2"></path>      <path class="logo-path" d="M20.915 21.431c0 0 0-0.799-0.799-1.127c-0.777-0.321-1.27 0.422-1.457 0.6 l-7.425 10.293c0 0-0.469 0.61-1.034-0.282l-8.13-10.292c0 0-0.517-0.611-1.128-0.423c-0.611 0.189-0.894 0.704-0.846 1.6 L0 44.74c0 0-0.046 1.4 1.3 1.363s1.316-1.222 1.316-1.222V25.144l7.002 9.023c0 0 1.1 1.5 2.209-0.188 c1.081-1.646 6.626-8.882 6.626-8.882v19.736c0 0-0.088 1.3 1.5 1.175c1.175-0.094 0.988-1.22 0.988-1.22V21.431z"></path>      <path class="logo-path" d="M168.546 43.734l-10.309-6.813c0 0 8.648-0.179 8.648-8.471 c0-8.294-8.531-8.118-8.531-8.118h-8.412c-2.107 0-1.953 1.6-1.953 1.6v22.69c0 0-0.038 1.5 1.1 1.5 c1.265 0 1.222-1.436 1.222-1.436V22.702h6.516c0.474 0 3.1 0 5.3 1.304c2.192 1.3 3.7 7.198-0.177 9.6 c-2.785 1.717-6.459 1.008-7.642 0.889c-1.185-0.12-1.306 0.414-1.483 1.186c-0.177 0.8 0.9 1.4 0.9 1.362l13.21 8.5 c0 0 1.4 1.2 2.1 0.18C169.967 44.4 168.5 43.7 168.5 43.7"></path>      <path class="logo-path" d="M95.522 19.596c-6.516-0.711-11.492 3.376-11.373 7.8 c0.117 4.4 3 5.7 8.1 6.634c5.096 0.9 7 1.7 7 1.658c2.665 1 2.5 4.3 1 5.9 c-1.423 1.601-4.148 2.558-5.766 2.616c-3.879 0.146-6.052-2.374-6.052-2.374c-0.492-0.407-0.683-1.486-1.69-1.25 c-1.347 0.316-0.296 1.836-0.296 1.836c2.311 3.2 7.2 3.6 7.2 3.554c5.45 0.7 8.648-3.139 8.648-3.139 c2.963-3.852 0.987-8.363-1.976-9.429c-3.17-1.142-6.139-1.234-10.05-2.065c-3.909-0.828-3.495-4.087-3.495-4.087 c0.059-2.37 2.252-5.271 7.643-5.332c5.392-0.059 8.5 3.4 8.5 3.436c1.304 1.4 2.1 0.5 2.133-0.12 c0.06-0.591-0.058-1.183-0.531-1.776C104.121 23.1 102 20.3 95.5 19.6"></path>      <path class="logo-path" d="M124.084 20.618c-1.126 0-1.185 1.067-1.185 1.067v15.166h-14.336V21.862 c0 0 0.296-1.42-1.305-1.362c-1.304 0.047-1.067 1.42-1.067 1.42v14.575h-0.889c0 0-1.303-0.06-1.303 1.2 c0 1.3 1.2 1.3 1.2 1.305h1.007v5.746c0 0 0 1.2 1.2 1.243c1.246 0 1.187-1.184 1.187-1.184v-5.984h14.1v6.103 c0 0-0.008 1.1 1.2 1.137c1.226 0 1.269-1.195 1.269-1.195V21.743C125.209 21.7 125.2 20.6 124.1 20.6"></path>      <path class="logo-path" d="M86.101 44.016c0 0-10.841-21.504-11.849-23.163c-1.007-1.66-2.072 0-2.072 0 l-8.047 15.604l-2.395 0.015c-0.888 0-0.982 0.633-0.982 1.284c0 1.1 1.1 0.9 1.1 0.929h1.067c0 0-2.447 4.637-2.726 5.3 c-0.355 0.889-0.416 1.5 0.5 1.955c1.008 0.5 1.659-0.77 1.659-0.77l3.436-6.399H80.71l2.903 5.9 c0 0 1 2 2.1 1.305C86.87 45.3 86.1 44 86.1 44 M66.965 36.374l5.984-12.026c0 0 0.296-0.475 0.6 0.1 c0.296 0.5 6 12 6 11.967H66.965z"></path>      <path class="logo-path" d="M58.314 34.283c0 0 3.87-1.954 3.87-6.575c0-4.622-4.563-7.199-8.294-7.199 h-6.517c0 0-1.512 0.2-1.512 1.744v10.479h-1.833c0 0-0.799-0.094-0.799 1.271c0 1.1 0.6 1.2 0.6 1.173h2.066v9.447 c0 0-0.046 1.5 1.5 1.48h7.213c0 0 6.016-0.165 6.016-6.837C60.57 35.9 58.3 34.3 58.3 34.3 M48.203 22.7 l6.338-0.005c1.718 0 5.1 1.7 5.1 5.451c0 4.443-5.095 4.501-5.095 4.501h-6.338V22.736z M53.557 43.831h-5.351v-8.748 l6.435-0.008c0.858 0 3.5 0.9 3.5 4.031C58.143 43.7 53.6 43.8 53.6 43.8"></path>      <path class="logo-path" d="M146.17 23.033c0 0 1.3 0.1 1.305-1.304c0-1.244-1.305-1.125-1.305-1.125 h-15.818c-2.251 0-2.012 1.717-2.012 1.717V36.54l-1.653 0.009c0 0-1.132 0.229-1.132 1.177c0 1.2 1.1 1.4 1.1 1.361h1.669 v4.917c0 2.5 1.7 2.1 1.7 2.073h15.818c0 0 0.9 0 0.889-1.185s-0.95-1.007-0.95-1.007h-14.798v-4.799h15.284 c0 0 0.937-0.177 0.937-1.361c0-1.186-1.125-1.246-1.125-1.246h-15.228V23.033H146.17z"></path>    </g>  </defs></svg>  <!--<script type="text/javascript" xmlns:th="http://www.thymeleaf.org" th:fragment="body">-->  <!--(function () {-->    <!--var em = document.createElement(\'script\');-->    <!--em.type = \'text/javascript\';-->    <!--em.async = true;-->    <!--em.src =-->      <!--(\'https:\' == document.location.protocol ? \'https://me-ssl\' : \'http://me-cdn\') + \'.effectivemeasure.net/em.js\';-->    <!--var s = document.getElementsByTagName(\'script\')[0];-->    <!--s.parentNode.insertBefore(em, s);-->  <!--}());--><!--</script>-->  <div class="">    <header class="header">      <!-- DESKTOP ADS BLOCK -->      <!-- DESKTOP ADS BLOCK -->      <!-- MOBILE ADS BLOCK -->                  <!-- MOBILE ADS BLOCK -->      <div class="header__top-for-mobile">        <div class="top-bar__triggers">          <a class="main-menu-trigger fa fa-bars fa-2x" href="#main-menu" style="float: right;"></a>          <!-- Logo -->          <div class="header__logo header-logo-margins" onclick="window.location.href=\'/countries/sa\'">              <svg viewBox="0 0 494.387 190.555">    <use xlink:href="#logo-white"></use>  </svg>            </div>          <a class="countries-menu-trigger header-country-margins" href="#countries-menu">            <span>السعودية</span>            <span class="fa fa-caret-down fa-4x"></span>          </a>          <!-- ngRepeat: image in images --><img ng-repeat="image in images" src="/assets/ui/images/mobile-logo-G20.png" class="ng-scope"><!-- end ngRepeat: image in images --><img ng-repeat="image in images" src="/assets/ui/images/mobile-logo-vision.png" class="ng-scope"><!-- end ngRepeat: image in images -->          <div class="header__left-side left-search-icon">            <a class="search-trigger js-search-trigger fa fa-search fa-2x" href="javascript:;" style="float: left;">            </a>          </div>        </div>        <!-- Search -->        <div class="search js-search" id="search">          <i class="fa fa-search fa-2x search__icon"></i>          <angucomplete-alt id="autocomplete__companies" input-class="search__input" minlength="1" ng-controller="AutocompleteController" pause="400" placeholder="اكتب كلمة البحث أو رمز الشركة" selected-object="selectItem" text-no-results="عفواً, لم يتم العثور على أي نتائج" text-searching="جارٍ البحث..." title-field="label" remote-url="/api/1/companySearch?query=" class="ng-scope ng-isolate-scope"><div class="angucomplete-holder" ng-class="{\'angucomplete-dropdown-visible\': showDropdown}">  <input id="autocomplete__companies_value" ng-model="searchStr" ng-disabled="disableInput" type="" placeholder="اكتب كلمة البحث أو رمز الشركة" maxlength="524288" ng-focus="onFocusHandler()" class="search__input ng-valid-maxlength" ng-blur="hideResults($event)" autocapitalize="off" autocorrect="off" autocomplete="off" ng-change="inputChangeHandler(searchStr)">  <div id="autocomplete__companies_dropdown" class="angucomplete-dropdown ng-hide" ng-show="showDropdown"><div class="angucomplete-searching ng-hide" ng-show="searching"><div class="spinner"><div class="dot1"></div><div class="dot2"></div></div></div>    <div class="angucomplete-searching ng-binding" ng-show="!searching &amp;&amp; (!results || results.length == 0)" ng-bind="textNoResults">عفواً, لم يتم العثور على أي نتائج</div>    <!-- ngRepeat: result in results -->  </div></div></angucomplete-alt>        </div>      </div>      <div class="header-desktop mi-show-for-large-up">        <div class="header__top-for-desktop">          <div class="header__top-for-desktop-row">            <a class="header__other-site" href="http://tawasul.mubasher.info/" target="_blank">              <i class="fa fa-caret-right fa-2x"></i>              تواصل            </a>            <a class="header__other-site" href="http://magazine.mubasher.info/" target="_blank">              <i class="fa fa-caret-right fa-2x"></i>              مجلة مباشر            </a>            <a class="header__other-site" href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">              <i class="fa fa-play-circle"></i>              <div style="direction: ltr; display: inline-block;">TV مباشر</div>            </a>                        <a class="header__other-site" href="/contact">              <i class="fa fa-envelope"></i>              اتصل بنا            </a>            <a class="header__other-site" href="/advertise">              <i class="fa fa-envelope"></i>              اعلن معنا            </a>            <!-- <a th:if="${#locale.getLanguage() == \'ar\'}" class="header__login-button" style="background: #458D37 !important;" th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank"                th:text="#{components.header.decypha}">ديسيفا</a>            <a th:if="${#locale.getLanguage() == \'en\'}" class="header__login-button" style="background: #458D37 !important; font-family: Roboto,sans-serif !important;" th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank"                th:text="#{components.header.decypha}">ديسيفا</a> -->            <!-- Page Content Buttons -->            <a class="header__login-button" ng-click="decypha(\'decypha\')" style="background: #458D37 !important; font-family: Roboto,sans-serif !important;">ديسيفا</a>            <!-- Page Content Button -->            <!--Add according to MFP-187-->            <a class="header__login-button" style="background: #00c2d6 !important;" target="_blank" href="https://contest.mubasher.info/#/home">المستثمر اﻷول</a>                        <style>              /*.pulse-logo{*/              /*display: inline-block;*/              /*width: 252px;*/              /*height: 100%;*/              /*background: #212121 url(../images/pulse-logo.png) no-repeat center 2px;*/              /*padding: 10px 50px 29px;*/              /*text-align: center;*/              /*color: black;*/              /*text-decoration: none;*/              /*margin-top: -6px;*/              /*}*/              .pulse-logo2{                padding: 5px 5px 4px;                min-width: 82px;                min-height: 21px;                max-width: 27%;              }            </style>            <a target="_blank" href="https://pulse.mubasher.info">              <img class="pulse-logo2" src="../../../images/pulse-logo.png">            </a>            <span class="header__spacer">              &nbsp;            </span>            <a class="header__social-link" target="_blank" href="https://twitter.com/mubasher"><i class="fa fa-twitter fa-lg"></i></a>            <a class="header__social-link" href="https://www.facebook.com/Mubasher.Info"><i class="fa fa-facebook fa-lg"></i></a>            <a class="header__social-link" href="https://www.youtube.com/channel/UC7hnxb7gD4nKZdZk3ZlZCYg">              <i class="fa fa-youtube fa-lg"></i>            </a>            <a class="header__social-link" href="https://www.linkedin.com/company/1477149">              <i class="fa fa-linkedin fa-lg"></i>            </a>            <a class="header__social-link" href="/news/rss"><i class="fa fa-rss fa-lg"></i></a>            <a class="header__social-link" href="https://play.google.com/store/apps/details?id=net.mis.mubasherinfo">              <i class="fa fa-android fa-lg"></i>            </a>            <a class="header__social-link" href="https://itunes.apple.com/app/imubasher/id494539772?mt=8">              <i class="fa fa-apple fa-lg"></i>            </a>            <a class="header__login-button" href="/account/login">              دخول              <i class="fa fa-user fa-lg"></i>            </a>                                    <a class="header__language" href="https://english.mubasher.info">              <span>ENGLISH</span>            </a>          </div>        </div>        <div class="header__columns">          <div class="header__column1">            <!-- Logo -->            <div class="header__logo-wrapper">              <div class="header__logo" onclick="window.location.href=\'/countries/sa\'">                  <svg viewBox="0 0 494.387 190.555">    <use xlink:href="#logo"></use>  </svg>                </div>              <div class="countries-menu-trigger">                <a href="javascript:;" id="mi-js-countries-menu-trigger">                  <span>السعودية</span>                  <span class="fa fa-caret-down"></span>                </a>                <nav class="header__countries-menu--desktop mi-js-countries-menu-desktop" style="">                  <ul>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=ae&amp;url=/countries/sa/companies">الإمارات</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=bh&amp;url=/countries/sa/companies">البحرين</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=om&amp;url=/countries/sa/companies">عُمان</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=qa&amp;url=/countries/sa/companies">قطر</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=kw&amp;url=/countries/sa/companies">الكويت</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=eg&amp;url=/countries/sa/companies">مصر</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=jo&amp;url=/countries/sa/companies">الأردن</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=tn&amp;url=/countries/sa/companies">تونس</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=ma&amp;url=/countries/sa/companies">المغرب</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=ps&amp;url=/countries/sa/companies">فلسطين</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=iq&amp;url=/countries/sa/companies">العراق</a>                    </li>                  </ul>                </nav>              </div>            </div>            <!--Market Status -->            <div class="header__market-status">              <div class="header__market-status-column">                <div class="header__market-status-row">                  <a class="header__market-name" href="/markets/TDWL">TDWL</a>                  <span class="header__market-status--close">مغلق</span>                </div>                              </div>              <span class="header__market-time">12 أغسطس 04:49 م</span>            </div>          </div>          <div class="header__column1 banner-logo-desktop" ng-class="{\'banner-desktop-en\':(getLanguage == \'en\')}">            <!-- Logo -->            <div class="header__logo-wrapper">              <!-- ngRepeat: image in images --><div class="header__logo ng-scope" ng-repeat="image in images">                  <div class="tooltip tooltipstered"><img src="/assets/ui/images/logo-G20.png">                    <span class="tooltiptext ng-binding" ng-class="{\'tooltip-desktop-en\':(getLanguage == \'en\')}" style="left: 95%">مجموعة العشرين 2020</span>                  </div>              </div><!-- end ngRepeat: image in images --><div class="header__logo ng-scope" ng-repeat="image in images">                  <div class="tooltip tooltipstered"><img src="/assets/ui/images/logo-vision.png">                    <span class="tooltiptext ng-binding" ng-class="{\'tooltip-desktop-en\':(getLanguage == \'en\')}" style="left: 95%">رؤية المملكة العربية السعودية 2030</span>                  </div>              </div><!-- end ngRepeat: image in images -->            </div>          </div><!--          <div class="header__column2">             &lt;!&ndash;<div th:replace="components/ads/news/dfp/desktop/LB2"/>&ndash;&gt;            &lt;!&ndash;=====to display default leaderboard ad-slot [728,90] ======&ndash;&gt;            <div th:if="${isHomePage}">              <div th:replace="components/ads/home/leaderboard"/>            </div>            <div th:unless="${isHomePage}">              <div>                <iframe id="leaderboard-ros-001" style="width: 736px; height: 108px;" class="ad-iframe" src="/ads/LB2"></iframe>              </div>            </div>            </div>-->           <!--======= billboard 790x250 ============ -->        </div>        <nav class="header__navigation mi-js-desktop-menu-container">          <ul class="dl-menu mi-show-for-large-up mi-js-desktop-menu">            <li class="dl-menu__menu-item dl-menu__menu-item--iconic-item">              <a href="/countries/sa">                <i class="fa fa-home fa-2x"></i>              </a>            </li>            <li class="dl-menu__menu-item" id="markets">              <a href="javascript:;">الأسواق</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/markets/TDWL">سوق الأسهم السعودي</a>                    </li>                    <li>                      <a href="/markets/EGX">البورصة المصرية</a>                    </li>                    <li>                      <a href="/markets/DFM">سوق دبي المالي</a>                    </li>                    <li>                      <a href="/markets/ADX">سوق أبوظبي</a>                    </li>                    <li>                      <a href="/markets/BB">بورصة البحرين</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/markets/QE">بورصة قطر</a>                    </li>                    <li>                      <a href="/markets/MSM">سوق مسقط</a>                    </li>                    <li>                      <a href="/markets/BK">سوق الكويت</a>                    </li>                    <li>                      <a href="/markets/ASE">بورصة عمان</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/markets/CSE">سوق الدار البيضاء</a>                    </li>                    <li>                      <a href="/markets/BDT">بورصة تونس</a>                    </li>                    <li>                      <a href="/markets/PEX">سوق فلسطين</a>                    </li>                    <li>                      <a href="/markets/ISX">سوق العراق</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/international-indices">مؤشرات الأسواق العالمية</a>                    </li>                    <li>                      <a href="/markets/commodities-prices">أسعار المعادن والطاقة</a>                    </li>                    <li>                      <a href="/countries/sa/currencies">أسعار العملات</a>                    </li>                    <!--<li>                      <a th:href="${@url.to(\'RMPC#regionalMap\')}"                         th:text="#{navigation.markets.regional-map}"/>                    </li>-->                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item" id="news">              <a href="javascript:;">الأخبار</a>              <div class="mi-js-submenu">                <ul class="dl-submenu">                  <li>                    <a href="javascript:;">يحدث الآن</a>                    <div class="nav-column">                      <h3>يحدث الآن</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/sa/now/top">أهم الأخبار</a>                        </li>                        <li>                          <a href="/news/sa/now/exclusive">حصرياً مباشر</a>                        </li>                        <li>                          <a href="/news/sa/now/latest">آخر الأخبار</a>                        </li>                                                  <li>                            <a href="/news/sa/now/announcements">إعلانات السوق</a>                          </li>                                                                          <li class="global__hide-for-ltr">                          <a href="/news/sa/now/popular">منتشر الآن</a>                        </li>                        <li>                          <a href="/news/sa/now/trending/">الأكثر مشاركة</a>                        </li>                        <li>                          <a href="/news/now/news-releases">بيانات صحفية</a>                        </li>                        <li>                          <a href="/news/international/misc">أخبار منوعة</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">نبض السوق</a>                    <div class="nav-column">                      <h3>نبض السوق</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/sa/pulse/stocks">أخبار الأسهم</a>                        </li>                        <li>                          <a href="/news/sa/pulse/analysis">تحليلات إخبارية</a>                        </li>                        <li>                          <a href="/news/sa/pulse/local">اقتصاد محلي</a>                        </li>                        <li>                          <a href="/news/sa/pulse/recommendations">توصيات</a>                        </li>                      </ul>                      <h3>أخبار القطاعات</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/sa/category/banking">بنوك</a>                        </li><li>                          <a href="/news/sa/category/realEstate">عقارات</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">أخبار الدول</a>                    <div class="nav-column">                      <h3>أخبار الدول</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/eg/now/latest">مصر</a>                        </li>                        <li>                          <a href="/news/sa/now/latest">السعودية</a>                        </li>                        <li>                          <a href="/news/ae/now/latest">الإمارات</a>                        </li>                        <li>                          <a href="/news/bh/now/latest">البحرين</a>                        </li>                        <li>                          <a href="/news/qa/now/latest">قطر</a>                        </li>                        <li>                          <a href="/news/om/now/latest">عمان</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">أخبار الدول</a>                    <div class="nav-column">                      <h3 class="invisible">أخبار الدول</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/kw/now/latest">الكويت</a>                        </li>                        <li>                          <a href="/news/jo/now/latest">الأردن</a>                        </li>                        <li>                          <a href="/news/ma/now/latest">المغرب</a>                        </li>                        <li>                          <a href="/news/tn/now/latest">تونس</a>                        </li>                        <li>                          <a href="/news/ps/now/latest">فلسطين</a>                        </li>                        <li>                          <a href="/news/iq/now/latest">العراق</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">أخبار إقليمية</a>                    <div class="nav-column">                      <h3>أخبار إقليمية</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/regions/gulf">الخليج</a>                        </li>                        <li>                          <a href="/news/regions/levant">الشام</a>                        </li>                        <li>                          <a href="/news/regions/north-africa">شمال أفريقيا</a>                        </li>                        <li>                          <a href="/news/regions/middle-east">الشرق الأوسط</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">أخبار عالمية</a>                    <div class="nav-column">                      <h3>أخبار عالمية</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/international/global-economy">اقتصاد عالمى</a>                        </li>                        <li>                          <a href="/news/international/goods-and-metals">أحداث عالمية</a>                        </li>                        <li>                          <a href="/news/international/global-indices">مؤشرات عالمية</a>                        </li>                        <li>                          <a href="/news/international/oil-and-energy">نفط ومعادن</a>                        </li>                        <li>                          <a href="/news/international/currencies">عملات</a>                        </li>                        <li>                          <a href="/news/international/global-reports">تقارير عالمية</a>                        </li>                      </ul>                    </div>                  </li>                </ul>              </div>            </li>            <li class="dl-menu__menu-item" id="companies">              <a href="javascript:;">الشركات</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <h3 class="invisible">.</h3>                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/companies">الشركات المدرجة</a>                    </li>                    <li>                      <a href="/countries/sa/events">مفكرة الشركات</a>                    </li>                    <li>                      <a href="/countries/sa/stock-prices">أسعار الأسهم</a>                    </li>                    <li>                      <a href="/countries/sa/fair-values">القيم العادلة</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <h3 class="invisible">.</h3>                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/earnings">إعلانات الأرباح</a>                    </li>                    <li>                      <a href="/countries/sa/corporate-action">الإجراءات</a>                    </li>                                        <li>                      <a href="/countries/sa/major-shareholders">كبار الملاك</a>                    </li>                    <li>                      <a href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <h3>الاكتتابات</h3>                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/ipos">قائمة الإكتتابات</a>                    </li>                    <li>                      <a href="/ipo/list">بحث فى الاكتتابات</a>                    </li>                    <li>                      <a href="/ipos/news">أخبار الاكتتابات</a>                    </li>                    <li>                      <a href="/ipo/calendar">مفكرة الاكتتابات</a>                    </li>                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item" id="funds">              <a href="javascript:;">صناديق الاستثمار</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/funds">صناديق الاستثمار</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/funds-statistics">إحصائيات الصناديق</a>                    </li>                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item" id="analysis-tools">              <a href="javascript:;">أدوات التحليل</a>              <!-- If current country has one market only -->              <div class="mi-js-submenu">                                  <div class="nav-column">                    <ul class="dl-submenu">                      <li>                        <a href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>                      </li>                      <li>                        <a href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>                      </li>                      <li>                        <a href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>                      </li>                    </ul>                  </div>                  <div class="nav-column">                    <ul class="dl-submenu">                      <li>                        <a href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>                      </li>                      <li>                        <a href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>                      </li>                      <li>                        <a href="/analysis-tools/performance-comparison">مقارنة الأداء</a>                      </li>                    </ul>                  </div>                                              </div>            </li>            <li class="dl-menu__menu-item" id="islamic-economy">              <a href="/news/islamic-finance">الاقتصاد الإسلامي</a>            </li>            <!--<li id="radio"                class="dl-menu__menu-item global__hide-for-ltr"                id="radio"                th:if="${#locale.getLanguage() == \'ar\'}">              <a href="javascript:;" th:text="#{navigation.radio}"/>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a th:href="${@url.to(\'RPC#live\')}" th:text="#{navigation.radio.live}"/>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#latestEpisodesPage\', countryCode)}">آخر الحلقات</a>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تقارير-اقتصادية\'}">تقارير                        اقتصادية</a>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تغطية-خاصة\'}">تغطية خاصة</a>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'مقالات\'}">مقالات</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a th:href="${@url.to(\'RPC#programs\')}" th:text="#{navigation.radio.programs}"/>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#videoPrograms\')}" th:text="#{navigation.radio.videoPrograms}"/>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#getExperts\')}">ضيوفنا</a>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#getPresenters\')}">المذيعون</a>                    </li>                  </ul>                </div>              </div>            </li>-->            <li class="dl-menu__menu-item global__hide-for-ltr" id="video">              <a href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">مباشر TV</a>            </li>                        <li class="dl-menu__menu-item" id="fixedincome">              <a href="javascript:;">السندات</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/fixedincome/bond/search" id="fixedIncomeBondScreener">بحث عن سندات</a>                    </li>                    <li>                      <a href="/fixed-income/news" id="fixedIncomeNews">أخبار السندات وأذون الخزانة</a>                    </li>                    <li>                      <a href="/fixedincome/calendar/searchForEvent" id="fixedIncomeCalendar">قائمة الأحداث</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/fixedincome/analytics/drawCurve" id="fixedIncomeAnalytics">تحليلات فنية</a>                    </li>                    <li>                      <a href="/fixedincome/leagueTables/view" id="fixedIncomeLeagueTables">جداول الديون</a>                    </li>                    <li>                      <a href="/fixedincome/research/search" id="fixedIncomeProspectus">تقارير</a>                    </li>                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item" id="personal">              <a href="javascript:;">شخصي</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/my/alerts">التنبيهات</a>                    </li>                    <li>                      <a href="/my/watch-list">أسهمي</a>                    </li>                    <li>                      <a href="/my/newsletters">النشرة البريدية</a>                    </li>                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item dl-menu__menu-item--iconic-item">              <a class="js-search-trigger" href="javascript:;">                <i class="fa fa-search fa-2x"></i>              </a>            </li>          </ul>          <!-- Search -->          <div class="search js-search js-desktop-search" id="search">            <angucomplete-alt id="autocomplete__companies" input-class="search__input" minlength="1" ng-controller="AutocompleteController" pause="400" selected-object="selectItem" text-no-results="عفواً, لم يتم العثور على أي نتائج" text-searching="جارٍ البحث..." title-field="label" remote-url="/api/1/companySearch?query=" placeholder="اكتب كلمة البحث أو رمز الشركة" class="ng-scope ng-isolate-scope"><div class="angucomplete-holder" ng-class="{\'angucomplete-dropdown-visible\': showDropdown}">  <input id="autocomplete__companies_value" ng-model="searchStr" ng-disabled="disableInput" type="" placeholder="اكتب كلمة البحث أو رمز الشركة" maxlength="524288" ng-focus="onFocusHandler()" class="search__input ng-valid-maxlength" ng-blur="hideResults($event)" autocapitalize="off" autocorrect="off" autocomplete="off" ng-change="inputChangeHandler(searchStr)">  <div id="autocomplete__companies_dropdown" class="angucomplete-dropdown ng-hide" ng-show="showDropdown"><div class="angucomplete-searching ng-hide" ng-show="searching"><div class="spinner"><div class="dot1"></div><div class="dot2"></div></div></div>    <div class="angucomplete-searching ng-binding" ng-show="!searching &amp;&amp; (!results || results.length == 0)" ng-bind="textNoResults">عفواً, لم يتم العثور على أي نتائج</div>    <!-- ngRepeat: result in results -->  </div></div></angucomplete-alt>            <i class="fa fa-search fa-2x"></i>          </div>        </nav>      </div>    </header>    <div id="Leaderboard">    </div>    <div></div>    <div class="mi-content">      <div>  <!--<div th:replace="components/ads/internal/mobile-banner" />-->  <main class="mi-main-content">      <h1 class="mi-section__title">الشركات المدرجة</h1>  <div class="mi-table-container ng-scope" ng-controller="PagedTableController as table" country="sa" src="/api/1/listed-companies">    <div class="global__table-container md-whiteframe-z1 ng-isolate-scope" st-init="" st-pipe="fetch" st-table="table.data">      <span class="global__no-results ng-hide" ng-show="table.rows.length == 0 &amp;&amp; table.loaded">عفواّ, لم نعثر على أى نتائج</span>      <table class="mi-table" ng-hide="!table.loaded || table.rows.length == 0" style="">        <thead class="mi-table__thead">          <tr class="mi-table__thead-tr">            <th st-ratio="20" style="width: 20%;">الشركة</th>            <th>السهم</th>            <th class="mi-hide-for-small">القطاع</th>                        <th>آخر سعر</th>            <th>نسبة التغيير</th>            <th class="mi-hide-for-small">آخر تحديث</th>          </tr>        </thead>        <tbody class="mi-table__tbody" ng-hide="table.reloading">          <!-- ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/5110/profile" class="ng-binding" href="/markets/TDWL/stocks/5110/profile">كهرباء السعودية</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/5110" class="ng-binding" href="/markets/TDWL/stocks/5110">5110</a>            </td>            <td class="mi-hide-for-small ng-binding">المرافق العامة</td>                        <td class="number ng-binding">15.48</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.13%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/7010/profile" class="ng-binding" href="/markets/TDWL/stocks/7010/profile">اس تي سي</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/7010" class="ng-binding" href="/markets/TDWL/stocks/7010">7010</a>            </td>            <td class="mi-hide-for-small ng-binding">الإتصالات</td>                        <td class="number ng-binding">96.7</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.21%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/6050/profile" class="ng-binding" href="/markets/TDWL/stocks/6050/profile">الأسماك</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/6050" class="ng-binding" href="/markets/TDWL/stocks/6050">6050</a>            </td>            <td class="mi-hide-for-small ng-binding">إنتاج الأغذية</td>                        <td class="number ng-binding">24.1</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              3.26%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/6060/profile" class="ng-binding" href="/markets/TDWL/stocks/6060/profile">الشرقية للتنمية</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/6060" class="ng-binding" href="/markets/TDWL/stocks/6060">6060</a>            </td>            <td class="mi-hide-for-small ng-binding">إنتاج الأغذية</td>                        <td class="number ng-binding">79.1</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              5.47%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/6070/profile" class="ng-binding" href="/markets/TDWL/stocks/6070/profile">الجوف</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/6070" class="ng-binding" href="/markets/TDWL/stocks/6070">6070</a>            </td>            <td class="mi-hide-for-small ng-binding">إنتاج الأغذية</td>                        <td class="number ng-binding">31.7</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              1.93%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/6090/profile" class="ng-binding" href="/markets/TDWL/stocks/6090/profile">جازادكو</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/6090" class="ng-binding" href="/markets/TDWL/stocks/6090">6090</a>            </td>            <td class="mi-hide-for-small ng-binding">إنتاج الأغذية</td>                        <td class="number ng-binding">13.38</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.15%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/1030/profile" class="ng-binding" href="/markets/TDWL/stocks/1030/profile">الإستثمار</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/1030" class="ng-binding" href="/markets/TDWL/stocks/1030">1030</a>            </td>            <td class="mi-hide-for-small ng-binding">البنوك</td>                        <td class="number ng-binding">14</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              2.49%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/2130/profile" class="ng-binding" href="/markets/TDWL/stocks/2130/profile">صدق</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/2130" class="ng-binding" href="/markets/TDWL/stocks/2130">2130</a>            </td>            <td class="mi-hide-for-small ng-binding">السلع طويلة الاجل</td>                        <td class="number ng-binding">9.76</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -1.21%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/8010/profile" class="ng-binding" href="/markets/TDWL/stocks/8010/profile">التعاونية</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8010" class="ng-binding" href="/markets/TDWL/stocks/8010">8010</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">85</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.58%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/7020/profile" class="ng-binding" href="/markets/TDWL/stocks/7020/profile">إتحاد إتصالات</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/7020" class="ng-binding" href="/markets/TDWL/stocks/7020">7020</a>            </td>            <td class="mi-hide-for-small ng-binding">الإتصالات</td>                        <td class="number ng-binding">27.1</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.55%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/1140/profile" class="ng-binding" href="/markets/TDWL/stocks/1140/profile">البلاد</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/1140" class="ng-binding" href="/markets/TDWL/stocks/1140">1140</a>            </td>            <td class="mi-hide-for-small ng-binding">البنوك</td>                        <td class="number ng-binding">24.54</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.49%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/2270/profile" class="ng-binding" href="/markets/TDWL/stocks/2270/profile">سدافكو</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/2270" class="ng-binding" href="/markets/TDWL/stocks/2270">2270</a>            </td>            <td class="mi-hide-for-small ng-binding">إنتاج الأغذية</td>                        <td class="number ng-binding">186</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.43%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/2280/profile" class="ng-binding" href="/markets/TDWL/stocks/2280/profile">المراعي</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/2280" class="ng-binding" href="/markets/TDWL/stocks/2280">2280</a>            </td>            <td class="mi-hide-for-small ng-binding">إنتاج الأغذية</td>                        <td class="number ng-binding">53.6</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.56%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/2290/profile" class="ng-binding" href="/markets/TDWL/stocks/2290/profile">ينساب</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/2290" class="ng-binding" href="/markets/TDWL/stocks/2290">2290</a>            </td>            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>                        <td class="number ng-binding">54</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              1.50%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/4200/profile" class="ng-binding" href="/markets/TDWL/stocks/4200/profile">الدريس</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4200" class="ng-binding" href="/markets/TDWL/stocks/4200">4200</a>            </td>            <td class="mi-hide-for-small ng-binding">الطاقة</td>                        <td class="number ng-binding">63.6</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              2.42%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/4210/profile" class="ng-binding" href="/markets/TDWL/stocks/4210/profile">الأبحاث والتسويق</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4210" class="ng-binding" href="/markets/TDWL/stocks/4210">4210</a>            </td>            <td class="mi-hide-for-small ng-binding">الإعلام والترفيه</td>                        <td class="number ng-binding">60</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              1.69%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/2300/profile" class="ng-binding" href="/markets/TDWL/stocks/2300/profile">صناعة الورق</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/2300" class="ng-binding" href="/markets/TDWL/stocks/2300">2300</a>            </td>            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>                        <td class="number ng-binding">47.65</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              2.36%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/2310/profile" class="ng-binding" href="/markets/TDWL/stocks/2310/profile">سبكيم العالمية</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/2310" class="ng-binding" href="/markets/TDWL/stocks/2310">2310</a>            </td>            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>                        <td class="number ng-binding">15.36</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -1.29%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/4220/profile" class="ng-binding" href="/markets/TDWL/stocks/4220/profile">إعمار</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4220" class="ng-binding" href="/markets/TDWL/stocks/4220">4220</a>            </td>            <td class="mi-hide-for-small ng-binding">إدارة وتطوير العقارات</td>                        <td class="number ng-binding">7.27</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.14%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/4240/profile" class="ng-binding" href="/markets/TDWL/stocks/4240/profile">الحكير</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4240" class="ng-binding" href="/markets/TDWL/stocks/4240">4240</a>            </td>            <td class="mi-hide-for-small ng-binding">تجزئة السلع الكمالية</td>                        <td class="number ng-binding">20.66</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.86%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index -->        </tbody>      </table>      <div ng-show="table.searcing" class="ng-hide">        <span class="global__loading">جارى التصفية, يرجى الإنتظار ...</span>        <div>    <div class="sk-spinner sk-spinner-wave">        <div class="sk-rect1"></div>        <div class="sk-rect2"></div>        <div class="sk-rect3"></div>        <div class="sk-rect4"></div>        <div class="sk-rect5"></div>    </div></div>      </div>      <div ng-hide="table.loaded" class="ng-hide" style="">        <div>    <div class="sk-spinner sk-spinner-wave">        <div class="sk-rect1"></div>        <div class="sk-rect2"></div>        <div class="sk-rect3"></div>        <div class="sk-rect4"></div>        <div class="sk-rect5"></div>    </div></div>      </div>      <div st-items-by-page="20" st-pagination="" st-template="/assets/ui/ngt/components/pagination/pagination.ng.html" class="ng-isolate-scope"><!-- ngIf: pages.length >= 2 --><div class="pagination ng-scope" ng-if="pages.length >= 2">    <nav role="navigation" aria-label="Pagination">        <ul class="cd-pagination no-space" role="menubar" aria-label="Pagination">            <!-- ngIf: currentPage > 1 --><li ng-if="currentPage > 1" class="ng-scope">                <a ng-click="selectPage(1)">                    <i class="fa fa-angle-double-right fa-lg"></i>                </a>            </li><!-- end ngIf: currentPage > 1 -->            <!-- ngIf: currentPage > 1 --><li class="cd-pagination__button ng-scope" aria-disabled="true" ng-if="currentPage > 1">                <a ng-click="selectPage(currentPage-1)" class="ng-binding">                  <i class="fa fa-lg fa-angle-right"></i>                  السابق                </a>            </li><!-- end ngIf: currentPage > 1 -->            <!-- ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">                <a ng-click="selectPage(page)" class="ng-binding">2</a>            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">                <a ng-click="selectPage(page)" class="ng-binding">3</a>            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope current">                <a ng-click="selectPage(page)" class="ng-binding">4</a>            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">                <a ng-click="selectPage(page)" class="ng-binding">5</a>            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">                <a ng-click="selectPage(page)" class="ng-binding">6</a>            </li><!-- end ngRepeat: page in pages -->            <!-- ngIf: currentPage < numPages --><li class="cd-pagination__button ng-scope" ng-if="currentPage < numPages">                <a ng-click="selectPage(currentPage+1)" href="" class="ng-binding">                  التالي                    <i class="fa fa-angle-left fa-lg"></i>                </a>            </li><!-- end ngIf: currentPage < numPages -->            <!-- ngIf: currentPage < numPages --><li ng-if="currentPage < numPages" class="ng-scope">                <a ng-click="selectPage(numPages)">                    <i class="fa fa-angle-double-left  fa-lg"></i>                </a>            </li><!-- end ngIf: currentPage < numPages -->        </ul>    </nav></div><!-- end ngIf: pages.length >= 2 --></div>    </div>  </div>    <!-- Speakol Widget - Removal IB-51 -->  <!-- <div th:replace="components/ads/common/speakol-one"/> -->  </main>  <aside class="mi-sidebar mi-show-for-large-up">    <!-- Radio component doesn\'t exist in English version -->    <!---->  <!--  <div th:unless="${device.isMobile()}">      <div>        <iframe onload="adjustIframeSize(this);" class="ad-iframe" src="/ads/side-bar"></iframe>      </div>      <script>        function adjustIframeSize(self) {          var index = 0;          var interval = setInterval( function(){            if (index < 3) {              self.style.height=self.contentDocument.body.scrollHeight +10 + \'px\';self.style.width=\'310px\';              index = index + 1;            } else {              clearInterval(interval)            }          }, 1);        }      </script>    </div>-->    <div>    <div class="mi-popular-news news-sidebar-mub md-whiteframe-z1 ng-scope" ng-controller="PopularNewsController as popular">    <h2 class="global__h2--collapsed">الأخبار الأكثر</h2>    <v-tabs active="tabs.active" class="vTabs--secondary ng-isolate-scope" control="tabs">      <!-- ngRepeat: page in popular.pages --><v-tab ng-bind="page.title" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope is-active" role="tab" aria-selected="true" tabindex="0">قراءة</v-tab><!-- end ngRepeat: page in popular.pages --><v-tab ng-bind="page.title" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope" role="tab" aria-selected="false" tabindex="-1">مشاركة</v-tab><!-- end ngRepeat: page in popular.pages -->    </v-tabs>    <v-pages active="tabs.active" class="vPages--default ng-isolate-scope" control="tabs" ng-swipe-left="tabs.next()" ng-swipe-right="tabs.previous()">      <!-- ngRepeat: page in popular.pages --><v-page ng-bind-html="page.content | unsafe" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope is-active" role="tabpanel">        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3680410/%D9%87%D9%8A%D8%A6%D8%A9-%D8%A7%D9%84%D9%86%D9%82%D9%84-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%B5%D8%B1%D9%81-%D8%AF%D8%B9%D9%85-%D8%A7%D9%84%D8%A3%D9%81%D8%B1%D8%A7%D8%AF-%D8%A7%D9%84%D8%B9%D8%A7%D9%85%D9%84%D9%8A%D9%86-%D9%81%D9%8A-%D9%86%D8%B4%D8%A7%D8%B7-%D8%AA%D9%88%D8%AC%D9%8A%D9%87-%D8%A7%D9%84%D9%85%D8%B1%D9%83%D8%A8%D8%A7%D8%AA-%D9%82%D8%B1%D9%8A%D8%A8%D8%A7-/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="فرع تابع لهيئة العامة للنقل السعودية" src="https://static.mubasher.info/File.Story_Image/3e19073c5aca3db54ef2c06eb4bf5ea6/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3680410/%D9%87%D9%8A%D8%A6%D8%A9-%D8%A7%D9%84%D9%86%D9%82%D9%84-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%B5%D8%B1%D9%81-%D8%AF%D8%B9%D9%85-%D8%A7%D9%84%D8%A3%D9%81%D8%B1%D8%A7%D8%AF-%D8%A7%D9%84%D8%B9%D8%A7%D9%85%D9%84%D9%8A%D9%86-%D9%81%D9%8A-%D9%86%D8%B4%D8%A7%D8%B7-%D8%AA%D9%88%D8%AC%D9%8A%D9%87-%D8%A7%D9%84%D9%85%D8%B1%D9%83%D8%A8%D8%A7%D8%AA-%D9%82%D8%B1%D9%8A%D8%A8%D8%A7-/">هيئة النقل السعودية: صرف دعم الأفراد العاملين في نشاط توجيه المركبات قريباً</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3680099/%D8%A7%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D8%B5%D8%AF%D8%B1-%D9%82%D8%B1%D8%A7%D8%B1%D8%A7-%D8%A8%D8%B4%D8%A3%D9%86-%D8%A7%D9%84%D9%85%D8%A8%D8%AA%D8%B9%D8%AB%D9%8A%D9%86/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="وزير التعليم السعودي، حمد بن محمد آل الشيخ، أرشيفية" src="https://static.mubasher.info/File.Story_Image/9e9e9919f67b43d61c15c7fd734289d3/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3680099/%D8%A7%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D8%B5%D8%AF%D8%B1-%D9%82%D8%B1%D8%A7%D8%B1%D8%A7-%D8%A8%D8%B4%D8%A3%D9%86-%D8%A7%D9%84%D9%85%D8%A8%D8%AA%D8%B9%D8%AB%D9%8A%D9%86/">التعليم السعودية تصدر قراراً بشأن المبتعثين</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3680101/%D9%85%D8%AD%D8%AF%D8%AB-%D8%A7%D9%84%D8%B0%D9%87%D8%A8-%D9%8A%D8%AA%D9%87%D8%A7%D9%88%D9%89-93-%D8%AF%D9%88%D9%84%D8%A7%D8%B1%D8%A7-%D8%B9%D9%86%D8%AF-%D8%A7%D9%84%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D9%85%D8%B9-%D9%85%D9%83%D8%A7%D8%B3%D8%A8-%D8%A7%D9%84%D8%A3%D8%B3%D9%87%D9%85/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/caeadbca5bf2481c2d38f04625e51f00/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3680101/%D9%85%D8%AD%D8%AF%D8%AB-%D8%A7%D9%84%D8%B0%D9%87%D8%A8-%D9%8A%D8%AA%D9%87%D8%A7%D9%88%D9%89-93-%D8%AF%D9%88%D9%84%D8%A7%D8%B1%D8%A7-%D8%B9%D9%86%D8%AF-%D8%A7%D9%84%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D9%85%D8%B9-%D9%85%D9%83%D8%A7%D8%B3%D8%A8-%D8%A7%D9%84%D8%A3%D8%B3%D9%87%D9%85/">محدث.. الذهب يتهاوى 93 دولاراً عند التسوية مع مكاسب الأسهم</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3679355/%D8%A7%D9%84%D9%84%D9%8A%D8%B1%D8%A9-%D8%A7%D9%84%D8%AA%D8%B1%D9%83%D9%8A%D8%A9-%D8%AA%D9%87%D8%A8%D8%B7-%D8%A5%D9%84%D9%89-%D9%85%D8%B3%D8%AA%D9%88%D9%89-%D8%AA%D8%A7%D8%B1%D9%8A%D8%AE%D9%8A-%D8%AC%D8%AF%D9%8A%D8%AF/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/1242bfad1995396ce3f6470a3d5584c2/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3679355/%D8%A7%D9%84%D9%84%D9%8A%D8%B1%D8%A9-%D8%A7%D9%84%D8%AA%D8%B1%D9%83%D9%8A%D8%A9-%D8%AA%D9%87%D8%A8%D8%B7-%D8%A5%D9%84%D9%89-%D9%85%D8%B3%D8%AA%D9%88%D9%89-%D8%AA%D8%A7%D8%B1%D9%8A%D8%AE%D9%8A-%D8%AC%D8%AF%D9%8A%D8%AF/">الليرة التركية تهبط إلى مستوى تاريخي جديد</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3679705/%D8%B9%D9%85%D9%84%D8%A9-%D8%A7%D9%84%D8%A8%D9%8A%D8%AA%D9%83%D9%88%D9%8A%D9%86-%D8%AA%D8%B9%D8%A7%D9%88%D8%AF-%D8%A7%D9%84%D8%B5%D8%B9%D9%88%D8%AF-%D8%A3%D8%B9%D9%84%D9%89-12-%D8%A3%D9%84%D9%81-%D8%AF%D9%88%D9%84%D8%A7%D8%B1/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/ab491b6531081c6058fa5b203b6cbecc/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3679705/%D8%B9%D9%85%D9%84%D8%A9-%D8%A7%D9%84%D8%A8%D9%8A%D8%AA%D9%83%D9%88%D9%8A%D9%86-%D8%AA%D8%B9%D8%A7%D9%88%D8%AF-%D8%A7%D9%84%D8%B5%D8%B9%D9%88%D8%AF-%D8%A3%D8%B9%D9%84%D9%89-12-%D8%A3%D9%84%D9%81-%D8%AF%D9%88%D9%84%D8%A7%D8%B1/">عملة البيتكوين تعاود الصعود أعلى 12 ألف دولار</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3679783/%D8%A3%D8%B1%D8%A7%D9%85%D9%83%D9%88-%D8%AA%D8%B1%D9%81%D8%B9-%D8%A3%D8%B3%D8%B9%D8%A7%D8%B1-%D8%A7%D9%84%D8%A8%D9%86%D8%B2%D9%8A%D9%86-%D8%A8%D9%86%D8%AD%D9%88-11-%D8%AD%D8%AA%D9%89-10-%D8%B3%D8%A8%D8%AA%D9%85%D8%A8%D8%B1/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="محطة للتزود بالوقود" src="https://static.mubasher.info/File.Story_Image/cf61a8737c62c57737e53b3677aa2bbc/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3679783/%D8%A3%D8%B1%D8%A7%D9%85%D9%83%D9%88-%D8%AA%D8%B1%D9%81%D8%B9-%D8%A3%D8%B3%D8%B9%D8%A7%D8%B1-%D8%A7%D9%84%D8%A8%D9%86%D8%B2%D9%8A%D9%86-%D8%A8%D9%86%D8%AD%D9%88-11-%D8%AD%D8%AA%D9%89-10-%D8%B3%D8%A8%D8%AA%D9%85%D8%A8%D8%B1/">أرامكو ترفع أسعار البنزين بنحو 11% حتى 10 سبتمبر</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3680546/%D8%A8%D9%803-%D8%B6%D9%88%D8%A7%D8%A8%D8%B7-%D8%A7%D9%84%D8%AA%D9%82%D8%A7%D8%B9%D8%AF-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D9%88%D8%B6%D8%AD-%D8%B7%D8%B1%D9%8A%D9%82%D8%A9-%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D8%A7%D9%84%D9%85%D8%B9%D8%A7%D8%B4-%D9%84%D9%85%D9%88%D8%B8%D9%81%D9%8A-%D8%A7%D9%84%D9%82%D8%B7%D8%A7%D8%B9-%D8%A7%D9%84%D8%B9%D8%A7%D9%85/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="مؤسسة التقاعد السعودية" src="https://static.mubasher.info/File.Story_Image/68cc490a847f0daba3afd0ddbd6d06c8/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3680546/%D8%A8%D9%803-%D8%B6%D9%88%D8%A7%D8%A8%D8%B7-%D8%A7%D9%84%D8%AA%D9%82%D8%A7%D8%B9%D8%AF-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D9%88%D8%B6%D8%AD-%D8%B7%D8%B1%D9%8A%D9%82%D8%A9-%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D8%A7%D9%84%D9%85%D8%B9%D8%A7%D8%B4-%D9%84%D9%85%D9%88%D8%B8%D9%81%D9%8A-%D8%A7%D9%84%D9%82%D8%B7%D8%A7%D8%B9-%D8%A7%D9%84%D8%B9%D8%A7%D9%85/">بـ3 ضوابط.. التقاعد السعودية توضح طريقة تسوية المعاش لموظفي القطاع العام</a>        </div>              </div>        <a class="mi-article-widget__more-button" href="/news/SA/now/popular">      <span>المزيد</span>      <i class="fa fa-chevron-left"></i>    </a>    </v-page><!-- end ngRepeat: page in popular.pages --><v-page ng-bind-html="page.content | unsafe" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope" role="tabpanel">            <a class="mi-article-widget__more-button" href="/news/SA/now/trending/">      <span>المزيد</span>      <i class="fa fa-chevron-left"></i>    </a>    </v-page><!-- end ngRepeat: page in popular.pages -->    </v-pages>  </div>    <div id="MPU">    </div>    </div>    <!-- Speakol Widget - Removal IB-51 -->    <!-- <div th:replace="components/ads/common/speakol-two"/> --><!--    <div th:unless="${device.isMobile()}">      <div th:replace="components/ads/insticator/insticator-widget"/>    </div>-->    <!-- -->    <!-- PS -->    <!--<div th:replace="components/ads/internal/may-like-articles" />-->    <!--<div th:replace="components/ads/internal/second-fold" />-->    <!--    <div th:if="${#locale.getLanguage() == \'ar\'}">          <span class="home__title">راديو مباشر</span>          <div class="internal-radio-carousel-container"></div>        </div>-->  </aside><!--  <div th:replace="components/ads/internal/mobile-fullpage"/>-->  <!--<div th:replace="components/ads/internal/mobile-interstitial"/>--><!--commented out as per Fayoumi\'s request-->  <!--<div th:replace="components/ads/internal/mobile-outstream"/>-->  <!--MFP-228 New Fixed-Replacement-ROS ads--><!--  <div th:replace="components/ads/home/mobile-fixed-replacement"/>  <div th:replace="components/ads/news/dfp/mobile/MPU3"/>--><!--Commented out as per Fayoumi\'s request-->  <!--<div th:replace="components/ads/internal/outstream"/>--><!--  <div th:if="${device.isMobile()}">    <div th:replace="components/ads/dfp/mobile-internal-pages"/>  </div>--><!--  <div th:if="${device.isMobile()}">    <div th:replace="components/ads/insticator/insticator-widget"/>  </div>--> <!-- <div th:replace="components/ads/internal/mobile-above-footer"/>--></div>    </div>    <footer>  <div class="mi-footer">    <div class="mi-show-for-large-up mi-footer__main-menu">      <ul>        <li class="mi-footer__menu-item mi-footer__menu__markets" id="markets">          <div class="mi-footer__menu-level1">الأسواق</div>          <ul>            <h3 class="mi-footer__menu-level2 invisible">الأسواق</h3>            <li>              <a class="mi-footer__menu-level3" href="/markets/TDWL">سوق الأسهم السعودي</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/EGX">البورصة المصرية</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/DFM">سوق دبي المالي</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/ADX">سوق أبوظبي</a>            </li>          </ul>          <ul>            <li>              <a class="mi-footer__menu-level3" href="/markets/BB">بورصة البحرين</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/QE">بورصة قطر</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/MSM">سوق مسقط</a>            </li>          </ul>          <ul>            <li>              <a class="mi-footer__menu-level3" href="/markets/KSE">سوق الكويت</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/ASE">بورصة عمان</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/CSE">سوق الدار البيضاء</a>            </li>          </ul>          <ul>            <li>              <a class="mi-footer__menu-level3" href="/markets/BDT">بورصة تونس</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/PEX">سوق فلسطين</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/ISX">سوق العراق</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/international-indices">مؤشرات الأسواق العالمية</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/commodities-prices">أسعار المعادن والطاقة</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/currencies">أسعار العملات</a>            </li>            <!--<li>              <a class="mi-footer__menu-level3"                 th:href="${@url.to(\'RMPC#regionalMap\')}"                 th:text="#{navigation.markets.regional-map}"/>            </li>-->          </ul>        </li>        <li class="mi-footer__menu-item mi-footer__menu__news" id="news">          <ul>            <div class="mi-footer__menu-level1">الأخبار</div>            <li class="mi-footer__menu__news__submenu">              <h3 class="mi-footer__menu-level2">أخبار الدول</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/eg/now/latest">مصر</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/latest">السعودية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/ae/now/latest">الإمارات</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/bh/now/latest">البحرين</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/qa/now/latest">قطر</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/om/now/latest">عمان</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/kw/now/latest">الكويت</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/jo/now/latest">الأردن</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/ma/now/latest">المغرب</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/tn/now/latest">تونس</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/ps/now/latest">فلسطين</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/iq/now/latest">العراق</a>                </li>              </ul>            </li>            <li class="mi-footer__menu__news__submenu">              <h3 class="mi-footer__menu-level2">أخبار إقليمية</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/regions/gulf">الخليج</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/regions/levant">الشام</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/regions/north-africa">شمال أفريقيا</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/regions/middle-east">الشرق الأوسط</a>                </li>              </ul>              <!-- happening now -->              <h3 class="mi-footer__menu-level2">يحدث الآن</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/top">أهم الأخبار</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/exclusive">حصرياً مباشر</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/latest">آخر الأخبار</a>                </li>                                  <li>                    <a class="mi-footer__menu-level3" href="/news/sa/now/announcements">إعلانات السوق</a>                  </li>                                                  <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/popular">منتشر الآن</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/trending/">الأكثر مشاركة</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/now/news-releases">بيانات صحفية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/misc">أخبار منوعة</a>                </li>              </ul>            </li>            <li class="mi-footer__menu__news__submenu">              <h3 class="mi-footer__menu-level2">نبض السوق</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/stocks">أخبار الأسهم</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/analysis">تحليلات إخبارية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/local">اقتصاد محلي</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/recommendations">توصيات</a>                </li>              </ul>              <h3 class="mi-footer__menu-level2">أخبار القطاعات</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/category/banking">بنوك</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/category/realEstate">عقارات</a>                </li>              </ul>              <h3 class="mi-footer__menu-level2">أخبار عالمية</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/global-economy">اقتصاد عالمى</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/goods-and-metals">أحداث عالمية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/global-indices">مؤشرات عالمية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/oil-and-energy">نفط ومعادن</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/currencies">عملات</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/global-reports">تقارير عالمية</a>                </li>              </ul>            </li>          </ul>        </li>        <li class="mi-footer__menu-item mi-footer__menu__companies" id="companies">          <div class="mi-footer__menu-level1">الشركات</div>          <ul>            <h3 class="mi-footer__menu-level2 invisible">الشركات</h3>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/companies">الشركات المدرجة</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/events">مفكرة الشركات</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/stock-prices">أسعار الأسهم</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/earnings">إعلانات الأرباح</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/fair-values">القيم العادلة</a>            </li>            <li>                          </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/major-shareholders">كبار الملاك</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/ipos">قائمة الإكتتابات</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/ipo/list">بحث فى الاكتتابات</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/ipos/news">أخبار الاكتتابات</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/ipo/calendar">مفكرة الاكتتابات</a>            </li>          </ul>        </li>        <li class="mi-footer__menu-item mi-footer__menu__analysis-tools" id="analysis-tools">          <div class="mi-footer__menu-level1">أدوات التحليل</div>          <!-- If current country has one market only -->                      <ul>              <h3 class="mi-footer__menu-level2 invisible">أدوات التحليل</h3>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/performance-comparison">مقارنة الأداء</a>              </li>            </ul>                    <!-- If current country has more than one markets i.e UAE -->                  </li>      </ul>    </div>    <div class="mi-footer__second-fold">      <div class="mi-footer__column1">        <div class="mi-footer__copyright">          <div class="mi-footer__logo" onclick="window.location.href=\'/countries/sa\'">              <svg viewBox="0 0 494.387 190.555">    <use xlink:href="#logo-white"></use>  </svg>            </div>          <span>جميع الحقوق تعود لشركة مباشر العالمية © 2005 - 2020</span>        </div>        <ul class="mi-footer__links">          <li>            <a href="/s/Terms">اتفاقية الاستخدام</a>          </li>          <li>            <a href="/s/disclaimer">إخلاء المسؤولية</a>          </li>          <li>            <a href="/s/aboutus">من نحن</a>          </li>          <li>            <a href="/contact">اتصل بنا</a>          </li>          <li>            <a href="/advertise">أعلن معنا</a>          </li>          <li>            <a href="http://www.decypha.com/" target="_blank">موقع ديسيفا</a>          </li>          <li>            <a href="/ir-services" target="_blank">خدمات المواقع</a>          </li>          <li>            <a href="/s/Jobs">وظائف</a>          </li>          <li>              <a target="_blank" href="/decypha-packages">ديسيفا</a>          </li>          <li>            <a href="/s/privacy-policy" target="_blank">سياسة الخصوصية</a>          </li>          <!--<li th:if="${#locale.getLanguage() == \'en\'}">            <a href="/s/decypha-financial-intelligence" th:text="#{components.footer.decypha-financial-intelligence}">Decypha Financial Intelligence</a>          </li>-->        </ul>        <div>جميع البيانات متأخرة 15 دقيقة أثناء الجلسة</div>        <div>هذا الموقع مرخص من وزراة الثقافة والإعلام السعودية</div>        <div>رقم التسجيل :ت 1 125 1435</div>      </div>      <div class="mi-footer__column2">        <ul class="mi-footer__social-icons">          <li>            <a target="_blank" href="https://twitter.com/mubasher"><i class="fa fa-twitter fa-2x"></i></a>          </li>          <li>            <a href="https://www.facebook.com/Mubasher.Info"><i class="fa fa-facebook fa-2x"></i></a>          </li>          <li>            <a href="https://www.youtube.com/channel/UC7hnxb7gD4nKZdZk3ZlZCYg"><i class="fa fa-youtube fa-2x"></i></a>          </li>          <li>            <a href="https://www.linkedin.com/company/1477149"><i class="fa fa-linkedin fa-2x"></i></a>          </li>          <li>            <a href="/news/rss"><i class="fa fa-rss fa-2x"></i></a>          </li>          <li>            <a href="https://play.google.com/store/apps/details?id=net.mis.mubasherinfo">              <i class="fa fa-android fa-2x"></i></a>          </li>          <li>            <a href="https://itunes.apple.com/app/imubasher/id494539772?mt=8"><i class="fa fa-apple fa-2x"></i></a>          </li>          </ul></div></div></div></footer>          </div>  <script src="//code.jquery.com/jquery-2.1.4.min.js"></script>  <script src="//ajax.googleapis.com/ajax/libs/angularjs/1.3.15/angular.min.js"></script>  <script src="/assets/ui/lib.min.js"></script>  <script src="/assets/ui/main.min.js"></script>  <div id="mi-js-scripts"></div>  <script>    <!-- Fix menu trigger on android browser4 -->    $(".dl-menu__menu-item").click(function () {      $(this).addClass(".dl-menu-item__hoverd");    });    $(document).ready(function () {      $(\'.tooltip\').tooltipster();      setTimeout(function(){ dataLayer.push({event: "triggerAds"});      console.log("triggerAds");      }, 1000);    });  </script>    <div pg-ng-tooltip=""></div></div>  <!-- Twitter universal website tag code -->  <script>    !function(e,t,n,s,u,a){e.twq||(s=e.twq=function(){s.exe?s.exe.apply(s,arguments):s.queue.push(arguments);    },s.version=\'1.1\',s.queue=[],u=t.createElement(n),u.async=!0,u.src=\'//static.ads-twitter.com/uwt.js\',      a=t.getElementsByTagName(n)[0],a.parentNode.insertBefore(u,a))}(window,document,\'script\');    // Insert Twitter Pixel ID and Standard Event data below    twq(\'init\',\'nyana\');    twq(\'track\',\'PageView\');  </script>  <!-- End Twitter universal website tag code --><div id="mm-blocker" class="mm-slideout"></div></body>' + '<body id="mi" ng-app="app" ng-controller="MainController" class="ar ng-scope" data-gr-c-s-loaded="true"><nav class="header__countries-menu mm-menu mm-offcanvas mm-top mm-front" id="countries-menu"><div class="mm-panel mm-opened mm-current" id="mm-8"><ul class="mm-listview mm-first mm-last">        <li class="header__country-selector__country">          <a href="/change-country?to=ae&amp;url=/countries/sa/companies">الإمارات</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=bh&amp;url=/countries/sa/companies">البحرين</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=om&amp;url=/countries/sa/companies">عُمان</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=qa&amp;url=/countries/sa/companies">قطر</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=kw&amp;url=/countries/sa/companies">الكويت</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=eg&amp;url=/countries/sa/companies">مصر</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=jo&amp;url=/countries/sa/companies">الأردن</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=tn&amp;url=/countries/sa/companies">تونس</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=ma&amp;url=/countries/sa/companies">المغرب</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=ps&amp;url=/countries/sa/companies">فلسطين</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=iq&amp;url=/countries/sa/companies">العراق</a>        </li>      </ul></div></nav><nav class="header__main-menu mm-menu mm-border-full mm-effect-slide-menu mm-effect-zoom-panels mm-pageshadow mm-offcanvas mm-right mm-hasnavbar-top mm-hasnavbar" id="main-menu"><div class="mm-navbar mm-navbar-top mm-hasbtns"><a class="mm-prev mm-btn mm-hidden"></a><a class="mm-title"> </a><a class="mm-close mm-btn" href="#wrapper"></a></div><div class="mm-panel mm-opened mm-current" id="mm-0"><ul class="mm-listview mm-first mm-last">        <li id="markets">          <a class="mm-next mm-fullsubopen" href="#mm-1" data-target="#mm-1"></a><span href="javascript:;">الأسواق</span>                  </li>        <li id="news">          <a class="mm-next mm-fullsubopen" href="#mm-2" data-target="#mm-2"></a><span href="javascript:;">الأخبار</span>                  </li>        <li id="companies">          <a class="mm-next mm-fullsubopen" href="#mm-3" data-target="#mm-3"></a><span href="javascript:;">الشركات</span>                  </li>        <li id="funds">          <a class="mm-next mm-fullsubopen" href="#mm-4" data-target="#mm-4"></a><span href="javascript:;">صناديق الاستثمار</span>                  </li>        <li id="analysis-tool">          <a class="mm-next mm-fullsubopen" href="#mm-5" data-target="#mm-5"></a><span href="javascript:;">أدوات التحليل</span>                  </li>        <li id="islamic-economy">          <a href="/news/islamic-finance">الاقتصاد الإسلامي</a>        </li>        <!--<li class="global__hide-for-ltr" id="radio" th:if="${#locale.getLanguage() == \'ar\'}">          <span th:text="#{navigation.radio}">راديو مباشر</span>          <ul>            <li>              <a th:href="${@url.to(\'RPC#live\')}" th:text="#{navigation.radio.live}"/>            </li>            <li>              <a th:href="${@url.to(\'RPC#latestEpisodesPage\', countryCode)}">آخر الحلقات</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تقارير-اقتصادية\'}">تقارير اقتصادية</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تغطية-خاصة\'}">تغطية خاصة</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'مقالات\'}">مقالات</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#programs\')}" th:text="#{navigation.radio.programs}"/>            </li>            <li>              <a th:href="${@url.to(\'RPC#videoPrograms\')}" th:text="#{navigation.radio.videoPrograms}"/>            </li>            <li>              <a th:href="${@url.to(\'RPC#getExperts\')}">ضيوفنا</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#getPresenters\')}">المذيعون</a>            </li>          </ul>        </li>-->        <li class="global__hide-for-ltr" id="video">          <a href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">مباشر TV</a>        </li>                <li id="fixedincome">          <a class="mm-next mm-fullsubopen" href="#mm-6" data-target="#mm-6"></a><span>السندات</span>                  </li>        <li>          <a class="mm-next mm-fullsubopen" href="#mm-7" data-target="#mm-7"></a><span>شخصي</span>                  </li>        <li>          <a href="http://tawasul.mubasher.info/" target="_blank">تواصل</a>        </li>        <!-- <li>          <a th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank" th:text="#{components.header.decypha}" target="_blank">          </a>        </li> -->        <li>          <a ng-click="decypha(\'decypha\')">ديسيفا</a>        </li>        <!--Add according to MFP-187-->        <li>          <a href="https://contest.mubasher.info/#/home" target="_blank">المستثمر اﻷول</a>        </li>        <li>          <!--Integrating Mubasher Pulse-->        </li><li>        <style>          .pulse-logo2{            padding: 5px 5px 4px;            min-width: 82px;            min-height: 21px;            max-width: 27%;          }        </style>        <a target="_blank" href="https://pulse.mubasher.info">          <img class="pulse-logo2" src="../../../images/pulse-logo.png">        </a>        </li>        <li>        </li><li>          <a href="http://magazine.mubasher.info/" target="_blank">            مجلة مباشر          </a>        </li>        <li class="mm-divider"></li>        <li>          <a href="https://english.mubasher.info">ENGLISH</a>        </li>        <li>                  </li>        <li>          <a class="header__login__text" href="/account/login">دخول</a>                  </li>      </ul></div><div class="mm-panel mm-hidden" id="mm-1"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الأسواق</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/markets/TDWL">سوق الأسهم السعودي</a>            </li>            <li>              <a href="/markets/EGX">البورصة المصرية</a>            </li>            <li>              <a href="/markets/DFM">سوق دبي المالي</a>            </li>            <li>              <a href="/markets/ADX">سوق أبوظبي</a>            </li>            <li>              <a href="/markets/BB">بورصة البحرين</a>            </li>            <li>              <a href="/markets/QE">بورصة قطر</a>            </li>            <li>              <a href="/markets/MSM">سوق مسقط</a>            </li>            <li>              <a href="/markets/BK">سوق الكويت</a>            </li>            <li>              <a href="/markets/ASE">بورصة عمان</a>            </li>            <li>              <a href="/markets/CSE">سوق الدار البيضاء</a>            </li>            <li>              <a href="/markets/BDT">بورصة تونس</a>            </li>            <li>              <a href="/markets/PEX">سوق فلسطين</a>            </li>            <li>              <a href="/markets/ISX">سوق العراق</a>            </li>            <li>              <a href="/international-indices">مؤشرات الأسواق العالمية</a>            </li>            <li>              <a href="/markets/commodities-prices">أسعار المعادن والطاقة</a>            </li>            <li>              <a href="/countries/sa/currencies">أسعار العملات</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-2"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الأخبار</a></div><ul class="mm-listview mm-first mm-last">            <!-- now -->            <li class="mm-divider">يحدث الآن</li>            <li>              <a href="/news/sa/now/top">أهم الأخبار</a>            </li>            <li>              <a href="/news/sa/now/exclusive">حصرياً مباشر</a>            </li>            <li>              <a href="/news/sa/now/latest">آخر الأخبار</a>            </li>                          <li>                <a href="/news/sa/now/announcements">إعلانات السوق</a>              </li>                                      <li class="global__hide-for-ltr">              <a href="/news/sa/now/popular">منتشر الآن</a>            </li>            <li>              <a href="/news/sa/now/trending/">الأكثر مشاركة</a>            </li>            <li>              <a href="/news/now/news-releases">بيانات صحفية</a>            </li><!--            <li>              <a th:href="${@url.to(\'NPC#miscellaneousNews\', countryCode)}"                 th:text="#{navigation.news.now.misc}"/>            </li>-->            <!-- recommendations-->            <li class="mm-divider">نبض السوق</li>            <li>              <a href="/news/sa/pulse/stocks">أخبار الأسهم</a>            </li>            <li>              <a href="/news/sa/pulse/analysis">تحليلات إخبارية</a>            </li>            <li>              <a href="/news/sa/pulse/local">اقتصاد محلي</a>            </li>            <li>              <a href="/news/sa/pulse/recommendations">توصيات</a>            </li>            <li class="mm-divider">أخبار القطاعات</li>            <li>              <a href="/news/sa/category/banking">بنوك</a>            </li>            <li>              <a href="/news/sa/category/realEstate">عقارات</a>            </li>            <li class="mm-divider">أخبار الدول</li>            <li>              <a href="/news/eg/now/latest">مصر</a>            </li>            <li>              <a href="/news/sa/now/latest">السعودية</a>            </li>            <li>              <a href="/news/ae/now/latest">الإمارات</a>            </li>            <li>              <a href="/news/bh/now/latest">البحرين</a>            </li>            <li>              <a href="/news/qa/now/latest">قطر</a>            </li>            <li>              <a href="/news/om/now/latest">عمان</a>            </li>            <li>              <a href="/news/kw/now/latest">الكويت</a>            </li>            <li>              <a href="/news/jo/now/latest">الأردن</a>            </li>            <li>              <a href="/news/ma/now/latest">المغرب</a>            </li>            <li>              <a href="/news/tn/now/latest">تونس</a>            </li>            <li>              <a href="/news/ps/now/latest">فلسطين</a>            </li>            <li>              <a href="/news/iq/now/latest">العراق</a>            </li>            <!-- regions-->            <li class="mm-divider">أخبار إقليمية</li>            <li>              <a href="/news/regions/gulf">الخليج</a>            </li>            <li>              <a href="/news/regions/levant">الشام</a>            </li>            <li>              <a href="/news/regions/north-africa">شمال أفريقيا</a>            </li>            <li>              <a href="/news/regions/middle-east">الشرق الأوسط</a>            </li>            <!-- international -->            <li class="mm-divider">أخبار عالمية</li>            <li>              <a href="/news/international/global-economy">اقتصاد عالمى</a>            </li>            <li>              <a href="/news/international/goods-and-metals">أحداث عالمية</a>            </li>              <li>                <a href="/news/international/global-indices">مؤشرات عالمية</a>              </li>              <li>                <a href="/news/international/oil-and-energy">نفط ومعادن</a>              </li>              <li>                <a href="/news/international/currencies">عملات</a>              </li>              <li>                <a href="/news/international/global-reports">تقارير عالمية</a>              </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-3"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الشركات</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/countries/sa/companies">الشركات المدرجة</a>            </li>            <li>              <a href="/countries/sa/events">مفكرة الشركات</a>            </li>            <li>              <a href="/countries/sa/stock-prices">أسعار الأسهم</a>            </li>            <li>              <a href="/countries/sa/earnings">إعلانات الأرباح</a>            </li>            <li>              <a href="/countries/sa/fair-values">القيم العادلة</a>            </li>            <li>              <a href="/countries/sa/corporate-action">الإجراءات</a>            </li>                        <li>              <a href="/countries/sa/major-shareholders">كبار الملاك</a>            </li>            <li>              <a href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>            </li>            <li class="mm-divider">الاكتتابات</li>            <li>              <a href="/countries/sa/ipos">قائمة الإكتتابات</a>            </li>            <li>              <a href="/ipo/list">بحث فى الاكتتابات</a>            </li>            <li>              <a href="/ipos/news">أخبار الاكتتابات</a>            </li>            <li>              <a href="/ipo/calendar">مفكرة الاكتتابات</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-4"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">صناديق الاستثمار</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/countries/sa/funds">صناديق الاستثمار</a>            </li>            <li>              <a href="/countries/sa/funds-statistics">إحصائيات الصناديق</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-5"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">أدوات التحليل</a></div><ul class="mm-listview mm-first mm-last">                                        <li>                <a href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>              </li>              <li>                <a href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>              </li>              <li>                <a href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>              </li>              <li>                <a href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>              </li>              <li>                <a href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>              </li>                        <li class="mm-divider">            </li>            <li>              <a href="/analysis-tools/performance-comparison">مقارنة الأداء</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-6"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">السندات</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/fixedincome/bond/search" id="fixedIncomeBondScreener">بحث عن سندات</a>            </li>            <li>              <a href="/fixed-income/news" id="fixedIncomeNews">أخبار السندات وأذون الخزانة</a>            </li>            <li>              <a href="/fixedincome/calendar/searchForEvent" id="fixedIncomeCalendar">قائمة الأحداث</a>            </li>            <li>              <a href="/fixedincome/analytics/drawCurve" id="fixedIncomeAnalytics">تحليلات فنية</a>            </li>            <li>              <a href="/fixedincome/leagueTables/view" id="fixedIncomeLeagueTables">جداول الديون</a>            </li>            <li>              <a href="/fixedincome/research/search" id="fixedIncomeProspectus">تقارير</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-7"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">شخصي</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/my/alerts">التنبيهات</a>            </li>            <li>              <a href="/my/watch-list">أسهمي</a>            </li>            <li>              <a href="/my/newsletters">النشرة البريدية</a>            </li>          </ul></div></nav><div class="js-wrapper mm-page mm-slideout" id="wrapper">  <svg class="hidden" version="1.1" viewBox="0 0 0 0" xmlns="http://www.w3.org/2000/svg">  <defs>    <style>      .logo-white-path {        clip-rule: evenodd;        fill-rule: evenodd;        fill: white;        font-size: 46.6299px;        font-family: \'HelveticaNeue\';      }      .logo-path {        clip-rule: evenodd;        fill-rule: evenodd;        fill: #324651;        text-align: center;        font-size: 46.6299px;        font-family: \'HelveticaNeue\';      }    </style>    <g id="logo-white">      <path class="logo-white-path" d="M209.596 29.677c-6.25 0.016-11.243-4.937-11.261-11.188 c-0.018-6.191 5.027-11.29 11.194-11.29c6.182-0.004 11.3 5.1 11.3 11.226C220.852 24.6 215.8 29.7 209.6 29.7"></path>      <path class="logo-white-path" d="M228.308 37.976c6.231-0.01 11.3 5 11.3 11.2 c0.015 6.189-5.011 11.227-11.233 11.252c-6.213 0.025-11.246-4.99-11.271-11.209C217.063 43 222.1 38 228.3 38"></path>      <path class="logo-white-path" d="M350.278 190.471c-6.27-0.009-11.204-4.942-11.197-11.212 c0.013-6.26 4.968-11.18 11.248-11.176c6.242 0 11.3 5 11.2 11.224C361.555 185.5 356.5 190.5 350.3 190.5"></path>      <path class="logo-white-path" d="M186.161 37.976c6.26 0 11.2 5 11.2 11.2 c-0.01 6.241-4.993 11.239-11.209 11.226c-6.257-0.017-11.212-4.99-11.212-11.228C174.949 42.9 179.9 38 186.2 38"></path>      <path class="logo-white-path" d="M455.92 80.125c-21.212 0-38.405 17.191-38.405 38.4 c0 4.3 0.7 8.4 2 12.316l-48.126 0.003l13.9-27.74h-3.242c0 0-2.13 0.019-2.822 0.1 c-2.13 0.126-3.67 0.098-7.926 1.351c-3.949 1.159-7.026 2.719-9.881 4.503c-2.381 1.493-5.863 4.278-8.803 7.7 c-2.912 3.325-5.713 7.695-5.713 7.695l-3.294 6.464l-41.201 0.003L364.7 0l-76.514 49.172l25.429-0.036L260.64 156.919h193.847 c0 0 0.9 0 1.4 0.01c21.212 0 38.4-17.183 38.4-38.403C494.32 97.3 477.1 80.1 455.9 80.125z M455.92 133.3 c-7.998 0-14.48-6.479-14.48-14.47c0-7.998 6.482-14.476 14.48-14.476c7.996 0 14.5 6.5 14.5 14.5 C470.393 126.8 463.9 133.3 455.9 133.327z"></path>      <path class="logo-white-path" d="M269.61 81.427c0 0-1.617 0.013-2.842 0.09c-2.001 0.132-3.655 0.07-7.903 1.3 c-3.946 1.162-7.021 2.722-9.876 4.507c-2.378 1.488-5.868 4.279-8.813 7.662c-2.904 3.327-5.282 8.108-5.282 8.108l-14.116 27.7 h-16.391l19.092-39.485h-3.237c0 0-1.617 0.015-2.835 0.095c-2.012 0.13-3.665 0.068-7.905 1.3 c-3.957 1.161-7.034 2.717-9.892 4.502c-2.373 1.493-5.857 4.28-8.808 7.668c-2.899 3.321-5.282 8.104-5.282 8.104l-8.901 17.8 h-16.959l13.92-27.753h-3.245c0 0-2.141 0.019-2.822 0.057c-2.133 0.126-3.663 0.098-7.926 1.4 c-3.944 1.159-7.026 2.719-9.884 4.503c-2.378 1.493-5.857 4.28-8.808 7.669c-2.904 3.329-5.708 7.695-5.708 7.695l-3.291 6.5 l-52.558-0.005l14.007-27.748h-3.242c0 0-2.131 0.019-2.815 0.057c-2.136 0.126-3.678 0.098-7.934 1.4 c-3.944 1.159-7.021 2.719-9.877 4.503c-2.383 1.493-5.858 4.28-8.813 7.669c-2.906 3.329-5.114 7.843-5.114 7.843l-16.204 31.1 l0 0c0 0-3.136 6.731-7.038 11.469c-3.094 3.766-7.43 6.804-9.757 8.194c-2.313 1.384-7.141 3.645-11.872 4.5 C5.251 180.9 0 180.5 0 180.502s2.33 2.1 5 3.806c2.034 1.4 4.3 2.4 5.5 3 c2.481 1.1 4.3 1.7 6.9 2.253c2.531 0.6 4.8 0.8 4.8 0.763s1.621 0.2 3.2 0.169c0.707 0 1.62-0.024 2.848-0.09 c2.001-0.134 3.5 0 7.904-1.323c4.033-1.188 7.072-2.582 9.92-4.368c2.383-1.478 5.952-4.249 8.904-7.627 c2.907-3.337 5.296-8.019 5.296-8.019l6.043-12.125l169.4 0.009l12.816-26.07l24.302-49.431H269.61z"></path>      <path class="logo-white-path" d="M30.239 76.472V55.626H22.45v-2.789h18.735v2.789h-7.819v20.846H30.239z"></path>      <path class="logo-white-path" d="M44.296 76.472V52.836h4.71l5.592 16.735c0.518 1.6 0.9 2.7 1.1 3.499c0.269-0.861 0.687-2.123 1.258-3.789 l5.658-16.446h4.209v23.636h-3.015V56.689l-6.869 19.783h-2.822l-6.835-20.121v20.121H44.296z"></path>    </g>    <g id="logo">      <path class="logo-path" d="M209.596 29.677c-6.25 0.016-11.243-4.937-11.261-11.188 c-0.018-6.191 5.027-11.29 11.194-11.29c6.182-0.004 11.3 5.1 11.3 11.226C220.852 24.6 215.8 29.7 209.6 29.7"></path>      <path class="logo-path" d="M228.308 37.976c6.231-0.01 11.3 5 11.3 11.2 c0.015 6.189-5.011 11.227-11.233 11.252c-6.213 0.025-11.246-4.99-11.271-11.209C217.063 43 222.1 38 228.3 38"></path>      <path class="logo-path" d="M350.278 190.471c-6.27-0.009-11.204-4.942-11.197-11.212 c0.013-6.26 4.968-11.18 11.248-11.176c6.242 0 11.3 5 11.2 11.224C361.555 185.5 356.5 190.5 350.3 190.5"></path>      <path class="logo-path" d="M186.161 37.976c6.26 0 11.2 5 11.2 11.2 c-0.01 6.241-4.993 11.239-11.209 11.226c-6.257-0.017-11.212-4.99-11.212-11.228C174.949 42.9 179.9 38 186.2 38"></path>      <path class="logo-path" d="M455.92 80.125c-21.212 0-38.405 17.191-38.405 38.4 c0 4.3 0.7 8.4 2 12.316l-48.126 0.003l13.9-27.74h-3.242c0 0-2.13 0.019-2.822 0.1 c-2.13 0.126-3.67 0.098-7.926 1.351c-3.949 1.159-7.026 2.719-9.881 4.503c-2.381 1.493-5.863 4.278-8.803 7.7 c-2.912 3.325-5.713 7.695-5.713 7.695l-3.294 6.464l-41.201 0.003L364.7 0l-76.514 49.172l25.429-0.036L260.64 156.919h193.847 c0 0 0.9 0 1.4 0.01c21.212 0 38.4-17.183 38.4-38.403C494.32 97.3 477.1 80.1 455.9 80.125z M455.92 133.3 c-7.998 0-14.48-6.479-14.48-14.47c0-7.998 6.482-14.476 14.48-14.476c7.996 0 14.5 6.5 14.5 14.5 C470.393 126.8 463.9 133.3 455.9 133.327z"></path>      <path class="logo-path" d="M269.61 81.427c0 0-1.617 0.013-2.842 0.09c-2.001 0.132-3.655 0.07-7.903 1.3 c-3.946 1.162-7.021 2.722-9.876 4.507c-2.378 1.488-5.868 4.279-8.813 7.662c-2.904 3.327-5.282 8.108-5.282 8.108l-14.116 27.7 h-16.391l19.092-39.485h-3.237c0 0-1.617 0.015-2.835 0.095c-2.012 0.13-3.665 0.068-7.905 1.3 c-3.957 1.161-7.034 2.717-9.892 4.502c-2.373 1.493-5.857 4.28-8.808 7.668c-2.899 3.321-5.282 8.104-5.282 8.104l-8.901 17.8 h-16.959l13.92-27.753h-3.245c0 0-2.141 0.019-2.822 0.057c-2.133 0.126-3.663 0.098-7.926 1.4 c-3.944 1.159-7.026 2.719-9.884 4.503c-2.378 1.493-5.857 4.28-8.808 7.669c-2.904 3.329-5.708 7.695-5.708 7.695l-3.291 6.5 l-52.558-0.005l14.007-27.748h-3.242c0 0-2.131 0.019-2.815 0.057c-2.136 0.126-3.678 0.098-7.934 1.4 c-3.944 1.159-7.021 2.719-9.877 4.503c-2.383 1.493-5.858 4.28-8.813 7.669c-2.906 3.329-5.114 7.843-5.114 7.843l-16.204 31.1 l0 0c0 0-3.136 6.731-7.038 11.469c-3.094 3.766-7.43 6.804-9.757 8.194c-2.313 1.384-7.141 3.645-11.872 4.5 C5.251 180.9 0 180.5 0 180.502s2.33 2.1 5 3.806c2.034 1.4 4.3 2.4 5.5 3 c2.481 1.1 4.3 1.7 6.9 2.253c2.531 0.6 4.8 0.8 4.8 0.763s1.621 0.2 3.2 0.169c0.707 0 1.62-0.024 2.848-0.09 c2.001-0.134 3.5 0 7.904-1.323c4.033-1.188 7.072-2.582 9.92-4.368c2.383-1.478 5.952-4.249 8.904-7.627 c2.907-3.337 5.296-8.019 5.296-8.019l6.043-12.125l169.4 0.009l12.816-26.07l24.302-49.431H269.61z"></path>      <path class="logo-path" d="M30.239 76.472V55.626H22.45v-2.789h18.735v2.789h-7.819v20.846H30.239z"></path>      <path class="logo-path" d="M44.296 76.472V52.836h4.71l5.592 16.735c0.518 1.6 0.9 2.7 1.1 3.499c0.269-0.861 0.687-2.123 1.258-3.789 l5.658-16.446h4.209v23.636h-3.015V56.689l-6.869 19.783h-2.822l-6.835-20.121v20.121H44.296z"></path>    </g>    <g id="logo-white-en">      <defs>        <rect height="65.7" width="326.9" x="-55"></rect>      </defs>      <clipPath>        <use overflow="visible" xlink:href="#SVGID_1_"></use>      </clipPath>      <path class="logo-white-path" d="M41.694 20.162c-1.315 0-1.315 0.987-1.315 0.987l0.094 13.8 c0 0 0.6 8.648-8.178 8.648c0 0-8.364 0.093-8.364-8.082V21.29c0 0 0.234-1.174-1.27-1.174c-1.362 0-1.221 1.174-1.221 1.174V36 c0 0 0.2 10.1 10.9 10.104c10.386 0 10.669-9.675 10.669-10.433V21.243C42.964 21.2 43 20.2 41.7 20.2"></path>      <path class="logo-white-path" d="M20.915 21.431c0 0 0-0.799-0.799-1.127c-0.777-0.321-1.27 0.422-1.457 0.6 l-7.425 10.293c0 0-0.469 0.61-1.034-0.282l-8.13-10.292c0 0-0.517-0.611-1.128-0.423c-0.611 0.189-0.894 0.704-0.846 1.6 L0 44.74c0 0-0.046 1.4 1.3 1.363s1.316-1.222 1.316-1.222V25.144l7.002 9.023c0 0 1.1 1.5 2.209-0.188 c1.081-1.646 6.626-8.882 6.626-8.882v19.736c0 0-0.088 1.3 1.5 1.175c1.175-0.094 0.988-1.22 0.988-1.22V21.431z"></path>      <path class="logo-white-path" d="M168.546 43.734l-10.309-6.813c0 0 8.648-0.179 8.648-8.471 c0-8.294-8.531-8.118-8.531-8.118h-8.412c-2.107 0-1.953 1.6-1.953 1.6v22.69c0 0-0.038 1.5 1.1 1.5 c1.265 0 1.222-1.436 1.222-1.436V22.702h6.516c0.474 0 3.1 0 5.3 1.304c2.192 1.3 3.7 7.198-0.177 9.6 c-2.785 1.717-6.459 1.008-7.642 0.889c-1.185-0.12-1.306 0.414-1.483 1.186c-0.177 0.8 0.9 1.4 0.9 1.362l13.21 8.5 c0 0 1.4 1.2 2.1 0.18C169.967 44.4 168.5 43.7 168.5 43.7"></path>      <path class="logo-white-path" d="M95.522 19.596c-6.516-0.711-11.492 3.376-11.373 7.8 c0.117 4.4 3 5.7 8.1 6.634c5.096 0.9 7 1.7 7 1.658c2.665 1 2.5 4.3 1 5.9 c-1.423 1.601-4.148 2.558-5.766 2.616c-3.879 0.146-6.052-2.374-6.052-2.374c-0.492-0.407-0.683-1.486-1.69-1.25 c-1.347 0.316-0.296 1.836-0.296 1.836c2.311 3.2 7.2 3.6 7.2 3.554c5.45 0.7 8.648-3.139 8.648-3.139 c2.963-3.852 0.987-8.363-1.976-9.429c-3.17-1.142-6.139-1.234-10.05-2.065c-3.909-0.828-3.495-4.087-3.495-4.087 c0.059-2.37 2.252-5.271 7.643-5.332c5.392-0.059 8.5 3.4 8.5 3.436c1.304 1.4 2.1 0.5 2.133-0.12 c0.06-0.591-0.058-1.183-0.531-1.776C104.121 23.1 102 20.3 95.5 19.6"></path>      <path class="logo-white-path" d="M124.084 20.618c-1.126 0-1.185 1.067-1.185 1.067v15.166h-14.336V21.862 c0 0 0.296-1.42-1.305-1.362c-1.304 0.047-1.067 1.42-1.067 1.42v14.575h-0.889c0 0-1.303-0.06-1.303 1.2 c0 1.3 1.2 1.3 1.2 1.305h1.007v5.746c0 0 0 1.2 1.2 1.243c1.246 0 1.187-1.184 1.187-1.184v-5.984h14.1v6.103 c0 0-0.008 1.1 1.2 1.137c1.226 0 1.269-1.195 1.269-1.195V21.743C125.209 21.7 125.2 20.6 124.1 20.6"></path>      <path class="logo-white-path" d="M86.101 44.016c0 0-10.841-21.504-11.849-23.163c-1.007-1.66-2.072 0-2.072 0 l-8.047 15.604l-2.395 0.015c-0.888 0-0.982 0.633-0.982 1.284c0 1.1 1.1 0.9 1.1 0.929h1.067c0 0-2.447 4.637-2.726 5.3 c-0.355 0.889-0.416 1.5 0.5 1.955c1.008 0.5 1.659-0.77 1.659-0.77l3.436-6.399H80.71l2.903 5.9 c0 0 1 2 2.1 1.305C86.87 45.3 86.1 44 86.1 44 M66.965 36.374l5.984-12.026c0 0 0.296-0.475 0.6 0.1 c0.296 0.5 6 12 6 11.967H66.965z"></path>      <path class="logo-white-path" d="M58.314 34.283c0 0 3.87-1.954 3.87-6.575c0-4.622-4.563-7.199-8.294-7.199 h-6.517c0 0-1.512 0.2-1.512 1.744v10.479h-1.833c0 0-0.799-0.094-0.799 1.271c0 1.1 0.6 1.2 0.6 1.173h2.066v9.447 c0 0-0.046 1.5 1.5 1.48h7.213c0 0 6.016-0.165 6.016-6.837C60.57 35.9 58.3 34.3 58.3 34.3 M48.203 22.7 l6.338-0.005c1.718 0 5.1 1.7 5.1 5.451c0 4.443-5.095 4.501-5.095 4.501h-6.338V22.736z M53.557 43.831h-5.351v-8.748 l6.435-0.008c0.858 0 3.5 0.9 3.5 4.031C58.143 43.7 53.6 43.8 53.6 43.8"></path>      <path class="logo-white-path" d="M146.17 23.033c0 0 1.3 0.1 1.305-1.304c0-1.244-1.305-1.125-1.305-1.125 h-15.818c-2.251 0-2.012 1.717-2.012 1.717V36.54l-1.653 0.009c0 0-1.132 0.229-1.132 1.177c0 1.2 1.1 1.4 1.1 1.361h1.669 v4.917c0 2.5 1.7 2.1 1.7 2.073h15.818c0 0 0.9 0 0.889-1.185s-0.95-1.007-0.95-1.007h-14.798v-4.799h15.284 c0 0 0.937-0.177 0.937-1.361c0-1.186-1.125-1.246-1.125-1.246h-15.228V23.033H146.17z"></path>    </g>    <g id="logo-en">      <defs>        <rect height="65.7" width="326.9" x="-55"></rect>      </defs>      <clipPath>        <use overflow="visible" xlink:href="#SVGID_1_"></use>      </clipPath>      <path class="logo-path" d="M41.694 20.162c-1.315 0-1.315 0.987-1.315 0.987l0.094 13.8 c0 0 0.6 8.648-8.178 8.648c0 0-8.364 0.093-8.364-8.082V21.29c0 0 0.234-1.174-1.27-1.174c-1.362 0-1.221 1.174-1.221 1.174V36 c0 0 0.2 10.1 10.9 10.104c10.386 0 10.669-9.675 10.669-10.433V21.243C42.964 21.2 43 20.2 41.7 20.2"></path>      <path class="logo-path" d="M20.915 21.431c0 0 0-0.799-0.799-1.127c-0.777-0.321-1.27 0.422-1.457 0.6 l-7.425 10.293c0 0-0.469 0.61-1.034-0.282l-8.13-10.292c0 0-0.517-0.611-1.128-0.423c-0.611 0.189-0.894 0.704-0.846 1.6 L0 44.74c0 0-0.046 1.4 1.3 1.363s1.316-1.222 1.316-1.222V25.144l7.002 9.023c0 0 1.1 1.5 2.209-0.188 c1.081-1.646 6.626-8.882 6.626-8.882v19.736c0 0-0.088 1.3 1.5 1.175c1.175-0.094 0.988-1.22 0.988-1.22V21.431z"></path>      <path class="logo-path" d="M168.546 43.734l-10.309-6.813c0 0 8.648-0.179 8.648-8.471 c0-8.294-8.531-8.118-8.531-8.118h-8.412c-2.107 0-1.953 1.6-1.953 1.6v22.69c0 0-0.038 1.5 1.1 1.5 c1.265 0 1.222-1.436 1.222-1.436V22.702h6.516c0.474 0 3.1 0 5.3 1.304c2.192 1.3 3.7 7.198-0.177 9.6 c-2.785 1.717-6.459 1.008-7.642 0.889c-1.185-0.12-1.306 0.414-1.483 1.186c-0.177 0.8 0.9 1.4 0.9 1.362l13.21 8.5 c0 0 1.4 1.2 2.1 0.18C169.967 44.4 168.5 43.7 168.5 43.7"></path>      <path class="logo-path" d="M95.522 19.596c-6.516-0.711-11.492 3.376-11.373 7.8 c0.117 4.4 3 5.7 8.1 6.634c5.096 0.9 7 1.7 7 1.658c2.665 1 2.5 4.3 1 5.9 c-1.423 1.601-4.148 2.558-5.766 2.616c-3.879 0.146-6.052-2.374-6.052-2.374c-0.492-0.407-0.683-1.486-1.69-1.25 c-1.347 0.316-0.296 1.836-0.296 1.836c2.311 3.2 7.2 3.6 7.2 3.554c5.45 0.7 8.648-3.139 8.648-3.139 c2.963-3.852 0.987-8.363-1.976-9.429c-3.17-1.142-6.139-1.234-10.05-2.065c-3.909-0.828-3.495-4.087-3.495-4.087 c0.059-2.37 2.252-5.271 7.643-5.332c5.392-0.059 8.5 3.4 8.5 3.436c1.304 1.4 2.1 0.5 2.133-0.12 c0.06-0.591-0.058-1.183-0.531-1.776C104.121 23.1 102 20.3 95.5 19.6"></path>      <path class="logo-path" d="M124.084 20.618c-1.126 0-1.185 1.067-1.185 1.067v15.166h-14.336V21.862 c0 0 0.296-1.42-1.305-1.362c-1.304 0.047-1.067 1.42-1.067 1.42v14.575h-0.889c0 0-1.303-0.06-1.303 1.2 c0 1.3 1.2 1.3 1.2 1.305h1.007v5.746c0 0 0 1.2 1.2 1.243c1.246 0 1.187-1.184 1.187-1.184v-5.984h14.1v6.103 c0 0-0.008 1.1 1.2 1.137c1.226 0 1.269-1.195 1.269-1.195V21.743C125.209 21.7 125.2 20.6 124.1 20.6"></path>      <path class="logo-path" d="M86.101 44.016c0 0-10.841-21.504-11.849-23.163c-1.007-1.66-2.072 0-2.072 0 l-8.047 15.604l-2.395 0.015c-0.888 0-0.982 0.633-0.982 1.284c0 1.1 1.1 0.9 1.1 0.929h1.067c0 0-2.447 4.637-2.726 5.3 c-0.355 0.889-0.416 1.5 0.5 1.955c1.008 0.5 1.659-0.77 1.659-0.77l3.436-6.399H80.71l2.903 5.9 c0 0 1 2 2.1 1.305C86.87 45.3 86.1 44 86.1 44 M66.965 36.374l5.984-12.026c0 0 0.296-0.475 0.6 0.1 c0.296 0.5 6 12 6 11.967H66.965z"></path>      <path class="logo-path" d="M58.314 34.283c0 0 3.87-1.954 3.87-6.575c0-4.622-4.563-7.199-8.294-7.199 h-6.517c0 0-1.512 0.2-1.512 1.744v10.479h-1.833c0 0-0.799-0.094-0.799 1.271c0 1.1 0.6 1.2 0.6 1.173h2.066v9.447 c0 0-0.046 1.5 1.5 1.48h7.213c0 0 6.016-0.165 6.016-6.837C60.57 35.9 58.3 34.3 58.3 34.3 M48.203 22.7 l6.338-0.005c1.718 0 5.1 1.7 5.1 5.451c0 4.443-5.095 4.501-5.095 4.501h-6.338V22.736z M53.557 43.831h-5.351v-8.748 l6.435-0.008c0.858 0 3.5 0.9 3.5 4.031C58.143 43.7 53.6 43.8 53.6 43.8"></path>      <path class="logo-path" d="M146.17 23.033c0 0 1.3 0.1 1.305-1.304c0-1.244-1.305-1.125-1.305-1.125 h-15.818c-2.251 0-2.012 1.717-2.012 1.717V36.54l-1.653 0.009c0 0-1.132 0.229-1.132 1.177c0 1.2 1.1 1.4 1.1 1.361h1.669 v4.917c0 2.5 1.7 2.1 1.7 2.073h15.818c0 0 0.9 0 0.889-1.185s-0.95-1.007-0.95-1.007h-14.798v-4.799h15.284 c0 0 0.937-0.177 0.937-1.361c0-1.186-1.125-1.246-1.125-1.246h-15.228V23.033H146.17z"></path>    </g>  </defs></svg>  <!--<script type="text/javascript" xmlns:th="http://www.thymeleaf.org" th:fragment="body">-->  <!--(function () {-->    <!--var em = document.createElement(\'script\');-->    <!--em.type = \'text/javascript\';-->    <!--em.async = true;-->    <!--em.src =-->      <!--(\'https:\' == document.location.protocol ? \'https://me-ssl\' : \'http://me-cdn\') + \'.effectivemeasure.net/em.js\';-->    <!--var s = document.getElementsByTagName(\'script\')[0];-->    <!--s.parentNode.insertBefore(em, s);-->  <!--}());--><!--</script>-->  <div class="">    <header class="header">      <!-- DESKTOP ADS BLOCK -->      <!-- DESKTOP ADS BLOCK -->      <!-- MOBILE ADS BLOCK -->                  <!-- MOBILE ADS BLOCK -->      <div class="header__top-for-mobile">        <div class="top-bar__triggers">          <a class="main-menu-trigger fa fa-bars fa-2x" href="#main-menu" style="float: right;"></a>          <!-- Logo -->          <div class="header__logo header-logo-margins" onclick="window.location.href=\'/countries/sa\'">              <svg viewBox="0 0 494.387 190.555">    <use xlink:href="#logo-white"></use>  </svg>            </div>          <a class="countries-menu-trigger header-country-margins" href="#countries-menu">            <span>السعودية</span>            <span class="fa fa-caret-down fa-4x"></span>          </a>          <!-- ngRepeat: image in images --><img ng-repeat="image in images" src="/assets/ui/images/mobile-logo-G20.png" class="ng-scope"><!-- end ngRepeat: image in images --><img ng-repeat="image in images" src="/assets/ui/images/mobile-logo-vision.png" class="ng-scope"><!-- end ngRepeat: image in images -->          <div class="header__left-side left-search-icon">            <a class="search-trigger js-search-trigger fa fa-search fa-2x" href="javascript:;" style="float: left;">            </a>          </div>        </div>        <!-- Search -->        <div class="search js-search" id="search">          <i class="fa fa-search fa-2x search__icon"></i>          <angucomplete-alt id="autocomplete__companies" input-class="search__input" minlength="1" ng-controller="AutocompleteController" pause="400" placeholder="اكتب كلمة البحث أو رمز الشركة" selected-object="selectItem" text-no-results="عفواً, لم يتم العثور على أي نتائج" text-searching="جارٍ البحث..." title-field="label" remote-url="/api/1/companySearch?query=" class="ng-scope ng-isolate-scope"><div class="angucomplete-holder" ng-class="{\'angucomplete-dropdown-visible\': showDropdown}">  <input id="autocomplete__companies_value" ng-model="searchStr" ng-disabled="disableInput" type="" placeholder="اكتب كلمة البحث أو رمز الشركة" maxlength="524288" ng-focus="onFocusHandler()" class="search__input ng-valid-maxlength" ng-blur="hideResults($event)" autocapitalize="off" autocorrect="off" autocomplete="off" ng-change="inputChangeHandler(searchStr)">  <div id="autocomplete__companies_dropdown" class="angucomplete-dropdown ng-hide" ng-show="showDropdown"><div class="angucomplete-searching ng-hide" ng-show="searching"><div class="spinner"><div class="dot1"></div><div class="dot2"></div></div></div>    <div class="angucomplete-searching ng-binding" ng-show="!searching &amp;&amp; (!results || results.length == 0)" ng-bind="textNoResults">عفواً, لم يتم العثور على أي نتائج</div>    <!-- ngRepeat: result in results -->  </div></div></angucomplete-alt>        </div>      </div>      <div class="header-desktop mi-show-for-large-up">        <div class="header__top-for-desktop">          <div class="header__top-for-desktop-row">            <a class="header__other-site" href="http://tawasul.mubasher.info/" target="_blank">              <i class="fa fa-caret-right fa-2x"></i>              تواصل            </a>            <a class="header__other-site" href="http://magazine.mubasher.info/" target="_blank">              <i class="fa fa-caret-right fa-2x"></i>              مجلة مباشر            </a>            <a class="header__other-site" href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">              <i class="fa fa-play-circle"></i>              <div style="direction: ltr; display: inline-block;">TV مباشر</div>            </a>                        <a class="header__other-site" href="/contact">              <i class="fa fa-envelope"></i>              اتصل بنا            </a>            <a class="header__other-site" href="/advertise">              <i class="fa fa-envelope"></i>              اعلن معنا            </a>            <!-- <a th:if="${#locale.getLanguage() == \'ar\'}" class="header__login-button" style="background: #458D37 !important;" th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank"                th:text="#{components.header.decypha}">ديسيفا</a>            <a th:if="${#locale.getLanguage() == \'en\'}" class="header__login-button" style="background: #458D37 !important; font-family: Roboto,sans-serif !important;" th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank"                th:text="#{components.header.decypha}">ديسيفا</a> -->            <!-- Page Content Buttons -->            <a class="header__login-button" ng-click="decypha(\'decypha\')" style="background: #458D37 !important; font-family: Roboto,sans-serif !important;">ديسيفا</a>            <!-- Page Content Button -->            <!--Add according to MFP-187-->            <a class="header__login-button" style="background: #00c2d6 !important;" target="_blank" href="https://contest.mubasher.info/#/home">المستثمر اﻷول</a>                        <style>              /*.pulse-logo{*/              /*display: inline-block;*/              /*width: 252px;*/              /*height: 100%;*/              /*background: #212121 url(../images/pulse-logo.png) no-repeat center 2px;*/              /*padding: 10px 50px 29px;*/              /*text-align: center;*/              /*color: black;*/              /*text-decoration: none;*/              /*margin-top: -6px;*/              /*}*/              .pulse-logo2{                padding: 5px 5px 4px;                min-width: 82px;                min-height: 21px;                max-width: 27%;              }            </style>            <a target="_blank" href="https://pulse.mubasher.info">              <img class="pulse-logo2" src="../../../images/pulse-logo.png">            </a>            <span class="header__spacer">              &nbsp;            </span>            <a class="header__social-link" target="_blank" href="https://twitter.com/mubasher"><i class="fa fa-twitter fa-lg"></i></a>            <a class="header__social-link" href="https://www.facebook.com/Mubasher.Info"><i class="fa fa-facebook fa-lg"></i></a>            <a class="header__social-link" href="https://www.youtube.com/channel/UC7hnxb7gD4nKZdZk3ZlZCYg">              <i class="fa fa-youtube fa-lg"></i>            </a>            <a class="header__social-link" href="https://www.linkedin.com/company/1477149">              <i class="fa fa-linkedin fa-lg"></i>            </a>            <a class="header__social-link" href="/news/rss"><i class="fa fa-rss fa-lg"></i></a>            <a class="header__social-link" href="https://play.google.com/store/apps/details?id=net.mis.mubasherinfo">              <i class="fa fa-android fa-lg"></i>            </a>            <a class="header__social-link" href="https://itunes.apple.com/app/imubasher/id494539772?mt=8">              <i class="fa fa-apple fa-lg"></i>            </a>            <a class="header__login-button" href="/account/login">              دخول              <i class="fa fa-user fa-lg"></i>            </a>                                    <a class="header__language" href="https://english.mubasher.info">              <span>ENGLISH</span>            </a>          </div>        </div>        <div class="header__columns">          <div class="header__column1">            <!-- Logo -->            <div class="header__logo-wrapper">              <div class="header__logo" onclick="window.location.href=\'/countries/sa\'">                  <svg viewBox="0 0 494.387 190.555">    <use xlink:href="#logo"></use>  </svg>                </div>              <div class="countries-menu-trigger">                <a href="javascript:;" id="mi-js-countries-menu-trigger">                  <span>السعودية</span>                  <span class="fa fa-caret-down"></span>                </a>                <nav class="header__countries-menu--desktop mi-js-countries-menu-desktop" style="">                  <ul>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=ae&amp;url=/countries/sa/companies">الإمارات</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=bh&amp;url=/countries/sa/companies">البحرين</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=om&amp;url=/countries/sa/companies">عُمان</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=qa&amp;url=/countries/sa/companies">قطر</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=kw&amp;url=/countries/sa/companies">الكويت</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=eg&amp;url=/countries/sa/companies">مصر</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=jo&amp;url=/countries/sa/companies">الأردن</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=tn&amp;url=/countries/sa/companies">تونس</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=ma&amp;url=/countries/sa/companies">المغرب</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=ps&amp;url=/countries/sa/companies">فلسطين</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=iq&amp;url=/countries/sa/companies">العراق</a>                    </li>                  </ul>                </nav>              </div>            </div>            <!--Market Status -->            <div class="header__market-status">              <div class="header__market-status-column">                <div class="header__market-status-row">                  <a class="header__market-name" href="/markets/TDWL">TDWL</a>                  <span class="header__market-status--close">مغلق</span>                </div>                              </div>              <span class="header__market-time">12 أغسطس 04:49 م</span>            </div>          </div>          <div class="header__column1 banner-logo-desktop" ng-class="{\'banner-desktop-en\':(getLanguage == \'en\')}">            <!-- Logo -->            <div class="header__logo-wrapper">              <!-- ngRepeat: image in images --><div class="header__logo ng-scope" ng-repeat="image in images">                  <div class="tooltip tooltipstered"><img src="/assets/ui/images/logo-G20.png">                    <span class="tooltiptext ng-binding" ng-class="{\'tooltip-desktop-en\':(getLanguage == \'en\')}" style="left: 95%">مجموعة العشرين 2020</span>                  </div>              </div><!-- end ngRepeat: image in images --><div class="header__logo ng-scope" ng-repeat="image in images">                  <div class="tooltip tooltipstered"><img src="/assets/ui/images/logo-vision.png">                    <span class="tooltiptext ng-binding" ng-class="{\'tooltip-desktop-en\':(getLanguage == \'en\')}" style="left: 95%">رؤية المملكة العربية السعودية 2030</span>                  </div>              </div><!-- end ngRepeat: image in images -->            </div>          </div><!--          <div class="header__column2">             &lt;!&ndash;<div th:replace="components/ads/news/dfp/desktop/LB2"/>&ndash;&gt;            &lt;!&ndash;=====to display default leaderboard ad-slot [728,90] ======&ndash;&gt;            <div th:if="${isHomePage}">              <div th:replace="components/ads/home/leaderboard"/>            </div>            <div th:unless="${isHomePage}">              <div>                <iframe id="leaderboard-ros-001" style="width: 736px; height: 108px;" class="ad-iframe" src="/ads/LB2"></iframe>              </div>            </div>            </div>-->           <!--======= billboard 790x250 ============ -->        </div>        <nav class="header__navigation mi-js-desktop-menu-container">          <ul class="dl-menu mi-show-for-large-up mi-js-desktop-menu">            <li class="dl-menu__menu-item dl-menu__menu-item--iconic-item">              <a href="/countries/sa">                <i class="fa fa-home fa-2x"></i>              </a>            </li>            <li class="dl-menu__menu-item" id="markets">              <a href="javascript:;">الأسواق</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/markets/TDWL">سوق الأسهم السعودي</a>                    </li>                    <li>                      <a href="/markets/EGX">البورصة المصرية</a>                    </li>                    <li>                      <a href="/markets/DFM">سوق دبي المالي</a>                    </li>                    <li>                      <a href="/markets/ADX">سوق أبوظبي</a>                    </li>                    <li>                      <a href="/markets/BB">بورصة البحرين</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/markets/QE">بورصة قطر</a>                    </li>                    <li>                      <a href="/markets/MSM">سوق مسقط</a>                    </li>                    <li>                      <a href="/markets/BK">سوق الكويت</a>                    </li>                    <li>                      <a href="/markets/ASE">بورصة عمان</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/markets/CSE">سوق الدار البيضاء</a>                    </li>                    <li>                      <a href="/markets/BDT">بورصة تونس</a>                    </li>                    <li>                      <a href="/markets/PEX">سوق فلسطين</a>                    </li>                    <li>                      <a href="/markets/ISX">سوق العراق</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/international-indices">مؤشرات الأسواق العالمية</a>                    </li>                    <li>                      <a href="/markets/commodities-prices">أسعار المعادن والطاقة</a>                    </li>                    <li>                      <a href="/countries/sa/currencies">أسعار العملات</a>                    </li>                    <!--<li>                      <a th:href="${@url.to(\'RMPC#regionalMap\')}"                         th:text="#{navigation.markets.regional-map}"/>                    </li>-->                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item" id="news">              <a href="javascript:;">الأخبار</a>              <div class="mi-js-submenu">                <ul class="dl-submenu">                  <li>                    <a href="javascript:;">يحدث الآن</a>                    <div class="nav-column">                      <h3>يحدث الآن</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/sa/now/top">أهم الأخبار</a>                        </li>                        <li>                          <a href="/news/sa/now/exclusive">حصرياً مباشر</a>                        </li>                        <li>                          <a href="/news/sa/now/latest">آخر الأخبار</a>                        </li>                                                  <li>                            <a href="/news/sa/now/announcements">إعلانات السوق</a>                          </li>                                                                          <li class="global__hide-for-ltr">                          <a href="/news/sa/now/popular">منتشر الآن</a>                        </li>                        <li>                          <a href="/news/sa/now/trending/">الأكثر مشاركة</a>                        </li>                        <li>                          <a href="/news/now/news-releases">بيانات صحفية</a>                        </li>                        <li>                          <a href="/news/international/misc">أخبار منوعة</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">نبض السوق</a>                    <div class="nav-column">                      <h3>نبض السوق</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/sa/pulse/stocks">أخبار الأسهم</a>                        </li>                        <li>                          <a href="/news/sa/pulse/analysis">تحليلات إخبارية</a>                        </li>                        <li>                          <a href="/news/sa/pulse/local">اقتصاد محلي</a>                        </li>                        <li>                          <a href="/news/sa/pulse/recommendations">توصيات</a>                        </li>                      </ul>                      <h3>أخبار القطاعات</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/sa/category/banking">بنوك</a>                        </li><li>                          <a href="/news/sa/category/realEstate">عقارات</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">أخبار الدول</a>                    <div class="nav-column">                      <h3>أخبار الدول</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/eg/now/latest">مصر</a>                        </li>                        <li>                          <a href="/news/sa/now/latest">السعودية</a>                        </li>                        <li>                          <a href="/news/ae/now/latest">الإمارات</a>                        </li>                        <li>                          <a href="/news/bh/now/latest">البحرين</a>                        </li>                        <li>                          <a href="/news/qa/now/latest">قطر</a>                        </li>                        <li>                          <a href="/news/om/now/latest">عمان</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">أخبار الدول</a>                    <div class="nav-column">                      <h3 class="invisible">أخبار الدول</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/kw/now/latest">الكويت</a>                        </li>                        <li>                          <a href="/news/jo/now/latest">الأردن</a>                        </li>                        <li>                          <a href="/news/ma/now/latest">المغرب</a>                        </li>                        <li>                          <a href="/news/tn/now/latest">تونس</a>                        </li>                        <li>                          <a href="/news/ps/now/latest">فلسطين</a>                        </li>                        <li>                          <a href="/news/iq/now/latest">العراق</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">أخبار إقليمية</a>                    <div class="nav-column">                      <h3>أخبار إقليمية</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/regions/gulf">الخليج</a>                        </li>                        <li>                          <a href="/news/regions/levant">الشام</a>                        </li>                        <li>                          <a href="/news/regions/north-africa">شمال أفريقيا</a>                        </li>                        <li>                          <a href="/news/regions/middle-east">الشرق الأوسط</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">أخبار عالمية</a>                    <div class="nav-column">                      <h3>أخبار عالمية</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/international/global-economy">اقتصاد عالمى</a>                        </li>                        <li>                          <a href="/news/international/goods-and-metals">أحداث عالمية</a>                        </li>                        <li>                          <a href="/news/international/global-indices">مؤشرات عالمية</a>                        </li>                        <li>                          <a href="/news/international/oil-and-energy">نفط ومعادن</a>                        </li>                        <li>                          <a href="/news/international/currencies">عملات</a>                        </li>                        <li>                          <a href="/news/international/global-reports">تقارير عالمية</a>                        </li>                      </ul>                    </div>                  </li>                </ul>              </div>            </li>            <li class="dl-menu__menu-item" id="companies">              <a href="javascript:;">الشركات</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <h3 class="invisible">.</h3>                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/companies">الشركات المدرجة</a>                    </li>                    <li>                      <a href="/countries/sa/events">مفكرة الشركات</a>                    </li>                    <li>                      <a href="/countries/sa/stock-prices">أسعار الأسهم</a>                    </li>                    <li>                      <a href="/countries/sa/fair-values">القيم العادلة</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <h3 class="invisible">.</h3>                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/earnings">إعلانات الأرباح</a>                    </li>                    <li>                      <a href="/countries/sa/corporate-action">الإجراءات</a>                    </li>                                        <li>                      <a href="/countries/sa/major-shareholders">كبار الملاك</a>                    </li>                    <li>                      <a href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <h3>الاكتتابات</h3>                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/ipos">قائمة الإكتتابات</a>                    </li>                    <li>                      <a href="/ipo/list">بحث فى الاكتتابات</a>                    </li>                    <li>                      <a href="/ipos/news">أخبار الاكتتابات</a>                    </li>                    <li>                      <a href="/ipo/calendar">مفكرة الاكتتابات</a>                    </li>                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item" id="funds">              <a href="javascript:;">صناديق الاستثمار</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/funds">صناديق الاستثمار</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/funds-statistics">إحصائيات الصناديق</a>                    </li>                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item" id="analysis-tools">              <a href="javascript:;">أدوات التحليل</a>              <!-- If current country has one market only -->              <div class="mi-js-submenu">                                  <div class="nav-column">                    <ul class="dl-submenu">                      <li>                        <a href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>                      </li>                      <li>                        <a href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>                      </li>                      <li>                        <a href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>                      </li>                    </ul>                  </div>                  <div class="nav-column">                    <ul class="dl-submenu">                      <li>                        <a href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>                      </li>                      <li>                        <a href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>                      </li>                      <li>                        <a href="/analysis-tools/performance-comparison">مقارنة الأداء</a>                      </li>                    </ul>                  </div>                                              </div>            </li>            <li class="dl-menu__menu-item" id="islamic-economy">              <a href="/news/islamic-finance">الاقتصاد الإسلامي</a>            </li>            <!--<li id="radio"                class="dl-menu__menu-item global__hide-for-ltr"                id="radio"                th:if="${#locale.getLanguage() == \'ar\'}">              <a href="javascript:;" th:text="#{navigation.radio}"/>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a th:href="${@url.to(\'RPC#live\')}" th:text="#{navigation.radio.live}"/>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#latestEpisodesPage\', countryCode)}">آخر الحلقات</a>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تقارير-اقتصادية\'}">تقارير                        اقتصادية</a>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تغطية-خاصة\'}">تغطية خاصة</a>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'مقالات\'}">مقالات</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a th:href="${@url.to(\'RPC#programs\')}" th:text="#{navigation.radio.programs}"/>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#videoPrograms\')}" th:text="#{navigation.radio.videoPrograms}"/>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#getExperts\')}">ضيوفنا</a>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#getPresenters\')}">المذيعون</a>                    </li>                  </ul>                </div>              </div>            </li>-->            <li class="dl-menu__menu-item global__hide-for-ltr" id="video">              <a href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">مباشر TV</a>            </li>                        <li class="dl-menu__menu-item" id="fixedincome">              <a href="javascript:;">السندات</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/fixedincome/bond/search" id="fixedIncomeBondScreener">بحث عن سندات</a>                    </li>                    <li>                      <a href="/fixed-income/news" id="fixedIncomeNews">أخبار السندات وأذون الخزانة</a>                    </li>                    <li>                      <a href="/fixedincome/calendar/searchForEvent" id="fixedIncomeCalendar">قائمة الأحداث</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/fixedincome/analytics/drawCurve" id="fixedIncomeAnalytics">تحليلات فنية</a>                    </li>                    <li>                      <a href="/fixedincome/leagueTables/view" id="fixedIncomeLeagueTables">جداول الديون</a>                    </li>                    <li>                      <a href="/fixedincome/research/search" id="fixedIncomeProspectus">تقارير</a>                    </li>                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item" id="personal">              <a href="javascript:;">شخصي</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/my/alerts">التنبيهات</a>                    </li>                    <li>                      <a href="/my/watch-list">أسهمي</a>                    </li>                    <li>                      <a href="/my/newsletters">النشرة البريدية</a>                    </li>                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item dl-menu__menu-item--iconic-item">              <a class="js-search-trigger" href="javascript:;">                <i class="fa fa-search fa-2x"></i>              </a>            </li>          </ul>          <!-- Search -->          <div class="search js-search js-desktop-search" id="search">            <angucomplete-alt id="autocomplete__companies" input-class="search__input" minlength="1" ng-controller="AutocompleteController" pause="400" selected-object="selectItem" text-no-results="عفواً, لم يتم العثور على أي نتائج" text-searching="جارٍ البحث..." title-field="label" remote-url="/api/1/companySearch?query=" placeholder="اكتب كلمة البحث أو رمز الشركة" class="ng-scope ng-isolate-scope"><div class="angucomplete-holder" ng-class="{\'angucomplete-dropdown-visible\': showDropdown}">  <input id="autocomplete__companies_value" ng-model="searchStr" ng-disabled="disableInput" type="" placeholder="اكتب كلمة البحث أو رمز الشركة" maxlength="524288" ng-focus="onFocusHandler()" class="search__input ng-valid-maxlength" ng-blur="hideResults($event)" autocapitalize="off" autocorrect="off" autocomplete="off" ng-change="inputChangeHandler(searchStr)">  <div id="autocomplete__companies_dropdown" class="angucomplete-dropdown ng-hide" ng-show="showDropdown"><div class="angucomplete-searching ng-hide" ng-show="searching"><div class="spinner"><div class="dot1"></div><div class="dot2"></div></div></div>    <div class="angucomplete-searching ng-binding" ng-show="!searching &amp;&amp; (!results || results.length == 0)" ng-bind="textNoResults">عفواً, لم يتم العثور على أي نتائج</div>    <!-- ngRepeat: result in results -->  </div></div></angucomplete-alt>            <i class="fa fa-search fa-2x"></i>          </div>        </nav>      </div>    </header>    <div id="Leaderboard">    </div>    <div></div>    <div class="mi-content">      <div>  <!--<div th:replace="components/ads/internal/mobile-banner" />-->  <main class="mi-main-content">      <h1 class="mi-section__title">الشركات المدرجة</h1>  <div class="mi-table-container ng-scope" ng-controller="PagedTableController as table" country="sa" src="/api/1/listed-companies">    <div class="global__table-container md-whiteframe-z1 ng-isolate-scope" st-init="" st-pipe="fetch" st-table="table.data">      <span class="global__no-results ng-hide" ng-show="table.rows.length == 0 &amp;&amp; table.loaded">عفواّ, لم نعثر على أى نتائج</span>      <table class="mi-table" ng-hide="!table.loaded || table.rows.length == 0" style="">        <thead class="mi-table__thead">          <tr class="mi-table__thead-tr">            <th st-ratio="20" style="width: 20%;">الشركة</th>            <th>السهم</th>            <th class="mi-hide-for-small">القطاع</th>                        <th>آخر سعر</th>            <th>نسبة التغيير</th>            <th class="mi-hide-for-small">آخر تحديث</th>          </tr>        </thead>        <tbody class="mi-table__tbody" ng-hide="table.reloading">          <!-- ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/2330/profile" class="ng-binding" href="/markets/TDWL/stocks/2330/profile">المتقدمة</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/2330" class="ng-binding" href="/markets/TDWL/stocks/2330">2330</a>            </td>            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>                        <td class="number ng-binding">53.9</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              1.70%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/2340/profile" class="ng-binding" href="/markets/TDWL/stocks/2340/profile">العبداللطيف</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/2340" class="ng-binding" href="/markets/TDWL/stocks/2340">2340</a>            </td>            <td class="mi-hide-for-small ng-binding">السلع طويلة الاجل</td>                        <td class="number ng-binding">11.3</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.53%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/2320/profile" class="ng-binding" href="/markets/TDWL/stocks/2320/profile">البابطين</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/2320" class="ng-binding" href="/markets/TDWL/stocks/2320">2320</a>            </td>            <td class="mi-hide-for-small ng-binding">السلع الرأسمالية</td>                        <td class="number ng-binding">25.65</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              3.76%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/4230/profile" class="ng-binding" href="/markets/TDWL/stocks/4230/profile">البحر الأحمر</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4230" class="ng-binding" href="/markets/TDWL/stocks/4230">4230</a>            </td>            <td class="mi-hide-for-small ng-binding">إدارة وتطوير العقارات</td>                        <td class="number ng-binding">15.62</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -1.01%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/8030/profile" class="ng-binding" href="/markets/TDWL/stocks/8030/profile">ميدغلف للتأمين</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8030" class="ng-binding" href="/markets/TDWL/stocks/8030">8030</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">24.7</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.16%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/2350/profile" class="ng-binding" href="/markets/TDWL/stocks/2350/profile">كيان السعودية</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/2350" class="ng-binding" href="/markets/TDWL/stocks/2350">2350</a>            </td>            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>                        <td class="number ng-binding">8.53</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.58%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/8020/profile" class="ng-binding" href="/markets/TDWL/stocks/8020/profile">ملاذ للتأمين</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8020" class="ng-binding" href="/markets/TDWL/stocks/8020">8020</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">15</td>            <td class="number ng-binding" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.00%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/8060/profile" class="ng-binding" href="/markets/TDWL/stocks/8060/profile">ولاء</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8060" class="ng-binding" href="/markets/TDWL/stocks/8060">8060</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">18.44</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.97%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/8070/profile" class="ng-binding" href="/markets/TDWL/stocks/8070/profile">الدرع العربي</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8070" class="ng-binding" href="/markets/TDWL/stocks/8070">8070</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">17.76</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.67%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/8080/profile" class="ng-binding" href="/markets/TDWL/stocks/8080/profile">ساب للتكافل</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8080" class="ng-binding" href="/markets/TDWL/stocks/8080">8080</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">23.8</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              1.28%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/8040/profile" class="ng-binding" href="/markets/TDWL/stocks/8040/profile">أليانز إس إف</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8040" class="ng-binding" href="/markets/TDWL/stocks/8040">8040</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">17.76</td>            <td class="number ng-binding" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.00%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/4250/profile" class="ng-binding" href="/markets/TDWL/stocks/4250/profile">جبل عمر</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4250" class="ng-binding" href="/markets/TDWL/stocks/4250">4250</a>            </td>            <td class="mi-hide-for-small ng-binding">إدارة وتطوير العقارات</td>                        <td class="number ng-binding">27</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.37%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/8120/profile" class="ng-binding" href="/markets/TDWL/stocks/8120/profile">إتحاد الخليج</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8120" class="ng-binding" href="/markets/TDWL/stocks/8120">8120</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">14.18</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.28%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/8130/profile" class="ng-binding" href="/markets/TDWL/stocks/8130/profile">الأهلي للتكافل</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8130" class="ng-binding" href="/markets/TDWL/stocks/8130">8130</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">27.6</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.73%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/8100/profile" class="ng-binding" href="/markets/TDWL/stocks/8100/profile">سايكو</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8100" class="ng-binding" href="/markets/TDWL/stocks/8100">8100</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">11.96</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.33%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/8110/profile" class="ng-binding" href="/markets/TDWL/stocks/8110/profile">وفا للتأمين</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8110" class="ng-binding" href="/markets/TDWL/stocks/8110">8110</a>            </td>            <td class="mi-hide-for-small ng-binding"></td>                        <td class="number ng-binding">9.5</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -5.75%            </td>            <td class="mi-hide-for-small ng-binding">11 نوفمبر 2018</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/8140/profile" class="ng-binding" href="/markets/TDWL/stocks/8140/profile">الأهلية</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8140" class="ng-binding" href="/markets/TDWL/stocks/8140">8140</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">10.18</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -1.36%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/8150/profile" class="ng-binding" href="/markets/TDWL/stocks/8150/profile">أسيج</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8150" class="ng-binding" href="/markets/TDWL/stocks/8150">8150</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">23.76</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -1.25%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/2360/profile" class="ng-binding" href="/markets/TDWL/stocks/2360/profile">الفخارية</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/2360" class="ng-binding" href="/markets/TDWL/stocks/2360">2360</a>            </td>            <td class="mi-hide-for-small ng-binding">السلع الرأسمالية</td>                        <td class="number ng-binding">48.4</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              1.15%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/4270/profile" class="ng-binding" href="/markets/TDWL/stocks/4270/profile">طباعة وتغليف</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4270" class="ng-binding" href="/markets/TDWL/stocks/4270">4270</a>            </td>            <td class="mi-hide-for-small ng-binding">الخدمات التجارية والمهنية</td>                        <td class="number ng-binding">14.96</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -1.58%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index -->        </tbody>      </table>      <div ng-show="table.searcing" class="ng-hide">        <span class="global__loading">جارى التصفية, يرجى الإنتظار ...</span>        <div>    <div class="sk-spinner sk-spinner-wave">        <div class="sk-rect1"></div>        <div class="sk-rect2"></div>        <div class="sk-rect3"></div>        <div class="sk-rect4"></div>        <div class="sk-rect5"></div>    </div></div>      </div>      <div ng-hide="table.loaded" class="ng-hide" style="">        <div>    <div class="sk-spinner sk-spinner-wave">        <div class="sk-rect1"></div>        <div class="sk-rect2"></div>        <div class="sk-rect3"></div>        <div class="sk-rect4"></div>        <div class="sk-rect5"></div>    </div></div>      </div>      <div st-items-by-page="20" st-pagination="" st-template="/assets/ui/ngt/components/pagination/pagination.ng.html" class="ng-isolate-scope"><!-- ngIf: pages.length >= 2 --><div class="pagination ng-scope" ng-if="pages.length >= 2">    <nav role="navigation" aria-label="Pagination">        <ul class="cd-pagination no-space" role="menubar" aria-label="Pagination">            <!-- ngIf: currentPage > 1 --><li ng-if="currentPage > 1" class="ng-scope">                <a ng-click="selectPage(1)">                    <i class="fa fa-angle-double-right fa-lg"></i>                </a>            </li><!-- end ngIf: currentPage > 1 -->            <!-- ngIf: currentPage > 1 --><li class="cd-pagination__button ng-scope" aria-disabled="true" ng-if="currentPage > 1">                <a ng-click="selectPage(currentPage-1)" class="ng-binding">                  <i class="fa fa-lg fa-angle-right"></i>                  السابق                </a>            </li><!-- end ngIf: currentPage > 1 -->            <!-- ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">                <a ng-click="selectPage(page)" class="ng-binding">3</a>            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">                <a ng-click="selectPage(page)" class="ng-binding">4</a>            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope current">                <a ng-click="selectPage(page)" class="ng-binding">5</a>            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">                <a ng-click="selectPage(page)" class="ng-binding">6</a>            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">                <a ng-click="selectPage(page)" class="ng-binding">7</a>            </li><!-- end ngRepeat: page in pages -->            <!-- ngIf: currentPage < numPages --><li class="cd-pagination__button ng-scope" ng-if="currentPage < numPages">                <a ng-click="selectPage(currentPage+1)" href="" class="ng-binding">                  التالي                    <i class="fa fa-angle-left fa-lg"></i>                </a>            </li><!-- end ngIf: currentPage < numPages -->            <!-- ngIf: currentPage < numPages --><li ng-if="currentPage < numPages" class="ng-scope">                <a ng-click="selectPage(numPages)">                    <i class="fa fa-angle-double-left  fa-lg"></i>                </a>            </li><!-- end ngIf: currentPage < numPages -->        </ul>    </nav></div><!-- end ngIf: pages.length >= 2 --></div>    </div>  </div>    <!-- Speakol Widget - Removal IB-51 -->  <!-- <div th:replace="components/ads/common/speakol-one"/> -->  </main>  <aside class="mi-sidebar mi-show-for-large-up">    <!-- Radio component doesn\'t exist in English version -->    <!---->  <!--  <div th:unless="${device.isMobile()}">      <div>        <iframe onload="adjustIframeSize(this);" class="ad-iframe" src="/ads/side-bar"></iframe>      </div>      <script>        function adjustIframeSize(self) {          var index = 0;          var interval = setInterval( function(){            if (index < 3) {              self.style.height=self.contentDocument.body.scrollHeight +10 + \'px\';self.style.width=\'310px\';              index = index + 1;            } else {              clearInterval(interval)            }          }, 1);        }      </script>    </div>-->    <div>    <div class="mi-popular-news news-sidebar-mub md-whiteframe-z1 ng-scope" ng-controller="PopularNewsController as popular">    <h2 class="global__h2--collapsed">الأخبار الأكثر</h2>    <v-tabs active="tabs.active" class="vTabs--secondary ng-isolate-scope" control="tabs">      <!-- ngRepeat: page in popular.pages --><v-tab ng-bind="page.title" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope is-active" role="tab" aria-selected="true" tabindex="0">قراءة</v-tab><!-- end ngRepeat: page in popular.pages --><v-tab ng-bind="page.title" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope" role="tab" aria-selected="false" tabindex="-1">مشاركة</v-tab><!-- end ngRepeat: page in popular.pages -->    </v-tabs>    <v-pages active="tabs.active" class="vPages--default ng-isolate-scope" control="tabs" ng-swipe-left="tabs.next()" ng-swipe-right="tabs.previous()">      <!-- ngRepeat: page in popular.pages --><v-page ng-bind-html="page.content | unsafe" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope is-active" role="tabpanel">        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3680410/%D9%87%D9%8A%D8%A6%D8%A9-%D8%A7%D9%84%D9%86%D9%82%D9%84-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%B5%D8%B1%D9%81-%D8%AF%D8%B9%D9%85-%D8%A7%D9%84%D8%A3%D9%81%D8%B1%D8%A7%D8%AF-%D8%A7%D9%84%D8%B9%D8%A7%D9%85%D9%84%D9%8A%D9%86-%D9%81%D9%8A-%D9%86%D8%B4%D8%A7%D8%B7-%D8%AA%D9%88%D8%AC%D9%8A%D9%87-%D8%A7%D9%84%D9%85%D8%B1%D9%83%D8%A8%D8%A7%D8%AA-%D9%82%D8%B1%D9%8A%D8%A8%D8%A7-/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="فرع تابع لهيئة العامة للنقل السعودية" src="https://static.mubasher.info/File.Story_Image/3e19073c5aca3db54ef2c06eb4bf5ea6/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3680410/%D9%87%D9%8A%D8%A6%D8%A9-%D8%A7%D9%84%D9%86%D9%82%D9%84-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%B5%D8%B1%D9%81-%D8%AF%D8%B9%D9%85-%D8%A7%D9%84%D8%A3%D9%81%D8%B1%D8%A7%D8%AF-%D8%A7%D9%84%D8%B9%D8%A7%D9%85%D9%84%D9%8A%D9%86-%D9%81%D9%8A-%D9%86%D8%B4%D8%A7%D8%B7-%D8%AA%D9%88%D8%AC%D9%8A%D9%87-%D8%A7%D9%84%D9%85%D8%B1%D9%83%D8%A8%D8%A7%D8%AA-%D9%82%D8%B1%D9%8A%D8%A8%D8%A7-/">هيئة النقل السعودية: صرف دعم الأفراد العاملين في نشاط توجيه المركبات قريباً</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3680099/%D8%A7%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D8%B5%D8%AF%D8%B1-%D9%82%D8%B1%D8%A7%D8%B1%D8%A7-%D8%A8%D8%B4%D8%A3%D9%86-%D8%A7%D9%84%D9%85%D8%A8%D8%AA%D8%B9%D8%AB%D9%8A%D9%86/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="وزير التعليم السعودي، حمد بن محمد آل الشيخ، أرشيفية" src="https://static.mubasher.info/File.Story_Image/9e9e9919f67b43d61c15c7fd734289d3/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3680099/%D8%A7%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D8%B5%D8%AF%D8%B1-%D9%82%D8%B1%D8%A7%D8%B1%D8%A7-%D8%A8%D8%B4%D8%A3%D9%86-%D8%A7%D9%84%D9%85%D8%A8%D8%AA%D8%B9%D8%AB%D9%8A%D9%86/">التعليم السعودية تصدر قراراً بشأن المبتعثين</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3680101/%D9%85%D8%AD%D8%AF%D8%AB-%D8%A7%D9%84%D8%B0%D9%87%D8%A8-%D9%8A%D8%AA%D9%87%D8%A7%D9%88%D9%89-93-%D8%AF%D9%88%D9%84%D8%A7%D8%B1%D8%A7-%D8%B9%D9%86%D8%AF-%D8%A7%D9%84%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D9%85%D8%B9-%D9%85%D9%83%D8%A7%D8%B3%D8%A8-%D8%A7%D9%84%D8%A3%D8%B3%D9%87%D9%85/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/caeadbca5bf2481c2d38f04625e51f00/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3680101/%D9%85%D8%AD%D8%AF%D8%AB-%D8%A7%D9%84%D8%B0%D9%87%D8%A8-%D9%8A%D8%AA%D9%87%D8%A7%D9%88%D9%89-93-%D8%AF%D9%88%D9%84%D8%A7%D8%B1%D8%A7-%D8%B9%D9%86%D8%AF-%D8%A7%D9%84%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D9%85%D8%B9-%D9%85%D9%83%D8%A7%D8%B3%D8%A8-%D8%A7%D9%84%D8%A3%D8%B3%D9%87%D9%85/">محدث.. الذهب يتهاوى 93 دولاراً عند التسوية مع مكاسب الأسهم</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3679355/%D8%A7%D9%84%D9%84%D9%8A%D8%B1%D8%A9-%D8%A7%D9%84%D8%AA%D8%B1%D9%83%D9%8A%D8%A9-%D8%AA%D9%87%D8%A8%D8%B7-%D8%A5%D9%84%D9%89-%D9%85%D8%B3%D8%AA%D9%88%D9%89-%D8%AA%D8%A7%D8%B1%D9%8A%D8%AE%D9%8A-%D8%AC%D8%AF%D9%8A%D8%AF/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/1242bfad1995396ce3f6470a3d5584c2/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3679355/%D8%A7%D9%84%D9%84%D9%8A%D8%B1%D8%A9-%D8%A7%D9%84%D8%AA%D8%B1%D9%83%D9%8A%D8%A9-%D8%AA%D9%87%D8%A8%D8%B7-%D8%A5%D9%84%D9%89-%D9%85%D8%B3%D8%AA%D9%88%D9%89-%D8%AA%D8%A7%D8%B1%D9%8A%D8%AE%D9%8A-%D8%AC%D8%AF%D9%8A%D8%AF/">الليرة التركية تهبط إلى مستوى تاريخي جديد</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3679705/%D8%B9%D9%85%D9%84%D8%A9-%D8%A7%D9%84%D8%A8%D9%8A%D8%AA%D9%83%D9%88%D9%8A%D9%86-%D8%AA%D8%B9%D8%A7%D9%88%D8%AF-%D8%A7%D9%84%D8%B5%D8%B9%D9%88%D8%AF-%D8%A3%D8%B9%D9%84%D9%89-12-%D8%A3%D9%84%D9%81-%D8%AF%D9%88%D9%84%D8%A7%D8%B1/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/ab491b6531081c6058fa5b203b6cbecc/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3679705/%D8%B9%D9%85%D9%84%D8%A9-%D8%A7%D9%84%D8%A8%D9%8A%D8%AA%D9%83%D9%88%D9%8A%D9%86-%D8%AA%D8%B9%D8%A7%D9%88%D8%AF-%D8%A7%D9%84%D8%B5%D8%B9%D9%88%D8%AF-%D8%A3%D8%B9%D9%84%D9%89-12-%D8%A3%D9%84%D9%81-%D8%AF%D9%88%D9%84%D8%A7%D8%B1/">عملة البيتكوين تعاود الصعود أعلى 12 ألف دولار</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3679783/%D8%A3%D8%B1%D8%A7%D9%85%D9%83%D9%88-%D8%AA%D8%B1%D9%81%D8%B9-%D8%A3%D8%B3%D8%B9%D8%A7%D8%B1-%D8%A7%D9%84%D8%A8%D9%86%D8%B2%D9%8A%D9%86-%D8%A8%D9%86%D8%AD%D9%88-11-%D8%AD%D8%AA%D9%89-10-%D8%B3%D8%A8%D8%AA%D9%85%D8%A8%D8%B1/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="محطة للتزود بالوقود" src="https://static.mubasher.info/File.Story_Image/cf61a8737c62c57737e53b3677aa2bbc/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3679783/%D8%A3%D8%B1%D8%A7%D9%85%D9%83%D9%88-%D8%AA%D8%B1%D9%81%D8%B9-%D8%A3%D8%B3%D8%B9%D8%A7%D8%B1-%D8%A7%D9%84%D8%A8%D9%86%D8%B2%D9%8A%D9%86-%D8%A8%D9%86%D8%AD%D9%88-11-%D8%AD%D8%AA%D9%89-10-%D8%B3%D8%A8%D8%AA%D9%85%D8%A8%D8%B1/">أرامكو ترفع أسعار البنزين بنحو 11% حتى 10 سبتمبر</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3680546/%D8%A8%D9%803-%D8%B6%D9%88%D8%A7%D8%A8%D8%B7-%D8%A7%D9%84%D8%AA%D9%82%D8%A7%D8%B9%D8%AF-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D9%88%D8%B6%D8%AD-%D8%B7%D8%B1%D9%8A%D9%82%D8%A9-%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D8%A7%D9%84%D9%85%D8%B9%D8%A7%D8%B4-%D9%84%D9%85%D9%88%D8%B8%D9%81%D9%8A-%D8%A7%D9%84%D9%82%D8%B7%D8%A7%D8%B9-%D8%A7%D9%84%D8%B9%D8%A7%D9%85/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="مؤسسة التقاعد السعودية" src="https://static.mubasher.info/File.Story_Image/68cc490a847f0daba3afd0ddbd6d06c8/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3680546/%D8%A8%D9%803-%D8%B6%D9%88%D8%A7%D8%A8%D8%B7-%D8%A7%D9%84%D8%AA%D9%82%D8%A7%D8%B9%D8%AF-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D9%88%D8%B6%D8%AD-%D8%B7%D8%B1%D9%8A%D9%82%D8%A9-%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D8%A7%D9%84%D9%85%D8%B9%D8%A7%D8%B4-%D9%84%D9%85%D9%88%D8%B8%D9%81%D9%8A-%D8%A7%D9%84%D9%82%D8%B7%D8%A7%D8%B9-%D8%A7%D9%84%D8%B9%D8%A7%D9%85/">بـ3 ضوابط.. التقاعد السعودية توضح طريقة تسوية المعاش لموظفي القطاع العام</a>        </div>              </div>        <a class="mi-article-widget__more-button" href="/news/SA/now/popular">      <span>المزيد</span>      <i class="fa fa-chevron-left"></i>    </a>    </v-page><!-- end ngRepeat: page in popular.pages --><v-page ng-bind-html="page.content | unsafe" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope" role="tabpanel">            <a class="mi-article-widget__more-button" href="/news/SA/now/trending/">      <span>المزيد</span>      <i class="fa fa-chevron-left"></i>    </a>    </v-page><!-- end ngRepeat: page in popular.pages -->    </v-pages>  </div>    <div id="MPU">    </div>    </div>    <!-- Speakol Widget - Removal IB-51 -->    <!-- <div th:replace="components/ads/common/speakol-two"/> --><!--    <div th:unless="${device.isMobile()}">      <div th:replace="components/ads/insticator/insticator-widget"/>    </div>-->    <!-- -->    <!-- PS -->    <!--<div th:replace="components/ads/internal/may-like-articles" />-->    <!--<div th:replace="components/ads/internal/second-fold" />-->    <!--    <div th:if="${#locale.getLanguage() == \'ar\'}">          <span class="home__title">راديو مباشر</span>          <div class="internal-radio-carousel-container"></div>        </div>-->  </aside><!--  <div th:replace="components/ads/internal/mobile-fullpage"/>-->  <!--<div th:replace="components/ads/internal/mobile-interstitial"/>--><!--commented out as per Fayoumi\'s request-->  <!--<div th:replace="components/ads/internal/mobile-outstream"/>-->  <!--MFP-228 New Fixed-Replacement-ROS ads--><!--  <div th:replace="components/ads/home/mobile-fixed-replacement"/>  <div th:replace="components/ads/news/dfp/mobile/MPU3"/>--><!--Commented out as per Fayoumi\'s request-->  <!--<div th:replace="components/ads/internal/outstream"/>--><!--  <div th:if="${device.isMobile()}">    <div th:replace="components/ads/dfp/mobile-internal-pages"/>  </div>--><!--  <div th:if="${device.isMobile()}">    <div th:replace="components/ads/insticator/insticator-widget"/>  </div>--> <!-- <div th:replace="components/ads/internal/mobile-above-footer"/>--></div>    </div>    <footer>  <div class="mi-footer">    <div class="mi-show-for-large-up mi-footer__main-menu">      <ul>        <li class="mi-footer__menu-item mi-footer__menu__markets" id="markets">          <div class="mi-footer__menu-level1">الأسواق</div>          <ul>            <h3 class="mi-footer__menu-level2 invisible">الأسواق</h3>            <li>              <a class="mi-footer__menu-level3" href="/markets/TDWL">سوق الأسهم السعودي</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/EGX">البورصة المصرية</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/DFM">سوق دبي المالي</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/ADX">سوق أبوظبي</a>            </li>          </ul>          <ul>            <li>              <a class="mi-footer__menu-level3" href="/markets/BB">بورصة البحرين</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/QE">بورصة قطر</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/MSM">سوق مسقط</a>            </li>          </ul>          <ul>            <li>              <a class="mi-footer__menu-level3" href="/markets/KSE">سوق الكويت</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/ASE">بورصة عمان</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/CSE">سوق الدار البيضاء</a>            </li>          </ul>          <ul>            <li>              <a class="mi-footer__menu-level3" href="/markets/BDT">بورصة تونس</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/PEX">سوق فلسطين</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/ISX">سوق العراق</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/international-indices">مؤشرات الأسواق العالمية</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/commodities-prices">أسعار المعادن والطاقة</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/currencies">أسعار العملات</a>            </li>            <!--<li>              <a class="mi-footer__menu-level3"                 th:href="${@url.to(\'RMPC#regionalMap\')}"                 th:text="#{navigation.markets.regional-map}"/>            </li>-->          </ul>        </li>        <li class="mi-footer__menu-item mi-footer__menu__news" id="news">          <ul>            <div class="mi-footer__menu-level1">الأخبار</div>            <li class="mi-footer__menu__news__submenu">              <h3 class="mi-footer__menu-level2">أخبار الدول</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/eg/now/latest">مصر</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/latest">السعودية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/ae/now/latest">الإمارات</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/bh/now/latest">البحرين</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/qa/now/latest">قطر</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/om/now/latest">عمان</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/kw/now/latest">الكويت</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/jo/now/latest">الأردن</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/ma/now/latest">المغرب</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/tn/now/latest">تونس</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/ps/now/latest">فلسطين</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/iq/now/latest">العراق</a>                </li>              </ul>            </li>            <li class="mi-footer__menu__news__submenu">              <h3 class="mi-footer__menu-level2">أخبار إقليمية</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/regions/gulf">الخليج</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/regions/levant">الشام</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/regions/north-africa">شمال أفريقيا</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/regions/middle-east">الشرق الأوسط</a>                </li>              </ul>              <!-- happening now -->              <h3 class="mi-footer__menu-level2">يحدث الآن</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/top">أهم الأخبار</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/exclusive">حصرياً مباشر</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/latest">آخر الأخبار</a>                </li>                                  <li>                    <a class="mi-footer__menu-level3" href="/news/sa/now/announcements">إعلانات السوق</a>                  </li>                                                  <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/popular">منتشر الآن</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/trending/">الأكثر مشاركة</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/now/news-releases">بيانات صحفية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/misc">أخبار منوعة</a>                </li>              </ul>            </li>            <li class="mi-footer__menu__news__submenu">              <h3 class="mi-footer__menu-level2">نبض السوق</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/stocks">أخبار الأسهم</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/analysis">تحليلات إخبارية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/local">اقتصاد محلي</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/recommendations">توصيات</a>                </li>              </ul>              <h3 class="mi-footer__menu-level2">أخبار القطاعات</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/category/banking">بنوك</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/category/realEstate">عقارات</a>                </li>              </ul>              <h3 class="mi-footer__menu-level2">أخبار عالمية</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/global-economy">اقتصاد عالمى</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/goods-and-metals">أحداث عالمية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/global-indices">مؤشرات عالمية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/oil-and-energy">نفط ومعادن</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/currencies">عملات</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/global-reports">تقارير عالمية</a>                </li>              </ul>            </li>          </ul>        </li>        <li class="mi-footer__menu-item mi-footer__menu__companies" id="companies">          <div class="mi-footer__menu-level1">الشركات</div>          <ul>            <h3 class="mi-footer__menu-level2 invisible">الشركات</h3>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/companies">الشركات المدرجة</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/events">مفكرة الشركات</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/stock-prices">أسعار الأسهم</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/earnings">إعلانات الأرباح</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/fair-values">القيم العادلة</a>            </li>            <li>                          </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/major-shareholders">كبار الملاك</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/ipos">قائمة الإكتتابات</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/ipo/list">بحث فى الاكتتابات</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/ipos/news">أخبار الاكتتابات</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/ipo/calendar">مفكرة الاكتتابات</a>            </li>          </ul>        </li>        <li class="mi-footer__menu-item mi-footer__menu__analysis-tools" id="analysis-tools">          <div class="mi-footer__menu-level1">أدوات التحليل</div>          <!-- If current country has one market only -->                      <ul>              <h3 class="mi-footer__menu-level2 invisible">أدوات التحليل</h3>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/performance-comparison">مقارنة الأداء</a>              </li>            </ul>                    <!-- If current country has more than one markets i.e UAE -->                  </li>      </ul>    </div>    <div class="mi-footer__second-fold">      <div class="mi-footer__column1">        <div class="mi-footer__copyright">          <div class="mi-footer__logo" onclick="window.location.href=\'/countries/sa\'">              <svg viewBox="0 0 494.387 190.555">    <use xlink:href="#logo-white"></use>  </svg>            </div>          <span>جميع الحقوق تعود لشركة مباشر العالمية © 2005 - 2020</span>        </div>        <ul class="mi-footer__links">          <li>            <a href="/s/Terms">اتفاقية الاستخدام</a>          </li>          <li>            <a href="/s/disclaimer">إخلاء المسؤولية</a>          </li>          <li>            <a href="/s/aboutus">من نحن</a>          </li>          <li>            <a href="/contact">اتصل بنا</a>          </li>          <li>            <a href="/advertise">أعلن معنا</a>          </li>          <li>            <a href="http://www.decypha.com/" target="_blank">موقع ديسيفا</a>          </li>          <li>            <a href="/ir-services" target="_blank">خدمات المواقع</a>          </li>          <li>            <a href="/s/Jobs">وظائف</a>          </li>          <li>              <a target="_blank" href="/decypha-packages">ديسيفا</a>          </li>          <li>            <a href="/s/privacy-policy" target="_blank">سياسة الخصوصية</a>          </li>          <!--<li th:if="${#locale.getLanguage() == \'en\'}">            <a href="/s/decypha-financial-intelligence" th:text="#{components.footer.decypha-financial-intelligence}">Decypha Financial Intelligence</a>          </li>-->        </ul>        <div>جميع البيانات متأخرة 15 دقيقة أثناء الجلسة</div>        <div>هذا الموقع مرخص من وزراة الثقافة والإعلام السعودية</div>        <div>رقم التسجيل :ت 1 125 1435</div>      </div>      <div class="mi-footer__column2">        <ul class="mi-footer__social-icons">          <li>            <a target="_blank" href="https://twitter.com/mubasher"><i class="fa fa-twitter fa-2x"></i></a>          </li>          <li>            <a href="https://www.facebook.com/Mubasher.Info"><i class="fa fa-facebook fa-2x"></i></a>          </li>          <li>            <a href="https://www.youtube.com/channel/UC7hnxb7gD4nKZdZk3ZlZCYg"><i class="fa fa-youtube fa-2x"></i></a>          </li>          <li>            <a href="https://www.linkedin.com/company/1477149"><i class="fa fa-linkedin fa-2x"></i></a>          </li>          <li>            <a href="/news/rss"><i class="fa fa-rss fa-2x"></i></a>          </li>          <li>            <a href="https://play.google.com/store/apps/details?id=net.mis.mubasherinfo">              <i class="fa fa-android fa-2x"></i></a>          </li>          <li>            <a href="https://itunes.apple.com/app/imubasher/id494539772?mt=8"><i class="fa fa-apple fa-2x"></i></a>          </li>          </ul></div></div></div></footer>          </div>  <script src="//code.jquery.com/jquery-2.1.4.min.js"></script>  <script src="//ajax.googleapis.com/ajax/libs/angularjs/1.3.15/angular.min.js"></script>  <script src="/assets/ui/lib.min.js"></script>  <script src="/assets/ui/main.min.js"></script>  <div id="mi-js-scripts"></div>  <script>    <!-- Fix menu trigger on android browser4 -->    $(".dl-menu__menu-item").click(function () {      $(this).addClass(".dl-menu-item__hoverd");    });    $(document).ready(function () {      $(\'.tooltip\').tooltipster();      setTimeout(function(){ dataLayer.push({event: "triggerAds"});      console.log("triggerAds");      }, 1000);    });  </script>    <div pg-ng-tooltip=""></div></div>  <!-- Twitter universal website tag code -->  <script>    !function(e,t,n,s,u,a){e.twq||(s=e.twq=function(){s.exe?s.exe.apply(s,arguments):s.queue.push(arguments);    },s.version=\'1.1\',s.queue=[],u=t.createElement(n),u.async=!0,u.src=\'//static.ads-twitter.com/uwt.js\',      a=t.getElementsByTagName(n)[0],a.parentNode.insertBefore(u,a))}(window,document,\'script\');    // Insert Twitter Pixel ID and Standard Event data below    twq(\'init\',\'nyana\');    twq(\'track\',\'PageView\');  </script>  <!-- End Twitter universal website tag code --><div id="mm-blocker" class="mm-slideout"></div></body>' + '<body id="mi" ng-app="app" ng-controller="MainController" class="ar ng-scope" data-gr-c-s-loaded="true"><nav class="header__countries-menu mm-menu mm-offcanvas mm-top mm-front" id="countries-menu"><div class="mm-panel mm-opened mm-current" id="mm-8"><ul class="mm-listview mm-first mm-last">        <li class="header__country-selector__country">          <a href="/change-country?to=ae&amp;url=/countries/sa/companies">الإمارات</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=bh&amp;url=/countries/sa/companies">البحرين</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=om&amp;url=/countries/sa/companies">عُمان</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=qa&amp;url=/countries/sa/companies">قطر</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=kw&amp;url=/countries/sa/companies">الكويت</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=eg&amp;url=/countries/sa/companies">مصر</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=jo&amp;url=/countries/sa/companies">الأردن</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=tn&amp;url=/countries/sa/companies">تونس</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=ma&amp;url=/countries/sa/companies">المغرب</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=ps&amp;url=/countries/sa/companies">فلسطين</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=iq&amp;url=/countries/sa/companies">العراق</a>        </li>      </ul></div></nav><nav class="header__main-menu mm-menu mm-border-full mm-effect-slide-menu mm-effect-zoom-panels mm-pageshadow mm-offcanvas mm-right mm-hasnavbar-top mm-hasnavbar" id="main-menu"><div class="mm-navbar mm-navbar-top mm-hasbtns"><a class="mm-prev mm-btn mm-hidden"></a><a class="mm-title"> </a><a class="mm-close mm-btn" href="#wrapper"></a></div><div class="mm-panel mm-opened mm-current" id="mm-0"><ul class="mm-listview mm-first mm-last">        <li id="markets">          <a class="mm-next mm-fullsubopen" href="#mm-1" data-target="#mm-1"></a><span href="javascript:;">الأسواق</span>                  </li>        <li id="news">          <a class="mm-next mm-fullsubopen" href="#mm-2" data-target="#mm-2"></a><span href="javascript:;">الأخبار</span>                  </li>        <li id="companies">          <a class="mm-next mm-fullsubopen" href="#mm-3" data-target="#mm-3"></a><span href="javascript:;">الشركات</span>                  </li>        <li id="funds">          <a class="mm-next mm-fullsubopen" href="#mm-4" data-target="#mm-4"></a><span href="javascript:;">صناديق الاستثمار</span>                  </li>        <li id="analysis-tool">          <a class="mm-next mm-fullsubopen" href="#mm-5" data-target="#mm-5"></a><span href="javascript:;">أدوات التحليل</span>                  </li>        <li id="islamic-economy">          <a href="/news/islamic-finance">الاقتصاد الإسلامي</a>        </li>        <!--<li class="global__hide-for-ltr" id="radio" th:if="${#locale.getLanguage() == \'ar\'}">          <span th:text="#{navigation.radio}">راديو مباشر</span>          <ul>            <li>              <a th:href="${@url.to(\'RPC#live\')}" th:text="#{navigation.radio.live}"/>            </li>            <li>              <a th:href="${@url.to(\'RPC#latestEpisodesPage\', countryCode)}">آخر الحلقات</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تقارير-اقتصادية\'}">تقارير اقتصادية</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تغطية-خاصة\'}">تغطية خاصة</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'مقالات\'}">مقالات</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#programs\')}" th:text="#{navigation.radio.programs}"/>            </li>            <li>              <a th:href="${@url.to(\'RPC#videoPrograms\')}" th:text="#{navigation.radio.videoPrograms}"/>            </li>            <li>              <a th:href="${@url.to(\'RPC#getExperts\')}">ضيوفنا</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#getPresenters\')}">المذيعون</a>            </li>          </ul>        </li>-->        <li class="global__hide-for-ltr" id="video">          <a href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">مباشر TV</a>        </li>                <li id="fixedincome">          <a class="mm-next mm-fullsubopen" href="#mm-6" data-target="#mm-6"></a><span>السندات</span>                  </li>        <li>          <a class="mm-next mm-fullsubopen" href="#mm-7" data-target="#mm-7"></a><span>شخصي</span>                  </li>        <li>          <a href="http://tawasul.mubasher.info/" target="_blank">تواصل</a>        </li>        <!-- <li>          <a th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank" th:text="#{components.header.decypha}" target="_blank">          </a>        </li> -->        <li>          <a ng-click="decypha(\'decypha\')">ديسيفا</a>        </li>        <!--Add according to MFP-187-->        <li>          <a href="https://contest.mubasher.info/#/home" target="_blank">المستثمر اﻷول</a>        </li>        <li>          <!--Integrating Mubasher Pulse-->        </li><li>        <style>          .pulse-logo2{            padding: 5px 5px 4px;            min-width: 82px;            min-height: 21px;            max-width: 27%;          }        </style>        <a target="_blank" href="https://pulse.mubasher.info">          <img class="pulse-logo2" src="../../../images/pulse-logo.png">        </a>        </li>        <li>        </li><li>          <a href="http://magazine.mubasher.info/" target="_blank">            مجلة مباشر          </a>        </li>        <li class="mm-divider"></li>        <li>          <a href="https://english.mubasher.info">ENGLISH</a>        </li>        <li>                  </li>        <li>          <a class="header__login__text" href="/account/login">دخول</a>                  </li>      </ul></div><div class="mm-panel mm-hidden" id="mm-1"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الأسواق</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/markets/TDWL">سوق الأسهم السعودي</a>            </li>            <li>              <a href="/markets/EGX">البورصة المصرية</a>            </li>            <li>              <a href="/markets/DFM">سوق دبي المالي</a>            </li>            <li>              <a href="/markets/ADX">سوق أبوظبي</a>            </li>            <li>              <a href="/markets/BB">بورصة البحرين</a>            </li>            <li>              <a href="/markets/QE">بورصة قطر</a>            </li>            <li>              <a href="/markets/MSM">سوق مسقط</a>            </li>            <li>              <a href="/markets/BK">سوق الكويت</a>            </li>            <li>              <a href="/markets/ASE">بورصة عمان</a>            </li>            <li>              <a href="/markets/CSE">سوق الدار البيضاء</a>            </li>            <li>              <a href="/markets/BDT">بورصة تونس</a>            </li>            <li>              <a href="/markets/PEX">سوق فلسطين</a>            </li>            <li>              <a href="/markets/ISX">سوق العراق</a>            </li>            <li>              <a href="/international-indices">مؤشرات الأسواق العالمية</a>            </li>            <li>              <a href="/markets/commodities-prices">أسعار المعادن والطاقة</a>            </li>            <li>              <a href="/countries/sa/currencies">أسعار العملات</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-2"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الأخبار</a></div><ul class="mm-listview mm-first mm-last">            <!-- now -->            <li class="mm-divider">يحدث الآن</li>            <li>              <a href="/news/sa/now/top">أهم الأخبار</a>            </li>            <li>              <a href="/news/sa/now/exclusive">حصرياً مباشر</a>            </li>            <li>              <a href="/news/sa/now/latest">آخر الأخبار</a>            </li>                          <li>                <a href="/news/sa/now/announcements">إعلانات السوق</a>              </li>                                      <li class="global__hide-for-ltr">              <a href="/news/sa/now/popular">منتشر الآن</a>            </li>            <li>              <a href="/news/sa/now/trending/">الأكثر مشاركة</a>            </li>            <li>              <a href="/news/now/news-releases">بيانات صحفية</a>            </li><!--            <li>              <a th:href="${@url.to(\'NPC#miscellaneousNews\', countryCode)}"                 th:text="#{navigation.news.now.misc}"/>            </li>-->            <!-- recommendations-->            <li class="mm-divider">نبض السوق</li>            <li>              <a href="/news/sa/pulse/stocks">أخبار الأسهم</a>            </li>            <li>              <a href="/news/sa/pulse/analysis">تحليلات إخبارية</a>            </li>            <li>              <a href="/news/sa/pulse/local">اقتصاد محلي</a>            </li>            <li>              <a href="/news/sa/pulse/recommendations">توصيات</a>            </li>            <li class="mm-divider">أخبار القطاعات</li>            <li>              <a href="/news/sa/category/banking">بنوك</a>            </li>            <li>              <a href="/news/sa/category/realEstate">عقارات</a>            </li>            <li class="mm-divider">أخبار الدول</li>            <li>              <a href="/news/eg/now/latest">مصر</a>            </li>            <li>              <a href="/news/sa/now/latest">السعودية</a>            </li>            <li>              <a href="/news/ae/now/latest">الإمارات</a>            </li>            <li>              <a href="/news/bh/now/latest">البحرين</a>            </li>            <li>              <a href="/news/qa/now/latest">قطر</a>            </li>            <li>              <a href="/news/om/now/latest">عمان</a>            </li>            <li>              <a href="/news/kw/now/latest">الكويت</a>            </li>            <li>              <a href="/news/jo/now/latest">الأردن</a>            </li>            <li>              <a href="/news/ma/now/latest">المغرب</a>            </li>            <li>              <a href="/news/tn/now/latest">تونس</a>            </li>            <li>              <a href="/news/ps/now/latest">فلسطين</a>            </li>            <li>              <a href="/news/iq/now/latest">العراق</a>            </li>            <!-- regions-->            <li class="mm-divider">أخبار إقليمية</li>            <li>              <a href="/news/regions/gulf">الخليج</a>            </li>            <li>              <a href="/news/regions/levant">الشام</a>            </li>            <li>              <a href="/news/regions/north-africa">شمال أفريقيا</a>            </li>            <li>              <a href="/news/regions/middle-east">الشرق الأوسط</a>            </li>            <!-- international -->            <li class="mm-divider">أخبار عالمية</li>            <li>              <a href="/news/international/global-economy">اقتصاد عالمى</a>            </li>            <li>              <a href="/news/international/goods-and-metals">أحداث عالمية</a>            </li>              <li>                <a href="/news/international/global-indices">مؤشرات عالمية</a>              </li>              <li>                <a href="/news/international/oil-and-energy">نفط ومعادن</a>              </li>              <li>                <a href="/news/international/currencies">عملات</a>              </li>              <li>                <a href="/news/international/global-reports">تقارير عالمية</a>              </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-3"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الشركات</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/countries/sa/companies">الشركات المدرجة</a>            </li>            <li>              <a href="/countries/sa/events">مفكرة الشركات</a>            </li>            <li>              <a href="/countries/sa/stock-prices">أسعار الأسهم</a>            </li>            <li>              <a href="/countries/sa/earnings">إعلانات الأرباح</a>            </li>            <li>              <a href="/countries/sa/fair-values">القيم العادلة</a>            </li>            <li>              <a href="/countries/sa/corporate-action">الإجراءات</a>            </li>                        <li>              <a href="/countries/sa/major-shareholders">كبار الملاك</a>            </li>            <li>              <a href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>            </li>            <li class="mm-divider">الاكتتابات</li>            <li>              <a href="/countries/sa/ipos">قائمة الإكتتابات</a>            </li>            <li>              <a href="/ipo/list">بحث فى الاكتتابات</a>            </li>            <li>              <a href="/ipos/news">أخبار الاكتتابات</a>            </li>            <li>              <a href="/ipo/calendar">مفكرة الاكتتابات</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-4"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">صناديق الاستثمار</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/countries/sa/funds">صناديق الاستثمار</a>            </li>            <li>              <a href="/countries/sa/funds-statistics">إحصائيات الصناديق</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-5"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">أدوات التحليل</a></div><ul class="mm-listview mm-first mm-last">                                        <li>                <a href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>              </li>              <li>                <a href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>              </li>              <li>                <a href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>              </li>              <li>                <a href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>              </li>              <li>                <a href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>              </li>                        <li class="mm-divider">            </li>            <li>              <a href="/analysis-tools/performance-comparison">مقارنة الأداء</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-6"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">السندات</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/fixedincome/bond/search" id="fixedIncomeBondScreener">بحث عن سندات</a>            </li>            <li>              <a href="/fixed-income/news" id="fixedIncomeNews">أخبار السندات وأذون الخزانة</a>            </li>            <li>              <a href="/fixedincome/calendar/searchForEvent" id="fixedIncomeCalendar">قائمة الأحداث</a>            </li>            <li>              <a href="/fixedincome/analytics/drawCurve" id="fixedIncomeAnalytics">تحليلات فنية</a>            </li>            <li>              <a href="/fixedincome/leagueTables/view" id="fixedIncomeLeagueTables">جداول الديون</a>            </li>            <li>              <a href="/fixedincome/research/search" id="fixedIncomeProspectus">تقارير</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-7"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">شخصي</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/my/alerts">التنبيهات</a>            </li>            <li>              <a href="/my/watch-list">أسهمي</a>            </li>            <li>              <a href="/my/newsletters">النشرة البريدية</a>            </li>          </ul></div></nav><div class="js-wrapper mm-page mm-slideout" id="wrapper">  <svg class="hidden" version="1.1" viewBox="0 0 0 0" xmlns="http://www.w3.org/2000/svg">  <defs>    <style>      .logo-white-path {        clip-rule: evenodd;        fill-rule: evenodd;        fill: white;        font-size: 46.6299px;        font-family: \'HelveticaNeue\';      }      .logo-path {        clip-rule: evenodd;        fill-rule: evenodd;        fill: #324651;        text-align: center;        font-size: 46.6299px;        font-family: \'HelveticaNeue\';      }    </style>    <g id="logo-white">      <path class="logo-white-path" d="M209.596 29.677c-6.25 0.016-11.243-4.937-11.261-11.188 c-0.018-6.191 5.027-11.29 11.194-11.29c6.182-0.004 11.3 5.1 11.3 11.226C220.852 24.6 215.8 29.7 209.6 29.7"></path>      <path class="logo-white-path" d="M228.308 37.976c6.231-0.01 11.3 5 11.3 11.2 c0.015 6.189-5.011 11.227-11.233 11.252c-6.213 0.025-11.246-4.99-11.271-11.209C217.063 43 222.1 38 228.3 38"></path>      <path class="logo-white-path" d="M350.278 190.471c-6.27-0.009-11.204-4.942-11.197-11.212 c0.013-6.26 4.968-11.18 11.248-11.176c6.242 0 11.3 5 11.2 11.224C361.555 185.5 356.5 190.5 350.3 190.5"></path>      <path class="logo-white-path" d="M186.161 37.976c6.26 0 11.2 5 11.2 11.2 c-0.01 6.241-4.993 11.239-11.209 11.226c-6.257-0.017-11.212-4.99-11.212-11.228C174.949 42.9 179.9 38 186.2 38"></path>      <path class="logo-white-path" d="M455.92 80.125c-21.212 0-38.405 17.191-38.405 38.4 c0 4.3 0.7 8.4 2 12.316l-48.126 0.003l13.9-27.74h-3.242c0 0-2.13 0.019-2.822 0.1 c-2.13 0.126-3.67 0.098-7.926 1.351c-3.949 1.159-7.026 2.719-9.881 4.503c-2.381 1.493-5.863 4.278-8.803 7.7 c-2.912 3.325-5.713 7.695-5.713 7.695l-3.294 6.464l-41.201 0.003L364.7 0l-76.514 49.172l25.429-0.036L260.64 156.919h193.847 c0 0 0.9 0 1.4 0.01c21.212 0 38.4-17.183 38.4-38.403C494.32 97.3 477.1 80.1 455.9 80.125z M455.92 133.3 c-7.998 0-14.48-6.479-14.48-14.47c0-7.998 6.482-14.476 14.48-14.476c7.996 0 14.5 6.5 14.5 14.5 C470.393 126.8 463.9 133.3 455.9 133.327z"></path>      <path class="logo-white-path" d="M269.61 81.427c0 0-1.617 0.013-2.842 0.09c-2.001 0.132-3.655 0.07-7.903 1.3 c-3.946 1.162-7.021 2.722-9.876 4.507c-2.378 1.488-5.868 4.279-8.813 7.662c-2.904 3.327-5.282 8.108-5.282 8.108l-14.116 27.7 h-16.391l19.092-39.485h-3.237c0 0-1.617 0.015-2.835 0.095c-2.012 0.13-3.665 0.068-7.905 1.3 c-3.957 1.161-7.034 2.717-9.892 4.502c-2.373 1.493-5.857 4.28-8.808 7.668c-2.899 3.321-5.282 8.104-5.282 8.104l-8.901 17.8 h-16.959l13.92-27.753h-3.245c0 0-2.141 0.019-2.822 0.057c-2.133 0.126-3.663 0.098-7.926 1.4 c-3.944 1.159-7.026 2.719-9.884 4.503c-2.378 1.493-5.857 4.28-8.808 7.669c-2.904 3.329-5.708 7.695-5.708 7.695l-3.291 6.5 l-52.558-0.005l14.007-27.748h-3.242c0 0-2.131 0.019-2.815 0.057c-2.136 0.126-3.678 0.098-7.934 1.4 c-3.944 1.159-7.021 2.719-9.877 4.503c-2.383 1.493-5.858 4.28-8.813 7.669c-2.906 3.329-5.114 7.843-5.114 7.843l-16.204 31.1 l0 0c0 0-3.136 6.731-7.038 11.469c-3.094 3.766-7.43 6.804-9.757 8.194c-2.313 1.384-7.141 3.645-11.872 4.5 C5.251 180.9 0 180.5 0 180.502s2.33 2.1 5 3.806c2.034 1.4 4.3 2.4 5.5 3 c2.481 1.1 4.3 1.7 6.9 2.253c2.531 0.6 4.8 0.8 4.8 0.763s1.621 0.2 3.2 0.169c0.707 0 1.62-0.024 2.848-0.09 c2.001-0.134 3.5 0 7.904-1.323c4.033-1.188 7.072-2.582 9.92-4.368c2.383-1.478 5.952-4.249 8.904-7.627 c2.907-3.337 5.296-8.019 5.296-8.019l6.043-12.125l169.4 0.009l12.816-26.07l24.302-49.431H269.61z"></path>      <path class="logo-white-path" d="M30.239 76.472V55.626H22.45v-2.789h18.735v2.789h-7.819v20.846H30.239z"></path>      <path class="logo-white-path" d="M44.296 76.472V52.836h4.71l5.592 16.735c0.518 1.6 0.9 2.7 1.1 3.499c0.269-0.861 0.687-2.123 1.258-3.789 l5.658-16.446h4.209v23.636h-3.015V56.689l-6.869 19.783h-2.822l-6.835-20.121v20.121H44.296z"></path>    </g>    <g id="logo">      <path class="logo-path" d="M209.596 29.677c-6.25 0.016-11.243-4.937-11.261-11.188 c-0.018-6.191 5.027-11.29 11.194-11.29c6.182-0.004 11.3 5.1 11.3 11.226C220.852 24.6 215.8 29.7 209.6 29.7"></path>      <path class="logo-path" d="M228.308 37.976c6.231-0.01 11.3 5 11.3 11.2 c0.015 6.189-5.011 11.227-11.233 11.252c-6.213 0.025-11.246-4.99-11.271-11.209C217.063 43 222.1 38 228.3 38"></path>      <path class="logo-path" d="M350.278 190.471c-6.27-0.009-11.204-4.942-11.197-11.212 c0.013-6.26 4.968-11.18 11.248-11.176c6.242 0 11.3 5 11.2 11.224C361.555 185.5 356.5 190.5 350.3 190.5"></path>      <path class="logo-path" d="M186.161 37.976c6.26 0 11.2 5 11.2 11.2 c-0.01 6.241-4.993 11.239-11.209 11.226c-6.257-0.017-11.212-4.99-11.212-11.228C174.949 42.9 179.9 38 186.2 38"></path>      <path class="logo-path" d="M455.92 80.125c-21.212 0-38.405 17.191-38.405 38.4 c0 4.3 0.7 8.4 2 12.316l-48.126 0.003l13.9-27.74h-3.242c0 0-2.13 0.019-2.822 0.1 c-2.13 0.126-3.67 0.098-7.926 1.351c-3.949 1.159-7.026 2.719-9.881 4.503c-2.381 1.493-5.863 4.278-8.803 7.7 c-2.912 3.325-5.713 7.695-5.713 7.695l-3.294 6.464l-41.201 0.003L364.7 0l-76.514 49.172l25.429-0.036L260.64 156.919h193.847 c0 0 0.9 0 1.4 0.01c21.212 0 38.4-17.183 38.4-38.403C494.32 97.3 477.1 80.1 455.9 80.125z M455.92 133.3 c-7.998 0-14.48-6.479-14.48-14.47c0-7.998 6.482-14.476 14.48-14.476c7.996 0 14.5 6.5 14.5 14.5 C470.393 126.8 463.9 133.3 455.9 133.327z"></path>      <path class="logo-path" d="M269.61 81.427c0 0-1.617 0.013-2.842 0.09c-2.001 0.132-3.655 0.07-7.903 1.3 c-3.946 1.162-7.021 2.722-9.876 4.507c-2.378 1.488-5.868 4.279-8.813 7.662c-2.904 3.327-5.282 8.108-5.282 8.108l-14.116 27.7 h-16.391l19.092-39.485h-3.237c0 0-1.617 0.015-2.835 0.095c-2.012 0.13-3.665 0.068-7.905 1.3 c-3.957 1.161-7.034 2.717-9.892 4.502c-2.373 1.493-5.857 4.28-8.808 7.668c-2.899 3.321-5.282 8.104-5.282 8.104l-8.901 17.8 h-16.959l13.92-27.753h-3.245c0 0-2.141 0.019-2.822 0.057c-2.133 0.126-3.663 0.098-7.926 1.4 c-3.944 1.159-7.026 2.719-9.884 4.503c-2.378 1.493-5.857 4.28-8.808 7.669c-2.904 3.329-5.708 7.695-5.708 7.695l-3.291 6.5 l-52.558-0.005l14.007-27.748h-3.242c0 0-2.131 0.019-2.815 0.057c-2.136 0.126-3.678 0.098-7.934 1.4 c-3.944 1.159-7.021 2.719-9.877 4.503c-2.383 1.493-5.858 4.28-8.813 7.669c-2.906 3.329-5.114 7.843-5.114 7.843l-16.204 31.1 l0 0c0 0-3.136 6.731-7.038 11.469c-3.094 3.766-7.43 6.804-9.757 8.194c-2.313 1.384-7.141 3.645-11.872 4.5 C5.251 180.9 0 180.5 0 180.502s2.33 2.1 5 3.806c2.034 1.4 4.3 2.4 5.5 3 c2.481 1.1 4.3 1.7 6.9 2.253c2.531 0.6 4.8 0.8 4.8 0.763s1.621 0.2 3.2 0.169c0.707 0 1.62-0.024 2.848-0.09 c2.001-0.134 3.5 0 7.904-1.323c4.033-1.188 7.072-2.582 9.92-4.368c2.383-1.478 5.952-4.249 8.904-7.627 c2.907-3.337 5.296-8.019 5.296-8.019l6.043-12.125l169.4 0.009l12.816-26.07l24.302-49.431H269.61z"></path>      <path class="logo-path" d="M30.239 76.472V55.626H22.45v-2.789h18.735v2.789h-7.819v20.846H30.239z"></path>      <path class="logo-path" d="M44.296 76.472V52.836h4.71l5.592 16.735c0.518 1.6 0.9 2.7 1.1 3.499c0.269-0.861 0.687-2.123 1.258-3.789 l5.658-16.446h4.209v23.636h-3.015V56.689l-6.869 19.783h-2.822l-6.835-20.121v20.121H44.296z"></path>    </g>    <g id="logo-white-en">      <defs>        <rect height="65.7" width="326.9" x="-55"></rect>      </defs>      <clipPath>        <use overflow="visible" xlink:href="#SVGID_1_"></use>      </clipPath>      <path class="logo-white-path" d="M41.694 20.162c-1.315 0-1.315 0.987-1.315 0.987l0.094 13.8 c0 0 0.6 8.648-8.178 8.648c0 0-8.364 0.093-8.364-8.082V21.29c0 0 0.234-1.174-1.27-1.174c-1.362 0-1.221 1.174-1.221 1.174V36 c0 0 0.2 10.1 10.9 10.104c10.386 0 10.669-9.675 10.669-10.433V21.243C42.964 21.2 43 20.2 41.7 20.2"></path>      <path class="logo-white-path" d="M20.915 21.431c0 0 0-0.799-0.799-1.127c-0.777-0.321-1.27 0.422-1.457 0.6 l-7.425 10.293c0 0-0.469 0.61-1.034-0.282l-8.13-10.292c0 0-0.517-0.611-1.128-0.423c-0.611 0.189-0.894 0.704-0.846 1.6 L0 44.74c0 0-0.046 1.4 1.3 1.363s1.316-1.222 1.316-1.222V25.144l7.002 9.023c0 0 1.1 1.5 2.209-0.188 c1.081-1.646 6.626-8.882 6.626-8.882v19.736c0 0-0.088 1.3 1.5 1.175c1.175-0.094 0.988-1.22 0.988-1.22V21.431z"></path>      <path class="logo-white-path" d="M168.546 43.734l-10.309-6.813c0 0 8.648-0.179 8.648-8.471 c0-8.294-8.531-8.118-8.531-8.118h-8.412c-2.107 0-1.953 1.6-1.953 1.6v22.69c0 0-0.038 1.5 1.1 1.5 c1.265 0 1.222-1.436 1.222-1.436V22.702h6.516c0.474 0 3.1 0 5.3 1.304c2.192 1.3 3.7 7.198-0.177 9.6 c-2.785 1.717-6.459 1.008-7.642 0.889c-1.185-0.12-1.306 0.414-1.483 1.186c-0.177 0.8 0.9 1.4 0.9 1.362l13.21 8.5 c0 0 1.4 1.2 2.1 0.18C169.967 44.4 168.5 43.7 168.5 43.7"></path>      <path class="logo-white-path" d="M95.522 19.596c-6.516-0.711-11.492 3.376-11.373 7.8 c0.117 4.4 3 5.7 8.1 6.634c5.096 0.9 7 1.7 7 1.658c2.665 1 2.5 4.3 1 5.9 c-1.423 1.601-4.148 2.558-5.766 2.616c-3.879 0.146-6.052-2.374-6.052-2.374c-0.492-0.407-0.683-1.486-1.69-1.25 c-1.347 0.316-0.296 1.836-0.296 1.836c2.311 3.2 7.2 3.6 7.2 3.554c5.45 0.7 8.648-3.139 8.648-3.139 c2.963-3.852 0.987-8.363-1.976-9.429c-3.17-1.142-6.139-1.234-10.05-2.065c-3.909-0.828-3.495-4.087-3.495-4.087 c0.059-2.37 2.252-5.271 7.643-5.332c5.392-0.059 8.5 3.4 8.5 3.436c1.304 1.4 2.1 0.5 2.133-0.12 c0.06-0.591-0.058-1.183-0.531-1.776C104.121 23.1 102 20.3 95.5 19.6"></path>      <path class="logo-white-path" d="M124.084 20.618c-1.126 0-1.185 1.067-1.185 1.067v15.166h-14.336V21.862 c0 0 0.296-1.42-1.305-1.362c-1.304 0.047-1.067 1.42-1.067 1.42v14.575h-0.889c0 0-1.303-0.06-1.303 1.2 c0 1.3 1.2 1.3 1.2 1.305h1.007v5.746c0 0 0 1.2 1.2 1.243c1.246 0 1.187-1.184 1.187-1.184v-5.984h14.1v6.103 c0 0-0.008 1.1 1.2 1.137c1.226 0 1.269-1.195 1.269-1.195V21.743C125.209 21.7 125.2 20.6 124.1 20.6"></path>      <path class="logo-white-path" d="M86.101 44.016c0 0-10.841-21.504-11.849-23.163c-1.007-1.66-2.072 0-2.072 0 l-8.047 15.604l-2.395 0.015c-0.888 0-0.982 0.633-0.982 1.284c0 1.1 1.1 0.9 1.1 0.929h1.067c0 0-2.447 4.637-2.726 5.3 c-0.355 0.889-0.416 1.5 0.5 1.955c1.008 0.5 1.659-0.77 1.659-0.77l3.436-6.399H80.71l2.903 5.9 c0 0 1 2 2.1 1.305C86.87 45.3 86.1 44 86.1 44 M66.965 36.374l5.984-12.026c0 0 0.296-0.475 0.6 0.1 c0.296 0.5 6 12 6 11.967H66.965z"></path>      <path class="logo-white-path" d="M58.314 34.283c0 0 3.87-1.954 3.87-6.575c0-4.622-4.563-7.199-8.294-7.199 h-6.517c0 0-1.512 0.2-1.512 1.744v10.479h-1.833c0 0-0.799-0.094-0.799 1.271c0 1.1 0.6 1.2 0.6 1.173h2.066v9.447 c0 0-0.046 1.5 1.5 1.48h7.213c0 0 6.016-0.165 6.016-6.837C60.57 35.9 58.3 34.3 58.3 34.3 M48.203 22.7 l6.338-0.005c1.718 0 5.1 1.7 5.1 5.451c0 4.443-5.095 4.501-5.095 4.501h-6.338V22.736z M53.557 43.831h-5.351v-8.748 l6.435-0.008c0.858 0 3.5 0.9 3.5 4.031C58.143 43.7 53.6 43.8 53.6 43.8"></path>      <path class="logo-white-path" d="M146.17 23.033c0 0 1.3 0.1 1.305-1.304c0-1.244-1.305-1.125-1.305-1.125 h-15.818c-2.251 0-2.012 1.717-2.012 1.717V36.54l-1.653 0.009c0 0-1.132 0.229-1.132 1.177c0 1.2 1.1 1.4 1.1 1.361h1.669 v4.917c0 2.5 1.7 2.1 1.7 2.073h15.818c0 0 0.9 0 0.889-1.185s-0.95-1.007-0.95-1.007h-14.798v-4.799h15.284 c0 0 0.937-0.177 0.937-1.361c0-1.186-1.125-1.246-1.125-1.246h-15.228V23.033H146.17z"></path>    </g>    <g id="logo-en">      <defs>        <rect height="65.7" width="326.9" x="-55"></rect>      </defs>      <clipPath>        <use overflow="visible" xlink:href="#SVGID_1_"></use>      </clipPath>      <path class="logo-path" d="M41.694 20.162c-1.315 0-1.315 0.987-1.315 0.987l0.094 13.8 c0 0 0.6 8.648-8.178 8.648c0 0-8.364 0.093-8.364-8.082V21.29c0 0 0.234-1.174-1.27-1.174c-1.362 0-1.221 1.174-1.221 1.174V36 c0 0 0.2 10.1 10.9 10.104c10.386 0 10.669-9.675 10.669-10.433V21.243C42.964 21.2 43 20.2 41.7 20.2"></path>      <path class="logo-path" d="M20.915 21.431c0 0 0-0.799-0.799-1.127c-0.777-0.321-1.27 0.422-1.457 0.6 l-7.425 10.293c0 0-0.469 0.61-1.034-0.282l-8.13-10.292c0 0-0.517-0.611-1.128-0.423c-0.611 0.189-0.894 0.704-0.846 1.6 L0 44.74c0 0-0.046 1.4 1.3 1.363s1.316-1.222 1.316-1.222V25.144l7.002 9.023c0 0 1.1 1.5 2.209-0.188 c1.081-1.646 6.626-8.882 6.626-8.882v19.736c0 0-0.088 1.3 1.5 1.175c1.175-0.094 0.988-1.22 0.988-1.22V21.431z"></path>      <path class="logo-path" d="M168.546 43.734l-10.309-6.813c0 0 8.648-0.179 8.648-8.471 c0-8.294-8.531-8.118-8.531-8.118h-8.412c-2.107 0-1.953 1.6-1.953 1.6v22.69c0 0-0.038 1.5 1.1 1.5 c1.265 0 1.222-1.436 1.222-1.436V22.702h6.516c0.474 0 3.1 0 5.3 1.304c2.192 1.3 3.7 7.198-0.177 9.6 c-2.785 1.717-6.459 1.008-7.642 0.889c-1.185-0.12-1.306 0.414-1.483 1.186c-0.177 0.8 0.9 1.4 0.9 1.362l13.21 8.5 c0 0 1.4 1.2 2.1 0.18C169.967 44.4 168.5 43.7 168.5 43.7"></path>      <path class="logo-path" d="M95.522 19.596c-6.516-0.711-11.492 3.376-11.373 7.8 c0.117 4.4 3 5.7 8.1 6.634c5.096 0.9 7 1.7 7 1.658c2.665 1 2.5 4.3 1 5.9 c-1.423 1.601-4.148 2.558-5.766 2.616c-3.879 0.146-6.052-2.374-6.052-2.374c-0.492-0.407-0.683-1.486-1.69-1.25 c-1.347 0.316-0.296 1.836-0.296 1.836c2.311 3.2 7.2 3.6 7.2 3.554c5.45 0.7 8.648-3.139 8.648-3.139 c2.963-3.852 0.987-8.363-1.976-9.429c-3.17-1.142-6.139-1.234-10.05-2.065c-3.909-0.828-3.495-4.087-3.495-4.087 c0.059-2.37 2.252-5.271 7.643-5.332c5.392-0.059 8.5 3.4 8.5 3.436c1.304 1.4 2.1 0.5 2.133-0.12 c0.06-0.591-0.058-1.183-0.531-1.776C104.121 23.1 102 20.3 95.5 19.6"></path>      <path class="logo-path" d="M124.084 20.618c-1.126 0-1.185 1.067-1.185 1.067v15.166h-14.336V21.862 c0 0 0.296-1.42-1.305-1.362c-1.304 0.047-1.067 1.42-1.067 1.42v14.575h-0.889c0 0-1.303-0.06-1.303 1.2 c0 1.3 1.2 1.3 1.2 1.305h1.007v5.746c0 0 0 1.2 1.2 1.243c1.246 0 1.187-1.184 1.187-1.184v-5.984h14.1v6.103 c0 0-0.008 1.1 1.2 1.137c1.226 0 1.269-1.195 1.269-1.195V21.743C125.209 21.7 125.2 20.6 124.1 20.6"></path>      <path class="logo-path" d="M86.101 44.016c0 0-10.841-21.504-11.849-23.163c-1.007-1.66-2.072 0-2.072 0 l-8.047 15.604l-2.395 0.015c-0.888 0-0.982 0.633-0.982 1.284c0 1.1 1.1 0.9 1.1 0.929h1.067c0 0-2.447 4.637-2.726 5.3 c-0.355 0.889-0.416 1.5 0.5 1.955c1.008 0.5 1.659-0.77 1.659-0.77l3.436-6.399H80.71l2.903 5.9 c0 0 1 2 2.1 1.305C86.87 45.3 86.1 44 86.1 44 M66.965 36.374l5.984-12.026c0 0 0.296-0.475 0.6 0.1 c0.296 0.5 6 12 6 11.967H66.965z"></path>      <path class="logo-path" d="M58.314 34.283c0 0 3.87-1.954 3.87-6.575c0-4.622-4.563-7.199-8.294-7.199 h-6.517c0 0-1.512 0.2-1.512 1.744v10.479h-1.833c0 0-0.799-0.094-0.799 1.271c0 1.1 0.6 1.2 0.6 1.173h2.066v9.447 c0 0-0.046 1.5 1.5 1.48h7.213c0 0 6.016-0.165 6.016-6.837C60.57 35.9 58.3 34.3 58.3 34.3 M48.203 22.7 l6.338-0.005c1.718 0 5.1 1.7 5.1 5.451c0 4.443-5.095 4.501-5.095 4.501h-6.338V22.736z M53.557 43.831h-5.351v-8.748 l6.435-0.008c0.858 0 3.5 0.9 3.5 4.031C58.143 43.7 53.6 43.8 53.6 43.8"></path>      <path class="logo-path" d="M146.17 23.033c0 0 1.3 0.1 1.305-1.304c0-1.244-1.305-1.125-1.305-1.125 h-15.818c-2.251 0-2.012 1.717-2.012 1.717V36.54l-1.653 0.009c0 0-1.132 0.229-1.132 1.177c0 1.2 1.1 1.4 1.1 1.361h1.669 v4.917c0 2.5 1.7 2.1 1.7 2.073h15.818c0 0 0.9 0 0.889-1.185s-0.95-1.007-0.95-1.007h-14.798v-4.799h15.284 c0 0 0.937-0.177 0.937-1.361c0-1.186-1.125-1.246-1.125-1.246h-15.228V23.033H146.17z"></path>    </g>  </defs></svg>  <!--<script type="text/javascript" xmlns:th="http://www.thymeleaf.org" th:fragment="body">-->  <!--(function () {-->    <!--var em = document.createElement(\'script\');-->    <!--em.type = \'text/javascript\';-->    <!--em.async = true;-->    <!--em.src =-->      <!--(\'https:\' == document.location.protocol ? \'https://me-ssl\' : \'http://me-cdn\') + \'.effectivemeasure.net/em.js\';-->    <!--var s = document.getElementsByTagName(\'script\')[0];-->    <!--s.parentNode.insertBefore(em, s);-->  <!--}());--><!--</script>-->  <div class="">    <header class="header">      <!-- DESKTOP ADS BLOCK -->      <!-- DESKTOP ADS BLOCK -->      <!-- MOBILE ADS BLOCK -->                  <!-- MOBILE ADS BLOCK -->      <div class="header__top-for-mobile">        <div class="top-bar__triggers">          <a class="main-menu-trigger fa fa-bars fa-2x" href="#main-menu" style="float: right;"></a>          <!-- Logo -->          <div class="header__logo header-logo-margins" onclick="window.location.href=\'/countries/sa\'">              <svg viewBox="0 0 494.387 190.555">    <use xlink:href="#logo-white"></use>  </svg>            </div>          <a class="countries-menu-trigger header-country-margins" href="#countries-menu">            <span>السعودية</span>            <span class="fa fa-caret-down fa-4x"></span>          </a>          <!-- ngRepeat: image in images --><img ng-repeat="image in images" src="/assets/ui/images/mobile-logo-G20.png" class="ng-scope"><!-- end ngRepeat: image in images --><img ng-repeat="image in images" src="/assets/ui/images/mobile-logo-vision.png" class="ng-scope"><!-- end ngRepeat: image in images -->          <div class="header__left-side left-search-icon">            <a class="search-trigger js-search-trigger fa fa-search fa-2x" href="javascript:;" style="float: left;">            </a>          </div>        </div>        <!-- Search -->        <div class="search js-search" id="search">          <i class="fa fa-search fa-2x search__icon"></i>          <angucomplete-alt id="autocomplete__companies" input-class="search__input" minlength="1" ng-controller="AutocompleteController" pause="400" placeholder="اكتب كلمة البحث أو رمز الشركة" selected-object="selectItem" text-no-results="عفواً, لم يتم العثور على أي نتائج" text-searching="جارٍ البحث..." title-field="label" remote-url="/api/1/companySearch?query=" class="ng-scope ng-isolate-scope"><div class="angucomplete-holder" ng-class="{\'angucomplete-dropdown-visible\': showDropdown}">  <input id="autocomplete__companies_value" ng-model="searchStr" ng-disabled="disableInput" type="" placeholder="اكتب كلمة البحث أو رمز الشركة" maxlength="524288" ng-focus="onFocusHandler()" class="search__input ng-valid-maxlength" ng-blur="hideResults($event)" autocapitalize="off" autocorrect="off" autocomplete="off" ng-change="inputChangeHandler(searchStr)">  <div id="autocomplete__companies_dropdown" class="angucomplete-dropdown ng-hide" ng-show="showDropdown"><div class="angucomplete-searching ng-hide" ng-show="searching"><div class="spinner"><div class="dot1"></div><div class="dot2"></div></div></div>    <div class="angucomplete-searching ng-binding" ng-show="!searching &amp;&amp; (!results || results.length == 0)" ng-bind="textNoResults">عفواً, لم يتم العثور على أي نتائج</div>    <!-- ngRepeat: result in results -->  </div></div></angucomplete-alt>        </div>      </div>      <div class="header-desktop mi-show-for-large-up">        <div class="header__top-for-desktop">          <div class="header__top-for-desktop-row">            <a class="header__other-site" href="http://tawasul.mubasher.info/" target="_blank">              <i class="fa fa-caret-right fa-2x"></i>              تواصل            </a>            <a class="header__other-site" href="http://magazine.mubasher.info/" target="_blank">              <i class="fa fa-caret-right fa-2x"></i>              مجلة مباشر            </a>            <a class="header__other-site" href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">              <i class="fa fa-play-circle"></i>              <div style="direction: ltr; display: inline-block;">TV مباشر</div>            </a>                        <a class="header__other-site" href="/contact">              <i class="fa fa-envelope"></i>              اتصل بنا            </a>            <a class="header__other-site" href="/advertise">              <i class="fa fa-envelope"></i>              اعلن معنا            </a>            <!-- <a th:if="${#locale.getLanguage() == \'ar\'}" class="header__login-button" style="background: #458D37 !important;" th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank"                th:text="#{components.header.decypha}">ديسيفا</a>            <a th:if="${#locale.getLanguage() == \'en\'}" class="header__login-button" style="background: #458D37 !important; font-family: Roboto,sans-serif !important;" th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank"                th:text="#{components.header.decypha}">ديسيفا</a> -->            <!-- Page Content Buttons -->            <a class="header__login-button" ng-click="decypha(\'decypha\')" style="background: #458D37 !important; font-family: Roboto,sans-serif !important;">ديسيفا</a>            <!-- Page Content Button -->            <!--Add according to MFP-187-->            <a class="header__login-button" style="background: #00c2d6 !important;" target="_blank" href="https://contest.mubasher.info/#/home">المستثمر اﻷول</a>                        <style>              /*.pulse-logo{*/              /*display: inline-block;*/              /*width: 252px;*/              /*height: 100%;*/              /*background: #212121 url(../images/pulse-logo.png) no-repeat center 2px;*/              /*padding: 10px 50px 29px;*/              /*text-align: center;*/              /*color: black;*/              /*text-decoration: none;*/              /*margin-top: -6px;*/              /*}*/              .pulse-logo2{                padding: 5px 5px 4px;                min-width: 82px;                min-height: 21px;                max-width: 27%;              }            </style>            <a target="_blank" href="https://pulse.mubasher.info">              <img class="pulse-logo2" src="../../../images/pulse-logo.png">            </a>            <span class="header__spacer">              &nbsp;            </span>            <a class="header__social-link" target="_blank" href="https://twitter.com/mubasher"><i class="fa fa-twitter fa-lg"></i></a>            <a class="header__social-link" href="https://www.facebook.com/Mubasher.Info"><i class="fa fa-facebook fa-lg"></i></a>            <a class="header__social-link" href="https://www.youtube.com/channel/UC7hnxb7gD4nKZdZk3ZlZCYg">              <i class="fa fa-youtube fa-lg"></i>            </a>            <a class="header__social-link" href="https://www.linkedin.com/company/1477149">              <i class="fa fa-linkedin fa-lg"></i>            </a>            <a class="header__social-link" href="/news/rss"><i class="fa fa-rss fa-lg"></i></a>            <a class="header__social-link" href="https://play.google.com/store/apps/details?id=net.mis.mubasherinfo">              <i class="fa fa-android fa-lg"></i>            </a>            <a class="header__social-link" href="https://itunes.apple.com/app/imubasher/id494539772?mt=8">              <i class="fa fa-apple fa-lg"></i>            </a>            <a class="header__login-button" href="/account/login">              دخول              <i class="fa fa-user fa-lg"></i>            </a>                                    <a class="header__language" href="https://english.mubasher.info">              <span>ENGLISH</span>            </a>          </div>        </div>        <div class="header__columns">          <div class="header__column1">            <!-- Logo -->            <div class="header__logo-wrapper">              <div class="header__logo" onclick="window.location.href=\'/countries/sa\'">                  <svg viewBox="0 0 494.387 190.555">    <use xlink:href="#logo"></use>  </svg>                </div>              <div class="countries-menu-trigger">                <a href="javascript:;" id="mi-js-countries-menu-trigger">                  <span>السعودية</span>                  <span class="fa fa-caret-down"></span>                </a>                <nav class="header__countries-menu--desktop mi-js-countries-menu-desktop" style="">                  <ul>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=ae&amp;url=/countries/sa/companies">الإمارات</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=bh&amp;url=/countries/sa/companies">البحرين</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=om&amp;url=/countries/sa/companies">عُمان</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=qa&amp;url=/countries/sa/companies">قطر</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=kw&amp;url=/countries/sa/companies">الكويت</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=eg&amp;url=/countries/sa/companies">مصر</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=jo&amp;url=/countries/sa/companies">الأردن</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=tn&amp;url=/countries/sa/companies">تونس</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=ma&amp;url=/countries/sa/companies">المغرب</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=ps&amp;url=/countries/sa/companies">فلسطين</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=iq&amp;url=/countries/sa/companies">العراق</a>                    </li>                  </ul>                </nav>              </div>            </div>            <!--Market Status -->            <div class="header__market-status">              <div class="header__market-status-column">                <div class="header__market-status-row">                  <a class="header__market-name" href="/markets/TDWL">TDWL</a>                  <span class="header__market-status--close">مغلق</span>                </div>                              </div>              <span class="header__market-time">12 أغسطس 04:49 م</span>            </div>          </div>          <div class="header__column1 banner-logo-desktop" ng-class="{\'banner-desktop-en\':(getLanguage == \'en\')}">            <!-- Logo -->            <div class="header__logo-wrapper">              <!-- ngRepeat: image in images --><div class="header__logo ng-scope" ng-repeat="image in images">                  <div class="tooltip tooltipstered"><img src="/assets/ui/images/logo-G20.png">                    <span class="tooltiptext ng-binding" ng-class="{\'tooltip-desktop-en\':(getLanguage == \'en\')}" style="left: 95%">مجموعة العشرين 2020</span>                  </div>              </div><!-- end ngRepeat: image in images --><div class="header__logo ng-scope" ng-repeat="image in images">                  <div class="tooltip tooltipstered"><img src="/assets/ui/images/logo-vision.png">                    <span class="tooltiptext ng-binding" ng-class="{\'tooltip-desktop-en\':(getLanguage == \'en\')}" style="left: 95%">رؤية المملكة العربية السعودية 2030</span>                  </div>              </div><!-- end ngRepeat: image in images -->            </div>          </div><!--          <div class="header__column2">             &lt;!&ndash;<div th:replace="components/ads/news/dfp/desktop/LB2"/>&ndash;&gt;            &lt;!&ndash;=====to display default leaderboard ad-slot [728,90] ======&ndash;&gt;            <div th:if="${isHomePage}">              <div th:replace="components/ads/home/leaderboard"/>            </div>            <div th:unless="${isHomePage}">              <div>                <iframe id="leaderboard-ros-001" style="width: 736px; height: 108px;" class="ad-iframe" src="/ads/LB2"></iframe>              </div>            </div>            </div>-->           <!--======= billboard 790x250 ============ -->        </div>        <nav class="header__navigation mi-js-desktop-menu-container">          <ul class="dl-menu mi-show-for-large-up mi-js-desktop-menu">            <li class="dl-menu__menu-item dl-menu__menu-item--iconic-item">              <a href="/countries/sa">                <i class="fa fa-home fa-2x"></i>              </a>            </li>            <li class="dl-menu__menu-item" id="markets">              <a href="javascript:;">الأسواق</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/markets/TDWL">سوق الأسهم السعودي</a>                    </li>                    <li>                      <a href="/markets/EGX">البورصة المصرية</a>                    </li>                    <li>                      <a href="/markets/DFM">سوق دبي المالي</a>                    </li>                    <li>                      <a href="/markets/ADX">سوق أبوظبي</a>                    </li>                    <li>                      <a href="/markets/BB">بورصة البحرين</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/markets/QE">بورصة قطر</a>                    </li>                    <li>                      <a href="/markets/MSM">سوق مسقط</a>                    </li>                    <li>                      <a href="/markets/BK">سوق الكويت</a>                    </li>                    <li>                      <a href="/markets/ASE">بورصة عمان</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/markets/CSE">سوق الدار البيضاء</a>                    </li>                    <li>                      <a href="/markets/BDT">بورصة تونس</a>                    </li>                    <li>                      <a href="/markets/PEX">سوق فلسطين</a>                    </li>                    <li>                      <a href="/markets/ISX">سوق العراق</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/international-indices">مؤشرات الأسواق العالمية</a>                    </li>                    <li>                      <a href="/markets/commodities-prices">أسعار المعادن والطاقة</a>                    </li>                    <li>                      <a href="/countries/sa/currencies">أسعار العملات</a>                    </li>                    <!--<li>                      <a th:href="${@url.to(\'RMPC#regionalMap\')}"                         th:text="#{navigation.markets.regional-map}"/>                    </li>-->                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item" id="news">              <a href="javascript:;">الأخبار</a>              <div class="mi-js-submenu">                <ul class="dl-submenu">                  <li>                    <a href="javascript:;">يحدث الآن</a>                    <div class="nav-column">                      <h3>يحدث الآن</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/sa/now/top">أهم الأخبار</a>                        </li>                        <li>                          <a href="/news/sa/now/exclusive">حصرياً مباشر</a>                        </li>                        <li>                          <a href="/news/sa/now/latest">آخر الأخبار</a>                        </li>                                                  <li>                            <a href="/news/sa/now/announcements">إعلانات السوق</a>                          </li>                                                                          <li class="global__hide-for-ltr">                          <a href="/news/sa/now/popular">منتشر الآن</a>                        </li>                        <li>                          <a href="/news/sa/now/trending/">الأكثر مشاركة</a>                        </li>                        <li>                          <a href="/news/now/news-releases">بيانات صحفية</a>                        </li>                        <li>                          <a href="/news/international/misc">أخبار منوعة</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">نبض السوق</a>                    <div class="nav-column">                      <h3>نبض السوق</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/sa/pulse/stocks">أخبار الأسهم</a>                        </li>                        <li>                          <a href="/news/sa/pulse/analysis">تحليلات إخبارية</a>                        </li>                        <li>                          <a href="/news/sa/pulse/local">اقتصاد محلي</a>                        </li>                        <li>                          <a href="/news/sa/pulse/recommendations">توصيات</a>                        </li>                      </ul>                      <h3>أخبار القطاعات</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/sa/category/banking">بنوك</a>                        </li><li>                          <a href="/news/sa/category/realEstate">عقارات</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">أخبار الدول</a>                    <div class="nav-column">                      <h3>أخبار الدول</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/eg/now/latest">مصر</a>                        </li>                        <li>                          <a href="/news/sa/now/latest">السعودية</a>                        </li>                        <li>                          <a href="/news/ae/now/latest">الإمارات</a>                        </li>                        <li>                          <a href="/news/bh/now/latest">البحرين</a>                        </li>                        <li>                          <a href="/news/qa/now/latest">قطر</a>                        </li>                        <li>                          <a href="/news/om/now/latest">عمان</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">أخبار الدول</a>                    <div class="nav-column">                      <h3 class="invisible">أخبار الدول</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/kw/now/latest">الكويت</a>                        </li>                        <li>                          <a href="/news/jo/now/latest">الأردن</a>                        </li>                        <li>                          <a href="/news/ma/now/latest">المغرب</a>                        </li>                        <li>                          <a href="/news/tn/now/latest">تونس</a>                        </li>                        <li>                          <a href="/news/ps/now/latest">فلسطين</a>                        </li>                        <li>                          <a href="/news/iq/now/latest">العراق</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">أخبار إقليمية</a>                    <div class="nav-column">                      <h3>أخبار إقليمية</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/regions/gulf">الخليج</a>                        </li>                        <li>                          <a href="/news/regions/levant">الشام</a>                        </li>                        <li>                          <a href="/news/regions/north-africa">شمال أفريقيا</a>                        </li>                        <li>                          <a href="/news/regions/middle-east">الشرق الأوسط</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">أخبار عالمية</a>                    <div class="nav-column">                      <h3>أخبار عالمية</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/international/global-economy">اقتصاد عالمى</a>                        </li>                        <li>                          <a href="/news/international/goods-and-metals">أحداث عالمية</a>                        </li>                        <li>                          <a href="/news/international/global-indices">مؤشرات عالمية</a>                        </li>                        <li>                          <a href="/news/international/oil-and-energy">نفط ومعادن</a>                        </li>                        <li>                          <a href="/news/international/currencies">عملات</a>                        </li>                        <li>                          <a href="/news/international/global-reports">تقارير عالمية</a>                        </li>                      </ul>                    </div>                  </li>                </ul>              </div>            </li>            <li class="dl-menu__menu-item" id="companies">              <a href="javascript:;">الشركات</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <h3 class="invisible">.</h3>                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/companies">الشركات المدرجة</a>                    </li>                    <li>                      <a href="/countries/sa/events">مفكرة الشركات</a>                    </li>                    <li>                      <a href="/countries/sa/stock-prices">أسعار الأسهم</a>                    </li>                    <li>                      <a href="/countries/sa/fair-values">القيم العادلة</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <h3 class="invisible">.</h3>                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/earnings">إعلانات الأرباح</a>                    </li>                    <li>                      <a href="/countries/sa/corporate-action">الإجراءات</a>                    </li>                                        <li>                      <a href="/countries/sa/major-shareholders">كبار الملاك</a>                    </li>                    <li>                      <a href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <h3>الاكتتابات</h3>                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/ipos">قائمة الإكتتابات</a>                    </li>                    <li>                      <a href="/ipo/list">بحث فى الاكتتابات</a>                    </li>                    <li>                      <a href="/ipos/news">أخبار الاكتتابات</a>                    </li>                    <li>                      <a href="/ipo/calendar">مفكرة الاكتتابات</a>                    </li>                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item" id="funds">              <a href="javascript:;">صناديق الاستثمار</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/funds">صناديق الاستثمار</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/funds-statistics">إحصائيات الصناديق</a>                    </li>                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item" id="analysis-tools">              <a href="javascript:;">أدوات التحليل</a>              <!-- If current country has one market only -->              <div class="mi-js-submenu">                                  <div class="nav-column">                    <ul class="dl-submenu">                      <li>                        <a href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>                      </li>                      <li>                        <a href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>                      </li>                      <li>                        <a href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>                      </li>                    </ul>                  </div>                  <div class="nav-column">                    <ul class="dl-submenu">                      <li>                        <a href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>                      </li>                      <li>                        <a href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>                      </li>                      <li>                        <a href="/analysis-tools/performance-comparison">مقارنة الأداء</a>                      </li>                    </ul>                  </div>                                              </div>            </li>            <li class="dl-menu__menu-item" id="islamic-economy">              <a href="/news/islamic-finance">الاقتصاد الإسلامي</a>            </li>            <!--<li id="radio"                class="dl-menu__menu-item global__hide-for-ltr"                id="radio"                th:if="${#locale.getLanguage() == \'ar\'}">              <a href="javascript:;" th:text="#{navigation.radio}"/>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a th:href="${@url.to(\'RPC#live\')}" th:text="#{navigation.radio.live}"/>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#latestEpisodesPage\', countryCode)}">آخر الحلقات</a>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تقارير-اقتصادية\'}">تقارير                        اقتصادية</a>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تغطية-خاصة\'}">تغطية خاصة</a>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'مقالات\'}">مقالات</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a th:href="${@url.to(\'RPC#programs\')}" th:text="#{navigation.radio.programs}"/>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#videoPrograms\')}" th:text="#{navigation.radio.videoPrograms}"/>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#getExperts\')}">ضيوفنا</a>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#getPresenters\')}">المذيعون</a>                    </li>                  </ul>                </div>              </div>            </li>-->            <li class="dl-menu__menu-item global__hide-for-ltr" id="video">              <a href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">مباشر TV</a>            </li>                        <li class="dl-menu__menu-item" id="fixedincome">              <a href="javascript:;">السندات</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/fixedincome/bond/search" id="fixedIncomeBondScreener">بحث عن سندات</a>                    </li>                    <li>                      <a href="/fixed-income/news" id="fixedIncomeNews">أخبار السندات وأذون الخزانة</a>                    </li>                    <li>                      <a href="/fixedincome/calendar/searchForEvent" id="fixedIncomeCalendar">قائمة الأحداث</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/fixedincome/analytics/drawCurve" id="fixedIncomeAnalytics">تحليلات فنية</a>                    </li>                    <li>                      <a href="/fixedincome/leagueTables/view" id="fixedIncomeLeagueTables">جداول الديون</a>                    </li>                    <li>                      <a href="/fixedincome/research/search" id="fixedIncomeProspectus">تقارير</a>                    </li>                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item" id="personal">              <a href="javascript:;">شخصي</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/my/alerts">التنبيهات</a>                    </li>                    <li>                      <a href="/my/watch-list">أسهمي</a>                    </li>                    <li>                      <a href="/my/newsletters">النشرة البريدية</a>                    </li>                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item dl-menu__menu-item--iconic-item">              <a class="js-search-trigger" href="javascript:;">                <i class="fa fa-search fa-2x"></i>              </a>            </li>          </ul>          <!-- Search -->          <div class="search js-search js-desktop-search" id="search">            <angucomplete-alt id="autocomplete__companies" input-class="search__input" minlength="1" ng-controller="AutocompleteController" pause="400" selected-object="selectItem" text-no-results="عفواً, لم يتم العثور على أي نتائج" text-searching="جارٍ البحث..." title-field="label" remote-url="/api/1/companySearch?query=" placeholder="اكتب كلمة البحث أو رمز الشركة" class="ng-scope ng-isolate-scope"><div class="angucomplete-holder" ng-class="{\'angucomplete-dropdown-visible\': showDropdown}">  <input id="autocomplete__companies_value" ng-model="searchStr" ng-disabled="disableInput" type="" placeholder="اكتب كلمة البحث أو رمز الشركة" maxlength="524288" ng-focus="onFocusHandler()" class="search__input ng-valid-maxlength" ng-blur="hideResults($event)" autocapitalize="off" autocorrect="off" autocomplete="off" ng-change="inputChangeHandler(searchStr)">  <div id="autocomplete__companies_dropdown" class="angucomplete-dropdown ng-hide" ng-show="showDropdown"><div class="angucomplete-searching ng-hide" ng-show="searching"><div class="spinner"><div class="dot1"></div><div class="dot2"></div></div></div>    <div class="angucomplete-searching ng-binding" ng-show="!searching &amp;&amp; (!results || results.length == 0)" ng-bind="textNoResults">عفواً, لم يتم العثور على أي نتائج</div>    <!-- ngRepeat: result in results -->  </div></div></angucomplete-alt>            <i class="fa fa-search fa-2x"></i>          </div>        </nav>      </div>    </header>    <div id="Leaderboard">    </div>    <div></div>    <div class="mi-content">      <div>  <!--<div th:replace="components/ads/internal/mobile-banner" />-->  <main class="mi-main-content">      <h1 class="mi-section__title">الشركات المدرجة</h1>  <div class="mi-table-container ng-scope" ng-controller="PagedTableController as table" country="sa" src="/api/1/listed-companies">    <div class="global__table-container md-whiteframe-z1 ng-isolate-scope" st-init="" st-pipe="fetch" st-table="table.data">      <span class="global__no-results ng-hide" ng-show="table.rows.length == 0 &amp;&amp; table.loaded">عفواّ, لم نعثر على أى نتائج</span>      <table class="mi-table" ng-hide="!table.loaded || table.rows.length == 0" style="">        <thead class="mi-table__thead">          <tr class="mi-table__thead-tr">            <th st-ratio="20" style="width: 20%;">الشركة</th>            <th>السهم</th>            <th class="mi-hide-for-small">القطاع</th>                        <th>آخر سعر</th>            <th>نسبة التغيير</th>            <th class="mi-hide-for-small">آخر تحديث</th>          </tr>        </thead>        <tbody class="mi-table__tbody" ng-hide="table.reloading">          <!-- ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/8050/profile" class="ng-binding" href="/markets/TDWL/stocks/8050/profile">سلامة</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8050" class="ng-binding" href="/markets/TDWL/stocks/8050">8050</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">14.5</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.14%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/4260/profile" class="ng-binding" href="/markets/TDWL/stocks/4260/profile">بدجت السعودية</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4260" class="ng-binding" href="/markets/TDWL/stocks/4260">4260</a>            </td>            <td class="mi-hide-for-small ng-binding">النقل</td>                        <td class="number ng-binding">32.4</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.61%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/4280/profile" class="ng-binding" href="/markets/TDWL/stocks/4280/profile">المملكة</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4280" class="ng-binding" href="/markets/TDWL/stocks/4280">4280</a>            </td>            <td class="mi-hide-for-small ng-binding">الإستثمار والتمويل</td>                        <td class="number ng-binding">6.84</td>            <td class="number ng-binding" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.00%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/8170/profile" class="ng-binding" href="/markets/TDWL/stocks/8170/profile">الاتحاد</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8170" class="ng-binding" href="/markets/TDWL/stocks/8170">8170</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">17.06</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              3.02%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/8180/profile" class="ng-binding" href="/markets/TDWL/stocks/8180/profile">الصقر للتأمين</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8180" class="ng-binding" href="/markets/TDWL/stocks/8180">8180</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">9.95</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.51%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/8160/profile" class="ng-binding" href="/markets/TDWL/stocks/8160/profile">التأمين العربية</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8160" class="ng-binding" href="/markets/TDWL/stocks/8160">8160</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">14.1</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              2.77%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/4290/profile" class="ng-binding" href="/markets/TDWL/stocks/4290/profile">الخليج للتدريب</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4290" class="ng-binding" href="/markets/TDWL/stocks/4290">4290</a>            </td>            <td class="mi-hide-for-small ng-binding">الخدمات الإستهلاكية</td>                        <td class="number ng-binding">15.5</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.78%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/2370/profile" class="ng-binding" href="/markets/TDWL/stocks/2370/profile">مسك</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/2370" class="ng-binding" href="/markets/TDWL/stocks/2370">2370</a>            </td>            <td class="mi-hide-for-small ng-binding">السلع الرأسمالية</td>                        <td class="number ng-binding">9.54</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.21%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/4300/profile" class="ng-binding" href="/markets/TDWL/stocks/4300/profile">دار الأركان</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4300" class="ng-binding" href="/markets/TDWL/stocks/4300">4300</a>            </td>            <td class="mi-hide-for-small ng-binding">إدارة وتطوير العقارات</td>                        <td class="number ng-binding">7.84</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -1.13%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/2380/profile" class="ng-binding" href="/markets/TDWL/stocks/2380/profile">بترو رابغ</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/2380" class="ng-binding" href="/markets/TDWL/stocks/2380">2380</a>            </td>            <td class="mi-hide-for-small ng-binding">الطاقة</td>                        <td class="number ng-binding">13.12</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.30%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/7030/profile" class="ng-binding" href="/markets/TDWL/stocks/7030/profile">زين السعودية</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/7030" class="ng-binding" href="/markets/TDWL/stocks/7030">7030</a>            </td>            <td class="mi-hide-for-small ng-binding">الإتصالات</td>                        <td class="number ng-binding">11.66</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.52%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/1150/profile" class="ng-binding" href="/markets/TDWL/stocks/1150/profile">الإنماء</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/1150" class="ng-binding" href="/markets/TDWL/stocks/1150">1150</a>            </td>            <td class="mi-hide-for-small ng-binding">البنوك</td>                        <td class="number ng-binding">15.06</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.26%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/8210/profile" class="ng-binding" href="/markets/TDWL/stocks/8210/profile">بوبا العربية</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8210" class="ng-binding" href="/markets/TDWL/stocks/8210">8210</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">122.4</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.49%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/8190/profile" class="ng-binding" href="/markets/TDWL/stocks/8190/profile">المتحدة للتأمين</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8190" class="ng-binding" href="/markets/TDWL/stocks/8190">8190</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">10.1</td>            <td class="number ng-binding" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.00%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/8200/profile" class="ng-binding" href="/markets/TDWL/stocks/8200/profile">الإعادة السعودية</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8200" class="ng-binding" href="/markets/TDWL/stocks/8200">8200</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">9.27</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.32%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/1210/profile" class="ng-binding" href="/markets/TDWL/stocks/1210/profile">بي سي آي</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/1210" class="ng-binding" href="/markets/TDWL/stocks/1210">1210</a>            </td>            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>                        <td class="number ng-binding">25.75</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.58%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/6001/profile" class="ng-binding" href="/markets/TDWL/stocks/6001/profile">حلواني إخوان</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/6001" class="ng-binding" href="/markets/TDWL/stocks/6001">6001</a>            </td>            <td class="mi-hide-for-small ng-binding">إنتاج الأغذية</td>                        <td class="number ng-binding">66.5</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.91%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/4001/profile" class="ng-binding" href="/markets/TDWL/stocks/4001/profile">أسواق ع العثيم</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4001" class="ng-binding" href="/markets/TDWL/stocks/4001">4001</a>            </td>            <td class="mi-hide-for-small ng-binding">تجزئة الأغذية</td>                        <td class="number ng-binding">119.2</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.67%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/7040/profile" class="ng-binding" href="/markets/TDWL/stocks/7040/profile">عذيب للإتصالات</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/7040" class="ng-binding" href="/markets/TDWL/stocks/7040">7040</a>            </td>            <td class="mi-hide-for-small ng-binding"></td>                        <td class="number ng-binding">5.35</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.93%            </td>            <td class="mi-hide-for-small ng-binding">28 يونيو 2018</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/1211/profile" class="ng-binding" href="/markets/TDWL/stocks/1211/profile">معادن</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/1211" class="ng-binding" href="/markets/TDWL/stocks/1211">1211</a>            </td>            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>                        <td class="number ng-binding">37.45</td>            <td class="number ng-binding" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.00%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index -->        </tbody>      </table>      <div ng-show="table.searcing" class="ng-hide">        <span class="global__loading">جارى التصفية, يرجى الإنتظار ...</span>        <div>    <div class="sk-spinner sk-spinner-wave">        <div class="sk-rect1"></div>        <div class="sk-rect2"></div>        <div class="sk-rect3"></div>        <div class="sk-rect4"></div>        <div class="sk-rect5"></div>    </div></div>      </div>      <div ng-hide="table.loaded" class="ng-hide" style="">        <div>    <div class="sk-spinner sk-spinner-wave">        <div class="sk-rect1"></div>        <div class="sk-rect2"></div>        <div class="sk-rect3"></div>        <div class="sk-rect4"></div>        <div class="sk-rect5"></div>    </div></div>      </div>      <div st-items-by-page="20" st-pagination="" st-template="/assets/ui/ngt/components/pagination/pagination.ng.html" class="ng-isolate-scope"><!-- ngIf: pages.length >= 2 --><div class="pagination ng-scope" ng-if="pages.length >= 2">    <nav role="navigation" aria-label="Pagination">        <ul class="cd-pagination no-space" role="menubar" aria-label="Pagination">            <!-- ngIf: currentPage > 1 --><li ng-if="currentPage > 1" class="ng-scope">                <a ng-click="selectPage(1)">                    <i class="fa fa-angle-double-right fa-lg"></i>                </a>            </li><!-- end ngIf: currentPage > 1 -->            <!-- ngIf: currentPage > 1 --><li class="cd-pagination__button ng-scope" aria-disabled="true" ng-if="currentPage > 1">                <a ng-click="selectPage(currentPage-1)" class="ng-binding">                  <i class="fa fa-lg fa-angle-right"></i>                  السابق                </a>            </li><!-- end ngIf: currentPage > 1 -->            <!-- ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">                <a ng-click="selectPage(page)" class="ng-binding">4</a>            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">                <a ng-click="selectPage(page)" class="ng-binding">5</a>            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope current">                <a ng-click="selectPage(page)" class="ng-binding">6</a>            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">                <a ng-click="selectPage(page)" class="ng-binding">7</a>            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">                <a ng-click="selectPage(page)" class="ng-binding">8</a>            </li><!-- end ngRepeat: page in pages -->            <!-- ngIf: currentPage < numPages --><li class="cd-pagination__button ng-scope" ng-if="currentPage < numPages">                <a ng-click="selectPage(currentPage+1)" href="" class="ng-binding">                  التالي                    <i class="fa fa-angle-left fa-lg"></i>                </a>            </li><!-- end ngIf: currentPage < numPages -->            <!-- ngIf: currentPage < numPages --><li ng-if="currentPage < numPages" class="ng-scope">                <a ng-click="selectPage(numPages)">                    <i class="fa fa-angle-double-left  fa-lg"></i>                </a>            </li><!-- end ngIf: currentPage < numPages -->        </ul>    </nav></div><!-- end ngIf: pages.length >= 2 --></div>    </div>  </div>    <!-- Speakol Widget - Removal IB-51 -->  <!-- <div th:replace="components/ads/common/speakol-one"/> -->  </main>  <aside class="mi-sidebar mi-show-for-large-up">    <!-- Radio component doesn\'t exist in English version -->    <!---->  <!--  <div th:unless="${device.isMobile()}">      <div>        <iframe onload="adjustIframeSize(this);" class="ad-iframe" src="/ads/side-bar"></iframe>      </div>      <script>        function adjustIframeSize(self) {          var index = 0;          var interval = setInterval( function(){            if (index < 3) {              self.style.height=self.contentDocument.body.scrollHeight +10 + \'px\';self.style.width=\'310px\';              index = index + 1;            } else {              clearInterval(interval)            }          }, 1);        }      </script>    </div>-->    <div>    <div class="mi-popular-news news-sidebar-mub md-whiteframe-z1 ng-scope" ng-controller="PopularNewsController as popular">    <h2 class="global__h2--collapsed">الأخبار الأكثر</h2>    <v-tabs active="tabs.active" class="vTabs--secondary ng-isolate-scope" control="tabs">      <!-- ngRepeat: page in popular.pages --><v-tab ng-bind="page.title" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope is-active" role="tab" aria-selected="true" tabindex="0">قراءة</v-tab><!-- end ngRepeat: page in popular.pages --><v-tab ng-bind="page.title" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope" role="tab" aria-selected="false" tabindex="-1">مشاركة</v-tab><!-- end ngRepeat: page in popular.pages -->    </v-tabs>    <v-pages active="tabs.active" class="vPages--default ng-isolate-scope" control="tabs" ng-swipe-left="tabs.next()" ng-swipe-right="tabs.previous()">      <!-- ngRepeat: page in popular.pages --><v-page ng-bind-html="page.content | unsafe" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope is-active" role="tabpanel">        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3680410/%D9%87%D9%8A%D8%A6%D8%A9-%D8%A7%D9%84%D9%86%D9%82%D9%84-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%B5%D8%B1%D9%81-%D8%AF%D8%B9%D9%85-%D8%A7%D9%84%D8%A3%D9%81%D8%B1%D8%A7%D8%AF-%D8%A7%D9%84%D8%B9%D8%A7%D9%85%D9%84%D9%8A%D9%86-%D9%81%D9%8A-%D9%86%D8%B4%D8%A7%D8%B7-%D8%AA%D9%88%D8%AC%D9%8A%D9%87-%D8%A7%D9%84%D9%85%D8%B1%D9%83%D8%A8%D8%A7%D8%AA-%D9%82%D8%B1%D9%8A%D8%A8%D8%A7-/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="فرع تابع لهيئة العامة للنقل السعودية" src="https://static.mubasher.info/File.Story_Image/3e19073c5aca3db54ef2c06eb4bf5ea6/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3680410/%D9%87%D9%8A%D8%A6%D8%A9-%D8%A7%D9%84%D9%86%D9%82%D9%84-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%B5%D8%B1%D9%81-%D8%AF%D8%B9%D9%85-%D8%A7%D9%84%D8%A3%D9%81%D8%B1%D8%A7%D8%AF-%D8%A7%D9%84%D8%B9%D8%A7%D9%85%D9%84%D9%8A%D9%86-%D9%81%D9%8A-%D9%86%D8%B4%D8%A7%D8%B7-%D8%AA%D9%88%D8%AC%D9%8A%D9%87-%D8%A7%D9%84%D9%85%D8%B1%D9%83%D8%A8%D8%A7%D8%AA-%D9%82%D8%B1%D9%8A%D8%A8%D8%A7-/">هيئة النقل السعودية: صرف دعم الأفراد العاملين في نشاط توجيه المركبات قريباً</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3680099/%D8%A7%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D8%B5%D8%AF%D8%B1-%D9%82%D8%B1%D8%A7%D8%B1%D8%A7-%D8%A8%D8%B4%D8%A3%D9%86-%D8%A7%D9%84%D9%85%D8%A8%D8%AA%D8%B9%D8%AB%D9%8A%D9%86/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="وزير التعليم السعودي، حمد بن محمد آل الشيخ، أرشيفية" src="https://static.mubasher.info/File.Story_Image/9e9e9919f67b43d61c15c7fd734289d3/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3680099/%D8%A7%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D8%B5%D8%AF%D8%B1-%D9%82%D8%B1%D8%A7%D8%B1%D8%A7-%D8%A8%D8%B4%D8%A3%D9%86-%D8%A7%D9%84%D9%85%D8%A8%D8%AA%D8%B9%D8%AB%D9%8A%D9%86/">التعليم السعودية تصدر قراراً بشأن المبتعثين</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3680101/%D9%85%D8%AD%D8%AF%D8%AB-%D8%A7%D9%84%D8%B0%D9%87%D8%A8-%D9%8A%D8%AA%D9%87%D8%A7%D9%88%D9%89-93-%D8%AF%D9%88%D9%84%D8%A7%D8%B1%D8%A7-%D8%B9%D9%86%D8%AF-%D8%A7%D9%84%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D9%85%D8%B9-%D9%85%D9%83%D8%A7%D8%B3%D8%A8-%D8%A7%D9%84%D8%A3%D8%B3%D9%87%D9%85/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/caeadbca5bf2481c2d38f04625e51f00/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3680101/%D9%85%D8%AD%D8%AF%D8%AB-%D8%A7%D9%84%D8%B0%D9%87%D8%A8-%D9%8A%D8%AA%D9%87%D8%A7%D9%88%D9%89-93-%D8%AF%D9%88%D9%84%D8%A7%D8%B1%D8%A7-%D8%B9%D9%86%D8%AF-%D8%A7%D9%84%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D9%85%D8%B9-%D9%85%D9%83%D8%A7%D8%B3%D8%A8-%D8%A7%D9%84%D8%A3%D8%B3%D9%87%D9%85/">محدث.. الذهب يتهاوى 93 دولاراً عند التسوية مع مكاسب الأسهم</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3679355/%D8%A7%D9%84%D9%84%D9%8A%D8%B1%D8%A9-%D8%A7%D9%84%D8%AA%D8%B1%D9%83%D9%8A%D8%A9-%D8%AA%D9%87%D8%A8%D8%B7-%D8%A5%D9%84%D9%89-%D9%85%D8%B3%D8%AA%D9%88%D9%89-%D8%AA%D8%A7%D8%B1%D9%8A%D8%AE%D9%8A-%D8%AC%D8%AF%D9%8A%D8%AF/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/1242bfad1995396ce3f6470a3d5584c2/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3679355/%D8%A7%D9%84%D9%84%D9%8A%D8%B1%D8%A9-%D8%A7%D9%84%D8%AA%D8%B1%D9%83%D9%8A%D8%A9-%D8%AA%D9%87%D8%A8%D8%B7-%D8%A5%D9%84%D9%89-%D9%85%D8%B3%D8%AA%D9%88%D9%89-%D8%AA%D8%A7%D8%B1%D9%8A%D8%AE%D9%8A-%D8%AC%D8%AF%D9%8A%D8%AF/">الليرة التركية تهبط إلى مستوى تاريخي جديد</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3679705/%D8%B9%D9%85%D9%84%D8%A9-%D8%A7%D9%84%D8%A8%D9%8A%D8%AA%D9%83%D9%88%D9%8A%D9%86-%D8%AA%D8%B9%D8%A7%D9%88%D8%AF-%D8%A7%D9%84%D8%B5%D8%B9%D9%88%D8%AF-%D8%A3%D8%B9%D9%84%D9%89-12-%D8%A3%D9%84%D9%81-%D8%AF%D9%88%D9%84%D8%A7%D8%B1/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/ab491b6531081c6058fa5b203b6cbecc/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3679705/%D8%B9%D9%85%D9%84%D8%A9-%D8%A7%D9%84%D8%A8%D9%8A%D8%AA%D9%83%D9%88%D9%8A%D9%86-%D8%AA%D8%B9%D8%A7%D9%88%D8%AF-%D8%A7%D9%84%D8%B5%D8%B9%D9%88%D8%AF-%D8%A3%D8%B9%D9%84%D9%89-12-%D8%A3%D9%84%D9%81-%D8%AF%D9%88%D9%84%D8%A7%D8%B1/">عملة البيتكوين تعاود الصعود أعلى 12 ألف دولار</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3679783/%D8%A3%D8%B1%D8%A7%D9%85%D9%83%D9%88-%D8%AA%D8%B1%D9%81%D8%B9-%D8%A3%D8%B3%D8%B9%D8%A7%D8%B1-%D8%A7%D9%84%D8%A8%D9%86%D8%B2%D9%8A%D9%86-%D8%A8%D9%86%D8%AD%D9%88-11-%D8%AD%D8%AA%D9%89-10-%D8%B3%D8%A8%D8%AA%D9%85%D8%A8%D8%B1/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="محطة للتزود بالوقود" src="https://static.mubasher.info/File.Story_Image/cf61a8737c62c57737e53b3677aa2bbc/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3679783/%D8%A3%D8%B1%D8%A7%D9%85%D9%83%D9%88-%D8%AA%D8%B1%D9%81%D8%B9-%D8%A3%D8%B3%D8%B9%D8%A7%D8%B1-%D8%A7%D9%84%D8%A8%D9%86%D8%B2%D9%8A%D9%86-%D8%A8%D9%86%D8%AD%D9%88-11-%D8%AD%D8%AA%D9%89-10-%D8%B3%D8%A8%D8%AA%D9%85%D8%A8%D8%B1/">أرامكو ترفع أسعار البنزين بنحو 11% حتى 10 سبتمبر</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3680546/%D8%A8%D9%803-%D8%B6%D9%88%D8%A7%D8%A8%D8%B7-%D8%A7%D9%84%D8%AA%D9%82%D8%A7%D8%B9%D8%AF-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D9%88%D8%B6%D8%AD-%D8%B7%D8%B1%D9%8A%D9%82%D8%A9-%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D8%A7%D9%84%D9%85%D8%B9%D8%A7%D8%B4-%D9%84%D9%85%D9%88%D8%B8%D9%81%D9%8A-%D8%A7%D9%84%D9%82%D8%B7%D8%A7%D8%B9-%D8%A7%D9%84%D8%B9%D8%A7%D9%85/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="مؤسسة التقاعد السعودية" src="https://static.mubasher.info/File.Story_Image/68cc490a847f0daba3afd0ddbd6d06c8/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3680546/%D8%A8%D9%803-%D8%B6%D9%88%D8%A7%D8%A8%D8%B7-%D8%A7%D9%84%D8%AA%D9%82%D8%A7%D8%B9%D8%AF-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D9%88%D8%B6%D8%AD-%D8%B7%D8%B1%D9%8A%D9%82%D8%A9-%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D8%A7%D9%84%D9%85%D8%B9%D8%A7%D8%B4-%D9%84%D9%85%D9%88%D8%B8%D9%81%D9%8A-%D8%A7%D9%84%D9%82%D8%B7%D8%A7%D8%B9-%D8%A7%D9%84%D8%B9%D8%A7%D9%85/">بـ3 ضوابط.. التقاعد السعودية توضح طريقة تسوية المعاش لموظفي القطاع العام</a>        </div>              </div>        <a class="mi-article-widget__more-button" href="/news/SA/now/popular">      <span>المزيد</span>      <i class="fa fa-chevron-left"></i>    </a>    </v-page><!-- end ngRepeat: page in popular.pages --><v-page ng-bind-html="page.content | unsafe" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope" role="tabpanel">            <a class="mi-article-widget__more-button" href="/news/SA/now/trending/">      <span>المزيد</span>      <i class="fa fa-chevron-left"></i>    </a>    </v-page><!-- end ngRepeat: page in popular.pages -->    </v-pages>  </div>    <div id="MPU">    </div>    </div>    <!-- Speakol Widget - Removal IB-51 -->    <!-- <div th:replace="components/ads/common/speakol-two"/> --><!--    <div th:unless="${device.isMobile()}">      <div th:replace="components/ads/insticator/insticator-widget"/>    </div>-->    <!-- -->    <!-- PS -->    <!--<div th:replace="components/ads/internal/may-like-articles" />-->    <!--<div th:replace="components/ads/internal/second-fold" />-->    <!--    <div th:if="${#locale.getLanguage() == \'ar\'}">          <span class="home__title">راديو مباشر</span>          <div class="internal-radio-carousel-container"></div>        </div>-->  </aside><!--  <div th:replace="components/ads/internal/mobile-fullpage"/>-->  <!--<div th:replace="components/ads/internal/mobile-interstitial"/>--><!--commented out as per Fayoumi\'s request-->  <!--<div th:replace="components/ads/internal/mobile-outstream"/>-->  <!--MFP-228 New Fixed-Replacement-ROS ads--><!--  <div th:replace="components/ads/home/mobile-fixed-replacement"/>  <div th:replace="components/ads/news/dfp/mobile/MPU3"/>--><!--Commented out as per Fayoumi\'s request-->  <!--<div th:replace="components/ads/internal/outstream"/>--><!--  <div th:if="${device.isMobile()}">    <div th:replace="components/ads/dfp/mobile-internal-pages"/>  </div>--><!--  <div th:if="${device.isMobile()}">    <div th:replace="components/ads/insticator/insticator-widget"/>  </div>--> <!-- <div th:replace="components/ads/internal/mobile-above-footer"/>--></div>    </div>    <footer>  <div class="mi-footer">    <div class="mi-show-for-large-up mi-footer__main-menu">      <ul>        <li class="mi-footer__menu-item mi-footer__menu__markets" id="markets">          <div class="mi-footer__menu-level1">الأسواق</div>          <ul>            <h3 class="mi-footer__menu-level2 invisible">الأسواق</h3>            <li>              <a class="mi-footer__menu-level3" href="/markets/TDWL">سوق الأسهم السعودي</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/EGX">البورصة المصرية</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/DFM">سوق دبي المالي</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/ADX">سوق أبوظبي</a>            </li>          </ul>          <ul>            <li>              <a class="mi-footer__menu-level3" href="/markets/BB">بورصة البحرين</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/QE">بورصة قطر</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/MSM">سوق مسقط</a>            </li>          </ul>          <ul>            <li>              <a class="mi-footer__menu-level3" href="/markets/KSE">سوق الكويت</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/ASE">بورصة عمان</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/CSE">سوق الدار البيضاء</a>            </li>          </ul>          <ul>            <li>              <a class="mi-footer__menu-level3" href="/markets/BDT">بورصة تونس</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/PEX">سوق فلسطين</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/ISX">سوق العراق</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/international-indices">مؤشرات الأسواق العالمية</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/commodities-prices">أسعار المعادن والطاقة</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/currencies">أسعار العملات</a>            </li>            <!--<li>              <a class="mi-footer__menu-level3"                 th:href="${@url.to(\'RMPC#regionalMap\')}"                 th:text="#{navigation.markets.regional-map}"/>            </li>-->          </ul>        </li>        <li class="mi-footer__menu-item mi-footer__menu__news" id="news">          <ul>            <div class="mi-footer__menu-level1">الأخبار</div>            <li class="mi-footer__menu__news__submenu">              <h3 class="mi-footer__menu-level2">أخبار الدول</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/eg/now/latest">مصر</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/latest">السعودية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/ae/now/latest">الإمارات</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/bh/now/latest">البحرين</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/qa/now/latest">قطر</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/om/now/latest">عمان</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/kw/now/latest">الكويت</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/jo/now/latest">الأردن</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/ma/now/latest">المغرب</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/tn/now/latest">تونس</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/ps/now/latest">فلسطين</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/iq/now/latest">العراق</a>                </li>              </ul>            </li>            <li class="mi-footer__menu__news__submenu">              <h3 class="mi-footer__menu-level2">أخبار إقليمية</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/regions/gulf">الخليج</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/regions/levant">الشام</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/regions/north-africa">شمال أفريقيا</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/regions/middle-east">الشرق الأوسط</a>                </li>              </ul>              <!-- happening now -->              <h3 class="mi-footer__menu-level2">يحدث الآن</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/top">أهم الأخبار</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/exclusive">حصرياً مباشر</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/latest">آخر الأخبار</a>                </li>                                  <li>                    <a class="mi-footer__menu-level3" href="/news/sa/now/announcements">إعلانات السوق</a>                  </li>                                                  <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/popular">منتشر الآن</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/trending/">الأكثر مشاركة</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/now/news-releases">بيانات صحفية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/misc">أخبار منوعة</a>                </li>              </ul>            </li>            <li class="mi-footer__menu__news__submenu">              <h3 class="mi-footer__menu-level2">نبض السوق</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/stocks">أخبار الأسهم</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/analysis">تحليلات إخبارية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/local">اقتصاد محلي</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/recommendations">توصيات</a>                </li>              </ul>              <h3 class="mi-footer__menu-level2">أخبار القطاعات</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/category/banking">بنوك</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/category/realEstate">عقارات</a>                </li>              </ul>              <h3 class="mi-footer__menu-level2">أخبار عالمية</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/global-economy">اقتصاد عالمى</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/goods-and-metals">أحداث عالمية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/global-indices">مؤشرات عالمية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/oil-and-energy">نفط ومعادن</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/currencies">عملات</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/global-reports">تقارير عالمية</a>                </li>              </ul>            </li>          </ul>        </li>        <li class="mi-footer__menu-item mi-footer__menu__companies" id="companies">          <div class="mi-footer__menu-level1">الشركات</div>          <ul>            <h3 class="mi-footer__menu-level2 invisible">الشركات</h3>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/companies">الشركات المدرجة</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/events">مفكرة الشركات</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/stock-prices">أسعار الأسهم</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/earnings">إعلانات الأرباح</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/fair-values">القيم العادلة</a>            </li>            <li>                          </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/major-shareholders">كبار الملاك</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/ipos">قائمة الإكتتابات</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/ipo/list">بحث فى الاكتتابات</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/ipos/news">أخبار الاكتتابات</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/ipo/calendar">مفكرة الاكتتابات</a>            </li>          </ul>        </li>        <li class="mi-footer__menu-item mi-footer__menu__analysis-tools" id="analysis-tools">          <div class="mi-footer__menu-level1">أدوات التحليل</div>          <!-- If current country has one market only -->                      <ul>              <h3 class="mi-footer__menu-level2 invisible">أدوات التحليل</h3>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/performance-comparison">مقارنة الأداء</a>              </li>            </ul>                    <!-- If current country has more than one markets i.e UAE -->                  </li>      </ul>    </div>    <div class="mi-footer__second-fold">      <div class="mi-footer__column1">        <div class="mi-footer__copyright">          <div class="mi-footer__logo" onclick="window.location.href=\'/countries/sa\'">              <svg viewBox="0 0 494.387 190.555">    <use xlink:href="#logo-white"></use>  </svg>            </div>          <span>جميع الحقوق تعود لشركة مباشر العالمية © 2005 - 2020</span>        </div>        <ul class="mi-footer__links">          <li>            <a href="/s/Terms">اتفاقية الاستخدام</a>          </li>          <li>            <a href="/s/disclaimer">إخلاء المسؤولية</a>          </li>          <li>            <a href="/s/aboutus">من نحن</a>          </li>          <li>            <a href="/contact">اتصل بنا</a>          </li>          <li>            <a href="/advertise">أعلن معنا</a>          </li>          <li>            <a href="http://www.decypha.com/" target="_blank">موقع ديسيفا</a>          </li>          <li>            <a href="/ir-services" target="_blank">خدمات المواقع</a>          </li>          <li>            <a href="/s/Jobs">وظائف</a>          </li>          <li>              <a target="_blank" href="/decypha-packages">ديسيفا</a>          </li>          <li>            <a href="/s/privacy-policy" target="_blank">سياسة الخصوصية</a>          </li>          <!--<li th:if="${#locale.getLanguage() == \'en\'}">            <a href="/s/decypha-financial-intelligence" th:text="#{components.footer.decypha-financial-intelligence}">Decypha Financial Intelligence</a>          </li>-->        </ul>        <div>جميع البيانات متأخرة 15 دقيقة أثناء الجلسة</div>        <div>هذا الموقع مرخص من وزراة الثقافة والإعلام السعودية</div>        <div>رقم التسجيل :ت 1 125 1435</div>      </div>      <div class="mi-footer__column2">        <ul class="mi-footer__social-icons">          <li>            <a target="_blank" href="https://twitter.com/mubasher"><i class="fa fa-twitter fa-2x"></i></a>          </li>          <li>            <a href="https://www.facebook.com/Mubasher.Info"><i class="fa fa-facebook fa-2x"></i></a>          </li>          <li>            <a href="https://www.youtube.com/channel/UC7hnxb7gD4nKZdZk3ZlZCYg"><i class="fa fa-youtube fa-2x"></i></a>          </li>          <li>            <a href="https://www.linkedin.com/company/1477149"><i class="fa fa-linkedin fa-2x"></i></a>          </li>          <li>            <a href="/news/rss"><i class="fa fa-rss fa-2x"></i></a>          </li>          <li>            <a href="https://play.google.com/store/apps/details?id=net.mis.mubasherinfo">              <i class="fa fa-android fa-2x"></i></a>          </li>          <li>            <a href="https://itunes.apple.com/app/imubasher/id494539772?mt=8"><i class="fa fa-apple fa-2x"></i></a>          </li>          </ul></div></div></div></footer>          </div>  <script src="//code.jquery.com/jquery-2.1.4.min.js"></script>  <script src="//ajax.googleapis.com/ajax/libs/angularjs/1.3.15/angular.min.js"></script>  <script src="/assets/ui/lib.min.js"></script>  <script src="/assets/ui/main.min.js"></script>  <div id="mi-js-scripts"></div>  <script>    <!-- Fix menu trigger on android browser4 -->    $(".dl-menu__menu-item").click(function () {      $(this).addClass(".dl-menu-item__hoverd");    });    $(document).ready(function () {      $(\'.tooltip\').tooltipster();      setTimeout(function(){ dataLayer.push({event: "triggerAds"});      console.log("triggerAds");      }, 1000);    });  </script>    <div pg-ng-tooltip=""></div></div>  <!-- Twitter universal website tag code -->  <script>    !function(e,t,n,s,u,a){e.twq||(s=e.twq=function(){s.exe?s.exe.apply(s,arguments):s.queue.push(arguments);    },s.version=\'1.1\',s.queue=[],u=t.createElement(n),u.async=!0,u.src=\'//static.ads-twitter.com/uwt.js\',      a=t.getElementsByTagName(n)[0],a.parentNode.insertBefore(u,a))}(window,document,\'script\');    // Insert Twitter Pixel ID and Standard Event data below    twq(\'init\',\'nyana\');    twq(\'track\',\'PageView\');  </script>  <!-- End Twitter universal website tag code --><div id="mm-blocker" class="mm-slideout"></div></body>' + '<body id="mi" ng-app="app" ng-controller="MainController" class="ar ng-scope" data-gr-c-s-loaded="true"><nav class="header__countries-menu mm-menu mm-offcanvas mm-top mm-front" id="countries-menu"><div class="mm-panel mm-opened mm-current" id="mm-8"><ul class="mm-listview mm-first mm-last">        <li class="header__country-selector__country">          <a href="/change-country?to=ae&amp;url=/countries/sa/companies">الإمارات</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=bh&amp;url=/countries/sa/companies">البحرين</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=om&amp;url=/countries/sa/companies">عُمان</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=qa&amp;url=/countries/sa/companies">قطر</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=kw&amp;url=/countries/sa/companies">الكويت</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=eg&amp;url=/countries/sa/companies">مصر</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=jo&amp;url=/countries/sa/companies">الأردن</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=tn&amp;url=/countries/sa/companies">تونس</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=ma&amp;url=/countries/sa/companies">المغرب</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=ps&amp;url=/countries/sa/companies">فلسطين</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=iq&amp;url=/countries/sa/companies">العراق</a>        </li>      </ul></div></nav><nav class="header__main-menu mm-menu mm-border-full mm-effect-slide-menu mm-effect-zoom-panels mm-pageshadow mm-offcanvas mm-right mm-hasnavbar-top mm-hasnavbar" id="main-menu"><div class="mm-navbar mm-navbar-top mm-hasbtns"><a class="mm-prev mm-btn mm-hidden"></a><a class="mm-title"> </a><a class="mm-close mm-btn" href="#wrapper"></a></div><div class="mm-panel mm-opened mm-current" id="mm-0"><ul class="mm-listview mm-first mm-last">        <li id="markets">          <a class="mm-next mm-fullsubopen" href="#mm-1" data-target="#mm-1"></a><span href="javascript:;">الأسواق</span>                  </li>        <li id="news">          <a class="mm-next mm-fullsubopen" href="#mm-2" data-target="#mm-2"></a><span href="javascript:;">الأخبار</span>                  </li>        <li id="companies">          <a class="mm-next mm-fullsubopen" href="#mm-3" data-target="#mm-3"></a><span href="javascript:;">الشركات</span>                  </li>        <li id="funds">          <a class="mm-next mm-fullsubopen" href="#mm-4" data-target="#mm-4"></a><span href="javascript:;">صناديق الاستثمار</span>                  </li>        <li id="analysis-tool">          <a class="mm-next mm-fullsubopen" href="#mm-5" data-target="#mm-5"></a><span href="javascript:;">أدوات التحليل</span>                  </li>        <li id="islamic-economy">          <a href="/news/islamic-finance">الاقتصاد الإسلامي</a>        </li>        <!--<li class="global__hide-for-ltr" id="radio" th:if="${#locale.getLanguage() == \'ar\'}">          <span th:text="#{navigation.radio}">راديو مباشر</span>          <ul>            <li>              <a th:href="${@url.to(\'RPC#live\')}" th:text="#{navigation.radio.live}"/>            </li>            <li>              <a th:href="${@url.to(\'RPC#latestEpisodesPage\', countryCode)}">آخر الحلقات</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تقارير-اقتصادية\'}">تقارير اقتصادية</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تغطية-خاصة\'}">تغطية خاصة</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'مقالات\'}">مقالات</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#programs\')}" th:text="#{navigation.radio.programs}"/>            </li>            <li>              <a th:href="${@url.to(\'RPC#videoPrograms\')}" th:text="#{navigation.radio.videoPrograms}"/>            </li>            <li>              <a th:href="${@url.to(\'RPC#getExperts\')}">ضيوفنا</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#getPresenters\')}">المذيعون</a>            </li>          </ul>        </li>-->        <li class="global__hide-for-ltr" id="video">          <a href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">مباشر TV</a>        </li>                <li id="fixedincome">          <a class="mm-next mm-fullsubopen" href="#mm-6" data-target="#mm-6"></a><span>السندات</span>                  </li>        <li>          <a class="mm-next mm-fullsubopen" href="#mm-7" data-target="#mm-7"></a><span>شخصي</span>                  </li>        <li>          <a href="http://tawasul.mubasher.info/" target="_blank">تواصل</a>        </li>        <!-- <li>          <a th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank" th:text="#{components.header.decypha}" target="_blank">          </a>        </li> -->        <li>          <a ng-click="decypha(\'decypha\')">ديسيفا</a>        </li>        <!--Add according to MFP-187-->        <li>          <a href="https://contest.mubasher.info/#/home" target="_blank">المستثمر اﻷول</a>        </li>        <li>          <!--Integrating Mubasher Pulse-->        </li><li>        <style>          .pulse-logo2{            padding: 5px 5px 4px;            min-width: 82px;            min-height: 21px;            max-width: 27%;          }        </style>        <a target="_blank" href="https://pulse.mubasher.info">          <img class="pulse-logo2" src="../../../images/pulse-logo.png">        </a>        </li>        <li>        </li><li>          <a href="http://magazine.mubasher.info/" target="_blank">            مجلة مباشر          </a>        </li>        <li class="mm-divider"></li>        <li>          <a href="https://english.mubasher.info">ENGLISH</a>        </li>        <li>                  </li>        <li>          <a class="header__login__text" href="/account/login">دخول</a>                  </li>      </ul></div><div class="mm-panel mm-hidden" id="mm-1"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الأسواق</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/markets/TDWL">سوق الأسهم السعودي</a>            </li>            <li>              <a href="/markets/EGX">البورصة المصرية</a>            </li>            <li>              <a href="/markets/DFM">سوق دبي المالي</a>            </li>            <li>              <a href="/markets/ADX">سوق أبوظبي</a>            </li>            <li>              <a href="/markets/BB">بورصة البحرين</a>            </li>            <li>              <a href="/markets/QE">بورصة قطر</a>            </li>            <li>              <a href="/markets/MSM">سوق مسقط</a>            </li>            <li>              <a href="/markets/BK">سوق الكويت</a>            </li>            <li>              <a href="/markets/ASE">بورصة عمان</a>            </li>            <li>              <a href="/markets/CSE">سوق الدار البيضاء</a>            </li>            <li>              <a href="/markets/BDT">بورصة تونس</a>            </li>            <li>              <a href="/markets/PEX">سوق فلسطين</a>            </li>            <li>              <a href="/markets/ISX">سوق العراق</a>            </li>            <li>              <a href="/international-indices">مؤشرات الأسواق العالمية</a>            </li>            <li>              <a href="/markets/commodities-prices">أسعار المعادن والطاقة</a>            </li>            <li>              <a href="/countries/sa/currencies">أسعار العملات</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-2"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الأخبار</a></div><ul class="mm-listview mm-first mm-last">            <!-- now -->            <li class="mm-divider">يحدث الآن</li>            <li>              <a href="/news/sa/now/top">أهم الأخبار</a>            </li>            <li>              <a href="/news/sa/now/exclusive">حصرياً مباشر</a>            </li>            <li>              <a href="/news/sa/now/latest">آخر الأخبار</a>            </li>                          <li>                <a href="/news/sa/now/announcements">إعلانات السوق</a>              </li>                                      <li class="global__hide-for-ltr">              <a href="/news/sa/now/popular">منتشر الآن</a>            </li>            <li>              <a href="/news/sa/now/trending/">الأكثر مشاركة</a>            </li>            <li>              <a href="/news/now/news-releases">بيانات صحفية</a>            </li><!--            <li>              <a th:href="${@url.to(\'NPC#miscellaneousNews\', countryCode)}"                 th:text="#{navigation.news.now.misc}"/>            </li>-->            <!-- recommendations-->            <li class="mm-divider">نبض السوق</li>            <li>              <a href="/news/sa/pulse/stocks">أخبار الأسهم</a>            </li>            <li>              <a href="/news/sa/pulse/analysis">تحليلات إخبارية</a>            </li>            <li>              <a href="/news/sa/pulse/local">اقتصاد محلي</a>            </li>            <li>              <a href="/news/sa/pulse/recommendations">توصيات</a>            </li>            <li class="mm-divider">أخبار القطاعات</li>            <li>              <a href="/news/sa/category/banking">بنوك</a>            </li>            <li>              <a href="/news/sa/category/realEstate">عقارات</a>            </li>            <li class="mm-divider">أخبار الدول</li>            <li>              <a href="/news/eg/now/latest">مصر</a>            </li>            <li>              <a href="/news/sa/now/latest">السعودية</a>            </li>            <li>              <a href="/news/ae/now/latest">الإمارات</a>            </li>            <li>              <a href="/news/bh/now/latest">البحرين</a>            </li>            <li>              <a href="/news/qa/now/latest">قطر</a>            </li>            <li>              <a href="/news/om/now/latest">عمان</a>            </li>            <li>              <a href="/news/kw/now/latest">الكويت</a>            </li>            <li>              <a href="/news/jo/now/latest">الأردن</a>            </li>            <li>              <a href="/news/ma/now/latest">المغرب</a>            </li>            <li>              <a href="/news/tn/now/latest">تونس</a>            </li>            <li>              <a href="/news/ps/now/latest">فلسطين</a>            </li>            <li>              <a href="/news/iq/now/latest">العراق</a>            </li>            <!-- regions-->            <li class="mm-divider">أخبار إقليمية</li>            <li>              <a href="/news/regions/gulf">الخليج</a>            </li>            <li>              <a href="/news/regions/levant">الشام</a>            </li>            <li>              <a href="/news/regions/north-africa">شمال أفريقيا</a>            </li>            <li>              <a href="/news/regions/middle-east">الشرق الأوسط</a>            </li>            <!-- international -->            <li class="mm-divider">أخبار عالمية</li>            <li>              <a href="/news/international/global-economy">اقتصاد عالمى</a>            </li>            <li>              <a href="/news/international/goods-and-metals">أحداث عالمية</a>            </li>              <li>                <a href="/news/international/global-indices">مؤشرات عالمية</a>              </li>              <li>                <a href="/news/international/oil-and-energy">نفط ومعادن</a>              </li>              <li>                <a href="/news/international/currencies">عملات</a>              </li>              <li>                <a href="/news/international/global-reports">تقارير عالمية</a>              </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-3"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الشركات</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/countries/sa/companies">الشركات المدرجة</a>            </li>            <li>              <a href="/countries/sa/events">مفكرة الشركات</a>            </li>            <li>              <a href="/countries/sa/stock-prices">أسعار الأسهم</a>            </li>            <li>              <a href="/countries/sa/earnings">إعلانات الأرباح</a>            </li>            <li>              <a href="/countries/sa/fair-values">القيم العادلة</a>            </li>            <li>              <a href="/countries/sa/corporate-action">الإجراءات</a>            </li>                        <li>              <a href="/countries/sa/major-shareholders">كبار الملاك</a>            </li>            <li>              <a href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>            </li>            <li class="mm-divider">الاكتتابات</li>            <li>              <a href="/countries/sa/ipos">قائمة الإكتتابات</a>            </li>            <li>              <a href="/ipo/list">بحث فى الاكتتابات</a>            </li>            <li>              <a href="/ipos/news">أخبار الاكتتابات</a>            </li>            <li>              <a href="/ipo/calendar">مفكرة الاكتتابات</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-4"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">صناديق الاستثمار</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/countries/sa/funds">صناديق الاستثمار</a>            </li>            <li>              <a href="/countries/sa/funds-statistics">إحصائيات الصناديق</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-5"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">أدوات التحليل</a></div><ul class="mm-listview mm-first mm-last">                                        <li>                <a href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>              </li>              <li>                <a href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>              </li>              <li>                <a href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>              </li>              <li>                <a href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>              </li>              <li>                <a href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>              </li>                        <li class="mm-divider">            </li>            <li>              <a href="/analysis-tools/performance-comparison">مقارنة الأداء</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-6"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">السندات</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/fixedincome/bond/search" id="fixedIncomeBondScreener">بحث عن سندات</a>            </li>            <li>              <a href="/fixed-income/news" id="fixedIncomeNews">أخبار السندات وأذون الخزانة</a>            </li>            <li>              <a href="/fixedincome/calendar/searchForEvent" id="fixedIncomeCalendar">قائمة الأحداث</a>            </li>            <li>              <a href="/fixedincome/analytics/drawCurve" id="fixedIncomeAnalytics">تحليلات فنية</a>            </li>            <li>              <a href="/fixedincome/leagueTables/view" id="fixedIncomeLeagueTables">جداول الديون</a>            </li>            <li>              <a href="/fixedincome/research/search" id="fixedIncomeProspectus">تقارير</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-7"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">شخصي</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/my/alerts">التنبيهات</a>            </li>            <li>              <a href="/my/watch-list">أسهمي</a>            </li>            <li>              <a href="/my/newsletters">النشرة البريدية</a>            </li>          </ul></div></nav><div class="js-wrapper mm-page mm-slideout" id="wrapper">  <svg class="hidden" version="1.1" viewBox="0 0 0 0" xmlns="http://www.w3.org/2000/svg">  <defs>    <style>      .logo-white-path {        clip-rule: evenodd;        fill-rule: evenodd;        fill: white;        font-size: 46.6299px;        font-family: \'HelveticaNeue\';      }      .logo-path {        clip-rule: evenodd;        fill-rule: evenodd;        fill: #324651;        text-align: center;        font-size: 46.6299px;        font-family: \'HelveticaNeue\';      }    </style>    <g id="logo-white">      <path class="logo-white-path" d="M209.596 29.677c-6.25 0.016-11.243-4.937-11.261-11.188 c-0.018-6.191 5.027-11.29 11.194-11.29c6.182-0.004 11.3 5.1 11.3 11.226C220.852 24.6 215.8 29.7 209.6 29.7"></path>      <path class="logo-white-path" d="M228.308 37.976c6.231-0.01 11.3 5 11.3 11.2 c0.015 6.189-5.011 11.227-11.233 11.252c-6.213 0.025-11.246-4.99-11.271-11.209C217.063 43 222.1 38 228.3 38"></path>      <path class="logo-white-path" d="M350.278 190.471c-6.27-0.009-11.204-4.942-11.197-11.212 c0.013-6.26 4.968-11.18 11.248-11.176c6.242 0 11.3 5 11.2 11.224C361.555 185.5 356.5 190.5 350.3 190.5"></path>      <path class="logo-white-path" d="M186.161 37.976c6.26 0 11.2 5 11.2 11.2 c-0.01 6.241-4.993 11.239-11.209 11.226c-6.257-0.017-11.212-4.99-11.212-11.228C174.949 42.9 179.9 38 186.2 38"></path>      <path class="logo-white-path" d="M455.92 80.125c-21.212 0-38.405 17.191-38.405 38.4 c0 4.3 0.7 8.4 2 12.316l-48.126 0.003l13.9-27.74h-3.242c0 0-2.13 0.019-2.822 0.1 c-2.13 0.126-3.67 0.098-7.926 1.351c-3.949 1.159-7.026 2.719-9.881 4.503c-2.381 1.493-5.863 4.278-8.803 7.7 c-2.912 3.325-5.713 7.695-5.713 7.695l-3.294 6.464l-41.201 0.003L364.7 0l-76.514 49.172l25.429-0.036L260.64 156.919h193.847 c0 0 0.9 0 1.4 0.01c21.212 0 38.4-17.183 38.4-38.403C494.32 97.3 477.1 80.1 455.9 80.125z M455.92 133.3 c-7.998 0-14.48-6.479-14.48-14.47c0-7.998 6.482-14.476 14.48-14.476c7.996 0 14.5 6.5 14.5 14.5 C470.393 126.8 463.9 133.3 455.9 133.327z"></path>      <path class="logo-white-path" d="M269.61 81.427c0 0-1.617 0.013-2.842 0.09c-2.001 0.132-3.655 0.07-7.903 1.3 c-3.946 1.162-7.021 2.722-9.876 4.507c-2.378 1.488-5.868 4.279-8.813 7.662c-2.904 3.327-5.282 8.108-5.282 8.108l-14.116 27.7 h-16.391l19.092-39.485h-3.237c0 0-1.617 0.015-2.835 0.095c-2.012 0.13-3.665 0.068-7.905 1.3 c-3.957 1.161-7.034 2.717-9.892 4.502c-2.373 1.493-5.857 4.28-8.808 7.668c-2.899 3.321-5.282 8.104-5.282 8.104l-8.901 17.8 h-16.959l13.92-27.753h-3.245c0 0-2.141 0.019-2.822 0.057c-2.133 0.126-3.663 0.098-7.926 1.4 c-3.944 1.159-7.026 2.719-9.884 4.503c-2.378 1.493-5.857 4.28-8.808 7.669c-2.904 3.329-5.708 7.695-5.708 7.695l-3.291 6.5 l-52.558-0.005l14.007-27.748h-3.242c0 0-2.131 0.019-2.815 0.057c-2.136 0.126-3.678 0.098-7.934 1.4 c-3.944 1.159-7.021 2.719-9.877 4.503c-2.383 1.493-5.858 4.28-8.813 7.669c-2.906 3.329-5.114 7.843-5.114 7.843l-16.204 31.1 l0 0c0 0-3.136 6.731-7.038 11.469c-3.094 3.766-7.43 6.804-9.757 8.194c-2.313 1.384-7.141 3.645-11.872 4.5 C5.251 180.9 0 180.5 0 180.502s2.33 2.1 5 3.806c2.034 1.4 4.3 2.4 5.5 3 c2.481 1.1 4.3 1.7 6.9 2.253c2.531 0.6 4.8 0.8 4.8 0.763s1.621 0.2 3.2 0.169c0.707 0 1.62-0.024 2.848-0.09 c2.001-0.134 3.5 0 7.904-1.323c4.033-1.188 7.072-2.582 9.92-4.368c2.383-1.478 5.952-4.249 8.904-7.627 c2.907-3.337 5.296-8.019 5.296-8.019l6.043-12.125l169.4 0.009l12.816-26.07l24.302-49.431H269.61z"></path>      <path class="logo-white-path" d="M30.239 76.472V55.626H22.45v-2.789h18.735v2.789h-7.819v20.846H30.239z"></path>      <path class="logo-white-path" d="M44.296 76.472V52.836h4.71l5.592 16.735c0.518 1.6 0.9 2.7 1.1 3.499c0.269-0.861 0.687-2.123 1.258-3.789 l5.658-16.446h4.209v23.636h-3.015V56.689l-6.869 19.783h-2.822l-6.835-20.121v20.121H44.296z"></path>    </g>    <g id="logo">      <path class="logo-path" d="M209.596 29.677c-6.25 0.016-11.243-4.937-11.261-11.188 c-0.018-6.191 5.027-11.29 11.194-11.29c6.182-0.004 11.3 5.1 11.3 11.226C220.852 24.6 215.8 29.7 209.6 29.7"></path>      <path class="logo-path" d="M228.308 37.976c6.231-0.01 11.3 5 11.3 11.2 c0.015 6.189-5.011 11.227-11.233 11.252c-6.213 0.025-11.246-4.99-11.271-11.209C217.063 43 222.1 38 228.3 38"></path>      <path class="logo-path" d="M350.278 190.471c-6.27-0.009-11.204-4.942-11.197-11.212 c0.013-6.26 4.968-11.18 11.248-11.176c6.242 0 11.3 5 11.2 11.224C361.555 185.5 356.5 190.5 350.3 190.5"></path>      <path class="logo-path" d="M186.161 37.976c6.26 0 11.2 5 11.2 11.2 c-0.01 6.241-4.993 11.239-11.209 11.226c-6.257-0.017-11.212-4.99-11.212-11.228C174.949 42.9 179.9 38 186.2 38"></path>      <path class="logo-path" d="M455.92 80.125c-21.212 0-38.405 17.191-38.405 38.4 c0 4.3 0.7 8.4 2 12.316l-48.126 0.003l13.9-27.74h-3.242c0 0-2.13 0.019-2.822 0.1 c-2.13 0.126-3.67 0.098-7.926 1.351c-3.949 1.159-7.026 2.719-9.881 4.503c-2.381 1.493-5.863 4.278-8.803 7.7 c-2.912 3.325-5.713 7.695-5.713 7.695l-3.294 6.464l-41.201 0.003L364.7 0l-76.514 49.172l25.429-0.036L260.64 156.919h193.847 c0 0 0.9 0 1.4 0.01c21.212 0 38.4-17.183 38.4-38.403C494.32 97.3 477.1 80.1 455.9 80.125z M455.92 133.3 c-7.998 0-14.48-6.479-14.48-14.47c0-7.998 6.482-14.476 14.48-14.476c7.996 0 14.5 6.5 14.5 14.5 C470.393 126.8 463.9 133.3 455.9 133.327z"></path>      <path class="logo-path" d="M269.61 81.427c0 0-1.617 0.013-2.842 0.09c-2.001 0.132-3.655 0.07-7.903 1.3 c-3.946 1.162-7.021 2.722-9.876 4.507c-2.378 1.488-5.868 4.279-8.813 7.662c-2.904 3.327-5.282 8.108-5.282 8.108l-14.116 27.7 h-16.391l19.092-39.485h-3.237c0 0-1.617 0.015-2.835 0.095c-2.012 0.13-3.665 0.068-7.905 1.3 c-3.957 1.161-7.034 2.717-9.892 4.502c-2.373 1.493-5.857 4.28-8.808 7.668c-2.899 3.321-5.282 8.104-5.282 8.104l-8.901 17.8 h-16.959l13.92-27.753h-3.245c0 0-2.141 0.019-2.822 0.057c-2.133 0.126-3.663 0.098-7.926 1.4 c-3.944 1.159-7.026 2.719-9.884 4.503c-2.378 1.493-5.857 4.28-8.808 7.669c-2.904 3.329-5.708 7.695-5.708 7.695l-3.291 6.5 l-52.558-0.005l14.007-27.748h-3.242c0 0-2.131 0.019-2.815 0.057c-2.136 0.126-3.678 0.098-7.934 1.4 c-3.944 1.159-7.021 2.719-9.877 4.503c-2.383 1.493-5.858 4.28-8.813 7.669c-2.906 3.329-5.114 7.843-5.114 7.843l-16.204 31.1 l0 0c0 0-3.136 6.731-7.038 11.469c-3.094 3.766-7.43 6.804-9.757 8.194c-2.313 1.384-7.141 3.645-11.872 4.5 C5.251 180.9 0 180.5 0 180.502s2.33 2.1 5 3.806c2.034 1.4 4.3 2.4 5.5 3 c2.481 1.1 4.3 1.7 6.9 2.253c2.531 0.6 4.8 0.8 4.8 0.763s1.621 0.2 3.2 0.169c0.707 0 1.62-0.024 2.848-0.09 c2.001-0.134 3.5 0 7.904-1.323c4.033-1.188 7.072-2.582 9.92-4.368c2.383-1.478 5.952-4.249 8.904-7.627 c2.907-3.337 5.296-8.019 5.296-8.019l6.043-12.125l169.4 0.009l12.816-26.07l24.302-49.431H269.61z"></path>      <path class="logo-path" d="M30.239 76.472V55.626H22.45v-2.789h18.735v2.789h-7.819v20.846H30.239z"></path>      <path class="logo-path" d="M44.296 76.472V52.836h4.71l5.592 16.735c0.518 1.6 0.9 2.7 1.1 3.499c0.269-0.861 0.687-2.123 1.258-3.789 l5.658-16.446h4.209v23.636h-3.015V56.689l-6.869 19.783h-2.822l-6.835-20.121v20.121H44.296z"></path>    </g>    <g id="logo-white-en">      <defs>        <rect height="65.7" width="326.9" x="-55"></rect>      </defs>      <clipPath>        <use overflow="visible" xlink:href="#SVGID_1_"></use>      </clipPath>      <path class="logo-white-path" d="M41.694 20.162c-1.315 0-1.315 0.987-1.315 0.987l0.094 13.8 c0 0 0.6 8.648-8.178 8.648c0 0-8.364 0.093-8.364-8.082V21.29c0 0 0.234-1.174-1.27-1.174c-1.362 0-1.221 1.174-1.221 1.174V36 c0 0 0.2 10.1 10.9 10.104c10.386 0 10.669-9.675 10.669-10.433V21.243C42.964 21.2 43 20.2 41.7 20.2"></path>      <path class="logo-white-path" d="M20.915 21.431c0 0 0-0.799-0.799-1.127c-0.777-0.321-1.27 0.422-1.457 0.6 l-7.425 10.293c0 0-0.469 0.61-1.034-0.282l-8.13-10.292c0 0-0.517-0.611-1.128-0.423c-0.611 0.189-0.894 0.704-0.846 1.6 L0 44.74c0 0-0.046 1.4 1.3 1.363s1.316-1.222 1.316-1.222V25.144l7.002 9.023c0 0 1.1 1.5 2.209-0.188 c1.081-1.646 6.626-8.882 6.626-8.882v19.736c0 0-0.088 1.3 1.5 1.175c1.175-0.094 0.988-1.22 0.988-1.22V21.431z"></path>      <path class="logo-white-path" d="M168.546 43.734l-10.309-6.813c0 0 8.648-0.179 8.648-8.471 c0-8.294-8.531-8.118-8.531-8.118h-8.412c-2.107 0-1.953 1.6-1.953 1.6v22.69c0 0-0.038 1.5 1.1 1.5 c1.265 0 1.222-1.436 1.222-1.436V22.702h6.516c0.474 0 3.1 0 5.3 1.304c2.192 1.3 3.7 7.198-0.177 9.6 c-2.785 1.717-6.459 1.008-7.642 0.889c-1.185-0.12-1.306 0.414-1.483 1.186c-0.177 0.8 0.9 1.4 0.9 1.362l13.21 8.5 c0 0 1.4 1.2 2.1 0.18C169.967 44.4 168.5 43.7 168.5 43.7"></path>      <path class="logo-white-path" d="M95.522 19.596c-6.516-0.711-11.492 3.376-11.373 7.8 c0.117 4.4 3 5.7 8.1 6.634c5.096 0.9 7 1.7 7 1.658c2.665 1 2.5 4.3 1 5.9 c-1.423 1.601-4.148 2.558-5.766 2.616c-3.879 0.146-6.052-2.374-6.052-2.374c-0.492-0.407-0.683-1.486-1.69-1.25 c-1.347 0.316-0.296 1.836-0.296 1.836c2.311 3.2 7.2 3.6 7.2 3.554c5.45 0.7 8.648-3.139 8.648-3.139 c2.963-3.852 0.987-8.363-1.976-9.429c-3.17-1.142-6.139-1.234-10.05-2.065c-3.909-0.828-3.495-4.087-3.495-4.087 c0.059-2.37 2.252-5.271 7.643-5.332c5.392-0.059 8.5 3.4 8.5 3.436c1.304 1.4 2.1 0.5 2.133-0.12 c0.06-0.591-0.058-1.183-0.531-1.776C104.121 23.1 102 20.3 95.5 19.6"></path>      <path class="logo-white-path" d="M124.084 20.618c-1.126 0-1.185 1.067-1.185 1.067v15.166h-14.336V21.862 c0 0 0.296-1.42-1.305-1.362c-1.304 0.047-1.067 1.42-1.067 1.42v14.575h-0.889c0 0-1.303-0.06-1.303 1.2 c0 1.3 1.2 1.3 1.2 1.305h1.007v5.746c0 0 0 1.2 1.2 1.243c1.246 0 1.187-1.184 1.187-1.184v-5.984h14.1v6.103 c0 0-0.008 1.1 1.2 1.137c1.226 0 1.269-1.195 1.269-1.195V21.743C125.209 21.7 125.2 20.6 124.1 20.6"></path>      <path class="logo-white-path" d="M86.101 44.016c0 0-10.841-21.504-11.849-23.163c-1.007-1.66-2.072 0-2.072 0 l-8.047 15.604l-2.395 0.015c-0.888 0-0.982 0.633-0.982 1.284c0 1.1 1.1 0.9 1.1 0.929h1.067c0 0-2.447 4.637-2.726 5.3 c-0.355 0.889-0.416 1.5 0.5 1.955c1.008 0.5 1.659-0.77 1.659-0.77l3.436-6.399H80.71l2.903 5.9 c0 0 1 2 2.1 1.305C86.87 45.3 86.1 44 86.1 44 M66.965 36.374l5.984-12.026c0 0 0.296-0.475 0.6 0.1 c0.296 0.5 6 12 6 11.967H66.965z"></path>      <path class="logo-white-path" d="M58.314 34.283c0 0 3.87-1.954 3.87-6.575c0-4.622-4.563-7.199-8.294-7.199 h-6.517c0 0-1.512 0.2-1.512 1.744v10.479h-1.833c0 0-0.799-0.094-0.799 1.271c0 1.1 0.6 1.2 0.6 1.173h2.066v9.447 c0 0-0.046 1.5 1.5 1.48h7.213c0 0 6.016-0.165 6.016-6.837C60.57 35.9 58.3 34.3 58.3 34.3 M48.203 22.7 l6.338-0.005c1.718 0 5.1 1.7 5.1 5.451c0 4.443-5.095 4.501-5.095 4.501h-6.338V22.736z M53.557 43.831h-5.351v-8.748 l6.435-0.008c0.858 0 3.5 0.9 3.5 4.031C58.143 43.7 53.6 43.8 53.6 43.8"></path>      <path class="logo-white-path" d="M146.17 23.033c0 0 1.3 0.1 1.305-1.304c0-1.244-1.305-1.125-1.305-1.125 h-15.818c-2.251 0-2.012 1.717-2.012 1.717V36.54l-1.653 0.009c0 0-1.132 0.229-1.132 1.177c0 1.2 1.1 1.4 1.1 1.361h1.669 v4.917c0 2.5 1.7 2.1 1.7 2.073h15.818c0 0 0.9 0 0.889-1.185s-0.95-1.007-0.95-1.007h-14.798v-4.799h15.284 c0 0 0.937-0.177 0.937-1.361c0-1.186-1.125-1.246-1.125-1.246h-15.228V23.033H146.17z"></path>    </g>    <g id="logo-en">      <defs>        <rect height="65.7" width="326.9" x="-55"></rect>      </defs>      <clipPath>        <use overflow="visible" xlink:href="#SVGID_1_"></use>      </clipPath>      <path class="logo-path" d="M41.694 20.162c-1.315 0-1.315 0.987-1.315 0.987l0.094 13.8 c0 0 0.6 8.648-8.178 8.648c0 0-8.364 0.093-8.364-8.082V21.29c0 0 0.234-1.174-1.27-1.174c-1.362 0-1.221 1.174-1.221 1.174V36 c0 0 0.2 10.1 10.9 10.104c10.386 0 10.669-9.675 10.669-10.433V21.243C42.964 21.2 43 20.2 41.7 20.2"></path>      <path class="logo-path" d="M20.915 21.431c0 0 0-0.799-0.799-1.127c-0.777-0.321-1.27 0.422-1.457 0.6 l-7.425 10.293c0 0-0.469 0.61-1.034-0.282l-8.13-10.292c0 0-0.517-0.611-1.128-0.423c-0.611 0.189-0.894 0.704-0.846 1.6 L0 44.74c0 0-0.046 1.4 1.3 1.363s1.316-1.222 1.316-1.222V25.144l7.002 9.023c0 0 1.1 1.5 2.209-0.188 c1.081-1.646 6.626-8.882 6.626-8.882v19.736c0 0-0.088 1.3 1.5 1.175c1.175-0.094 0.988-1.22 0.988-1.22V21.431z"></path>      <path class="logo-path" d="M168.546 43.734l-10.309-6.813c0 0 8.648-0.179 8.648-8.471 c0-8.294-8.531-8.118-8.531-8.118h-8.412c-2.107 0-1.953 1.6-1.953 1.6v22.69c0 0-0.038 1.5 1.1 1.5 c1.265 0 1.222-1.436 1.222-1.436V22.702h6.516c0.474 0 3.1 0 5.3 1.304c2.192 1.3 3.7 7.198-0.177 9.6 c-2.785 1.717-6.459 1.008-7.642 0.889c-1.185-0.12-1.306 0.414-1.483 1.186c-0.177 0.8 0.9 1.4 0.9 1.362l13.21 8.5 c0 0 1.4 1.2 2.1 0.18C169.967 44.4 168.5 43.7 168.5 43.7"></path>      <path class="logo-path" d="M95.522 19.596c-6.516-0.711-11.492 3.376-11.373 7.8 c0.117 4.4 3 5.7 8.1 6.634c5.096 0.9 7 1.7 7 1.658c2.665 1 2.5 4.3 1 5.9 c-1.423 1.601-4.148 2.558-5.766 2.616c-3.879 0.146-6.052-2.374-6.052-2.374c-0.492-0.407-0.683-1.486-1.69-1.25 c-1.347 0.316-0.296 1.836-0.296 1.836c2.311 3.2 7.2 3.6 7.2 3.554c5.45 0.7 8.648-3.139 8.648-3.139 c2.963-3.852 0.987-8.363-1.976-9.429c-3.17-1.142-6.139-1.234-10.05-2.065c-3.909-0.828-3.495-4.087-3.495-4.087 c0.059-2.37 2.252-5.271 7.643-5.332c5.392-0.059 8.5 3.4 8.5 3.436c1.304 1.4 2.1 0.5 2.133-0.12 c0.06-0.591-0.058-1.183-0.531-1.776C104.121 23.1 102 20.3 95.5 19.6"></path>      <path class="logo-path" d="M124.084 20.618c-1.126 0-1.185 1.067-1.185 1.067v15.166h-14.336V21.862 c0 0 0.296-1.42-1.305-1.362c-1.304 0.047-1.067 1.42-1.067 1.42v14.575h-0.889c0 0-1.303-0.06-1.303 1.2 c0 1.3 1.2 1.3 1.2 1.305h1.007v5.746c0 0 0 1.2 1.2 1.243c1.246 0 1.187-1.184 1.187-1.184v-5.984h14.1v6.103 c0 0-0.008 1.1 1.2 1.137c1.226 0 1.269-1.195 1.269-1.195V21.743C125.209 21.7 125.2 20.6 124.1 20.6"></path>      <path class="logo-path" d="M86.101 44.016c0 0-10.841-21.504-11.849-23.163c-1.007-1.66-2.072 0-2.072 0 l-8.047 15.604l-2.395 0.015c-0.888 0-0.982 0.633-0.982 1.284c0 1.1 1.1 0.9 1.1 0.929h1.067c0 0-2.447 4.637-2.726 5.3 c-0.355 0.889-0.416 1.5 0.5 1.955c1.008 0.5 1.659-0.77 1.659-0.77l3.436-6.399H80.71l2.903 5.9 c0 0 1 2 2.1 1.305C86.87 45.3 86.1 44 86.1 44 M66.965 36.374l5.984-12.026c0 0 0.296-0.475 0.6 0.1 c0.296 0.5 6 12 6 11.967H66.965z"></path>      <path class="logo-path" d="M58.314 34.283c0 0 3.87-1.954 3.87-6.575c0-4.622-4.563-7.199-8.294-7.199 h-6.517c0 0-1.512 0.2-1.512 1.744v10.479h-1.833c0 0-0.799-0.094-0.799 1.271c0 1.1 0.6 1.2 0.6 1.173h2.066v9.447 c0 0-0.046 1.5 1.5 1.48h7.213c0 0 6.016-0.165 6.016-6.837C60.57 35.9 58.3 34.3 58.3 34.3 M48.203 22.7 l6.338-0.005c1.718 0 5.1 1.7 5.1 5.451c0 4.443-5.095 4.501-5.095 4.501h-6.338V22.736z M53.557 43.831h-5.351v-8.748 l6.435-0.008c0.858 0 3.5 0.9 3.5 4.031C58.143 43.7 53.6 43.8 53.6 43.8"></path>      <path class="logo-path" d="M146.17 23.033c0 0 1.3 0.1 1.305-1.304c0-1.244-1.305-1.125-1.305-1.125 h-15.818c-2.251 0-2.012 1.717-2.012 1.717V36.54l-1.653 0.009c0 0-1.132 0.229-1.132 1.177c0 1.2 1.1 1.4 1.1 1.361h1.669 v4.917c0 2.5 1.7 2.1 1.7 2.073h15.818c0 0 0.9 0 0.889-1.185s-0.95-1.007-0.95-1.007h-14.798v-4.799h15.284 c0 0 0.937-0.177 0.937-1.361c0-1.186-1.125-1.246-1.125-1.246h-15.228V23.033H146.17z"></path>    </g>  </defs></svg>  <!--<script type="text/javascript" xmlns:th="http://www.thymeleaf.org" th:fragment="body">-->  <!--(function () {-->    <!--var em = document.createElement(\'script\');-->    <!--em.type = \'text/javascript\';-->    <!--em.async = true;-->    <!--em.src =-->      <!--(\'https:\' == document.location.protocol ? \'https://me-ssl\' : \'http://me-cdn\') + \'.effectivemeasure.net/em.js\';-->    <!--var s = document.getElementsByTagName(\'script\')[0];-->    <!--s.parentNode.insertBefore(em, s);-->  <!--}());--><!--</script>-->  <div class="">    <header class="header">      <!-- DESKTOP ADS BLOCK -->      <!-- DESKTOP ADS BLOCK -->      <!-- MOBILE ADS BLOCK -->                  <!-- MOBILE ADS BLOCK -->      <div class="header__top-for-mobile">        <div class="top-bar__triggers">          <a class="main-menu-trigger fa fa-bars fa-2x" href="#main-menu" style="float: right;"></a>          <!-- Logo -->          <div class="header__logo header-logo-margins" onclick="window.location.href=\'/countries/sa\'">              <svg viewBox="0 0 494.387 190.555">    <use xlink:href="#logo-white"></use>  </svg>            </div>          <a class="countries-menu-trigger header-country-margins" href="#countries-menu">            <span>السعودية</span>            <span class="fa fa-caret-down fa-4x"></span>          </a>          <!-- ngRepeat: image in images --><img ng-repeat="image in images" src="/assets/ui/images/mobile-logo-G20.png" class="ng-scope"><!-- end ngRepeat: image in images --><img ng-repeat="image in images" src="/assets/ui/images/mobile-logo-vision.png" class="ng-scope"><!-- end ngRepeat: image in images -->          <div class="header__left-side left-search-icon">            <a class="search-trigger js-search-trigger fa fa-search fa-2x" href="javascript:;" style="float: left;">            </a>          </div>        </div>        <!-- Search -->        <div class="search js-search" id="search">          <i class="fa fa-search fa-2x search__icon"></i>          <angucomplete-alt id="autocomplete__companies" input-class="search__input" minlength="1" ng-controller="AutocompleteController" pause="400" placeholder="اكتب كلمة البحث أو رمز الشركة" selected-object="selectItem" text-no-results="عفواً, لم يتم العثور على أي نتائج" text-searching="جارٍ البحث..." title-field="label" remote-url="/api/1/companySearch?query=" class="ng-scope ng-isolate-scope"><div class="angucomplete-holder" ng-class="{\'angucomplete-dropdown-visible\': showDropdown}">  <input id="autocomplete__companies_value" ng-model="searchStr" ng-disabled="disableInput" type="" placeholder="اكتب كلمة البحث أو رمز الشركة" maxlength="524288" ng-focus="onFocusHandler()" class="search__input ng-valid-maxlength" ng-blur="hideResults($event)" autocapitalize="off" autocorrect="off" autocomplete="off" ng-change="inputChangeHandler(searchStr)">  <div id="autocomplete__companies_dropdown" class="angucomplete-dropdown ng-hide" ng-show="showDropdown"><div class="angucomplete-searching ng-hide" ng-show="searching"><div class="spinner"><div class="dot1"></div><div class="dot2"></div></div></div>    <div class="angucomplete-searching ng-binding" ng-show="!searching &amp;&amp; (!results || results.length == 0)" ng-bind="textNoResults">عفواً, لم يتم العثور على أي نتائج</div>    <!-- ngRepeat: result in results -->  </div></div></angucomplete-alt>        </div>      </div>      <div class="header-desktop mi-show-for-large-up">        <div class="header__top-for-desktop">          <div class="header__top-for-desktop-row">            <a class="header__other-site" href="http://tawasul.mubasher.info/" target="_blank">              <i class="fa fa-caret-right fa-2x"></i>              تواصل            </a>            <a class="header__other-site" href="http://magazine.mubasher.info/" target="_blank">              <i class="fa fa-caret-right fa-2x"></i>              مجلة مباشر            </a>            <a class="header__other-site" href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">              <i class="fa fa-play-circle"></i>              <div style="direction: ltr; display: inline-block;">TV مباشر</div>            </a>                        <a class="header__other-site" href="/contact">              <i class="fa fa-envelope"></i>              اتصل بنا            </a>            <a class="header__other-site" href="/advertise">              <i class="fa fa-envelope"></i>              اعلن معنا            </a>            <!-- <a th:if="${#locale.getLanguage() == \'ar\'}" class="header__login-button" style="background: #458D37 !important;" th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank"                th:text="#{components.header.decypha}">ديسيفا</a>            <a th:if="${#locale.getLanguage() == \'en\'}" class="header__login-button" style="background: #458D37 !important; font-family: Roboto,sans-serif !important;" th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank"                th:text="#{components.header.decypha}">ديسيفا</a> -->            <!-- Page Content Buttons -->            <a class="header__login-button" ng-click="decypha(\'decypha\')" style="background: #458D37 !important; font-family: Roboto,sans-serif !important;">ديسيفا</a>            <!-- Page Content Button -->            <!--Add according to MFP-187-->            <a class="header__login-button" style="background: #00c2d6 !important;" target="_blank" href="https://contest.mubasher.info/#/home">المستثمر اﻷول</a>                        <style>              /*.pulse-logo{*/              /*display: inline-block;*/              /*width: 252px;*/              /*height: 100%;*/              /*background: #212121 url(../images/pulse-logo.png) no-repeat center 2px;*/              /*padding: 10px 50px 29px;*/              /*text-align: center;*/              /*color: black;*/              /*text-decoration: none;*/              /*margin-top: -6px;*/              /*}*/              .pulse-logo2{                padding: 5px 5px 4px;                min-width: 82px;                min-height: 21px;                max-width: 27%;              }            </style>            <a target="_blank" href="https://pulse.mubasher.info">              <img class="pulse-logo2" src="../../../images/pulse-logo.png">            </a>            <span class="header__spacer">              &nbsp;            </span>            <a class="header__social-link" target="_blank" href="https://twitter.com/mubasher"><i class="fa fa-twitter fa-lg"></i></a>            <a class="header__social-link" href="https://www.facebook.com/Mubasher.Info"><i class="fa fa-facebook fa-lg"></i></a>            <a class="header__social-link" href="https://www.youtube.com/channel/UC7hnxb7gD4nKZdZk3ZlZCYg">              <i class="fa fa-youtube fa-lg"></i>            </a>            <a class="header__social-link" href="https://www.linkedin.com/company/1477149">              <i class="fa fa-linkedin fa-lg"></i>            </a>            <a class="header__social-link" href="/news/rss"><i class="fa fa-rss fa-lg"></i></a>            <a class="header__social-link" href="https://play.google.com/store/apps/details?id=net.mis.mubasherinfo">              <i class="fa fa-android fa-lg"></i>            </a>            <a class="header__social-link" href="https://itunes.apple.com/app/imubasher/id494539772?mt=8">              <i class="fa fa-apple fa-lg"></i>            </a>            <a class="header__login-button" href="/account/login">              دخول              <i class="fa fa-user fa-lg"></i>            </a>                                    <a class="header__language" href="https://english.mubasher.info">              <span>ENGLISH</span>            </a>          </div>        </div>        <div class="header__columns">          <div class="header__column1">            <!-- Logo -->            <div class="header__logo-wrapper">              <div class="header__logo" onclick="window.location.href=\'/countries/sa\'">                  <svg viewBox="0 0 494.387 190.555">    <use xlink:href="#logo"></use>  </svg>                </div>              <div class="countries-menu-trigger">                <a href="javascript:;" id="mi-js-countries-menu-trigger">                  <span>السعودية</span>                  <span class="fa fa-caret-down"></span>                </a>                <nav class="header__countries-menu--desktop mi-js-countries-menu-desktop" style="">                  <ul>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=ae&amp;url=/countries/sa/companies">الإمارات</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=bh&amp;url=/countries/sa/companies">البحرين</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=om&amp;url=/countries/sa/companies">عُمان</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=qa&amp;url=/countries/sa/companies">قطر</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=kw&amp;url=/countries/sa/companies">الكويت</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=eg&amp;url=/countries/sa/companies">مصر</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=jo&amp;url=/countries/sa/companies">الأردن</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=tn&amp;url=/countries/sa/companies">تونس</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=ma&amp;url=/countries/sa/companies">المغرب</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=ps&amp;url=/countries/sa/companies">فلسطين</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=iq&amp;url=/countries/sa/companies">العراق</a>                    </li>                  </ul>                </nav>              </div>            </div>            <!--Market Status -->            <div class="header__market-status">              <div class="header__market-status-column">                <div class="header__market-status-row">                  <a class="header__market-name" href="/markets/TDWL">TDWL</a>                  <span class="header__market-status--close">مغلق</span>                </div>                              </div>              <span class="header__market-time">12 أغسطس 04:49 م</span>            </div>          </div>          <div class="header__column1 banner-logo-desktop" ng-class="{\'banner-desktop-en\':(getLanguage == \'en\')}">            <!-- Logo -->            <div class="header__logo-wrapper">              <!-- ngRepeat: image in images --><div class="header__logo ng-scope" ng-repeat="image in images">                  <div class="tooltip tooltipstered"><img src="/assets/ui/images/logo-G20.png">                    <span class="tooltiptext ng-binding" ng-class="{\'tooltip-desktop-en\':(getLanguage == \'en\')}" style="left: 95%">مجموعة العشرين 2020</span>                  </div>              </div><!-- end ngRepeat: image in images --><div class="header__logo ng-scope" ng-repeat="image in images">                  <div class="tooltip tooltipstered"><img src="/assets/ui/images/logo-vision.png">                    <span class="tooltiptext ng-binding" ng-class="{\'tooltip-desktop-en\':(getLanguage == \'en\')}" style="left: 95%">رؤية المملكة العربية السعودية 2030</span>                  </div>              </div><!-- end ngRepeat: image in images -->            </div>          </div><!--          <div class="header__column2">             &lt;!&ndash;<div th:replace="components/ads/news/dfp/desktop/LB2"/>&ndash;&gt;            &lt;!&ndash;=====to display default leaderboard ad-slot [728,90] ======&ndash;&gt;            <div th:if="${isHomePage}">              <div th:replace="components/ads/home/leaderboard"/>            </div>            <div th:unless="${isHomePage}">              <div>                <iframe id="leaderboard-ros-001" style="width: 736px; height: 108px;" class="ad-iframe" src="/ads/LB2"></iframe>              </div>            </div>            </div>-->           <!--======= billboard 790x250 ============ -->        </div>        <nav class="header__navigation mi-js-desktop-menu-container">          <ul class="dl-menu mi-show-for-large-up mi-js-desktop-menu">            <li class="dl-menu__menu-item dl-menu__menu-item--iconic-item">              <a href="/countries/sa">                <i class="fa fa-home fa-2x"></i>              </a>            </li>            <li class="dl-menu__menu-item" id="markets">              <a href="javascript:;">الأسواق</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/markets/TDWL">سوق الأسهم السعودي</a>                    </li>                    <li>                      <a href="/markets/EGX">البورصة المصرية</a>                    </li>                    <li>                      <a href="/markets/DFM">سوق دبي المالي</a>                    </li>                    <li>                      <a href="/markets/ADX">سوق أبوظبي</a>                    </li>                    <li>                      <a href="/markets/BB">بورصة البحرين</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/markets/QE">بورصة قطر</a>                    </li>                    <li>                      <a href="/markets/MSM">سوق مسقط</a>                    </li>                    <li>                      <a href="/markets/BK">سوق الكويت</a>                    </li>                    <li>                      <a href="/markets/ASE">بورصة عمان</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/markets/CSE">سوق الدار البيضاء</a>                    </li>                    <li>                      <a href="/markets/BDT">بورصة تونس</a>                    </li>                    <li>                      <a href="/markets/PEX">سوق فلسطين</a>                    </li>                    <li>                      <a href="/markets/ISX">سوق العراق</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/international-indices">مؤشرات الأسواق العالمية</a>                    </li>                    <li>                      <a href="/markets/commodities-prices">أسعار المعادن والطاقة</a>                    </li>                    <li>                      <a href="/countries/sa/currencies">أسعار العملات</a>                    </li>                    <!--<li>                      <a th:href="${@url.to(\'RMPC#regionalMap\')}"                         th:text="#{navigation.markets.regional-map}"/>                    </li>-->                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item" id="news">              <a href="javascript:;">الأخبار</a>              <div class="mi-js-submenu">                <ul class="dl-submenu">                  <li>                    <a href="javascript:;">يحدث الآن</a>                    <div class="nav-column">                      <h3>يحدث الآن</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/sa/now/top">أهم الأخبار</a>                        </li>                        <li>                          <a href="/news/sa/now/exclusive">حصرياً مباشر</a>                        </li>                        <li>                          <a href="/news/sa/now/latest">آخر الأخبار</a>                        </li>                                                  <li>                            <a href="/news/sa/now/announcements">إعلانات السوق</a>                          </li>                                                                          <li class="global__hide-for-ltr">                          <a href="/news/sa/now/popular">منتشر الآن</a>                        </li>                        <li>                          <a href="/news/sa/now/trending/">الأكثر مشاركة</a>                        </li>                        <li>                          <a href="/news/now/news-releases">بيانات صحفية</a>                        </li>                        <li>                          <a href="/news/international/misc">أخبار منوعة</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">نبض السوق</a>                    <div class="nav-column">                      <h3>نبض السوق</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/sa/pulse/stocks">أخبار الأسهم</a>                        </li>                        <li>                          <a href="/news/sa/pulse/analysis">تحليلات إخبارية</a>                        </li>                        <li>                          <a href="/news/sa/pulse/local">اقتصاد محلي</a>                        </li>                        <li>                          <a href="/news/sa/pulse/recommendations">توصيات</a>                        </li>                      </ul>                      <h3>أخبار القطاعات</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/sa/category/banking">بنوك</a>                        </li><li>                          <a href="/news/sa/category/realEstate">عقارات</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">أخبار الدول</a>                    <div class="nav-column">                      <h3>أخبار الدول</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/eg/now/latest">مصر</a>                        </li>                        <li>                          <a href="/news/sa/now/latest">السعودية</a>                        </li>                        <li>                          <a href="/news/ae/now/latest">الإمارات</a>                        </li>                        <li>                          <a href="/news/bh/now/latest">البحرين</a>                        </li>                        <li>                          <a href="/news/qa/now/latest">قطر</a>                        </li>                        <li>                          <a href="/news/om/now/latest">عمان</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">أخبار الدول</a>                    <div class="nav-column">                      <h3 class="invisible">أخبار الدول</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/kw/now/latest">الكويت</a>                        </li>                        <li>                          <a href="/news/jo/now/latest">الأردن</a>                        </li>                        <li>                          <a href="/news/ma/now/latest">المغرب</a>                        </li>                        <li>                          <a href="/news/tn/now/latest">تونس</a>                        </li>                        <li>                          <a href="/news/ps/now/latest">فلسطين</a>                        </li>                        <li>                          <a href="/news/iq/now/latest">العراق</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">أخبار إقليمية</a>                    <div class="nav-column">                      <h3>أخبار إقليمية</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/regions/gulf">الخليج</a>                        </li>                        <li>                          <a href="/news/regions/levant">الشام</a>                        </li>                        <li>                          <a href="/news/regions/north-africa">شمال أفريقيا</a>                        </li>                        <li>                          <a href="/news/regions/middle-east">الشرق الأوسط</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">أخبار عالمية</a>                    <div class="nav-column">                      <h3>أخبار عالمية</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/international/global-economy">اقتصاد عالمى</a>                        </li>                        <li>                          <a href="/news/international/goods-and-metals">أحداث عالمية</a>                        </li>                        <li>                          <a href="/news/international/global-indices">مؤشرات عالمية</a>                        </li>                        <li>                          <a href="/news/international/oil-and-energy">نفط ومعادن</a>                        </li>                        <li>                          <a href="/news/international/currencies">عملات</a>                        </li>                        <li>                          <a href="/news/international/global-reports">تقارير عالمية</a>                        </li>                      </ul>                    </div>                  </li>                </ul>              </div>            </li>            <li class="dl-menu__menu-item" id="companies">              <a href="javascript:;">الشركات</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <h3 class="invisible">.</h3>                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/companies">الشركات المدرجة</a>                    </li>                    <li>                      <a href="/countries/sa/events">مفكرة الشركات</a>                    </li>                    <li>                      <a href="/countries/sa/stock-prices">أسعار الأسهم</a>                    </li>                    <li>                      <a href="/countries/sa/fair-values">القيم العادلة</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <h3 class="invisible">.</h3>                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/earnings">إعلانات الأرباح</a>                    </li>                    <li>                      <a href="/countries/sa/corporate-action">الإجراءات</a>                    </li>                                        <li>                      <a href="/countries/sa/major-shareholders">كبار الملاك</a>                    </li>                    <li>                      <a href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <h3>الاكتتابات</h3>                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/ipos">قائمة الإكتتابات</a>                    </li>                    <li>                      <a href="/ipo/list">بحث فى الاكتتابات</a>                    </li>                    <li>                      <a href="/ipos/news">أخبار الاكتتابات</a>                    </li>                    <li>                      <a href="/ipo/calendar">مفكرة الاكتتابات</a>                    </li>                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item" id="funds">              <a href="javascript:;">صناديق الاستثمار</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/funds">صناديق الاستثمار</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/funds-statistics">إحصائيات الصناديق</a>                    </li>                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item" id="analysis-tools">              <a href="javascript:;">أدوات التحليل</a>              <!-- If current country has one market only -->              <div class="mi-js-submenu">                                  <div class="nav-column">                    <ul class="dl-submenu">                      <li>                        <a href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>                      </li>                      <li>                        <a href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>                      </li>                      <li>                        <a href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>                      </li>                    </ul>                  </div>                  <div class="nav-column">                    <ul class="dl-submenu">                      <li>                        <a href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>                      </li>                      <li>                        <a href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>                      </li>                      <li>                        <a href="/analysis-tools/performance-comparison">مقارنة الأداء</a>                      </li>                    </ul>                  </div>                                              </div>            </li>            <li class="dl-menu__menu-item" id="islamic-economy">              <a href="/news/islamic-finance">الاقتصاد الإسلامي</a>            </li>            <!--<li id="radio"                class="dl-menu__menu-item global__hide-for-ltr"                id="radio"                th:if="${#locale.getLanguage() == \'ar\'}">              <a href="javascript:;" th:text="#{navigation.radio}"/>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a th:href="${@url.to(\'RPC#live\')}" th:text="#{navigation.radio.live}"/>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#latestEpisodesPage\', countryCode)}">آخر الحلقات</a>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تقارير-اقتصادية\'}">تقارير                        اقتصادية</a>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تغطية-خاصة\'}">تغطية خاصة</a>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'مقالات\'}">مقالات</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a th:href="${@url.to(\'RPC#programs\')}" th:text="#{navigation.radio.programs}"/>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#videoPrograms\')}" th:text="#{navigation.radio.videoPrograms}"/>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#getExperts\')}">ضيوفنا</a>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#getPresenters\')}">المذيعون</a>                    </li>                  </ul>                </div>              </div>            </li>-->            <li class="dl-menu__menu-item global__hide-for-ltr" id="video">              <a href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">مباشر TV</a>            </li>                        <li class="dl-menu__menu-item" id="fixedincome">              <a href="javascript:;">السندات</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/fixedincome/bond/search" id="fixedIncomeBondScreener">بحث عن سندات</a>                    </li>                    <li>                      <a href="/fixed-income/news" id="fixedIncomeNews">أخبار السندات وأذون الخزانة</a>                    </li>                    <li>                      <a href="/fixedincome/calendar/searchForEvent" id="fixedIncomeCalendar">قائمة الأحداث</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/fixedincome/analytics/drawCurve" id="fixedIncomeAnalytics">تحليلات فنية</a>                    </li>                    <li>                      <a href="/fixedincome/leagueTables/view" id="fixedIncomeLeagueTables">جداول الديون</a>                    </li>                    <li>                      <a href="/fixedincome/research/search" id="fixedIncomeProspectus">تقارير</a>                    </li>                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item" id="personal">              <a href="javascript:;">شخصي</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/my/alerts">التنبيهات</a>                    </li>                    <li>                      <a href="/my/watch-list">أسهمي</a>                    </li>                    <li>                      <a href="/my/newsletters">النشرة البريدية</a>                    </li>                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item dl-menu__menu-item--iconic-item">              <a class="js-search-trigger" href="javascript:;">                <i class="fa fa-search fa-2x"></i>              </a>            </li>          </ul>          <!-- Search -->          <div class="search js-search js-desktop-search" id="search">            <angucomplete-alt id="autocomplete__companies" input-class="search__input" minlength="1" ng-controller="AutocompleteController" pause="400" selected-object="selectItem" text-no-results="عفواً, لم يتم العثور على أي نتائج" text-searching="جارٍ البحث..." title-field="label" remote-url="/api/1/companySearch?query=" placeholder="اكتب كلمة البحث أو رمز الشركة" class="ng-scope ng-isolate-scope"><div class="angucomplete-holder" ng-class="{\'angucomplete-dropdown-visible\': showDropdown}">  <input id="autocomplete__companies_value" ng-model="searchStr" ng-disabled="disableInput" type="" placeholder="اكتب كلمة البحث أو رمز الشركة" maxlength="524288" ng-focus="onFocusHandler()" class="search__input ng-valid-maxlength" ng-blur="hideResults($event)" autocapitalize="off" autocorrect="off" autocomplete="off" ng-change="inputChangeHandler(searchStr)">  <div id="autocomplete__companies_dropdown" class="angucomplete-dropdown ng-hide" ng-show="showDropdown"><div class="angucomplete-searching ng-hide" ng-show="searching"><div class="spinner"><div class="dot1"></div><div class="dot2"></div></div></div>    <div class="angucomplete-searching ng-binding" ng-show="!searching &amp;&amp; (!results || results.length == 0)" ng-bind="textNoResults">عفواً, لم يتم العثور على أي نتائج</div>    <!-- ngRepeat: result in results -->  </div></div></angucomplete-alt>            <i class="fa fa-search fa-2x"></i>          </div>        </nav>      </div>    </header>    <div id="Leaderboard">    </div>    <div></div>    <div class="mi-content">      <div>  <!--<div th:replace="components/ads/internal/mobile-banner" />-->  <main class="mi-main-content">      <h1 class="mi-section__title">الشركات المدرجة</h1>  <div class="mi-table-container ng-scope" ng-controller="PagedTableController as table" country="sa" src="/api/1/listed-companies">    <div class="global__table-container md-whiteframe-z1 ng-isolate-scope" st-init="" st-pipe="fetch" st-table="table.data">      <span class="global__no-results ng-hide" ng-show="table.rows.length == 0 &amp;&amp; table.loaded">عفواّ, لم نعثر على أى نتائج</span>      <table class="mi-table" ng-hide="!table.loaded || table.rows.length == 0" style="">        <thead class="mi-table__thead">          <tr class="mi-table__thead-tr">            <th st-ratio="20" style="width: 20%;">الشركة</th>            <th>السهم</th>            <th class="mi-hide-for-small">القطاع</th>                        <th>آخر سعر</th>            <th>نسبة التغيير</th>            <th class="mi-hide-for-small">آخر تحديث</th>          </tr>        </thead>        <tbody class="mi-table__tbody" ng-hide="table.reloading">          <!-- ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/2001/profile" class="ng-binding" href="/markets/TDWL/stocks/2001/profile">كيمانول</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/2001" class="ng-binding" href="/markets/TDWL/stocks/2001">2001</a>            </td>            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>                        <td class="number ng-binding">8.13</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.62%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/1212/profile" class="ng-binding" href="/markets/TDWL/stocks/1212/profile">أسترا الصناعية</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/1212" class="ng-binding" href="/markets/TDWL/stocks/1212">1212</a>            </td>            <td class="mi-hide-for-small ng-binding">السلع الرأسمالية</td>                        <td class="number ng-binding">21.72</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -1.27%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/2002/profile" class="ng-binding" href="/markets/TDWL/stocks/2002/profile">بتروكيم</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/2002" class="ng-binding" href="/markets/TDWL/stocks/2002">2002</a>            </td>            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>                        <td class="number ng-binding">26.5</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -1.30%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/4310/profile" class="ng-binding" href="/markets/TDWL/stocks/4310/profile">مدينة المعرفة</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4310" class="ng-binding" href="/markets/TDWL/stocks/4310">4310</a>            </td>            <td class="mi-hide-for-small ng-binding">إدارة وتطوير العقارات</td>                        <td class="number ng-binding">9.35</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.64%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/6002/profile" class="ng-binding" href="/markets/TDWL/stocks/6002/profile">هرفي للأغذية</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/6002" class="ng-binding" href="/markets/TDWL/stocks/6002">6002</a>            </td>            <td class="mi-hide-for-small ng-binding">الخدمات الإستهلاكية</td>                        <td class="number ng-binding">47.8</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.74%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/3091/profile" class="ng-binding" href="/markets/TDWL/stocks/3091/profile">أسمنت الجوف</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/3091" class="ng-binding" href="/markets/TDWL/stocks/3091">3091</a>            </td>            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>                        <td class="number ng-binding">9.32</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.54%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/3001/profile" class="ng-binding" href="/markets/TDWL/stocks/3001/profile">أسمنت حائل</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/3001" class="ng-binding" href="/markets/TDWL/stocks/3001">3001</a>            </td>            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>                        <td class="number ng-binding">13.24</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.46%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/3002/profile" class="ng-binding" href="/markets/TDWL/stocks/3002/profile">أسمنت نجران</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/3002" class="ng-binding" href="/markets/TDWL/stocks/3002">3002</a>            </td>            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>                        <td class="number ng-binding">11.8</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.34%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/6004/profile" class="ng-binding" href="/markets/TDWL/stocks/6004/profile">التموين</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/6004" class="ng-binding" href="/markets/TDWL/stocks/6004">6004</a>            </td>            <td class="mi-hide-for-small ng-binding">الخدمات التجارية والمهنية</td>                        <td class="number ng-binding">83.3</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -1.07%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/8290/profile" class="ng-binding" href="/markets/TDWL/stocks/8290/profile">سوليدرتي تكافل</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8290" class="ng-binding" href="/markets/TDWL/stocks/8290">8290</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">14.34</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              1.41%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/8250/profile" class="ng-binding" href="/markets/TDWL/stocks/8250/profile">اكسا التعاونية</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8250" class="ng-binding" href="/markets/TDWL/stocks/8250">8250</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">40.25</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.12%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/8240/profile" class="ng-binding" href="/markets/TDWL/stocks/8240/profile">تْشب</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8240" class="ng-binding" href="/markets/TDWL/stocks/8240">8240</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">24.38</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.81%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/8230/profile" class="ng-binding" href="/markets/TDWL/stocks/8230/profile">تكافل الراجحي</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8230" class="ng-binding" href="/markets/TDWL/stocks/8230">8230</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">74.2</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.67%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/8270/profile" class="ng-binding" href="/markets/TDWL/stocks/8270/profile">بروج للتأمين</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8270" class="ng-binding" href="/markets/TDWL/stocks/8270">8270</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">18.22</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.11%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/1320/profile" class="ng-binding" href="/markets/TDWL/stocks/1320/profile">أنابيب السعودية</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/1320" class="ng-binding" href="/markets/TDWL/stocks/1320">1320</a>            </td>            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>                        <td class="number ng-binding">17.68</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.11%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/8260/profile" class="ng-binding" href="/markets/TDWL/stocks/8260/profile">الخليجية العامة</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8260" class="ng-binding" href="/markets/TDWL/stocks/8260">8260</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">12.66</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              2.26%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/8280/profile" class="ng-binding" href="/markets/TDWL/stocks/8280/profile">العالمية</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8280" class="ng-binding" href="/markets/TDWL/stocks/8280">8280</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">18.32</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.66%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/4002/profile" class="ng-binding" href="/markets/TDWL/stocks/4002/profile">المواساة</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4002" class="ng-binding" href="/markets/TDWL/stocks/4002">4002</a>            </td>            <td class="mi-hide-for-small ng-binding">الرعاية الصحية</td>                        <td class="number ng-binding">108.2</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -3.22%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/1214/profile" class="ng-binding" href="/markets/TDWL/stocks/1214/profile">شاكر</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/1214" class="ng-binding" href="/markets/TDWL/stocks/1214">1214</a>            </td>            <td class="mi-hide-for-small ng-binding">تجزئة السلع الكمالية</td>                        <td class="number ng-binding">12.42</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.48%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/1213/profile" class="ng-binding" href="/markets/TDWL/stocks/1213/profile">نسيج</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/1213" class="ng-binding" href="/markets/TDWL/stocks/1213">1213</a>            </td>            <td class="mi-hide-for-small ng-binding">السلع طويلة الاجل</td>                        <td class="number ng-binding">13.72</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              1.33%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index -->        </tbody>      </table>      <div ng-show="table.searcing" class="ng-hide">        <span class="global__loading">جارى التصفية, يرجى الإنتظار ...</span>        <div>    <div class="sk-spinner sk-spinner-wave">        <div class="sk-rect1"></div>        <div class="sk-rect2"></div>        <div class="sk-rect3"></div>        <div class="sk-rect4"></div>        <div class="sk-rect5"></div>    </div></div>      </div>      <div ng-hide="table.loaded" class="ng-hide" style="">        <div>    <div class="sk-spinner sk-spinner-wave">        <div class="sk-rect1"></div>        <div class="sk-rect2"></div>        <div class="sk-rect3"></div>        <div class="sk-rect4"></div>        <div class="sk-rect5"></div>    </div></div>      </div>      <div st-items-by-page="20" st-pagination="" st-template="/assets/ui/ngt/components/pagination/pagination.ng.html" class="ng-isolate-scope"><!-- ngIf: pages.length >= 2 --><div class="pagination ng-scope" ng-if="pages.length >= 2">    <nav role="navigation" aria-label="Pagination">        <ul class="cd-pagination no-space" role="menubar" aria-label="Pagination">            <!-- ngIf: currentPage > 1 --><li ng-if="currentPage > 1" class="ng-scope">                <a ng-click="selectPage(1)">                    <i class="fa fa-angle-double-right fa-lg"></i>                </a>            </li><!-- end ngIf: currentPage > 1 -->            <!-- ngIf: currentPage > 1 --><li class="cd-pagination__button ng-scope" aria-disabled="true" ng-if="currentPage > 1">                <a ng-click="selectPage(currentPage-1)" class="ng-binding">                  <i class="fa fa-lg fa-angle-right"></i>                  السابق                </a>            </li><!-- end ngIf: currentPage > 1 -->            <!-- ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">                <a ng-click="selectPage(page)" class="ng-binding">5</a>            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">                <a ng-click="selectPage(page)" class="ng-binding">6</a>            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope current">                <a ng-click="selectPage(page)" class="ng-binding">7</a>            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">                <a ng-click="selectPage(page)" class="ng-binding">8</a>            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">                <a ng-click="selectPage(page)" class="ng-binding">9</a>            </li><!-- end ngRepeat: page in pages -->            <!-- ngIf: currentPage < numPages --><li class="cd-pagination__button ng-scope" ng-if="currentPage < numPages">                <a ng-click="selectPage(currentPage+1)" href="" class="ng-binding">                  التالي                    <i class="fa fa-angle-left fa-lg"></i>                </a>            </li><!-- end ngIf: currentPage < numPages -->            <!-- ngIf: currentPage < numPages --><li ng-if="currentPage < numPages" class="ng-scope">                <a ng-click="selectPage(numPages)">                    <i class="fa fa-angle-double-left  fa-lg"></i>                </a>            </li><!-- end ngIf: currentPage < numPages -->        </ul>    </nav></div><!-- end ngIf: pages.length >= 2 --></div>    </div>  </div>    <!-- Speakol Widget - Removal IB-51 -->  <!-- <div th:replace="components/ads/common/speakol-one"/> -->  </main>  <aside class="mi-sidebar mi-show-for-large-up">    <!-- Radio component doesn\'t exist in English version -->    <!---->  <!--  <div th:unless="${device.isMobile()}">      <div>        <iframe onload="adjustIframeSize(this);" class="ad-iframe" src="/ads/side-bar"></iframe>      </div>      <script>        function adjustIframeSize(self) {          var index = 0;          var interval = setInterval( function(){            if (index < 3) {              self.style.height=self.contentDocument.body.scrollHeight +10 + \'px\';self.style.width=\'310px\';              index = index + 1;            } else {              clearInterval(interval)            }          }, 1);        }      </script>    </div>-->    <div>    <div class="mi-popular-news news-sidebar-mub md-whiteframe-z1 ng-scope" ng-controller="PopularNewsController as popular">    <h2 class="global__h2--collapsed">الأخبار الأكثر</h2>    <v-tabs active="tabs.active" class="vTabs--secondary ng-isolate-scope" control="tabs">      <!-- ngRepeat: page in popular.pages --><v-tab ng-bind="page.title" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope is-active" role="tab" aria-selected="true" tabindex="0">قراءة</v-tab><!-- end ngRepeat: page in popular.pages --><v-tab ng-bind="page.title" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope" role="tab" aria-selected="false" tabindex="-1">مشاركة</v-tab><!-- end ngRepeat: page in popular.pages -->    </v-tabs>    <v-pages active="tabs.active" class="vPages--default ng-isolate-scope" control="tabs" ng-swipe-left="tabs.next()" ng-swipe-right="tabs.previous()">      <!-- ngRepeat: page in popular.pages --><v-page ng-bind-html="page.content | unsafe" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope is-active" role="tabpanel">        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3680410/%D9%87%D9%8A%D8%A6%D8%A9-%D8%A7%D9%84%D9%86%D9%82%D9%84-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%B5%D8%B1%D9%81-%D8%AF%D8%B9%D9%85-%D8%A7%D9%84%D8%A3%D9%81%D8%B1%D8%A7%D8%AF-%D8%A7%D9%84%D8%B9%D8%A7%D9%85%D9%84%D9%8A%D9%86-%D9%81%D9%8A-%D9%86%D8%B4%D8%A7%D8%B7-%D8%AA%D9%88%D8%AC%D9%8A%D9%87-%D8%A7%D9%84%D9%85%D8%B1%D9%83%D8%A8%D8%A7%D8%AA-%D9%82%D8%B1%D9%8A%D8%A8%D8%A7-/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="فرع تابع لهيئة العامة للنقل السعودية" src="https://static.mubasher.info/File.Story_Image/3e19073c5aca3db54ef2c06eb4bf5ea6/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3680410/%D9%87%D9%8A%D8%A6%D8%A9-%D8%A7%D9%84%D9%86%D9%82%D9%84-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%B5%D8%B1%D9%81-%D8%AF%D8%B9%D9%85-%D8%A7%D9%84%D8%A3%D9%81%D8%B1%D8%A7%D8%AF-%D8%A7%D9%84%D8%B9%D8%A7%D9%85%D9%84%D9%8A%D9%86-%D9%81%D9%8A-%D9%86%D8%B4%D8%A7%D8%B7-%D8%AA%D9%88%D8%AC%D9%8A%D9%87-%D8%A7%D9%84%D9%85%D8%B1%D9%83%D8%A8%D8%A7%D8%AA-%D9%82%D8%B1%D9%8A%D8%A8%D8%A7-/">هيئة النقل السعودية: صرف دعم الأفراد العاملين في نشاط توجيه المركبات قريباً</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3680099/%D8%A7%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D8%B5%D8%AF%D8%B1-%D9%82%D8%B1%D8%A7%D8%B1%D8%A7-%D8%A8%D8%B4%D8%A3%D9%86-%D8%A7%D9%84%D9%85%D8%A8%D8%AA%D8%B9%D8%AB%D9%8A%D9%86/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="وزير التعليم السعودي، حمد بن محمد آل الشيخ، أرشيفية" src="https://static.mubasher.info/File.Story_Image/9e9e9919f67b43d61c15c7fd734289d3/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3680099/%D8%A7%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D8%B5%D8%AF%D8%B1-%D9%82%D8%B1%D8%A7%D8%B1%D8%A7-%D8%A8%D8%B4%D8%A3%D9%86-%D8%A7%D9%84%D9%85%D8%A8%D8%AA%D8%B9%D8%AB%D9%8A%D9%86/">التعليم السعودية تصدر قراراً بشأن المبتعثين</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3680101/%D9%85%D8%AD%D8%AF%D8%AB-%D8%A7%D9%84%D8%B0%D9%87%D8%A8-%D9%8A%D8%AA%D9%87%D8%A7%D9%88%D9%89-93-%D8%AF%D9%88%D9%84%D8%A7%D8%B1%D8%A7-%D8%B9%D9%86%D8%AF-%D8%A7%D9%84%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D9%85%D8%B9-%D9%85%D9%83%D8%A7%D8%B3%D8%A8-%D8%A7%D9%84%D8%A3%D8%B3%D9%87%D9%85/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/caeadbca5bf2481c2d38f04625e51f00/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3680101/%D9%85%D8%AD%D8%AF%D8%AB-%D8%A7%D9%84%D8%B0%D9%87%D8%A8-%D9%8A%D8%AA%D9%87%D8%A7%D9%88%D9%89-93-%D8%AF%D9%88%D9%84%D8%A7%D8%B1%D8%A7-%D8%B9%D9%86%D8%AF-%D8%A7%D9%84%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D9%85%D8%B9-%D9%85%D9%83%D8%A7%D8%B3%D8%A8-%D8%A7%D9%84%D8%A3%D8%B3%D9%87%D9%85/">محدث.. الذهب يتهاوى 93 دولاراً عند التسوية مع مكاسب الأسهم</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3679355/%D8%A7%D9%84%D9%84%D9%8A%D8%B1%D8%A9-%D8%A7%D9%84%D8%AA%D8%B1%D9%83%D9%8A%D8%A9-%D8%AA%D9%87%D8%A8%D8%B7-%D8%A5%D9%84%D9%89-%D9%85%D8%B3%D8%AA%D9%88%D9%89-%D8%AA%D8%A7%D8%B1%D9%8A%D8%AE%D9%8A-%D8%AC%D8%AF%D9%8A%D8%AF/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/1242bfad1995396ce3f6470a3d5584c2/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3679355/%D8%A7%D9%84%D9%84%D9%8A%D8%B1%D8%A9-%D8%A7%D9%84%D8%AA%D8%B1%D9%83%D9%8A%D8%A9-%D8%AA%D9%87%D8%A8%D8%B7-%D8%A5%D9%84%D9%89-%D9%85%D8%B3%D8%AA%D9%88%D9%89-%D8%AA%D8%A7%D8%B1%D9%8A%D8%AE%D9%8A-%D8%AC%D8%AF%D9%8A%D8%AF/">الليرة التركية تهبط إلى مستوى تاريخي جديد</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3679705/%D8%B9%D9%85%D9%84%D8%A9-%D8%A7%D9%84%D8%A8%D9%8A%D8%AA%D9%83%D9%88%D9%8A%D9%86-%D8%AA%D8%B9%D8%A7%D9%88%D8%AF-%D8%A7%D9%84%D8%B5%D8%B9%D9%88%D8%AF-%D8%A3%D8%B9%D9%84%D9%89-12-%D8%A3%D9%84%D9%81-%D8%AF%D9%88%D9%84%D8%A7%D8%B1/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/ab491b6531081c6058fa5b203b6cbecc/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3679705/%D8%B9%D9%85%D9%84%D8%A9-%D8%A7%D9%84%D8%A8%D9%8A%D8%AA%D9%83%D9%88%D9%8A%D9%86-%D8%AA%D8%B9%D8%A7%D9%88%D8%AF-%D8%A7%D9%84%D8%B5%D8%B9%D9%88%D8%AF-%D8%A3%D8%B9%D9%84%D9%89-12-%D8%A3%D9%84%D9%81-%D8%AF%D9%88%D9%84%D8%A7%D8%B1/">عملة البيتكوين تعاود الصعود أعلى 12 ألف دولار</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3679783/%D8%A3%D8%B1%D8%A7%D9%85%D9%83%D9%88-%D8%AA%D8%B1%D9%81%D8%B9-%D8%A3%D8%B3%D8%B9%D8%A7%D8%B1-%D8%A7%D9%84%D8%A8%D9%86%D8%B2%D9%8A%D9%86-%D8%A8%D9%86%D8%AD%D9%88-11-%D8%AD%D8%AA%D9%89-10-%D8%B3%D8%A8%D8%AA%D9%85%D8%A8%D8%B1/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="محطة للتزود بالوقود" src="https://static.mubasher.info/File.Story_Image/cf61a8737c62c57737e53b3677aa2bbc/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3679783/%D8%A3%D8%B1%D8%A7%D9%85%D9%83%D9%88-%D8%AA%D8%B1%D9%81%D8%B9-%D8%A3%D8%B3%D8%B9%D8%A7%D8%B1-%D8%A7%D9%84%D8%A8%D9%86%D8%B2%D9%8A%D9%86-%D8%A8%D9%86%D8%AD%D9%88-11-%D8%AD%D8%AA%D9%89-10-%D8%B3%D8%A8%D8%AA%D9%85%D8%A8%D8%B1/">أرامكو ترفع أسعار البنزين بنحو 11% حتى 10 سبتمبر</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3680546/%D8%A8%D9%803-%D8%B6%D9%88%D8%A7%D8%A8%D8%B7-%D8%A7%D9%84%D8%AA%D9%82%D8%A7%D8%B9%D8%AF-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D9%88%D8%B6%D8%AD-%D8%B7%D8%B1%D9%8A%D9%82%D8%A9-%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D8%A7%D9%84%D9%85%D8%B9%D8%A7%D8%B4-%D9%84%D9%85%D9%88%D8%B8%D9%81%D9%8A-%D8%A7%D9%84%D9%82%D8%B7%D8%A7%D8%B9-%D8%A7%D9%84%D8%B9%D8%A7%D9%85/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="مؤسسة التقاعد السعودية" src="https://static.mubasher.info/File.Story_Image/68cc490a847f0daba3afd0ddbd6d06c8/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3680546/%D8%A8%D9%803-%D8%B6%D9%88%D8%A7%D8%A8%D8%B7-%D8%A7%D9%84%D8%AA%D9%82%D8%A7%D8%B9%D8%AF-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D9%88%D8%B6%D8%AD-%D8%B7%D8%B1%D9%8A%D9%82%D8%A9-%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D8%A7%D9%84%D9%85%D8%B9%D8%A7%D8%B4-%D9%84%D9%85%D9%88%D8%B8%D9%81%D9%8A-%D8%A7%D9%84%D9%82%D8%B7%D8%A7%D8%B9-%D8%A7%D9%84%D8%B9%D8%A7%D9%85/">بـ3 ضوابط.. التقاعد السعودية توضح طريقة تسوية المعاش لموظفي القطاع العام</a>        </div>              </div>        <a class="mi-article-widget__more-button" href="/news/SA/now/popular">      <span>المزيد</span>      <i class="fa fa-chevron-left"></i>    </a>    </v-page><!-- end ngRepeat: page in popular.pages --><v-page ng-bind-html="page.content | unsafe" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope" role="tabpanel">            <a class="mi-article-widget__more-button" href="/news/SA/now/trending/">      <span>المزيد</span>      <i class="fa fa-chevron-left"></i>    </a>    </v-page><!-- end ngRepeat: page in popular.pages -->    </v-pages>  </div>    <div id="MPU">    </div>    </div>    <!-- Speakol Widget - Removal IB-51 -->    <!-- <div th:replace="components/ads/common/speakol-two"/> --><!--    <div th:unless="${device.isMobile()}">      <div th:replace="components/ads/insticator/insticator-widget"/>    </div>-->    <!-- -->    <!-- PS -->    <!--<div th:replace="components/ads/internal/may-like-articles" />-->    <!--<div th:replace="components/ads/internal/second-fold" />-->    <!--    <div th:if="${#locale.getLanguage() == \'ar\'}">          <span class="home__title">راديو مباشر</span>          <div class="internal-radio-carousel-container"></div>        </div>-->  </aside><!--  <div th:replace="components/ads/internal/mobile-fullpage"/>-->  <!--<div th:replace="components/ads/internal/mobile-interstitial"/>--><!--commented out as per Fayoumi\'s request-->  <!--<div th:replace="components/ads/internal/mobile-outstream"/>-->  <!--MFP-228 New Fixed-Replacement-ROS ads--><!--  <div th:replace="components/ads/home/mobile-fixed-replacement"/>  <div th:replace="components/ads/news/dfp/mobile/MPU3"/>--><!--Commented out as per Fayoumi\'s request-->  <!--<div th:replace="components/ads/internal/outstream"/>--><!--  <div th:if="${device.isMobile()}">    <div th:replace="components/ads/dfp/mobile-internal-pages"/>  </div>--><!--  <div th:if="${device.isMobile()}">    <div th:replace="components/ads/insticator/insticator-widget"/>  </div>--> <!-- <div th:replace="components/ads/internal/mobile-above-footer"/>--></div>    </div>    <footer>  <div class="mi-footer">    <div class="mi-show-for-large-up mi-footer__main-menu">      <ul>        <li class="mi-footer__menu-item mi-footer__menu__markets" id="markets">          <div class="mi-footer__menu-level1">الأسواق</div>          <ul>            <h3 class="mi-footer__menu-level2 invisible">الأسواق</h3>            <li>              <a class="mi-footer__menu-level3" href="/markets/TDWL">سوق الأسهم السعودي</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/EGX">البورصة المصرية</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/DFM">سوق دبي المالي</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/ADX">سوق أبوظبي</a>            </li>          </ul>          <ul>            <li>              <a class="mi-footer__menu-level3" href="/markets/BB">بورصة البحرين</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/QE">بورصة قطر</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/MSM">سوق مسقط</a>            </li>          </ul>          <ul>            <li>              <a class="mi-footer__menu-level3" href="/markets/KSE">سوق الكويت</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/ASE">بورصة عمان</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/CSE">سوق الدار البيضاء</a>            </li>          </ul>          <ul>            <li>              <a class="mi-footer__menu-level3" href="/markets/BDT">بورصة تونس</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/PEX">سوق فلسطين</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/ISX">سوق العراق</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/international-indices">مؤشرات الأسواق العالمية</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/commodities-prices">أسعار المعادن والطاقة</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/currencies">أسعار العملات</a>            </li>            <!--<li>              <a class="mi-footer__menu-level3"                 th:href="${@url.to(\'RMPC#regionalMap\')}"                 th:text="#{navigation.markets.regional-map}"/>            </li>-->          </ul>        </li>        <li class="mi-footer__menu-item mi-footer__menu__news" id="news">          <ul>            <div class="mi-footer__menu-level1">الأخبار</div>            <li class="mi-footer__menu__news__submenu">              <h3 class="mi-footer__menu-level2">أخبار الدول</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/eg/now/latest">مصر</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/latest">السعودية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/ae/now/latest">الإمارات</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/bh/now/latest">البحرين</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/qa/now/latest">قطر</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/om/now/latest">عمان</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/kw/now/latest">الكويت</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/jo/now/latest">الأردن</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/ma/now/latest">المغرب</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/tn/now/latest">تونس</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/ps/now/latest">فلسطين</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/iq/now/latest">العراق</a>                </li>              </ul>            </li>            <li class="mi-footer__menu__news__submenu">              <h3 class="mi-footer__menu-level2">أخبار إقليمية</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/regions/gulf">الخليج</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/regions/levant">الشام</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/regions/north-africa">شمال أفريقيا</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/regions/middle-east">الشرق الأوسط</a>                </li>              </ul>              <!-- happening now -->              <h3 class="mi-footer__menu-level2">يحدث الآن</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/top">أهم الأخبار</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/exclusive">حصرياً مباشر</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/latest">آخر الأخبار</a>                </li>                                  <li>                    <a class="mi-footer__menu-level3" href="/news/sa/now/announcements">إعلانات السوق</a>                  </li>                                                  <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/popular">منتشر الآن</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/trending/">الأكثر مشاركة</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/now/news-releases">بيانات صحفية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/misc">أخبار منوعة</a>                </li>              </ul>            </li>            <li class="mi-footer__menu__news__submenu">              <h3 class="mi-footer__menu-level2">نبض السوق</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/stocks">أخبار الأسهم</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/analysis">تحليلات إخبارية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/local">اقتصاد محلي</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/recommendations">توصيات</a>                </li>              </ul>              <h3 class="mi-footer__menu-level2">أخبار القطاعات</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/category/banking">بنوك</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/category/realEstate">عقارات</a>                </li>              </ul>              <h3 class="mi-footer__menu-level2">أخبار عالمية</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/global-economy">اقتصاد عالمى</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/goods-and-metals">أحداث عالمية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/global-indices">مؤشرات عالمية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/oil-and-energy">نفط ومعادن</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/currencies">عملات</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/global-reports">تقارير عالمية</a>                </li>              </ul>            </li>          </ul>        </li>        <li class="mi-footer__menu-item mi-footer__menu__companies" id="companies">          <div class="mi-footer__menu-level1">الشركات</div>          <ul>            <h3 class="mi-footer__menu-level2 invisible">الشركات</h3>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/companies">الشركات المدرجة</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/events">مفكرة الشركات</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/stock-prices">أسعار الأسهم</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/earnings">إعلانات الأرباح</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/fair-values">القيم العادلة</a>            </li>            <li>                          </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/major-shareholders">كبار الملاك</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/ipos">قائمة الإكتتابات</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/ipo/list">بحث فى الاكتتابات</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/ipos/news">أخبار الاكتتابات</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/ipo/calendar">مفكرة الاكتتابات</a>            </li>          </ul>        </li>        <li class="mi-footer__menu-item mi-footer__menu__analysis-tools" id="analysis-tools">          <div class="mi-footer__menu-level1">أدوات التحليل</div>          <!-- If current country has one market only -->                      <ul>              <h3 class="mi-footer__menu-level2 invisible">أدوات التحليل</h3>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/performance-comparison">مقارنة الأداء</a>              </li>            </ul>                    <!-- If current country has more than one markets i.e UAE -->                  </li>      </ul>    </div>    <div class="mi-footer__second-fold">      <div class="mi-footer__column1">        <div class="mi-footer__copyright">          <div class="mi-footer__logo" onclick="window.location.href=\'/countries/sa\'">              <svg viewBox="0 0 494.387 190.555">    <use xlink:href="#logo-white"></use>  </svg>            </div>          <span>جميع الحقوق تعود لشركة مباشر العالمية © 2005 - 2020</span>        </div>        <ul class="mi-footer__links">          <li>            <a href="/s/Terms">اتفاقية الاستخدام</a>          </li>          <li>            <a href="/s/disclaimer">إخلاء المسؤولية</a>          </li>          <li>            <a href="/s/aboutus">من نحن</a>          </li>          <li>            <a href="/contact">اتصل بنا</a>          </li>          <li>            <a href="/advertise">أعلن معنا</a>          </li>          <li>            <a href="http://www.decypha.com/" target="_blank">موقع ديسيفا</a>          </li>          <li>            <a href="/ir-services" target="_blank">خدمات المواقع</a>          </li>          <li>            <a href="/s/Jobs">وظائف</a>          </li>          <li>              <a target="_blank" href="/decypha-packages">ديسيفا</a>          </li>          <li>            <a href="/s/privacy-policy" target="_blank">سياسة الخصوصية</a>          </li>          <!--<li th:if="${#locale.getLanguage() == \'en\'}">            <a href="/s/decypha-financial-intelligence" th:text="#{components.footer.decypha-financial-intelligence}">Decypha Financial Intelligence</a>          </li>-->        </ul>        <div>جميع البيانات متأخرة 15 دقيقة أثناء الجلسة</div>        <div>هذا الموقع مرخص من وزراة الثقافة والإعلام السعودية</div>        <div>رقم التسجيل :ت 1 125 1435</div>      </div>      <div class="mi-footer__column2">        <ul class="mi-footer__social-icons">          <li>            <a target="_blank" href="https://twitter.com/mubasher"><i class="fa fa-twitter fa-2x"></i></a>          </li>          <li>            <a href="https://www.facebook.com/Mubasher.Info"><i class="fa fa-facebook fa-2x"></i></a>          </li>          <li>            <a href="https://www.youtube.com/channel/UC7hnxb7gD4nKZdZk3ZlZCYg"><i class="fa fa-youtube fa-2x"></i></a>          </li>          <li>            <a href="https://www.linkedin.com/company/1477149"><i class="fa fa-linkedin fa-2x"></i></a>          </li>          <li>            <a href="/news/rss"><i class="fa fa-rss fa-2x"></i></a>          </li>          <li>            <a href="https://play.google.com/store/apps/details?id=net.mis.mubasherinfo">              <i class="fa fa-android fa-2x"></i></a>          </li>          <li>            <a href="https://itunes.apple.com/app/imubasher/id494539772?mt=8"><i class="fa fa-apple fa-2x"></i></a>          </li>          </ul></div></div></div></footer>          </div>  <script src="//code.jquery.com/jquery-2.1.4.min.js"></script>  <script src="//ajax.googleapis.com/ajax/libs/angularjs/1.3.15/angular.min.js"></script>  <script src="/assets/ui/lib.min.js"></script>  <script src="/assets/ui/main.min.js"></script>  <div id="mi-js-scripts"></div>  <script>    <!-- Fix menu trigger on android browser4 -->    $(".dl-menu__menu-item").click(function () {      $(this).addClass(".dl-menu-item__hoverd");    });    $(document).ready(function () {      $(\'.tooltip\').tooltipster();      setTimeout(function(){ dataLayer.push({event: "triggerAds"});      console.log("triggerAds");      }, 1000);    });  </script>    <div pg-ng-tooltip=""></div></div>  <!-- Twitter universal website tag code -->  <script>    !function(e,t,n,s,u,a){e.twq||(s=e.twq=function(){s.exe?s.exe.apply(s,arguments):s.queue.push(arguments);    },s.version=\'1.1\',s.queue=[],u=t.createElement(n),u.async=!0,u.src=\'//static.ads-twitter.com/uwt.js\',      a=t.getElementsByTagName(n)[0],a.parentNode.insertBefore(u,a))}(window,document,\'script\');    // Insert Twitter Pixel ID and Standard Event data below    twq(\'init\',\'nyana\');    twq(\'track\',\'PageView\');  </script>  <!-- End Twitter universal website tag code --><div id="mm-blocker" class="mm-slideout"></div></body>' + '<body id="mi" ng-app="app" ng-controller="MainController" class="ar ng-scope" data-gr-c-s-loaded="true"><nav class="header__countries-menu mm-menu mm-offcanvas mm-top mm-front" id="countries-menu"><div class="mm-panel mm-opened mm-current" id="mm-8"><ul class="mm-listview mm-first mm-last">        <li class="header__country-selector__country">          <a href="/change-country?to=ae&amp;url=/countries/sa/companies">الإمارات</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=bh&amp;url=/countries/sa/companies">البحرين</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=om&amp;url=/countries/sa/companies">عُمان</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=qa&amp;url=/countries/sa/companies">قطر</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=kw&amp;url=/countries/sa/companies">الكويت</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=eg&amp;url=/countries/sa/companies">مصر</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=jo&amp;url=/countries/sa/companies">الأردن</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=tn&amp;url=/countries/sa/companies">تونس</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=ma&amp;url=/countries/sa/companies">المغرب</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=ps&amp;url=/countries/sa/companies">فلسطين</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=iq&amp;url=/countries/sa/companies">العراق</a>        </li>      </ul></div></nav><nav class="header__main-menu mm-menu mm-border-full mm-effect-slide-menu mm-effect-zoom-panels mm-pageshadow mm-offcanvas mm-right mm-hasnavbar-top mm-hasnavbar" id="main-menu"><div class="mm-navbar mm-navbar-top mm-hasbtns"><a class="mm-prev mm-btn mm-hidden"></a><a class="mm-title"> </a><a class="mm-close mm-btn" href="#wrapper"></a></div><div class="mm-panel mm-opened mm-current" id="mm-0"><ul class="mm-listview mm-first mm-last">        <li id="markets">          <a class="mm-next mm-fullsubopen" href="#mm-1" data-target="#mm-1"></a><span href="javascript:;">الأسواق</span>                  </li>        <li id="news">          <a class="mm-next mm-fullsubopen" href="#mm-2" data-target="#mm-2"></a><span href="javascript:;">الأخبار</span>                  </li>        <li id="companies">          <a class="mm-next mm-fullsubopen" href="#mm-3" data-target="#mm-3"></a><span href="javascript:;">الشركات</span>                  </li>        <li id="funds">          <a class="mm-next mm-fullsubopen" href="#mm-4" data-target="#mm-4"></a><span href="javascript:;">صناديق الاستثمار</span>                  </li>        <li id="analysis-tool">          <a class="mm-next mm-fullsubopen" href="#mm-5" data-target="#mm-5"></a><span href="javascript:;">أدوات التحليل</span>                  </li>        <li id="islamic-economy">          <a href="/news/islamic-finance">الاقتصاد الإسلامي</a>        </li>        <!--<li class="global__hide-for-ltr" id="radio" th:if="${#locale.getLanguage() == \'ar\'}">          <span th:text="#{navigation.radio}">راديو مباشر</span>          <ul>            <li>              <a th:href="${@url.to(\'RPC#live\')}" th:text="#{navigation.radio.live}"/>            </li>            <li>              <a th:href="${@url.to(\'RPC#latestEpisodesPage\', countryCode)}">آخر الحلقات</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تقارير-اقتصادية\'}">تقارير اقتصادية</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تغطية-خاصة\'}">تغطية خاصة</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'مقالات\'}">مقالات</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#programs\')}" th:text="#{navigation.radio.programs}"/>            </li>            <li>              <a th:href="${@url.to(\'RPC#videoPrograms\')}" th:text="#{navigation.radio.videoPrograms}"/>            </li>            <li>              <a th:href="${@url.to(\'RPC#getExperts\')}">ضيوفنا</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#getPresenters\')}">المذيعون</a>            </li>          </ul>        </li>-->        <li class="global__hide-for-ltr" id="video">          <a href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">مباشر TV</a>        </li>                <li id="fixedincome">          <a class="mm-next mm-fullsubopen" href="#mm-6" data-target="#mm-6"></a><span>السندات</span>                  </li>        <li>          <a class="mm-next mm-fullsubopen" href="#mm-7" data-target="#mm-7"></a><span>شخصي</span>                  </li>        <li>          <a href="http://tawasul.mubasher.info/" target="_blank">تواصل</a>        </li>        <!-- <li>          <a th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank" th:text="#{components.header.decypha}" target="_blank">          </a>        </li> -->        <li>          <a ng-click="decypha(\'decypha\')">ديسيفا</a>        </li>        <!--Add according to MFP-187-->        <li>          <a href="https://contest.mubasher.info/#/home" target="_blank">المستثمر اﻷول</a>        </li>        <li>          <!--Integrating Mubasher Pulse-->        </li><li>        <style>          .pulse-logo2{            padding: 5px 5px 4px;            min-width: 82px;            min-height: 21px;            max-width: 27%;          }        </style>        <a target="_blank" href="https://pulse.mubasher.info">          <img class="pulse-logo2" src="../../../images/pulse-logo.png">        </a>        </li>        <li>        </li><li>          <a href="http://magazine.mubasher.info/" target="_blank">            مجلة مباشر          </a>        </li>        <li class="mm-divider"></li>        <li>          <a href="https://english.mubasher.info">ENGLISH</a>        </li>        <li>                  </li>        <li>          <a class="header__login__text" href="/account/login">دخول</a>                  </li>      </ul></div><div class="mm-panel mm-hidden" id="mm-1"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الأسواق</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/markets/TDWL">سوق الأسهم السعودي</a>            </li>            <li>              <a href="/markets/EGX">البورصة المصرية</a>            </li>            <li>              <a href="/markets/DFM">سوق دبي المالي</a>            </li>            <li>              <a href="/markets/ADX">سوق أبوظبي</a>            </li>            <li>              <a href="/markets/BB">بورصة البحرين</a>            </li>            <li>              <a href="/markets/QE">بورصة قطر</a>            </li>            <li>              <a href="/markets/MSM">سوق مسقط</a>            </li>            <li>              <a href="/markets/BK">سوق الكويت</a>            </li>            <li>              <a href="/markets/ASE">بورصة عمان</a>            </li>            <li>              <a href="/markets/CSE">سوق الدار البيضاء</a>            </li>            <li>              <a href="/markets/BDT">بورصة تونس</a>            </li>            <li>              <a href="/markets/PEX">سوق فلسطين</a>            </li>            <li>              <a href="/markets/ISX">سوق العراق</a>            </li>            <li>              <a href="/international-indices">مؤشرات الأسواق العالمية</a>            </li>            <li>              <a href="/markets/commodities-prices">أسعار المعادن والطاقة</a>            </li>            <li>              <a href="/countries/sa/currencies">أسعار العملات</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-2"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الأخبار</a></div><ul class="mm-listview mm-first mm-last">            <!-- now -->            <li class="mm-divider">يحدث الآن</li>            <li>              <a href="/news/sa/now/top">أهم الأخبار</a>            </li>            <li>              <a href="/news/sa/now/exclusive">حصرياً مباشر</a>            </li>            <li>              <a href="/news/sa/now/latest">آخر الأخبار</a>            </li>                          <li>                <a href="/news/sa/now/announcements">إعلانات السوق</a>              </li>                                      <li class="global__hide-for-ltr">              <a href="/news/sa/now/popular">منتشر الآن</a>            </li>            <li>              <a href="/news/sa/now/trending/">الأكثر مشاركة</a>            </li>            <li>              <a href="/news/now/news-releases">بيانات صحفية</a>            </li><!--            <li>              <a th:href="${@url.to(\'NPC#miscellaneousNews\', countryCode)}"                 th:text="#{navigation.news.now.misc}"/>            </li>-->            <!-- recommendations-->            <li class="mm-divider">نبض السوق</li>            <li>              <a href="/news/sa/pulse/stocks">أخبار الأسهم</a>            </li>            <li>              <a href="/news/sa/pulse/analysis">تحليلات إخبارية</a>            </li>            <li>              <a href="/news/sa/pulse/local">اقتصاد محلي</a>            </li>            <li>              <a href="/news/sa/pulse/recommendations">توصيات</a>            </li>            <li class="mm-divider">أخبار القطاعات</li>            <li>              <a href="/news/sa/category/banking">بنوك</a>            </li>            <li>              <a href="/news/sa/category/realEstate">عقارات</a>            </li>            <li class="mm-divider">أخبار الدول</li>            <li>              <a href="/news/eg/now/latest">مصر</a>            </li>            <li>              <a href="/news/sa/now/latest">السعودية</a>            </li>            <li>              <a href="/news/ae/now/latest">الإمارات</a>            </li>            <li>              <a href="/news/bh/now/latest">البحرين</a>            </li>            <li>              <a href="/news/qa/now/latest">قطر</a>            </li>            <li>              <a href="/news/om/now/latest">عمان</a>            </li>            <li>              <a href="/news/kw/now/latest">الكويت</a>            </li>            <li>              <a href="/news/jo/now/latest">الأردن</a>            </li>            <li>              <a href="/news/ma/now/latest">المغرب</a>            </li>            <li>              <a href="/news/tn/now/latest">تونس</a>            </li>            <li>              <a href="/news/ps/now/latest">فلسطين</a>            </li>            <li>              <a href="/news/iq/now/latest">العراق</a>            </li>            <!-- regions-->            <li class="mm-divider">أخبار إقليمية</li>            <li>              <a href="/news/regions/gulf">الخليج</a>            </li>            <li>              <a href="/news/regions/levant">الشام</a>            </li>            <li>              <a href="/news/regions/north-africa">شمال أفريقيا</a>            </li>            <li>              <a href="/news/regions/middle-east">الشرق الأوسط</a>            </li>            <!-- international -->            <li class="mm-divider">أخبار عالمية</li>            <li>              <a href="/news/international/global-economy">اقتصاد عالمى</a>            </li>            <li>              <a href="/news/international/goods-and-metals">أحداث عالمية</a>            </li>              <li>                <a href="/news/international/global-indices">مؤشرات عالمية</a>              </li>              <li>                <a href="/news/international/oil-and-energy">نفط ومعادن</a>              </li>              <li>                <a href="/news/international/currencies">عملات</a>              </li>              <li>                <a href="/news/international/global-reports">تقارير عالمية</a>              </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-3"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الشركات</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/countries/sa/companies">الشركات المدرجة</a>            </li>            <li>              <a href="/countries/sa/events">مفكرة الشركات</a>            </li>            <li>              <a href="/countries/sa/stock-prices">أسعار الأسهم</a>            </li>            <li>              <a href="/countries/sa/earnings">إعلانات الأرباح</a>            </li>            <li>              <a href="/countries/sa/fair-values">القيم العادلة</a>            </li>            <li>              <a href="/countries/sa/corporate-action">الإجراءات</a>            </li>                        <li>              <a href="/countries/sa/major-shareholders">كبار الملاك</a>            </li>            <li>              <a href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>            </li>            <li class="mm-divider">الاكتتابات</li>            <li>              <a href="/countries/sa/ipos">قائمة الإكتتابات</a>            </li>            <li>              <a href="/ipo/list">بحث فى الاكتتابات</a>            </li>            <li>              <a href="/ipos/news">أخبار الاكتتابات</a>            </li>            <li>              <a href="/ipo/calendar">مفكرة الاكتتابات</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-4"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">صناديق الاستثمار</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/countries/sa/funds">صناديق الاستثمار</a>            </li>            <li>              <a href="/countries/sa/funds-statistics">إحصائيات الصناديق</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-5"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">أدوات التحليل</a></div><ul class="mm-listview mm-first mm-last">                                        <li>                <a href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>              </li>              <li>                <a href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>              </li>              <li>                <a href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>              </li>              <li>                <a href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>              </li>              <li>                <a href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>              </li>                        <li class="mm-divider">            </li>            <li>              <a href="/analysis-tools/performance-comparison">مقارنة الأداء</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-6"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">السندات</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/fixedincome/bond/search" id="fixedIncomeBondScreener">بحث عن سندات</a>            </li>            <li>              <a href="/fixed-income/news" id="fixedIncomeNews">أخبار السندات وأذون الخزانة</a>            </li>            <li>              <a href="/fixedincome/calendar/searchForEvent" id="fixedIncomeCalendar">قائمة الأحداث</a>            </li>            <li>              <a href="/fixedincome/analytics/drawCurve" id="fixedIncomeAnalytics">تحليلات فنية</a>            </li>            <li>              <a href="/fixedincome/leagueTables/view" id="fixedIncomeLeagueTables">جداول الديون</a>            </li>            <li>              <a href="/fixedincome/research/search" id="fixedIncomeProspectus">تقارير</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-7"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">شخصي</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/my/alerts">التنبيهات</a>            </li>            <li>              <a href="/my/watch-list">أسهمي</a>            </li>            <li>              <a href="/my/newsletters">النشرة البريدية</a>            </li>          </ul></div></nav><div class="js-wrapper mm-page mm-slideout" id="wrapper">  <svg class="hidden" version="1.1" viewBox="0 0 0 0" xmlns="http://www.w3.org/2000/svg">  <defs>    <style>      .logo-white-path {        clip-rule: evenodd;        fill-rule: evenodd;        fill: white;        font-size: 46.6299px;        font-family: \'HelveticaNeue\';      }      .logo-path {        clip-rule: evenodd;        fill-rule: evenodd;        fill: #324651;        text-align: center;        font-size: 46.6299px;        font-family: \'HelveticaNeue\';      }    </style>    <g id="logo-white">      <path class="logo-white-path" d="M209.596 29.677c-6.25 0.016-11.243-4.937-11.261-11.188 c-0.018-6.191 5.027-11.29 11.194-11.29c6.182-0.004 11.3 5.1 11.3 11.226C220.852 24.6 215.8 29.7 209.6 29.7"></path>      <path class="logo-white-path" d="M228.308 37.976c6.231-0.01 11.3 5 11.3 11.2 c0.015 6.189-5.011 11.227-11.233 11.252c-6.213 0.025-11.246-4.99-11.271-11.209C217.063 43 222.1 38 228.3 38"></path>      <path class="logo-white-path" d="M350.278 190.471c-6.27-0.009-11.204-4.942-11.197-11.212 c0.013-6.26 4.968-11.18 11.248-11.176c6.242 0 11.3 5 11.2 11.224C361.555 185.5 356.5 190.5 350.3 190.5"></path>      <path class="logo-white-path" d="M186.161 37.976c6.26 0 11.2 5 11.2 11.2 c-0.01 6.241-4.993 11.239-11.209 11.226c-6.257-0.017-11.212-4.99-11.212-11.228C174.949 42.9 179.9 38 186.2 38"></path>      <path class="logo-white-path" d="M455.92 80.125c-21.212 0-38.405 17.191-38.405 38.4 c0 4.3 0.7 8.4 2 12.316l-48.126 0.003l13.9-27.74h-3.242c0 0-2.13 0.019-2.822 0.1 c-2.13 0.126-3.67 0.098-7.926 1.351c-3.949 1.159-7.026 2.719-9.881 4.503c-2.381 1.493-5.863 4.278-8.803 7.7 c-2.912 3.325-5.713 7.695-5.713 7.695l-3.294 6.464l-41.201 0.003L364.7 0l-76.514 49.172l25.429-0.036L260.64 156.919h193.847 c0 0 0.9 0 1.4 0.01c21.212 0 38.4-17.183 38.4-38.403C494.32 97.3 477.1 80.1 455.9 80.125z M455.92 133.3 c-7.998 0-14.48-6.479-14.48-14.47c0-7.998 6.482-14.476 14.48-14.476c7.996 0 14.5 6.5 14.5 14.5 C470.393 126.8 463.9 133.3 455.9 133.327z"></path>      <path class="logo-white-path" d="M269.61 81.427c0 0-1.617 0.013-2.842 0.09c-2.001 0.132-3.655 0.07-7.903 1.3 c-3.946 1.162-7.021 2.722-9.876 4.507c-2.378 1.488-5.868 4.279-8.813 7.662c-2.904 3.327-5.282 8.108-5.282 8.108l-14.116 27.7 h-16.391l19.092-39.485h-3.237c0 0-1.617 0.015-2.835 0.095c-2.012 0.13-3.665 0.068-7.905 1.3 c-3.957 1.161-7.034 2.717-9.892 4.502c-2.373 1.493-5.857 4.28-8.808 7.668c-2.899 3.321-5.282 8.104-5.282 8.104l-8.901 17.8 h-16.959l13.92-27.753h-3.245c0 0-2.141 0.019-2.822 0.057c-2.133 0.126-3.663 0.098-7.926 1.4 c-3.944 1.159-7.026 2.719-9.884 4.503c-2.378 1.493-5.857 4.28-8.808 7.669c-2.904 3.329-5.708 7.695-5.708 7.695l-3.291 6.5 l-52.558-0.005l14.007-27.748h-3.242c0 0-2.131 0.019-2.815 0.057c-2.136 0.126-3.678 0.098-7.934 1.4 c-3.944 1.159-7.021 2.719-9.877 4.503c-2.383 1.493-5.858 4.28-8.813 7.669c-2.906 3.329-5.114 7.843-5.114 7.843l-16.204 31.1 l0 0c0 0-3.136 6.731-7.038 11.469c-3.094 3.766-7.43 6.804-9.757 8.194c-2.313 1.384-7.141 3.645-11.872 4.5 C5.251 180.9 0 180.5 0 180.502s2.33 2.1 5 3.806c2.034 1.4 4.3 2.4 5.5 3 c2.481 1.1 4.3 1.7 6.9 2.253c2.531 0.6 4.8 0.8 4.8 0.763s1.621 0.2 3.2 0.169c0.707 0 1.62-0.024 2.848-0.09 c2.001-0.134 3.5 0 7.904-1.323c4.033-1.188 7.072-2.582 9.92-4.368c2.383-1.478 5.952-4.249 8.904-7.627 c2.907-3.337 5.296-8.019 5.296-8.019l6.043-12.125l169.4 0.009l12.816-26.07l24.302-49.431H269.61z"></path>      <path class="logo-white-path" d="M30.239 76.472V55.626H22.45v-2.789h18.735v2.789h-7.819v20.846H30.239z"></path>      <path class="logo-white-path" d="M44.296 76.472V52.836h4.71l5.592 16.735c0.518 1.6 0.9 2.7 1.1 3.499c0.269-0.861 0.687-2.123 1.258-3.789 l5.658-16.446h4.209v23.636h-3.015V56.689l-6.869 19.783h-2.822l-6.835-20.121v20.121H44.296z"></path>    </g>    <g id="logo">      <path class="logo-path" d="M209.596 29.677c-6.25 0.016-11.243-4.937-11.261-11.188 c-0.018-6.191 5.027-11.29 11.194-11.29c6.182-0.004 11.3 5.1 11.3 11.226C220.852 24.6 215.8 29.7 209.6 29.7"></path>      <path class="logo-path" d="M228.308 37.976c6.231-0.01 11.3 5 11.3 11.2 c0.015 6.189-5.011 11.227-11.233 11.252c-6.213 0.025-11.246-4.99-11.271-11.209C217.063 43 222.1 38 228.3 38"></path>      <path class="logo-path" d="M350.278 190.471c-6.27-0.009-11.204-4.942-11.197-11.212 c0.013-6.26 4.968-11.18 11.248-11.176c6.242 0 11.3 5 11.2 11.224C361.555 185.5 356.5 190.5 350.3 190.5"></path>      <path class="logo-path" d="M186.161 37.976c6.26 0 11.2 5 11.2 11.2 c-0.01 6.241-4.993 11.239-11.209 11.226c-6.257-0.017-11.212-4.99-11.212-11.228C174.949 42.9 179.9 38 186.2 38"></path>      <path class="logo-path" d="M455.92 80.125c-21.212 0-38.405 17.191-38.405 38.4 c0 4.3 0.7 8.4 2 12.316l-48.126 0.003l13.9-27.74h-3.242c0 0-2.13 0.019-2.822 0.1 c-2.13 0.126-3.67 0.098-7.926 1.351c-3.949 1.159-7.026 2.719-9.881 4.503c-2.381 1.493-5.863 4.278-8.803 7.7 c-2.912 3.325-5.713 7.695-5.713 7.695l-3.294 6.464l-41.201 0.003L364.7 0l-76.514 49.172l25.429-0.036L260.64 156.919h193.847 c0 0 0.9 0 1.4 0.01c21.212 0 38.4-17.183 38.4-38.403C494.32 97.3 477.1 80.1 455.9 80.125z M455.92 133.3 c-7.998 0-14.48-6.479-14.48-14.47c0-7.998 6.482-14.476 14.48-14.476c7.996 0 14.5 6.5 14.5 14.5 C470.393 126.8 463.9 133.3 455.9 133.327z"></path>      <path class="logo-path" d="M269.61 81.427c0 0-1.617 0.013-2.842 0.09c-2.001 0.132-3.655 0.07-7.903 1.3 c-3.946 1.162-7.021 2.722-9.876 4.507c-2.378 1.488-5.868 4.279-8.813 7.662c-2.904 3.327-5.282 8.108-5.282 8.108l-14.116 27.7 h-16.391l19.092-39.485h-3.237c0 0-1.617 0.015-2.835 0.095c-2.012 0.13-3.665 0.068-7.905 1.3 c-3.957 1.161-7.034 2.717-9.892 4.502c-2.373 1.493-5.857 4.28-8.808 7.668c-2.899 3.321-5.282 8.104-5.282 8.104l-8.901 17.8 h-16.959l13.92-27.753h-3.245c0 0-2.141 0.019-2.822 0.057c-2.133 0.126-3.663 0.098-7.926 1.4 c-3.944 1.159-7.026 2.719-9.884 4.503c-2.378 1.493-5.857 4.28-8.808 7.669c-2.904 3.329-5.708 7.695-5.708 7.695l-3.291 6.5 l-52.558-0.005l14.007-27.748h-3.242c0 0-2.131 0.019-2.815 0.057c-2.136 0.126-3.678 0.098-7.934 1.4 c-3.944 1.159-7.021 2.719-9.877 4.503c-2.383 1.493-5.858 4.28-8.813 7.669c-2.906 3.329-5.114 7.843-5.114 7.843l-16.204 31.1 l0 0c0 0-3.136 6.731-7.038 11.469c-3.094 3.766-7.43 6.804-9.757 8.194c-2.313 1.384-7.141 3.645-11.872 4.5 C5.251 180.9 0 180.5 0 180.502s2.33 2.1 5 3.806c2.034 1.4 4.3 2.4 5.5 3 c2.481 1.1 4.3 1.7 6.9 2.253c2.531 0.6 4.8 0.8 4.8 0.763s1.621 0.2 3.2 0.169c0.707 0 1.62-0.024 2.848-0.09 c2.001-0.134 3.5 0 7.904-1.323c4.033-1.188 7.072-2.582 9.92-4.368c2.383-1.478 5.952-4.249 8.904-7.627 c2.907-3.337 5.296-8.019 5.296-8.019l6.043-12.125l169.4 0.009l12.816-26.07l24.302-49.431H269.61z"></path>      <path class="logo-path" d="M30.239 76.472V55.626H22.45v-2.789h18.735v2.789h-7.819v20.846H30.239z"></path>      <path class="logo-path" d="M44.296 76.472V52.836h4.71l5.592 16.735c0.518 1.6 0.9 2.7 1.1 3.499c0.269-0.861 0.687-2.123 1.258-3.789 l5.658-16.446h4.209v23.636h-3.015V56.689l-6.869 19.783h-2.822l-6.835-20.121v20.121H44.296z"></path>    </g>    <g id="logo-white-en">      <defs>        <rect height="65.7" width="326.9" x="-55"></rect>      </defs>      <clipPath>        <use overflow="visible" xlink:href="#SVGID_1_"></use>      </clipPath>      <path class="logo-white-path" d="M41.694 20.162c-1.315 0-1.315 0.987-1.315 0.987l0.094 13.8 c0 0 0.6 8.648-8.178 8.648c0 0-8.364 0.093-8.364-8.082V21.29c0 0 0.234-1.174-1.27-1.174c-1.362 0-1.221 1.174-1.221 1.174V36 c0 0 0.2 10.1 10.9 10.104c10.386 0 10.669-9.675 10.669-10.433V21.243C42.964 21.2 43 20.2 41.7 20.2"></path>      <path class="logo-white-path" d="M20.915 21.431c0 0 0-0.799-0.799-1.127c-0.777-0.321-1.27 0.422-1.457 0.6 l-7.425 10.293c0 0-0.469 0.61-1.034-0.282l-8.13-10.292c0 0-0.517-0.611-1.128-0.423c-0.611 0.189-0.894 0.704-0.846 1.6 L0 44.74c0 0-0.046 1.4 1.3 1.363s1.316-1.222 1.316-1.222V25.144l7.002 9.023c0 0 1.1 1.5 2.209-0.188 c1.081-1.646 6.626-8.882 6.626-8.882v19.736c0 0-0.088 1.3 1.5 1.175c1.175-0.094 0.988-1.22 0.988-1.22V21.431z"></path>      <path class="logo-white-path" d="M168.546 43.734l-10.309-6.813c0 0 8.648-0.179 8.648-8.471 c0-8.294-8.531-8.118-8.531-8.118h-8.412c-2.107 0-1.953 1.6-1.953 1.6v22.69c0 0-0.038 1.5 1.1 1.5 c1.265 0 1.222-1.436 1.222-1.436V22.702h6.516c0.474 0 3.1 0 5.3 1.304c2.192 1.3 3.7 7.198-0.177 9.6 c-2.785 1.717-6.459 1.008-7.642 0.889c-1.185-0.12-1.306 0.414-1.483 1.186c-0.177 0.8 0.9 1.4 0.9 1.362l13.21 8.5 c0 0 1.4 1.2 2.1 0.18C169.967 44.4 168.5 43.7 168.5 43.7"></path>      <path class="logo-white-path" d="M95.522 19.596c-6.516-0.711-11.492 3.376-11.373 7.8 c0.117 4.4 3 5.7 8.1 6.634c5.096 0.9 7 1.7 7 1.658c2.665 1 2.5 4.3 1 5.9 c-1.423 1.601-4.148 2.558-5.766 2.616c-3.879 0.146-6.052-2.374-6.052-2.374c-0.492-0.407-0.683-1.486-1.69-1.25 c-1.347 0.316-0.296 1.836-0.296 1.836c2.311 3.2 7.2 3.6 7.2 3.554c5.45 0.7 8.648-3.139 8.648-3.139 c2.963-3.852 0.987-8.363-1.976-9.429c-3.17-1.142-6.139-1.234-10.05-2.065c-3.909-0.828-3.495-4.087-3.495-4.087 c0.059-2.37 2.252-5.271 7.643-5.332c5.392-0.059 8.5 3.4 8.5 3.436c1.304 1.4 2.1 0.5 2.133-0.12 c0.06-0.591-0.058-1.183-0.531-1.776C104.121 23.1 102 20.3 95.5 19.6"></path>      <path class="logo-white-path" d="M124.084 20.618c-1.126 0-1.185 1.067-1.185 1.067v15.166h-14.336V21.862 c0 0 0.296-1.42-1.305-1.362c-1.304 0.047-1.067 1.42-1.067 1.42v14.575h-0.889c0 0-1.303-0.06-1.303 1.2 c0 1.3 1.2 1.3 1.2 1.305h1.007v5.746c0 0 0 1.2 1.2 1.243c1.246 0 1.187-1.184 1.187-1.184v-5.984h14.1v6.103 c0 0-0.008 1.1 1.2 1.137c1.226 0 1.269-1.195 1.269-1.195V21.743C125.209 21.7 125.2 20.6 124.1 20.6"></path>      <path class="logo-white-path" d="M86.101 44.016c0 0-10.841-21.504-11.849-23.163c-1.007-1.66-2.072 0-2.072 0 l-8.047 15.604l-2.395 0.015c-0.888 0-0.982 0.633-0.982 1.284c0 1.1 1.1 0.9 1.1 0.929h1.067c0 0-2.447 4.637-2.726 5.3 c-0.355 0.889-0.416 1.5 0.5 1.955c1.008 0.5 1.659-0.77 1.659-0.77l3.436-6.399H80.71l2.903 5.9 c0 0 1 2 2.1 1.305C86.87 45.3 86.1 44 86.1 44 M66.965 36.374l5.984-12.026c0 0 0.296-0.475 0.6 0.1 c0.296 0.5 6 12 6 11.967H66.965z"></path>      <path class="logo-white-path" d="M58.314 34.283c0 0 3.87-1.954 3.87-6.575c0-4.622-4.563-7.199-8.294-7.199 h-6.517c0 0-1.512 0.2-1.512 1.744v10.479h-1.833c0 0-0.799-0.094-0.799 1.271c0 1.1 0.6 1.2 0.6 1.173h2.066v9.447 c0 0-0.046 1.5 1.5 1.48h7.213c0 0 6.016-0.165 6.016-6.837C60.57 35.9 58.3 34.3 58.3 34.3 M48.203 22.7 l6.338-0.005c1.718 0 5.1 1.7 5.1 5.451c0 4.443-5.095 4.501-5.095 4.501h-6.338V22.736z M53.557 43.831h-5.351v-8.748 l6.435-0.008c0.858 0 3.5 0.9 3.5 4.031C58.143 43.7 53.6 43.8 53.6 43.8"></path>      <path class="logo-white-path" d="M146.17 23.033c0 0 1.3 0.1 1.305-1.304c0-1.244-1.305-1.125-1.305-1.125 h-15.818c-2.251 0-2.012 1.717-2.012 1.717V36.54l-1.653 0.009c0 0-1.132 0.229-1.132 1.177c0 1.2 1.1 1.4 1.1 1.361h1.669 v4.917c0 2.5 1.7 2.1 1.7 2.073h15.818c0 0 0.9 0 0.889-1.185s-0.95-1.007-0.95-1.007h-14.798v-4.799h15.284 c0 0 0.937-0.177 0.937-1.361c0-1.186-1.125-1.246-1.125-1.246h-15.228V23.033H146.17z"></path>    </g>    <g id="logo-en">      <defs>        <rect height="65.7" width="326.9" x="-55"></rect>      </defs>      <clipPath>        <use overflow="visible" xlink:href="#SVGID_1_"></use>      </clipPath>      <path class="logo-path" d="M41.694 20.162c-1.315 0-1.315 0.987-1.315 0.987l0.094 13.8 c0 0 0.6 8.648-8.178 8.648c0 0-8.364 0.093-8.364-8.082V21.29c0 0 0.234-1.174-1.27-1.174c-1.362 0-1.221 1.174-1.221 1.174V36 c0 0 0.2 10.1 10.9 10.104c10.386 0 10.669-9.675 10.669-10.433V21.243C42.964 21.2 43 20.2 41.7 20.2"></path>      <path class="logo-path" d="M20.915 21.431c0 0 0-0.799-0.799-1.127c-0.777-0.321-1.27 0.422-1.457 0.6 l-7.425 10.293c0 0-0.469 0.61-1.034-0.282l-8.13-10.292c0 0-0.517-0.611-1.128-0.423c-0.611 0.189-0.894 0.704-0.846 1.6 L0 44.74c0 0-0.046 1.4 1.3 1.363s1.316-1.222 1.316-1.222V25.144l7.002 9.023c0 0 1.1 1.5 2.209-0.188 c1.081-1.646 6.626-8.882 6.626-8.882v19.736c0 0-0.088 1.3 1.5 1.175c1.175-0.094 0.988-1.22 0.988-1.22V21.431z"></path>      <path class="logo-path" d="M168.546 43.734l-10.309-6.813c0 0 8.648-0.179 8.648-8.471 c0-8.294-8.531-8.118-8.531-8.118h-8.412c-2.107 0-1.953 1.6-1.953 1.6v22.69c0 0-0.038 1.5 1.1 1.5 c1.265 0 1.222-1.436 1.222-1.436V22.702h6.516c0.474 0 3.1 0 5.3 1.304c2.192 1.3 3.7 7.198-0.177 9.6 c-2.785 1.717-6.459 1.008-7.642 0.889c-1.185-0.12-1.306 0.414-1.483 1.186c-0.177 0.8 0.9 1.4 0.9 1.362l13.21 8.5 c0 0 1.4 1.2 2.1 0.18C169.967 44.4 168.5 43.7 168.5 43.7"></path>      <path class="logo-path" d="M95.522 19.596c-6.516-0.711-11.492 3.376-11.373 7.8 c0.117 4.4 3 5.7 8.1 6.634c5.096 0.9 7 1.7 7 1.658c2.665 1 2.5 4.3 1 5.9 c-1.423 1.601-4.148 2.558-5.766 2.616c-3.879 0.146-6.052-2.374-6.052-2.374c-0.492-0.407-0.683-1.486-1.69-1.25 c-1.347 0.316-0.296 1.836-0.296 1.836c2.311 3.2 7.2 3.6 7.2 3.554c5.45 0.7 8.648-3.139 8.648-3.139 c2.963-3.852 0.987-8.363-1.976-9.429c-3.17-1.142-6.139-1.234-10.05-2.065c-3.909-0.828-3.495-4.087-3.495-4.087 c0.059-2.37 2.252-5.271 7.643-5.332c5.392-0.059 8.5 3.4 8.5 3.436c1.304 1.4 2.1 0.5 2.133-0.12 c0.06-0.591-0.058-1.183-0.531-1.776C104.121 23.1 102 20.3 95.5 19.6"></path>      <path class="logo-path" d="M124.084 20.618c-1.126 0-1.185 1.067-1.185 1.067v15.166h-14.336V21.862 c0 0 0.296-1.42-1.305-1.362c-1.304 0.047-1.067 1.42-1.067 1.42v14.575h-0.889c0 0-1.303-0.06-1.303 1.2 c0 1.3 1.2 1.3 1.2 1.305h1.007v5.746c0 0 0 1.2 1.2 1.243c1.246 0 1.187-1.184 1.187-1.184v-5.984h14.1v6.103 c0 0-0.008 1.1 1.2 1.137c1.226 0 1.269-1.195 1.269-1.195V21.743C125.209 21.7 125.2 20.6 124.1 20.6"></path>      <path class="logo-path" d="M86.101 44.016c0 0-10.841-21.504-11.849-23.163c-1.007-1.66-2.072 0-2.072 0 l-8.047 15.604l-2.395 0.015c-0.888 0-0.982 0.633-0.982 1.284c0 1.1 1.1 0.9 1.1 0.929h1.067c0 0-2.447 4.637-2.726 5.3 c-0.355 0.889-0.416 1.5 0.5 1.955c1.008 0.5 1.659-0.77 1.659-0.77l3.436-6.399H80.71l2.903 5.9 c0 0 1 2 2.1 1.305C86.87 45.3 86.1 44 86.1 44 M66.965 36.374l5.984-12.026c0 0 0.296-0.475 0.6 0.1 c0.296 0.5 6 12 6 11.967H66.965z"></path>      <path class="logo-path" d="M58.314 34.283c0 0 3.87-1.954 3.87-6.575c0-4.622-4.563-7.199-8.294-7.199 h-6.517c0 0-1.512 0.2-1.512 1.744v10.479h-1.833c0 0-0.799-0.094-0.799 1.271c0 1.1 0.6 1.2 0.6 1.173h2.066v9.447 c0 0-0.046 1.5 1.5 1.48h7.213c0 0 6.016-0.165 6.016-6.837C60.57 35.9 58.3 34.3 58.3 34.3 M48.203 22.7 l6.338-0.005c1.718 0 5.1 1.7 5.1 5.451c0 4.443-5.095 4.501-5.095 4.501h-6.338V22.736z M53.557 43.831h-5.351v-8.748 l6.435-0.008c0.858 0 3.5 0.9 3.5 4.031C58.143 43.7 53.6 43.8 53.6 43.8"></path>      <path class="logo-path" d="M146.17 23.033c0 0 1.3 0.1 1.305-1.304c0-1.244-1.305-1.125-1.305-1.125 h-15.818c-2.251 0-2.012 1.717-2.012 1.717V36.54l-1.653 0.009c0 0-1.132 0.229-1.132 1.177c0 1.2 1.1 1.4 1.1 1.361h1.669 v4.917c0 2.5 1.7 2.1 1.7 2.073h15.818c0 0 0.9 0 0.889-1.185s-0.95-1.007-0.95-1.007h-14.798v-4.799h15.284 c0 0 0.937-0.177 0.937-1.361c0-1.186-1.125-1.246-1.125-1.246h-15.228V23.033H146.17z"></path>    </g>  </defs></svg>  <!--<script type="text/javascript" xmlns:th="http://www.thymeleaf.org" th:fragment="body">-->  <!--(function () {-->    <!--var em = document.createElement(\'script\');-->    <!--em.type = \'text/javascript\';-->    <!--em.async = true;-->    <!--em.src =-->      <!--(\'https:\' == document.location.protocol ? \'https://me-ssl\' : \'http://me-cdn\') + \'.effectivemeasure.net/em.js\';-->    <!--var s = document.getElementsByTagName(\'script\')[0];-->    <!--s.parentNode.insertBefore(em, s);-->  <!--}());--><!--</script>-->  <div class="">    <header class="header">      <!-- DESKTOP ADS BLOCK -->      <!-- DESKTOP ADS BLOCK -->      <!-- MOBILE ADS BLOCK -->                  <!-- MOBILE ADS BLOCK -->      <div class="header__top-for-mobile">        <div class="top-bar__triggers">          <a class="main-menu-trigger fa fa-bars fa-2x" href="#main-menu" style="float: right;"></a>          <!-- Logo -->          <div class="header__logo header-logo-margins" onclick="window.location.href=\'/countries/sa\'">              <svg viewBox="0 0 494.387 190.555">    <use xlink:href="#logo-white"></use>  </svg>            </div>          <a class="countries-menu-trigger header-country-margins" href="#countries-menu">            <span>السعودية</span>            <span class="fa fa-caret-down fa-4x"></span>          </a>          <!-- ngRepeat: image in images --><img ng-repeat="image in images" src="/assets/ui/images/mobile-logo-G20.png" class="ng-scope"><!-- end ngRepeat: image in images --><img ng-repeat="image in images" src="/assets/ui/images/mobile-logo-vision.png" class="ng-scope"><!-- end ngRepeat: image in images -->          <div class="header__left-side left-search-icon">            <a class="search-trigger js-search-trigger fa fa-search fa-2x" href="javascript:;" style="float: left;">            </a>          </div>        </div>        <!-- Search -->        <div class="search js-search" id="search">          <i class="fa fa-search fa-2x search__icon"></i>          <angucomplete-alt id="autocomplete__companies" input-class="search__input" minlength="1" ng-controller="AutocompleteController" pause="400" placeholder="اكتب كلمة البحث أو رمز الشركة" selected-object="selectItem" text-no-results="عفواً, لم يتم العثور على أي نتائج" text-searching="جارٍ البحث..." title-field="label" remote-url="/api/1/companySearch?query=" class="ng-scope ng-isolate-scope"><div class="angucomplete-holder" ng-class="{\'angucomplete-dropdown-visible\': showDropdown}">  <input id="autocomplete__companies_value" ng-model="searchStr" ng-disabled="disableInput" type="" placeholder="اكتب كلمة البحث أو رمز الشركة" maxlength="524288" ng-focus="onFocusHandler()" class="search__input ng-valid-maxlength" ng-blur="hideResults($event)" autocapitalize="off" autocorrect="off" autocomplete="off" ng-change="inputChangeHandler(searchStr)">  <div id="autocomplete__companies_dropdown" class="angucomplete-dropdown ng-hide" ng-show="showDropdown"><div class="angucomplete-searching ng-hide" ng-show="searching"><div class="spinner"><div class="dot1"></div><div class="dot2"></div></div></div>    <div class="angucomplete-searching ng-binding" ng-show="!searching &amp;&amp; (!results || results.length == 0)" ng-bind="textNoResults">عفواً, لم يتم العثور على أي نتائج</div>    <!-- ngRepeat: result in results -->  </div></div></angucomplete-alt>        </div>      </div>      <div class="header-desktop mi-show-for-large-up">        <div class="header__top-for-desktop">          <div class="header__top-for-desktop-row">            <a class="header__other-site" href="http://tawasul.mubasher.info/" target="_blank">              <i class="fa fa-caret-right fa-2x"></i>              تواصل            </a>            <a class="header__other-site" href="http://magazine.mubasher.info/" target="_blank">              <i class="fa fa-caret-right fa-2x"></i>              مجلة مباشر            </a>            <a class="header__other-site" href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">              <i class="fa fa-play-circle"></i>              <div style="direction: ltr; display: inline-block;">TV مباشر</div>            </a>                        <a class="header__other-site" href="/contact">              <i class="fa fa-envelope"></i>              اتصل بنا            </a>            <a class="header__other-site" href="/advertise">              <i class="fa fa-envelope"></i>              اعلن معنا            </a>            <!-- <a th:if="${#locale.getLanguage() == \'ar\'}" class="header__login-button" style="background: #458D37 !important;" th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank"                th:text="#{components.header.decypha}">ديسيفا</a>            <a th:if="${#locale.getLanguage() == \'en\'}" class="header__login-button" style="background: #458D37 !important; font-family: Roboto,sans-serif !important;" th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank"                th:text="#{components.header.decypha}">ديسيفا</a> -->            <!-- Page Content Buttons -->            <a class="header__login-button" ng-click="decypha(\'decypha\')" style="background: #458D37 !important; font-family: Roboto,sans-serif !important;">ديسيفا</a>            <!-- Page Content Button -->            <!--Add according to MFP-187-->            <a class="header__login-button" style="background: #00c2d6 !important;" target="_blank" href="https://contest.mubasher.info/#/home">المستثمر اﻷول</a>                        <style>              /*.pulse-logo{*/              /*display: inline-block;*/              /*width: 252px;*/              /*height: 100%;*/              /*background: #212121 url(../images/pulse-logo.png) no-repeat center 2px;*/              /*padding: 10px 50px 29px;*/              /*text-align: center;*/              /*color: black;*/              /*text-decoration: none;*/              /*margin-top: -6px;*/              /*}*/              .pulse-logo2{                padding: 5px 5px 4px;                min-width: 82px;                min-height: 21px;                max-width: 27%;              }            </style>            <a target="_blank" href="https://pulse.mubasher.info">              <img class="pulse-logo2" src="../../../images/pulse-logo.png">            </a>            <span class="header__spacer">              &nbsp;            </span>            <a class="header__social-link" target="_blank" href="https://twitter.com/mubasher"><i class="fa fa-twitter fa-lg"></i></a>            <a class="header__social-link" href="https://www.facebook.com/Mubasher.Info"><i class="fa fa-facebook fa-lg"></i></a>            <a class="header__social-link" href="https://www.youtube.com/channel/UC7hnxb7gD4nKZdZk3ZlZCYg">              <i class="fa fa-youtube fa-lg"></i>            </a>            <a class="header__social-link" href="https://www.linkedin.com/company/1477149">              <i class="fa fa-linkedin fa-lg"></i>            </a>            <a class="header__social-link" href="/news/rss"><i class="fa fa-rss fa-lg"></i></a>            <a class="header__social-link" href="https://play.google.com/store/apps/details?id=net.mis.mubasherinfo">              <i class="fa fa-android fa-lg"></i>            </a>            <a class="header__social-link" href="https://itunes.apple.com/app/imubasher/id494539772?mt=8">              <i class="fa fa-apple fa-lg"></i>            </a>            <a class="header__login-button" href="/account/login">              دخول              <i class="fa fa-user fa-lg"></i>            </a>                                    <a class="header__language" href="https://english.mubasher.info">              <span>ENGLISH</span>            </a>          </div>        </div>        <div class="header__columns">          <div class="header__column1">            <!-- Logo -->            <div class="header__logo-wrapper">              <div class="header__logo" onclick="window.location.href=\'/countries/sa\'">                  <svg viewBox="0 0 494.387 190.555">    <use xlink:href="#logo"></use>  </svg>                </div>              <div class="countries-menu-trigger">                <a href="javascript:;" id="mi-js-countries-menu-trigger">                  <span>السعودية</span>                  <span class="fa fa-caret-down"></span>                </a>                <nav class="header__countries-menu--desktop mi-js-countries-menu-desktop" style="">                  <ul>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=ae&amp;url=/countries/sa/companies">الإمارات</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=bh&amp;url=/countries/sa/companies">البحرين</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=om&amp;url=/countries/sa/companies">عُمان</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=qa&amp;url=/countries/sa/companies">قطر</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=kw&amp;url=/countries/sa/companies">الكويت</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=eg&amp;url=/countries/sa/companies">مصر</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=jo&amp;url=/countries/sa/companies">الأردن</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=tn&amp;url=/countries/sa/companies">تونس</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=ma&amp;url=/countries/sa/companies">المغرب</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=ps&amp;url=/countries/sa/companies">فلسطين</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=iq&amp;url=/countries/sa/companies">العراق</a>                    </li>                  </ul>                </nav>              </div>            </div>            <!--Market Status -->            <div class="header__market-status">              <div class="header__market-status-column">                <div class="header__market-status-row">                  <a class="header__market-name" href="/markets/TDWL">TDWL</a>                  <span class="header__market-status--close">مغلق</span>                </div>                              </div>              <span class="header__market-time">12 أغسطس 04:49 م</span>            </div>          </div>          <div class="header__column1 banner-logo-desktop" ng-class="{\'banner-desktop-en\':(getLanguage == \'en\')}">            <!-- Logo -->            <div class="header__logo-wrapper">              <!-- ngRepeat: image in images --><div class="header__logo ng-scope" ng-repeat="image in images">                  <div class="tooltip tooltipstered"><img src="/assets/ui/images/logo-G20.png">                    <span class="tooltiptext ng-binding" ng-class="{\'tooltip-desktop-en\':(getLanguage == \'en\')}" style="left: 95%">مجموعة العشرين 2020</span>                  </div>              </div><!-- end ngRepeat: image in images --><div class="header__logo ng-scope" ng-repeat="image in images">                  <div class="tooltip tooltipstered"><img src="/assets/ui/images/logo-vision.png">                    <span class="tooltiptext ng-binding" ng-class="{\'tooltip-desktop-en\':(getLanguage == \'en\')}" style="left: 95%">رؤية المملكة العربية السعودية 2030</span>                  </div>              </div><!-- end ngRepeat: image in images -->            </div>          </div><!--          <div class="header__column2">             &lt;!&ndash;<div th:replace="components/ads/news/dfp/desktop/LB2"/>&ndash;&gt;            &lt;!&ndash;=====to display default leaderboard ad-slot [728,90] ======&ndash;&gt;            <div th:if="${isHomePage}">              <div th:replace="components/ads/home/leaderboard"/>            </div>            <div th:unless="${isHomePage}">              <div>                <iframe id="leaderboard-ros-001" style="width: 736px; height: 108px;" class="ad-iframe" src="/ads/LB2"></iframe>              </div>            </div>            </div>-->           <!--======= billboard 790x250 ============ -->        </div>        <nav class="header__navigation mi-js-desktop-menu-container">          <ul class="dl-menu mi-show-for-large-up mi-js-desktop-menu">            <li class="dl-menu__menu-item dl-menu__menu-item--iconic-item">              <a href="/countries/sa">                <i class="fa fa-home fa-2x"></i>              </a>            </li>            <li class="dl-menu__menu-item" id="markets">              <a href="javascript:;">الأسواق</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/markets/TDWL">سوق الأسهم السعودي</a>                    </li>                    <li>                      <a href="/markets/EGX">البورصة المصرية</a>                    </li>                    <li>                      <a href="/markets/DFM">سوق دبي المالي</a>                    </li>                    <li>                      <a href="/markets/ADX">سوق أبوظبي</a>                    </li>                    <li>                      <a href="/markets/BB">بورصة البحرين</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/markets/QE">بورصة قطر</a>                    </li>                    <li>                      <a href="/markets/MSM">سوق مسقط</a>                    </li>                    <li>                      <a href="/markets/BK">سوق الكويت</a>                    </li>                    <li>                      <a href="/markets/ASE">بورصة عمان</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/markets/CSE">سوق الدار البيضاء</a>                    </li>                    <li>                      <a href="/markets/BDT">بورصة تونس</a>                    </li>                    <li>                      <a href="/markets/PEX">سوق فلسطين</a>                    </li>                    <li>                      <a href="/markets/ISX">سوق العراق</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/international-indices">مؤشرات الأسواق العالمية</a>                    </li>                    <li>                      <a href="/markets/commodities-prices">أسعار المعادن والطاقة</a>                    </li>                    <li>                      <a href="/countries/sa/currencies">أسعار العملات</a>                    </li>                    <!--<li>                      <a th:href="${@url.to(\'RMPC#regionalMap\')}"                         th:text="#{navigation.markets.regional-map}"/>                    </li>-->                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item" id="news">              <a href="javascript:;">الأخبار</a>              <div class="mi-js-submenu">                <ul class="dl-submenu">                  <li>                    <a href="javascript:;">يحدث الآن</a>                    <div class="nav-column">                      <h3>يحدث الآن</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/sa/now/top">أهم الأخبار</a>                        </li>                        <li>                          <a href="/news/sa/now/exclusive">حصرياً مباشر</a>                        </li>                        <li>                          <a href="/news/sa/now/latest">آخر الأخبار</a>                        </li>                                                  <li>                            <a href="/news/sa/now/announcements">إعلانات السوق</a>                          </li>                                                                          <li class="global__hide-for-ltr">                          <a href="/news/sa/now/popular">منتشر الآن</a>                        </li>                        <li>                          <a href="/news/sa/now/trending/">الأكثر مشاركة</a>                        </li>                        <li>                          <a href="/news/now/news-releases">بيانات صحفية</a>                        </li>                        <li>                          <a href="/news/international/misc">أخبار منوعة</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">نبض السوق</a>                    <div class="nav-column">                      <h3>نبض السوق</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/sa/pulse/stocks">أخبار الأسهم</a>                        </li>                        <li>                          <a href="/news/sa/pulse/analysis">تحليلات إخبارية</a>                        </li>                        <li>                          <a href="/news/sa/pulse/local">اقتصاد محلي</a>                        </li>                        <li>                          <a href="/news/sa/pulse/recommendations">توصيات</a>                        </li>                      </ul>                      <h3>أخبار القطاعات</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/sa/category/banking">بنوك</a>                        </li><li>                          <a href="/news/sa/category/realEstate">عقارات</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">أخبار الدول</a>                    <div class="nav-column">                      <h3>أخبار الدول</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/eg/now/latest">مصر</a>                        </li>                        <li>                          <a href="/news/sa/now/latest">السعودية</a>                        </li>                        <li>                          <a href="/news/ae/now/latest">الإمارات</a>                        </li>                        <li>                          <a href="/news/bh/now/latest">البحرين</a>                        </li>                        <li>                          <a href="/news/qa/now/latest">قطر</a>                        </li>                        <li>                          <a href="/news/om/now/latest">عمان</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">أخبار الدول</a>                    <div class="nav-column">                      <h3 class="invisible">أخبار الدول</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/kw/now/latest">الكويت</a>                        </li>                        <li>                          <a href="/news/jo/now/latest">الأردن</a>                        </li>                        <li>                          <a href="/news/ma/now/latest">المغرب</a>                        </li>                        <li>                          <a href="/news/tn/now/latest">تونس</a>                        </li>                        <li>                          <a href="/news/ps/now/latest">فلسطين</a>                        </li>                        <li>                          <a href="/news/iq/now/latest">العراق</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">أخبار إقليمية</a>                    <div class="nav-column">                      <h3>أخبار إقليمية</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/regions/gulf">الخليج</a>                        </li>                        <li>                          <a href="/news/regions/levant">الشام</a>                        </li>                        <li>                          <a href="/news/regions/north-africa">شمال أفريقيا</a>                        </li>                        <li>                          <a href="/news/regions/middle-east">الشرق الأوسط</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">أخبار عالمية</a>                    <div class="nav-column">                      <h3>أخبار عالمية</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/international/global-economy">اقتصاد عالمى</a>                        </li>                        <li>                          <a href="/news/international/goods-and-metals">أحداث عالمية</a>                        </li>                        <li>                          <a href="/news/international/global-indices">مؤشرات عالمية</a>                        </li>                        <li>                          <a href="/news/international/oil-and-energy">نفط ومعادن</a>                        </li>                        <li>                          <a href="/news/international/currencies">عملات</a>                        </li>                        <li>                          <a href="/news/international/global-reports">تقارير عالمية</a>                        </li>                      </ul>                    </div>                  </li>                </ul>              </div>            </li>            <li class="dl-menu__menu-item" id="companies">              <a href="javascript:;">الشركات</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <h3 class="invisible">.</h3>                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/companies">الشركات المدرجة</a>                    </li>                    <li>                      <a href="/countries/sa/events">مفكرة الشركات</a>                    </li>                    <li>                      <a href="/countries/sa/stock-prices">أسعار الأسهم</a>                    </li>                    <li>                      <a href="/countries/sa/fair-values">القيم العادلة</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <h3 class="invisible">.</h3>                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/earnings">إعلانات الأرباح</a>                    </li>                    <li>                      <a href="/countries/sa/corporate-action">الإجراءات</a>                    </li>                                        <li>                      <a href="/countries/sa/major-shareholders">كبار الملاك</a>                    </li>                    <li>                      <a href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <h3>الاكتتابات</h3>                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/ipos">قائمة الإكتتابات</a>                    </li>                    <li>                      <a href="/ipo/list">بحث فى الاكتتابات</a>                    </li>                    <li>                      <a href="/ipos/news">أخبار الاكتتابات</a>                    </li>                    <li>                      <a href="/ipo/calendar">مفكرة الاكتتابات</a>                    </li>                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item" id="funds">              <a href="javascript:;">صناديق الاستثمار</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/funds">صناديق الاستثمار</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/funds-statistics">إحصائيات الصناديق</a>                    </li>                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item" id="analysis-tools">              <a href="javascript:;">أدوات التحليل</a>              <!-- If current country has one market only -->              <div class="mi-js-submenu">                                  <div class="nav-column">                    <ul class="dl-submenu">                      <li>                        <a href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>                      </li>                      <li>                        <a href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>                      </li>                      <li>                        <a href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>                      </li>                    </ul>                  </div>                  <div class="nav-column">                    <ul class="dl-submenu">                      <li>                        <a href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>                      </li>                      <li>                        <a href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>                      </li>                      <li>                        <a href="/analysis-tools/performance-comparison">مقارنة الأداء</a>                      </li>                    </ul>                  </div>                                              </div>            </li>            <li class="dl-menu__menu-item" id="islamic-economy">              <a href="/news/islamic-finance">الاقتصاد الإسلامي</a>            </li>            <!--<li id="radio"                class="dl-menu__menu-item global__hide-for-ltr"                id="radio"                th:if="${#locale.getLanguage() == \'ar\'}">              <a href="javascript:;" th:text="#{navigation.radio}"/>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a th:href="${@url.to(\'RPC#live\')}" th:text="#{navigation.radio.live}"/>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#latestEpisodesPage\', countryCode)}">آخر الحلقات</a>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تقارير-اقتصادية\'}">تقارير                        اقتصادية</a>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تغطية-خاصة\'}">تغطية خاصة</a>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'مقالات\'}">مقالات</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a th:href="${@url.to(\'RPC#programs\')}" th:text="#{navigation.radio.programs}"/>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#videoPrograms\')}" th:text="#{navigation.radio.videoPrograms}"/>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#getExperts\')}">ضيوفنا</a>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#getPresenters\')}">المذيعون</a>                    </li>                  </ul>                </div>              </div>            </li>-->            <li class="dl-menu__menu-item global__hide-for-ltr" id="video">              <a href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">مباشر TV</a>            </li>                        <li class="dl-menu__menu-item" id="fixedincome">              <a href="javascript:;">السندات</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/fixedincome/bond/search" id="fixedIncomeBondScreener">بحث عن سندات</a>                    </li>                    <li>                      <a href="/fixed-income/news" id="fixedIncomeNews">أخبار السندات وأذون الخزانة</a>                    </li>                    <li>                      <a href="/fixedincome/calendar/searchForEvent" id="fixedIncomeCalendar">قائمة الأحداث</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/fixedincome/analytics/drawCurve" id="fixedIncomeAnalytics">تحليلات فنية</a>                    </li>                    <li>                      <a href="/fixedincome/leagueTables/view" id="fixedIncomeLeagueTables">جداول الديون</a>                    </li>                    <li>                      <a href="/fixedincome/research/search" id="fixedIncomeProspectus">تقارير</a>                    </li>                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item" id="personal">              <a href="javascript:;">شخصي</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/my/alerts">التنبيهات</a>                    </li>                    <li>                      <a href="/my/watch-list">أسهمي</a>                    </li>                    <li>                      <a href="/my/newsletters">النشرة البريدية</a>                    </li>                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item dl-menu__menu-item--iconic-item">              <a class="js-search-trigger" href="javascript:;">                <i class="fa fa-search fa-2x"></i>              </a>            </li>          </ul>          <!-- Search -->          <div class="search js-search js-desktop-search" id="search">            <angucomplete-alt id="autocomplete__companies" input-class="search__input" minlength="1" ng-controller="AutocompleteController" pause="400" selected-object="selectItem" text-no-results="عفواً, لم يتم العثور على أي نتائج" text-searching="جارٍ البحث..." title-field="label" remote-url="/api/1/companySearch?query=" placeholder="اكتب كلمة البحث أو رمز الشركة" class="ng-scope ng-isolate-scope"><div class="angucomplete-holder" ng-class="{\'angucomplete-dropdown-visible\': showDropdown}">  <input id="autocomplete__companies_value" ng-model="searchStr" ng-disabled="disableInput" type="" placeholder="اكتب كلمة البحث أو رمز الشركة" maxlength="524288" ng-focus="onFocusHandler()" class="search__input ng-valid-maxlength" ng-blur="hideResults($event)" autocapitalize="off" autocorrect="off" autocomplete="off" ng-change="inputChangeHandler(searchStr)">  <div id="autocomplete__companies_dropdown" class="angucomplete-dropdown ng-hide" ng-show="showDropdown"><div class="angucomplete-searching ng-hide" ng-show="searching"><div class="spinner"><div class="dot1"></div><div class="dot2"></div></div></div>    <div class="angucomplete-searching ng-binding" ng-show="!searching &amp;&amp; (!results || results.length == 0)" ng-bind="textNoResults">عفواً, لم يتم العثور على أي نتائج</div>    <!-- ngRepeat: result in results -->  </div></div></angucomplete-alt>            <i class="fa fa-search fa-2x"></i>          </div>        </nav>      </div>    </header>    <div id="Leaderboard">    </div>    <div></div>    <div class="mi-content">      <div>  <!--<div th:replace="components/ads/internal/mobile-banner" />-->  <main class="mi-main-content">      <h1 class="mi-section__title">الشركات المدرجة</h1>  <div class="mi-table-container ng-scope" ng-controller="PagedTableController as table" country="sa" src="/api/1/listed-companies">    <div class="global__table-container md-whiteframe-z1 ng-isolate-scope" st-init="" st-pipe="fetch" st-table="table.data">      <span class="global__no-results ng-hide" ng-show="table.rows.length == 0 &amp;&amp; table.loaded">عفواّ, لم نعثر على أى نتائج</span>      <table class="mi-table" ng-hide="!table.loaded || table.rows.length == 0" style="">        <thead class="mi-table__thead">          <tr class="mi-table__thead-tr">            <th st-ratio="20" style="width: 20%;">الشركة</th>            <th>السهم</th>            <th class="mi-hide-for-small">القطاع</th>                        <th>آخر سعر</th>            <th>نسبة التغيير</th>            <th class="mi-hide-for-small">آخر تحديث</th>          </tr>        </thead>        <tbody class="mi-table__tbody" ng-hide="table.reloading">          <!-- ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/8310/profile" class="ng-binding" href="/markets/TDWL/stocks/8310/profile">أمانة للتأمين</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8310" class="ng-binding" href="/markets/TDWL/stocks/8310">8310</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">13.16</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.15%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/8300/profile" class="ng-binding" href="/markets/TDWL/stocks/8300/profile">الوطنية</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8300" class="ng-binding" href="/markets/TDWL/stocks/8300">8300</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">33.1</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -2.65%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/1330/profile" class="ng-binding" href="/markets/TDWL/stocks/1330/profile">الخضري</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/1330" class="ng-binding" href="/markets/TDWL/stocks/1330">1330</a>            </td>            <td class="mi-hide-for-small ng-binding">السلع الرأسمالية</td>                        <td class="number ng-binding">5.39</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -6.26%            </td>            <td class="mi-hide-for-small ng-binding">29 أبريل 2019</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/1301/profile" class="ng-binding" href="/markets/TDWL/stocks/1301/profile">أسلاك</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/1301" class="ng-binding" href="/markets/TDWL/stocks/1301">1301</a>            </td>            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>                        <td class="number ng-binding">22.98</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.70%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/4003/profile" class="ng-binding" href="/markets/TDWL/stocks/4003/profile">إكسترا</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4003" class="ng-binding" href="/markets/TDWL/stocks/4003">4003</a>            </td>            <td class="mi-hide-for-small ng-binding">تجزئة السلع الكمالية</td>                        <td class="number ng-binding">57.5</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.17%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/8311/profile" class="ng-binding" href="/markets/TDWL/stocks/8311/profile">عناية</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8311" class="ng-binding" href="/markets/TDWL/stocks/8311">8311</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">22.16</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.91%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/1201/profile" class="ng-binding" href="/markets/TDWL/stocks/1201/profile">تكوين</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/1201" class="ng-binding" href="/markets/TDWL/stocks/1201">1201</a>            </td>            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>                        <td class="number ng-binding">9.35</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.95%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/8312/profile" class="ng-binding" href="/markets/TDWL/stocks/8312/profile">الإنماء طوكيو م</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8312" class="ng-binding" href="/markets/TDWL/stocks/8312">8312</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">14.5</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              3.87%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/3003/profile" class="ng-binding" href="/markets/TDWL/stocks/3003/profile">أسمنت المدينة</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/3003" class="ng-binding" href="/markets/TDWL/stocks/3003">3003</a>            </td>            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>                        <td class="number ng-binding">16.9</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.24%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/1810/profile" class="ng-binding" href="/markets/TDWL/stocks/1810/profile">سيرا</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/1810" class="ng-binding" href="/markets/TDWL/stocks/1810">1810</a>            </td>            <td class="mi-hide-for-small ng-binding">الخدمات الإستهلاكية</td>                        <td class="number ng-binding">16.98</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.12%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/4007/profile" class="ng-binding" href="/markets/TDWL/stocks/4007/profile">الحمادي</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4007" class="ng-binding" href="/markets/TDWL/stocks/4007">4007</a>            </td>            <td class="mi-hide-for-small ng-binding">الرعاية الصحية</td>                        <td class="number ng-binding">26.4</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.94%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/4004/profile" class="ng-binding" href="/markets/TDWL/stocks/4004/profile">دله الصحية</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4004" class="ng-binding" href="/markets/TDWL/stocks/4004">4004</a>            </td>            <td class="mi-hide-for-small ng-binding">الرعاية الصحية</td>                        <td class="number ng-binding">56.1</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -1.41%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/3005/profile" class="ng-binding" href="/markets/TDWL/stocks/3005/profile">أسمنت ام القرى</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/3005" class="ng-binding" href="/markets/TDWL/stocks/3005">3005</a>            </td>            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>                        <td class="number ng-binding">24.62</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -1.05%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/4031/profile" class="ng-binding" href="/markets/TDWL/stocks/4031/profile">الخدمات الأرضية</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4031" class="ng-binding" href="/markets/TDWL/stocks/4031">4031</a>            </td>            <td class="mi-hide-for-small ng-binding">النقل</td>                        <td class="number ng-binding">29.7</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -1.33%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/3004/profile" class="ng-binding" href="/markets/TDWL/stocks/3004/profile">أسمنت الشمالية</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/3004" class="ng-binding" href="/markets/TDWL/stocks/3004">3004</a>            </td>            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>                        <td class="number ng-binding">10.16</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.59%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/2222/profile" class="ng-binding" href="/markets/TDWL/stocks/2222/profile">أرامكو السعودية</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/2222" class="ng-binding" href="/markets/TDWL/stocks/2222">2222</a>            </td>            <td class="mi-hide-for-small ng-binding">الطاقة</td>                        <td class="number ng-binding">33.15</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.45%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/4321/profile" class="ng-binding" href="/markets/TDWL/stocks/4321/profile">المراكز</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4321" class="ng-binding" href="/markets/TDWL/stocks/4321">4321</a>            </td>            <td class="mi-hide-for-small ng-binding">إدارة وتطوير العقارات</td>                        <td class="number ng-binding">25.5</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -1.54%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/1182/profile" class="ng-binding" href="/markets/TDWL/stocks/1182/profile">أملاك</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/1182" class="ng-binding" href="/markets/TDWL/stocks/1182">1182</a>            </td>            <td class="mi-hide-for-small ng-binding">البنوك</td>                        <td class="number ng-binding">22.28</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -1.15%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/4011/profile" class="ng-binding" href="/markets/TDWL/stocks/4011/profile">لازوردي</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4011" class="ng-binding" href="/markets/TDWL/stocks/4011">4011</a>            </td>            <td class="mi-hide-for-small ng-binding">السلع طويلة الاجل</td>                        <td class="number ng-binding">14.82</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -3.14%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/4009/profile" class="ng-binding" href="/markets/TDWL/stocks/4009/profile">المستشفى السعودي الألماني</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4009" class="ng-binding" href="/markets/TDWL/stocks/4009">4009</a>            </td>            <td class="mi-hide-for-small ng-binding">الرعاية الصحية</td>                        <td class="number ng-binding">35.85</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -1.51%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index -->        </tbody>      </table>      <div ng-show="table.searcing" class="ng-hide">        <span class="global__loading">جارى التصفية, يرجى الإنتظار ...</span>        <div>    <div class="sk-spinner sk-spinner-wave">        <div class="sk-rect1"></div>        <div class="sk-rect2"></div>        <div class="sk-rect3"></div>        <div class="sk-rect4"></div>        <div class="sk-rect5"></div>    </div></div>      </div>      <div ng-hide="table.loaded" class="ng-hide" style="">        <div>    <div class="sk-spinner sk-spinner-wave">        <div class="sk-rect1"></div>        <div class="sk-rect2"></div>        <div class="sk-rect3"></div>        <div class="sk-rect4"></div>        <div class="sk-rect5"></div>    </div></div>      </div>      <div st-items-by-page="20" st-pagination="" st-template="/assets/ui/ngt/components/pagination/pagination.ng.html" class="ng-isolate-scope"><!-- ngIf: pages.length >= 2 --><div class="pagination ng-scope" ng-if="pages.length >= 2">    <nav role="navigation" aria-label="Pagination">        <ul class="cd-pagination no-space" role="menubar" aria-label="Pagination">            <!-- ngIf: currentPage > 1 --><li ng-if="currentPage > 1" class="ng-scope">                <a ng-click="selectPage(1)">                    <i class="fa fa-angle-double-right fa-lg"></i>                </a>            </li><!-- end ngIf: currentPage > 1 -->            <!-- ngIf: currentPage > 1 --><li class="cd-pagination__button ng-scope" aria-disabled="true" ng-if="currentPage > 1">                <a ng-click="selectPage(currentPage-1)" class="ng-binding">                  <i class="fa fa-lg fa-angle-right"></i>                  السابق                </a>            </li><!-- end ngIf: currentPage > 1 -->            <!-- ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">                <a ng-click="selectPage(page)" class="ng-binding">6</a>            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">                <a ng-click="selectPage(page)" class="ng-binding">7</a>            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope current">                <a ng-click="selectPage(page)" class="ng-binding">8</a>            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">                <a ng-click="selectPage(page)" class="ng-binding">9</a>            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">                <a ng-click="selectPage(page)" class="ng-binding">10</a>            </li><!-- end ngRepeat: page in pages -->            <!-- ngIf: currentPage < numPages --><li class="cd-pagination__button ng-scope" ng-if="currentPage < numPages">                <a ng-click="selectPage(currentPage+1)" href="" class="ng-binding">                  التالي                    <i class="fa fa-angle-left fa-lg"></i>                </a>            </li><!-- end ngIf: currentPage < numPages -->            <!-- ngIf: currentPage < numPages --><li ng-if="currentPage < numPages" class="ng-scope">                <a ng-click="selectPage(numPages)">                    <i class="fa fa-angle-double-left  fa-lg"></i>                </a>            </li><!-- end ngIf: currentPage < numPages -->        </ul>    </nav></div><!-- end ngIf: pages.length >= 2 --></div>    </div>  </div>    <!-- Speakol Widget - Removal IB-51 -->  <!-- <div th:replace="components/ads/common/speakol-one"/> -->  </main>  <aside class="mi-sidebar mi-show-for-large-up">    <!-- Radio component doesn\'t exist in English version -->    <!---->  <!--  <div th:unless="${device.isMobile()}">      <div>        <iframe onload="adjustIframeSize(this);" class="ad-iframe" src="/ads/side-bar"></iframe>      </div>      <script>        function adjustIframeSize(self) {          var index = 0;          var interval = setInterval( function(){            if (index < 3) {              self.style.height=self.contentDocument.body.scrollHeight +10 + \'px\';self.style.width=\'310px\';              index = index + 1;            } else {              clearInterval(interval)            }          }, 1);        }      </script>    </div>-->    <div>    <div class="mi-popular-news news-sidebar-mub md-whiteframe-z1 ng-scope" ng-controller="PopularNewsController as popular">    <h2 class="global__h2--collapsed">الأخبار الأكثر</h2>    <v-tabs active="tabs.active" class="vTabs--secondary ng-isolate-scope" control="tabs">      <!-- ngRepeat: page in popular.pages --><v-tab ng-bind="page.title" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope is-active" role="tab" aria-selected="true" tabindex="0">قراءة</v-tab><!-- end ngRepeat: page in popular.pages --><v-tab ng-bind="page.title" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope" role="tab" aria-selected="false" tabindex="-1">مشاركة</v-tab><!-- end ngRepeat: page in popular.pages -->    </v-tabs>    <v-pages active="tabs.active" class="vPages--default ng-isolate-scope" control="tabs" ng-swipe-left="tabs.next()" ng-swipe-right="tabs.previous()">      <!-- ngRepeat: page in popular.pages --><v-page ng-bind-html="page.content | unsafe" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope is-active" role="tabpanel">        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3680410/%D9%87%D9%8A%D8%A6%D8%A9-%D8%A7%D9%84%D9%86%D9%82%D9%84-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%B5%D8%B1%D9%81-%D8%AF%D8%B9%D9%85-%D8%A7%D9%84%D8%A3%D9%81%D8%B1%D8%A7%D8%AF-%D8%A7%D9%84%D8%B9%D8%A7%D9%85%D9%84%D9%8A%D9%86-%D9%81%D9%8A-%D9%86%D8%B4%D8%A7%D8%B7-%D8%AA%D9%88%D8%AC%D9%8A%D9%87-%D8%A7%D9%84%D9%85%D8%B1%D9%83%D8%A8%D8%A7%D8%AA-%D9%82%D8%B1%D9%8A%D8%A8%D8%A7-/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="فرع تابع لهيئة العامة للنقل السعودية" src="https://static.mubasher.info/File.Story_Image/3e19073c5aca3db54ef2c06eb4bf5ea6/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3680410/%D9%87%D9%8A%D8%A6%D8%A9-%D8%A7%D9%84%D9%86%D9%82%D9%84-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%B5%D8%B1%D9%81-%D8%AF%D8%B9%D9%85-%D8%A7%D9%84%D8%A3%D9%81%D8%B1%D8%A7%D8%AF-%D8%A7%D9%84%D8%B9%D8%A7%D9%85%D9%84%D9%8A%D9%86-%D9%81%D9%8A-%D9%86%D8%B4%D8%A7%D8%B7-%D8%AA%D9%88%D8%AC%D9%8A%D9%87-%D8%A7%D9%84%D9%85%D8%B1%D9%83%D8%A8%D8%A7%D8%AA-%D9%82%D8%B1%D9%8A%D8%A8%D8%A7-/">هيئة النقل السعودية: صرف دعم الأفراد العاملين في نشاط توجيه المركبات قريباً</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3680099/%D8%A7%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D8%B5%D8%AF%D8%B1-%D9%82%D8%B1%D8%A7%D8%B1%D8%A7-%D8%A8%D8%B4%D8%A3%D9%86-%D8%A7%D9%84%D9%85%D8%A8%D8%AA%D8%B9%D8%AB%D9%8A%D9%86/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="وزير التعليم السعودي، حمد بن محمد آل الشيخ، أرشيفية" src="https://static.mubasher.info/File.Story_Image/9e9e9919f67b43d61c15c7fd734289d3/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3680099/%D8%A7%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D8%B5%D8%AF%D8%B1-%D9%82%D8%B1%D8%A7%D8%B1%D8%A7-%D8%A8%D8%B4%D8%A3%D9%86-%D8%A7%D9%84%D9%85%D8%A8%D8%AA%D8%B9%D8%AB%D9%8A%D9%86/">التعليم السعودية تصدر قراراً بشأن المبتعثين</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3680101/%D9%85%D8%AD%D8%AF%D8%AB-%D8%A7%D9%84%D8%B0%D9%87%D8%A8-%D9%8A%D8%AA%D9%87%D8%A7%D9%88%D9%89-93-%D8%AF%D9%88%D9%84%D8%A7%D8%B1%D8%A7-%D8%B9%D9%86%D8%AF-%D8%A7%D9%84%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D9%85%D8%B9-%D9%85%D9%83%D8%A7%D8%B3%D8%A8-%D8%A7%D9%84%D8%A3%D8%B3%D9%87%D9%85/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/caeadbca5bf2481c2d38f04625e51f00/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3680101/%D9%85%D8%AD%D8%AF%D8%AB-%D8%A7%D9%84%D8%B0%D9%87%D8%A8-%D9%8A%D8%AA%D9%87%D8%A7%D9%88%D9%89-93-%D8%AF%D9%88%D9%84%D8%A7%D8%B1%D8%A7-%D8%B9%D9%86%D8%AF-%D8%A7%D9%84%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D9%85%D8%B9-%D9%85%D9%83%D8%A7%D8%B3%D8%A8-%D8%A7%D9%84%D8%A3%D8%B3%D9%87%D9%85/">محدث.. الذهب يتهاوى 93 دولاراً عند التسوية مع مكاسب الأسهم</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3679355/%D8%A7%D9%84%D9%84%D9%8A%D8%B1%D8%A9-%D8%A7%D9%84%D8%AA%D8%B1%D9%83%D9%8A%D8%A9-%D8%AA%D9%87%D8%A8%D8%B7-%D8%A5%D9%84%D9%89-%D9%85%D8%B3%D8%AA%D9%88%D9%89-%D8%AA%D8%A7%D8%B1%D9%8A%D8%AE%D9%8A-%D8%AC%D8%AF%D9%8A%D8%AF/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/1242bfad1995396ce3f6470a3d5584c2/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3679355/%D8%A7%D9%84%D9%84%D9%8A%D8%B1%D8%A9-%D8%A7%D9%84%D8%AA%D8%B1%D9%83%D9%8A%D8%A9-%D8%AA%D9%87%D8%A8%D8%B7-%D8%A5%D9%84%D9%89-%D9%85%D8%B3%D8%AA%D9%88%D9%89-%D8%AA%D8%A7%D8%B1%D9%8A%D8%AE%D9%8A-%D8%AC%D8%AF%D9%8A%D8%AF/">الليرة التركية تهبط إلى مستوى تاريخي جديد</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3679705/%D8%B9%D9%85%D9%84%D8%A9-%D8%A7%D9%84%D8%A8%D9%8A%D8%AA%D9%83%D9%88%D9%8A%D9%86-%D8%AA%D8%B9%D8%A7%D9%88%D8%AF-%D8%A7%D9%84%D8%B5%D8%B9%D9%88%D8%AF-%D8%A3%D8%B9%D9%84%D9%89-12-%D8%A3%D9%84%D9%81-%D8%AF%D9%88%D9%84%D8%A7%D8%B1/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/ab491b6531081c6058fa5b203b6cbecc/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3679705/%D8%B9%D9%85%D9%84%D8%A9-%D8%A7%D9%84%D8%A8%D9%8A%D8%AA%D9%83%D9%88%D9%8A%D9%86-%D8%AA%D8%B9%D8%A7%D9%88%D8%AF-%D8%A7%D9%84%D8%B5%D8%B9%D9%88%D8%AF-%D8%A3%D8%B9%D9%84%D9%89-12-%D8%A3%D9%84%D9%81-%D8%AF%D9%88%D9%84%D8%A7%D8%B1/">عملة البيتكوين تعاود الصعود أعلى 12 ألف دولار</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3679783/%D8%A3%D8%B1%D8%A7%D9%85%D9%83%D9%88-%D8%AA%D8%B1%D9%81%D8%B9-%D8%A3%D8%B3%D8%B9%D8%A7%D8%B1-%D8%A7%D9%84%D8%A8%D9%86%D8%B2%D9%8A%D9%86-%D8%A8%D9%86%D8%AD%D9%88-11-%D8%AD%D8%AA%D9%89-10-%D8%B3%D8%A8%D8%AA%D9%85%D8%A8%D8%B1/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="محطة للتزود بالوقود" src="https://static.mubasher.info/File.Story_Image/cf61a8737c62c57737e53b3677aa2bbc/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3679783/%D8%A3%D8%B1%D8%A7%D9%85%D9%83%D9%88-%D8%AA%D8%B1%D9%81%D8%B9-%D8%A3%D8%B3%D8%B9%D8%A7%D8%B1-%D8%A7%D9%84%D8%A8%D9%86%D8%B2%D9%8A%D9%86-%D8%A8%D9%86%D8%AD%D9%88-11-%D8%AD%D8%AA%D9%89-10-%D8%B3%D8%A8%D8%AA%D9%85%D8%A8%D8%B1/">أرامكو ترفع أسعار البنزين بنحو 11% حتى 10 سبتمبر</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3680546/%D8%A8%D9%803-%D8%B6%D9%88%D8%A7%D8%A8%D8%B7-%D8%A7%D9%84%D8%AA%D9%82%D8%A7%D8%B9%D8%AF-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D9%88%D8%B6%D8%AD-%D8%B7%D8%B1%D9%8A%D9%82%D8%A9-%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D8%A7%D9%84%D9%85%D8%B9%D8%A7%D8%B4-%D9%84%D9%85%D9%88%D8%B8%D9%81%D9%8A-%D8%A7%D9%84%D9%82%D8%B7%D8%A7%D8%B9-%D8%A7%D9%84%D8%B9%D8%A7%D9%85/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="مؤسسة التقاعد السعودية" src="https://static.mubasher.info/File.Story_Image/68cc490a847f0daba3afd0ddbd6d06c8/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3680546/%D8%A8%D9%803-%D8%B6%D9%88%D8%A7%D8%A8%D8%B7-%D8%A7%D9%84%D8%AA%D9%82%D8%A7%D8%B9%D8%AF-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D9%88%D8%B6%D8%AD-%D8%B7%D8%B1%D9%8A%D9%82%D8%A9-%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D8%A7%D9%84%D9%85%D8%B9%D8%A7%D8%B4-%D9%84%D9%85%D9%88%D8%B8%D9%81%D9%8A-%D8%A7%D9%84%D9%82%D8%B7%D8%A7%D8%B9-%D8%A7%D9%84%D8%B9%D8%A7%D9%85/">بـ3 ضوابط.. التقاعد السعودية توضح طريقة تسوية المعاش لموظفي القطاع العام</a>        </div>              </div>        <a class="mi-article-widget__more-button" href="/news/SA/now/popular">      <span>المزيد</span>      <i class="fa fa-chevron-left"></i>    </a>    </v-page><!-- end ngRepeat: page in popular.pages --><v-page ng-bind-html="page.content | unsafe" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope" role="tabpanel">            <a class="mi-article-widget__more-button" href="/news/SA/now/trending/">      <span>المزيد</span>      <i class="fa fa-chevron-left"></i>    </a>    </v-page><!-- end ngRepeat: page in popular.pages -->    </v-pages>  </div>    <div id="MPU">    </div>    </div>    <!-- Speakol Widget - Removal IB-51 -->    <!-- <div th:replace="components/ads/common/speakol-two"/> --><!--    <div th:unless="${device.isMobile()}">      <div th:replace="components/ads/insticator/insticator-widget"/>    </div>-->    <!-- -->    <!-- PS -->    <!--<div th:replace="components/ads/internal/may-like-articles" />-->    <!--<div th:replace="components/ads/internal/second-fold" />-->    <!--    <div th:if="${#locale.getLanguage() == \'ar\'}">          <span class="home__title">راديو مباشر</span>          <div class="internal-radio-carousel-container"></div>        </div>-->  </aside><!--  <div th:replace="components/ads/internal/mobile-fullpage"/>-->  <!--<div th:replace="components/ads/internal/mobile-interstitial"/>--><!--commented out as per Fayoumi\'s request-->  <!--<div th:replace="components/ads/internal/mobile-outstream"/>-->  <!--MFP-228 New Fixed-Replacement-ROS ads--><!--  <div th:replace="components/ads/home/mobile-fixed-replacement"/>  <div th:replace="components/ads/news/dfp/mobile/MPU3"/>--><!--Commented out as per Fayoumi\'s request-->  <!--<div th:replace="components/ads/internal/outstream"/>--><!--  <div th:if="${device.isMobile()}">    <div th:replace="components/ads/dfp/mobile-internal-pages"/>  </div>--><!--  <div th:if="${device.isMobile()}">    <div th:replace="components/ads/insticator/insticator-widget"/>  </div>--> <!-- <div th:replace="components/ads/internal/mobile-above-footer"/>--></div>    </div>    <footer>  <div class="mi-footer">    <div class="mi-show-for-large-up mi-footer__main-menu">      <ul>        <li class="mi-footer__menu-item mi-footer__menu__markets" id="markets">          <div class="mi-footer__menu-level1">الأسواق</div>          <ul>            <h3 class="mi-footer__menu-level2 invisible">الأسواق</h3>            <li>              <a class="mi-footer__menu-level3" href="/markets/TDWL">سوق الأسهم السعودي</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/EGX">البورصة المصرية</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/DFM">سوق دبي المالي</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/ADX">سوق أبوظبي</a>            </li>          </ul>          <ul>            <li>              <a class="mi-footer__menu-level3" href="/markets/BB">بورصة البحرين</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/QE">بورصة قطر</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/MSM">سوق مسقط</a>            </li>          </ul>          <ul>            <li>              <a class="mi-footer__menu-level3" href="/markets/KSE">سوق الكويت</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/ASE">بورصة عمان</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/CSE">سوق الدار البيضاء</a>            </li>          </ul>          <ul>            <li>              <a class="mi-footer__menu-level3" href="/markets/BDT">بورصة تونس</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/PEX">سوق فلسطين</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/ISX">سوق العراق</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/international-indices">مؤشرات الأسواق العالمية</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/commodities-prices">أسعار المعادن والطاقة</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/currencies">أسعار العملات</a>            </li>            <!--<li>              <a class="mi-footer__menu-level3"                 th:href="${@url.to(\'RMPC#regionalMap\')}"                 th:text="#{navigation.markets.regional-map}"/>            </li>-->          </ul>        </li>        <li class="mi-footer__menu-item mi-footer__menu__news" id="news">          <ul>            <div class="mi-footer__menu-level1">الأخبار</div>            <li class="mi-footer__menu__news__submenu">              <h3 class="mi-footer__menu-level2">أخبار الدول</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/eg/now/latest">مصر</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/latest">السعودية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/ae/now/latest">الإمارات</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/bh/now/latest">البحرين</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/qa/now/latest">قطر</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/om/now/latest">عمان</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/kw/now/latest">الكويت</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/jo/now/latest">الأردن</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/ma/now/latest">المغرب</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/tn/now/latest">تونس</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/ps/now/latest">فلسطين</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/iq/now/latest">العراق</a>                </li>              </ul>            </li>            <li class="mi-footer__menu__news__submenu">              <h3 class="mi-footer__menu-level2">أخبار إقليمية</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/regions/gulf">الخليج</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/regions/levant">الشام</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/regions/north-africa">شمال أفريقيا</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/regions/middle-east">الشرق الأوسط</a>                </li>              </ul>              <!-- happening now -->              <h3 class="mi-footer__menu-level2">يحدث الآن</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/top">أهم الأخبار</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/exclusive">حصرياً مباشر</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/latest">آخر الأخبار</a>                </li>                                  <li>                    <a class="mi-footer__menu-level3" href="/news/sa/now/announcements">إعلانات السوق</a>                  </li>                                                  <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/popular">منتشر الآن</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/trending/">الأكثر مشاركة</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/now/news-releases">بيانات صحفية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/misc">أخبار منوعة</a>                </li>              </ul>            </li>            <li class="mi-footer__menu__news__submenu">              <h3 class="mi-footer__menu-level2">نبض السوق</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/stocks">أخبار الأسهم</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/analysis">تحليلات إخبارية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/local">اقتصاد محلي</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/recommendations">توصيات</a>                </li>              </ul>              <h3 class="mi-footer__menu-level2">أخبار القطاعات</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/category/banking">بنوك</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/category/realEstate">عقارات</a>                </li>              </ul>              <h3 class="mi-footer__menu-level2">أخبار عالمية</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/global-economy">اقتصاد عالمى</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/goods-and-metals">أحداث عالمية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/global-indices">مؤشرات عالمية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/oil-and-energy">نفط ومعادن</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/currencies">عملات</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/global-reports">تقارير عالمية</a>                </li>              </ul>            </li>          </ul>        </li>        <li class="mi-footer__menu-item mi-footer__menu__companies" id="companies">          <div class="mi-footer__menu-level1">الشركات</div>          <ul>            <h3 class="mi-footer__menu-level2 invisible">الشركات</h3>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/companies">الشركات المدرجة</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/events">مفكرة الشركات</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/stock-prices">أسعار الأسهم</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/earnings">إعلانات الأرباح</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/fair-values">القيم العادلة</a>            </li>            <li>                          </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/major-shareholders">كبار الملاك</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/ipos">قائمة الإكتتابات</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/ipo/list">بحث فى الاكتتابات</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/ipos/news">أخبار الاكتتابات</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/ipo/calendar">مفكرة الاكتتابات</a>            </li>          </ul>        </li>        <li class="mi-footer__menu-item mi-footer__menu__analysis-tools" id="analysis-tools">          <div class="mi-footer__menu-level1">أدوات التحليل</div>          <!-- If current country has one market only -->                      <ul>              <h3 class="mi-footer__menu-level2 invisible">أدوات التحليل</h3>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/performance-comparison">مقارنة الأداء</a>              </li>            </ul>                    <!-- If current country has more than one markets i.e UAE -->                  </li>      </ul>    </div>    <div class="mi-footer__second-fold">      <div class="mi-footer__column1">        <div class="mi-footer__copyright">          <div class="mi-footer__logo" onclick="window.location.href=\'/countries/sa\'">              <svg viewBox="0 0 494.387 190.555">    <use xlink:href="#logo-white"></use>  </svg>            </div>          <span>جميع الحقوق تعود لشركة مباشر العالمية © 2005 - 2020</span>        </div>        <ul class="mi-footer__links">          <li>            <a href="/s/Terms">اتفاقية الاستخدام</a>          </li>          <li>            <a href="/s/disclaimer">إخلاء المسؤولية</a>          </li>          <li>            <a href="/s/aboutus">من نحن</a>          </li>          <li>            <a href="/contact">اتصل بنا</a>          </li>          <li>            <a href="/advertise">أعلن معنا</a>          </li>          <li>            <a href="http://www.decypha.com/" target="_blank">موقع ديسيفا</a>          </li>          <li>            <a href="/ir-services" target="_blank">خدمات المواقع</a>          </li>          <li>            <a href="/s/Jobs">وظائف</a>          </li>          <li>              <a target="_blank" href="/decypha-packages">ديسيفا</a>          </li>          <li>            <a href="/s/privacy-policy" target="_blank">سياسة الخصوصية</a>          </li>          <!--<li th:if="${#locale.getLanguage() == \'en\'}">            <a href="/s/decypha-financial-intelligence" th:text="#{components.footer.decypha-financial-intelligence}">Decypha Financial Intelligence</a>          </li>-->        </ul>        <div>جميع البيانات متأخرة 15 دقيقة أثناء الجلسة</div>        <div>هذا الموقع مرخص من وزراة الثقافة والإعلام السعودية</div>        <div>رقم التسجيل :ت 1 125 1435</div>      </div>      <div class="mi-footer__column2">        <ul class="mi-footer__social-icons">          <li>            <a target="_blank" href="https://twitter.com/mubasher"><i class="fa fa-twitter fa-2x"></i></a>          </li>          <li>            <a href="https://www.facebook.com/Mubasher.Info"><i class="fa fa-facebook fa-2x"></i></a>          </li>          <li>            <a href="https://www.youtube.com/channel/UC7hnxb7gD4nKZdZk3ZlZCYg"><i class="fa fa-youtube fa-2x"></i></a>          </li>          <li>            <a href="https://www.linkedin.com/company/1477149"><i class="fa fa-linkedin fa-2x"></i></a>          </li>          <li>            <a href="/news/rss"><i class="fa fa-rss fa-2x"></i></a>          </li>          <li>            <a href="https://play.google.com/store/apps/details?id=net.mis.mubasherinfo">              <i class="fa fa-android fa-2x"></i></a>          </li>          <li>            <a href="https://itunes.apple.com/app/imubasher/id494539772?mt=8"><i class="fa fa-apple fa-2x"></i></a>          </li>          </ul></div></div></div></footer>          </div>  <script src="//code.jquery.com/jquery-2.1.4.min.js"></script>  <script src="//ajax.googleapis.com/ajax/libs/angularjs/1.3.15/angular.min.js"></script>  <script src="/assets/ui/lib.min.js"></script>  <script src="/assets/ui/main.min.js"></script>  <div id="mi-js-scripts"></div>  <script>    <!-- Fix menu trigger on android browser4 -->    $(".dl-menu__menu-item").click(function () {      $(this).addClass(".dl-menu-item__hoverd");    });    $(document).ready(function () {      $(\'.tooltip\').tooltipster();      setTimeout(function(){ dataLayer.push({event: "triggerAds"});      console.log("triggerAds");      }, 1000);    });  </script>    <div pg-ng-tooltip=""></div></div>  <!-- Twitter universal website tag code -->  <script>    !function(e,t,n,s,u,a){e.twq||(s=e.twq=function(){s.exe?s.exe.apply(s,arguments):s.queue.push(arguments);    },s.version=\'1.1\',s.queue=[],u=t.createElement(n),u.async=!0,u.src=\'//static.ads-twitter.com/uwt.js\',      a=t.getElementsByTagName(n)[0],a.parentNode.insertBefore(u,a))}(window,document,\'script\');    // Insert Twitter Pixel ID and Standard Event data below    twq(\'init\',\'nyana\');    twq(\'track\',\'PageView\');  </script>  <!-- End Twitter universal website tag code --><div id="mm-blocker" class="mm-slideout"></div></body>' + '<body id="mi" ng-app="app" ng-controller="MainController" class="ar ng-scope" data-gr-c-s-loaded="true"><nav class="header__countries-menu mm-menu mm-offcanvas mm-top mm-front" id="countries-menu"><div class="mm-panel mm-opened mm-current" id="mm-8"><ul class="mm-listview mm-first mm-last">        <li class="header__country-selector__country">          <a href="/change-country?to=ae&amp;url=/countries/sa/companies">الإمارات</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=bh&amp;url=/countries/sa/companies">البحرين</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=om&amp;url=/countries/sa/companies">عُمان</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=qa&amp;url=/countries/sa/companies">قطر</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=kw&amp;url=/countries/sa/companies">الكويت</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=eg&amp;url=/countries/sa/companies">مصر</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=jo&amp;url=/countries/sa/companies">الأردن</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=tn&amp;url=/countries/sa/companies">تونس</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=ma&amp;url=/countries/sa/companies">المغرب</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=ps&amp;url=/countries/sa/companies">فلسطين</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=iq&amp;url=/countries/sa/companies">العراق</a>        </li>      </ul></div></nav><nav class="header__main-menu mm-menu mm-border-full mm-effect-slide-menu mm-effect-zoom-panels mm-pageshadow mm-offcanvas mm-right mm-hasnavbar-top mm-hasnavbar" id="main-menu"><div class="mm-navbar mm-navbar-top mm-hasbtns"><a class="mm-prev mm-btn mm-hidden"></a><a class="mm-title"> </a><a class="mm-close mm-btn" href="#wrapper"></a></div><div class="mm-panel mm-opened mm-current" id="mm-0"><ul class="mm-listview mm-first mm-last">        <li id="markets">          <a class="mm-next mm-fullsubopen" href="#mm-1" data-target="#mm-1"></a><span href="javascript:;">الأسواق</span>                  </li>        <li id="news">          <a class="mm-next mm-fullsubopen" href="#mm-2" data-target="#mm-2"></a><span href="javascript:;">الأخبار</span>                  </li>        <li id="companies">          <a class="mm-next mm-fullsubopen" href="#mm-3" data-target="#mm-3"></a><span href="javascript:;">الشركات</span>                  </li>        <li id="funds">          <a class="mm-next mm-fullsubopen" href="#mm-4" data-target="#mm-4"></a><span href="javascript:;">صناديق الاستثمار</span>                  </li>        <li id="analysis-tool">          <a class="mm-next mm-fullsubopen" href="#mm-5" data-target="#mm-5"></a><span href="javascript:;">أدوات التحليل</span>                  </li>        <li id="islamic-economy">          <a href="/news/islamic-finance">الاقتصاد الإسلامي</a>        </li>        <!--<li class="global__hide-for-ltr" id="radio" th:if="${#locale.getLanguage() == \'ar\'}">          <span th:text="#{navigation.radio}">راديو مباشر</span>          <ul>            <li>              <a th:href="${@url.to(\'RPC#live\')}" th:text="#{navigation.radio.live}"/>            </li>            <li>              <a th:href="${@url.to(\'RPC#latestEpisodesPage\', countryCode)}">آخر الحلقات</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تقارير-اقتصادية\'}">تقارير اقتصادية</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تغطية-خاصة\'}">تغطية خاصة</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'مقالات\'}">مقالات</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#programs\')}" th:text="#{navigation.radio.programs}"/>            </li>            <li>              <a th:href="${@url.to(\'RPC#videoPrograms\')}" th:text="#{navigation.radio.videoPrograms}"/>            </li>            <li>              <a th:href="${@url.to(\'RPC#getExperts\')}">ضيوفنا</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#getPresenters\')}">المذيعون</a>            </li>          </ul>        </li>-->        <li class="global__hide-for-ltr" id="video">          <a href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">مباشر TV</a>        </li>                <li id="fixedincome">          <a class="mm-next mm-fullsubopen" href="#mm-6" data-target="#mm-6"></a><span>السندات</span>                  </li>        <li>          <a class="mm-next mm-fullsubopen" href="#mm-7" data-target="#mm-7"></a><span>شخصي</span>                  </li>        <li>          <a href="http://tawasul.mubasher.info/" target="_blank">تواصل</a>        </li>        <!-- <li>          <a th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank" th:text="#{components.header.decypha}" target="_blank">          </a>        </li> -->        <li>          <a ng-click="decypha(\'decypha\')">ديسيفا</a>        </li>        <!--Add according to MFP-187-->        <li>          <a href="https://contest.mubasher.info/#/home" target="_blank">المستثمر اﻷول</a>        </li>        <li>          <!--Integrating Mubasher Pulse-->        </li><li>        <style>          .pulse-logo2{            padding: 5px 5px 4px;            min-width: 82px;            min-height: 21px;            max-width: 27%;          }        </style>        <a target="_blank" href="https://pulse.mubasher.info">          <img class="pulse-logo2" src="../../../images/pulse-logo.png">        </a>        </li>        <li>        </li><li>          <a href="http://magazine.mubasher.info/" target="_blank">            مجلة مباشر          </a>        </li>        <li class="mm-divider"></li>        <li>          <a href="https://english.mubasher.info">ENGLISH</a>        </li>        <li>                  </li>        <li>          <a class="header__login__text" href="/account/login">دخول</a>                  </li>      </ul></div><div class="mm-panel mm-hidden" id="mm-1"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الأسواق</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/markets/TDWL">سوق الأسهم السعودي</a>            </li>            <li>              <a href="/markets/EGX">البورصة المصرية</a>            </li>            <li>              <a href="/markets/DFM">سوق دبي المالي</a>            </li>            <li>              <a href="/markets/ADX">سوق أبوظبي</a>            </li>            <li>              <a href="/markets/BB">بورصة البحرين</a>            </li>            <li>              <a href="/markets/QE">بورصة قطر</a>            </li>            <li>              <a href="/markets/MSM">سوق مسقط</a>            </li>            <li>              <a href="/markets/BK">سوق الكويت</a>            </li>            <li>              <a href="/markets/ASE">بورصة عمان</a>            </li>            <li>              <a href="/markets/CSE">سوق الدار البيضاء</a>            </li>            <li>              <a href="/markets/BDT">بورصة تونس</a>            </li>            <li>              <a href="/markets/PEX">سوق فلسطين</a>            </li>            <li>              <a href="/markets/ISX">سوق العراق</a>            </li>            <li>              <a href="/international-indices">مؤشرات الأسواق العالمية</a>            </li>            <li>              <a href="/markets/commodities-prices">أسعار المعادن والطاقة</a>            </li>            <li>              <a href="/countries/sa/currencies">أسعار العملات</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-2"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الأخبار</a></div><ul class="mm-listview mm-first mm-last">            <!-- now -->            <li class="mm-divider">يحدث الآن</li>            <li>              <a href="/news/sa/now/top">أهم الأخبار</a>            </li>            <li>              <a href="/news/sa/now/exclusive">حصرياً مباشر</a>            </li>            <li>              <a href="/news/sa/now/latest">آخر الأخبار</a>            </li>                          <li>                <a href="/news/sa/now/announcements">إعلانات السوق</a>              </li>                                      <li class="global__hide-for-ltr">              <a href="/news/sa/now/popular">منتشر الآن</a>            </li>            <li>              <a href="/news/sa/now/trending/">الأكثر مشاركة</a>            </li>            <li>              <a href="/news/now/news-releases">بيانات صحفية</a>            </li><!--            <li>              <a th:href="${@url.to(\'NPC#miscellaneousNews\', countryCode)}"                 th:text="#{navigation.news.now.misc}"/>            </li>-->            <!-- recommendations-->            <li class="mm-divider">نبض السوق</li>            <li>              <a href="/news/sa/pulse/stocks">أخبار الأسهم</a>            </li>            <li>              <a href="/news/sa/pulse/analysis">تحليلات إخبارية</a>            </li>            <li>              <a href="/news/sa/pulse/local">اقتصاد محلي</a>            </li>            <li>              <a href="/news/sa/pulse/recommendations">توصيات</a>            </li>            <li class="mm-divider">أخبار القطاعات</li>            <li>              <a href="/news/sa/category/banking">بنوك</a>            </li>            <li>              <a href="/news/sa/category/realEstate">عقارات</a>            </li>            <li class="mm-divider">أخبار الدول</li>            <li>              <a href="/news/eg/now/latest">مصر</a>            </li>            <li>              <a href="/news/sa/now/latest">السعودية</a>            </li>            <li>              <a href="/news/ae/now/latest">الإمارات</a>            </li>            <li>              <a href="/news/bh/now/latest">البحرين</a>            </li>            <li>              <a href="/news/qa/now/latest">قطر</a>            </li>            <li>              <a href="/news/om/now/latest">عمان</a>            </li>            <li>              <a href="/news/kw/now/latest">الكويت</a>            </li>            <li>              <a href="/news/jo/now/latest">الأردن</a>            </li>            <li>              <a href="/news/ma/now/latest">المغرب</a>            </li>            <li>              <a href="/news/tn/now/latest">تونس</a>            </li>            <li>              <a href="/news/ps/now/latest">فلسطين</a>            </li>            <li>              <a href="/news/iq/now/latest">العراق</a>            </li>            <!-- regions-->            <li class="mm-divider">أخبار إقليمية</li>            <li>              <a href="/news/regions/gulf">الخليج</a>            </li>            <li>              <a href="/news/regions/levant">الشام</a>            </li>            <li>              <a href="/news/regions/north-africa">شمال أفريقيا</a>            </li>            <li>              <a href="/news/regions/middle-east">الشرق الأوسط</a>            </li>            <!-- international -->            <li class="mm-divider">أخبار عالمية</li>            <li>              <a href="/news/international/global-economy">اقتصاد عالمى</a>            </li>            <li>              <a href="/news/international/goods-and-metals">أحداث عالمية</a>            </li>              <li>                <a href="/news/international/global-indices">مؤشرات عالمية</a>              </li>              <li>                <a href="/news/international/oil-and-energy">نفط ومعادن</a>              </li>              <li>                <a href="/news/international/currencies">عملات</a>              </li>              <li>                <a href="/news/international/global-reports">تقارير عالمية</a>              </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-3"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الشركات</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/countries/sa/companies">الشركات المدرجة</a>            </li>            <li>              <a href="/countries/sa/events">مفكرة الشركات</a>            </li>            <li>              <a href="/countries/sa/stock-prices">أسعار الأسهم</a>            </li>            <li>              <a href="/countries/sa/earnings">إعلانات الأرباح</a>            </li>            <li>              <a href="/countries/sa/fair-values">القيم العادلة</a>            </li>            <li>              <a href="/countries/sa/corporate-action">الإجراءات</a>            </li>                        <li>              <a href="/countries/sa/major-shareholders">كبار الملاك</a>            </li>            <li>              <a href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>            </li>            <li class="mm-divider">الاكتتابات</li>            <li>              <a href="/countries/sa/ipos">قائمة الإكتتابات</a>            </li>            <li>              <a href="/ipo/list">بحث فى الاكتتابات</a>            </li>            <li>              <a href="/ipos/news">أخبار الاكتتابات</a>            </li>            <li>              <a href="/ipo/calendar">مفكرة الاكتتابات</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-4"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">صناديق الاستثمار</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/countries/sa/funds">صناديق الاستثمار</a>            </li>            <li>              <a href="/countries/sa/funds-statistics">إحصائيات الصناديق</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-5"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">أدوات التحليل</a></div><ul class="mm-listview mm-first mm-last">                                        <li>                <a href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>              </li>              <li>                <a href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>              </li>              <li>                <a href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>              </li>              <li>                <a href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>              </li>              <li>                <a href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>              </li>                        <li class="mm-divider">            </li>            <li>              <a href="/analysis-tools/performance-comparison">مقارنة الأداء</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-6"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">السندات</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/fixedincome/bond/search" id="fixedIncomeBondScreener">بحث عن سندات</a>            </li>            <li>              <a href="/fixed-income/news" id="fixedIncomeNews">أخبار السندات وأذون الخزانة</a>            </li>            <li>              <a href="/fixedincome/calendar/searchForEvent" id="fixedIncomeCalendar">قائمة الأحداث</a>            </li>            <li>              <a href="/fixedincome/analytics/drawCurve" id="fixedIncomeAnalytics">تحليلات فنية</a>            </li>            <li>              <a href="/fixedincome/leagueTables/view" id="fixedIncomeLeagueTables">جداول الديون</a>            </li>            <li>              <a href="/fixedincome/research/search" id="fixedIncomeProspectus">تقارير</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-7"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">شخصي</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/my/alerts">التنبيهات</a>            </li>            <li>              <a href="/my/watch-list">أسهمي</a>            </li>            <li>              <a href="/my/newsletters">النشرة البريدية</a>            </li>          </ul></div></nav><div class="js-wrapper mm-page mm-slideout" id="wrapper">  <svg class="hidden" version="1.1" viewBox="0 0 0 0" xmlns="http://www.w3.org/2000/svg">  <defs>    <style>      .logo-white-path {        clip-rule: evenodd;        fill-rule: evenodd;        fill: white;        font-size: 46.6299px;        font-family: \'HelveticaNeue\';      }      .logo-path {        clip-rule: evenodd;        fill-rule: evenodd;        fill: #324651;        text-align: center;        font-size: 46.6299px;        font-family: \'HelveticaNeue\';      }    </style>    <g id="logo-white">      <path class="logo-white-path" d="M209.596 29.677c-6.25 0.016-11.243-4.937-11.261-11.188 c-0.018-6.191 5.027-11.29 11.194-11.29c6.182-0.004 11.3 5.1 11.3 11.226C220.852 24.6 215.8 29.7 209.6 29.7"></path>      <path class="logo-white-path" d="M228.308 37.976c6.231-0.01 11.3 5 11.3 11.2 c0.015 6.189-5.011 11.227-11.233 11.252c-6.213 0.025-11.246-4.99-11.271-11.209C217.063 43 222.1 38 228.3 38"></path>      <path class="logo-white-path" d="M350.278 190.471c-6.27-0.009-11.204-4.942-11.197-11.212 c0.013-6.26 4.968-11.18 11.248-11.176c6.242 0 11.3 5 11.2 11.224C361.555 185.5 356.5 190.5 350.3 190.5"></path>      <path class="logo-white-path" d="M186.161 37.976c6.26 0 11.2 5 11.2 11.2 c-0.01 6.241-4.993 11.239-11.209 11.226c-6.257-0.017-11.212-4.99-11.212-11.228C174.949 42.9 179.9 38 186.2 38"></path>      <path class="logo-white-path" d="M455.92 80.125c-21.212 0-38.405 17.191-38.405 38.4 c0 4.3 0.7 8.4 2 12.316l-48.126 0.003l13.9-27.74h-3.242c0 0-2.13 0.019-2.822 0.1 c-2.13 0.126-3.67 0.098-7.926 1.351c-3.949 1.159-7.026 2.719-9.881 4.503c-2.381 1.493-5.863 4.278-8.803 7.7 c-2.912 3.325-5.713 7.695-5.713 7.695l-3.294 6.464l-41.201 0.003L364.7 0l-76.514 49.172l25.429-0.036L260.64 156.919h193.847 c0 0 0.9 0 1.4 0.01c21.212 0 38.4-17.183 38.4-38.403C494.32 97.3 477.1 80.1 455.9 80.125z M455.92 133.3 c-7.998 0-14.48-6.479-14.48-14.47c0-7.998 6.482-14.476 14.48-14.476c7.996 0 14.5 6.5 14.5 14.5 C470.393 126.8 463.9 133.3 455.9 133.327z"></path>      <path class="logo-white-path" d="M269.61 81.427c0 0-1.617 0.013-2.842 0.09c-2.001 0.132-3.655 0.07-7.903 1.3 c-3.946 1.162-7.021 2.722-9.876 4.507c-2.378 1.488-5.868 4.279-8.813 7.662c-2.904 3.327-5.282 8.108-5.282 8.108l-14.116 27.7 h-16.391l19.092-39.485h-3.237c0 0-1.617 0.015-2.835 0.095c-2.012 0.13-3.665 0.068-7.905 1.3 c-3.957 1.161-7.034 2.717-9.892 4.502c-2.373 1.493-5.857 4.28-8.808 7.668c-2.899 3.321-5.282 8.104-5.282 8.104l-8.901 17.8 h-16.959l13.92-27.753h-3.245c0 0-2.141 0.019-2.822 0.057c-2.133 0.126-3.663 0.098-7.926 1.4 c-3.944 1.159-7.026 2.719-9.884 4.503c-2.378 1.493-5.857 4.28-8.808 7.669c-2.904 3.329-5.708 7.695-5.708 7.695l-3.291 6.5 l-52.558-0.005l14.007-27.748h-3.242c0 0-2.131 0.019-2.815 0.057c-2.136 0.126-3.678 0.098-7.934 1.4 c-3.944 1.159-7.021 2.719-9.877 4.503c-2.383 1.493-5.858 4.28-8.813 7.669c-2.906 3.329-5.114 7.843-5.114 7.843l-16.204 31.1 l0 0c0 0-3.136 6.731-7.038 11.469c-3.094 3.766-7.43 6.804-9.757 8.194c-2.313 1.384-7.141 3.645-11.872 4.5 C5.251 180.9 0 180.5 0 180.502s2.33 2.1 5 3.806c2.034 1.4 4.3 2.4 5.5 3 c2.481 1.1 4.3 1.7 6.9 2.253c2.531 0.6 4.8 0.8 4.8 0.763s1.621 0.2 3.2 0.169c0.707 0 1.62-0.024 2.848-0.09 c2.001-0.134 3.5 0 7.904-1.323c4.033-1.188 7.072-2.582 9.92-4.368c2.383-1.478 5.952-4.249 8.904-7.627 c2.907-3.337 5.296-8.019 5.296-8.019l6.043-12.125l169.4 0.009l12.816-26.07l24.302-49.431H269.61z"></path>      <path class="logo-white-path" d="M30.239 76.472V55.626H22.45v-2.789h18.735v2.789h-7.819v20.846H30.239z"></path>      <path class="logo-white-path" d="M44.296 76.472V52.836h4.71l5.592 16.735c0.518 1.6 0.9 2.7 1.1 3.499c0.269-0.861 0.687-2.123 1.258-3.789 l5.658-16.446h4.209v23.636h-3.015V56.689l-6.869 19.783h-2.822l-6.835-20.121v20.121H44.296z"></path>    </g>    <g id="logo">      <path class="logo-path" d="M209.596 29.677c-6.25 0.016-11.243-4.937-11.261-11.188 c-0.018-6.191 5.027-11.29 11.194-11.29c6.182-0.004 11.3 5.1 11.3 11.226C220.852 24.6 215.8 29.7 209.6 29.7"></path>      <path class="logo-path" d="M228.308 37.976c6.231-0.01 11.3 5 11.3 11.2 c0.015 6.189-5.011 11.227-11.233 11.252c-6.213 0.025-11.246-4.99-11.271-11.209C217.063 43 222.1 38 228.3 38"></path>      <path class="logo-path" d="M350.278 190.471c-6.27-0.009-11.204-4.942-11.197-11.212 c0.013-6.26 4.968-11.18 11.248-11.176c6.242 0 11.3 5 11.2 11.224C361.555 185.5 356.5 190.5 350.3 190.5"></path>      <path class="logo-path" d="M186.161 37.976c6.26 0 11.2 5 11.2 11.2 c-0.01 6.241-4.993 11.239-11.209 11.226c-6.257-0.017-11.212-4.99-11.212-11.228C174.949 42.9 179.9 38 186.2 38"></path>      <path class="logo-path" d="M455.92 80.125c-21.212 0-38.405 17.191-38.405 38.4 c0 4.3 0.7 8.4 2 12.316l-48.126 0.003l13.9-27.74h-3.242c0 0-2.13 0.019-2.822 0.1 c-2.13 0.126-3.67 0.098-7.926 1.351c-3.949 1.159-7.026 2.719-9.881 4.503c-2.381 1.493-5.863 4.278-8.803 7.7 c-2.912 3.325-5.713 7.695-5.713 7.695l-3.294 6.464l-41.201 0.003L364.7 0l-76.514 49.172l25.429-0.036L260.64 156.919h193.847 c0 0 0.9 0 1.4 0.01c21.212 0 38.4-17.183 38.4-38.403C494.32 97.3 477.1 80.1 455.9 80.125z M455.92 133.3 c-7.998 0-14.48-6.479-14.48-14.47c0-7.998 6.482-14.476 14.48-14.476c7.996 0 14.5 6.5 14.5 14.5 C470.393 126.8 463.9 133.3 455.9 133.327z"></path>      <path class="logo-path" d="M269.61 81.427c0 0-1.617 0.013-2.842 0.09c-2.001 0.132-3.655 0.07-7.903 1.3 c-3.946 1.162-7.021 2.722-9.876 4.507c-2.378 1.488-5.868 4.279-8.813 7.662c-2.904 3.327-5.282 8.108-5.282 8.108l-14.116 27.7 h-16.391l19.092-39.485h-3.237c0 0-1.617 0.015-2.835 0.095c-2.012 0.13-3.665 0.068-7.905 1.3 c-3.957 1.161-7.034 2.717-9.892 4.502c-2.373 1.493-5.857 4.28-8.808 7.668c-2.899 3.321-5.282 8.104-5.282 8.104l-8.901 17.8 h-16.959l13.92-27.753h-3.245c0 0-2.141 0.019-2.822 0.057c-2.133 0.126-3.663 0.098-7.926 1.4 c-3.944 1.159-7.026 2.719-9.884 4.503c-2.378 1.493-5.857 4.28-8.808 7.669c-2.904 3.329-5.708 7.695-5.708 7.695l-3.291 6.5 l-52.558-0.005l14.007-27.748h-3.242c0 0-2.131 0.019-2.815 0.057c-2.136 0.126-3.678 0.098-7.934 1.4 c-3.944 1.159-7.021 2.719-9.877 4.503c-2.383 1.493-5.858 4.28-8.813 7.669c-2.906 3.329-5.114 7.843-5.114 7.843l-16.204 31.1 l0 0c0 0-3.136 6.731-7.038 11.469c-3.094 3.766-7.43 6.804-9.757 8.194c-2.313 1.384-7.141 3.645-11.872 4.5 C5.251 180.9 0 180.5 0 180.502s2.33 2.1 5 3.806c2.034 1.4 4.3 2.4 5.5 3 c2.481 1.1 4.3 1.7 6.9 2.253c2.531 0.6 4.8 0.8 4.8 0.763s1.621 0.2 3.2 0.169c0.707 0 1.62-0.024 2.848-0.09 c2.001-0.134 3.5 0 7.904-1.323c4.033-1.188 7.072-2.582 9.92-4.368c2.383-1.478 5.952-4.249 8.904-7.627 c2.907-3.337 5.296-8.019 5.296-8.019l6.043-12.125l169.4 0.009l12.816-26.07l24.302-49.431H269.61z"></path>      <path class="logo-path" d="M30.239 76.472V55.626H22.45v-2.789h18.735v2.789h-7.819v20.846H30.239z"></path>      <path class="logo-path" d="M44.296 76.472V52.836h4.71l5.592 16.735c0.518 1.6 0.9 2.7 1.1 3.499c0.269-0.861 0.687-2.123 1.258-3.789 l5.658-16.446h4.209v23.636h-3.015V56.689l-6.869 19.783h-2.822l-6.835-20.121v20.121H44.296z"></path>    </g>    <g id="logo-white-en">      <defs>        <rect height="65.7" width="326.9" x="-55"></rect>      </defs>      <clipPath>        <use overflow="visible" xlink:href="#SVGID_1_"></use>      </clipPath>      <path class="logo-white-path" d="M41.694 20.162c-1.315 0-1.315 0.987-1.315 0.987l0.094 13.8 c0 0 0.6 8.648-8.178 8.648c0 0-8.364 0.093-8.364-8.082V21.29c0 0 0.234-1.174-1.27-1.174c-1.362 0-1.221 1.174-1.221 1.174V36 c0 0 0.2 10.1 10.9 10.104c10.386 0 10.669-9.675 10.669-10.433V21.243C42.964 21.2 43 20.2 41.7 20.2"></path>      <path class="logo-white-path" d="M20.915 21.431c0 0 0-0.799-0.799-1.127c-0.777-0.321-1.27 0.422-1.457 0.6 l-7.425 10.293c0 0-0.469 0.61-1.034-0.282l-8.13-10.292c0 0-0.517-0.611-1.128-0.423c-0.611 0.189-0.894 0.704-0.846 1.6 L0 44.74c0 0-0.046 1.4 1.3 1.363s1.316-1.222 1.316-1.222V25.144l7.002 9.023c0 0 1.1 1.5 2.209-0.188 c1.081-1.646 6.626-8.882 6.626-8.882v19.736c0 0-0.088 1.3 1.5 1.175c1.175-0.094 0.988-1.22 0.988-1.22V21.431z"></path>      <path class="logo-white-path" d="M168.546 43.734l-10.309-6.813c0 0 8.648-0.179 8.648-8.471 c0-8.294-8.531-8.118-8.531-8.118h-8.412c-2.107 0-1.953 1.6-1.953 1.6v22.69c0 0-0.038 1.5 1.1 1.5 c1.265 0 1.222-1.436 1.222-1.436V22.702h6.516c0.474 0 3.1 0 5.3 1.304c2.192 1.3 3.7 7.198-0.177 9.6 c-2.785 1.717-6.459 1.008-7.642 0.889c-1.185-0.12-1.306 0.414-1.483 1.186c-0.177 0.8 0.9 1.4 0.9 1.362l13.21 8.5 c0 0 1.4 1.2 2.1 0.18C169.967 44.4 168.5 43.7 168.5 43.7"></path>      <path class="logo-white-path" d="M95.522 19.596c-6.516-0.711-11.492 3.376-11.373 7.8 c0.117 4.4 3 5.7 8.1 6.634c5.096 0.9 7 1.7 7 1.658c2.665 1 2.5 4.3 1 5.9 c-1.423 1.601-4.148 2.558-5.766 2.616c-3.879 0.146-6.052-2.374-6.052-2.374c-0.492-0.407-0.683-1.486-1.69-1.25 c-1.347 0.316-0.296 1.836-0.296 1.836c2.311 3.2 7.2 3.6 7.2 3.554c5.45 0.7 8.648-3.139 8.648-3.139 c2.963-3.852 0.987-8.363-1.976-9.429c-3.17-1.142-6.139-1.234-10.05-2.065c-3.909-0.828-3.495-4.087-3.495-4.087 c0.059-2.37 2.252-5.271 7.643-5.332c5.392-0.059 8.5 3.4 8.5 3.436c1.304 1.4 2.1 0.5 2.133-0.12 c0.06-0.591-0.058-1.183-0.531-1.776C104.121 23.1 102 20.3 95.5 19.6"></path>      <path class="logo-white-path" d="M124.084 20.618c-1.126 0-1.185 1.067-1.185 1.067v15.166h-14.336V21.862 c0 0 0.296-1.42-1.305-1.362c-1.304 0.047-1.067 1.42-1.067 1.42v14.575h-0.889c0 0-1.303-0.06-1.303 1.2 c0 1.3 1.2 1.3 1.2 1.305h1.007v5.746c0 0 0 1.2 1.2 1.243c1.246 0 1.187-1.184 1.187-1.184v-5.984h14.1v6.103 c0 0-0.008 1.1 1.2 1.137c1.226 0 1.269-1.195 1.269-1.195V21.743C125.209 21.7 125.2 20.6 124.1 20.6"></path>      <path class="logo-white-path" d="M86.101 44.016c0 0-10.841-21.504-11.849-23.163c-1.007-1.66-2.072 0-2.072 0 l-8.047 15.604l-2.395 0.015c-0.888 0-0.982 0.633-0.982 1.284c0 1.1 1.1 0.9 1.1 0.929h1.067c0 0-2.447 4.637-2.726 5.3 c-0.355 0.889-0.416 1.5 0.5 1.955c1.008 0.5 1.659-0.77 1.659-0.77l3.436-6.399H80.71l2.903 5.9 c0 0 1 2 2.1 1.305C86.87 45.3 86.1 44 86.1 44 M66.965 36.374l5.984-12.026c0 0 0.296-0.475 0.6 0.1 c0.296 0.5 6 12 6 11.967H66.965z"></path>      <path class="logo-white-path" d="M58.314 34.283c0 0 3.87-1.954 3.87-6.575c0-4.622-4.563-7.199-8.294-7.199 h-6.517c0 0-1.512 0.2-1.512 1.744v10.479h-1.833c0 0-0.799-0.094-0.799 1.271c0 1.1 0.6 1.2 0.6 1.173h2.066v9.447 c0 0-0.046 1.5 1.5 1.48h7.213c0 0 6.016-0.165 6.016-6.837C60.57 35.9 58.3 34.3 58.3 34.3 M48.203 22.7 l6.338-0.005c1.718 0 5.1 1.7 5.1 5.451c0 4.443-5.095 4.501-5.095 4.501h-6.338V22.736z M53.557 43.831h-5.351v-8.748 l6.435-0.008c0.858 0 3.5 0.9 3.5 4.031C58.143 43.7 53.6 43.8 53.6 43.8"></path>      <path class="logo-white-path" d="M146.17 23.033c0 0 1.3 0.1 1.305-1.304c0-1.244-1.305-1.125-1.305-1.125 h-15.818c-2.251 0-2.012 1.717-2.012 1.717V36.54l-1.653 0.009c0 0-1.132 0.229-1.132 1.177c0 1.2 1.1 1.4 1.1 1.361h1.669 v4.917c0 2.5 1.7 2.1 1.7 2.073h15.818c0 0 0.9 0 0.889-1.185s-0.95-1.007-0.95-1.007h-14.798v-4.799h15.284 c0 0 0.937-0.177 0.937-1.361c0-1.186-1.125-1.246-1.125-1.246h-15.228V23.033H146.17z"></path>    </g>    <g id="logo-en">      <defs>        <rect height="65.7" width="326.9" x="-55"></rect>      </defs>      <clipPath>        <use overflow="visible" xlink:href="#SVGID_1_"></use>      </clipPath>      <path class="logo-path" d="M41.694 20.162c-1.315 0-1.315 0.987-1.315 0.987l0.094 13.8 c0 0 0.6 8.648-8.178 8.648c0 0-8.364 0.093-8.364-8.082V21.29c0 0 0.234-1.174-1.27-1.174c-1.362 0-1.221 1.174-1.221 1.174V36 c0 0 0.2 10.1 10.9 10.104c10.386 0 10.669-9.675 10.669-10.433V21.243C42.964 21.2 43 20.2 41.7 20.2"></path>      <path class="logo-path" d="M20.915 21.431c0 0 0-0.799-0.799-1.127c-0.777-0.321-1.27 0.422-1.457 0.6 l-7.425 10.293c0 0-0.469 0.61-1.034-0.282l-8.13-10.292c0 0-0.517-0.611-1.128-0.423c-0.611 0.189-0.894 0.704-0.846 1.6 L0 44.74c0 0-0.046 1.4 1.3 1.363s1.316-1.222 1.316-1.222V25.144l7.002 9.023c0 0 1.1 1.5 2.209-0.188 c1.081-1.646 6.626-8.882 6.626-8.882v19.736c0 0-0.088 1.3 1.5 1.175c1.175-0.094 0.988-1.22 0.988-1.22V21.431z"></path>      <path class="logo-path" d="M168.546 43.734l-10.309-6.813c0 0 8.648-0.179 8.648-8.471 c0-8.294-8.531-8.118-8.531-8.118h-8.412c-2.107 0-1.953 1.6-1.953 1.6v22.69c0 0-0.038 1.5 1.1 1.5 c1.265 0 1.222-1.436 1.222-1.436V22.702h6.516c0.474 0 3.1 0 5.3 1.304c2.192 1.3 3.7 7.198-0.177 9.6 c-2.785 1.717-6.459 1.008-7.642 0.889c-1.185-0.12-1.306 0.414-1.483 1.186c-0.177 0.8 0.9 1.4 0.9 1.362l13.21 8.5 c0 0 1.4 1.2 2.1 0.18C169.967 44.4 168.5 43.7 168.5 43.7"></path>      <path class="logo-path" d="M95.522 19.596c-6.516-0.711-11.492 3.376-11.373 7.8 c0.117 4.4 3 5.7 8.1 6.634c5.096 0.9 7 1.7 7 1.658c2.665 1 2.5 4.3 1 5.9 c-1.423 1.601-4.148 2.558-5.766 2.616c-3.879 0.146-6.052-2.374-6.052-2.374c-0.492-0.407-0.683-1.486-1.69-1.25 c-1.347 0.316-0.296 1.836-0.296 1.836c2.311 3.2 7.2 3.6 7.2 3.554c5.45 0.7 8.648-3.139 8.648-3.139 c2.963-3.852 0.987-8.363-1.976-9.429c-3.17-1.142-6.139-1.234-10.05-2.065c-3.909-0.828-3.495-4.087-3.495-4.087 c0.059-2.37 2.252-5.271 7.643-5.332c5.392-0.059 8.5 3.4 8.5 3.436c1.304 1.4 2.1 0.5 2.133-0.12 c0.06-0.591-0.058-1.183-0.531-1.776C104.121 23.1 102 20.3 95.5 19.6"></path>      <path class="logo-path" d="M124.084 20.618c-1.126 0-1.185 1.067-1.185 1.067v15.166h-14.336V21.862 c0 0 0.296-1.42-1.305-1.362c-1.304 0.047-1.067 1.42-1.067 1.42v14.575h-0.889c0 0-1.303-0.06-1.303 1.2 c0 1.3 1.2 1.3 1.2 1.305h1.007v5.746c0 0 0 1.2 1.2 1.243c1.246 0 1.187-1.184 1.187-1.184v-5.984h14.1v6.103 c0 0-0.008 1.1 1.2 1.137c1.226 0 1.269-1.195 1.269-1.195V21.743C125.209 21.7 125.2 20.6 124.1 20.6"></path>      <path class="logo-path" d="M86.101 44.016c0 0-10.841-21.504-11.849-23.163c-1.007-1.66-2.072 0-2.072 0 l-8.047 15.604l-2.395 0.015c-0.888 0-0.982 0.633-0.982 1.284c0 1.1 1.1 0.9 1.1 0.929h1.067c0 0-2.447 4.637-2.726 5.3 c-0.355 0.889-0.416 1.5 0.5 1.955c1.008 0.5 1.659-0.77 1.659-0.77l3.436-6.399H80.71l2.903 5.9 c0 0 1 2 2.1 1.305C86.87 45.3 86.1 44 86.1 44 M66.965 36.374l5.984-12.026c0 0 0.296-0.475 0.6 0.1 c0.296 0.5 6 12 6 11.967H66.965z"></path>      <path class="logo-path" d="M58.314 34.283c0 0 3.87-1.954 3.87-6.575c0-4.622-4.563-7.199-8.294-7.199 h-6.517c0 0-1.512 0.2-1.512 1.744v10.479h-1.833c0 0-0.799-0.094-0.799 1.271c0 1.1 0.6 1.2 0.6 1.173h2.066v9.447 c0 0-0.046 1.5 1.5 1.48h7.213c0 0 6.016-0.165 6.016-6.837C60.57 35.9 58.3 34.3 58.3 34.3 M48.203 22.7 l6.338-0.005c1.718 0 5.1 1.7 5.1 5.451c0 4.443-5.095 4.501-5.095 4.501h-6.338V22.736z M53.557 43.831h-5.351v-8.748 l6.435-0.008c0.858 0 3.5 0.9 3.5 4.031C58.143 43.7 53.6 43.8 53.6 43.8"></path>      <path class="logo-path" d="M146.17 23.033c0 0 1.3 0.1 1.305-1.304c0-1.244-1.305-1.125-1.305-1.125 h-15.818c-2.251 0-2.012 1.717-2.012 1.717V36.54l-1.653 0.009c0 0-1.132 0.229-1.132 1.177c0 1.2 1.1 1.4 1.1 1.361h1.669 v4.917c0 2.5 1.7 2.1 1.7 2.073h15.818c0 0 0.9 0 0.889-1.185s-0.95-1.007-0.95-1.007h-14.798v-4.799h15.284 c0 0 0.937-0.177 0.937-1.361c0-1.186-1.125-1.246-1.125-1.246h-15.228V23.033H146.17z"></path>    </g>  </defs></svg>  <!--<script type="text/javascript" xmlns:th="http://www.thymeleaf.org" th:fragment="body">-->  <!--(function () {-->    <!--var em = document.createElement(\'script\');-->    <!--em.type = \'text/javascript\';-->    <!--em.async = true;-->    <!--em.src =-->      <!--(\'https:\' == document.location.protocol ? \'https://me-ssl\' : \'http://me-cdn\') + \'.effectivemeasure.net/em.js\';-->    <!--var s = document.getElementsByTagName(\'script\')[0];-->    <!--s.parentNode.insertBefore(em, s);-->  <!--}());--><!--</script>-->  <div class="">    <header class="header">      <!-- DESKTOP ADS BLOCK -->      <!-- DESKTOP ADS BLOCK -->      <!-- MOBILE ADS BLOCK -->                  <!-- MOBILE ADS BLOCK -->      <div class="header__top-for-mobile">        <div class="top-bar__triggers">          <a class="main-menu-trigger fa fa-bars fa-2x" href="#main-menu" style="float: right;"></a>          <!-- Logo -->          <div class="header__logo header-logo-margins" onclick="window.location.href=\'/countries/sa\'">              <svg viewBox="0 0 494.387 190.555">    <use xlink:href="#logo-white"></use>  </svg>            </div>          <a class="countries-menu-trigger header-country-margins" href="#countries-menu">            <span>السعودية</span>            <span class="fa fa-caret-down fa-4x"></span>          </a>          <!-- ngRepeat: image in images --><img ng-repeat="image in images" src="/assets/ui/images/mobile-logo-G20.png" class="ng-scope"><!-- end ngRepeat: image in images --><img ng-repeat="image in images" src="/assets/ui/images/mobile-logo-vision.png" class="ng-scope"><!-- end ngRepeat: image in images -->          <div class="header__left-side left-search-icon">            <a class="search-trigger js-search-trigger fa fa-search fa-2x" href="javascript:;" style="float: left;">            </a>          </div>        </div>        <!-- Search -->        <div class="search js-search" id="search">          <i class="fa fa-search fa-2x search__icon"></i>          <angucomplete-alt id="autocomplete__companies" input-class="search__input" minlength="1" ng-controller="AutocompleteController" pause="400" placeholder="اكتب كلمة البحث أو رمز الشركة" selected-object="selectItem" text-no-results="عفواً, لم يتم العثور على أي نتائج" text-searching="جارٍ البحث..." title-field="label" remote-url="/api/1/companySearch?query=" class="ng-scope ng-isolate-scope"><div class="angucomplete-holder" ng-class="{\'angucomplete-dropdown-visible\': showDropdown}">  <input id="autocomplete__companies_value" ng-model="searchStr" ng-disabled="disableInput" type="" placeholder="اكتب كلمة البحث أو رمز الشركة" maxlength="524288" ng-focus="onFocusHandler()" class="search__input ng-valid-maxlength" ng-blur="hideResults($event)" autocapitalize="off" autocorrect="off" autocomplete="off" ng-change="inputChangeHandler(searchStr)">  <div id="autocomplete__companies_dropdown" class="angucomplete-dropdown ng-hide" ng-show="showDropdown"><div class="angucomplete-searching ng-hide" ng-show="searching"><div class="spinner"><div class="dot1"></div><div class="dot2"></div></div></div>    <div class="angucomplete-searching ng-binding" ng-show="!searching &amp;&amp; (!results || results.length == 0)" ng-bind="textNoResults">عفواً, لم يتم العثور على أي نتائج</div>    <!-- ngRepeat: result in results -->  </div></div></angucomplete-alt>        </div>      </div>      <div class="header-desktop mi-show-for-large-up">        <div class="header__top-for-desktop">          <div class="header__top-for-desktop-row">            <a class="header__other-site" href="http://tawasul.mubasher.info/" target="_blank">              <i class="fa fa-caret-right fa-2x"></i>              تواصل            </a>            <a class="header__other-site" href="http://magazine.mubasher.info/" target="_blank">              <i class="fa fa-caret-right fa-2x"></i>              مجلة مباشر            </a>            <a class="header__other-site" href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">              <i class="fa fa-play-circle"></i>              <div style="direction: ltr; display: inline-block;">TV مباشر</div>            </a>                        <a class="header__other-site" href="/contact">              <i class="fa fa-envelope"></i>              اتصل بنا            </a>            <a class="header__other-site" href="/advertise">              <i class="fa fa-envelope"></i>              اعلن معنا            </a>            <!-- <a th:if="${#locale.getLanguage() == \'ar\'}" class="header__login-button" style="background: #458D37 !important;" th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank"                th:text="#{components.header.decypha}">ديسيفا</a>            <a th:if="${#locale.getLanguage() == \'en\'}" class="header__login-button" style="background: #458D37 !important; font-family: Roboto,sans-serif !important;" th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank"                th:text="#{components.header.decypha}">ديسيفا</a> -->            <!-- Page Content Buttons -->            <a class="header__login-button" ng-click="decypha(\'decypha\')" style="background: #458D37 !important; font-family: Roboto,sans-serif !important;">ديسيفا</a>            <!-- Page Content Button -->            <!--Add according to MFP-187-->            <a class="header__login-button" style="background: #00c2d6 !important;" target="_blank" href="https://contest.mubasher.info/#/home">المستثمر اﻷول</a>                        <style>              /*.pulse-logo{*/              /*display: inline-block;*/              /*width: 252px;*/              /*height: 100%;*/              /*background: #212121 url(../images/pulse-logo.png) no-repeat center 2px;*/              /*padding: 10px 50px 29px;*/              /*text-align: center;*/              /*color: black;*/              /*text-decoration: none;*/              /*margin-top: -6px;*/              /*}*/              .pulse-logo2{                padding: 5px 5px 4px;                min-width: 82px;                min-height: 21px;                max-width: 27%;              }            </style>            <a target="_blank" href="https://pulse.mubasher.info">              <img class="pulse-logo2" src="../../../images/pulse-logo.png">            </a>            <span class="header__spacer">              &nbsp;            </span>            <a class="header__social-link" target="_blank" href="https://twitter.com/mubasher"><i class="fa fa-twitter fa-lg"></i></a>            <a class="header__social-link" href="https://www.facebook.com/Mubasher.Info"><i class="fa fa-facebook fa-lg"></i></a>            <a class="header__social-link" href="https://www.youtube.com/channel/UC7hnxb7gD4nKZdZk3ZlZCYg">              <i class="fa fa-youtube fa-lg"></i>            </a>            <a class="header__social-link" href="https://www.linkedin.com/company/1477149">              <i class="fa fa-linkedin fa-lg"></i>            </a>            <a class="header__social-link" href="/news/rss"><i class="fa fa-rss fa-lg"></i></a>            <a class="header__social-link" href="https://play.google.com/store/apps/details?id=net.mis.mubasherinfo">              <i class="fa fa-android fa-lg"></i>            </a>            <a class="header__social-link" href="https://itunes.apple.com/app/imubasher/id494539772?mt=8">              <i class="fa fa-apple fa-lg"></i>            </a>            <a class="header__login-button" href="/account/login">              دخول              <i class="fa fa-user fa-lg"></i>            </a>                                    <a class="header__language" href="https://english.mubasher.info">              <span>ENGLISH</span>            </a>          </div>        </div>        <div class="header__columns">          <div class="header__column1">            <!-- Logo -->            <div class="header__logo-wrapper">              <div class="header__logo" onclick="window.location.href=\'/countries/sa\'">                  <svg viewBox="0 0 494.387 190.555">    <use xlink:href="#logo"></use>  </svg>                </div>              <div class="countries-menu-trigger">                <a href="javascript:;" id="mi-js-countries-menu-trigger">                  <span>السعودية</span>                  <span class="fa fa-caret-down"></span>                </a>                <nav class="header__countries-menu--desktop mi-js-countries-menu-desktop" style="">                  <ul>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=ae&amp;url=/countries/sa/companies">الإمارات</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=bh&amp;url=/countries/sa/companies">البحرين</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=om&amp;url=/countries/sa/companies">عُمان</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=qa&amp;url=/countries/sa/companies">قطر</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=kw&amp;url=/countries/sa/companies">الكويت</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=eg&amp;url=/countries/sa/companies">مصر</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=jo&amp;url=/countries/sa/companies">الأردن</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=tn&amp;url=/countries/sa/companies">تونس</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=ma&amp;url=/countries/sa/companies">المغرب</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=ps&amp;url=/countries/sa/companies">فلسطين</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=iq&amp;url=/countries/sa/companies">العراق</a>                    </li>                  </ul>                </nav>              </div>            </div>            <!--Market Status -->            <div class="header__market-status">              <div class="header__market-status-column">                <div class="header__market-status-row">                  <a class="header__market-name" href="/markets/TDWL">TDWL</a>                  <span class="header__market-status--close">مغلق</span>                </div>                              </div>              <span class="header__market-time">12 أغسطس 04:49 م</span>            </div>          </div>          <div class="header__column1 banner-logo-desktop" ng-class="{\'banner-desktop-en\':(getLanguage == \'en\')}">            <!-- Logo -->            <div class="header__logo-wrapper">              <!-- ngRepeat: image in images --><div class="header__logo ng-scope" ng-repeat="image in images">                  <div class="tooltip tooltipstered"><img src="/assets/ui/images/logo-G20.png">                    <span class="tooltiptext ng-binding" ng-class="{\'tooltip-desktop-en\':(getLanguage == \'en\')}" style="left: 95%">مجموعة العشرين 2020</span>                  </div>              </div><!-- end ngRepeat: image in images --><div class="header__logo ng-scope" ng-repeat="image in images">                  <div class="tooltip tooltipstered"><img src="/assets/ui/images/logo-vision.png">                    <span class="tooltiptext ng-binding" ng-class="{\'tooltip-desktop-en\':(getLanguage == \'en\')}" style="left: 95%">رؤية المملكة العربية السعودية 2030</span>                  </div>              </div><!-- end ngRepeat: image in images -->            </div>          </div><!--          <div class="header__column2">             &lt;!&ndash;<div th:replace="components/ads/news/dfp/desktop/LB2"/>&ndash;&gt;            &lt;!&ndash;=====to display default leaderboard ad-slot [728,90] ======&ndash;&gt;            <div th:if="${isHomePage}">              <div th:replace="components/ads/home/leaderboard"/>            </div>            <div th:unless="${isHomePage}">              <div>                <iframe id="leaderboard-ros-001" style="width: 736px; height: 108px;" class="ad-iframe" src="/ads/LB2"></iframe>              </div>            </div>            </div>-->           <!--======= billboard 790x250 ============ -->        </div>        <nav class="header__navigation mi-js-desktop-menu-container">          <ul class="dl-menu mi-show-for-large-up mi-js-desktop-menu">            <li class="dl-menu__menu-item dl-menu__menu-item--iconic-item">              <a href="/countries/sa">                <i class="fa fa-home fa-2x"></i>              </a>            </li>            <li class="dl-menu__menu-item" id="markets">              <a href="javascript:;">الأسواق</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/markets/TDWL">سوق الأسهم السعودي</a>                    </li>                    <li>                      <a href="/markets/EGX">البورصة المصرية</a>                    </li>                    <li>                      <a href="/markets/DFM">سوق دبي المالي</a>                    </li>                    <li>                      <a href="/markets/ADX">سوق أبوظبي</a>                    </li>                    <li>                      <a href="/markets/BB">بورصة البحرين</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/markets/QE">بورصة قطر</a>                    </li>                    <li>                      <a href="/markets/MSM">سوق مسقط</a>                    </li>                    <li>                      <a href="/markets/BK">سوق الكويت</a>                    </li>                    <li>                      <a href="/markets/ASE">بورصة عمان</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/markets/CSE">سوق الدار البيضاء</a>                    </li>                    <li>                      <a href="/markets/BDT">بورصة تونس</a>                    </li>                    <li>                      <a href="/markets/PEX">سوق فلسطين</a>                    </li>                    <li>                      <a href="/markets/ISX">سوق العراق</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/international-indices">مؤشرات الأسواق العالمية</a>                    </li>                    <li>                      <a href="/markets/commodities-prices">أسعار المعادن والطاقة</a>                    </li>                    <li>                      <a href="/countries/sa/currencies">أسعار العملات</a>                    </li>                    <!--<li>                      <a th:href="${@url.to(\'RMPC#regionalMap\')}"                         th:text="#{navigation.markets.regional-map}"/>                    </li>-->                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item" id="news">              <a href="javascript:;">الأخبار</a>              <div class="mi-js-submenu">                <ul class="dl-submenu">                  <li>                    <a href="javascript:;">يحدث الآن</a>                    <div class="nav-column">                      <h3>يحدث الآن</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/sa/now/top">أهم الأخبار</a>                        </li>                        <li>                          <a href="/news/sa/now/exclusive">حصرياً مباشر</a>                        </li>                        <li>                          <a href="/news/sa/now/latest">آخر الأخبار</a>                        </li>                                                  <li>                            <a href="/news/sa/now/announcements">إعلانات السوق</a>                          </li>                                                                          <li class="global__hide-for-ltr">                          <a href="/news/sa/now/popular">منتشر الآن</a>                        </li>                        <li>                          <a href="/news/sa/now/trending/">الأكثر مشاركة</a>                        </li>                        <li>                          <a href="/news/now/news-releases">بيانات صحفية</a>                        </li>                        <li>                          <a href="/news/international/misc">أخبار منوعة</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">نبض السوق</a>                    <div class="nav-column">                      <h3>نبض السوق</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/sa/pulse/stocks">أخبار الأسهم</a>                        </li>                        <li>                          <a href="/news/sa/pulse/analysis">تحليلات إخبارية</a>                        </li>                        <li>                          <a href="/news/sa/pulse/local">اقتصاد محلي</a>                        </li>                        <li>                          <a href="/news/sa/pulse/recommendations">توصيات</a>                        </li>                      </ul>                      <h3>أخبار القطاعات</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/sa/category/banking">بنوك</a>                        </li><li>                          <a href="/news/sa/category/realEstate">عقارات</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">أخبار الدول</a>                    <div class="nav-column">                      <h3>أخبار الدول</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/eg/now/latest">مصر</a>                        </li>                        <li>                          <a href="/news/sa/now/latest">السعودية</a>                        </li>                        <li>                          <a href="/news/ae/now/latest">الإمارات</a>                        </li>                        <li>                          <a href="/news/bh/now/latest">البحرين</a>                        </li>                        <li>                          <a href="/news/qa/now/latest">قطر</a>                        </li>                        <li>                          <a href="/news/om/now/latest">عمان</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">أخبار الدول</a>                    <div class="nav-column">                      <h3 class="invisible">أخبار الدول</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/kw/now/latest">الكويت</a>                        </li>                        <li>                          <a href="/news/jo/now/latest">الأردن</a>                        </li>                        <li>                          <a href="/news/ma/now/latest">المغرب</a>                        </li>                        <li>                          <a href="/news/tn/now/latest">تونس</a>                        </li>                        <li>                          <a href="/news/ps/now/latest">فلسطين</a>                        </li>                        <li>                          <a href="/news/iq/now/latest">العراق</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">أخبار إقليمية</a>                    <div class="nav-column">                      <h3>أخبار إقليمية</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/regions/gulf">الخليج</a>                        </li>                        <li>                          <a href="/news/regions/levant">الشام</a>                        </li>                        <li>                          <a href="/news/regions/north-africa">شمال أفريقيا</a>                        </li>                        <li>                          <a href="/news/regions/middle-east">الشرق الأوسط</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">أخبار عالمية</a>                    <div class="nav-column">                      <h3>أخبار عالمية</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/international/global-economy">اقتصاد عالمى</a>                        </li>                        <li>                          <a href="/news/international/goods-and-metals">أحداث عالمية</a>                        </li>                        <li>                          <a href="/news/international/global-indices">مؤشرات عالمية</a>                        </li>                        <li>                          <a href="/news/international/oil-and-energy">نفط ومعادن</a>                        </li>                        <li>                          <a href="/news/international/currencies">عملات</a>                        </li>                        <li>                          <a href="/news/international/global-reports">تقارير عالمية</a>                        </li>                      </ul>                    </div>                  </li>                </ul>              </div>            </li>            <li class="dl-menu__menu-item" id="companies">              <a href="javascript:;">الشركات</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <h3 class="invisible">.</h3>                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/companies">الشركات المدرجة</a>                    </li>                    <li>                      <a href="/countries/sa/events">مفكرة الشركات</a>                    </li>                    <li>                      <a href="/countries/sa/stock-prices">أسعار الأسهم</a>                    </li>                    <li>                      <a href="/countries/sa/fair-values">القيم العادلة</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <h3 class="invisible">.</h3>                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/earnings">إعلانات الأرباح</a>                    </li>                    <li>                      <a href="/countries/sa/corporate-action">الإجراءات</a>                    </li>                                        <li>                      <a href="/countries/sa/major-shareholders">كبار الملاك</a>                    </li>                    <li>                      <a href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <h3>الاكتتابات</h3>                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/ipos">قائمة الإكتتابات</a>                    </li>                    <li>                      <a href="/ipo/list">بحث فى الاكتتابات</a>                    </li>                    <li>                      <a href="/ipos/news">أخبار الاكتتابات</a>                    </li>                    <li>                      <a href="/ipo/calendar">مفكرة الاكتتابات</a>                    </li>                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item" id="funds">              <a href="javascript:;">صناديق الاستثمار</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/funds">صناديق الاستثمار</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/funds-statistics">إحصائيات الصناديق</a>                    </li>                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item" id="analysis-tools">              <a href="javascript:;">أدوات التحليل</a>              <!-- If current country has one market only -->              <div class="mi-js-submenu">                                  <div class="nav-column">                    <ul class="dl-submenu">                      <li>                        <a href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>                      </li>                      <li>                        <a href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>                      </li>                      <li>                        <a href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>                      </li>                    </ul>                  </div>                  <div class="nav-column">                    <ul class="dl-submenu">                      <li>                        <a href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>                      </li>                      <li>                        <a href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>                      </li>                      <li>                        <a href="/analysis-tools/performance-comparison">مقارنة الأداء</a>                      </li>                    </ul>                  </div>                                              </div>            </li>            <li class="dl-menu__menu-item" id="islamic-economy">              <a href="/news/islamic-finance">الاقتصاد الإسلامي</a>            </li>            <!--<li id="radio"                class="dl-menu__menu-item global__hide-for-ltr"                id="radio"                th:if="${#locale.getLanguage() == \'ar\'}">              <a href="javascript:;" th:text="#{navigation.radio}"/>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a th:href="${@url.to(\'RPC#live\')}" th:text="#{navigation.radio.live}"/>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#latestEpisodesPage\', countryCode)}">آخر الحلقات</a>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تقارير-اقتصادية\'}">تقارير                        اقتصادية</a>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تغطية-خاصة\'}">تغطية خاصة</a>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'مقالات\'}">مقالات</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a th:href="${@url.to(\'RPC#programs\')}" th:text="#{navigation.radio.programs}"/>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#videoPrograms\')}" th:text="#{navigation.radio.videoPrograms}"/>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#getExperts\')}">ضيوفنا</a>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#getPresenters\')}">المذيعون</a>                    </li>                  </ul>                </div>              </div>            </li>-->            <li class="dl-menu__menu-item global__hide-for-ltr" id="video">              <a href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">مباشر TV</a>            </li>                        <li class="dl-menu__menu-item" id="fixedincome">              <a href="javascript:;">السندات</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/fixedincome/bond/search" id="fixedIncomeBondScreener">بحث عن سندات</a>                    </li>                    <li>                      <a href="/fixed-income/news" id="fixedIncomeNews">أخبار السندات وأذون الخزانة</a>                    </li>                    <li>                      <a href="/fixedincome/calendar/searchForEvent" id="fixedIncomeCalendar">قائمة الأحداث</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/fixedincome/analytics/drawCurve" id="fixedIncomeAnalytics">تحليلات فنية</a>                    </li>                    <li>                      <a href="/fixedincome/leagueTables/view" id="fixedIncomeLeagueTables">جداول الديون</a>                    </li>                    <li>                      <a href="/fixedincome/research/search" id="fixedIncomeProspectus">تقارير</a>                    </li>                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item" id="personal">              <a href="javascript:;">شخصي</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/my/alerts">التنبيهات</a>                    </li>                    <li>                      <a href="/my/watch-list">أسهمي</a>                    </li>                    <li>                      <a href="/my/newsletters">النشرة البريدية</a>                    </li>                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item dl-menu__menu-item--iconic-item">              <a class="js-search-trigger" href="javascript:;">                <i class="fa fa-search fa-2x"></i>              </a>            </li>          </ul>          <!-- Search -->          <div class="search js-search js-desktop-search" id="search">            <angucomplete-alt id="autocomplete__companies" input-class="search__input" minlength="1" ng-controller="AutocompleteController" pause="400" selected-object="selectItem" text-no-results="عفواً, لم يتم العثور على أي نتائج" text-searching="جارٍ البحث..." title-field="label" remote-url="/api/1/companySearch?query=" placeholder="اكتب كلمة البحث أو رمز الشركة" class="ng-scope ng-isolate-scope"><div class="angucomplete-holder" ng-class="{\'angucomplete-dropdown-visible\': showDropdown}">  <input id="autocomplete__companies_value" ng-model="searchStr" ng-disabled="disableInput" type="" placeholder="اكتب كلمة البحث أو رمز الشركة" maxlength="524288" ng-focus="onFocusHandler()" class="search__input ng-valid-maxlength" ng-blur="hideResults($event)" autocapitalize="off" autocorrect="off" autocomplete="off" ng-change="inputChangeHandler(searchStr)">  <div id="autocomplete__companies_dropdown" class="angucomplete-dropdown ng-hide" ng-show="showDropdown"><div class="angucomplete-searching ng-hide" ng-show="searching"><div class="spinner"><div class="dot1"></div><div class="dot2"></div></div></div>    <div class="angucomplete-searching ng-binding" ng-show="!searching &amp;&amp; (!results || results.length == 0)" ng-bind="textNoResults">عفواً, لم يتم العثور على أي نتائج</div>    <!-- ngRepeat: result in results -->  </div></div></angucomplete-alt>            <i class="fa fa-search fa-2x"></i>          </div>        </nav>      </div>    </header>    <div id="Leaderboard">    </div>    <div></div>    <div class="mi-content">      <div>  <!--<div th:replace="components/ads/internal/mobile-banner" />-->  <main class="mi-main-content">      <h1 class="mi-section__title">الشركات المدرجة</h1>  <div class="mi-table-container ng-scope" ng-controller="PagedTableController as table" country="sa" src="/api/1/listed-companies">    <div class="global__table-container md-whiteframe-z1 ng-isolate-scope" st-init="" st-pipe="fetch" st-table="table.data">      <span class="global__no-results ng-hide" ng-show="table.rows.length == 0 &amp;&amp; table.loaded">عفواّ, لم نعثر على أى نتائج</span>      <table class="mi-table" ng-hide="!table.loaded || table.rows.length == 0" style="">        <thead class="mi-table__thead">          <tr class="mi-table__thead-tr">            <th st-ratio="20" style="width: 20%;">الشركة</th>            <th>السهم</th>            <th class="mi-hide-for-small">القطاع</th>                        <th>آخر سعر</th>            <th>نسبة التغيير</th>            <th class="mi-hide-for-small">آخر تحديث</th>          </tr>        </thead>        <tbody class="mi-table__tbody" ng-hide="table.reloading">          <!-- ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/4292/profile" class="ng-binding" href="/markets/TDWL/stocks/4292/profile">عطاء</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4292" class="ng-binding" href="/markets/TDWL/stocks/4292">4292</a>            </td>            <td class="mi-hide-for-small ng-binding">الخدمات الإستهلاكية</td>                        <td class="number ng-binding">38.5</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              2.80%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/3007/profile" class="ng-binding" href="/markets/TDWL/stocks/3007/profile">الواحة</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/3007" class="ng-binding" href="/markets/TDWL/stocks/3007">3007</a>            </td>            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>                        <td class="number ng-binding">53.8</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.19%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/4005/profile" class="ng-binding" href="/markets/TDWL/stocks/4005/profile">رعاية</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4005" class="ng-binding" href="/markets/TDWL/stocks/4005">4005</a>            </td>            <td class="mi-hide-for-small ng-binding">الرعاية الصحية</td>                        <td class="number ng-binding">49</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              2.73%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/1302/profile" class="ng-binding" href="/markets/TDWL/stocks/1302/profile">بوان</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/1302" class="ng-binding" href="/markets/TDWL/stocks/1302">1302</a>            </td>            <td class="mi-hide-for-small ng-binding">السلع الرأسمالية</td>                        <td class="number ng-binding">14.66</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.69%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/1820/profile" class="ng-binding" href="/markets/TDWL/stocks/1820/profile">مجموعة الحكير</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/1820" class="ng-binding" href="/markets/TDWL/stocks/1820">1820</a>            </td>            <td class="mi-hide-for-small ng-binding">الخدمات الإستهلاكية</td>                        <td class="number ng-binding">15.64</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              1.43%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/8012/profile" class="ng-binding" href="/markets/TDWL/stocks/8012/profile">جزيرة تكافل</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/8012" class="ng-binding" href="/markets/TDWL/stocks/8012">8012</a>            </td>            <td class="mi-hide-for-small ng-binding">التأمين</td>                        <td class="number ng-binding">19</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.73%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/1180/profile" class="ng-binding" href="/markets/TDWL/stocks/1180/profile">الأهلي</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/1180" class="ng-binding" href="/markets/TDWL/stocks/1180">1180</a>            </td>            <td class="mi-hide-for-small ng-binding">البنوك</td>                        <td class="number ng-binding">37</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.27%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/4013/profile" class="ng-binding" href="/markets/TDWL/stocks/4013/profile">الحبيب</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4013" class="ng-binding" href="/markets/TDWL/stocks/4013">4013</a>            </td>            <td class="mi-hide-for-small ng-binding">الرعاية الصحية</td>                        <td class="number ng-binding">87.7</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.34%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/1830/profile" class="ng-binding" href="/markets/TDWL/stocks/1830/profile">وقت اللياقة</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/1830" class="ng-binding" href="/markets/TDWL/stocks/1830">1830</a>            </td>            <td class="mi-hide-for-small ng-binding">الخدمات الإستهلاكية</td>                        <td class="number ng-binding">61.1</td>            <td class="number ng-binding" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.00%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/7201/profile" class="ng-binding" href="/markets/TDWL/stocks/7201/profile">بحر العرب</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/7201" class="ng-binding" href="/markets/TDWL/stocks/7201">7201</a>            </td>            <td class="mi-hide-for-small ng-binding">التطبيقات وخدمات التقنية</td>                        <td class="number ng-binding">56.9</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.70%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/4320/profile" class="ng-binding" href="/markets/TDWL/stocks/4320/profile">الأندلس</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4320" class="ng-binding" href="/markets/TDWL/stocks/4320">4320</a>            </td>            <td class="mi-hide-for-small ng-binding">إدارة وتطوير العقارات</td>                        <td class="number ng-binding">15.9</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.75%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/1304/profile" class="ng-binding" href="/markets/TDWL/stocks/1304/profile">اليمامة للحديد</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/1304" class="ng-binding" href="/markets/TDWL/stocks/1304">1304</a>            </td>            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>                        <td class="number ng-binding">19.04</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.31%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/1202/profile" class="ng-binding" href="/markets/TDWL/stocks/1202/profile">مبكو</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/1202" class="ng-binding" href="/markets/TDWL/stocks/1202">1202</a>            </td>            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>                        <td class="number ng-binding">15.3</td>            <td class="number ng-binding" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.00%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/4051/profile" class="ng-binding" href="/markets/TDWL/stocks/4051/profile">باعظيم</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4051" class="ng-binding" href="/markets/TDWL/stocks/4051">4051</a>            </td>            <td class="mi-hide-for-small ng-binding">تجزئة السلع الكمالية</td>                        <td class="number ng-binding">56</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.18%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/1303/profile" class="ng-binding" href="/markets/TDWL/stocks/1303/profile">الصناعات الكهربائية</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/1303" class="ng-binding" href="/markets/TDWL/stocks/1303">1303</a>            </td>            <td class="mi-hide-for-small ng-binding">السلع الرأسمالية</td>                        <td class="number ng-binding">15.56</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.38%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/4006/profile" class="ng-binding" href="/markets/TDWL/stocks/4006/profile">أسواق المزرعة</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4006" class="ng-binding" href="/markets/TDWL/stocks/4006">4006</a>            </td>            <td class="mi-hide-for-small ng-binding">تجزئة الأغذية</td>                        <td class="number ng-binding">25.55</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.58%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/4008/profile" class="ng-binding" href="/markets/TDWL/stocks/4008/profile">ساكو</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4008" class="ng-binding" href="/markets/TDWL/stocks/4008">4008</a>            </td>            <td class="mi-hide-for-small ng-binding">تجزئة السلع الكمالية</td>                        <td class="number ng-binding">47</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.21%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/6012/profile" class="ng-binding" href="/markets/TDWL/stocks/6012/profile">ريدان</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/6012" class="ng-binding" href="/markets/TDWL/stocks/6012">6012</a>            </td>            <td class="mi-hide-for-small ng-binding">الخدمات الإستهلاكية</td>                        <td class="number ng-binding">21.2</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.66%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/4141/profile" class="ng-binding" href="/markets/TDWL/stocks/4141/profile">العمران</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4141" class="ng-binding" href="/markets/TDWL/stocks/4141">4141</a>            </td>            <td class="mi-hide-for-small ng-binding">السلع الرأسمالية</td>                        <td class="number ng-binding">72.6</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              2.69%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index">            <td>              <a ng-href="/markets/TDWL/stocks/7200/profile" class="ng-binding" href="/markets/TDWL/stocks/7200/profile">إم آي إس</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/7200" class="ng-binding" href="/markets/TDWL/stocks/7200">7200</a>            </td>            <td class="mi-hide-for-small ng-binding">التطبيقات وخدمات التقنية</td>                        <td class="number ng-binding">57.1</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.70%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index -->        </tbody>      </table>      <div ng-show="table.searcing" class="ng-hide">        <span class="global__loading">جارى التصفية, يرجى الإنتظار ...</span>        <div>    <div class="sk-spinner sk-spinner-wave">        <div class="sk-rect1"></div>        <div class="sk-rect2"></div>        <div class="sk-rect3"></div>        <div class="sk-rect4"></div>        <div class="sk-rect5"></div>    </div></div>      </div>      <div ng-hide="table.loaded" class="ng-hide" style="">        <div>    <div class="sk-spinner sk-spinner-wave">        <div class="sk-rect1"></div>        <div class="sk-rect2"></div>        <div class="sk-rect3"></div>        <div class="sk-rect4"></div>        <div class="sk-rect5"></div>    </div></div>      </div>      <div st-items-by-page="20" st-pagination="" st-template="/assets/ui/ngt/components/pagination/pagination.ng.html" class="ng-isolate-scope"><!-- ngIf: pages.length >= 2 --><div class="pagination ng-scope" ng-if="pages.length >= 2">    <nav role="navigation" aria-label="Pagination">        <ul class="cd-pagination no-space" role="menubar" aria-label="Pagination">            <!-- ngIf: currentPage > 1 --><li ng-if="currentPage > 1" class="ng-scope">                <a ng-click="selectPage(1)">                    <i class="fa fa-angle-double-right fa-lg"></i>                </a>            </li><!-- end ngIf: currentPage > 1 -->            <!-- ngIf: currentPage > 1 --><li class="cd-pagination__button ng-scope" aria-disabled="true" ng-if="currentPage > 1">                <a ng-click="selectPage(currentPage-1)" class="ng-binding">                  <i class="fa fa-lg fa-angle-right"></i>                  السابق                </a>            </li><!-- end ngIf: currentPage > 1 -->            <!-- ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">                <a ng-click="selectPage(page)" class="ng-binding">6</a>            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">                <a ng-click="selectPage(page)" class="ng-binding">7</a>            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">                <a ng-click="selectPage(page)" class="ng-binding">8</a>            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope current">                <a ng-click="selectPage(page)" class="ng-binding">9</a>            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">                <a ng-click="selectPage(page)" class="ng-binding">10</a>            </li><!-- end ngRepeat: page in pages -->            <!-- ngIf: currentPage < numPages --><li class="cd-pagination__button ng-scope" ng-if="currentPage < numPages">                <a ng-click="selectPage(currentPage+1)" href="" class="ng-binding">                  التالي                    <i class="fa fa-angle-left fa-lg"></i>                </a>            </li><!-- end ngIf: currentPage < numPages -->            <!-- ngIf: currentPage < numPages --><li ng-if="currentPage < numPages" class="ng-scope">                <a ng-click="selectPage(numPages)">                    <i class="fa fa-angle-double-left  fa-lg"></i>                </a>            </li><!-- end ngIf: currentPage < numPages -->        </ul>    </nav></div><!-- end ngIf: pages.length >= 2 --></div>    </div>  </div>    <!-- Speakol Widget - Removal IB-51 -->  <!-- <div th:replace="components/ads/common/speakol-one"/> -->  </main>  <aside class="mi-sidebar mi-show-for-large-up">    <!-- Radio component doesn\'t exist in English version -->    <!---->  <!--  <div th:unless="${device.isMobile()}">      <div>        <iframe onload="adjustIframeSize(this);" class="ad-iframe" src="/ads/side-bar"></iframe>      </div>      <script>        function adjustIframeSize(self) {          var index = 0;          var interval = setInterval( function(){            if (index < 3) {              self.style.height=self.contentDocument.body.scrollHeight +10 + \'px\';self.style.width=\'310px\';              index = index + 1;            } else {              clearInterval(interval)            }          }, 1);        }      </script>    </div>-->    <div>    <div class="mi-popular-news news-sidebar-mub md-whiteframe-z1 ng-scope" ng-controller="PopularNewsController as popular">    <h2 class="global__h2--collapsed">الأخبار الأكثر</h2>    <v-tabs active="tabs.active" class="vTabs--secondary ng-isolate-scope" control="tabs">      <!-- ngRepeat: page in popular.pages --><v-tab ng-bind="page.title" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope is-active" role="tab" aria-selected="true" tabindex="0">قراءة</v-tab><!-- end ngRepeat: page in popular.pages --><v-tab ng-bind="page.title" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope" role="tab" aria-selected="false" tabindex="-1">مشاركة</v-tab><!-- end ngRepeat: page in popular.pages -->    </v-tabs>    <v-pages active="tabs.active" class="vPages--default ng-isolate-scope" control="tabs" ng-swipe-left="tabs.next()" ng-swipe-right="tabs.previous()">      <!-- ngRepeat: page in popular.pages --><v-page ng-bind-html="page.content | unsafe" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope is-active" role="tabpanel">        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3680410/%D9%87%D9%8A%D8%A6%D8%A9-%D8%A7%D9%84%D9%86%D9%82%D9%84-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%B5%D8%B1%D9%81-%D8%AF%D8%B9%D9%85-%D8%A7%D9%84%D8%A3%D9%81%D8%B1%D8%A7%D8%AF-%D8%A7%D9%84%D8%B9%D8%A7%D9%85%D9%84%D9%8A%D9%86-%D9%81%D9%8A-%D9%86%D8%B4%D8%A7%D8%B7-%D8%AA%D9%88%D8%AC%D9%8A%D9%87-%D8%A7%D9%84%D9%85%D8%B1%D9%83%D8%A8%D8%A7%D8%AA-%D9%82%D8%B1%D9%8A%D8%A8%D8%A7-/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="فرع تابع لهيئة العامة للنقل السعودية" src="https://static.mubasher.info/File.Story_Image/3e19073c5aca3db54ef2c06eb4bf5ea6/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3680410/%D9%87%D9%8A%D8%A6%D8%A9-%D8%A7%D9%84%D9%86%D9%82%D9%84-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%B5%D8%B1%D9%81-%D8%AF%D8%B9%D9%85-%D8%A7%D9%84%D8%A3%D9%81%D8%B1%D8%A7%D8%AF-%D8%A7%D9%84%D8%B9%D8%A7%D9%85%D9%84%D9%8A%D9%86-%D9%81%D9%8A-%D9%86%D8%B4%D8%A7%D8%B7-%D8%AA%D9%88%D8%AC%D9%8A%D9%87-%D8%A7%D9%84%D9%85%D8%B1%D9%83%D8%A8%D8%A7%D8%AA-%D9%82%D8%B1%D9%8A%D8%A8%D8%A7-/">هيئة النقل السعودية: صرف دعم الأفراد العاملين في نشاط توجيه المركبات قريباً</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3680099/%D8%A7%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D8%B5%D8%AF%D8%B1-%D9%82%D8%B1%D8%A7%D8%B1%D8%A7-%D8%A8%D8%B4%D8%A3%D9%86-%D8%A7%D9%84%D9%85%D8%A8%D8%AA%D8%B9%D8%AB%D9%8A%D9%86/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="وزير التعليم السعودي، حمد بن محمد آل الشيخ، أرشيفية" src="https://static.mubasher.info/File.Story_Image/9e9e9919f67b43d61c15c7fd734289d3/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3680099/%D8%A7%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D8%B5%D8%AF%D8%B1-%D9%82%D8%B1%D8%A7%D8%B1%D8%A7-%D8%A8%D8%B4%D8%A3%D9%86-%D8%A7%D9%84%D9%85%D8%A8%D8%AA%D8%B9%D8%AB%D9%8A%D9%86/">التعليم السعودية تصدر قراراً بشأن المبتعثين</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3680101/%D9%85%D8%AD%D8%AF%D8%AB-%D8%A7%D9%84%D8%B0%D9%87%D8%A8-%D9%8A%D8%AA%D9%87%D8%A7%D9%88%D9%89-93-%D8%AF%D9%88%D9%84%D8%A7%D8%B1%D8%A7-%D8%B9%D9%86%D8%AF-%D8%A7%D9%84%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D9%85%D8%B9-%D9%85%D9%83%D8%A7%D8%B3%D8%A8-%D8%A7%D9%84%D8%A3%D8%B3%D9%87%D9%85/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/caeadbca5bf2481c2d38f04625e51f00/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3680101/%D9%85%D8%AD%D8%AF%D8%AB-%D8%A7%D9%84%D8%B0%D9%87%D8%A8-%D9%8A%D8%AA%D9%87%D8%A7%D9%88%D9%89-93-%D8%AF%D9%88%D9%84%D8%A7%D8%B1%D8%A7-%D8%B9%D9%86%D8%AF-%D8%A7%D9%84%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D9%85%D8%B9-%D9%85%D9%83%D8%A7%D8%B3%D8%A8-%D8%A7%D9%84%D8%A3%D8%B3%D9%87%D9%85/">محدث.. الذهب يتهاوى 93 دولاراً عند التسوية مع مكاسب الأسهم</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3679355/%D8%A7%D9%84%D9%84%D9%8A%D8%B1%D8%A9-%D8%A7%D9%84%D8%AA%D8%B1%D9%83%D9%8A%D8%A9-%D8%AA%D9%87%D8%A8%D8%B7-%D8%A5%D9%84%D9%89-%D9%85%D8%B3%D8%AA%D9%88%D9%89-%D8%AA%D8%A7%D8%B1%D9%8A%D8%AE%D9%8A-%D8%AC%D8%AF%D9%8A%D8%AF/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/1242bfad1995396ce3f6470a3d5584c2/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3679355/%D8%A7%D9%84%D9%84%D9%8A%D8%B1%D8%A9-%D8%A7%D9%84%D8%AA%D8%B1%D9%83%D9%8A%D8%A9-%D8%AA%D9%87%D8%A8%D8%B7-%D8%A5%D9%84%D9%89-%D9%85%D8%B3%D8%AA%D9%88%D9%89-%D8%AA%D8%A7%D8%B1%D9%8A%D8%AE%D9%8A-%D8%AC%D8%AF%D9%8A%D8%AF/">الليرة التركية تهبط إلى مستوى تاريخي جديد</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3679705/%D8%B9%D9%85%D9%84%D8%A9-%D8%A7%D9%84%D8%A8%D9%8A%D8%AA%D9%83%D9%88%D9%8A%D9%86-%D8%AA%D8%B9%D8%A7%D9%88%D8%AF-%D8%A7%D9%84%D8%B5%D8%B9%D9%88%D8%AF-%D8%A3%D8%B9%D9%84%D9%89-12-%D8%A3%D9%84%D9%81-%D8%AF%D9%88%D9%84%D8%A7%D8%B1/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/ab491b6531081c6058fa5b203b6cbecc/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3679705/%D8%B9%D9%85%D9%84%D8%A9-%D8%A7%D9%84%D8%A8%D9%8A%D8%AA%D9%83%D9%88%D9%8A%D9%86-%D8%AA%D8%B9%D8%A7%D9%88%D8%AF-%D8%A7%D9%84%D8%B5%D8%B9%D9%88%D8%AF-%D8%A3%D8%B9%D9%84%D9%89-12-%D8%A3%D9%84%D9%81-%D8%AF%D9%88%D9%84%D8%A7%D8%B1/">عملة البيتكوين تعاود الصعود أعلى 12 ألف دولار</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3679783/%D8%A3%D8%B1%D8%A7%D9%85%D9%83%D9%88-%D8%AA%D8%B1%D9%81%D8%B9-%D8%A3%D8%B3%D8%B9%D8%A7%D8%B1-%D8%A7%D9%84%D8%A8%D9%86%D8%B2%D9%8A%D9%86-%D8%A8%D9%86%D8%AD%D9%88-11-%D8%AD%D8%AA%D9%89-10-%D8%B3%D8%A8%D8%AA%D9%85%D8%A8%D8%B1/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="محطة للتزود بالوقود" src="https://static.mubasher.info/File.Story_Image/cf61a8737c62c57737e53b3677aa2bbc/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3679783/%D8%A3%D8%B1%D8%A7%D9%85%D9%83%D9%88-%D8%AA%D8%B1%D9%81%D8%B9-%D8%A3%D8%B3%D8%B9%D8%A7%D8%B1-%D8%A7%D9%84%D8%A8%D9%86%D8%B2%D9%8A%D9%86-%D8%A8%D9%86%D8%AD%D9%88-11-%D8%AD%D8%AA%D9%89-10-%D8%B3%D8%A8%D8%AA%D9%85%D8%A8%D8%B1/">أرامكو ترفع أسعار البنزين بنحو 11% حتى 10 سبتمبر</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3680546/%D8%A8%D9%803-%D8%B6%D9%88%D8%A7%D8%A8%D8%B7-%D8%A7%D9%84%D8%AA%D9%82%D8%A7%D8%B9%D8%AF-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D9%88%D8%B6%D8%AD-%D8%B7%D8%B1%D9%8A%D9%82%D8%A9-%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D8%A7%D9%84%D9%85%D8%B9%D8%A7%D8%B4-%D9%84%D9%85%D9%88%D8%B8%D9%81%D9%8A-%D8%A7%D9%84%D9%82%D8%B7%D8%A7%D8%B9-%D8%A7%D9%84%D8%B9%D8%A7%D9%85/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="مؤسسة التقاعد السعودية" src="https://static.mubasher.info/File.Story_Image/68cc490a847f0daba3afd0ddbd6d06c8/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3680546/%D8%A8%D9%803-%D8%B6%D9%88%D8%A7%D8%A8%D8%B7-%D8%A7%D9%84%D8%AA%D9%82%D8%A7%D8%B9%D8%AF-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D9%88%D8%B6%D8%AD-%D8%B7%D8%B1%D9%8A%D9%82%D8%A9-%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D8%A7%D9%84%D9%85%D8%B9%D8%A7%D8%B4-%D9%84%D9%85%D9%88%D8%B8%D9%81%D9%8A-%D8%A7%D9%84%D9%82%D8%B7%D8%A7%D8%B9-%D8%A7%D9%84%D8%B9%D8%A7%D9%85/">بـ3 ضوابط.. التقاعد السعودية توضح طريقة تسوية المعاش لموظفي القطاع العام</a>        </div>              </div>        <a class="mi-article-widget__more-button" href="/news/SA/now/popular">      <span>المزيد</span>      <i class="fa fa-chevron-left"></i>    </a>    </v-page><!-- end ngRepeat: page in popular.pages --><v-page ng-bind-html="page.content | unsafe" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope" role="tabpanel">            <a class="mi-article-widget__more-button" href="/news/SA/now/trending/">      <span>المزيد</span>      <i class="fa fa-chevron-left"></i>    </a>    </v-page><!-- end ngRepeat: page in popular.pages -->    </v-pages>  </div>    <div id="MPU">    </div>    </div>    <!-- Speakol Widget - Removal IB-51 -->    <!-- <div th:replace="components/ads/common/speakol-two"/> --><!--    <div th:unless="${device.isMobile()}">      <div th:replace="components/ads/insticator/insticator-widget"/>    </div>-->    <!-- -->    <!-- PS -->    <!--<div th:replace="components/ads/internal/may-like-articles" />-->    <!--<div th:replace="components/ads/internal/second-fold" />-->    <!--    <div th:if="${#locale.getLanguage() == \'ar\'}">          <span class="home__title">راديو مباشر</span>          <div class="internal-radio-carousel-container"></div>        </div>-->  </aside><!--  <div th:replace="components/ads/internal/mobile-fullpage"/>-->  <!--<div th:replace="components/ads/internal/mobile-interstitial"/>--><!--commented out as per Fayoumi\'s request-->  <!--<div th:replace="components/ads/internal/mobile-outstream"/>-->  <!--MFP-228 New Fixed-Replacement-ROS ads--><!--  <div th:replace="components/ads/home/mobile-fixed-replacement"/>  <div th:replace="components/ads/news/dfp/mobile/MPU3"/>--><!--Commented out as per Fayoumi\'s request-->  <!--<div th:replace="components/ads/internal/outstream"/>--><!--  <div th:if="${device.isMobile()}">    <div th:replace="components/ads/dfp/mobile-internal-pages"/>  </div>--><!--  <div th:if="${device.isMobile()}">    <div th:replace="components/ads/insticator/insticator-widget"/>  </div>--> <!-- <div th:replace="components/ads/internal/mobile-above-footer"/>--></div>    </div>    <footer>  <div class="mi-footer">    <div class="mi-show-for-large-up mi-footer__main-menu">      <ul>        <li class="mi-footer__menu-item mi-footer__menu__markets" id="markets">          <div class="mi-footer__menu-level1">الأسواق</div>          <ul>            <h3 class="mi-footer__menu-level2 invisible">الأسواق</h3>            <li>              <a class="mi-footer__menu-level3" href="/markets/TDWL">سوق الأسهم السعودي</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/EGX">البورصة المصرية</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/DFM">سوق دبي المالي</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/ADX">سوق أبوظبي</a>            </li>          </ul>          <ul>            <li>              <a class="mi-footer__menu-level3" href="/markets/BB">بورصة البحرين</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/QE">بورصة قطر</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/MSM">سوق مسقط</a>            </li>          </ul>          <ul>            <li>              <a class="mi-footer__menu-level3" href="/markets/KSE">سوق الكويت</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/ASE">بورصة عمان</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/CSE">سوق الدار البيضاء</a>            </li>          </ul>          <ul>            <li>              <a class="mi-footer__menu-level3" href="/markets/BDT">بورصة تونس</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/PEX">سوق فلسطين</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/ISX">سوق العراق</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/international-indices">مؤشرات الأسواق العالمية</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/commodities-prices">أسعار المعادن والطاقة</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/currencies">أسعار العملات</a>            </li>            <!--<li>              <a class="mi-footer__menu-level3"                 th:href="${@url.to(\'RMPC#regionalMap\')}"                 th:text="#{navigation.markets.regional-map}"/>            </li>-->          </ul>        </li>        <li class="mi-footer__menu-item mi-footer__menu__news" id="news">          <ul>            <div class="mi-footer__menu-level1">الأخبار</div>            <li class="mi-footer__menu__news__submenu">              <h3 class="mi-footer__menu-level2">أخبار الدول</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/eg/now/latest">مصر</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/latest">السعودية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/ae/now/latest">الإمارات</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/bh/now/latest">البحرين</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/qa/now/latest">قطر</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/om/now/latest">عمان</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/kw/now/latest">الكويت</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/jo/now/latest">الأردن</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/ma/now/latest">المغرب</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/tn/now/latest">تونس</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/ps/now/latest">فلسطين</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/iq/now/latest">العراق</a>                </li>              </ul>            </li>            <li class="mi-footer__menu__news__submenu">              <h3 class="mi-footer__menu-level2">أخبار إقليمية</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/regions/gulf">الخليج</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/regions/levant">الشام</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/regions/north-africa">شمال أفريقيا</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/regions/middle-east">الشرق الأوسط</a>                </li>              </ul>              <!-- happening now -->              <h3 class="mi-footer__menu-level2">يحدث الآن</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/top">أهم الأخبار</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/exclusive">حصرياً مباشر</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/latest">آخر الأخبار</a>                </li>                                  <li>                    <a class="mi-footer__menu-level3" href="/news/sa/now/announcements">إعلانات السوق</a>                  </li>                                                  <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/popular">منتشر الآن</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/trending/">الأكثر مشاركة</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/now/news-releases">بيانات صحفية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/misc">أخبار منوعة</a>                </li>              </ul>            </li>            <li class="mi-footer__menu__news__submenu">              <h3 class="mi-footer__menu-level2">نبض السوق</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/stocks">أخبار الأسهم</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/analysis">تحليلات إخبارية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/local">اقتصاد محلي</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/recommendations">توصيات</a>                </li>              </ul>              <h3 class="mi-footer__menu-level2">أخبار القطاعات</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/category/banking">بنوك</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/category/realEstate">عقارات</a>                </li>              </ul>              <h3 class="mi-footer__menu-level2">أخبار عالمية</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/global-economy">اقتصاد عالمى</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/goods-and-metals">أحداث عالمية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/global-indices">مؤشرات عالمية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/oil-and-energy">نفط ومعادن</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/currencies">عملات</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/global-reports">تقارير عالمية</a>                </li>              </ul>            </li>          </ul>        </li>        <li class="mi-footer__menu-item mi-footer__menu__companies" id="companies">          <div class="mi-footer__menu-level1">الشركات</div>          <ul>            <h3 class="mi-footer__menu-level2 invisible">الشركات</h3>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/companies">الشركات المدرجة</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/events">مفكرة الشركات</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/stock-prices">أسعار الأسهم</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/earnings">إعلانات الأرباح</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/fair-values">القيم العادلة</a>            </li>            <li>                          </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/major-shareholders">كبار الملاك</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/ipos">قائمة الإكتتابات</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/ipo/list">بحث فى الاكتتابات</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/ipos/news">أخبار الاكتتابات</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/ipo/calendar">مفكرة الاكتتابات</a>            </li>          </ul>        </li>        <li class="mi-footer__menu-item mi-footer__menu__analysis-tools" id="analysis-tools">          <div class="mi-footer__menu-level1">أدوات التحليل</div>          <!-- If current country has one market only -->                      <ul>              <h3 class="mi-footer__menu-level2 invisible">أدوات التحليل</h3>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/performance-comparison">مقارنة الأداء</a>              </li>            </ul>                    <!-- If current country has more than one markets i.e UAE -->                  </li>      </ul>    </div>    <div class="mi-footer__second-fold">      <div class="mi-footer__column1">        <div class="mi-footer__copyright">          <div class="mi-footer__logo" onclick="window.location.href=\'/countries/sa\'">              <svg viewBox="0 0 494.387 190.555">    <use xlink:href="#logo-white"></use>  </svg>            </div>          <span>جميع الحقوق تعود لشركة مباشر العالمية © 2005 - 2020</span>        </div>        <ul class="mi-footer__links">          <li>            <a href="/s/Terms">اتفاقية الاستخدام</a>          </li>          <li>            <a href="/s/disclaimer">إخلاء المسؤولية</a>          </li>          <li>            <a href="/s/aboutus">من نحن</a>          </li>          <li>            <a href="/contact">اتصل بنا</a>          </li>          <li>            <a href="/advertise">أعلن معنا</a>          </li>          <li>            <a href="http://www.decypha.com/" target="_blank">موقع ديسيفا</a>          </li>          <li>            <a href="/ir-services" target="_blank">خدمات المواقع</a>          </li>          <li>            <a href="/s/Jobs">وظائف</a>          </li>          <li>              <a target="_blank" href="/decypha-packages">ديسيفا</a>          </li>          <li>            <a href="/s/privacy-policy" target="_blank">سياسة الخصوصية</a>          </li>          <!--<li th:if="${#locale.getLanguage() == \'en\'}">            <a href="/s/decypha-financial-intelligence" th:text="#{components.footer.decypha-financial-intelligence}">Decypha Financial Intelligence</a>          </li>-->        </ul>        <div>جميع البيانات متأخرة 15 دقيقة أثناء الجلسة</div>        <div>هذا الموقع مرخص من وزراة الثقافة والإعلام السعودية</div>        <div>رقم التسجيل :ت 1 125 1435</div>      </div>      <div class="mi-footer__column2">        <ul class="mi-footer__social-icons">          <li>            <a target="_blank" href="https://twitter.com/mubasher"><i class="fa fa-twitter fa-2x"></i></a>          </li>          <li>            <a href="https://www.facebook.com/Mubasher.Info"><i class="fa fa-facebook fa-2x"></i></a>          </li>          <li>            <a href="https://www.youtube.com/channel/UC7hnxb7gD4nKZdZk3ZlZCYg"><i class="fa fa-youtube fa-2x"></i></a>          </li>          <li>            <a href="https://www.linkedin.com/company/1477149"><i class="fa fa-linkedin fa-2x"></i></a>          </li>          <li>            <a href="/news/rss"><i class="fa fa-rss fa-2x"></i></a>          </li>          <li>            <a href="https://play.google.com/store/apps/details?id=net.mis.mubasherinfo">              <i class="fa fa-android fa-2x"></i></a>          </li>          <li>            <a href="https://itunes.apple.com/app/imubasher/id494539772?mt=8"><i class="fa fa-apple fa-2x"></i></a>          </li>          </ul></div></div></div></footer>          </div>  <script src="//code.jquery.com/jquery-2.1.4.min.js"></script>  <script src="//ajax.googleapis.com/ajax/libs/angularjs/1.3.15/angular.min.js"></script>  <script src="/assets/ui/lib.min.js"></script>  <script src="/assets/ui/main.min.js"></script>  <div id="mi-js-scripts"></div>  <script>    <!-- Fix menu trigger on android browser4 -->    $(".dl-menu__menu-item").click(function () {      $(this).addClass(".dl-menu-item__hoverd");    });    $(document).ready(function () {      $(\'.tooltip\').tooltipster();      setTimeout(function(){ dataLayer.push({event: "triggerAds"});      console.log("triggerAds");      }, 1000);    });  </script>    <div pg-ng-tooltip=""></div></div>  <!-- Twitter universal website tag code -->  <script>    !function(e,t,n,s,u,a){e.twq||(s=e.twq=function(){s.exe?s.exe.apply(s,arguments):s.queue.push(arguments);    },s.version=\'1.1\',s.queue=[],u=t.createElement(n),u.async=!0,u.src=\'//static.ads-twitter.com/uwt.js\',      a=t.getElementsByTagName(n)[0],a.parentNode.insertBefore(u,a))}(window,document,\'script\');    // Insert Twitter Pixel ID and Standard Event data below    twq(\'init\',\'nyana\');    twq(\'track\',\'PageView\');  </script>  <!-- End Twitter universal website tag code --><div id="mm-blocker" class="mm-slideout"></div></body>' + '<body id="mi" ng-app="app" ng-controller="MainController" class="ar ng-scope" data-gr-c-s-loaded="true"><nav class="header__countries-menu mm-menu mm-offcanvas mm-top mm-front" id="countries-menu"><div class="mm-panel mm-opened mm-current" id="mm-8"><ul class="mm-listview mm-first mm-last">        <li class="header__country-selector__country">          <a href="/change-country?to=ae&amp;url=/countries/sa/companies">الإمارات</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=bh&amp;url=/countries/sa/companies">البحرين</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=om&amp;url=/countries/sa/companies">عُمان</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=qa&amp;url=/countries/sa/companies">قطر</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=kw&amp;url=/countries/sa/companies">الكويت</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=eg&amp;url=/countries/sa/companies">مصر</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=jo&amp;url=/countries/sa/companies">الأردن</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=tn&amp;url=/countries/sa/companies">تونس</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=ma&amp;url=/countries/sa/companies">المغرب</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=ps&amp;url=/countries/sa/companies">فلسطين</a>        </li>        <li class="header__country-selector__country">          <a href="/change-country?to=iq&amp;url=/countries/sa/companies">العراق</a>        </li>      </ul></div></nav><nav class="header__main-menu mm-menu mm-border-full mm-effect-slide-menu mm-effect-zoom-panels mm-pageshadow mm-offcanvas mm-right mm-hasnavbar-top mm-hasnavbar" id="main-menu"><div class="mm-navbar mm-navbar-top mm-hasbtns"><a class="mm-prev mm-btn mm-hidden"></a><a class="mm-title"> </a><a class="mm-close mm-btn" href="#wrapper"></a></div><div class="mm-panel mm-opened mm-current" id="mm-0"><ul class="mm-listview mm-first mm-last">        <li id="markets">          <a class="mm-next mm-fullsubopen" href="#mm-1" data-target="#mm-1"></a><span href="javascript:;">الأسواق</span>                  </li>        <li id="news">          <a class="mm-next mm-fullsubopen" href="#mm-2" data-target="#mm-2"></a><span href="javascript:;">الأخبار</span>                  </li>        <li id="companies">          <a class="mm-next mm-fullsubopen" href="#mm-3" data-target="#mm-3"></a><span href="javascript:;">الشركات</span>                  </li>        <li id="funds">          <a class="mm-next mm-fullsubopen" href="#mm-4" data-target="#mm-4"></a><span href="javascript:;">صناديق الاستثمار</span>                  </li>        <li id="analysis-tool">          <a class="mm-next mm-fullsubopen" href="#mm-5" data-target="#mm-5"></a><span href="javascript:;">أدوات التحليل</span>                  </li>        <li id="islamic-economy">          <a href="/news/islamic-finance">الاقتصاد الإسلامي</a>        </li>        <!--<li class="global__hide-for-ltr" id="radio" th:if="${#locale.getLanguage() == \'ar\'}">          <span th:text="#{navigation.radio}">راديو مباشر</span>          <ul>            <li>              <a th:href="${@url.to(\'RPC#live\')}" th:text="#{navigation.radio.live}"/>            </li>            <li>              <a th:href="${@url.to(\'RPC#latestEpisodesPage\', countryCode)}">آخر الحلقات</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تقارير-اقتصادية\'}">تقارير اقتصادية</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تغطية-خاصة\'}">تغطية خاصة</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'مقالات\'}">مقالات</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#programs\')}" th:text="#{navigation.radio.programs}"/>            </li>            <li>              <a th:href="${@url.to(\'RPC#videoPrograms\')}" th:text="#{navigation.radio.videoPrograms}"/>            </li>            <li>              <a th:href="${@url.to(\'RPC#getExperts\')}">ضيوفنا</a>            </li>            <li>              <a th:href="${@url.to(\'RPC#getPresenters\')}">المذيعون</a>            </li>          </ul>        </li>-->        <li class="global__hide-for-ltr" id="video">          <a href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">مباشر TV</a>        </li>                <li id="fixedincome">          <a class="mm-next mm-fullsubopen" href="#mm-6" data-target="#mm-6"></a><span>السندات</span>                  </li>        <li>          <a class="mm-next mm-fullsubopen" href="#mm-7" data-target="#mm-7"></a><span>شخصي</span>                  </li>        <li>          <a href="http://tawasul.mubasher.info/" target="_blank">تواصل</a>        </li>        <!-- <li>          <a th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank" th:text="#{components.header.decypha}" target="_blank">          </a>        </li> -->        <li>          <a ng-click="decypha(\'decypha\')">ديسيفا</a>        </li>        <!--Add according to MFP-187-->        <li>          <a href="https://contest.mubasher.info/#/home" target="_blank">المستثمر اﻷول</a>        </li>        <li>          <!--Integrating Mubasher Pulse-->        </li><li>        <style>          .pulse-logo2{            padding: 5px 5px 4px;            min-width: 82px;            min-height: 21px;            max-width: 27%;          }        </style>        <a target="_blank" href="https://pulse.mubasher.info">          <img class="pulse-logo2" src="../../../images/pulse-logo.png">        </a>        </li>        <li>        </li><li>          <a href="http://magazine.mubasher.info/" target="_blank">            مجلة مباشر          </a>        </li>        <li class="mm-divider"></li>        <li>          <a href="https://english.mubasher.info">ENGLISH</a>        </li>        <li>                  </li>        <li>          <a class="header__login__text" href="/account/login">دخول</a>                  </li>      </ul></div><div class="mm-panel mm-hidden" id="mm-1"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الأسواق</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/markets/TDWL">سوق الأسهم السعودي</a>            </li>            <li>              <a href="/markets/EGX">البورصة المصرية</a>            </li>            <li>              <a href="/markets/DFM">سوق دبي المالي</a>            </li>            <li>              <a href="/markets/ADX">سوق أبوظبي</a>            </li>            <li>              <a href="/markets/BB">بورصة البحرين</a>            </li>            <li>              <a href="/markets/QE">بورصة قطر</a>            </li>            <li>              <a href="/markets/MSM">سوق مسقط</a>            </li>            <li>              <a href="/markets/BK">سوق الكويت</a>            </li>            <li>              <a href="/markets/ASE">بورصة عمان</a>            </li>            <li>              <a href="/markets/CSE">سوق الدار البيضاء</a>            </li>            <li>              <a href="/markets/BDT">بورصة تونس</a>            </li>            <li>              <a href="/markets/PEX">سوق فلسطين</a>            </li>            <li>              <a href="/markets/ISX">سوق العراق</a>            </li>            <li>              <a href="/international-indices">مؤشرات الأسواق العالمية</a>            </li>            <li>              <a href="/markets/commodities-prices">أسعار المعادن والطاقة</a>            </li>            <li>              <a href="/countries/sa/currencies">أسعار العملات</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-2"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الأخبار</a></div><ul class="mm-listview mm-first mm-last">            <!-- now -->            <li class="mm-divider">يحدث الآن</li>            <li>              <a href="/news/sa/now/top">أهم الأخبار</a>            </li>            <li>              <a href="/news/sa/now/exclusive">حصرياً مباشر</a>            </li>            <li>              <a href="/news/sa/now/latest">آخر الأخبار</a>            </li>                          <li>                <a href="/news/sa/now/announcements">إعلانات السوق</a>              </li>                                      <li class="global__hide-for-ltr">              <a href="/news/sa/now/popular">منتشر الآن</a>            </li>            <li>              <a href="/news/sa/now/trending/">الأكثر مشاركة</a>            </li>            <li>              <a href="/news/now/news-releases">بيانات صحفية</a>            </li><!--            <li>              <a th:href="${@url.to(\'NPC#miscellaneousNews\', countryCode)}"                 th:text="#{navigation.news.now.misc}"/>            </li>-->            <!-- recommendations-->            <li class="mm-divider">نبض السوق</li>            <li>              <a href="/news/sa/pulse/stocks">أخبار الأسهم</a>            </li>            <li>              <a href="/news/sa/pulse/analysis">تحليلات إخبارية</a>            </li>            <li>              <a href="/news/sa/pulse/local">اقتصاد محلي</a>            </li>            <li>              <a href="/news/sa/pulse/recommendations">توصيات</a>            </li>            <li class="mm-divider">أخبار القطاعات</li>            <li>              <a href="/news/sa/category/banking">بنوك</a>            </li>            <li>              <a href="/news/sa/category/realEstate">عقارات</a>            </li>            <li class="mm-divider">أخبار الدول</li>            <li>              <a href="/news/eg/now/latest">مصر</a>            </li>            <li>              <a href="/news/sa/now/latest">السعودية</a>            </li>            <li>              <a href="/news/ae/now/latest">الإمارات</a>            </li>            <li>              <a href="/news/bh/now/latest">البحرين</a>            </li>            <li>              <a href="/news/qa/now/latest">قطر</a>            </li>            <li>              <a href="/news/om/now/latest">عمان</a>            </li>            <li>              <a href="/news/kw/now/latest">الكويت</a>            </li>            <li>              <a href="/news/jo/now/latest">الأردن</a>            </li>            <li>              <a href="/news/ma/now/latest">المغرب</a>            </li>            <li>              <a href="/news/tn/now/latest">تونس</a>            </li>            <li>              <a href="/news/ps/now/latest">فلسطين</a>            </li>            <li>              <a href="/news/iq/now/latest">العراق</a>            </li>            <!-- regions-->            <li class="mm-divider">أخبار إقليمية</li>            <li>              <a href="/news/regions/gulf">الخليج</a>            </li>            <li>              <a href="/news/regions/levant">الشام</a>            </li>            <li>              <a href="/news/regions/north-africa">شمال أفريقيا</a>            </li>            <li>              <a href="/news/regions/middle-east">الشرق الأوسط</a>            </li>            <!-- international -->            <li class="mm-divider">أخبار عالمية</li>            <li>              <a href="/news/international/global-economy">اقتصاد عالمى</a>            </li>            <li>              <a href="/news/international/goods-and-metals">أحداث عالمية</a>            </li>              <li>                <a href="/news/international/global-indices">مؤشرات عالمية</a>              </li>              <li>                <a href="/news/international/oil-and-energy">نفط ومعادن</a>              </li>              <li>                <a href="/news/international/currencies">عملات</a>              </li>              <li>                <a href="/news/international/global-reports">تقارير عالمية</a>              </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-3"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">الشركات</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/countries/sa/companies">الشركات المدرجة</a>            </li>            <li>              <a href="/countries/sa/events">مفكرة الشركات</a>            </li>            <li>              <a href="/countries/sa/stock-prices">أسعار الأسهم</a>            </li>            <li>              <a href="/countries/sa/earnings">إعلانات الأرباح</a>            </li>            <li>              <a href="/countries/sa/fair-values">القيم العادلة</a>            </li>            <li>              <a href="/countries/sa/corporate-action">الإجراءات</a>            </li>                        <li>              <a href="/countries/sa/major-shareholders">كبار الملاك</a>            </li>            <li>              <a href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>            </li>            <li class="mm-divider">الاكتتابات</li>            <li>              <a href="/countries/sa/ipos">قائمة الإكتتابات</a>            </li>            <li>              <a href="/ipo/list">بحث فى الاكتتابات</a>            </li>            <li>              <a href="/ipos/news">أخبار الاكتتابات</a>            </li>            <li>              <a href="/ipo/calendar">مفكرة الاكتتابات</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-4"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">صناديق الاستثمار</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/countries/sa/funds">صناديق الاستثمار</a>            </li>            <li>              <a href="/countries/sa/funds-statistics">إحصائيات الصناديق</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-5"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">أدوات التحليل</a></div><ul class="mm-listview mm-first mm-last">                                        <li>                <a href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>              </li>              <li>                <a href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>              </li>              <li>                <a href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>              </li>              <li>                <a href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>              </li>              <li>                <a href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>              </li>                        <li class="mm-divider">            </li>            <li>              <a href="/analysis-tools/performance-comparison">مقارنة الأداء</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-6"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">السندات</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/fixedincome/bond/search" id="fixedIncomeBondScreener">بحث عن سندات</a>            </li>            <li>              <a href="/fixed-income/news" id="fixedIncomeNews">أخبار السندات وأذون الخزانة</a>            </li>            <li>              <a href="/fixedincome/calendar/searchForEvent" id="fixedIncomeCalendar">قائمة الأحداث</a>            </li>            <li>              <a href="/fixedincome/analytics/drawCurve" id="fixedIncomeAnalytics">تحليلات فنية</a>            </li>            <li>              <a href="/fixedincome/leagueTables/view" id="fixedIncomeLeagueTables">جداول الديون</a>            </li>            <li>              <a href="/fixedincome/research/search" id="fixedIncomeProspectus">تقارير</a>            </li>          </ul></div><div class="mm-panel mm-hidden" id="mm-7"><div class="mm-navbar"><a class="mm-btn mm-prev" href="#mm-0" data-target="#mm-0"></a><a class="mm-title">شخصي</a></div><ul class="mm-listview mm-first mm-last">            <li>              <a href="/my/alerts">التنبيهات</a>            </li>            <li>              <a href="/my/watch-list">أسهمي</a>            </li>            <li>              <a href="/my/newsletters">النشرة البريدية</a>            </li>          </ul></div></nav><div class="js-wrapper mm-page mm-slideout" id="wrapper">  <svg class="hidden" version="1.1" viewBox="0 0 0 0" xmlns="http://www.w3.org/2000/svg">  <defs>    <style>      .logo-white-path {        clip-rule: evenodd;        fill-rule: evenodd;        fill: white;        font-size: 46.6299px;        font-family: \'HelveticaNeue\';      }      .logo-path {        clip-rule: evenodd;        fill-rule: evenodd;        fill: #324651;        text-align: center;        font-size: 46.6299px;        font-family: \'HelveticaNeue\';      }    </style>    <g id="logo-white">      <path class="logo-white-path" d="M209.596 29.677c-6.25 0.016-11.243-4.937-11.261-11.188 c-0.018-6.191 5.027-11.29 11.194-11.29c6.182-0.004 11.3 5.1 11.3 11.226C220.852 24.6 215.8 29.7 209.6 29.7"></path>      <path class="logo-white-path" d="M228.308 37.976c6.231-0.01 11.3 5 11.3 11.2 c0.015 6.189-5.011 11.227-11.233 11.252c-6.213 0.025-11.246-4.99-11.271-11.209C217.063 43 222.1 38 228.3 38"></path>      <path class="logo-white-path" d="M350.278 190.471c-6.27-0.009-11.204-4.942-11.197-11.212 c0.013-6.26 4.968-11.18 11.248-11.176c6.242 0 11.3 5 11.2 11.224C361.555 185.5 356.5 190.5 350.3 190.5"></path>      <path class="logo-white-path" d="M186.161 37.976c6.26 0 11.2 5 11.2 11.2 c-0.01 6.241-4.993 11.239-11.209 11.226c-6.257-0.017-11.212-4.99-11.212-11.228C174.949 42.9 179.9 38 186.2 38"></path>      <path class="logo-white-path" d="M455.92 80.125c-21.212 0-38.405 17.191-38.405 38.4 c0 4.3 0.7 8.4 2 12.316l-48.126 0.003l13.9-27.74h-3.242c0 0-2.13 0.019-2.822 0.1 c-2.13 0.126-3.67 0.098-7.926 1.351c-3.949 1.159-7.026 2.719-9.881 4.503c-2.381 1.493-5.863 4.278-8.803 7.7 c-2.912 3.325-5.713 7.695-5.713 7.695l-3.294 6.464l-41.201 0.003L364.7 0l-76.514 49.172l25.429-0.036L260.64 156.919h193.847 c0 0 0.9 0 1.4 0.01c21.212 0 38.4-17.183 38.4-38.403C494.32 97.3 477.1 80.1 455.9 80.125z M455.92 133.3 c-7.998 0-14.48-6.479-14.48-14.47c0-7.998 6.482-14.476 14.48-14.476c7.996 0 14.5 6.5 14.5 14.5 C470.393 126.8 463.9 133.3 455.9 133.327z"></path>      <path class="logo-white-path" d="M269.61 81.427c0 0-1.617 0.013-2.842 0.09c-2.001 0.132-3.655 0.07-7.903 1.3 c-3.946 1.162-7.021 2.722-9.876 4.507c-2.378 1.488-5.868 4.279-8.813 7.662c-2.904 3.327-5.282 8.108-5.282 8.108l-14.116 27.7 h-16.391l19.092-39.485h-3.237c0 0-1.617 0.015-2.835 0.095c-2.012 0.13-3.665 0.068-7.905 1.3 c-3.957 1.161-7.034 2.717-9.892 4.502c-2.373 1.493-5.857 4.28-8.808 7.668c-2.899 3.321-5.282 8.104-5.282 8.104l-8.901 17.8 h-16.959l13.92-27.753h-3.245c0 0-2.141 0.019-2.822 0.057c-2.133 0.126-3.663 0.098-7.926 1.4 c-3.944 1.159-7.026 2.719-9.884 4.503c-2.378 1.493-5.857 4.28-8.808 7.669c-2.904 3.329-5.708 7.695-5.708 7.695l-3.291 6.5 l-52.558-0.005l14.007-27.748h-3.242c0 0-2.131 0.019-2.815 0.057c-2.136 0.126-3.678 0.098-7.934 1.4 c-3.944 1.159-7.021 2.719-9.877 4.503c-2.383 1.493-5.858 4.28-8.813 7.669c-2.906 3.329-5.114 7.843-5.114 7.843l-16.204 31.1 l0 0c0 0-3.136 6.731-7.038 11.469c-3.094 3.766-7.43 6.804-9.757 8.194c-2.313 1.384-7.141 3.645-11.872 4.5 C5.251 180.9 0 180.5 0 180.502s2.33 2.1 5 3.806c2.034 1.4 4.3 2.4 5.5 3 c2.481 1.1 4.3 1.7 6.9 2.253c2.531 0.6 4.8 0.8 4.8 0.763s1.621 0.2 3.2 0.169c0.707 0 1.62-0.024 2.848-0.09 c2.001-0.134 3.5 0 7.904-1.323c4.033-1.188 7.072-2.582 9.92-4.368c2.383-1.478 5.952-4.249 8.904-7.627 c2.907-3.337 5.296-8.019 5.296-8.019l6.043-12.125l169.4 0.009l12.816-26.07l24.302-49.431H269.61z"></path>      <path class="logo-white-path" d="M30.239 76.472V55.626H22.45v-2.789h18.735v2.789h-7.819v20.846H30.239z"></path>      <path class="logo-white-path" d="M44.296 76.472V52.836h4.71l5.592 16.735c0.518 1.6 0.9 2.7 1.1 3.499c0.269-0.861 0.687-2.123 1.258-3.789 l5.658-16.446h4.209v23.636h-3.015V56.689l-6.869 19.783h-2.822l-6.835-20.121v20.121H44.296z"></path>    </g>    <g id="logo">      <path class="logo-path" d="M209.596 29.677c-6.25 0.016-11.243-4.937-11.261-11.188 c-0.018-6.191 5.027-11.29 11.194-11.29c6.182-0.004 11.3 5.1 11.3 11.226C220.852 24.6 215.8 29.7 209.6 29.7"></path>      <path class="logo-path" d="M228.308 37.976c6.231-0.01 11.3 5 11.3 11.2 c0.015 6.189-5.011 11.227-11.233 11.252c-6.213 0.025-11.246-4.99-11.271-11.209C217.063 43 222.1 38 228.3 38"></path>      <path class="logo-path" d="M350.278 190.471c-6.27-0.009-11.204-4.942-11.197-11.212 c0.013-6.26 4.968-11.18 11.248-11.176c6.242 0 11.3 5 11.2 11.224C361.555 185.5 356.5 190.5 350.3 190.5"></path>      <path class="logo-path" d="M186.161 37.976c6.26 0 11.2 5 11.2 11.2 c-0.01 6.241-4.993 11.239-11.209 11.226c-6.257-0.017-11.212-4.99-11.212-11.228C174.949 42.9 179.9 38 186.2 38"></path>      <path class="logo-path" d="M455.92 80.125c-21.212 0-38.405 17.191-38.405 38.4 c0 4.3 0.7 8.4 2 12.316l-48.126 0.003l13.9-27.74h-3.242c0 0-2.13 0.019-2.822 0.1 c-2.13 0.126-3.67 0.098-7.926 1.351c-3.949 1.159-7.026 2.719-9.881 4.503c-2.381 1.493-5.863 4.278-8.803 7.7 c-2.912 3.325-5.713 7.695-5.713 7.695l-3.294 6.464l-41.201 0.003L364.7 0l-76.514 49.172l25.429-0.036L260.64 156.919h193.847 c0 0 0.9 0 1.4 0.01c21.212 0 38.4-17.183 38.4-38.403C494.32 97.3 477.1 80.1 455.9 80.125z M455.92 133.3 c-7.998 0-14.48-6.479-14.48-14.47c0-7.998 6.482-14.476 14.48-14.476c7.996 0 14.5 6.5 14.5 14.5 C470.393 126.8 463.9 133.3 455.9 133.327z"></path>      <path class="logo-path" d="M269.61 81.427c0 0-1.617 0.013-2.842 0.09c-2.001 0.132-3.655 0.07-7.903 1.3 c-3.946 1.162-7.021 2.722-9.876 4.507c-2.378 1.488-5.868 4.279-8.813 7.662c-2.904 3.327-5.282 8.108-5.282 8.108l-14.116 27.7 h-16.391l19.092-39.485h-3.237c0 0-1.617 0.015-2.835 0.095c-2.012 0.13-3.665 0.068-7.905 1.3 c-3.957 1.161-7.034 2.717-9.892 4.502c-2.373 1.493-5.857 4.28-8.808 7.668c-2.899 3.321-5.282 8.104-5.282 8.104l-8.901 17.8 h-16.959l13.92-27.753h-3.245c0 0-2.141 0.019-2.822 0.057c-2.133 0.126-3.663 0.098-7.926 1.4 c-3.944 1.159-7.026 2.719-9.884 4.503c-2.378 1.493-5.857 4.28-8.808 7.669c-2.904 3.329-5.708 7.695-5.708 7.695l-3.291 6.5 l-52.558-0.005l14.007-27.748h-3.242c0 0-2.131 0.019-2.815 0.057c-2.136 0.126-3.678 0.098-7.934 1.4 c-3.944 1.159-7.021 2.719-9.877 4.503c-2.383 1.493-5.858 4.28-8.813 7.669c-2.906 3.329-5.114 7.843-5.114 7.843l-16.204 31.1 l0 0c0 0-3.136 6.731-7.038 11.469c-3.094 3.766-7.43 6.804-9.757 8.194c-2.313 1.384-7.141 3.645-11.872 4.5 C5.251 180.9 0 180.5 0 180.502s2.33 2.1 5 3.806c2.034 1.4 4.3 2.4 5.5 3 c2.481 1.1 4.3 1.7 6.9 2.253c2.531 0.6 4.8 0.8 4.8 0.763s1.621 0.2 3.2 0.169c0.707 0 1.62-0.024 2.848-0.09 c2.001-0.134 3.5 0 7.904-1.323c4.033-1.188 7.072-2.582 9.92-4.368c2.383-1.478 5.952-4.249 8.904-7.627 c2.907-3.337 5.296-8.019 5.296-8.019l6.043-12.125l169.4 0.009l12.816-26.07l24.302-49.431H269.61z"></path>      <path class="logo-path" d="M30.239 76.472V55.626H22.45v-2.789h18.735v2.789h-7.819v20.846H30.239z"></path>      <path class="logo-path" d="M44.296 76.472V52.836h4.71l5.592 16.735c0.518 1.6 0.9 2.7 1.1 3.499c0.269-0.861 0.687-2.123 1.258-3.789 l5.658-16.446h4.209v23.636h-3.015V56.689l-6.869 19.783h-2.822l-6.835-20.121v20.121H44.296z"></path>    </g>    <g id="logo-white-en">      <defs>        <rect height="65.7" width="326.9" x="-55"></rect>      </defs>      <clipPath>        <use overflow="visible" xlink:href="#SVGID_1_"></use>      </clipPath>      <path class="logo-white-path" d="M41.694 20.162c-1.315 0-1.315 0.987-1.315 0.987l0.094 13.8 c0 0 0.6 8.648-8.178 8.648c0 0-8.364 0.093-8.364-8.082V21.29c0 0 0.234-1.174-1.27-1.174c-1.362 0-1.221 1.174-1.221 1.174V36 c0 0 0.2 10.1 10.9 10.104c10.386 0 10.669-9.675 10.669-10.433V21.243C42.964 21.2 43 20.2 41.7 20.2"></path>      <path class="logo-white-path" d="M20.915 21.431c0 0 0-0.799-0.799-1.127c-0.777-0.321-1.27 0.422-1.457 0.6 l-7.425 10.293c0 0-0.469 0.61-1.034-0.282l-8.13-10.292c0 0-0.517-0.611-1.128-0.423c-0.611 0.189-0.894 0.704-0.846 1.6 L0 44.74c0 0-0.046 1.4 1.3 1.363s1.316-1.222 1.316-1.222V25.144l7.002 9.023c0 0 1.1 1.5 2.209-0.188 c1.081-1.646 6.626-8.882 6.626-8.882v19.736c0 0-0.088 1.3 1.5 1.175c1.175-0.094 0.988-1.22 0.988-1.22V21.431z"></path>      <path class="logo-white-path" d="M168.546 43.734l-10.309-6.813c0 0 8.648-0.179 8.648-8.471 c0-8.294-8.531-8.118-8.531-8.118h-8.412c-2.107 0-1.953 1.6-1.953 1.6v22.69c0 0-0.038 1.5 1.1 1.5 c1.265 0 1.222-1.436 1.222-1.436V22.702h6.516c0.474 0 3.1 0 5.3 1.304c2.192 1.3 3.7 7.198-0.177 9.6 c-2.785 1.717-6.459 1.008-7.642 0.889c-1.185-0.12-1.306 0.414-1.483 1.186c-0.177 0.8 0.9 1.4 0.9 1.362l13.21 8.5 c0 0 1.4 1.2 2.1 0.18C169.967 44.4 168.5 43.7 168.5 43.7"></path>      <path class="logo-white-path" d="M95.522 19.596c-6.516-0.711-11.492 3.376-11.373 7.8 c0.117 4.4 3 5.7 8.1 6.634c5.096 0.9 7 1.7 7 1.658c2.665 1 2.5 4.3 1 5.9 c-1.423 1.601-4.148 2.558-5.766 2.616c-3.879 0.146-6.052-2.374-6.052-2.374c-0.492-0.407-0.683-1.486-1.69-1.25 c-1.347 0.316-0.296 1.836-0.296 1.836c2.311 3.2 7.2 3.6 7.2 3.554c5.45 0.7 8.648-3.139 8.648-3.139 c2.963-3.852 0.987-8.363-1.976-9.429c-3.17-1.142-6.139-1.234-10.05-2.065c-3.909-0.828-3.495-4.087-3.495-4.087 c0.059-2.37 2.252-5.271 7.643-5.332c5.392-0.059 8.5 3.4 8.5 3.436c1.304 1.4 2.1 0.5 2.133-0.12 c0.06-0.591-0.058-1.183-0.531-1.776C104.121 23.1 102 20.3 95.5 19.6"></path>      <path class="logo-white-path" d="M124.084 20.618c-1.126 0-1.185 1.067-1.185 1.067v15.166h-14.336V21.862 c0 0 0.296-1.42-1.305-1.362c-1.304 0.047-1.067 1.42-1.067 1.42v14.575h-0.889c0 0-1.303-0.06-1.303 1.2 c0 1.3 1.2 1.3 1.2 1.305h1.007v5.746c0 0 0 1.2 1.2 1.243c1.246 0 1.187-1.184 1.187-1.184v-5.984h14.1v6.103 c0 0-0.008 1.1 1.2 1.137c1.226 0 1.269-1.195 1.269-1.195V21.743C125.209 21.7 125.2 20.6 124.1 20.6"></path>      <path class="logo-white-path" d="M86.101 44.016c0 0-10.841-21.504-11.849-23.163c-1.007-1.66-2.072 0-2.072 0 l-8.047 15.604l-2.395 0.015c-0.888 0-0.982 0.633-0.982 1.284c0 1.1 1.1 0.9 1.1 0.929h1.067c0 0-2.447 4.637-2.726 5.3 c-0.355 0.889-0.416 1.5 0.5 1.955c1.008 0.5 1.659-0.77 1.659-0.77l3.436-6.399H80.71l2.903 5.9 c0 0 1 2 2.1 1.305C86.87 45.3 86.1 44 86.1 44 M66.965 36.374l5.984-12.026c0 0 0.296-0.475 0.6 0.1 c0.296 0.5 6 12 6 11.967H66.965z"></path>      <path class="logo-white-path" d="M58.314 34.283c0 0 3.87-1.954 3.87-6.575c0-4.622-4.563-7.199-8.294-7.199 h-6.517c0 0-1.512 0.2-1.512 1.744v10.479h-1.833c0 0-0.799-0.094-0.799 1.271c0 1.1 0.6 1.2 0.6 1.173h2.066v9.447 c0 0-0.046 1.5 1.5 1.48h7.213c0 0 6.016-0.165 6.016-6.837C60.57 35.9 58.3 34.3 58.3 34.3 M48.203 22.7 l6.338-0.005c1.718 0 5.1 1.7 5.1 5.451c0 4.443-5.095 4.501-5.095 4.501h-6.338V22.736z M53.557 43.831h-5.351v-8.748 l6.435-0.008c0.858 0 3.5 0.9 3.5 4.031C58.143 43.7 53.6 43.8 53.6 43.8"></path>      <path class="logo-white-path" d="M146.17 23.033c0 0 1.3 0.1 1.305-1.304c0-1.244-1.305-1.125-1.305-1.125 h-15.818c-2.251 0-2.012 1.717-2.012 1.717V36.54l-1.653 0.009c0 0-1.132 0.229-1.132 1.177c0 1.2 1.1 1.4 1.1 1.361h1.669 v4.917c0 2.5 1.7 2.1 1.7 2.073h15.818c0 0 0.9 0 0.889-1.185s-0.95-1.007-0.95-1.007h-14.798v-4.799h15.284 c0 0 0.937-0.177 0.937-1.361c0-1.186-1.125-1.246-1.125-1.246h-15.228V23.033H146.17z"></path>    </g>    <g id="logo-en">      <defs>        <rect height="65.7" width="326.9" x="-55"></rect>      </defs>      <clipPath>        <use overflow="visible" xlink:href="#SVGID_1_"></use>      </clipPath>      <path class="logo-path" d="M41.694 20.162c-1.315 0-1.315 0.987-1.315 0.987l0.094 13.8 c0 0 0.6 8.648-8.178 8.648c0 0-8.364 0.093-8.364-8.082V21.29c0 0 0.234-1.174-1.27-1.174c-1.362 0-1.221 1.174-1.221 1.174V36 c0 0 0.2 10.1 10.9 10.104c10.386 0 10.669-9.675 10.669-10.433V21.243C42.964 21.2 43 20.2 41.7 20.2"></path>      <path class="logo-path" d="M20.915 21.431c0 0 0-0.799-0.799-1.127c-0.777-0.321-1.27 0.422-1.457 0.6 l-7.425 10.293c0 0-0.469 0.61-1.034-0.282l-8.13-10.292c0 0-0.517-0.611-1.128-0.423c-0.611 0.189-0.894 0.704-0.846 1.6 L0 44.74c0 0-0.046 1.4 1.3 1.363s1.316-1.222 1.316-1.222V25.144l7.002 9.023c0 0 1.1 1.5 2.209-0.188 c1.081-1.646 6.626-8.882 6.626-8.882v19.736c0 0-0.088 1.3 1.5 1.175c1.175-0.094 0.988-1.22 0.988-1.22V21.431z"></path>      <path class="logo-path" d="M168.546 43.734l-10.309-6.813c0 0 8.648-0.179 8.648-8.471 c0-8.294-8.531-8.118-8.531-8.118h-8.412c-2.107 0-1.953 1.6-1.953 1.6v22.69c0 0-0.038 1.5 1.1 1.5 c1.265 0 1.222-1.436 1.222-1.436V22.702h6.516c0.474 0 3.1 0 5.3 1.304c2.192 1.3 3.7 7.198-0.177 9.6 c-2.785 1.717-6.459 1.008-7.642 0.889c-1.185-0.12-1.306 0.414-1.483 1.186c-0.177 0.8 0.9 1.4 0.9 1.362l13.21 8.5 c0 0 1.4 1.2 2.1 0.18C169.967 44.4 168.5 43.7 168.5 43.7"></path>      <path class="logo-path" d="M95.522 19.596c-6.516-0.711-11.492 3.376-11.373 7.8 c0.117 4.4 3 5.7 8.1 6.634c5.096 0.9 7 1.7 7 1.658c2.665 1 2.5 4.3 1 5.9 c-1.423 1.601-4.148 2.558-5.766 2.616c-3.879 0.146-6.052-2.374-6.052-2.374c-0.492-0.407-0.683-1.486-1.69-1.25 c-1.347 0.316-0.296 1.836-0.296 1.836c2.311 3.2 7.2 3.6 7.2 3.554c5.45 0.7 8.648-3.139 8.648-3.139 c2.963-3.852 0.987-8.363-1.976-9.429c-3.17-1.142-6.139-1.234-10.05-2.065c-3.909-0.828-3.495-4.087-3.495-4.087 c0.059-2.37 2.252-5.271 7.643-5.332c5.392-0.059 8.5 3.4 8.5 3.436c1.304 1.4 2.1 0.5 2.133-0.12 c0.06-0.591-0.058-1.183-0.531-1.776C104.121 23.1 102 20.3 95.5 19.6"></path>      <path class="logo-path" d="M124.084 20.618c-1.126 0-1.185 1.067-1.185 1.067v15.166h-14.336V21.862 c0 0 0.296-1.42-1.305-1.362c-1.304 0.047-1.067 1.42-1.067 1.42v14.575h-0.889c0 0-1.303-0.06-1.303 1.2 c0 1.3 1.2 1.3 1.2 1.305h1.007v5.746c0 0 0 1.2 1.2 1.243c1.246 0 1.187-1.184 1.187-1.184v-5.984h14.1v6.103 c0 0-0.008 1.1 1.2 1.137c1.226 0 1.269-1.195 1.269-1.195V21.743C125.209 21.7 125.2 20.6 124.1 20.6"></path>      <path class="logo-path" d="M86.101 44.016c0 0-10.841-21.504-11.849-23.163c-1.007-1.66-2.072 0-2.072 0 l-8.047 15.604l-2.395 0.015c-0.888 0-0.982 0.633-0.982 1.284c0 1.1 1.1 0.9 1.1 0.929h1.067c0 0-2.447 4.637-2.726 5.3 c-0.355 0.889-0.416 1.5 0.5 1.955c1.008 0.5 1.659-0.77 1.659-0.77l3.436-6.399H80.71l2.903 5.9 c0 0 1 2 2.1 1.305C86.87 45.3 86.1 44 86.1 44 M66.965 36.374l5.984-12.026c0 0 0.296-0.475 0.6 0.1 c0.296 0.5 6 12 6 11.967H66.965z"></path>      <path class="logo-path" d="M58.314 34.283c0 0 3.87-1.954 3.87-6.575c0-4.622-4.563-7.199-8.294-7.199 h-6.517c0 0-1.512 0.2-1.512 1.744v10.479h-1.833c0 0-0.799-0.094-0.799 1.271c0 1.1 0.6 1.2 0.6 1.173h2.066v9.447 c0 0-0.046 1.5 1.5 1.48h7.213c0 0 6.016-0.165 6.016-6.837C60.57 35.9 58.3 34.3 58.3 34.3 M48.203 22.7 l6.338-0.005c1.718 0 5.1 1.7 5.1 5.451c0 4.443-5.095 4.501-5.095 4.501h-6.338V22.736z M53.557 43.831h-5.351v-8.748 l6.435-0.008c0.858 0 3.5 0.9 3.5 4.031C58.143 43.7 53.6 43.8 53.6 43.8"></path>      <path class="logo-path" d="M146.17 23.033c0 0 1.3 0.1 1.305-1.304c0-1.244-1.305-1.125-1.305-1.125 h-15.818c-2.251 0-2.012 1.717-2.012 1.717V36.54l-1.653 0.009c0 0-1.132 0.229-1.132 1.177c0 1.2 1.1 1.4 1.1 1.361h1.669 v4.917c0 2.5 1.7 2.1 1.7 2.073h15.818c0 0 0.9 0 0.889-1.185s-0.95-1.007-0.95-1.007h-14.798v-4.799h15.284 c0 0 0.937-0.177 0.937-1.361c0-1.186-1.125-1.246-1.125-1.246h-15.228V23.033H146.17z"></path>    </g>  </defs></svg>  <!--<script type="text/javascript" xmlns:th="http://www.thymeleaf.org" th:fragment="body">-->  <!--(function () {-->    <!--var em = document.createElement(\'script\');-->    <!--em.type = \'text/javascript\';-->    <!--em.async = true;-->    <!--em.src =-->      <!--(\'https:\' == document.location.protocol ? \'https://me-ssl\' : \'http://me-cdn\') + \'.effectivemeasure.net/em.js\';-->    <!--var s = document.getElementsByTagName(\'script\')[0];-->    <!--s.parentNode.insertBefore(em, s);-->  <!--}());--><!--</script>-->  <div class="">    <header class="header">      <!-- DESKTOP ADS BLOCK -->      <!-- DESKTOP ADS BLOCK -->      <!-- MOBILE ADS BLOCK -->                  <!-- MOBILE ADS BLOCK -->      <div class="header__top-for-mobile">        <div class="top-bar__triggers">          <a class="main-menu-trigger fa fa-bars fa-2x" href="#main-menu" style="float: right;"></a>          <!-- Logo -->          <div class="header__logo header-logo-margins" onclick="window.location.href=\'/countries/sa\'">              <svg viewBox="0 0 494.387 190.555">    <use xlink:href="#logo-white"></use>  </svg>            </div>          <a class="countries-menu-trigger header-country-margins" href="#countries-menu">            <span>السعودية</span>            <span class="fa fa-caret-down fa-4x"></span>          </a>          <!-- ngRepeat: image in images --><img ng-repeat="image in images" src="/assets/ui/images/mobile-logo-G20.png" class="ng-scope"><!-- end ngRepeat: image in images --><img ng-repeat="image in images" src="/assets/ui/images/mobile-logo-vision.png" class="ng-scope"><!-- end ngRepeat: image in images -->          <div class="header__left-side left-search-icon">            <a class="search-trigger js-search-trigger fa fa-search fa-2x" href="javascript:;" style="float: left;">            </a>          </div>        </div>        <!-- Search -->        <div class="search js-search" id="search">          <i class="fa fa-search fa-2x search__icon"></i>          <angucomplete-alt id="autocomplete__companies" input-class="search__input" minlength="1" ng-controller="AutocompleteController" pause="400" placeholder="اكتب كلمة البحث أو رمز الشركة" selected-object="selectItem" text-no-results="عفواً, لم يتم العثور على أي نتائج" text-searching="جارٍ البحث..." title-field="label" remote-url="/api/1/companySearch?query=" class="ng-scope ng-isolate-scope"><div class="angucomplete-holder" ng-class="{\'angucomplete-dropdown-visible\': showDropdown}">  <input id="autocomplete__companies_value" ng-model="searchStr" ng-disabled="disableInput" type="" placeholder="اكتب كلمة البحث أو رمز الشركة" maxlength="524288" ng-focus="onFocusHandler()" class="search__input ng-valid-maxlength" ng-blur="hideResults($event)" autocapitalize="off" autocorrect="off" autocomplete="off" ng-change="inputChangeHandler(searchStr)">  <div id="autocomplete__companies_dropdown" class="angucomplete-dropdown ng-hide" ng-show="showDropdown"><div class="angucomplete-searching ng-hide" ng-show="searching"><div class="spinner"><div class="dot1"></div><div class="dot2"></div></div></div>    <div class="angucomplete-searching ng-binding" ng-show="!searching &amp;&amp; (!results || results.length == 0)" ng-bind="textNoResults">عفواً, لم يتم العثور على أي نتائج</div>    <!-- ngRepeat: result in results -->  </div></div></angucomplete-alt>        </div>      </div>      <div class="header-desktop mi-show-for-large-up">        <div class="header__top-for-desktop">          <div class="header__top-for-desktop-row">            <a class="header__other-site" href="http://tawasul.mubasher.info/" target="_blank">              <i class="fa fa-caret-right fa-2x"></i>              تواصل            </a>            <a class="header__other-site" href="http://magazine.mubasher.info/" target="_blank">              <i class="fa fa-caret-right fa-2x"></i>              مجلة مباشر            </a>            <a class="header__other-site" href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">              <i class="fa fa-play-circle"></i>              <div style="direction: ltr; display: inline-block;">TV مباشر</div>            </a>                        <a class="header__other-site" href="/contact">              <i class="fa fa-envelope"></i>              اتصل بنا            </a>            <a class="header__other-site" href="/advertise">              <i class="fa fa-envelope"></i>              اعلن معنا            </a>            <!-- <a th:if="${#locale.getLanguage() == \'ar\'}" class="header__login-button" style="background: #458D37 !important;" th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank"                th:text="#{components.header.decypha}">ديسيفا</a>            <a th:if="${#locale.getLanguage() == \'en\'}" class="header__login-button" style="background: #458D37 !important; font-family: Roboto,sans-serif !important;" th:href="${@url.to(\'PPC#decyphaPackages\')}" target="_blank"                th:text="#{components.header.decypha}">ديسيفا</a> -->            <!-- Page Content Buttons -->            <a class="header__login-button" ng-click="decypha(\'decypha\')" style="background: #458D37 !important; font-family: Roboto,sans-serif !important;">ديسيفا</a>            <!-- Page Content Button -->            <!--Add according to MFP-187-->            <a class="header__login-button" style="background: #00c2d6 !important;" target="_blank" href="https://contest.mubasher.info/#/home">المستثمر اﻷول</a>                        <style>              /*.pulse-logo{*/              /*display: inline-block;*/              /*width: 252px;*/              /*height: 100%;*/              /*background: #212121 url(../images/pulse-logo.png) no-repeat center 2px;*/              /*padding: 10px 50px 29px;*/              /*text-align: center;*/              /*color: black;*/              /*text-decoration: none;*/              /*margin-top: -6px;*/              /*}*/              .pulse-logo2{                padding: 5px 5px 4px;                min-width: 82px;                min-height: 21px;                max-width: 27%;              }            </style>            <a target="_blank" href="https://pulse.mubasher.info">              <img class="pulse-logo2" src="../../../images/pulse-logo.png">            </a>            <span class="header__spacer">              &nbsp;            </span>            <a class="header__social-link" target="_blank" href="https://twitter.com/mubasher"><i class="fa fa-twitter fa-lg"></i></a>            <a class="header__social-link" href="https://www.facebook.com/Mubasher.Info"><i class="fa fa-facebook fa-lg"></i></a>            <a class="header__social-link" href="https://www.youtube.com/channel/UC7hnxb7gD4nKZdZk3ZlZCYg">              <i class="fa fa-youtube fa-lg"></i>            </a>            <a class="header__social-link" href="https://www.linkedin.com/company/1477149">              <i class="fa fa-linkedin fa-lg"></i>            </a>            <a class="header__social-link" href="/news/rss"><i class="fa fa-rss fa-lg"></i></a>            <a class="header__social-link" href="https://play.google.com/store/apps/details?id=net.mis.mubasherinfo">              <i class="fa fa-android fa-lg"></i>            </a>            <a class="header__social-link" href="https://itunes.apple.com/app/imubasher/id494539772?mt=8">              <i class="fa fa-apple fa-lg"></i>            </a>            <a class="header__login-button" href="/account/login">              دخول              <i class="fa fa-user fa-lg"></i>            </a>                                    <a class="header__language" href="https://english.mubasher.info">              <span>ENGLISH</span>            </a>          </div>        </div>        <div class="header__columns">          <div class="header__column1">            <!-- Logo -->            <div class="header__logo-wrapper">              <div class="header__logo" onclick="window.location.href=\'/countries/sa\'">                  <svg viewBox="0 0 494.387 190.555">    <use xlink:href="#logo"></use>  </svg>                </div>              <div class="countries-menu-trigger">                <a href="javascript:;" id="mi-js-countries-menu-trigger">                  <span>السعودية</span>                  <span class="fa fa-caret-down"></span>                </a>                <nav class="header__countries-menu--desktop mi-js-countries-menu-desktop" style="">                  <ul>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=ae&amp;url=/countries/sa/companies">الإمارات</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=bh&amp;url=/countries/sa/companies">البحرين</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=om&amp;url=/countries/sa/companies">عُمان</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=qa&amp;url=/countries/sa/companies">قطر</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=kw&amp;url=/countries/sa/companies">الكويت</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=eg&amp;url=/countries/sa/companies">مصر</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=jo&amp;url=/countries/sa/companies">الأردن</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=tn&amp;url=/countries/sa/companies">تونس</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=ma&amp;url=/countries/sa/companies">المغرب</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=ps&amp;url=/countries/sa/companies">فلسطين</a>                    </li>                    <li class="header__country-selector--desktop__country">                      <a href="/change-country?to=iq&amp;url=/countries/sa/companies">العراق</a>                    </li>                  </ul>                </nav>              </div>            </div>            <!--Market Status -->            <div class="header__market-status">              <div class="header__market-status-column">                <div class="header__market-status-row">                  <a class="header__market-name" href="/markets/TDWL">TDWL</a>                  <span class="header__market-status--close">مغلق</span>                </div>                              </div>              <span class="header__market-time">12 أغسطس 04:49 م</span>            </div>          </div>          <div class="header__column1 banner-logo-desktop" ng-class="{\'banner-desktop-en\':(getLanguage == \'en\')}">            <!-- Logo -->            <div class="header__logo-wrapper">              <!-- ngRepeat: image in images --><div class="header__logo ng-scope" ng-repeat="image in images">                  <div class="tooltip tooltipstered"><img src="/assets/ui/images/logo-G20.png">                    <span class="tooltiptext ng-binding" ng-class="{\'tooltip-desktop-en\':(getLanguage == \'en\')}" style="left: 95%">مجموعة العشرين 2020</span>                  </div>              </div><!-- end ngRepeat: image in images --><div class="header__logo ng-scope" ng-repeat="image in images">                  <div class="tooltip tooltipstered"><img src="/assets/ui/images/logo-vision.png">                    <span class="tooltiptext ng-binding" ng-class="{\'tooltip-desktop-en\':(getLanguage == \'en\')}" style="left: 95%">رؤية المملكة العربية السعودية 2030</span>                  </div>              </div><!-- end ngRepeat: image in images -->            </div>          </div><!--          <div class="header__column2">             &lt;!&ndash;<div th:replace="components/ads/news/dfp/desktop/LB2"/>&ndash;&gt;            &lt;!&ndash;=====to display default leaderboard ad-slot [728,90] ======&ndash;&gt;            <div th:if="${isHomePage}">              <div th:replace="components/ads/home/leaderboard"/>            </div>            <div th:unless="${isHomePage}">              <div>                <iframe id="leaderboard-ros-001" style="width: 736px; height: 108px;" class="ad-iframe" src="/ads/LB2"></iframe>              </div>            </div>            </div>-->           <!--======= billboard 790x250 ============ -->        </div>        <nav class="header__navigation mi-js-desktop-menu-container">          <ul class="dl-menu mi-show-for-large-up mi-js-desktop-menu">            <li class="dl-menu__menu-item dl-menu__menu-item--iconic-item">              <a href="/countries/sa">                <i class="fa fa-home fa-2x"></i>              </a>            </li>            <li class="dl-menu__menu-item" id="markets">              <a href="javascript:;">الأسواق</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/markets/TDWL">سوق الأسهم السعودي</a>                    </li>                    <li>                      <a href="/markets/EGX">البورصة المصرية</a>                    </li>                    <li>                      <a href="/markets/DFM">سوق دبي المالي</a>                    </li>                    <li>                      <a href="/markets/ADX">سوق أبوظبي</a>                    </li>                    <li>                      <a href="/markets/BB">بورصة البحرين</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/markets/QE">بورصة قطر</a>                    </li>                    <li>                      <a href="/markets/MSM">سوق مسقط</a>                    </li>                    <li>                      <a href="/markets/BK">سوق الكويت</a>                    </li>                    <li>                      <a href="/markets/ASE">بورصة عمان</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/markets/CSE">سوق الدار البيضاء</a>                    </li>                    <li>                      <a href="/markets/BDT">بورصة تونس</a>                    </li>                    <li>                      <a href="/markets/PEX">سوق فلسطين</a>                    </li>                    <li>                      <a href="/markets/ISX">سوق العراق</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/international-indices">مؤشرات الأسواق العالمية</a>                    </li>                    <li>                      <a href="/markets/commodities-prices">أسعار المعادن والطاقة</a>                    </li>                    <li>                      <a href="/countries/sa/currencies">أسعار العملات</a>                    </li>                    <!--<li>                      <a th:href="${@url.to(\'RMPC#regionalMap\')}"                         th:text="#{navigation.markets.regional-map}"/>                    </li>-->                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item" id="news">              <a href="javascript:;">الأخبار</a>              <div class="mi-js-submenu">                <ul class="dl-submenu">                  <li>                    <a href="javascript:;">يحدث الآن</a>                    <div class="nav-column">                      <h3>يحدث الآن</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/sa/now/top">أهم الأخبار</a>                        </li>                        <li>                          <a href="/news/sa/now/exclusive">حصرياً مباشر</a>                        </li>                        <li>                          <a href="/news/sa/now/latest">آخر الأخبار</a>                        </li>                                                  <li>                            <a href="/news/sa/now/announcements">إعلانات السوق</a>                          </li>                                                                          <li class="global__hide-for-ltr">                          <a href="/news/sa/now/popular">منتشر الآن</a>                        </li>                        <li>                          <a href="/news/sa/now/trending/">الأكثر مشاركة</a>                        </li>                        <li>                          <a href="/news/now/news-releases">بيانات صحفية</a>                        </li>                        <li>                          <a href="/news/international/misc">أخبار منوعة</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">نبض السوق</a>                    <div class="nav-column">                      <h3>نبض السوق</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/sa/pulse/stocks">أخبار الأسهم</a>                        </li>                        <li>                          <a href="/news/sa/pulse/analysis">تحليلات إخبارية</a>                        </li>                        <li>                          <a href="/news/sa/pulse/local">اقتصاد محلي</a>                        </li>                        <li>                          <a href="/news/sa/pulse/recommendations">توصيات</a>                        </li>                      </ul>                      <h3>أخبار القطاعات</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/sa/category/banking">بنوك</a>                        </li><li>                          <a href="/news/sa/category/realEstate">عقارات</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">أخبار الدول</a>                    <div class="nav-column">                      <h3>أخبار الدول</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/eg/now/latest">مصر</a>                        </li>                        <li>                          <a href="/news/sa/now/latest">السعودية</a>                        </li>                        <li>                          <a href="/news/ae/now/latest">الإمارات</a>                        </li>                        <li>                          <a href="/news/bh/now/latest">البحرين</a>                        </li>                        <li>                          <a href="/news/qa/now/latest">قطر</a>                        </li>                        <li>                          <a href="/news/om/now/latest">عمان</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">أخبار الدول</a>                    <div class="nav-column">                      <h3 class="invisible">أخبار الدول</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/kw/now/latest">الكويت</a>                        </li>                        <li>                          <a href="/news/jo/now/latest">الأردن</a>                        </li>                        <li>                          <a href="/news/ma/now/latest">المغرب</a>                        </li>                        <li>                          <a href="/news/tn/now/latest">تونس</a>                        </li>                        <li>                          <a href="/news/ps/now/latest">فلسطين</a>                        </li>                        <li>                          <a href="/news/iq/now/latest">العراق</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">أخبار إقليمية</a>                    <div class="nav-column">                      <h3>أخبار إقليمية</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/regions/gulf">الخليج</a>                        </li>                        <li>                          <a href="/news/regions/levant">الشام</a>                        </li>                        <li>                          <a href="/news/regions/north-africa">شمال أفريقيا</a>                        </li>                        <li>                          <a href="/news/regions/middle-east">الشرق الأوسط</a>                        </li>                      </ul>                    </div>                  </li>                  <li>                    <a href="javascript:;">أخبار عالمية</a>                    <div class="nav-column">                      <h3>أخبار عالمية</h3>                      <ul class="dl-submenu">                        <li>                          <a href="/news/international/global-economy">اقتصاد عالمى</a>                        </li>                        <li>                          <a href="/news/international/goods-and-metals">أحداث عالمية</a>                        </li>                        <li>                          <a href="/news/international/global-indices">مؤشرات عالمية</a>                        </li>                        <li>                          <a href="/news/international/oil-and-energy">نفط ومعادن</a>                        </li>                        <li>                          <a href="/news/international/currencies">عملات</a>                        </li>                        <li>                          <a href="/news/international/global-reports">تقارير عالمية</a>                        </li>                      </ul>                    </div>                  </li>                </ul>              </div>            </li>            <li class="dl-menu__menu-item" id="companies">              <a href="javascript:;">الشركات</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <h3 class="invisible">.</h3>                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/companies">الشركات المدرجة</a>                    </li>                    <li>                      <a href="/countries/sa/events">مفكرة الشركات</a>                    </li>                    <li>                      <a href="/countries/sa/stock-prices">أسعار الأسهم</a>                    </li>                    <li>                      <a href="/countries/sa/fair-values">القيم العادلة</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <h3 class="invisible">.</h3>                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/earnings">إعلانات الأرباح</a>                    </li>                    <li>                      <a href="/countries/sa/corporate-action">الإجراءات</a>                    </li>                                        <li>                      <a href="/countries/sa/major-shareholders">كبار الملاك</a>                    </li>                    <li>                      <a href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <h3>الاكتتابات</h3>                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/ipos">قائمة الإكتتابات</a>                    </li>                    <li>                      <a href="/ipo/list">بحث فى الاكتتابات</a>                    </li>                    <li>                      <a href="/ipos/news">أخبار الاكتتابات</a>                    </li>                    <li>                      <a href="/ipo/calendar">مفكرة الاكتتابات</a>                    </li>                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item" id="funds">              <a href="javascript:;">صناديق الاستثمار</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/funds">صناديق الاستثمار</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/countries/sa/funds-statistics">إحصائيات الصناديق</a>                    </li>                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item" id="analysis-tools">              <a href="javascript:;">أدوات التحليل</a>              <!-- If current country has one market only -->              <div class="mi-js-submenu">                                  <div class="nav-column">                    <ul class="dl-submenu">                      <li>                        <a href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>                      </li>                      <li>                        <a href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>                      </li>                      <li>                        <a href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>                      </li>                    </ul>                  </div>                  <div class="nav-column">                    <ul class="dl-submenu">                      <li>                        <a href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>                      </li>                      <li>                        <a href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>                      </li>                      <li>                        <a href="/analysis-tools/performance-comparison">مقارنة الأداء</a>                      </li>                    </ul>                  </div>                                              </div>            </li>            <li class="dl-menu__menu-item" id="islamic-economy">              <a href="/news/islamic-finance">الاقتصاد الإسلامي</a>            </li>            <!--<li id="radio"                class="dl-menu__menu-item global__hide-for-ltr"                id="radio"                th:if="${#locale.getLanguage() == \'ar\'}">              <a href="javascript:;" th:text="#{navigation.radio}"/>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a th:href="${@url.to(\'RPC#live\')}" th:text="#{navigation.radio.live}"/>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#latestEpisodesPage\', countryCode)}">آخر الحلقات</a>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تقارير-اقتصادية\'}">تقارير                        اقتصادية</a>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'تغطية-خاصة\'}">تغطية خاصة</a>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#searchRadioProgram\') + \'مقالات\'}">مقالات</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a th:href="${@url.to(\'RPC#programs\')}" th:text="#{navigation.radio.programs}"/>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#videoPrograms\')}" th:text="#{navigation.radio.videoPrograms}"/>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#getExperts\')}">ضيوفنا</a>                    </li>                    <li>                      <a th:href="${@url.to(\'RPC#getPresenters\')}">المذيعون</a>                    </li>                  </ul>                </div>              </div>            </li>-->            <li class="dl-menu__menu-item global__hide-for-ltr" id="video">              <a href="/mubashertv/آخر-الحلقات?playlistId=PL2c0DZc94_Hql725VckPjSeAIaHq6SbBt">مباشر TV</a>            </li>                        <li class="dl-menu__menu-item" id="fixedincome">              <a href="javascript:;">السندات</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/fixedincome/bond/search" id="fixedIncomeBondScreener">بحث عن سندات</a>                    </li>                    <li>                      <a href="/fixed-income/news" id="fixedIncomeNews">أخبار السندات وأذون الخزانة</a>                    </li>                    <li>                      <a href="/fixedincome/calendar/searchForEvent" id="fixedIncomeCalendar">قائمة الأحداث</a>                    </li>                  </ul>                </div>                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/fixedincome/analytics/drawCurve" id="fixedIncomeAnalytics">تحليلات فنية</a>                    </li>                    <li>                      <a href="/fixedincome/leagueTables/view" id="fixedIncomeLeagueTables">جداول الديون</a>                    </li>                    <li>                      <a href="/fixedincome/research/search" id="fixedIncomeProspectus">تقارير</a>                    </li>                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item" id="personal">              <a href="javascript:;">شخصي</a>              <div class="mi-js-submenu">                <div class="nav-column">                  <ul class="dl-submenu">                    <li>                      <a href="/my/alerts">التنبيهات</a>                    </li>                    <li>                      <a href="/my/watch-list">أسهمي</a>                    </li>                    <li>                      <a href="/my/newsletters">النشرة البريدية</a>                    </li>                  </ul>                </div>              </div>            </li>            <li class="dl-menu__menu-item dl-menu__menu-item--iconic-item">              <a class="js-search-trigger" href="javascript:;">                <i class="fa fa-search fa-2x"></i>              </a>            </li>          </ul>          <!-- Search -->          <div class="search js-search js-desktop-search" id="search">            <angucomplete-alt id="autocomplete__companies" input-class="search__input" minlength="1" ng-controller="AutocompleteController" pause="400" selected-object="selectItem" text-no-results="عفواً, لم يتم العثور على أي نتائج" text-searching="جارٍ البحث..." title-field="label" remote-url="/api/1/companySearch?query=" placeholder="اكتب كلمة البحث أو رمز الشركة" class="ng-scope ng-isolate-scope"><div class="angucomplete-holder" ng-class="{\'angucomplete-dropdown-visible\': showDropdown}">  <input id="autocomplete__companies_value" ng-model="searchStr" ng-disabled="disableInput" type="" placeholder="اكتب كلمة البحث أو رمز الشركة" maxlength="524288" ng-focus="onFocusHandler()" class="search__input ng-valid-maxlength" ng-blur="hideResults($event)" autocapitalize="off" autocorrect="off" autocomplete="off" ng-change="inputChangeHandler(searchStr)">  <div id="autocomplete__companies_dropdown" class="angucomplete-dropdown ng-hide" ng-show="showDropdown"><div class="angucomplete-searching ng-hide" ng-show="searching"><div class="spinner"><div class="dot1"></div><div class="dot2"></div></div></div>    <div class="angucomplete-searching ng-binding" ng-show="!searching &amp;&amp; (!results || results.length == 0)" ng-bind="textNoResults">عفواً, لم يتم العثور على أي نتائج</div>    <!-- ngRepeat: result in results -->  </div></div></angucomplete-alt>            <i class="fa fa-search fa-2x"></i>          </div>        </nav>      </div>    </header>    <div id="Leaderboard">    </div>    <div></div>    <div class="mi-content">      <div>  <!--<div th:replace="components/ads/internal/mobile-banner" />-->  <main class="mi-main-content">      <h1 class="mi-section__title">الشركات المدرجة</h1>  <div class="mi-table-container ng-scope" ng-controller="PagedTableController as table" country="sa" src="/api/1/listed-companies">    <div class="global__table-container md-whiteframe-z1 ng-isolate-scope" st-init="" st-pipe="fetch" st-table="table.data">      <span class="global__no-results ng-hide" ng-show="table.rows.length == 0 &amp;&amp; table.loaded">عفواّ, لم نعثر على أى نتائج</span>      <table class="mi-table" ng-hide="!table.loaded || table.rows.length == 0" style="">        <thead class="mi-table__thead">          <tr class="mi-table__thead-tr">            <th st-ratio="20" style="width: 20%;">الشركة</th>            <th>السهم</th>            <th class="mi-hide-for-small">القطاع</th>                        <th>آخر سعر</th>            <th>نسبة التغيير</th>            <th class="mi-hide-for-small">آخر تحديث</th>          </tr>        </thead>        <tbody class="mi-table__tbody" ng-hide="table.reloading">          <!-- ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/4012/profile" class="ng-binding" href="/markets/TDWL/stocks/4012/profile">الأصيل</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4012" class="ng-binding" href="/markets/TDWL/stocks/4012">4012</a>            </td>            <td class="mi-hide-for-small ng-binding">السلع طويلة الاجل</td>                        <td class="number ng-binding">56.4</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.88%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/4191/profile" class="ng-binding" href="/markets/TDWL/stocks/4191/profile">أبو معطي</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4191" class="ng-binding" href="/markets/TDWL/stocks/4191">4191</a>            </td>            <td class="mi-hide-for-small ng-binding">تجزئة السلع الكمالية</td>                        <td class="number ng-binding">22.98</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.86%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/9511/profile" class="ng-binding" href="/markets/TDWL/stocks/9511/profile">سمو</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/9511" class="ng-binding" href="/markets/TDWL/stocks/9511">9511</a>            </td>            <td class="mi-hide-for-small ng-binding">إدارة وتطوير العقارات</td>                        <td class="number ng-binding">47.75</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.21%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/9510/profile" class="ng-binding" href="/markets/TDWL/stocks/9510/profile">الوطنية للبناء والتسويق</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/9510" class="ng-binding" href="/markets/TDWL/stocks/9510">9510</a>            </td>            <td class="mi-hide-for-small ng-binding">السلع الرأسمالية</td>                        <td class="number ng-binding">210</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -8.70%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/9501/profile" class="ng-binding" href="/markets/TDWL/stocks/9501/profile">التطويرية الغذائية</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/9501" class="ng-binding" href="/markets/TDWL/stocks/9501">9501</a>            </td>            <td class="mi-hide-for-small ng-binding">الخدمات الإستهلاكية</td>                        <td class="number ng-binding">58.5</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.17%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/9504/profile" class="ng-binding" href="/markets/TDWL/stocks/9504/profile">الصمعاني</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/9504" class="ng-binding" href="/markets/TDWL/stocks/9504">9504</a>            </td>            <td class="mi-hide-for-small ng-binding">الخدمات التجارية والمهنية</td>                        <td class="number ng-binding">73.6</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.14%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/3008/profile" class="ng-binding" href="/markets/TDWL/stocks/3008/profile">الكثيري</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/3008" class="ng-binding" href="/markets/TDWL/stocks/3008">3008</a>            </td>            <td class="mi-hide-for-small ng-binding">المواد الأساسية</td>                        <td class="number ng-binding">109.6</td>            <td class="number ng-binding down" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              -0.72%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/4291/profile" class="ng-binding" href="/markets/TDWL/stocks/4291/profile">الوطنية للتعليم</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/4291" class="ng-binding" href="/markets/TDWL/stocks/4291">4291</a>            </td>            <td class="mi-hide-for-small ng-binding">الخدمات الإستهلاكية</td>                        <td class="number ng-binding">50.9</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              1.60%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index --><tr class="mi-table__tbody-tr ng-scope" ng-repeat="row in table.rows track by $index" style="">            <td>              <a ng-href="/markets/TDWL/stocks/1831/profile" class="ng-binding" href="/markets/TDWL/stocks/1831/profile">مهارة</a>            </td>            <td>              <a ng-href="/markets/TDWL/stocks/1831" class="ng-binding" href="/markets/TDWL/stocks/1831">1831</a>            </td>            <td class="mi-hide-for-small ng-binding">الخدمات التجارية والمهنية</td>                        <td class="number ng-binding">75.3</td>            <td class="number ng-binding up" ng-class="{up:(row.changePercentage > 0), down:(row.changePercentage < 0)}">              0.94%            </td>            <td class="mi-hide-for-small ng-binding">12 أغسطس 2020</td>          </tr><!-- end ngRepeat: row in table.rows track by $index -->        </tbody>      </table>      <div ng-show="table.searcing" class="ng-hide">        <span class="global__loading">جارى التصفية, يرجى الإنتظار ...</span>        <div>    <div class="sk-spinner sk-spinner-wave">        <div class="sk-rect1"></div>        <div class="sk-rect2"></div>        <div class="sk-rect3"></div>        <div class="sk-rect4"></div>        <div class="sk-rect5"></div>    </div></div>      </div>      <div ng-hide="table.loaded" class="ng-hide" style="">        <div>    <div class="sk-spinner sk-spinner-wave">        <div class="sk-rect1"></div>        <div class="sk-rect2"></div>        <div class="sk-rect3"></div>        <div class="sk-rect4"></div>        <div class="sk-rect5"></div>    </div></div>      </div>      <div st-items-by-page="20" st-pagination="" st-template="/assets/ui/ngt/components/pagination/pagination.ng.html" class="ng-isolate-scope"><!-- ngIf: pages.length >= 2 --><div class="pagination ng-scope" ng-if="pages.length >= 2">    <nav role="navigation" aria-label="Pagination">        <ul class="cd-pagination no-space" role="menubar" aria-label="Pagination">            <!-- ngIf: currentPage > 1 --><li ng-if="currentPage > 1" class="ng-scope">                <a ng-click="selectPage(1)">                    <i class="fa fa-angle-double-right fa-lg"></i>                </a>            </li><!-- end ngIf: currentPage > 1 -->            <!-- ngIf: currentPage > 1 --><li class="cd-pagination__button ng-scope" aria-disabled="true" ng-if="currentPage > 1">                <a ng-click="selectPage(currentPage-1)" class="ng-binding">                  <i class="fa fa-lg fa-angle-right"></i>                  السابق                </a>            </li><!-- end ngIf: currentPage > 1 -->            <!-- ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">                <a ng-click="selectPage(page)" class="ng-binding">6</a>            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">                <a ng-click="selectPage(page)" class="ng-binding">7</a>            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">                <a ng-click="selectPage(page)" class="ng-binding">8</a>            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope">                <a ng-click="selectPage(page)" class="ng-binding">9</a>            </li><!-- end ngRepeat: page in pages --><li ng-repeat="page in pages" ng-class="{current: page==currentPage}" class="ng-scope current">                <a ng-click="selectPage(page)" class="ng-binding">10</a>            </li><!-- end ngRepeat: page in pages -->            <!-- ngIf: currentPage < numPages -->            <!-- ngIf: currentPage < numPages -->        </ul>    </nav></div><!-- end ngIf: pages.length >= 2 --></div>    </div>  </div>    <!-- Speakol Widget - Removal IB-51 -->  <!-- <div th:replace="components/ads/common/speakol-one"/> -->  </main>  <aside class="mi-sidebar mi-show-for-large-up">    <!-- Radio component doesn\'t exist in English version -->    <!---->  <!--  <div th:unless="${device.isMobile()}">      <div>        <iframe onload="adjustIframeSize(this);" class="ad-iframe" src="/ads/side-bar"></iframe>      </div>      <script>        function adjustIframeSize(self) {          var index = 0;          var interval = setInterval( function(){            if (index < 3) {              self.style.height=self.contentDocument.body.scrollHeight +10 + \'px\';self.style.width=\'310px\';              index = index + 1;            } else {              clearInterval(interval)            }          }, 1);        }      </script>    </div>-->    <div>    <div class="mi-popular-news news-sidebar-mub md-whiteframe-z1 ng-scope" ng-controller="PopularNewsController as popular">    <h2 class="global__h2--collapsed">الأخبار الأكثر</h2>    <v-tabs active="tabs.active" class="vTabs--secondary ng-isolate-scope" control="tabs">      <!-- ngRepeat: page in popular.pages --><v-tab ng-bind="page.title" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope is-active" role="tab" aria-selected="true" tabindex="0">قراءة</v-tab><!-- end ngRepeat: page in popular.pages --><v-tab ng-bind="page.title" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope" role="tab" aria-selected="false" tabindex="-1">مشاركة</v-tab><!-- end ngRepeat: page in popular.pages -->    </v-tabs>    <v-pages active="tabs.active" class="vPages--default ng-isolate-scope" control="tabs" ng-swipe-left="tabs.next()" ng-swipe-right="tabs.previous()">      <!-- ngRepeat: page in popular.pages --><v-page ng-bind-html="page.content | unsafe" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope is-active" role="tabpanel">        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3680410/%D9%87%D9%8A%D8%A6%D8%A9-%D8%A7%D9%84%D9%86%D9%82%D9%84-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%B5%D8%B1%D9%81-%D8%AF%D8%B9%D9%85-%D8%A7%D9%84%D8%A3%D9%81%D8%B1%D8%A7%D8%AF-%D8%A7%D9%84%D8%B9%D8%A7%D9%85%D9%84%D9%8A%D9%86-%D9%81%D9%8A-%D9%86%D8%B4%D8%A7%D8%B7-%D8%AA%D9%88%D8%AC%D9%8A%D9%87-%D8%A7%D9%84%D9%85%D8%B1%D9%83%D8%A8%D8%A7%D8%AA-%D9%82%D8%B1%D9%8A%D8%A8%D8%A7-/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="فرع تابع لهيئة العامة للنقل السعودية" src="https://static.mubasher.info/File.Story_Image/3e19073c5aca3db54ef2c06eb4bf5ea6/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3680410/%D9%87%D9%8A%D8%A6%D8%A9-%D8%A7%D9%84%D9%86%D9%82%D9%84-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%B5%D8%B1%D9%81-%D8%AF%D8%B9%D9%85-%D8%A7%D9%84%D8%A3%D9%81%D8%B1%D8%A7%D8%AF-%D8%A7%D9%84%D8%B9%D8%A7%D9%85%D9%84%D9%8A%D9%86-%D9%81%D9%8A-%D9%86%D8%B4%D8%A7%D8%B7-%D8%AA%D9%88%D8%AC%D9%8A%D9%87-%D8%A7%D9%84%D9%85%D8%B1%D9%83%D8%A8%D8%A7%D8%AA-%D9%82%D8%B1%D9%8A%D8%A8%D8%A7-/">هيئة النقل السعودية: صرف دعم الأفراد العاملين في نشاط توجيه المركبات قريباً</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3680099/%D8%A7%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D8%B5%D8%AF%D8%B1-%D9%82%D8%B1%D8%A7%D8%B1%D8%A7-%D8%A8%D8%B4%D8%A3%D9%86-%D8%A7%D9%84%D9%85%D8%A8%D8%AA%D8%B9%D8%AB%D9%8A%D9%86/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="وزير التعليم السعودي، حمد بن محمد آل الشيخ، أرشيفية" src="https://static.mubasher.info/File.Story_Image/9e9e9919f67b43d61c15c7fd734289d3/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3680099/%D8%A7%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D8%B5%D8%AF%D8%B1-%D9%82%D8%B1%D8%A7%D8%B1%D8%A7-%D8%A8%D8%B4%D8%A3%D9%86-%D8%A7%D9%84%D9%85%D8%A8%D8%AA%D8%B9%D8%AB%D9%8A%D9%86/">التعليم السعودية تصدر قراراً بشأن المبتعثين</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3680101/%D9%85%D8%AD%D8%AF%D8%AB-%D8%A7%D9%84%D8%B0%D9%87%D8%A8-%D9%8A%D8%AA%D9%87%D8%A7%D9%88%D9%89-93-%D8%AF%D9%88%D9%84%D8%A7%D8%B1%D8%A7-%D8%B9%D9%86%D8%AF-%D8%A7%D9%84%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D9%85%D8%B9-%D9%85%D9%83%D8%A7%D8%B3%D8%A8-%D8%A7%D9%84%D8%A3%D8%B3%D9%87%D9%85/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/caeadbca5bf2481c2d38f04625e51f00/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3680101/%D9%85%D8%AD%D8%AF%D8%AB-%D8%A7%D9%84%D8%B0%D9%87%D8%A8-%D9%8A%D8%AA%D9%87%D8%A7%D9%88%D9%89-93-%D8%AF%D9%88%D9%84%D8%A7%D8%B1%D8%A7-%D8%B9%D9%86%D8%AF-%D8%A7%D9%84%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D9%85%D8%B9-%D9%85%D9%83%D8%A7%D8%B3%D8%A8-%D8%A7%D9%84%D8%A3%D8%B3%D9%87%D9%85/">محدث.. الذهب يتهاوى 93 دولاراً عند التسوية مع مكاسب الأسهم</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3679355/%D8%A7%D9%84%D9%84%D9%8A%D8%B1%D8%A9-%D8%A7%D9%84%D8%AA%D8%B1%D9%83%D9%8A%D8%A9-%D8%AA%D9%87%D8%A8%D8%B7-%D8%A5%D9%84%D9%89-%D9%85%D8%B3%D8%AA%D9%88%D9%89-%D8%AA%D8%A7%D8%B1%D9%8A%D8%AE%D9%8A-%D8%AC%D8%AF%D9%8A%D8%AF/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/1242bfad1995396ce3f6470a3d5584c2/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3679355/%D8%A7%D9%84%D9%84%D9%8A%D8%B1%D8%A9-%D8%A7%D9%84%D8%AA%D8%B1%D9%83%D9%8A%D8%A9-%D8%AA%D9%87%D8%A8%D8%B7-%D8%A5%D9%84%D9%89-%D9%85%D8%B3%D8%AA%D9%88%D9%89-%D8%AA%D8%A7%D8%B1%D9%8A%D8%AE%D9%8A-%D8%AC%D8%AF%D9%8A%D8%AF/">الليرة التركية تهبط إلى مستوى تاريخي جديد</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3679705/%D8%B9%D9%85%D9%84%D8%A9-%D8%A7%D9%84%D8%A8%D9%8A%D8%AA%D9%83%D9%88%D9%8A%D9%86-%D8%AA%D8%B9%D8%A7%D9%88%D8%AF-%D8%A7%D9%84%D8%B5%D8%B9%D9%88%D8%AF-%D8%A3%D8%B9%D9%84%D9%89-12-%D8%A3%D9%84%D9%81-%D8%AF%D9%88%D9%84%D8%A7%D8%B1/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" src="https://static.mubasher.info/File.Story_Image/ab491b6531081c6058fa5b203b6cbecc/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3679705/%D8%B9%D9%85%D9%84%D8%A9-%D8%A7%D9%84%D8%A8%D9%8A%D8%AA%D9%83%D9%88%D9%8A%D9%86-%D8%AA%D8%B9%D8%A7%D9%88%D8%AF-%D8%A7%D9%84%D8%B5%D8%B9%D9%88%D8%AF-%D8%A3%D8%B9%D9%84%D9%89-12-%D8%A3%D9%84%D9%81-%D8%AF%D9%88%D9%84%D8%A7%D8%B1/">عملة البيتكوين تعاود الصعود أعلى 12 ألف دولار</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3679783/%D8%A3%D8%B1%D8%A7%D9%85%D9%83%D9%88-%D8%AA%D8%B1%D9%81%D8%B9-%D8%A3%D8%B3%D8%B9%D8%A7%D8%B1-%D8%A7%D9%84%D8%A8%D9%86%D8%B2%D9%8A%D9%86-%D8%A8%D9%86%D8%AD%D9%88-11-%D8%AD%D8%AA%D9%89-10-%D8%B3%D8%A8%D8%AA%D9%85%D8%A8%D8%B1/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="محطة للتزود بالوقود" src="https://static.mubasher.info/File.Story_Image/cf61a8737c62c57737e53b3677aa2bbc/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3679783/%D8%A3%D8%B1%D8%A7%D9%85%D9%83%D9%88-%D8%AA%D8%B1%D9%81%D8%B9-%D8%A3%D8%B3%D8%B9%D8%A7%D8%B1-%D8%A7%D9%84%D8%A8%D9%86%D8%B2%D9%8A%D9%86-%D8%A8%D9%86%D8%AD%D9%88-11-%D8%AD%D8%AA%D9%89-10-%D8%B3%D8%A8%D8%AA%D9%85%D8%A8%D8%B1/">أرامكو ترفع أسعار البنزين بنحو 11% حتى 10 سبتمبر</a>        </div>              </div>        <!--      <th:block>        <div th:remove="tag" th:if="${i.index == 1}">          <div th:replace="components/ads/internal/native" ></div>          <div th:replace="components/ads/internal/mobile-native" ></div>        </div>      </th:block>-->      <div class="mi-home-media-block">        <a class="mi-home-media-block__image" href="/news/3680546/%D8%A8%D9%803-%D8%B6%D9%88%D8%A7%D8%A8%D8%B7-%D8%A7%D9%84%D8%AA%D9%82%D8%A7%D8%B9%D8%AF-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D9%88%D8%B6%D8%AD-%D8%B7%D8%B1%D9%8A%D9%82%D8%A9-%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D8%A7%D9%84%D9%85%D8%B9%D8%A7%D8%B4-%D9%84%D9%85%D9%88%D8%B8%D9%81%D9%8A-%D8%A7%D9%84%D9%82%D8%B7%D8%A7%D8%B9-%D8%A7%D9%84%D8%B9%D8%A7%D9%85/">          <img onerror="this.src=\'/assets/ui/images/news/news-default.jpg\';" alt="مؤسسة التقاعد السعودية" src="https://static.mubasher.info/File.Story_Image/68cc490a847f0daba3afd0ddbd6d06c8/144.jpg">        </a>        <div class="mi-home-media-block__content">          <a class="mi-home-media-block__title" href="/news/3680546/%D8%A8%D9%803-%D8%B6%D9%88%D8%A7%D8%A8%D8%B7-%D8%A7%D9%84%D8%AA%D9%82%D8%A7%D8%B9%D8%AF-%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D8%A9-%D8%AA%D9%88%D8%B6%D8%AD-%D8%B7%D8%B1%D9%8A%D9%82%D8%A9-%D8%AA%D8%B3%D9%88%D9%8A%D8%A9-%D8%A7%D9%84%D9%85%D8%B9%D8%A7%D8%B4-%D9%84%D9%85%D9%88%D8%B8%D9%81%D9%8A-%D8%A7%D9%84%D9%82%D8%B7%D8%A7%D8%B9-%D8%A7%D9%84%D8%B9%D8%A7%D9%85/">بـ3 ضوابط.. التقاعد السعودية توضح طريقة تسوية المعاش لموظفي القطاع العام</a>        </div>              </div>        <a class="mi-article-widget__more-button" href="/news/SA/now/popular">      <span>المزيد</span>      <i class="fa fa-chevron-left"></i>    </a>    </v-page><!-- end ngRepeat: page in popular.pages --><v-page ng-bind-html="page.content | unsafe" ng-repeat="page in popular.pages" class="ng-binding ng-scope ng-isolate-scope" role="tabpanel">            <a class="mi-article-widget__more-button" href="/news/SA/now/trending/">      <span>المزيد</span>      <i class="fa fa-chevron-left"></i>    </a>    </v-page><!-- end ngRepeat: page in popular.pages -->    </v-pages>  </div>    <div id="MPU">    </div>    </div>    <!-- Speakol Widget - Removal IB-51 -->    <!-- <div th:replace="components/ads/common/speakol-two"/> --><!--    <div th:unless="${device.isMobile()}">      <div th:replace="components/ads/insticator/insticator-widget"/>    </div>-->    <!-- -->    <!-- PS -->    <!--<div th:replace="components/ads/internal/may-like-articles" />-->    <!--<div th:replace="components/ads/internal/second-fold" />-->    <!--    <div th:if="${#locale.getLanguage() == \'ar\'}">          <span class="home__title">راديو مباشر</span>          <div class="internal-radio-carousel-container"></div>        </div>-->  </aside><!--  <div th:replace="components/ads/internal/mobile-fullpage"/>-->  <!--<div th:replace="components/ads/internal/mobile-interstitial"/>--><!--commented out as per Fayoumi\'s request-->  <!--<div th:replace="components/ads/internal/mobile-outstream"/>-->  <!--MFP-228 New Fixed-Replacement-ROS ads--><!--  <div th:replace="components/ads/home/mobile-fixed-replacement"/>  <div th:replace="components/ads/news/dfp/mobile/MPU3"/>--><!--Commented out as per Fayoumi\'s request-->  <!--<div th:replace="components/ads/internal/outstream"/>--><!--  <div th:if="${device.isMobile()}">    <div th:replace="components/ads/dfp/mobile-internal-pages"/>  </div>--><!--  <div th:if="${device.isMobile()}">    <div th:replace="components/ads/insticator/insticator-widget"/>  </div>--> <!-- <div th:replace="components/ads/internal/mobile-above-footer"/>--></div>    </div>    <footer>  <div class="mi-footer">    <div class="mi-show-for-large-up mi-footer__main-menu">      <ul>        <li class="mi-footer__menu-item mi-footer__menu__markets" id="markets">          <div class="mi-footer__menu-level1">الأسواق</div>          <ul>            <h3 class="mi-footer__menu-level2 invisible">الأسواق</h3>            <li>              <a class="mi-footer__menu-level3" href="/markets/TDWL">سوق الأسهم السعودي</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/EGX">البورصة المصرية</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/DFM">سوق دبي المالي</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/ADX">سوق أبوظبي</a>            </li>          </ul>          <ul>            <li>              <a class="mi-footer__menu-level3" href="/markets/BB">بورصة البحرين</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/QE">بورصة قطر</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/MSM">سوق مسقط</a>            </li>          </ul>          <ul>            <li>              <a class="mi-footer__menu-level3" href="/markets/KSE">سوق الكويت</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/ASE">بورصة عمان</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/CSE">سوق الدار البيضاء</a>            </li>          </ul>          <ul>            <li>              <a class="mi-footer__menu-level3" href="/markets/BDT">بورصة تونس</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/PEX">سوق فلسطين</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/ISX">سوق العراق</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/international-indices">مؤشرات الأسواق العالمية</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/markets/commodities-prices">أسعار المعادن والطاقة</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/currencies">أسعار العملات</a>            </li>            <!--<li>              <a class="mi-footer__menu-level3"                 th:href="${@url.to(\'RMPC#regionalMap\')}"                 th:text="#{navigation.markets.regional-map}"/>            </li>-->          </ul>        </li>        <li class="mi-footer__menu-item mi-footer__menu__news" id="news">          <ul>            <div class="mi-footer__menu-level1">الأخبار</div>            <li class="mi-footer__menu__news__submenu">              <h3 class="mi-footer__menu-level2">أخبار الدول</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/eg/now/latest">مصر</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/latest">السعودية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/ae/now/latest">الإمارات</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/bh/now/latest">البحرين</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/qa/now/latest">قطر</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/om/now/latest">عمان</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/kw/now/latest">الكويت</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/jo/now/latest">الأردن</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/ma/now/latest">المغرب</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/tn/now/latest">تونس</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/ps/now/latest">فلسطين</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/iq/now/latest">العراق</a>                </li>              </ul>            </li>            <li class="mi-footer__menu__news__submenu">              <h3 class="mi-footer__menu-level2">أخبار إقليمية</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/regions/gulf">الخليج</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/regions/levant">الشام</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/regions/north-africa">شمال أفريقيا</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/regions/middle-east">الشرق الأوسط</a>                </li>              </ul>              <!-- happening now -->              <h3 class="mi-footer__menu-level2">يحدث الآن</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/top">أهم الأخبار</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/exclusive">حصرياً مباشر</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/latest">آخر الأخبار</a>                </li>                                  <li>                    <a class="mi-footer__menu-level3" href="/news/sa/now/announcements">إعلانات السوق</a>                  </li>                                                  <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/popular">منتشر الآن</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/now/trending/">الأكثر مشاركة</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/now/news-releases">بيانات صحفية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/misc">أخبار منوعة</a>                </li>              </ul>            </li>            <li class="mi-footer__menu__news__submenu">              <h3 class="mi-footer__menu-level2">نبض السوق</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/stocks">أخبار الأسهم</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/analysis">تحليلات إخبارية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/local">اقتصاد محلي</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/pulse/recommendations">توصيات</a>                </li>              </ul>              <h3 class="mi-footer__menu-level2">أخبار القطاعات</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/category/banking">بنوك</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/sa/category/realEstate">عقارات</a>                </li>              </ul>              <h3 class="mi-footer__menu-level2">أخبار عالمية</h3>              <ul>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/global-economy">اقتصاد عالمى</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/goods-and-metals">أحداث عالمية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/global-indices">مؤشرات عالمية</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/oil-and-energy">نفط ومعادن</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/currencies">عملات</a>                </li>                <li>                  <a class="mi-footer__menu-level3" href="/news/international/global-reports">تقارير عالمية</a>                </li>              </ul>            </li>          </ul>        </li>        <li class="mi-footer__menu-item mi-footer__menu__companies" id="companies">          <div class="mi-footer__menu-level1">الشركات</div>          <ul>            <h3 class="mi-footer__menu-level2 invisible">الشركات</h3>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/companies">الشركات المدرجة</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/events">مفكرة الشركات</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/stock-prices">أسعار الأسهم</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/earnings">إعلانات الأرباح</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/fair-values">القيم العادلة</a>            </li>            <li>                          </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/major-shareholders">كبار الملاك</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/ipos/capital-increase">زيادة رأس المال</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/countries/sa/ipos">قائمة الإكتتابات</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/ipo/list">بحث فى الاكتتابات</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/ipos/news">أخبار الاكتتابات</a>            </li>            <li>              <a class="mi-footer__menu-level3" href="/ipo/calendar">مفكرة الاكتتابات</a>            </li>          </ul>        </li>        <li class="mi-footer__menu-item mi-footer__menu__analysis-tools" id="analysis-tools">          <div class="mi-footer__menu-level1">أدوات التحليل</div>          <!-- If current country has one market only -->                      <ul>              <h3 class="mi-footer__menu-level2 invisible">أدوات التحليل</h3>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/most-active-winners/TDWL">إحصائيات الشركات</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/stocks-support-resistance/TDWL">الدعم والمقاومة</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/liquidity-monitor/TDWL">مراقب السيولة</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/volume-monitor/TDWL">مراقب حجم التداول</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/financial-ratios/TDWL">المؤشرات المالية</a>              </li>              <li>                <a class="mi-footer__menu-level3" href="/analysis-tools/performance-comparison">مقارنة الأداء</a>              </li>            </ul>                    <!-- If current country has more than one markets i.e UAE -->                  </li>      </ul>    </div>    <div class="mi-footer__second-fold">      <div class="mi-footer__column1">        <div class="mi-footer__copyright">          <div class="mi-footer__logo" onclick="window.location.href=\'/countries/sa\'">              <svg viewBox="0 0 494.387 190.555">    <use xlink:href="#logo-white"></use>  </svg>            </div>          <span>جميع الحقوق تعود لشركة مباشر العالمية © 2005 - 2020</span>        </div>        <ul class="mi-footer__links">          <li>            <a href="/s/Terms">اتفاقية الاستخدام</a>          </li>          <li>            <a href="/s/disclaimer">إخلاء المسؤولية</a>          </li>          <li>            <a href="/s/aboutus">من نحن</a>          </li>          <li>            <a href="/contact">اتصل بنا</a>          </li>          <li>            <a href="/advertise">أعلن معنا</a>          </li>          <li>            <a href="http://www.decypha.com/" target="_blank">موقع ديسيفا</a>          </li>          <li>            <a href="/ir-services" target="_blank">خدمات المواقع</a>          </li>          <li>            <a href="/s/Jobs">وظائف</a>          </li>          <li>              <a target="_blank" href="/decypha-packages">ديسيفا</a>          </li>          <li>            <a href="/s/privacy-policy" target="_blank">سياسة الخصوصية</a>          </li>          <!--<li th:if="${#locale.getLanguage() == \'en\'}">            <a href="/s/decypha-financial-intelligence" th:text="#{components.footer.decypha-financial-intelligence}">Decypha Financial Intelligence</a>          </li>-->        </ul>        <div>جميع البيانات متأخرة 15 دقيقة أثناء الجلسة</div>        <div>هذا الموقع مرخص من وزراة الثقافة والإعلام السعودية</div>        <div>رقم التسجيل :ت 1 125 1435</div>      </div>      <div class="mi-footer__column2">        <ul class="mi-footer__social-icons">          <li>            <a target="_blank" href="https://twitter.com/mubasher"><i class="fa fa-twitter fa-2x"></i></a>          </li>          <li>            <a href="https://www.facebook.com/Mubasher.Info"><i class="fa fa-facebook fa-2x"></i></a>          </li>          <li>            <a href="https://www.youtube.com/channel/UC7hnxb7gD4nKZdZk3ZlZCYg"><i class="fa fa-youtube fa-2x"></i></a>          </li>          <li>            <a href="https://www.linkedin.com/company/1477149"><i class="fa fa-linkedin fa-2x"></i></a>          </li>          <li>            <a href="/news/rss"><i class="fa fa-rss fa-2x"></i></a>          </li>          <li>            <a href="https://play.google.com/store/apps/details?id=net.mis.mubasherinfo">              <i class="fa fa-android fa-2x"></i></a>          </li>          <li>            <a href="https://itunes.apple.com/app/imubasher/id494539772?mt=8"><i class="fa fa-apple fa-2x"></i></a>          </li>          </ul></div></div></div></footer>          </div>  <script src="//code.jquery.com/jquery-2.1.4.min.js"></script>  <script src="//ajax.googleapis.com/ajax/libs/angularjs/1.3.15/angular.min.js"></script>  <script src="/assets/ui/lib.min.js"></script>  <script src="/assets/ui/main.min.js"></script>  <div id="mi-js-scripts"></div>  <script>    <!-- Fix menu trigger on android browser4 -->    $(".dl-menu__menu-item").click(function () {      $(this).addClass(".dl-menu-item__hoverd");    });    $(document).ready(function () {      $(\'.tooltip\').tooltipster();      setTimeout(function(){ dataLayer.push({event: "triggerAds"});      console.log("triggerAds");      }, 1000);    });  </script>    <div pg-ng-tooltip=""></div></div>  <!-- Twitter universal website tag code -->  <script>    !function(e,t,n,s,u,a){e.twq||(s=e.twq=function(){s.exe?s.exe.apply(s,arguments):s.queue.push(arguments);    },s.version=\'1.1\',s.queue=[],u=t.createElement(n),u.async=!0,u.src=\'//static.ads-twitter.com/uwt.js\',      a=t.getElementsByTagName(n)[0],a.parentNode.insertBefore(u,a))}(window,document,\'script\');    // Insert Twitter Pixel ID and Standard Event data below    twq(\'init\',\'nyana\');    twq(\'track\',\'PageView\');  </script>  <!-- End Twitter universal website tag code --><div id="mm-blocker" class="mm-slideout"></div></body>'
companiesdf = pd.concat(pd.read_html(html, encoding="utf-8")) 
companiesdf = companiesdf.iloc[:, 0:3] # Remove non-relvant columns
companiesdf = companiesdf.reset_index(drop=True)

# %%
stockIds = db["stockIds"]
stockIds.insert_many(companiesdf.to_dict("records"))

# %%
for i, row in companiesdf.iterrows():
    try:
        document = {}
        ticker = yf.Ticker(str(row.loc["السهم"]) + ".SR")
            
        for col in columns:
                if ticker.info.get(col, None) is None: continue
                document.update({col: ticker.info[col]})

        history = ticker.history(period="max")
        history.index = history.index.astype(str)
        document.update({"history": history.to_dict()})

        companies.insert_one(document)
    except Exception as err:
        print(f"\nSkipped\t{str(row)}\nError:\t{err}\n")
# Out:
# - 2370.SR: 1d data not available for startTime=-2208988800 and endTime=1597536430. Only 100 years worth of day granularity data are allowed to be fetched per request.
#
# Skipped	الشركة    زين السعودية
# السهم             7030
# القطاع       الإتصالات
# Name: 110, dtype: object
# Error:	'regularMarketOpen'
#
#
# Skipped	الشركة      أسترا الصناعية
# السهم                 1212
# القطاع    السلع الرأسمالية
# Name: 121, dtype: object
# Error:	'regularMarketOpen'
#
# - 8312.SR: No data found, symbol may be delisted
# - 2222.SR: 1d data not available for startTime=-2208988800 and endTime=1597536607. Only 100 years worth of day granularity data are allowed to be fetched per request.
#
# Skipped	الشركة                   عطاء
# السهم                    4292
# القطاع    الخدمات الإستهلاكية
# Name: 160, dtype: object
# Error:	'regularMarketOpen'
#
#
# Skipped	الشركة             الواحة
# السهم                3007
# القطاع    المواد الأساسية
# Name: 161, dtype: object
# ...

# %%
companies.count_documents({})
# Out:
# 202

# %%
#companies.delete_many({})

# %%
db.command("collstats", "events")
# Out:
# {'ns': 'tadawul.events',
#  'size': 0,
#  'count': 0,
#  'storageSize': 0,
#  'totalSize': 0,
#  'nindexes': 0,
#  'totalIndexSize': 0,
#  'indexDetails': {},
#  'indexSizes': {},
#  'scaleFactor': 1,
#  'ok': 1.0}

# %%
db.command("dbstats")
# Out:
# {'db': 'tadawul',
#  'collections': 3,
#  'views': 0,
#  'objects': 391,
#  'avgObjSize': 147645.81329923274,
#  'dataSize': 57729513.0,
#  'storageSize': 20721664.0,
#  'indexes': 3,
#  'indexSize': 69632.0,
#  'totalSize': 20791296.0,
#  'scaleFactor': 1.0,
#  'fsUsedSize': 797010726912.0,
#  'fsTotalSize': 890696101888.0,
#  'ok': 1.0}

# %%
a = next(companies.find(sort=[("dividendYield", -1)]))

h = a.pop("history")
print(pd.DataFrame(h))
a
# Out:
#              Open   High    Low  Close     Volume  Dividends  Stock Splits
# 2012-01-17  13.30  13.40  13.07  13.13   846547.0        0.0           0.0
# 2012-01-18  13.20  13.66  13.10  13.53  1028786.0        0.0           0.0
# 2012-01-22  13.53  13.53  13.53  13.53        0.0        0.0           0.0
# 2012-01-23  13.53  13.53  13.53  13.53        0.0        0.0           0.0
# 2012-01-24  13.56  13.76  13.50  13.63  1059553.0        0.0           0.0
# ...           ...    ...    ...    ...        ...        ...           ...
# 2020-08-09  21.70  22.22  21.58  22.14   718636.0        0.0           0.0
# 2020-08-10  22.14  22.40  21.96  22.10   426081.0        0.0           0.0
# 2020-08-11  22.12  23.60  22.00  22.82  1959304.0        0.0           0.0
# 2020-08-12  22.86  23.12  22.80  22.98   254740.0        0.0           0.0
# 2020-08-13  22.98  22.98  22.98  22.98        0.0        0.0           0.0
#
# [2113 rows x 7 columns]
# {'_id': ObjectId('5f38793503d4ca362c0da189'),
# ...

# %%
import numpy as np
np.array([[1, 2, 7], [3, 4, 8]]) @ np.array([[1, 2], [3, 9], [4, 16]])
# Out:
# array([[ 35, 132],
#        [ 47, 170]])

# %%
pd.DataFrame(tuple(stockIds.find({})))
# Out:
#                           _id                     الشركة  السهم  \
# 0    5f34e41b91c30b141f7377a7                      سامبا   1090
# 1    5f34e41b91c30b141f7377a8            السعودي الفرنسي   1050
# 2    5f34e41b91c30b141f7377a9                    الجزيرة   1020
# 3    5f34e41b91c30b141f7377aa                     الرياض   1010
# 4    5f34e41b91c30b141f7377ab                        ساب   1060
# 5    5f34e41b91c30b141f7377ac                     العربي   1080
# 6    5f34e41b91c30b141f7377ad                    الراجحي   1120
# 7    5f34e41b91c30b141f7377ae                      سيسكو   2190
# 8    5f34e41b91c30b141f7377af                    المصافي   2030
# 9    5f34e41b91c30b141f7377b0                       زجاج   2150
# 10   5f34e41b91c30b141f7377b1                       نادك   6010
# 11   5f34e41b91c30b141f7377b2                       جاكو   6020
# 12   5f34e41b91c30b141f7377b3              تبوك الزراعية   6040
# 13   5f34e41b91c30b141f7377b4                        دور   4010
# ...
